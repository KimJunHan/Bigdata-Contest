# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# R2 값, 결정계수 계산
from sklearn.metrics import r2_score

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
# w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
w = pd.read_csv('d:/project/contest/data/processed/날씨_ver071915.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '생수'만 빼서 df생성
item = '생수'
grouped_by = 'date'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not','미세', '초미세', '공기상태',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %%
# MAD적용
gs_day_w['outlier'] = pd.DataFrame(mad_based_outlier(gs_day_w['qty']))
gs_day_w = gs_day_w.loc[gs_day_w.outlier==False]

# %%
# list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
list_col = ['temp', 'cloud', 'wind','lgt_time',
            'rain_or_not', 'snow_or_not', '공기상태'] #+'rain_or_not', 'snow_or_not'
lowVIF(w,20,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239620  snow_or_not
# 1    2.479988  rain_or_not
# 2    3.114369         공기상태
# 3    4.013218         temp
# 4    6.725926        cloud
# 5    8.084050     lgt_time
# 6    9.334878         wind

# %%
train_data = gs_day_w.loc[gs_day_w.date.between('2016-01-01','2017-12-31')]
test_data = gs_day_w.loc[gs_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만
combined = gs_day_w.loc[:,list_col]
target = gs_day_w.loc[:,'qty']
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 7
# 오브젝트형 자료 컬럼 갯수 : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
#### 내가 '공기상태'라는 컬럼이 사실은 category형이라는것을 알기에 직접 dummy컬럼 생성
airCondition_dummies = pd.get_dummies(combined['공기상태'],prefix='공기상태')
combined = pd.concat([combined, airCondition_dummies], axis=1)
combined.drop(['공기상태'],axis = 1 , inplace=True)
######################################################################################
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 10 개의 columns이 있었습니다.

# %%
combined.head(2)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
# 1   5.7    7.8   2.0       3.6            0            0       0       1
#
#    공기상태_2  공기상태_3
# 0       1       0
# 1       0       0

# %%
# 공기상태_0,공기상태_1,공기상태_2가 전부 0이면,   공기상태_3이 1이란 소리고
#                                                               공기상태가 '매우나쁨' 임을 추정할수 있다.
# 그런이유로 공기상태_3삭제
combined.drop(['공기상태_3'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
#
#    공기상태_2
# 0       1

# %%
Xy = pd.concat([target,combined], axis=1)
# Xy.head(1)

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 9)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 166,145
# Trainable params: 166,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 582us/step - loss: 10281.4054 - mean_absolute_error: 10281.4054 - val_loss: 9027.7752 - val_mean_absolute_error: 9027.7752
#
# Epoch 00001: val_loss improved from inf to 9027.77518, saving model to 생수date-Weights-001--9027.77518-cat02-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 104us/step - loss: 9763.7397 - mean_absolute_error: 9763.7397 - val_loss: 7248.3327 - val_mean_absolute_error: 7248.3327
#
# Epoch 00002: val_loss improved from 9027.77518 to 7248.33267, saving model to 생수date-Weights-002--7248.33267-cat02-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 80us/step - loss: 4624.5638 - mean_absolute_error: 4624.5638 - val_loss: 2415.2142 - val_mean_absolute_error: 2415.2142
#
# Epoch 00003: val_loss improved from 7248.33267 to 2415.21419, saving model to 생수date-Weights-003--2415.21419-cat02-vf05.hdf5
# Epoch 4/500
# 585/585 [==============================] - 0s 78us/step - loss: 1851.2263 - mean_absolute_error: 1851.2263 - val_loss: 1514.8271 - val_mean_absolute_error: 1514.8271
#
# Epoch 00004: val_loss improved from 2415.21419 to 1514.82712, saving model to 생수date-Weights-004--1514.82712-cat02-vf05.hdf5
# Epoch 5/500
# 585/585 [==============================] - 0s 73us/step - loss: 1600.5953 - mean_absolute_error: 1600.5953 - val_loss: 1377.0535 - val_mean_absolute_error: 1377.0535
#
# Epoch 00005: val_loss improved from 1514.82712 to 1377.05352, saving model to 생수date-Weights-005--1377.05352-cat02-vf05.hdf5
# Epoch 6/500
# 585/585 [==============================] - 0s 80us/step - loss: 1601.8071 - mean_absolute_error: 1601.8071 - val_loss: 1379.4564 - val_mean_absolute_error: 1379.4564
#
# Epoch 00006: val_loss did not improve from 1377.05352
# Epoch 7/500
# 585/585 [==============================] - 0s 90us/step - loss: 1569.8282 - mean_absolute_error: 1569.8282 - val_loss: 1392.0033 - val_mean_absolute_error: 1392.0033
#
# Epoch 00007: val_loss did not improve from 1377.05352
# Epoch 8/500
# 585/585 [==============================] - 0s 97us/step - loss: 1561.5700 - mean_absolute_error: 1561.5700 - val_loss: 1421.9374 - val_mean_absolute_error: 1421.9374
#
# Epoch 00008: val_loss did not improve from 1377.05352
# Epoch 9/500
# 585/585 [==============================] - 0s 94us/step - loss: 1563.7821 - mean_absolute_error: 1563.7821 - val_loss: 1456.6894 - val_mean_absolute_error: 1456.6894
#
# Epoch 00009: val_loss did not improve from 1377.05352
# Epoch 10/500
# 585/585 [==============================] - 0s 90us/step - loss: 1579.2332 - mean_absolute_error: 1579.2332 - val_loss: 1491.8444 - val_mean_absolute_error: 1491.8444
#
# Epoch 00010: val_loss did not improve from 1377.05352
# Epoch 11/500
# 585/585 [==============================] - 0s 82us/step - loss: 1585.4712 - mean_absolute_error: 1585.4712 - val_loss: 1393.9733 - val_mean_absolute_error: 1393.9733
#
# Epoch 00011: val_loss did not improve from 1377.05352
# Epoch 12/500
# 585/585 [==============================] - 0s 84us/step - loss: 1557.2193 - mean_absolute_error: 1557.2193 - val_loss: 1422.8659 - val_mean_absolute_error: 1422.8659
#
# Epoch 00012: val_loss did not improve from 1377.05352
# Epoch 13/500
# 585/585 [==============================] - 0s 92us/step - loss: 1545.4910 - mean_absolute_error: 1545.4910 - val_loss: 1391.1411 - val_mean_absolute_error: 1391.1411
#
# Epoch 00013: val_loss did not improve from 1377.05352
# Epoch 14/500
# 585/585 [==============================] - 0s 89us/step - loss: 1528.2990 - mean_absolute_error: 1528.2990 - val_loss: 1394.2416 - val_mean_absolute_error: 1394.2416
#
# Epoch 00014: val_loss did not improve from 1377.05352
# Epoch 15/500
# 585/585 [==============================] - 0s 92us/step - loss: 1604.1271 - mean_absolute_error: 1604.1271 - val_loss: 1665.9026 - val_mean_absolute_error: 1665.9026
#
# Epoch 00015: val_loss did not improve from 1377.05352
# Epoch 16/500
# 585/585 [==============================] - 0s 92us/step - loss: 1532.7473 - mean_absolute_error: 1532.7473 - val_loss: 1455.0200 - val_mean_absolute_error: 1455.0200
#
# Epoch 00016: val_loss did not improve from 1377.05352
# Epoch 17/500
# 585/585 [==============================] - 0s 87us/step - loss: 1544.5589 - mean_absolute_error: 1544.5589 - val_loss: 1486.7589 - val_mean_absolute_error: 1486.7589
#
# Epoch 00017: val_loss did not improve from 1377.05352
# Epoch 18/500
# 585/585 [==============================] - 0s 85us/step - loss: 1546.3576 - mean_absolute_error: 1546.3576 - val_loss: 1388.0345 - val_mean_absolute_error: 1388.0345
#
# Epoch 00018: val_loss did not improve from 1377.05352
# Epoch 19/500
# 585/585 [==============================] - 0s 85us/step - loss: 1531.3441 - mean_absolute_error: 1531.3441 - val_loss: 1440.6626 - val_mean_absolute_error: 1440.6626
#
# Epoch 00019: val_loss did not improve from 1377.05352
# Epoch 20/500
# 585/585 [==============================] - 0s 94us/step - loss: 1526.0786 - mean_absolute_error: 1526.0786 - val_loss: 1373.7607 - val_mean_absolute_error: 1373.7607
#
# Epoch 00020: val_loss improved from 1377.05352 to 1373.76070, saving model to 생수date-Weights-020--1373.76070-cat02-vf05.hdf5
# Epoch 21/500
# 585/585 [==============================] - 0s 94us/step - loss: 1516.5842 - mean_absolute_error: 1516.5842 - val_loss: 1372.4537 - val_mean_absolute_error: 1372.4537
#
# Epoch 00021: val_loss improved from 1373.76070 to 1372.45369, saving model to 생수date-Weights-021--1372.45369-cat02-vf05.hdf5
# Epoch 22/500
# 585/585 [==============================] - 0s 92us/step - loss: 1522.4791 - mean_absolute_error: 1522.4791 - val_loss: 1318.8745 - val_mean_absolute_error: 1318.8745
#
# Epoch 00022: val_loss improved from 1372.45369 to 1318.87451, saving model to 생수date-Weights-022--1318.87451-cat02-vf05.hdf5
# Epoch 23/500
# 585/585 [==============================] - 0s 90us/step - loss: 1499.7589 - mean_absolute_error: 1499.7589 - val_loss: 1342.7811 - val_mean_absolute_error: 1342.7811
#
# Epoch 00023: val_loss did not improve from 1318.87451
# Epoch 24/500
# 585/585 [==============================] - 0s 92us/step - loss: 1506.1549 - mean_absolute_error: 1506.1549 - val_loss: 1353.7576 - val_mean_absolute_error: 1353.7576
#
# Epoch 00024: val_loss did not improve from 1318.87451
# Epoch 25/500
# 585/585 [==============================] - 0s 102us/step - loss: 1495.3719 - mean_absolute_error: 1495.3719 - val_loss: 1309.1334 - val_mean_absolute_error: 1309.1334
#
# Epoch 00025: val_loss improved from 1318.87451 to 1309.13342, saving model to 생수date-Weights-025--1309.13342-cat02-vf05.hdf5
# Epoch 26/500
# 585/585 [==============================] - 0s 89us/step - loss: 1550.1512 - mean_absolute_error: 1550.1512 - val_loss: 1292.1695 - val_mean_absolute_error: 1292.1695
#
# Epoch 00026: val_loss improved from 1309.13342 to 1292.16947, saving model to 생수date-Weights-026--1292.16947-cat02-vf05.hdf5
# Epoch 27/500
# 585/585 [==============================] - 0s 113us/step - loss: 1495.1660 - mean_absolute_error: 1495.1660 - val_loss: 1298.8786 - val_mean_absolute_error: 1298.8786
#
# Epoch 00027: val_loss did not improve from 1292.16947
# Epoch 28/500
# 585/585 [==============================] - 0s 118us/step - loss: 1538.8682 - mean_absolute_error: 1538.8682 - val_loss: 1370.5589 - val_mean_absolute_error: 1370.5589
#
# Epoch 00028: val_loss did not improve from 1292.16947
# Epoch 29/500
# 585/585 [==============================] - 0s 107us/step - loss: 1489.0999 - mean_absolute_error: 1489.0999 - val_loss: 1411.3252 - val_mean_absolute_error: 1411.3252
#
# Epoch 00029: val_loss did not improve from 1292.16947
# Epoch 30/500
# 585/585 [==============================] - 0s 92us/step - loss: 1471.6223 - mean_absolute_error: 1471.6223 - val_loss: 1365.8923 - val_mean_absolute_error: 1365.8923
#
# Epoch 00030: val_loss did not improve from 1292.16947
# Epoch 31/500
# 585/585 [==============================] - 0s 101us/step - loss: 1493.1915 - mean_absolute_error: 1493.1915 - val_loss: 1345.7243 - val_mean_absolute_error: 1345.7243
#
# Epoch 00031: val_loss did not improve from 1292.16947
# Epoch 32/500
# 585/585 [==============================] - 0s 101us/step - loss: 1521.7370 - mean_absolute_error: 1521.7370 - val_loss: 1464.6033 - val_mean_absolute_error: 1464.6033
#
# Epoch 00032: val_loss did not improve from 1292.16947
# Epoch 33/500
# 585/585 [==============================] - 0s 84us/step - loss: 1476.9706 - mean_absolute_error: 1476.9706 - val_loss: 1351.4841 - val_mean_absolute_error: 1351.4841
#
# Epoch 00033: val_loss did not improve from 1292.16947
# Epoch 34/500
# 585/585 [==============================] - 0s 90us/step - loss: 1493.2971 - mean_absolute_error: 1493.2971 - val_loss: 1531.9203 - val_mean_absolute_error: 1531.9203
#
# Epoch 00034: val_loss did not improve from 1292.16947
# Epoch 35/500
# 585/585 [==============================] - 0s 94us/step - loss: 1510.3231 - mean_absolute_error: 1510.3231 - val_loss: 1385.6142 - val_mean_absolute_error: 1385.6142
#
# Epoch 00035: val_loss did not improve from 1292.16947
# Epoch 36/500
# 585/585 [==============================] - 0s 85us/step - loss: 1494.0543 - mean_absolute_error: 1494.0543 - val_loss: 1393.1872 - val_mean_absolute_error: 1393.1872
#
# Epoch 00036: val_loss did not improve from 1292.16947
# Epoch 37/500
# 585/585 [==============================] - 0s 95us/step - loss: 1453.8925 - mean_absolute_error: 1453.8925 - val_loss: 1299.4526 - val_mean_absolute_error: 1299.4526
#
# Epoch 00037: val_loss did not improve from 1292.16947
# Epoch 38/500
# 585/585 [==============================] - 0s 109us/step - loss: 1451.1025 - mean_absolute_error: 1451.1025 - val_loss: 1318.7174 - val_mean_absolute_error: 1318.7174
#
# Epoch 00038: val_loss did not improve from 1292.16947
# Epoch 39/500
# 585/585 [==============================] - 0s 99us/step - loss: 1439.6030 - mean_absolute_error: 1439.6030 - val_loss: 1322.1206 - val_mean_absolute_error: 1322.1206
#
# Epoch 00039: val_loss did not improve from 1292.16947
# Epoch 40/500
# 585/585 [==============================] - 0s 92us/step - loss: 1446.9788 - mean_absolute_error: 1446.9788 - val_loss: 1307.0093 - val_mean_absolute_error: 1307.0093
#
# Epoch 00040: val_loss did not improve from 1292.16947
# Epoch 41/500
# 585/585 [==============================] - 0s 97us/step - loss: 1436.0442 - mean_absolute_error: 1436.0442 - val_loss: 1370.9985 - val_mean_absolute_error: 1370.9985
#
# Epoch 00041: val_loss did not improve from 1292.16947
# Epoch 42/500
# 585/585 [==============================] - 0s 99us/step - loss: 1450.4021 - mean_absolute_error: 1450.4021 - val_loss: 1247.5954 - val_mean_absolute_error: 1247.5954
#
# Epoch 00042: val_loss improved from 1292.16947 to 1247.59544, saving model to 생수date-Weights-042--1247.59544-cat02-vf05.hdf5
# Epoch 43/500
# 585/585 [==============================] - 0s 99us/step - loss: 1469.0307 - mean_absolute_error: 1469.0307 - val_loss: 1237.7718 - val_mean_absolute_error: 1237.7718
#
# Epoch 00043: val_loss improved from 1247.59544 to 1237.77182, saving model to 생수date-Weights-043--1237.77182-cat02-vf05.hdf5
# Epoch 44/500
# 585/585 [==============================] - 0s 94us/step - loss: 1573.6090 - mean_absolute_error: 1573.6090 - val_loss: 1234.4131 - val_mean_absolute_error: 1234.4131
#
# Epoch 00044: val_loss improved from 1237.77182 to 1234.41313, saving model to 생수date-Weights-044--1234.41313-cat02-vf05.hdf5
# Epoch 45/500
# 585/585 [==============================] - 0s 101us/step - loss: 1499.2083 - mean_absolute_error: 1499.2083 - val_loss: 1233.4651 - val_mean_absolute_error: 1233.4651
#
# Epoch 00045: val_loss improved from 1234.41313 to 1233.46514, saving model to 생수date-Weights-045--1233.46514-cat02-vf05.hdf5
# Epoch 46/500
# 585/585 [==============================] - 0s 107us/step - loss: 1426.1681 - mean_absolute_error: 1426.1681 - val_loss: 1236.7768 - val_mean_absolute_error: 1236.7768
#
# Epoch 00046: val_loss did not improve from 1233.46514
# Epoch 47/500
# 585/585 [==============================] - 0s 113us/step - loss: 1422.8904 - mean_absolute_error: 1422.8904 - val_loss: 1273.4799 - val_mean_absolute_error: 1273.4799
#
# Epoch 00047: val_loss did not improve from 1233.46514
# Epoch 48/500
# 585/585 [==============================] - 0s 95us/step - loss: 1430.8148 - mean_absolute_error: 1430.8148 - val_loss: 1236.7691 - val_mean_absolute_error: 1236.7691
#
# Epoch 00048: val_loss did not improve from 1233.46514
# Epoch 49/500
# 585/585 [==============================] - 0s 113us/step - loss: 1485.6456 - mean_absolute_error: 1485.6456 - val_loss: 1198.1298 - val_mean_absolute_error: 1198.1298
#
# Epoch 00049: val_loss improved from 1233.46514 to 1198.12976, saving model to 생수date-Weights-049--1198.12976-cat02-vf05.hdf5
# Epoch 50/500
# 585/585 [==============================] - 0s 107us/step - loss: 1414.2251 - mean_absolute_error: 1414.2251 - val_loss: 1246.7598 - val_mean_absolute_error: 1246.7598
#
# Epoch 00050: val_loss did not improve from 1198.12976
# Epoch 51/500
# 585/585 [==============================] - 0s 106us/step - loss: 1419.8236 - mean_absolute_error: 1419.8236 - val_loss: 1294.9021 - val_mean_absolute_error: 1294.9021
#
# Epoch 00051: val_loss did not improve from 1198.12976
# Epoch 52/500
# 585/585 [==============================] - 0s 101us/step - loss: 1426.2598 - mean_absolute_error: 1426.2598 - val_loss: 1263.1356 - val_mean_absolute_error: 1263.1356
#
# Epoch 00052: val_loss did not improve from 1198.12976
# Epoch 53/500
# 585/585 [==============================] - 0s 114us/step - loss: 1409.2476 - mean_absolute_error: 1409.2476 - val_loss: 1227.4433 - val_mean_absolute_error: 1227.4433
#
# Epoch 00053: val_loss did not improve from 1198.12976
# Epoch 54/500
# 585/585 [==============================] - 0s 111us/step - loss: 1467.3540 - mean_absolute_error: 1467.3540 - val_loss: 1341.3090 - val_mean_absolute_error: 1341.3090
#
# Epoch 00054: val_loss did not improve from 1198.12976
# Epoch 55/500
# 585/585 [==============================] - 0s 109us/step - loss: 1482.7420 - mean_absolute_error: 1482.7420 - val_loss: 1302.8047 - val_mean_absolute_error: 1302.8047
#
# Epoch 00055: val_loss did not improve from 1198.12976
# Epoch 56/500
# 585/585 [==============================] - 0s 121us/step - loss: 1413.1353 - mean_absolute_error: 1413.1353 - val_loss: 1297.4548 - val_mean_absolute_error: 1297.4548
#
# Epoch 00056: val_loss did not improve from 1198.12976
# Epoch 57/500
# 585/585 [==============================] - 0s 116us/step - loss: 1402.3933 - mean_absolute_error: 1402.3933 - val_loss: 1221.5286 - val_mean_absolute_error: 1221.5286
#
# Epoch 00057: val_loss did not improve from 1198.12976
# Epoch 58/500
# 585/585 [==============================] - 0s 109us/step - loss: 1394.7551 - mean_absolute_error: 1394.7551 - val_loss: 1202.7545 - val_mean_absolute_error: 1202.7545
#
# Epoch 00058: val_loss did not improve from 1198.12976
# Epoch 59/500
# 585/585 [==============================] - 0s 109us/step - loss: 1403.9878 - mean_absolute_error: 1403.9878 - val_loss: 1197.2304 - val_mean_absolute_error: 1197.2304
#
# Epoch 00059: val_loss improved from 1198.12976 to 1197.23039, saving model to 생수date-Weights-059--1197.23039-cat02-vf05.hdf5
# Epoch 60/500
# 585/585 [==============================] - 0s 116us/step - loss: 1446.4744 - mean_absolute_error: 1446.4744 - val_loss: 1217.5471 - val_mean_absolute_error: 1217.5471
#
# Epoch 00060: val_loss did not improve from 1197.23039
# Epoch 61/500
# 585/585 [==============================] - 0s 109us/step - loss: 1390.6857 - mean_absolute_error: 1390.6857 - val_loss: 1299.5053 - val_mean_absolute_error: 1299.5053
#
# Epoch 00061: val_loss did not improve from 1197.23039
# Epoch 62/500
# 585/585 [==============================] - 0s 107us/step - loss: 1384.1705 - mean_absolute_error: 1384.1705 - val_loss: 1202.3499 - val_mean_absolute_error: 1202.3499
#
# Epoch 00062: val_loss did not improve from 1197.23039
# Epoch 63/500
# 585/585 [==============================] - 0s 113us/step - loss: 1392.8324 - mean_absolute_error: 1392.8324 - val_loss: 1363.2654 - val_mean_absolute_error: 1363.2654
#
# Epoch 00063: val_loss did not improve from 1197.23039
# Epoch 64/500
# 585/585 [==============================] - 0s 107us/step - loss: 1385.0552 - mean_absolute_error: 1385.0552 - val_loss: 1264.8317 - val_mean_absolute_error: 1264.8317
#
# Epoch 00064: val_loss did not improve from 1197.23039
# Epoch 65/500
# 585/585 [==============================] - 0s 107us/step - loss: 1379.0084 - mean_absolute_error: 1379.0084 - val_loss: 1227.2426 - val_mean_absolute_error: 1227.2426
#
# Epoch 00065: val_loss did not improve from 1197.23039
# Epoch 66/500
# 585/585 [==============================] - 0s 106us/step - loss: 1383.3791 - mean_absolute_error: 1383.3791 - val_loss: 1283.4919 - val_mean_absolute_error: 1283.4919
#
# Epoch 00066: val_loss did not improve from 1197.23039
# Epoch 67/500
# 585/585 [==============================] - 0s 109us/step - loss: 1381.5655 - mean_absolute_error: 1381.5655 - val_loss: 1281.6849 - val_mean_absolute_error: 1281.6849
#
# Epoch 00067: val_loss did not improve from 1197.23039
# Epoch 68/500
# 585/585 [==============================] - 0s 111us/step - loss: 1375.8885 - mean_absolute_error: 1375.8885 - val_loss: 1322.7816 - val_mean_absolute_error: 1322.7816
#
# Epoch 00068: val_loss did not improve from 1197.23039
# Epoch 69/500
# 585/585 [==============================] - 0s 102us/step - loss: 1388.8938 - mean_absolute_error: 1388.8938 - val_loss: 1328.2070 - val_mean_absolute_error: 1328.2070
#
# Epoch 00069: val_loss did not improve from 1197.23039
# Epoch 70/500
# 585/585 [==============================] - 0s 128us/step - loss: 1381.8580 - mean_absolute_error: 1381.8580 - val_loss: 1244.0879 - val_mean_absolute_error: 1244.0879
#
# Epoch 00070: val_loss did not improve from 1197.23039
# Epoch 71/500
# 585/585 [==============================] - 0s 126us/step - loss: 1401.8404 - mean_absolute_error: 1401.8404 - val_loss: 1270.9542 - val_mean_absolute_error: 1270.9542
#
# Epoch 00071: val_loss did not improve from 1197.23039
# Epoch 72/500
# 585/585 [==============================] - 0s 123us/step - loss: 1409.3221 - mean_absolute_error: 1409.3221 - val_loss: 1457.4115 - val_mean_absolute_error: 1457.4115
#
# Epoch 00072: val_loss did not improve from 1197.23039
# Epoch 73/500
# 585/585 [==============================] - 0s 121us/step - loss: 1413.3109 - mean_absolute_error: 1413.3109 - val_loss: 1212.2162 - val_mean_absolute_error: 1212.2162
#
# Epoch 00073: val_loss did not improve from 1197.23039
# Epoch 74/500
# 585/585 [==============================] - 0s 128us/step - loss: 1386.6123 - mean_absolute_error: 1386.6123 - val_loss: 1243.8599 - val_mean_absolute_error: 1243.8599
#
# Epoch 00074: val_loss did not improve from 1197.23039
# Epoch 75/500
# 585/585 [==============================] - 0s 116us/step - loss: 1355.1833 - mean_absolute_error: 1355.1833 - val_loss: 1228.6467 - val_mean_absolute_error: 1228.6467
#
# Epoch 00075: val_loss did not improve from 1197.23039
# Epoch 76/500
# 585/585 [==============================] - 0s 114us/step - loss: 1400.9031 - mean_absolute_error: 1400.9031 - val_loss: 1476.0219 - val_mean_absolute_error: 1476.0219
#
# Epoch 00076: val_loss did not improve from 1197.23039
# Epoch 77/500
# 585/585 [==============================] - 0s 126us/step - loss: 1387.1896 - mean_absolute_error: 1387.1896 - val_loss: 1155.7970 - val_mean_absolute_error: 1155.7970
#
# Epoch 00077: val_loss improved from 1197.23039 to 1155.79696, saving model to 생수date-Weights-077--1155.79696-cat02-vf05.hdf5
# Epoch 78/500
# 585/585 [==============================] - 0s 113us/step - loss: 1365.4193 - mean_absolute_error: 1365.4193 - val_loss: 1184.9071 - val_mean_absolute_error: 1184.9071
#
# Epoch 00078: val_loss did not improve from 1155.79696
# Epoch 79/500
# 585/585 [==============================] - 0s 118us/step - loss: 1372.3083 - mean_absolute_error: 1372.3083 - val_loss: 1299.3499 - val_mean_absolute_error: 1299.3499
#
# Epoch 00079: val_loss did not improve from 1155.79696
# Epoch 80/500
# 585/585 [==============================] - 0s 124us/step - loss: 1353.6071 - mean_absolute_error: 1353.6071 - val_loss: 1230.8034 - val_mean_absolute_error: 1230.8034
#
# Epoch 00080: val_loss did not improve from 1155.79696
# Epoch 81/500
# 585/585 [==============================] - 0s 121us/step - loss: 1360.5261 - mean_absolute_error: 1360.5261 - val_loss: 1250.1792 - val_mean_absolute_error: 1250.1792
#
# Epoch 00081: val_loss did not improve from 1155.79696
# Epoch 82/500
# 585/585 [==============================] - 0s 128us/step - loss: 1363.4086 - mean_absolute_error: 1363.4086 - val_loss: 1448.6361 - val_mean_absolute_error: 1448.6361
#
# Epoch 00082: val_loss did not improve from 1155.79696
# Epoch 83/500
# 585/585 [==============================] - 0s 126us/step - loss: 1339.9721 - mean_absolute_error: 1339.9721 - val_loss: 1344.4269 - val_mean_absolute_error: 1344.4269
#
# Epoch 00083: val_loss did not improve from 1155.79696
# Epoch 84/500
# 585/585 [==============================] - 0s 128us/step - loss: 1361.6181 - mean_absolute_error: 1361.6181 - val_loss: 1180.9739 - val_mean_absolute_error: 1180.9739
#
# Epoch 00084: val_loss did not improve from 1155.79696
# Epoch 85/500
# 585/585 [==============================] - 0s 130us/step - loss: 1407.6158 - mean_absolute_error: 1407.6158 - val_loss: 1290.0253 - val_mean_absolute_error: 1290.0253
#
# Epoch 00085: val_loss did not improve from 1155.79696
# Epoch 86/500
# 585/585 [==============================] - 0s 133us/step - loss: 1377.7752 - mean_absolute_error: 1377.7752 - val_loss: 1571.9911 - val_mean_absolute_error: 1571.9911
#
# Epoch 00086: val_loss did not improve from 1155.79696
# Epoch 87/500
# 585/585 [==============================] - 0s 116us/step - loss: 1405.9970 - mean_absolute_error: 1405.9970 - val_loss: 1369.9692 - val_mean_absolute_error: 1369.9692
#
# Epoch 00087: val_loss did not improve from 1155.79696
# Epoch 88/500
# 585/585 [==============================] - 0s 118us/step - loss: 1338.3302 - mean_absolute_error: 1338.3302 - val_loss: 1322.5057 - val_mean_absolute_error: 1322.5057
#
# Epoch 00088: val_loss did not improve from 1155.79696
# Epoch 89/500
# 585/585 [==============================] - 0s 107us/step - loss: 1349.1319 - mean_absolute_error: 1349.1319 - val_loss: 1300.3127 - val_mean_absolute_error: 1300.3127
#
# Epoch 00089: val_loss did not improve from 1155.79696
# Epoch 90/500
# 585/585 [==============================] - 0s 116us/step - loss: 1343.1797 - mean_absolute_error: 1343.1797 - val_loss: 1269.9888 - val_mean_absolute_error: 1269.9888
#
# Epoch 00090: val_loss did not improve from 1155.79696
# Epoch 91/500
# 585/585 [==============================] - 0s 116us/step - loss: 1350.2058 - mean_absolute_error: 1350.2058 - val_loss: 1360.5768 - val_mean_absolute_error: 1360.5768
#
# Epoch 00091: val_loss did not improve from 1155.79696
# Epoch 92/500
# 585/585 [==============================] - 0s 118us/step - loss: 1344.1561 - mean_absolute_error: 1344.1561 - val_loss: 1417.7500 - val_mean_absolute_error: 1417.7500
#
# Epoch 00092: val_loss did not improve from 1155.79696
# Epoch 93/500
# 585/585 [==============================] - 0s 119us/step - loss: 1344.1401 - mean_absolute_error: 1344.1401 - val_loss: 1344.1428 - val_mean_absolute_error: 1344.1428
#
# Epoch 00093: val_loss did not improve from 1155.79696
# Epoch 94/500
# 585/585 [==============================] - 0s 116us/step - loss: 1337.5701 - mean_absolute_error: 1337.5701 - val_loss: 1159.7267 - val_mean_absolute_error: 1159.7267
#
# Epoch 00094: val_loss did not improve from 1155.79696
# Epoch 95/500
# 585/585 [==============================] - 0s 119us/step - loss: 1343.7804 - mean_absolute_error: 1343.7804 - val_loss: 1226.9835 - val_mean_absolute_error: 1226.9835
#
# Epoch 00095: val_loss did not improve from 1155.79696
# Epoch 96/500
# 585/585 [==============================] - 0s 145us/step - loss: 1346.4617 - mean_absolute_error: 1346.4617 - val_loss: 1179.3969 - val_mean_absolute_error: 1179.3969
#
# Epoch 00096: val_loss did not improve from 1155.79696
# Epoch 97/500
# 585/585 [==============================] - 0s 114us/step - loss: 1367.2403 - mean_absolute_error: 1367.2403 - val_loss: 1470.7870 - val_mean_absolute_error: 1470.7870
#
# Epoch 00097: val_loss did not improve from 1155.79696
# Epoch 98/500
# 585/585 [==============================] - 0s 114us/step - loss: 1341.2154 - mean_absolute_error: 1341.2154 - val_loss: 1408.3713 - val_mean_absolute_error: 1408.3713
#
# Epoch 00098: val_loss did not improve from 1155.79696
# Epoch 99/500
# 585/585 [==============================] - 0s 130us/step - loss: 1331.2591 - mean_absolute_error: 1331.2591 - val_loss: 1602.9096 - val_mean_absolute_error: 1602.9096
#
# Epoch 00099: val_loss did not improve from 1155.79696
# Epoch 100/500
# 585/585 [==============================] - 0s 111us/step - loss: 1354.7700 - mean_absolute_error: 1354.7700 - val_loss: 1215.4980 - val_mean_absolute_error: 1215.4980
# Epoch 00100: val_loss did not improve from 1155.79696
# Epoch 101/500
# 585/585 [==============================] - 0s 133us/step - loss: 1326.5191 - mean_absolute_error: 1326.5191 - val_loss: 1222.1692 - val_mean_absolute_error: 1222.1692
#
# Epoch 00101: val_loss did not improve from 1155.79696
# Epoch 102/500
# 585/585 [==============================] - 0s 116us/step - loss: 1317.9063 - mean_absolute_error: 1317.9063 - val_loss: 1201.4327 - val_mean_absolute_error: 1201.4327
#
# Epoch 00102: val_loss did not improve from 1155.79696
# Epoch 103/500
# 585/585 [==============================] - 0s 142us/step - loss: 1339.4341 - mean_absolute_error: 1339.4341 - val_loss: 1355.3329 - val_mean_absolute_error: 1355.3329
#
# Epoch 00103: val_loss did not improve from 1155.79696
# Epoch 104/500
# 585/585 [==============================] - 0s 135us/step - loss: 1330.1481 - mean_absolute_error: 1330.1481 - val_loss: 1252.2982 - val_mean_absolute_error: 1252.2982
#
# Epoch 00104: val_loss did not improve from 1155.79696
# Epoch 105/500
# 585/585 [==============================] - 0s 135us/step - loss: 1349.0810 - mean_absolute_error: 1349.0810 - val_loss: 1239.1296 - val_mean_absolute_error: 1239.1296
#
# Epoch 00105: val_loss did not improve from 1155.79696
# Epoch 106/500
# 585/585 [==============================] - 0s 148us/step - loss: 1359.4962 - mean_absolute_error: 1359.4962 - val_loss: 1290.1790 - val_mean_absolute_error: 1290.1790
#
# Epoch 00106: val_loss did not improve from 1155.79696
# Epoch 107/500
# 585/585 [==============================] - 0s 148us/step - loss: 1316.6889 - mean_absolute_error: 1316.6889 - val_loss: 1258.5464 - val_mean_absolute_error: 1258.5464
#
# Epoch 00107: val_loss did not improve from 1155.79696
# Epoch 108/500
# 585/585 [==============================] - 0s 135us/step - loss: 1320.9289 - mean_absolute_error: 1320.9289 - val_loss: 1256.7368 - val_mean_absolute_error: 1256.7368
#
# Epoch 00108: val_loss did not improve from 1155.79696
# Epoch 109/500
# 585/585 [==============================] - 0s 140us/step - loss: 1319.7055 - mean_absolute_error: 1319.7055 - val_loss: 1155.5509 - val_mean_absolute_error: 1155.5509
#
# Epoch 00109: val_loss improved from 1155.79696 to 1155.55090, saving model to 생수date-Weights-109--1155.55090-cat02-vf05.hdf5
# Epoch 110/500
# 585/585 [==============================] - 0s 128us/step - loss: 1343.0661 - mean_absolute_error: 1343.0661 - val_loss: 1585.1832 - val_mean_absolute_error: 1585.1832
#
# Epoch 00110: val_loss did not improve from 1155.55090
# Epoch 111/500
# 585/585 [==============================] - 0s 131us/step - loss: 1340.9104 - mean_absolute_error: 1340.9104 - val_loss: 1180.8667 - val_mean_absolute_error: 1180.8667
#
# Epoch 00111: val_loss did not improve from 1155.55090
# Epoch 112/500
# 585/585 [==============================] - 0s 124us/step - loss: 1320.5452 - mean_absolute_error: 1320.5452 - val_loss: 1373.5783 - val_mean_absolute_error: 1373.5783
#
# Epoch 00112: val_loss did not improve from 1155.55090
# Epoch 113/500
# 585/585 [==============================] - 0s 153us/step - loss: 1372.6161 - mean_absolute_error: 1372.6161 - val_loss: 1183.9526 - val_mean_absolute_error: 1183.9526
#
# Epoch 00113: val_loss did not improve from 1155.55090
# Epoch 114/500
# 585/585 [==============================] - 0s 135us/step - loss: 1344.1575 - mean_absolute_error: 1344.1575 - val_loss: 1191.3556 - val_mean_absolute_error: 1191.3556
#
# Epoch 00114: val_loss did not improve from 1155.55090
# Epoch 115/500
# 585/585 [==============================] - 0s 147us/step - loss: 1320.0234 - mean_absolute_error: 1320.0234 - val_loss: 1271.8643 - val_mean_absolute_error: 1271.8643
#
# Epoch 00115: val_loss did not improve from 1155.55090
# Epoch 116/500
# 585/585 [==============================] - 0s 131us/step - loss: 1323.5933 - mean_absolute_error: 1323.5933 - val_loss: 1156.2103 - val_mean_absolute_error: 1156.2103
#
# Epoch 00116: val_loss did not improve from 1155.55090
# Epoch 117/500
# 585/585 [==============================] - 0s 121us/step - loss: 1351.2005 - mean_absolute_error: 1351.2005 - val_loss: 1218.8614 - val_mean_absolute_error: 1218.8614
#
# Epoch 00117: val_loss did not improve from 1155.55090
# Epoch 118/500
# 585/585 [==============================] - 0s 126us/step - loss: 1322.2490 - mean_absolute_error: 1322.2490 - val_loss: 1358.7882 - val_mean_absolute_error: 1358.7882
#
# Epoch 00118: val_loss did not improve from 1155.55090
# Epoch 119/500
# 585/585 [==============================] - 0s 121us/step - loss: 1316.0901 - mean_absolute_error: 1316.0901 - val_loss: 1293.9194 - val_mean_absolute_error: 1293.9194
#
# Epoch 00119: val_loss did not improve from 1155.55090
# Epoch 120/500
# 585/585 [==============================] - 0s 124us/step - loss: 1341.0449 - mean_absolute_error: 1341.0449 - val_loss: 1322.4406 - val_mean_absolute_error: 1322.4406
#
# Epoch 00120: val_loss did not improve from 1155.55090
# Epoch 121/500
# 585/585 [==============================] - 0s 124us/step - loss: 1300.4264 - mean_absolute_error: 1300.4264 - val_loss: 1317.0219 - val_mean_absolute_error: 1317.0219
#
# Epoch 00121: val_loss did not improve from 1155.55090
# Epoch 122/500
# 585/585 [==============================] - 0s 128us/step - loss: 1297.9802 - mean_absolute_error: 1297.9802 - val_loss: 1255.1214 - val_mean_absolute_error: 1255.1214
#
# Epoch 00122: val_loss did not improve from 1155.55090
# Epoch 123/500
# 585/585 [==============================] - 0s 123us/step - loss: 1303.8214 - mean_absolute_error: 1303.8214 - val_loss: 1235.2647 - val_mean_absolute_error: 1235.2647
#
# Epoch 00123: val_loss did not improve from 1155.55090
# Epoch 124/500
# 585/585 [==============================] - 0s 124us/step - loss: 1296.9330 - mean_absolute_error: 1296.9330 - val_loss: 1314.6119 - val_mean_absolute_error: 1314.6119
#
# Epoch 00124: val_loss did not improve from 1155.55090
# Epoch 125/500
# 585/585 [==============================] - 0s 116us/step - loss: 1308.1210 - mean_absolute_error: 1308.1210 - val_loss: 1389.1326 - val_mean_absolute_error: 1389.1326
#
# Epoch 00125: val_loss did not improve from 1155.55090
# Epoch 126/500
# 585/585 [==============================] - 0s 123us/step - loss: 1318.2171 - mean_absolute_error: 1318.2171 - val_loss: 1158.0123 - val_mean_absolute_error: 1158.0123
#
# Epoch 00126: val_loss did not improve from 1155.55090
# Epoch 127/500
# 585/585 [==============================] - 0s 124us/step - loss: 1318.2743 - mean_absolute_error: 1318.2743 - val_loss: 1282.3080 - val_mean_absolute_error: 1282.3080
#
# Epoch 00127: val_loss did not improve from 1155.55090
# Epoch 128/500
# 585/585 [==============================] - 0s 119us/step - loss: 1304.3077 - mean_absolute_error: 1304.3077 - val_loss: 1302.3110 - val_mean_absolute_error: 1302.3110
#
# Epoch 00128: val_loss did not improve from 1155.55090
# Epoch 129/500
# 585/585 [==============================] - 0s 126us/step - loss: 1295.6232 - mean_absolute_error: 1295.6232 - val_loss: 1226.6147 - val_mean_absolute_error: 1226.6147
#
# Epoch 00129: val_loss did not improve from 1155.55090
# Epoch 130/500
# 585/585 [==============================] - 0s 130us/step - loss: 1302.8651 - mean_absolute_error: 1302.8651 - val_loss: 1236.0145 - val_mean_absolute_error: 1236.0145
#
# Epoch 00130: val_loss did not improve from 1155.55090
# Epoch 131/500
# 585/585 [==============================] - 0s 128us/step - loss: 1300.9871 - mean_absolute_error: 1300.9871 - val_loss: 1283.3921 - val_mean_absolute_error: 1283.3921
#
# Epoch 00131: val_loss did not improve from 1155.55090
# Epoch 132/500
# 585/585 [==============================] - 0s 123us/step - loss: 1308.1150 - mean_absolute_error: 1308.1150 - val_loss: 1258.7090 - val_mean_absolute_error: 1258.7090
#
# Epoch 00132: val_loss did not improve from 1155.55090
# Epoch 133/500
# 585/585 [==============================] - 0s 124us/step - loss: 1320.1419 - mean_absolute_error: 1320.1419 - val_loss: 1210.9340 - val_mean_absolute_error: 1210.9340
#
# Epoch 00133: val_loss did not improve from 1155.55090
# Epoch 134/500
# 585/585 [==============================] - 0s 138us/step - loss: 1311.2028 - mean_absolute_error: 1311.2028 - val_loss: 1214.1895 - val_mean_absolute_error: 1214.1895
#
# Epoch 00134: val_loss did not improve from 1155.55090
# Epoch 135/500
# 585/585 [==============================] - 0s 130us/step - loss: 1295.6784 - mean_absolute_error: 1295.6784 - val_loss: 1481.1789 - val_mean_absolute_error: 1481.1789
#
# Epoch 00135: val_loss did not improve from 1155.55090
# Epoch 136/500
# 585/585 [==============================] - 0s 130us/step - loss: 1309.6977 - mean_absolute_error: 1309.6977 - val_loss: 1213.0568 - val_mean_absolute_error: 1213.0568
#
# Epoch 00136: val_loss did not improve from 1155.55090
# Epoch 137/500
# 585/585 [==============================] - 0s 128us/step - loss: 1294.7415 - mean_absolute_error: 1294.7415 - val_loss: 1252.4433 - val_mean_absolute_error: 1252.4433
#
# Epoch 00137: val_loss did not improve from 1155.55090
# Epoch 138/500
# 585/585 [==============================] - 0s 140us/step - loss: 1307.5946 - mean_absolute_error: 1307.5946 - val_loss: 1314.8308 - val_mean_absolute_error: 1314.8308
#
# Epoch 00138: val_loss did not improve from 1155.55090
# Epoch 139/500
# 585/585 [==============================] - 0s 131us/step - loss: 1303.3618 - mean_absolute_error: 1303.3618 - val_loss: 1293.3842 - val_mean_absolute_error: 1293.3842
#
# Epoch 00139: val_loss did not improve from 1155.55090
# Epoch 140/500
# 585/585 [==============================] - 0s 153us/step - loss: 1320.6016 - mean_absolute_error: 1320.6016 - val_loss: 1652.3562 - val_mean_absolute_error: 1652.3562
#
# Epoch 00140: val_loss did not improve from 1155.55090
# Epoch 141/500
# 585/585 [==============================] - 0s 135us/step - loss: 1330.0147 - mean_absolute_error: 1330.0147 - val_loss: 1136.7764 - val_mean_absolute_error: 1136.7764
#
# Epoch 00141: val_loss improved from 1155.55090 to 1136.77638, saving model to 생수date-Weights-141--1136.77638-cat02-vf05.hdf5
# Epoch 142/500
# 585/585 [==============================] - 0s 235us/step - loss: 1328.7667 - mean_absolute_error: 1328.7667 - val_loss: 1323.0810 - val_mean_absolute_error: 1323.0810
#
# Epoch 00142: val_loss did not improve from 1136.77638
# Epoch 143/500
# 585/585 [==============================] - 0s 143us/step - loss: 1323.2096 - mean_absolute_error: 1323.2096 - val_loss: 1398.6236 - val_mean_absolute_error: 1398.6236
#
# Epoch 00143: val_loss did not improve from 1136.77638
# Epoch 144/500
# 585/585 [==============================] - 0s 147us/step - loss: 1309.0107 - mean_absolute_error: 1309.0107 - val_loss: 1370.6489 - val_mean_absolute_error: 1370.6489
#
# Epoch 00144: val_loss did not improve from 1136.77638
# Epoch 145/500
# 585/585 [==============================] - 0s 128us/step - loss: 1288.7035 - mean_absolute_error: 1288.7035 - val_loss: 1311.2816 - val_mean_absolute_error: 1311.2816
#
# Epoch 00145: val_loss did not improve from 1136.77638
# Epoch 146/500
# 585/585 [==============================] - 0s 152us/step - loss: 1292.2848 - mean_absolute_error: 1292.2848 - val_loss: 1541.7055 - val_mean_absolute_error: 1541.7055
#
# Epoch 00146: val_loss did not improve from 1136.77638
# Epoch 147/500
# 585/585 [==============================] - 0s 138us/step - loss: 1286.4882 - mean_absolute_error: 1286.4882 - val_loss: 1460.7813 - val_mean_absolute_error: 1460.7813
#
# Epoch 00147: val_loss did not improve from 1136.77638
# Epoch 148/500
# 585/585 [==============================] - 0s 142us/step - loss: 1284.0401 - mean_absolute_error: 1284.0401 - val_loss: 1343.5617 - val_mean_absolute_error: 1343.5617
#
# Epoch 00148: val_loss did not improve from 1136.77638
# Epoch 149/500
# 585/585 [==============================] - 0s 138us/step - loss: 1283.6905 - mean_absolute_error: 1283.6905 - val_loss: 1690.6148 - val_mean_absolute_error: 1690.6148
#
# Epoch 00149: val_loss did not improve from 1136.77638
# Epoch 150/500
# 585/585 [==============================] - 0s 133us/step - loss: 1325.6797 - mean_absolute_error: 1325.6797 - val_loss: 1384.2973 - val_mean_absolute_error: 1384.2973
#
# Epoch 00150: val_loss did not improve from 1136.77638
# Epoch 151/500
# 585/585 [==============================] - 0s 136us/step - loss: 1278.2170 - mean_absolute_error: 1278.2170 - val_loss: 1141.1655 - val_mean_absolute_error: 1141.1655
#
# Epoch 00151: val_loss did not improve from 1136.77638
# Epoch 152/500
# 585/585 [==============================] - 0s 150us/step - loss: 1350.5638 - mean_absolute_error: 1350.5638 - val_loss: 1239.7612 - val_mean_absolute_error: 1239.7612
#
# Epoch 00152: val_loss did not improve from 1136.77638
# Epoch 153/500
# 585/585 [==============================] - 0s 140us/step - loss: 1311.0119 - mean_absolute_error: 1311.0119 - val_loss: 1512.4839 - val_mean_absolute_error: 1512.4839
#
# Epoch 00153: val_loss did not improve from 1136.77638
# Epoch 154/500
# 585/585 [==============================] - 0s 189us/step - loss: 1316.4995 - mean_absolute_error: 1316.4995 - val_loss: 1232.1044 - val_mean_absolute_error: 1232.1044
#
# Epoch 00154: val_loss did not improve from 1136.77638
# Epoch 155/500
# 585/585 [==============================] - 0s 136us/step - loss: 1341.3228 - mean_absolute_error: 1341.3228 - val_loss: 1134.9308 - val_mean_absolute_error: 1134.9308
#
# Epoch 00155: val_loss improved from 1136.77638 to 1134.93077, saving model to 생수date-Weights-155--1134.93077-cat02-vf05.hdf5
# Epoch 156/500
# 585/585 [==============================] - 0s 126us/step - loss: 1288.6341 - mean_absolute_error: 1288.6341 - val_loss: 1433.9253 - val_mean_absolute_error: 1433.9253
#
# Epoch 00156: val_loss did not improve from 1134.93077
# Epoch 157/500
# 585/585 [==============================] - 0s 155us/step - loss: 1317.5274 - mean_absolute_error: 1317.5274 - val_loss: 1528.9099 - val_mean_absolute_error: 1528.9099
#
# Epoch 00157: val_loss did not improve from 1134.93077
# Epoch 158/500
# 585/585 [==============================] - 0s 124us/step - loss: 1303.9728 - mean_absolute_error: 1303.9728 - val_loss: 1343.0786 - val_mean_absolute_error: 1343.0786
#
# Epoch 00158: val_loss did not improve from 1134.93077
# Epoch 159/500
# 585/585 [==============================] - 0s 143us/step - loss: 1280.3528 - mean_absolute_error: 1280.3528 - val_loss: 1273.9465 - val_mean_absolute_error: 1273.9465
#
# Epoch 00159: val_loss did not improve from 1134.93077
# Epoch 160/500
# 585/585 [==============================] - 0s 133us/step - loss: 1268.1645 - mean_absolute_error: 1268.1645 - val_loss: 1387.7995 - val_mean_absolute_error: 1387.7995
#
# Epoch 00160: val_loss did not improve from 1134.93077
# Epoch 161/500
# 585/585 [==============================] - 0s 130us/step - loss: 1323.1110 - mean_absolute_error: 1323.1110 - val_loss: 1478.2405 - val_mean_absolute_error: 1478.2405
#
# Epoch 00161: val_loss did not improve from 1134.93077
# Epoch 162/500
# 585/585 [==============================] - 0s 130us/step - loss: 1350.5011 - mean_absolute_error: 1350.5011 - val_loss: 1238.8962 - val_mean_absolute_error: 1238.8962
#
# Epoch 00162: val_loss did not improve from 1134.93077
# Epoch 163/500
# 585/585 [==============================] - 0s 124us/step - loss: 1304.8740 - mean_absolute_error: 1304.8740 - val_loss: 1303.7221 - val_mean_absolute_error: 1303.7221
#
# Epoch 00163: val_loss did not improve from 1134.93077
# Epoch 164/500
# 585/585 [==============================] - 0s 142us/step - loss: 1279.0069 - mean_absolute_error: 1279.0069 - val_loss: 1263.5481 - val_mean_absolute_error: 1263.5481
#
# Epoch 00164: val_loss did not improve from 1134.93077
# Epoch 165/500
# 585/585 [==============================] - 0s 133us/step - loss: 1277.1130 - mean_absolute_error: 1277.1130 - val_loss: 1506.6142 - val_mean_absolute_error: 1506.6142
#
# Epoch 00165: val_loss did not improve from 1134.93077
# Epoch 166/500
# 585/585 [==============================] - 0s 133us/step - loss: 1330.8820 - mean_absolute_error: 1330.8820 - val_loss: 1534.7448 - val_mean_absolute_error: 1534.7448
#
# Epoch 00166: val_loss did not improve from 1134.93077
# Epoch 167/500
# 585/585 [==============================] - 0s 140us/step - loss: 1288.9839 - mean_absolute_error: 1288.9839 - val_loss: 1547.3947 - val_mean_absolute_error: 1547.3947
#
# Epoch 00167: val_loss did not improve from 1134.93077
# Epoch 168/500
# 585/585 [==============================] - 0s 142us/step - loss: 1276.7101 - mean_absolute_error: 1276.7101 - val_loss: 1317.8247 - val_mean_absolute_error: 1317.8247
#
# Epoch 00168: val_loss did not improve from 1134.93077
# Epoch 169/500
# 585/585 [==============================] - 0s 138us/step - loss: 1261.3873 - mean_absolute_error: 1261.3873 - val_loss: 1232.1185 - val_mean_absolute_error: 1232.1185
#
# Epoch 00169: val_loss did not improve from 1134.93077
# Epoch 170/500
# 585/585 [==============================] - 0s 133us/step - loss: 1267.4479 - mean_absolute_error: 1267.4479 - val_loss: 1366.4364 - val_mean_absolute_error: 1366.4364
#
# Epoch 00170: val_loss did not improve from 1134.93077
# Epoch 171/500
# 585/585 [==============================] - 0s 143us/step - loss: 1285.0724 - mean_absolute_error: 1285.0724 - val_loss: 1604.2246 - val_mean_absolute_error: 1604.2246
#
# Epoch 00171: val_loss did not improve from 1134.93077
# Epoch 172/500
# 585/585 [==============================] - 0s 130us/step - loss: 1268.8566 - mean_absolute_error: 1268.8566 - val_loss: 1380.7056 - val_mean_absolute_error: 1380.7056
#
# Epoch 00172: val_loss did not improve from 1134.93077
# Epoch 173/500
# 585/585 [==============================] - 0s 155us/step - loss: 1297.5802 - mean_absolute_error: 1297.5802 - val_loss: 1375.4915 - val_mean_absolute_error: 1375.4915
#
# Epoch 00173: val_loss did not improve from 1134.93077
# Epoch 174/500
# 585/585 [==============================] - 0s 152us/step - loss: 1264.5052 - mean_absolute_error: 1264.5052 - val_loss: 1293.0555 - val_mean_absolute_error: 1293.0555
#
# Epoch 00174: val_loss did not improve from 1134.93077
# Epoch 175/500
# 585/585 [==============================] - 0s 157us/step - loss: 1264.4940 - mean_absolute_error: 1264.4940 - val_loss: 1591.5406 - val_mean_absolute_error: 1591.5406
#
# Epoch 00175: val_loss did not improve from 1134.93077
# Epoch 176/500
# 585/585 [==============================] - 0s 155us/step - loss: 1284.9689 - mean_absolute_error: 1284.9689 - val_loss: 1322.4457 - val_mean_absolute_error: 1322.4457
#
# Epoch 00176: val_loss did not improve from 1134.93077
# Epoch 177/500
# 585/585 [==============================] - 0s 160us/step - loss: 1257.5104 - mean_absolute_error: 1257.5104 - val_loss: 1267.5043 - val_mean_absolute_error: 1267.5043
#
# Epoch 00177: val_loss did not improve from 1134.93077
# Epoch 178/500
# 585/585 [==============================] - 0s 157us/step - loss: 1266.0215 - mean_absolute_error: 1266.0215 - val_loss: 1211.4627 - val_mean_absolute_error: 1211.4627
#
# Epoch 00178: val_loss did not improve from 1134.93077
# Epoch 179/500
# 585/585 [==============================] - 0s 143us/step - loss: 1306.9763 - mean_absolute_error: 1306.9763 - val_loss: 1726.0755 - val_mean_absolute_error: 1726.0755
#
# Epoch 00179: val_loss did not improve from 1134.93077
# Epoch 180/500
# 585/585 [==============================] - 0s 142us/step - loss: 1405.6335 - mean_absolute_error: 1405.6335 - val_loss: 1378.1498 - val_mean_absolute_error: 1378.1498
#
# Epoch 00180: val_loss did not improve from 1134.93077
# Epoch 181/500
# 585/585 [==============================] - 0s 155us/step - loss: 1279.1777 - mean_absolute_error: 1279.1777 - val_loss: 1469.1650 - val_mean_absolute_error: 1469.1650
#
# Epoch 00181: val_loss did not improve from 1134.93077
# Epoch 182/500
# 585/585 [==============================] - 0s 152us/step - loss: 1260.2562 - mean_absolute_error: 1260.2562 - val_loss: 1258.5773 - val_mean_absolute_error: 1258.5773
#
# Epoch 00182: val_loss did not improve from 1134.93077
# Epoch 183/500
# 585/585 [==============================] - 0s 155us/step - loss: 1267.8320 - mean_absolute_error: 1267.8320 - val_loss: 1514.9642 - val_mean_absolute_error: 1514.9642
#
# Epoch 00183: val_loss did not improve from 1134.93077
# Epoch 184/500
# 585/585 [==============================] - 0s 124us/step - loss: 1275.4577 - mean_absolute_error: 1275.4577 - val_loss: 1275.3502 - val_mean_absolute_error: 1275.3502
#
# Epoch 00184: val_loss did not improve from 1134.93077
# Epoch 185/500
# 585/585 [==============================] - 0s 138us/step - loss: 1267.9490 - mean_absolute_error: 1267.9490 - val_loss: 1524.5519 - val_mean_absolute_error: 1524.5519
#
# Epoch 00185: val_loss did not improve from 1134.93077
# Epoch 186/500
# 585/585 [==============================] - 0s 160us/step - loss: 1287.8151 - mean_absolute_error: 1287.8151 - val_loss: 1360.7531 - val_mean_absolute_error: 1360.7531
#
# Epoch 00186: val_loss did not improve from 1134.93077
# Epoch 187/500
# 585/585 [==============================] - 0s 147us/step - loss: 1270.2080 - mean_absolute_error: 1270.2080 - val_loss: 1501.8086 - val_mean_absolute_error: 1501.8086
#
# Epoch 00187: val_loss did not improve from 1134.93077
# Epoch 188/500
# 585/585 [==============================] - 0s 152us/step - loss: 1261.2973 - mean_absolute_error: 1261.2973 - val_loss: 1273.6658 - val_mean_absolute_error: 1273.6658
#
# Epoch 00188: val_loss did not improve from 1134.93077
# Epoch 189/500
# 585/585 [==============================] - 0s 165us/step - loss: 1293.7788 - mean_absolute_error: 1293.7788 - val_loss: 1374.2375 - val_mean_absolute_error: 1374.2375
#
# Epoch 00189: val_loss did not improve from 1134.93077
# Epoch 190/500
# 585/585 [==============================] - 0s 162us/step - loss: 1278.6405 - mean_absolute_error: 1278.6405 - val_loss: 1542.0860 - val_mean_absolute_error: 1542.0860
#
# Epoch 00190: val_loss did not improve from 1134.93077
# Epoch 191/500
# 585/585 [==============================] - 0s 143us/step - loss: 1265.2349 - mean_absolute_error: 1265.2349 - val_loss: 1521.0081 - val_mean_absolute_error: 1521.0081
#
# Epoch 00191: val_loss did not improve from 1134.93077
# Epoch 192/500
# 585/585 [==============================] - 0s 147us/step - loss: 1267.8828 - mean_absolute_error: 1267.8828 - val_loss: 1419.1311 - val_mean_absolute_error: 1419.1311
#
# Epoch 00192: val_loss did not improve from 1134.93077
# Epoch 193/500
# 585/585 [==============================] - 0s 143us/step - loss: 1261.8296 - mean_absolute_error: 1261.8296 - val_loss: 1225.6121 - val_mean_absolute_error: 1225.6121
#
# Epoch 00193: val_loss did not improve from 1134.93077
# Epoch 194/500
# 585/585 [==============================] - 0s 157us/step - loss: 1298.3581 - mean_absolute_error: 1298.3581 - val_loss: 1682.8660 - val_mean_absolute_error: 1682.8660
#
# Epoch 00194: val_loss did not improve from 1134.93077
# Epoch 195/500
# 585/585 [==============================] - 0s 169us/step - loss: 1281.5565 - mean_absolute_error: 1281.5565 - val_loss: 1398.8314 - val_mean_absolute_error: 1398.8314
#
# Epoch 00195: val_loss did not improve from 1134.93077
# Epoch 196/500
# 585/585 [==============================] - 0s 147us/step - loss: 1272.3427 - mean_absolute_error: 1272.3427 - val_loss: 1267.4672 - val_mean_absolute_error: 1267.4672
#
# Epoch 00196: val_loss did not improve from 1134.93077
# Epoch 197/500
# 585/585 [==============================] - 0s 136us/step - loss: 1280.1109 - mean_absolute_error: 1280.1109 - val_loss: 1300.5122 - val_mean_absolute_error: 1300.5122
#
# Epoch 00197: val_loss did not improve from 1134.93077
# Epoch 198/500
# 585/585 [==============================] - 0s 152us/step - loss: 1268.8657 - mean_absolute_error: 1268.8657 - val_loss: 1428.4239 - val_mean_absolute_error: 1428.4239
#
# ...
#
# Epoch 00433: val_loss did not improve from 1134.93077
# Epoch 434/500
# 585/585 [==============================] - 0s 147us/step - loss: 1172.1391 - mean_absolute_error: 1172.1391 - val_loss: 1365.9694 - val_mean_absolute_error: 1365.9694
#
# Epoch 00434: val_loss did not improve from 1134.93077
# Epoch 435/500
# 585/585 [==============================] - 0s 153us/step - loss: 1214.8140 - mean_absolute_error: 1214.8140 - val_loss: 1673.6792 - val_mean_absolute_error: 1673.6792
#
# Epoch 00435: val_loss did not improve from 1134.93077
# Epoch 436/500
# 585/585 [==============================] - 0s 155us/step - loss: 1128.9890 - mean_absolute_error: 1128.9890 - val_loss: 1567.0338 - val_mean_absolute_error: 1567.0338
#
# Epoch 00436: val_loss did not improve from 1134.93077
# Epoch 437/500
# 585/585 [==============================] - 0s 143us/step - loss: 1148.5370 - mean_absolute_error: 1148.5370 - val_loss: 1508.9737 - val_mean_absolute_error: 1508.9737
#
# Epoch 00437: val_loss did not improve from 1134.93077
# Epoch 438/500
# 585/585 [==============================] - 0s 145us/step - loss: 1135.2190 - mean_absolute_error: 1135.2190 - val_loss: 1511.5731 - val_mean_absolute_error: 1511.5731
#
# Epoch 00438: val_loss did not improve from 1134.93077
# Epoch 439/500
# 585/585 [==============================] - 0s 142us/step - loss: 1137.4202 - mean_absolute_error: 1137.4202 - val_loss: 1709.2512 - val_mean_absolute_error: 1709.2512
#
# Epoch 00439: val_loss did not improve from 1134.93077
# Epoch 440/500
# 585/585 [==============================] - 0s 136us/step - loss: 1133.3909 - mean_absolute_error: 1133.3909 - val_loss: 1342.9095 - val_mean_absolute_error: 1342.9095
#
# Epoch 00440: val_loss did not improve from 1134.93077
# Epoch 441/500
# 585/585 [==============================] - 0s 133us/step - loss: 1138.8652 - mean_absolute_error: 1138.8652 - val_loss: 1475.1719 - val_mean_absolute_error: 1475.1719
#
# Epoch 00441: val_loss did not improve from 1134.93077
# Epoch 442/500
# 585/585 [==============================] - 0s 148us/step - loss: 1152.8512 - mean_absolute_error: 1152.8512 - val_loss: 1489.1585 - val_mean_absolute_error: 1489.1585
#
# Epoch 00442: val_loss did not improve from 1134.93077
# Epoch 443/500
# 585/585 [==============================] - 0s 136us/step - loss: 1151.6828 - mean_absolute_error: 1151.6828 - val_loss: 1743.1148 - val_mean_absolute_error: 1743.1148
#
# Epoch 00443: val_loss did not improve from 1134.93077
# Epoch 444/500
# 585/585 [==============================] - 0s 143us/step - loss: 1157.9994 - mean_absolute_error: 1157.9994 - val_loss: 1512.3787 - val_mean_absolute_error: 1512.3787
#
# Epoch 00444: val_loss did not improve from 1134.93077
# Epoch 445/500
# 585/585 [==============================] - 0s 155us/step - loss: 1208.6020 - mean_absolute_error: 1208.6020 - val_loss: 1375.2611 - val_mean_absolute_error: 1375.2611
#
# Epoch 00445: val_loss did not improve from 1134.93077
# Epoch 446/500
# 585/585 [==============================] - 0s 142us/step - loss: 1179.4961 - mean_absolute_error: 1179.4961 - val_loss: 1607.6417 - val_mean_absolute_error: 1607.6417
#
# Epoch 00446: val_loss did not improve from 1134.93077
# Epoch 447/500
# 585/585 [==============================] - 0s 155us/step - loss: 1132.4326 - mean_absolute_error: 1132.4326 - val_loss: 1364.8562 - val_mean_absolute_error: 1364.8562
#
# Epoch 00447: val_loss did not improve from 1134.93077
# Epoch 448/500
# 585/585 [==============================] - 0s 153us/step - loss: 1141.1405 - mean_absolute_error: 1141.1405 - val_loss: 1757.0523 - val_mean_absolute_error: 1757.0523
#
# Epoch 00448: val_loss did not improve from 1134.93077
# Epoch 449/500
# 585/585 [==============================] - 0s 159us/step - loss: 1145.1817 - mean_absolute_error: 1145.1817 - val_loss: 1455.1038 - val_mean_absolute_error: 1455.1038
#
# Epoch 00449: val_loss did not improve from 1134.93077
# Epoch 450/500
# 585/585 [==============================] - 0s 153us/step - loss: 1122.1525 - mean_absolute_error: 1122.1525 - val_loss: 1600.6630 - val_mean_absolute_error: 1600.6630
#
# Epoch 00450: val_loss did not improve from 1134.93077
# Epoch 451/500
# 585/585 [==============================] - 0s 145us/step - loss: 1131.6555 - mean_absolute_error: 1131.6555 - val_loss: 1586.4715 - val_mean_absolute_error: 1586.4715
#
# Epoch 00451: val_loss did not improve from 1134.93077
# Epoch 452/500
# 585/585 [==============================] - 0s 160us/step - loss: 1151.2931 - mean_absolute_error: 1151.2931 - val_loss: 1347.0287 - val_mean_absolute_error: 1347.0287
#
# Epoch 00452: val_loss did not improve from 1134.93077
# Epoch 453/500
# 585/585 [==============================] - 0s 162us/step - loss: 1173.1360 - mean_absolute_error: 1173.1360 - val_loss: 1515.4718 - val_mean_absolute_error: 1515.4718
#
# Epoch 00453: val_loss did not improve from 1134.93077
# Epoch 454/500
# 585/585 [==============================] - 0s 147us/step - loss: 1133.0698 - mean_absolute_error: 1133.0698 - val_loss: 1659.4566 - val_mean_absolute_error: 1659.4566
#
# Epoch 00454: val_loss did not improve from 1134.93077
# Epoch 455/500
# 585/585 [==============================] - 0s 165us/step - loss: 1137.0426 - mean_absolute_error: 1137.0426 - val_loss: 1396.5178 - val_mean_absolute_error: 1396.5178
#
# Epoch 00455: val_loss did not improve from 1134.93077
# Epoch 456/500
# 585/585 [==============================] - 0s 169us/step - loss: 1132.6112 - mean_absolute_error: 1132.6112 - val_loss: 1508.8151 - val_mean_absolute_error: 1508.8151
#
# Epoch 00456: val_loss did not improve from 1134.93077
# Epoch 457/500
# 585/585 [==============================] - 0s 162us/step - loss: 1117.9647 - mean_absolute_error: 1117.9647 - val_loss: 1457.4081 - val_mean_absolute_error: 1457.4081
#
# Epoch 00457: val_loss did not improve from 1134.93077
# Epoch 458/500
# 585/585 [==============================] - 0s 145us/step - loss: 1128.3474 - mean_absolute_error: 1128.3474 - val_loss: 1558.5941 - val_mean_absolute_error: 1558.5941
#
# Epoch 00458: val_loss did not improve from 1134.93077
# Epoch 459/500
# 585/585 [==============================] - 0s 155us/step - loss: 1126.5304 - mean_absolute_error: 1126.5304 - val_loss: 2007.4748 - val_mean_absolute_error: 2007.4748
#
# Epoch 00459: val_loss did not improve from 1134.93077
# Epoch 460/500
# 585/585 [==============================] - 0s 157us/step - loss: 1183.5011 - mean_absolute_error: 1183.5011 - val_loss: 1448.4317 - val_mean_absolute_error: 1448.4317
#
# Epoch 00460: val_loss did not improve from 1134.93077
# Epoch 461/500
# 585/585 [==============================] - 0s 160us/step - loss: 1157.5153 - mean_absolute_error: 1157.5153 - val_loss: 1836.2255 - val_mean_absolute_error: 1836.2255
#
# Epoch 00461: val_loss did not improve from 1134.93077
# Epoch 462/500
# 585/585 [==============================] - 0s 150us/step - loss: 1190.4217 - mean_absolute_error: 1190.4217 - val_loss: 1662.1420 - val_mean_absolute_error: 1662.1420
#
# Epoch 00462: val_loss did not improve from 1134.93077
# Epoch 463/500
# 585/585 [==============================] - 0s 170us/step - loss: 1161.6061 - mean_absolute_error: 1161.6061 - val_loss: 1607.7261 - val_mean_absolute_error: 1607.7261
#
# Epoch 00463: val_loss did not improve from 1134.93077
# Epoch 464/500
# 585/585 [==============================] - 0s 186us/step - loss: 1146.3058 - mean_absolute_error: 1146.3058 - val_loss: 1491.1593 - val_mean_absolute_error: 1491.1593
#
# Epoch 00464: val_loss did not improve from 1134.93077
# Epoch 465/500
# 585/585 [==============================] - 0s 191us/step - loss: 1152.0708 - mean_absolute_error: 1152.0708 - val_loss: 1480.3524 - val_mean_absolute_error: 1480.3524
#
# Epoch 00465: val_loss did not improve from 1134.93077
# Epoch 466/500
# 585/585 [==============================] - 0s 160us/step - loss: 1125.5157 - mean_absolute_error: 1125.5157 - val_loss: 1507.5080 - val_mean_absolute_error: 1507.5080
#
# Epoch 00466: val_loss did not improve from 1134.93077
# Epoch 467/500
# 585/585 [==============================] - 0s 165us/step - loss: 1123.3302 - mean_absolute_error: 1123.3302 - val_loss: 1652.5724 - val_mean_absolute_error: 1652.5724
#
# Epoch 00467: val_loss did not improve from 1134.93077
# Epoch 468/500
# 585/585 [==============================] - 0s 167us/step - loss: 1146.0032 - mean_absolute_error: 1146.0032 - val_loss: 1572.2764 - val_mean_absolute_error: 1572.2764
#
# Epoch 00468: val_loss did not improve from 1134.93077
# Epoch 469/500
# 585/585 [==============================] - 0s 153us/step - loss: 1174.4900 - mean_absolute_error: 1174.4900 - val_loss: 1609.3958 - val_mean_absolute_error: 1609.3958
#
# Epoch 00469: val_loss did not improve from 1134.93077
# Epoch 470/500
# 585/585 [==============================] - 0s 153us/step - loss: 1118.1452 - mean_absolute_error: 1118.1452 - val_loss: 1540.7559 - val_mean_absolute_error: 1540.7559
#
# Epoch 00470: val_loss did not improve from 1134.93077
# Epoch 471/500
# 585/585 [==============================] - 0s 164us/step - loss: 1123.5371 - mean_absolute_error: 1123.5371 - val_loss: 1655.8986 - val_mean_absolute_error: 1655.8986
#
# Epoch 00471: val_loss did not improve from 1134.93077
# Epoch 472/500
# 585/585 [==============================] - 0s 164us/step - loss: 1115.6078 - mean_absolute_error: 1115.6078 - val_loss: 1652.0237 - val_mean_absolute_error: 1652.0237
#
# Epoch 00472: val_loss did not improve from 1134.93077
# Epoch 473/500
# 585/585 [==============================] - 0s 157us/step - loss: 1142.8300 - mean_absolute_error: 1142.8300 - val_loss: 1429.7486 - val_mean_absolute_error: 1429.7486
#
# Epoch 00473: val_loss did not improve from 1134.93077
# Epoch 474/500
# 585/585 [==============================] - 0s 142us/step - loss: 1116.9236 - mean_absolute_error: 1116.9236 - val_loss: 1616.6218 - val_mean_absolute_error: 1616.6218
#
# Epoch 00474: val_loss did not improve from 1134.93077
# Epoch 475/500
# 585/585 [==============================] - 0s 142us/step - loss: 1146.6604 - mean_absolute_error: 1146.6604 - val_loss: 1552.5949 - val_mean_absolute_error: 1552.5949
#
# Epoch 00475: val_loss did not improve from 1134.93077
# Epoch 476/500
# 585/585 [==============================] - 0s 135us/step - loss: 1136.6150 - mean_absolute_error: 1136.6150 - val_loss: 1636.9985 - val_mean_absolute_error: 1636.9985
#
# Epoch 00476: val_loss did not improve from 1134.93077
# Epoch 477/500
# 585/585 [==============================] - 0s 140us/step - loss: 1122.2330 - mean_absolute_error: 1122.2330 - val_loss: 1662.3926 - val_mean_absolute_error: 1662.3926
#
# Epoch 00477: val_loss did not improve from 1134.93077
# Epoch 478/500
# 585/585 [==============================] - 0s 140us/step - loss: 1119.4849 - mean_absolute_error: 1119.4849 - val_loss: 1368.6816 - val_mean_absolute_error: 1368.6816
#
# Epoch 00478: val_loss did not improve from 1134.93077
# Epoch 479/500
# 585/585 [==============================] - 0s 152us/step - loss: 1146.5806 - mean_absolute_error: 1146.5806 - val_loss: 1584.7279 - val_mean_absolute_error: 1584.7279
#
# Epoch 00479: val_loss did not improve from 1134.93077
# Epoch 480/500
# 585/585 [==============================] - 0s 135us/step - loss: 1133.2729 - mean_absolute_error: 1133.2729 - val_loss: 1437.2518 - val_mean_absolute_error: 1437.2518
#
# Epoch 00480: val_loss did not improve from 1134.93077
# Epoch 481/500
# 585/585 [==============================] - 0s 140us/step - loss: 1122.2888 - mean_absolute_error: 1122.2888 - val_loss: 1671.8478 - val_mean_absolute_error: 1671.8478
#
# Epoch 00481: val_loss did not improve from 1134.93077
# Epoch 482/500
# 585/585 [==============================] - 0s 148us/step - loss: 1123.9685 - mean_absolute_error: 1123.9685 - val_loss: 1543.0446 - val_mean_absolute_error: 1543.0446
#
# Epoch 00482: val_loss did not improve from 1134.93077
# Epoch 483/500
# 585/585 [==============================] - 0s 150us/step - loss: 1144.4868 - mean_absolute_error: 1144.4868 - val_loss: 1606.2877 - val_mean_absolute_error: 1606.2877
#
# Epoch 00483: val_loss did not improve from 1134.93077
# Epoch 484/500
# 585/585 [==============================] - 0s 147us/step - loss: 1199.1150 - mean_absolute_error: 1199.1150 - val_loss: 1297.4503 - val_mean_absolute_error: 1297.4503
#
# Epoch 00484: val_loss did not improve from 1134.93077
# Epoch 485/500
# 585/585 [==============================] - 0s 155us/step - loss: 1133.4828 - mean_absolute_error: 1133.4828 - val_loss: 1660.3559 - val_mean_absolute_error: 1660.3559
#
# Epoch 00485: val_loss did not improve from 1134.93077
# Epoch 486/500
# 585/585 [==============================] - 0s 140us/step - loss: 1118.6096 - mean_absolute_error: 1118.6096 - val_loss: 1401.8966 - val_mean_absolute_error: 1401.8966
#
# Epoch 00486: val_loss did not improve from 1134.93077
# Epoch 487/500
# 585/585 [==============================] - 0s 142us/step - loss: 1129.6418 - mean_absolute_error: 1129.6418 - val_loss: 1632.0191 - val_mean_absolute_error: 1632.0191
#
# Epoch 00487: val_loss did not improve from 1134.93077
# Epoch 488/500
# 585/585 [==============================] - 0s 147us/step - loss: 1111.7825 - mean_absolute_error: 1111.7825 - val_loss: 1471.5599 - val_mean_absolute_error: 1471.5599
#
# Epoch 00488: val_loss did not improve from 1134.93077
# Epoch 489/500
# 585/585 [==============================] - 0s 143us/step - loss: 1098.6516 - mean_absolute_error: 1098.6516 - val_loss: 1484.9817 - val_mean_absolute_error: 1484.9817
#
# Epoch 00489: val_loss did not improve from 1134.93077
# Epoch 490/500
# 585/585 [==============================] - 0s 155us/step - loss: 1110.6633 - mean_absolute_error: 1110.6633 - val_loss: 1694.5260 - val_mean_absolute_error: 1694.5260
#
# Epoch 00490: val_loss did not improve from 1134.93077
# Epoch 491/500
# 585/585 [==============================] - 0s 157us/step - loss: 1110.6764 - mean_absolute_error: 1110.6764 - val_loss: 1617.0808 - val_mean_absolute_error: 1617.0808
#
# Epoch 00491: val_loss did not improve from 1134.93077
# Epoch 492/500
# 585/585 [==============================] - 0s 157us/step - loss: 1106.6901 - mean_absolute_error: 1106.6901 - val_loss: 1593.9433 - val_mean_absolute_error: 1593.9433
#
# Epoch 00492: val_loss did not improve from 1134.93077
# Epoch 493/500
# 585/585 [==============================] - 0s 147us/step - loss: 1115.4948 - mean_absolute_error: 1115.4948 - val_loss: 1524.6097 - val_mean_absolute_error: 1524.6097
#
# Epoch 00493: val_loss did not improve from 1134.93077
# Epoch 494/500
# 585/585 [==============================] - 0s 169us/step - loss: 1135.1495 - mean_absolute_error: 1135.1495 - val_loss: 1794.5697 - val_mean_absolute_error: 1794.5697
#
# Epoch 00494: val_loss did not improve from 1134.93077
# Epoch 495/500
# 585/585 [==============================] - 0s 159us/step - loss: 1181.9194 - mean_absolute_error: 1181.9194 - val_loss: 1445.9564 - val_mean_absolute_error: 1445.9564
#
# Epoch 00495: val_loss did not improve from 1134.93077
# Epoch 496/500
# 585/585 [==============================] - 0s 172us/step - loss: 1131.9651 - mean_absolute_error: 1131.9651 - val_loss: 1328.0978 - val_mean_absolute_error: 1328.0978
#
# Epoch 00496: val_loss did not improve from 1134.93077
# Epoch 497/500
# 585/585 [==============================] - 0s 148us/step - loss: 1154.6619 - mean_absolute_error: 1154.6619 - val_loss: 1623.0008 - val_mean_absolute_error: 1623.0008
#
# Epoch 00497: val_loss did not improve from 1134.93077
# Epoch 498/500
# 585/585 [==============================] - 0s 172us/step - loss: 1116.0421 - mean_absolute_error: 1116.0421 - val_loss: 1432.7150 - val_mean_absolute_error: 1432.7150
#
# Epoch 00498: val_loss did not improve from 1134.93077
# Epoch 499/500
# 585/585 [==============================] - 0s 169us/step - loss: 1110.8423 - mean_absolute_error: 1110.8423 - val_loss: 1501.4731 - val_mean_absolute_error: 1501.4731
#
# Epoch 00499: val_loss did not improve from 1134.93077
# Epoch 500/500
# 585/585 [==============================] - 0s 153us/step - loss: 1112.3441 - mean_absolute_error: 1112.3441 - val_loss: 1398.7564 - val_mean_absolute_error: 1398.7564
#
# Epoch 00500: val_loss did not improve from 1134.93077

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = '생수date-Weights-178--1095.84476-cat02-vf05.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']

print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

columns_in_data = list(train_X.columns)
customF = formulaGen(target='qty',ind_features=columns_in_data)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
print('검증세트점수 : {:.3f}'.format( r2_score(val_y, olsModel.predict(val_X))   ) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.925
# 검증세트점수 : 0.021
# XGBoost을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.753
# 검증세트점수 : 0.277
# LinearRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.607
# 검증세트점수 : 0.262
# RidgeRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.600
# 검증세트점수 : 0.253
# LassoRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.607
# 검증세트점수 : 0.261
# OLS을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.607
# 검증세트점수 : 0.262

# %%
print(item, 'ols model')

# columns_in_data = ['temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not', 'snow_or_not',
#                     '공기상태_0', '공기상태_1', '공기상태_2']

# formulaGen은 단순 1차 다항식을 제조해준다.
# customF = formulaGen(target='qty',ind_features=columns_in_data)
customF = formulaGen(target='qty',ind_features=['temp', 'wind','lgt_time','rain_or_not'])
# customF = 'qty ~ temp + cloud  + rain_or_not + 공기상태_0 + 공기상태_1+공기상태_2'

olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()

print('사람이 직접 식을 때려 박았을때 : {:.3f}'.format(r2_score(val_y, olsModel.predict(val_X))) )

olsModel.summary()
# Out:
# 생수 ols model
# 사람이 직접 식을 때려 박았을때 : 0.176
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.599
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     271.5
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          1.19e-142
# Time:                        21:02:12   Log-Likelihood:                -6506.8
# No. Observations:                 732   AIC:                         1.302e+04
# Df Residuals:                     727   BIC:                         1.305e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7613.4165    274.438     27.742      0.000    7074.630    8152.203
# temp          184.4513      6.102     30.230      0.000     172.472     196.430
# wind         -298.8762    100.603     -2.971      0.003    -496.384    -101.368
# lgt_time      113.1948     20.254      5.589      0.000      73.431     152.959
# rain_or_not  -485.5637    177.625     -2.734      0.006    -834.283    -136.844
# ==============================================================================
# Omnibus:                      146.139   Durbin-Watson:                   1.257
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              360.660
# Skew:                           1.039   Prob(JB):                     4.83e-79
# Kurtosis:                       5.740   Cond. No.                         80.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
#             '공기상태_0', '공기상태_1', '공기상태_2']
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
            '공기상태']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = gs_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 예측률 계산
# https://yamalab.tistory.com/46

# RMSE (Root Mean Squared Error) : 
# OLS 추정에서 일반적인 표준 오차이다. 예측 대상의 scale(단위 크기)에 주의해야하는 단점이 있다. 
# MSE는 root를 수식에서 제외, SSE는 root와 분모를 제외한 수식으로, SE가 붙은 척도들은 거기서 거기인 척도들이라고 보면 된다.
# 다만 디테일한 사용법에 차이가 있을 뿐.

# MAPE (Mean Absolute Percentage Error) :

# 위 방법의 단점을 보완한 것이다. 
# At는 실제값, Ft는 예측값인데, 이를 At로 나누어서 오차를 절대적 크기로 보는것이 아닌
# 비율의 크기로 보고자 하는 것이 핵심이다.
# 이 방법은 At가 0에 가까울수록 비정상적인 값이 나온다는 단점이 있다.

# MAPE가 0에 가까울수록 좋은 모델
result_df['mape_keras'] = abs((result_df.qty - result_df.keras_qty) / result_df.qty )
result_df['mape_rf'] = abs((result_df.qty - result_df.rf_qty) / result_df.qty )
result_df['mape_xgb'] = abs((result_df.qty - result_df.xgb_qty) / result_df.qty )
result_df['mape_lin'] = abs((result_df.qty - result_df.lin_qty) / result_df.qty )
result_df['mape_ridge'] = abs((result_df.qty - result_df.ridge_qty) / result_df.qty )
result_df['mape_lasso'] = abs((result_df.qty - result_df.lasso_qty) / result_df.qty )
result_df['mape_ols'] = abs((result_df.qty - result_df.ols_qty) / result_df.qty )

print('Keras 인공 신경망 모델 MAPE \t: {:<.2f}'.format(result_df['mape_keras'].sum() / result_df.shape[0] ))
# print('RandomForest 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_rf'].sum() / result_df.shape[0] ))
# print('XGBoosting  모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_xgb'].sum() / result_df.shape[0] ))
print('Linear 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lin'].sum() / result_df.shape[0] ))
print('Ridge 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_ridge'].sum() / result_df.shape[0] ))
print('Lasso 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lasso'].sum() / result_df.shape[0] ))
print('OLS 모델 MAPE \t\t\t: {:<.2f}'.format(result_df['mape_ols'].sum() / result_df.shape[0] ))
# Out:
# Keras 인공 신경망 모델 MAPE 	: 0.14
# Linear 모델 MAPE 		: 0.15
# Ridge 모델 MAPE 		: 0.16
# Lasso 모델 MAPE 		: 0.15
# OLS 모델 MAPE 			: 0.16

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not','snow_or_not', 
#                                                   '공기상태_0', '공기상태_1', '공기상태_2']

# 1~9 : 1 temp ~ 9 공기상태_2
n= 1
# alpha 값 0~1
alp = 0.8
# scatter plot 점 크기
dot_size = 10

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# # 1~106 / 106~156
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
