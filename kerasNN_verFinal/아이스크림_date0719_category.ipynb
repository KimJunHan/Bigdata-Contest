# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# R2 값, 결정계수 계산
from sklearn.metrics import r2_score

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
# w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
w = pd.read_csv('d:/project/contest/data/processed/날씨_ver071915.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '아이스크림'만 빼서 df생성
item = '아이스크림'
grouped_by = 'date'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not','미세', '초미세', '공기상태',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %%
# list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
list_col = ['temp', 'cloud', 'wind','lgt_time',
            'rain_or_not', 'snow_or_not', '공기상태'] #+'rain_or_not', 'snow_or_not'
lowVIF(w,20,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239620  snow_or_not
# 1    2.479988  rain_or_not
# 2    3.114369         공기상태
# 3    4.013218         temp
# 4    6.725926        cloud
# 5    8.084050     lgt_time
# 6    9.334878         wind

# %%
train_data = gs_day_w.loc[gs_day_w.date.between('2016-01-01','2017-12-31')]
test_data = gs_day_w.loc[gs_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만
combined = gs_day_w.loc[:,list_col]
target = gs_day_w.loc[:,'qty']
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 7
# 오브젝트형 자료 컬럼 갯수 : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
#### 내가 '공기상태'라는 컬럼이 사실은 category형이라는것을 알기에 직접 dummy컬럼 생성
airCondition_dummies = pd.get_dummies(combined['공기상태'],prefix='공기상태')
combined = pd.concat([combined, airCondition_dummies], axis=1)
combined.drop(['공기상태'],axis = 1 , inplace=True)
######################################################################################
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 10 개의 columns이 있었습니다.

# %%
combined.head(2)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
# 1   5.7    7.8   2.0       3.6            0            0       0       1
#
#    공기상태_2  공기상태_3
# 0       1       0
# 1       0       0

# %%
# 공기상태_0,공기상태_1,공기상태_2가 전부 0이면,   공기상태_3이 1이란 소리고
#                                                               공기상태가 '매우나쁨' 임을 추정할수 있다.
# 그런이유로 공기상태_3삭제
combined.drop(['공기상태_3'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
#
#    공기상태_2
# 0       1

# %%
Xy = pd.concat([target,combined], axis=1)
# Xy.head(1)

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 9)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# 인풋 레이어
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# 숨겨진 레이어
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# 출력 레이어
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 21:06:04.655783  5612 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 21:06:04.670720  5612 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 21:06:04.673712  5612 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 21:06:04.726571  5612 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,145
# Trainable params: 166,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 21:06:09.335141  5612 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 21:06:09.440280  5612 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 527us/step - loss: 21697.6520 - mean_absolute_error: 21697.6520 - val_loss: 14591.5670 - val_mean_absolute_error: 14591.5670
#
# Epoch 00001: val_loss improved from inf to 14591.56696, saving model to 아이스크림date-Weights-001--14591.56696-cat02-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 82us/step - loss: 20963.9032 - mean_absolute_error: 20963.9032 - val_loss: 11874.2268 - val_mean_absolute_error: 11874.2268
#
# Epoch 00002: val_loss improved from 14591.56696 to 11874.22682, saving model to 아이스크림date-Weights-002--11874.22682-cat02-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 78us/step - loss: 11425.2276 - mean_absolute_error: 11425.2276 - val_loss: 11104.6889 - val_mean_absolute_error: 11104.6889
#
# Epoch 00003: val_loss improved from 11874.22682 to 11104.68886, saving model to 아이스크림date-Weights-003--11104.68886-cat02-vf05.hdf5
# Epoch 4/500
# 585/585 [==============================] - 0s 70us/step - loss: 5417.9047 - mean_absolute_error: 5417.9047 - val_loss: 5334.5028 - val_mean_absolute_error: 5334.5028
#
# Epoch 00004: val_loss improved from 11104.68886 to 5334.50282, saving model to 아이스크림date-Weights-004--5334.50282-cat02-vf05.hdf5
# Epoch 5/500
# 585/585 [==============================] - 0s 73us/step - loss: 4912.2537 - mean_absolute_error: 4912.2537 - val_loss: 6135.2025 - val_mean_absolute_error: 6135.2025
#
# Epoch 00005: val_loss did not improve from 5334.50282
# Epoch 6/500
# 585/585 [==============================] - 0s 77us/step - loss: 4756.8708 - mean_absolute_error: 4756.8708 - val_loss: 5846.3880 - val_mean_absolute_error: 5846.3880
#
# Epoch 00006: val_loss did not improve from 5334.50282
# Epoch 7/500
# 585/585 [==============================] - 0s 75us/step - loss: 4599.8052 - mean_absolute_error: 4599.8052 - val_loss: 5398.0445 - val_mean_absolute_error: 5398.0445
#
# Epoch 00007: val_loss did not improve from 5334.50282
# Epoch 8/500
# 585/585 [==============================] - 0s 80us/step - loss: 4398.1659 - mean_absolute_error: 4398.1659 - val_loss: 7201.5303 - val_mean_absolute_error: 7201.5303
#
# Epoch 00008: val_loss did not improve from 5334.50282
# Epoch 9/500
# 585/585 [==============================] - 0s 82us/step - loss: 4291.8600 - mean_absolute_error: 4291.8600 - val_loss: 5541.4604 - val_mean_absolute_error: 5541.4604
#
# Epoch 00009: val_loss did not improve from 5334.50282
# Epoch 10/500
# 585/585 [==============================] - 0s 73us/step - loss: 4217.3635 - mean_absolute_error: 4217.3635 - val_loss: 4924.3471 - val_mean_absolute_error: 4924.3471
#
# Epoch 00010: val_loss improved from 5334.50282 to 4924.34710, saving model to 아이스크림date-Weights-010--4924.34710-cat02-vf05.hdf5
# Epoch 11/500
# 585/585 [==============================] - 0s 78us/step - loss: 4060.8985 - mean_absolute_error: 4060.8985 - val_loss: 5740.5649 - val_mean_absolute_error: 5740.5649
#
# Epoch 00011: val_loss did not improve from 4924.34710
# Epoch 12/500
# 585/585 [==============================] - 0s 73us/step - loss: 3995.2258 - mean_absolute_error: 3995.2258 - val_loss: 6873.3029 - val_mean_absolute_error: 6873.3029
#
# Epoch 00012: val_loss did not improve from 4924.34710
# Epoch 13/500
# 585/585 [==============================] - 0s 72us/step - loss: 3877.1499 - mean_absolute_error: 3877.1499 - val_loss: 5913.3243 - val_mean_absolute_error: 5913.3243
#
# Epoch 00013: val_loss did not improve from 4924.34710
# Epoch 14/500
# 585/585 [==============================] - 0s 82us/step - loss: 3823.5415 - mean_absolute_error: 3823.5415 - val_loss: 5474.3853 - val_mean_absolute_error: 5474.3853
#
# Epoch 00014: val_loss did not improve from 4924.34710
# Epoch 15/500
# 585/585 [==============================] - 0s 84us/step - loss: 3774.2882 - mean_absolute_error: 3774.2882 - val_loss: 5483.4976 - val_mean_absolute_error: 5483.4976
#
# Epoch 00015: val_loss did not improve from 4924.34710
# Epoch 16/500
# 585/585 [==============================] - 0s 73us/step - loss: 3742.3870 - mean_absolute_error: 3742.3870 - val_loss: 5170.4344 - val_mean_absolute_error: 5170.4344
#
# Epoch 00016: val_loss did not improve from 4924.34710
# Epoch 17/500
# 585/585 [==============================] - 0s 87us/step - loss: 3780.6436 - mean_absolute_error: 3780.6436 - val_loss: 5113.8997 - val_mean_absolute_error: 5113.8997
#
# Epoch 00017: val_loss did not improve from 4924.34710
# Epoch 18/500
# 585/585 [==============================] - 0s 90us/step - loss: 3658.8251 - mean_absolute_error: 3658.8251 - val_loss: 6004.9063 - val_mean_absolute_error: 6004.9063
#
# Epoch 00018: val_loss did not improve from 4924.34710
# Epoch 19/500
# 585/585 [==============================] - 0s 87us/step - loss: 3648.7925 - mean_absolute_error: 3648.7925 - val_loss: 5093.5454 - val_mean_absolute_error: 5093.5454
#
# Epoch 00019: val_loss did not improve from 4924.34710
# Epoch 20/500
# 585/585 [==============================] - 0s 85us/step - loss: 3635.6631 - mean_absolute_error: 3635.6631 - val_loss: 5921.0223 - val_mean_absolute_error: 5921.0223
#
# Epoch 00020: val_loss did not improve from 4924.34710
# Epoch 21/500
# 585/585 [==============================] - 0s 85us/step - loss: 3617.9507 - mean_absolute_error: 3617.9507 - val_loss: 6159.4702 - val_mean_absolute_error: 6159.4702
#
# Epoch 00021: val_loss did not improve from 4924.34710
# Epoch 22/500
# 585/585 [==============================] - 0s 84us/step - loss: 3611.4325 - mean_absolute_error: 3611.4325 - val_loss: 5437.0848 - val_mean_absolute_error: 5437.0848
#
# Epoch 00022: val_loss did not improve from 4924.34710
# Epoch 23/500
# 585/585 [==============================] - 0s 75us/step - loss: 3555.3706 - mean_absolute_error: 3555.3706 - val_loss: 6815.0815 - val_mean_absolute_error: 6815.0815
#
# Epoch 00023: val_loss did not improve from 4924.34710
# Epoch 24/500
# 585/585 [==============================] - 0s 90us/step - loss: 3637.6690 - mean_absolute_error: 3637.6690 - val_loss: 6975.2539 - val_mean_absolute_error: 6975.2539
#
# Epoch 00024: val_loss did not improve from 4924.34710
# Epoch 25/500
# 585/585 [==============================] - 0s 77us/step - loss: 3646.7645 - mean_absolute_error: 3646.7645 - val_loss: 6677.0439 - val_mean_absolute_error: 6677.0439
#
# Epoch 00025: val_loss did not improve from 4924.34710
# Epoch 26/500
# 585/585 [==============================] - 0s 94us/step - loss: 3611.7735 - mean_absolute_error: 3611.7735 - val_loss: 5332.7176 - val_mean_absolute_error: 5332.7176
#
# Epoch 00026: val_loss did not improve from 4924.34710
# Epoch 27/500
# 585/585 [==============================] - 0s 78us/step - loss: 3669.0899 - mean_absolute_error: 3669.0899 - val_loss: 6323.6228 - val_mean_absolute_error: 6323.6228
#
# Epoch 00027: val_loss did not improve from 4924.34710
# Epoch 28/500
# 585/585 [==============================] - 0s 99us/step - loss: 3569.1182 - mean_absolute_error: 3569.1182 - val_loss: 7269.2864 - val_mean_absolute_error: 7269.2864
#
# Epoch 00028: val_loss did not improve from 4924.34710
# Epoch 29/500
# 585/585 [==============================] - 0s 78us/step - loss: 3626.5011 - mean_absolute_error: 3626.5011 - val_loss: 5900.5236 - val_mean_absolute_error: 5900.5236
#
# Epoch 00029: val_loss did not improve from 4924.34710
# Epoch 30/500
# 585/585 [==============================] - 0s 84us/step - loss: 3519.1270 - mean_absolute_error: 3519.1270 - val_loss: 5582.0718 - val_mean_absolute_error: 5582.0718
#
# Epoch 00030: val_loss did not improve from 4924.34710
# Epoch 31/500
# 585/585 [==============================] - 0s 82us/step - loss: 3533.6097 - mean_absolute_error: 3533.6097 - val_loss: 5031.7491 - val_mean_absolute_error: 5031.7491
#
# Epoch 00031: val_loss did not improve from 4924.34710
# Epoch 32/500
# 585/585 [==============================] - 0s 77us/step - loss: 3619.3006 - mean_absolute_error: 3619.3006 - val_loss: 5135.7640 - val_mean_absolute_error: 5135.7640
#
# Epoch 00032: val_loss did not improve from 4924.34710
# Epoch 33/500
# 585/585 [==============================] - 0s 94us/step - loss: 3561.4754 - mean_absolute_error: 3561.4754 - val_loss: 5904.0110 - val_mean_absolute_error: 5904.0110
#
# Epoch 00033: val_loss did not improve from 4924.34710
# Epoch 34/500
# 585/585 [==============================] - 0s 95us/step - loss: 3554.7051 - mean_absolute_error: 3554.7051 - val_loss: 5751.5490 - val_mean_absolute_error: 5751.5490
#
# Epoch 00034: val_loss did not improve from 4924.34710
# Epoch 35/500
# 585/585 [==============================] - 0s 94us/step - loss: 3494.0961 - mean_absolute_error: 3494.0961 - val_loss: 5464.8785 - val_mean_absolute_error: 5464.8785
#
# Epoch 00035: val_loss did not improve from 4924.34710
# Epoch 36/500
# 585/585 [==============================] - 0s 94us/step - loss: 3489.3970 - mean_absolute_error: 3489.3970 - val_loss: 5800.6341 - val_mean_absolute_error: 5800.6341
#
# Epoch 00036: val_loss did not improve from 4924.34710
# Epoch 37/500
# 585/585 [==============================] - 0s 80us/step - loss: 3596.5101 - mean_absolute_error: 3596.5101 - val_loss: 5553.7833 - val_mean_absolute_error: 5553.7833
#
# Epoch 00037: val_loss did not improve from 4924.34710
# Epoch 38/500
# 585/585 [==============================] - 0s 94us/step - loss: 3553.9684 - mean_absolute_error: 3553.9684 - val_loss: 5956.5408 - val_mean_absolute_error: 5956.5408
#
# Epoch 00038: val_loss did not improve from 4924.34710
# Epoch 39/500
# 585/585 [==============================] - 0s 92us/step - loss: 3704.2724 - mean_absolute_error: 3704.2724 - val_loss: 6141.5714 - val_mean_absolute_error: 6141.5714
#
# Epoch 00039: val_loss did not improve from 4924.34710
# Epoch 40/500
# 585/585 [==============================] - 0s 101us/step - loss: 3485.8105 - mean_absolute_error: 3485.8105 - val_loss: 6681.1025 - val_mean_absolute_error: 6681.1025
#
# Epoch 00040: val_loss did not improve from 4924.34710
# Epoch 41/500
# 585/585 [==============================] - 0s 116us/step - loss: 3685.9067 - mean_absolute_error: 3685.9067 - val_loss: 5978.5577 - val_mean_absolute_error: 5978.5577
#
# Epoch 00041: val_loss did not improve from 4924.34710
# Epoch 42/500
# 585/585 [==============================] - 0s 99us/step - loss: 3469.8791 - mean_absolute_error: 3469.8791 - val_loss: 5650.9664 - val_mean_absolute_error: 5650.9664
#
# Epoch 00042: val_loss did not improve from 4924.34710
# Epoch 43/500
# 585/585 [==============================] - 0s 102us/step - loss: 3540.1628 - mean_absolute_error: 3540.1628 - val_loss: 5236.0012 - val_mean_absolute_error: 5236.0012
#
# Epoch 00043: val_loss did not improve from 4924.34710
# Epoch 44/500
# 585/585 [==============================] - 0s 104us/step - loss: 3500.0454 - mean_absolute_error: 3500.0454 - val_loss: 5359.5851 - val_mean_absolute_error: 5359.5851
#
# Epoch 00044: val_loss did not improve from 4924.34710
# Epoch 45/500
# 585/585 [==============================] - 0s 99us/step - loss: 3459.6022 - mean_absolute_error: 3459.6022 - val_loss: 5456.7560 - val_mean_absolute_error: 5456.7560
#
# Epoch 00045: val_loss did not improve from 4924.34710
# Epoch 46/500
# 585/585 [==============================] - 0s 94us/step - loss: 3471.7837 - mean_absolute_error: 3471.7837 - val_loss: 4457.9228 - val_mean_absolute_error: 4457.9228
#
# Epoch 00046: val_loss improved from 4924.34710 to 4457.92282, saving model to 아이스크림date-Weights-046--4457.92282-cat02-vf05.hdf5
# Epoch 47/500
# 585/585 [==============================] - 0s 87us/step - loss: 3534.5377 - mean_absolute_error: 3534.5377 - val_loss: 5014.3845 - val_mean_absolute_error: 5014.3845
#
# Epoch 00047: val_loss did not improve from 4457.92282
# Epoch 48/500
# 585/585 [==============================] - 0s 87us/step - loss: 3459.7316 - mean_absolute_error: 3459.7316 - val_loss: 4889.1264 - val_mean_absolute_error: 4889.1264
#
# Epoch 00048: val_loss did not improve from 4457.92282
# Epoch 49/500
# 585/585 [==============================] - 0s 94us/step - loss: 3483.8984 - mean_absolute_error: 3483.8984 - val_loss: 4137.2774 - val_mean_absolute_error: 4137.2774
#
# Epoch 00049: val_loss improved from 4457.92282 to 4137.27738, saving model to 아이스크림date-Weights-049--4137.27738-cat02-vf05.hdf5
# Epoch 50/500
# 585/585 [==============================] - 0s 85us/step - loss: 3530.6427 - mean_absolute_error: 3530.6427 - val_loss: 5036.8920 - val_mean_absolute_error: 5036.8920
#
# Epoch 00050: val_loss did not improve from 4137.27738
# Epoch 51/500
# 585/585 [==============================] - 0s 89us/step - loss: 3549.7299 - mean_absolute_error: 3549.7299 - val_loss: 6793.3146 - val_mean_absolute_error: 6793.3146
#
# Epoch 00051: val_loss did not improve from 4137.27738
# Epoch 52/500
# 585/585 [==============================] - 0s 82us/step - loss: 3441.1965 - mean_absolute_error: 3441.1965 - val_loss: 5067.8728 - val_mean_absolute_error: 5067.8728
#
# Epoch 00052: val_loss did not improve from 4137.27738
# Epoch 53/500
# 585/585 [==============================] - 0s 87us/step - loss: 3509.2984 - mean_absolute_error: 3509.2984 - val_loss: 4997.4928 - val_mean_absolute_error: 4997.4928
#
# Epoch 00053: val_loss did not improve from 4137.27738
# Epoch 54/500
# 585/585 [==============================] - 0s 85us/step - loss: 3431.0697 - mean_absolute_error: 3431.0697 - val_loss: 5967.9264 - val_mean_absolute_error: 5967.9264
#
# Epoch 00054: val_loss did not improve from 4137.27738
# Epoch 55/500
# 585/585 [==============================] - 0s 104us/step - loss: 3467.1123 - mean_absolute_error: 3467.1123 - val_loss: 6391.2141 - val_mean_absolute_error: 6391.2141
#
# Epoch 00055: val_loss did not improve from 4137.27738
# Epoch 56/500
# 585/585 [==============================] - 0s 87us/step - loss: 3465.5503 - mean_absolute_error: 3465.5503 - val_loss: 5491.1058 - val_mean_absolute_error: 5491.1058
#
# Epoch 00056: val_loss did not improve from 4137.27738
# Epoch 57/500
# 585/585 [==============================] - 0s 85us/step - loss: 3428.0749 - mean_absolute_error: 3428.0749 - val_loss: 5845.3447 - val_mean_absolute_error: 5845.3447
#
# Epoch 00057: val_loss did not improve from 4137.27738
# Epoch 58/500
# 585/585 [==============================] - 0s 84us/step - loss: 3476.3105 - mean_absolute_error: 3476.3105 - val_loss: 5696.3185 - val_mean_absolute_error: 5696.3185
#
# Epoch 00058: val_loss did not improve from 4137.27738
# Epoch 59/500
# 585/585 [==============================] - 0s 101us/step - loss: 3443.8434 - mean_absolute_error: 3443.8434 - val_loss: 5340.4711 - val_mean_absolute_error: 5340.4711
#
# Epoch 00059: val_loss did not improve from 4137.27738
# Epoch 60/500
# 585/585 [==============================] - 0s 89us/step - loss: 3512.4542 - mean_absolute_error: 3512.4542 - val_loss: 4754.7218 - val_mean_absolute_error: 4754.7218
#
# Epoch 00060: val_loss did not improve from 4137.27738
# Epoch 61/500
# 585/585 [==============================] - 0s 87us/step - loss: 3440.3135 - mean_absolute_error: 3440.3135 - val_loss: 6344.1901 - val_mean_absolute_error: 6344.1901
#
# Epoch 00061: val_loss did not improve from 4137.27738
# Epoch 62/500
# 585/585 [==============================] - 0s 90us/step - loss: 3478.2281 - mean_absolute_error: 3478.2281 - val_loss: 5378.3826 - val_mean_absolute_error: 5378.3826
#
# Epoch 00062: val_loss did not improve from 4137.27738
# Epoch 63/500
# 585/585 [==============================] - 0s 87us/step - loss: 3401.3472 - mean_absolute_error: 3401.3472 - val_loss: 5174.6987 - val_mean_absolute_error: 5174.6987
#
# Epoch 00063: val_loss did not improve from 4137.27738
# Epoch 64/500
# 585/585 [==============================] - 0s 87us/step - loss: 3449.7850 - mean_absolute_error: 3449.7850 - val_loss: 5529.7037 - val_mean_absolute_error: 5529.7037
#
# Epoch 00064: val_loss did not improve from 4137.27738
# Epoch 65/500
# 585/585 [==============================] - 0s 95us/step - loss: 3440.0714 - mean_absolute_error: 3440.0714 - val_loss: 5345.5105 - val_mean_absolute_error: 5345.5105
#
# Epoch 00065: val_loss did not improve from 4137.27738
# Epoch 66/500
# 585/585 [==============================] - 0s 97us/step - loss: 3441.4536 - mean_absolute_error: 3441.4536 - val_loss: 5950.0328 - val_mean_absolute_error: 5950.0328
#
# Epoch 00066: val_loss did not improve from 4137.27738
# Epoch 67/500
# 585/585 [==============================] - 0s 92us/step - loss: 3410.3992 - mean_absolute_error: 3410.3992 - val_loss: 5723.6859 - val_mean_absolute_error: 5723.6859
#
# Epoch 00067: val_loss did not improve from 4137.27738
# Epoch 68/500
# 585/585 [==============================] - 0s 94us/step - loss: 3384.7460 - mean_absolute_error: 3384.7460 - val_loss: 4726.0729 - val_mean_absolute_error: 4726.0729
#
# Epoch 00068: val_loss did not improve from 4137.27738
# Epoch 69/500
# 585/585 [==============================] - 0s 94us/step - loss: 3494.7028 - mean_absolute_error: 3494.7028 - val_loss: 5598.7285 - val_mean_absolute_error: 5598.7285
#
# Epoch 00069: val_loss did not improve from 4137.27738
# Epoch 70/500
# 585/585 [==============================] - 0s 92us/step - loss: 3431.3532 - mean_absolute_error: 3431.3532 - val_loss: 5688.8995 - val_mean_absolute_error: 5688.8995
#
# Epoch 00070: val_loss did not improve from 4137.27738
# Epoch 71/500
# 585/585 [==============================] - 0s 102us/step - loss: 3395.7539 - mean_absolute_error: 3395.7539 - val_loss: 5033.3298 - val_mean_absolute_error: 5033.3298
#
# Epoch 00071: val_loss did not improve from 4137.27738
# Epoch 72/500
# 585/585 [==============================] - 0s 109us/step - loss: 3466.3370 - mean_absolute_error: 3466.3370 - val_loss: 5978.9625 - val_mean_absolute_error: 5978.9625
#
# Epoch 00072: val_loss did not improve from 4137.27738
# Epoch 73/500
# 585/585 [==============================] - 0s 102us/step - loss: 3473.5015 - mean_absolute_error: 3473.5015 - val_loss: 5834.6855 - val_mean_absolute_error: 5834.6855
#
# Epoch 00073: val_loss did not improve from 4137.27738
# Epoch 74/500
# 585/585 [==============================] - 0s 97us/step - loss: 3460.3475 - mean_absolute_error: 3460.3475 - val_loss: 5548.9037 - val_mean_absolute_error: 5548.9037
#
# Epoch 00074: val_loss did not improve from 4137.27738
# Epoch 75/500
# 585/585 [==============================] - 0s 114us/step - loss: 3393.1335 - mean_absolute_error: 3393.1335 - val_loss: 5649.6702 - val_mean_absolute_error: 5649.6702
#
# Epoch 00075: val_loss did not improve from 4137.27738
# Epoch 76/500
# 585/585 [==============================] - 0s 121us/step - loss: 3410.4775 - mean_absolute_error: 3410.4775 - val_loss: 5313.7553 - val_mean_absolute_error: 5313.7553
#
# Epoch 00076: val_loss did not improve from 4137.27738
# Epoch 77/500
# 585/585 [==============================] - 0s 118us/step - loss: 3440.1055 - mean_absolute_error: 3440.1055 - val_loss: 4341.9477 - val_mean_absolute_error: 4341.9477
#
# Epoch 00077: val_loss did not improve from 4137.27738
# Epoch 78/500
# 585/585 [==============================] - 0s 130us/step - loss: 3547.4806 - mean_absolute_error: 3547.4806 - val_loss: 4426.4721 - val_mean_absolute_error: 4426.4721
#
# Epoch 00078: val_loss did not improve from 4137.27738
# Epoch 79/500
# 585/585 [==============================] - 0s 107us/step - loss: 3499.4006 - mean_absolute_error: 3499.4006 - val_loss: 3708.7906 - val_mean_absolute_error: 3708.7906
#
# Epoch 00079: val_loss improved from 4137.27738 to 3708.79060, saving model to 아이스크림date-Weights-079--3708.79060-cat02-vf05.hdf5
# Epoch 80/500
# 585/585 [==============================] - 0s 106us/step - loss: 3553.0135 - mean_absolute_error: 3553.0135 - val_loss: 5424.1021 - val_mean_absolute_error: 5424.1021
#
# Epoch 00080: val_loss did not improve from 3708.79060
# Epoch 81/500
# 585/585 [==============================] - 0s 99us/step - loss: 3386.1864 - mean_absolute_error: 3386.1864 - val_loss: 5426.2525 - val_mean_absolute_error: 5426.2525
#
# Epoch 00081: val_loss did not improve from 3708.79060
# Epoch 82/500
# 585/585 [==============================] - 0s 114us/step - loss: 3404.1946 - mean_absolute_error: 3404.1946 - val_loss: 5486.7686 - val_mean_absolute_error: 5486.7686
#
# Epoch 00082: val_loss did not improve from 3708.79060
# Epoch 83/500
# 585/585 [==============================] - 0s 111us/step - loss: 3511.3331 - mean_absolute_error: 3511.3331 - val_loss: 5809.9415 - val_mean_absolute_error: 5809.9415
#
# Epoch 00083: val_loss did not improve from 3708.79060
# Epoch 84/500
# 585/585 [==============================] - 0s 109us/step - loss: 3411.6640 - mean_absolute_error: 3411.6640 - val_loss: 5972.2222 - val_mean_absolute_error: 5972.2222
#
# Epoch 00084: val_loss did not improve from 3708.79060
# Epoch 85/500
# 585/585 [==============================] - 0s 119us/step - loss: 3370.9547 - mean_absolute_error: 3370.9547 - val_loss: 5377.5816 - val_mean_absolute_error: 5377.5816
#
# Epoch 00085: val_loss did not improve from 3708.79060
# Epoch 86/500
# 585/585 [==============================] - 0s 104us/step - loss: 3483.2249 - mean_absolute_error: 3483.2249 - val_loss: 4886.8651 - val_mean_absolute_error: 4886.8651
#
# Epoch 00086: val_loss did not improve from 3708.79060
# Epoch 87/500
# 585/585 [==============================] - 0s 113us/step - loss: 3389.3702 - mean_absolute_error: 3389.3702 - val_loss: 5340.2977 - val_mean_absolute_error: 5340.2977
#
# Epoch 00087: val_loss did not improve from 3708.79060
# Epoch 88/500
# 585/585 [==============================] - 0s 109us/step - loss: 3394.3514 - mean_absolute_error: 3394.3514 - val_loss: 5776.8142 - val_mean_absolute_error: 5776.8142
#
# Epoch 00088: val_loss did not improve from 3708.79060
# Epoch 89/500
# 585/585 [==============================] - 0s 95us/step - loss: 3371.5614 - mean_absolute_error: 3371.5614 - val_loss: 5335.1214 - val_mean_absolute_error: 5335.1214
#
# Epoch 00089: val_loss did not improve from 3708.79060
# Epoch 90/500
# 585/585 [==============================] - 0s 102us/step - loss: 3407.6666 - mean_absolute_error: 3407.6666 - val_loss: 6014.9986 - val_mean_absolute_error: 6014.9986
#
# Epoch 00090: val_loss did not improve from 3708.79060
# Epoch 91/500
# 585/585 [==============================] - 0s 119us/step - loss: 3469.4426 - mean_absolute_error: 3469.4426 - val_loss: 4561.7645 - val_mean_absolute_error: 4561.7645
#
# Epoch 00091: val_loss did not improve from 3708.79060
# Epoch 92/500
# 585/585 [==============================] - 0s 107us/step - loss: 3515.8478 - mean_absolute_error: 3515.8478 - val_loss: 5720.2516 - val_mean_absolute_error: 5720.2516
#
# Epoch 00092: val_loss did not improve from 3708.79060
# Epoch 93/500
# 585/585 [==============================] - 0s 106us/step - loss: 3404.6868 - mean_absolute_error: 3404.6868 - val_loss: 5128.8160 - val_mean_absolute_error: 5128.8160
#
# Epoch 00093: val_loss did not improve from 3708.79060
# Epoch 94/500
# 585/585 [==============================] - 0s 109us/step - loss: 3377.1632 - mean_absolute_error: 3377.1632 - val_loss: 5270.4969 - val_mean_absolute_error: 5270.4969
#
# Epoch 00094: val_loss did not improve from 3708.79060
# Epoch 95/500
# 585/585 [==============================] - 0s 113us/step - loss: 3376.6936 - mean_absolute_error: 3376.6936 - val_loss: 6041.8774 - val_mean_absolute_error: 6041.8774
#
# Epoch 00095: val_loss did not improve from 3708.79060
# Epoch 96/500
# 585/585 [==============================] - 0s 119us/step - loss: 3507.9270 - mean_absolute_error: 3507.9270 - val_loss: 5659.3650 - val_mean_absolute_error: 5659.3650
#
# Epoch 00096: val_loss did not improve from 3708.79060
# Epoch 97/500
# 585/585 [==============================] - 0s 118us/step - loss: 3361.6031 - mean_absolute_error: 3361.6031 - val_loss: 5115.0787 - val_mean_absolute_error: 5115.0787
#
# Epoch 00097: val_loss did not improve from 3708.79060
# Epoch 98/500
# 585/585 [==============================] - 0s 128us/step - loss: 3438.1122 - mean_absolute_error: 3438.1122 - val_loss: 4690.0513 - val_mean_absolute_error: 4690.0513
#
# Epoch 00098: val_loss did not improve from 3708.79060
# Epoch 99/500
# 585/585 [==============================] - 0s 111us/step - loss: 3537.0314 - mean_absolute_error: 3537.0314 - val_loss: 4967.1339 - val_mean_absolute_error: 4967.1339
#
# Epoch 00099: val_loss did not improve from 3708.79060
# Epoch 100/500
# 585/585 [==============================] - 0s 109us/step - loss: 3349.8482 - mean_absolute_error: 3349.8482 - val_loss: 5594.4554 - val_mean_absolute_error: 5594.4554
#
# Epoch 00100: val_loss did not improve from 3708.79060
# Epoch 101/500
# 585/585 [==============================] - 0s 102us/step - loss: 3343.8413 - mean_absolute_error: 3343.8413 - val_loss: 5616.6205 - val_mean_absolute_error: 5616.6205
#
# Epoch 00101: val_loss did not improve from 3708.79060
# Epoch 102/500
# 585/585 [==============================] - 0s 99us/step - loss: 3371.9627 - mean_absolute_error: 3371.9627 - val_loss: 5879.9456 - val_mean_absolute_error: 5879.9456
# Epoch 00102: val_loss did not improve from 3708.79060
# Epoch 103/500
# 585/585 [==============================] - 0s 128us/step - loss: 3404.8732 - mean_absolute_error: 3404.8732 - val_loss: 5895.7922 - val_mean_absolute_error: 5895.7922
#
# Epoch 00103: val_loss did not improve from 3708.79060
# Epoch 104/500
# 585/585 [==============================] - 0s 123us/step - loss: 3362.9420 - mean_absolute_error: 3362.9420 - val_loss: 5094.0567 - val_mean_absolute_error: 5094.0567
#
# Epoch 00104: val_loss did not improve from 3708.79060
# Epoch 105/500
# 585/585 [==============================] - 0s 121us/step - loss: 3369.6697 - mean_absolute_error: 3369.6697 - val_loss: 5934.3839 - val_mean_absolute_error: 5934.3839
#
# Epoch 00105: val_loss did not improve from 3708.79060
# Epoch 106/500
# 585/585 [==============================] - 0s 121us/step - loss: 3402.9311 - mean_absolute_error: 3402.9311 - val_loss: 4913.8162 - val_mean_absolute_error: 4913.8162
#
# Epoch 00106: val_loss did not improve from 3708.79060
# Epoch 107/500
# 585/585 [==============================] - 0s 114us/step - loss: 3420.5914 - mean_absolute_error: 3420.5914 - val_loss: 6173.3840 - val_mean_absolute_error: 6173.3840
#
# Epoch 00107: val_loss did not improve from 3708.79060
# Epoch 108/500
# 585/585 [==============================] - 0s 116us/step - loss: 3363.6140 - mean_absolute_error: 3363.6140 - val_loss: 5560.6471 - val_mean_absolute_error: 5560.6471
#
# Epoch 00108: val_loss did not improve from 3708.79060
# Epoch 109/500
# 585/585 [==============================] - 0s 116us/step - loss: 3334.9288 - mean_absolute_error: 3334.9288 - val_loss: 5311.7809 - val_mean_absolute_error: 5311.7809
#
# Epoch 00109: val_loss did not improve from 3708.79060
# Epoch 110/500
# 585/585 [==============================] - 0s 113us/step - loss: 3383.2959 - mean_absolute_error: 3383.2959 - val_loss: 4579.4718 - val_mean_absolute_error: 4579.4718
#
# Epoch 00110: val_loss did not improve from 3708.79060
# Epoch 111/500
# 585/585 [==============================] - 0s 114us/step - loss: 3327.3696 - mean_absolute_error: 3327.3696 - val_loss: 4457.4204 - val_mean_absolute_error: 4457.4204
#
# Epoch 00111: val_loss did not improve from 3708.79060
# Epoch 112/500
# 585/585 [==============================] - 0s 109us/step - loss: 3390.0746 - mean_absolute_error: 3390.0746 - val_loss: 4763.9135 - val_mean_absolute_error: 4763.9135
#
# Epoch 00112: val_loss did not improve from 3708.79060
# Epoch 113/500
# 585/585 [==============================] - 0s 123us/step - loss: 3395.2626 - mean_absolute_error: 3395.2626 - val_loss: 4995.2511 - val_mean_absolute_error: 4995.2511
#
# Epoch 00113: val_loss did not improve from 3708.79060
# Epoch 114/500
# 585/585 [==============================] - 0s 121us/step - loss: 3346.4963 - mean_absolute_error: 3346.4963 - val_loss: 5976.2642 - val_mean_absolute_error: 5976.2642
#
# Epoch 00114: val_loss did not improve from 3708.79060
# Epoch 115/500
# 585/585 [==============================] - 0s 131us/step - loss: 3320.4107 - mean_absolute_error: 3320.4107 - val_loss: 5138.8818 - val_mean_absolute_error: 5138.8818
#
# Epoch 00115: val_loss did not improve from 3708.79060
# Epoch 116/500
# 585/585 [==============================] - 0s 130us/step - loss: 3338.2159 - mean_absolute_error: 3338.2159 - val_loss: 6397.3569 - val_mean_absolute_error: 6397.3569
#
# Epoch 00116: val_loss did not improve from 3708.79060
# Epoch 117/500
# 585/585 [==============================] - 0s 114us/step - loss: 3371.0708 - mean_absolute_error: 3371.0708 - val_loss: 5251.1053 - val_mean_absolute_error: 5251.1053
#
# Epoch 00117: val_loss did not improve from 3708.79060
# Epoch 118/500
# 585/585 [==============================] - 0s 124us/step - loss: 3385.5726 - mean_absolute_error: 3385.5726 - val_loss: 4397.5284 - val_mean_absolute_error: 4397.5284
#
# Epoch 00118: val_loss did not improve from 3708.79060
# Epoch 119/500
# 585/585 [==============================] - 0s 126us/step - loss: 3345.4942 - mean_absolute_error: 3345.4942 - val_loss: 6087.3139 - val_mean_absolute_error: 6087.3139
#
# Epoch 00119: val_loss did not improve from 3708.79060
# Epoch 120/500
# 585/585 [==============================] - 0s 111us/step - loss: 3320.4255 - mean_absolute_error: 3320.4255 - val_loss: 6445.2090 - val_mean_absolute_error: 6445.2090
#
# Epoch 00120: val_loss did not improve from 3708.79060
# Epoch 121/500
# 585/585 [==============================] - 0s 111us/step - loss: 3431.9146 - mean_absolute_error: 3431.9146 - val_loss: 5117.1319 - val_mean_absolute_error: 5117.1319
#
# Epoch 00121: val_loss did not improve from 3708.79060
# Epoch 122/500
# 585/585 [==============================] - 0s 107us/step - loss: 3341.6905 - mean_absolute_error: 3341.6905 - val_loss: 5074.9787 - val_mean_absolute_error: 5074.9787
#
# Epoch 00122: val_loss did not improve from 3708.79060
# Epoch 123/500
# 585/585 [==============================] - 0s 102us/step - loss: 3317.1321 - mean_absolute_error: 3317.1321 - val_loss: 4619.1078 - val_mean_absolute_error: 4619.1078
#
# Epoch 00123: val_loss did not improve from 3708.79060
# Epoch 124/500
# 585/585 [==============================] - 0s 111us/step - loss: 3370.6068 - mean_absolute_error: 3370.6068 - val_loss: 5626.5781 - val_mean_absolute_error: 5626.5781
#
# Epoch 00124: val_loss did not improve from 3708.79060
# Epoch 125/500
# 585/585 [==============================] - 0s 123us/step - loss: 3328.1887 - mean_absolute_error: 3328.1887 - val_loss: 4975.0033 - val_mean_absolute_error: 4975.0033
#
# Epoch 00125: val_loss did not improve from 3708.79060
# Epoch 126/500
# 585/585 [==============================] - 0s 111us/step - loss: 3298.1196 - mean_absolute_error: 3298.1196 - val_loss: 5550.1492 - val_mean_absolute_error: 5550.1492
#
# Epoch 00126: val_loss did not improve from 3708.79060
# Epoch 127/500
# 585/585 [==============================] - 0s 113us/step - loss: 3431.6180 - mean_absolute_error: 3431.6180 - val_loss: 5298.7344 - val_mean_absolute_error: 5298.7344
#
# Epoch 00127: val_loss did not improve from 3708.79060
# Epoch 128/500
# 585/585 [==============================] - 0s 107us/step - loss: 3305.8564 - mean_absolute_error: 3305.8564 - val_loss: 5812.2073 - val_mean_absolute_error: 5812.2073
#
# Epoch 00128: val_loss did not improve from 3708.79060
# Epoch 129/500
# 585/585 [==============================] - 0s 126us/step - loss: 3304.8114 - mean_absolute_error: 3304.8114 - val_loss: 5267.6501 - val_mean_absolute_error: 5267.6501
#
# Epoch 00129: val_loss did not improve from 3708.79060
# Epoch 130/500
# 585/585 [==============================] - 0s 128us/step - loss: 3319.1556 - mean_absolute_error: 3319.1556 - val_loss: 5414.1202 - val_mean_absolute_error: 5414.1202
#
# Epoch 00130: val_loss did not improve from 3708.79060
# Epoch 131/500
# 585/585 [==============================] - 0s 123us/step - loss: 3446.9451 - mean_absolute_error: 3446.9451 - val_loss: 5246.6281 - val_mean_absolute_error: 5246.6281
#
# Epoch 00131: val_loss did not improve from 3708.79060
# Epoch 132/500
# 585/585 [==============================] - 0s 130us/step - loss: 3313.1511 - mean_absolute_error: 3313.1511 - val_loss: 5934.9370 - val_mean_absolute_error: 5934.9370
#
# Epoch 00132: val_loss did not improve from 3708.79060
# Epoch 133/500
# 585/585 [==============================] - 0s 124us/step - loss: 3327.0711 - mean_absolute_error: 3327.0711 - val_loss: 5972.8564 - val_mean_absolute_error: 5972.8564
#
# Epoch 00133: val_loss did not improve from 3708.79060
# Epoch 134/500
# 585/585 [==============================] - 0s 135us/step - loss: 3288.3673 - mean_absolute_error: 3288.3673 - val_loss: 4344.7225 - val_mean_absolute_error: 4344.7225
#
# Epoch 00134: val_loss did not improve from 3708.79060
# Epoch 135/500
# 585/585 [==============================] - 0s 126us/step - loss: 3448.0794 - mean_absolute_error: 3448.0794 - val_loss: 4846.6804 - val_mean_absolute_error: 4846.6804
#
# Epoch 00135: val_loss did not improve from 3708.79060
# Epoch 136/500
# 585/585 [==============================] - 0s 133us/step - loss: 3345.5968 - mean_absolute_error: 3345.5968 - val_loss: 5205.8298 - val_mean_absolute_error: 5205.8298
#
# Epoch 00136: val_loss did not improve from 3708.79060
# Epoch 137/500
# 585/585 [==============================] - 0s 116us/step - loss: 3389.3663 - mean_absolute_error: 3389.3663 - val_loss: 4306.0891 - val_mean_absolute_error: 4306.0891
#
# Epoch 00137: val_loss did not improve from 3708.79060
# Epoch 138/500
# 585/585 [==============================] - 0s 124us/step - loss: 3378.3047 - mean_absolute_error: 3378.3047 - val_loss: 4896.9825 - val_mean_absolute_error: 4896.9825
#
# Epoch 00138: val_loss did not improve from 3708.79060
# Epoch 139/500
# 585/585 [==============================] - 0s 135us/step - loss: 3346.9396 - mean_absolute_error: 3346.9396 - val_loss: 5021.8120 - val_mean_absolute_error: 5021.8120
#
# Epoch 00139: val_loss did not improve from 3708.79060
# Epoch 140/500
# 585/585 [==============================] - 0s 114us/step - loss: 3295.6363 - mean_absolute_error: 3295.6363 - val_loss: 5698.3469 - val_mean_absolute_error: 5698.3469
#
# Epoch 00140: val_loss did not improve from 3708.79060
# Epoch 141/500
# 585/585 [==============================] - 0s 128us/step - loss: 3288.1274 - mean_absolute_error: 3288.1274 - val_loss: 4676.5886 - val_mean_absolute_error: 4676.5886
#
# Epoch 00141: val_loss did not improve from 3708.79060
# Epoch 142/500
# 585/585 [==============================] - 0s 128us/step - loss: 3326.6176 - mean_absolute_error: 3326.6176 - val_loss: 5284.4616 - val_mean_absolute_error: 5284.4616
#
# Epoch 00142: val_loss did not improve from 3708.79060
# Epoch 143/500
# 585/585 [==============================] - 0s 119us/step - loss: 3331.4583 - mean_absolute_error: 3331.4583 - val_loss: 5443.2449 - val_mean_absolute_error: 5443.2449
#
# Epoch 00143: val_loss did not improve from 3708.79060
# Epoch 144/500
# 585/585 [==============================] - 0s 118us/step - loss: 3299.4125 - mean_absolute_error: 3299.4125 - val_loss: 5481.1947 - val_mean_absolute_error: 5481.1947
#
# Epoch 00144: val_loss did not improve from 3708.79060
# Epoch 145/500
# 585/585 [==============================] - 0s 128us/step - loss: 3331.8193 - mean_absolute_error: 3331.8193 - val_loss: 5278.3704 - val_mean_absolute_error: 5278.3704
#
# Epoch 00145: val_loss did not improve from 3708.79060
# Epoch 146/500
# 585/585 [==============================] - 0s 128us/step - loss: 3312.4481 - mean_absolute_error: 3312.4481 - val_loss: 5030.6184 - val_mean_absolute_error: 5030.6184
#
# Epoch 00146: val_loss did not improve from 3708.79060
# Epoch 147/500
# 585/585 [==============================] - 0s 123us/step - loss: 3305.1876 - mean_absolute_error: 3305.1876 - val_loss: 5951.6773 - val_mean_absolute_error: 5951.6773
#
# Epoch 00147: val_loss did not improve from 3708.79060
# Epoch 148/500
# 585/585 [==============================] - 0s 126us/step - loss: 3424.3481 - mean_absolute_error: 3424.3481 - val_loss: 5911.2064 - val_mean_absolute_error: 5911.2064
#
# Epoch 00148: val_loss did not improve from 3708.79060
# Epoch 149/500
# 585/585 [==============================] - 0s 140us/step - loss: 3408.4569 - mean_absolute_error: 3408.4569 - val_loss: 5138.3461 - val_mean_absolute_error: 5138.3461
#
# Epoch 00149: val_loss did not improve from 3708.79060
# Epoch 150/500
# 585/585 [==============================] - 0s 130us/step - loss: 3282.9870 - mean_absolute_error: 3282.9870 - val_loss: 4942.1155 - val_mean_absolute_error: 4942.1155
#
# Epoch 00150: val_loss did not improve from 3708.79060
# Epoch 151/500
# 585/585 [==============================] - 0s 148us/step - loss: 3311.6138 - mean_absolute_error: 3311.6138 - val_loss: 4956.4393 - val_mean_absolute_error: 4956.4393
#
# Epoch 00151: val_loss did not improve from 3708.79060
# Epoch 152/500
# 585/585 [==============================] - 0s 123us/step - loss: 3359.6746 - mean_absolute_error: 3359.6746 - val_loss: 5200.9136 - val_mean_absolute_error: 5200.9136
#
# Epoch 00152: val_loss did not improve from 3708.79060
# Epoch 153/500
# 585/585 [==============================] - 0s 135us/step - loss: 3308.5550 - mean_absolute_error: 3308.5550 - val_loss: 4662.3842 - val_mean_absolute_error: 4662.3842
#
# Epoch 00153: val_loss did not improve from 3708.79060
# Epoch 154/500
# 585/585 [==============================] - 0s 126us/step - loss: 3329.1908 - mean_absolute_error: 3329.1908 - val_loss: 3657.3504 - val_mean_absolute_error: 3657.3504
#
# Epoch 00154: val_loss improved from 3708.79060 to 3657.35040, saving model to 아이스크림date-Weights-154--3657.35040-cat02-vf05.hdf5
# Epoch 155/500
# 585/585 [==============================] - 0s 140us/step - loss: 3491.8690 - mean_absolute_error: 3491.8690 - val_loss: 4632.4931 - val_mean_absolute_error: 4632.4931
#
# Epoch 00155: val_loss did not improve from 3657.35040
# Epoch 156/500
# 585/585 [==============================] - 0s 131us/step - loss: 3332.7808 - mean_absolute_error: 3332.7808 - val_loss: 4469.2865 - val_mean_absolute_error: 4469.2865
#
# Epoch 00156: val_loss did not improve from 3657.35040
# Epoch 157/500
# 585/585 [==============================] - 0s 121us/step - loss: 3332.4791 - mean_absolute_error: 3332.4791 - val_loss: 5093.4935 - val_mean_absolute_error: 5093.4935
#
# Epoch 00157: val_loss did not improve from 3657.35040
# Epoch 158/500
# 585/585 [==============================] - 0s 123us/step - loss: 3255.8161 - mean_absolute_error: 3255.8161 - val_loss: 4400.5495 - val_mean_absolute_error: 4400.5495
#
# Epoch 00158: val_loss did not improve from 3657.35040
# Epoch 159/500
# 585/585 [==============================] - 0s 123us/step - loss: 3393.6221 - mean_absolute_error: 3393.6221 - val_loss: 4119.5554 - val_mean_absolute_error: 4119.5554
#
# Epoch 00159: val_loss did not improve from 3657.35040
# Epoch 160/500
# 585/585 [==============================] - 0s 119us/step - loss: 3349.7192 - mean_absolute_error: 3349.7192 - val_loss: 4929.8358 - val_mean_absolute_error: 4929.8358
#
# Epoch 00160: val_loss did not improve from 3657.35040
# Epoch 161/500
# 585/585 [==============================] - 0s 119us/step - loss: 3252.0619 - mean_absolute_error: 3252.0619 - val_loss: 5256.2464 - val_mean_absolute_error: 5256.2464
#
# Epoch 00161: val_loss did not improve from 3657.35040
# Epoch 162/500
# 585/585 [==============================] - 0s 119us/step - loss: 3256.9371 - mean_absolute_error: 3256.9371 - val_loss: 4713.0456 - val_mean_absolute_error: 4713.0456
#
# Epoch 00162: val_loss did not improve from 3657.35040
# Epoch 163/500
# 585/585 [==============================] - 0s 201us/step - loss: 3292.5181 - mean_absolute_error: 3292.5181 - val_loss: 4778.6881 - val_mean_absolute_error: 4778.6881
#
# Epoch 00163: val_loss did not improve from 3657.35040
# Epoch 164/500
# 585/585 [==============================] - 0s 232us/step - loss: 3271.9447 - mean_absolute_error: 3271.9447 - val_loss: 4264.4712 - val_mean_absolute_error: 4264.4712
#
# Epoch 00164: val_loss did not improve from 3657.35040
# Epoch 165/500
# 585/585 [==============================] - 0s 126us/step - loss: 3279.5783 - mean_absolute_error: 3279.5783 - val_loss: 4874.5851 - val_mean_absolute_error: 4874.5851
#
# Epoch 00165: val_loss did not improve from 3657.35040
# Epoch 166/500
# 585/585 [==============================] - 0s 116us/step - loss: 3247.4381 - mean_absolute_error: 3247.4381 - val_loss: 5720.3403 - val_mean_absolute_error: 5720.3403
#
# Epoch 00166: val_loss did not improve from 3657.35040
# Epoch 167/500
# 585/585 [==============================] - 0s 131us/step - loss: 3297.8534 - mean_absolute_error: 3297.8534 - val_loss: 4908.9322 - val_mean_absolute_error: 4908.9322
#
# Epoch 00167: val_loss did not improve from 3657.35040
# Epoch 168/500
# 585/585 [==============================] - 0s 142us/step - loss: 3281.8340 - mean_absolute_error: 3281.8340 - val_loss: 6231.1754 - val_mean_absolute_error: 6231.1754
#
# Epoch 00168: val_loss did not improve from 3657.35040
# Epoch 169/500
# 585/585 [==============================] - 0s 142us/step - loss: 3457.8768 - mean_absolute_error: 3457.8768 - val_loss: 5694.0677 - val_mean_absolute_error: 5694.0677
#
# Epoch 00169: val_loss did not improve from 3657.35040
# Epoch 170/500
# 585/585 [==============================] - 0s 140us/step - loss: 3277.6698 - mean_absolute_error: 3277.6698 - val_loss: 5567.4674 - val_mean_absolute_error: 5567.4674
#
# Epoch 00170: val_loss did not improve from 3657.35040
# Epoch 171/500
# 585/585 [==============================] - 0s 131us/step - loss: 3303.3875 - mean_absolute_error: 3303.3875 - val_loss: 4786.1275 - val_mean_absolute_error: 4786.1275
#
# Epoch 00171: val_loss did not improve from 3657.35040
# Epoch 172/500
# 585/585 [==============================] - 0s 131us/step - loss: 3236.2441 - mean_absolute_error: 3236.2441 - val_loss: 4732.3012 - val_mean_absolute_error: 4732.3012
#
# Epoch 00172: val_loss did not improve from 3657.35040
# Epoch 173/500
# 585/585 [==============================] - 0s 142us/step - loss: 3380.0978 - mean_absolute_error: 3380.0978 - val_loss: 4437.1710 - val_mean_absolute_error: 4437.1710
#
# Epoch 00173: val_loss did not improve from 3657.35040
# Epoch 174/500
# 585/585 [==============================] - 0s 142us/step - loss: 3299.6975 - mean_absolute_error: 3299.6975 - val_loss: 4832.7066 - val_mean_absolute_error: 4832.7066
#
# Epoch 00174: val_loss did not improve from 3657.35040
# Epoch 175/500
# 585/585 [==============================] - 0s 145us/step - loss: 3244.0338 - mean_absolute_error: 3244.0338 - val_loss: 5447.0093 - val_mean_absolute_error: 5447.0093
#
# Epoch 00175: val_loss did not improve from 3657.35040
# Epoch 176/500
# 585/585 [==============================] - 0s 142us/step - loss: 3242.9501 - mean_absolute_error: 3242.9501 - val_loss: 5631.8681 - val_mean_absolute_error: 5631.8681
#
# Epoch 00176: val_loss did not improve from 3657.35040
# Epoch 177/500
# 585/585 [==============================] - 0s 133us/step - loss: 3272.7342 - mean_absolute_error: 3272.7342 - val_loss: 4939.7011 - val_mean_absolute_error: 4939.7011
#
# Epoch 00177: val_loss did not improve from 3657.35040
# Epoch 178/500
# 585/585 [==============================] - 0s 126us/step - loss: 3277.1900 - mean_absolute_error: 3277.1900 - val_loss: 4972.7933 - val_mean_absolute_error: 4972.7933
#
# Epoch 00178: val_loss did not improve from 3657.35040
# Epoch 179/500
# 585/585 [==============================] - 0s 128us/step - loss: 3337.2772 - mean_absolute_error: 3337.2772 - val_loss: 5525.2398 - val_mean_absolute_error: 5525.2398
#
# Epoch 00179: val_loss did not improve from 3657.35040
# Epoch 180/500
# 585/585 [==============================] - 0s 153us/step - loss: 3272.4923 - mean_absolute_error: 3272.4923 - val_loss: 5223.3122 - val_mean_absolute_error: 5223.3122
#
# Epoch 00180: val_loss did not improve from 3657.35040
# Epoch 181/500
# 585/585 [==============================] - 0s 142us/step - loss: 3248.2747 - mean_absolute_error: 3248.2747 - val_loss: 4775.9739 - val_mean_absolute_error: 4775.9739
#
# Epoch 00181: val_loss did not improve from 3657.35040
# Epoch 182/500
# 585/585 [==============================] - 0s 133us/step - loss: 3355.2317 - mean_absolute_error: 3355.2317 - val_loss: 4855.0605 - val_mean_absolute_error: 4855.0605
#
# Epoch 00182: val_loss did not improve from 3657.35040
# Epoch 183/500
# 585/585 [==============================] - 0s 135us/step - loss: 3271.7853 - mean_absolute_error: 3271.7853 - val_loss: 5527.8369 - val_mean_absolute_error: 5527.8369
#
# Epoch 00183: val_loss did not improve from 3657.35040
# Epoch 184/500
# 585/585 [==============================] - 0s 143us/step - loss: 3269.5808 - mean_absolute_error: 3269.5808 - val_loss: 5755.6400 - val_mean_absolute_error: 5755.6400
#
# Epoch 00184: val_loss did not improve from 3657.35040
# Epoch 185/500
# 585/585 [==============================] - 0s 140us/step - loss: 3229.3271 - mean_absolute_error: 3229.3271 - val_loss: 4775.7220 - val_mean_absolute_error: 4775.7220
#
# Epoch 00185: val_loss did not improve from 3657.35040
# Epoch 186/500
# 585/585 [==============================] - 0s 130us/step - loss: 3253.7057 - mean_absolute_error: 3253.7057 - val_loss: 4509.5614 - val_mean_absolute_error: 4509.5614
#
# Epoch 00186: val_loss did not improve from 3657.35040
# Epoch 187/500
# 585/585 [==============================] - 0s 131us/step - loss: 3296.2944 - mean_absolute_error: 3296.2944 - val_loss: 5334.5142 - val_mean_absolute_error: 5334.5142
#
# Epoch 00187: val_loss did not improve from 3657.35040
# Epoch 188/500
# 585/585 [==============================] - 0s 143us/step - loss: 3252.4893 - mean_absolute_error: 3252.4893 - val_loss: 5384.5618 - val_mean_absolute_error: 5384.5618
#
# Epoch 00188: val_loss did not improve from 3657.35040
# Epoch 189/500
# 585/585 [==============================] - 0s 136us/step - loss: 3290.9637 - mean_absolute_error: 3290.9637 - val_loss: 5736.4318 - val_mean_absolute_error: 5736.4318
#
# Epoch 00189: val_loss did not improve from 3657.35040
# Epoch 190/500
# 585/585 [==============================] - 0s 136us/step - loss: 3299.1243 - mean_absolute_error: 3299.1243 - val_loss: 4814.8988 - val_mean_absolute_error: 4814.8988
#
# Epoch 00190: val_loss did not improve from 3657.35040
# Epoch 191/500
# 585/585 [==============================] - 0s 150us/step - loss: 3209.8280 - mean_absolute_error: 3209.8280 - val_loss: 5810.2068 - val_mean_absolute_error: 5810.2068
#
# Epoch 00191: val_loss did not improve from 3657.35040
# Epoch 192/500
# 585/585 [==============================] - 0s 138us/step - loss: 3201.7453 - mean_absolute_error: 3201.7453 - val_loss: 4532.2820 - val_mean_absolute_error: 4532.2820
#
# Epoch 00192: val_loss did not improve from 3657.35040
# Epoch 193/500
# 585/585 [==============================] - 0s 133us/step - loss: 3263.0975 - mean_absolute_error: 3263.0975 - val_loss: 5394.6631 - val_mean_absolute_error: 5394.6631
#
# Epoch 00193: val_loss did not improve from 3657.35040
# Epoch 194/500
# 585/585 [==============================] - 0s 140us/step - loss: 3226.7373 - mean_absolute_error: 3226.7373 - val_loss: 4260.9434 - val_mean_absolute_error: 4260.9434
#
# Epoch 00194: val_loss did not improve from 3657.35040
# Epoch 195/500
# 585/585 [==============================] - 0s 133us/step - loss: 3224.2408 - mean_absolute_error: 3224.2408 - val_loss: 5355.9645 - val_mean_absolute_error: 5355.9645
#
# Epoch 00195: val_loss did not improve from 3657.35040
# Epoch 196/500
# 585/585 [==============================] - 0s 143us/step - loss: 3241.0307 - mean_absolute_error: 3241.0307 - val_loss: 6886.8693 - val_mean_absolute_error: 6886.8693
#
# Epoch 00196: val_loss did not improve from 3657.35040
# Epoch 197/500
# 585/585 [==============================] - 0s 152us/step - loss: 3407.9571 - mean_absolute_error: 3407.9571 - val_loss: 5685.3767 - val_mean_absolute_error: 5685.3767
#
# Epoch 00197: val_loss did not improve from 3657.35040
# Epoch 198/500
# 585/585 [==============================] - 0s 130us/step - loss: 3230.5423 - mean_absolute_error: 3230.5423 - val_loss: 5441.2470 - val_mean_absolute_error: 5441.2470
#
# Epoch 00198: val_loss did not improve from 3657.35040
# Epoch 199/500
# 585/585 [==============================] - 0s 130us/step - loss: 3223.6376 - mean_absolute_error: 3223.6376 - val_loss: 5205.8056 - val_mean_absolute_error: 5205.8056
#
# Epoch 00199: val_loss did not improve from 3657.35040
# Epoch 200/500
# ...
#
# Epoch 00433: val_loss did not improve from 3657.35040
# Epoch 434/500
# 585/585 [==============================] - 0s 145us/step - loss: 3038.6606 - mean_absolute_error: 3038.6606 - val_loss: 5377.9447 - val_mean_absolute_error: 5377.9447
#
# Epoch 00434: val_loss did not improve from 3657.35040
# Epoch 435/500
# 585/585 [==============================] - 0s 131us/step - loss: 3022.0134 - mean_absolute_error: 3022.0134 - val_loss: 5019.9850 - val_mean_absolute_error: 5019.9850
#
# Epoch 00435: val_loss did not improve from 3657.35040
# Epoch 436/500
# 585/585 [==============================] - 0s 145us/step - loss: 3048.0105 - mean_absolute_error: 3048.0105 - val_loss: 4436.2322 - val_mean_absolute_error: 4436.2322
#
# Epoch 00436: val_loss did not improve from 3657.35040
# Epoch 437/500
# 585/585 [==============================] - 0s 148us/step - loss: 3058.4603 - mean_absolute_error: 3058.4603 - val_loss: 4966.8756 - val_mean_absolute_error: 4966.8756
#
# Epoch 00437: val_loss did not improve from 3657.35040
# Epoch 438/500
# 585/585 [==============================] - 0s 133us/step - loss: 3018.3200 - mean_absolute_error: 3018.3200 - val_loss: 5324.3668 - val_mean_absolute_error: 5324.3668
#
# Epoch 00438: val_loss did not improve from 3657.35040
# Epoch 439/500
# 585/585 [==============================] - 0s 135us/step - loss: 3063.2839 - mean_absolute_error: 3063.2839 - val_loss: 5514.9554 - val_mean_absolute_error: 5514.9554
#
# Epoch 00439: val_loss did not improve from 3657.35040
# Epoch 440/500
# 585/585 [==============================] - 0s 143us/step - loss: 3046.2408 - mean_absolute_error: 3046.2408 - val_loss: 4980.9873 - val_mean_absolute_error: 4980.9873
#
# Epoch 00440: val_loss did not improve from 3657.35040
# Epoch 441/500
# 585/585 [==============================] - 0s 136us/step - loss: 3022.5164 - mean_absolute_error: 3022.5164 - val_loss: 4497.2402 - val_mean_absolute_error: 4497.2402
#
# Epoch 00441: val_loss did not improve from 3657.35040
# Epoch 442/500
# 585/585 [==============================] - 0s 135us/step - loss: 3056.0446 - mean_absolute_error: 3056.0446 - val_loss: 5178.4302 - val_mean_absolute_error: 5178.4302
#
# Epoch 00442: val_loss did not improve from 3657.35040
# Epoch 443/500
# 585/585 [==============================] - 0s 140us/step - loss: 3129.8609 - mean_absolute_error: 3129.8609 - val_loss: 5403.1639 - val_mean_absolute_error: 5403.1639
#
# Epoch 00443: val_loss did not improve from 3657.35040
# Epoch 444/500
# 585/585 [==============================] - 0s 140us/step - loss: 3005.7881 - mean_absolute_error: 3005.7881 - val_loss: 5049.4679 - val_mean_absolute_error: 5049.4679
#
# Epoch 00444: val_loss did not improve from 3657.35040
# Epoch 445/500
# 585/585 [==============================] - 0s 140us/step - loss: 3038.4301 - mean_absolute_error: 3038.4301 - val_loss: 4130.0499 - val_mean_absolute_error: 4130.0499
#
# Epoch 00445: val_loss did not improve from 3657.35040
# Epoch 446/500
# 585/585 [==============================] - 0s 133us/step - loss: 3028.4544 - mean_absolute_error: 3028.4544 - val_loss: 4815.3609 - val_mean_absolute_error: 4815.3609
#
# Epoch 00446: val_loss did not improve from 3657.35040
# Epoch 447/500
# 585/585 [==============================] - 0s 136us/step - loss: 2993.1856 - mean_absolute_error: 2993.1856 - val_loss: 4696.9124 - val_mean_absolute_error: 4696.9124
#
# Epoch 00447: val_loss did not improve from 3657.35040
# Epoch 448/500
# 585/585 [==============================] - 0s 135us/step - loss: 3059.2302 - mean_absolute_error: 3059.2302 - val_loss: 4371.3325 - val_mean_absolute_error: 4371.3325
#
# Epoch 00448: val_loss did not improve from 3657.35040
# Epoch 449/500
# 585/585 [==============================] - 0s 136us/step - loss: 3099.0780 - mean_absolute_error: 3099.0780 - val_loss: 4440.4089 - val_mean_absolute_error: 4440.4089
#
# Epoch 00449: val_loss did not improve from 3657.35040
# Epoch 450/500
# 585/585 [==============================] - 0s 135us/step - loss: 3024.0910 - mean_absolute_error: 3024.0910 - val_loss: 4890.7490 - val_mean_absolute_error: 4890.7490
#
# Epoch 00450: val_loss did not improve from 3657.35040
# Epoch 451/500
# 585/585 [==============================] - 0s 148us/step - loss: 3008.8444 - mean_absolute_error: 3008.8444 - val_loss: 5067.9914 - val_mean_absolute_error: 5067.9914
#
# Epoch 00451: val_loss did not improve from 3657.35040
# Epoch 452/500
# 585/585 [==============================] - 0s 182us/step - loss: 3094.7285 - mean_absolute_error: 3094.7285 - val_loss: 5068.7368 - val_mean_absolute_error: 5068.7368
#
# Epoch 00452: val_loss did not improve from 3657.35040
# Epoch 453/500
# 585/585 [==============================] - 0s 169us/step - loss: 3035.2986 - mean_absolute_error: 3035.2986 - val_loss: 4721.3988 - val_mean_absolute_error: 4721.3988
#
# Epoch 00453: val_loss did not improve from 3657.35040
# Epoch 454/500
# 585/585 [==============================] - 0s 174us/step - loss: 3035.3390 - mean_absolute_error: 3035.3390 - val_loss: 4851.8136 - val_mean_absolute_error: 4851.8136
#
# Epoch 00454: val_loss did not improve from 3657.35040
# Epoch 455/500
# 585/585 [==============================] - 0s 172us/step - loss: 3026.1738 - mean_absolute_error: 3026.1738 - val_loss: 4637.2422 - val_mean_absolute_error: 4637.2422
#
# Epoch 00455: val_loss did not improve from 3657.35040
# Epoch 456/500
# 585/585 [==============================] - 0s 182us/step - loss: 3068.7617 - mean_absolute_error: 3068.7617 - val_loss: 4352.9447 - val_mean_absolute_error: 4352.9447
#
# Epoch 00456: val_loss did not improve from 3657.35040
# Epoch 457/500
# 585/585 [==============================] - 0s 174us/step - loss: 3018.6840 - mean_absolute_error: 3018.6840 - val_loss: 5246.8087 - val_mean_absolute_error: 5246.8087
#
# Epoch 00457: val_loss did not improve from 3657.35040
# Epoch 458/500
# 585/585 [==============================] - 0s 196us/step - loss: 2996.0193 - mean_absolute_error: 2996.0193 - val_loss: 4962.4286 - val_mean_absolute_error: 4962.4286
#
# Epoch 00458: val_loss did not improve from 3657.35040
# Epoch 459/500
# 585/585 [==============================] - 0s 193us/step - loss: 3005.3802 - mean_absolute_error: 3005.3802 - val_loss: 4817.9038 - val_mean_absolute_error: 4817.9038
#
# Epoch 00459: val_loss did not improve from 3657.35040
# Epoch 460/500
# 585/585 [==============================] - 0s 199us/step - loss: 3012.0555 - mean_absolute_error: 3012.0555 - val_loss: 4927.4203 - val_mean_absolute_error: 4927.4203
#
# Epoch 00460: val_loss did not improve from 3657.35040
# Epoch 461/500
# 585/585 [==============================] - 0s 201us/step - loss: 3052.3810 - mean_absolute_error: 3052.3810 - val_loss: 5445.6544 - val_mean_absolute_error: 5445.6544
#
# Epoch 00461: val_loss did not improve from 3657.35040
# Epoch 462/500
# 585/585 [==============================] - 0s 189us/step - loss: 3043.9800 - mean_absolute_error: 3043.9800 - val_loss: 4743.0129 - val_mean_absolute_error: 4743.0129
#
# Epoch 00462: val_loss did not improve from 3657.35040
# Epoch 463/500
# 585/585 [==============================] - 0s 182us/step - loss: 3031.7078 - mean_absolute_error: 3031.7078 - val_loss: 4802.6780 - val_mean_absolute_error: 4802.6780
#
# Epoch 00463: val_loss did not improve from 3657.35040
# Epoch 464/500
# 585/585 [==============================] - 0s 205us/step - loss: 3033.4450 - mean_absolute_error: 3033.4450 - val_loss: 5304.7041 - val_mean_absolute_error: 5304.7041
#
# Epoch 00464: val_loss did not improve from 3657.35040
# Epoch 465/500
# 585/585 [==============================] - 0s 217us/step - loss: 2992.9028 - mean_absolute_error: 2992.9028 - val_loss: 5094.4571 - val_mean_absolute_error: 5094.4571
#
# Epoch 00465: val_loss did not improve from 3657.35040
# Epoch 466/500
# 585/585 [==============================] - 0s 189us/step - loss: 3014.6290 - mean_absolute_error: 3014.6290 - val_loss: 5575.1997 - val_mean_absolute_error: 5575.1997
#
# Epoch 00466: val_loss did not improve from 3657.35040
# Epoch 467/500
# 585/585 [==============================] - 0s 188us/step - loss: 3010.4946 - mean_absolute_error: 3010.4946 - val_loss: 5485.2379 - val_mean_absolute_error: 5485.2379
#
# Epoch 00467: val_loss did not improve from 3657.35040
# Epoch 468/500
# 585/585 [==============================] - 0s 189us/step - loss: 3054.7598 - mean_absolute_error: 3054.7598 - val_loss: 5848.6384 - val_mean_absolute_error: 5848.6384
#
# Epoch 00468: val_loss did not improve from 3657.35040
# Epoch 469/500
# 585/585 [==============================] - 0s 170us/step - loss: 3062.4705 - mean_absolute_error: 3062.4705 - val_loss: 5306.4535 - val_mean_absolute_error: 5306.4535
#
# Epoch 00469: val_loss did not improve from 3657.35040
# Epoch 470/500
# 585/585 [==============================] - 0s 181us/step - loss: 3047.2977 - mean_absolute_error: 3047.2977 - val_loss: 5121.9621 - val_mean_absolute_error: 5121.9621
#
# Epoch 00470: val_loss did not improve from 3657.35040
# Epoch 471/500
# 585/585 [==============================] - 0s 172us/step - loss: 3035.9428 - mean_absolute_error: 3035.9428 - val_loss: 5464.6660 - val_mean_absolute_error: 5464.6660
#
# Epoch 00471: val_loss did not improve from 3657.35040
# Epoch 472/500
# 585/585 [==============================] - 0s 181us/step - loss: 3069.6395 - mean_absolute_error: 3069.6395 - val_loss: 4700.5792 - val_mean_absolute_error: 4700.5792
#
# Epoch 00472: val_loss did not improve from 3657.35040
# Epoch 473/500
# 585/585 [==============================] - 0s 164us/step - loss: 3011.8200 - mean_absolute_error: 3011.8200 - val_loss: 4738.6964 - val_mean_absolute_error: 4738.6964
#
# Epoch 00473: val_loss did not improve from 3657.35040
# Epoch 474/500
# 585/585 [==============================] - 0s 165us/step - loss: 2948.0027 - mean_absolute_error: 2948.0027 - val_loss: 5175.9062 - val_mean_absolute_error: 5175.9062
#
# Epoch 00474: val_loss did not improve from 3657.35040
# Epoch 475/500
# 585/585 [==============================] - 0s 159us/step - loss: 2966.9208 - mean_absolute_error: 2966.9208 - val_loss: 4845.2183 - val_mean_absolute_error: 4845.2183
#
# Epoch 00475: val_loss did not improve from 3657.35040
# Epoch 476/500
# 585/585 [==============================] - 0s 155us/step - loss: 3035.7351 - mean_absolute_error: 3035.7351 - val_loss: 4021.3372 - val_mean_absolute_error: 4021.3372
#
# Epoch 00476: val_loss did not improve from 3657.35040
# Epoch 477/500
# 585/585 [==============================] - 0s 155us/step - loss: 3084.0501 - mean_absolute_error: 3084.0501 - val_loss: 5231.9041 - val_mean_absolute_error: 5231.9041
#
# Epoch 00477: val_loss did not improve from 3657.35040
# Epoch 478/500
# 585/585 [==============================] - 0s 155us/step - loss: 3033.2715 - mean_absolute_error: 3033.2715 - val_loss: 5473.2975 - val_mean_absolute_error: 5473.2975
#
# Epoch 00478: val_loss did not improve from 3657.35040
# Epoch 479/500
# 585/585 [==============================] - 0s 176us/step - loss: 3108.4750 - mean_absolute_error: 3108.4750 - val_loss: 5479.5934 - val_mean_absolute_error: 5479.5934
#
# Epoch 00479: val_loss did not improve from 3657.35040
# Epoch 480/500
# 585/585 [==============================] - 0s 150us/step - loss: 3029.5987 - mean_absolute_error: 3029.5987 - val_loss: 4751.7828 - val_mean_absolute_error: 4751.7828
#
# Epoch 00480: val_loss did not improve from 3657.35040
# Epoch 481/500
# 585/585 [==============================] - 0s 143us/step - loss: 3021.2436 - mean_absolute_error: 3021.2436 - val_loss: 4868.0080 - val_mean_absolute_error: 4868.0080
#
# Epoch 00481: val_loss did not improve from 3657.35040
# Epoch 482/500
# 585/585 [==============================] - 0s 143us/step - loss: 2985.7472 - mean_absolute_error: 2985.7472 - val_loss: 4599.4387 - val_mean_absolute_error: 4599.4387
#
# Epoch 00482: val_loss did not improve from 3657.35040
# Epoch 483/500
# 585/585 [==============================] - 0s 143us/step - loss: 2999.6339 - mean_absolute_error: 2999.6339 - val_loss: 4960.4809 - val_mean_absolute_error: 4960.4809
#
# Epoch 00483: val_loss did not improve from 3657.35040
# Epoch 484/500
# 585/585 [==============================] - 0s 162us/step - loss: 3049.4280 - mean_absolute_error: 3049.4280 - val_loss: 4814.8697 - val_mean_absolute_error: 4814.8697
#
# Epoch 00484: val_loss did not improve from 3657.35040
# Epoch 485/500
# 585/585 [==============================] - 0s 162us/step - loss: 2977.3867 - mean_absolute_error: 2977.3867 - val_loss: 4790.6232 - val_mean_absolute_error: 4790.6232
#
# Epoch 00485: val_loss did not improve from 3657.35040
# Epoch 486/500
# 585/585 [==============================] - 0s 142us/step - loss: 2971.4450 - mean_absolute_error: 2971.4450 - val_loss: 4649.4457 - val_mean_absolute_error: 4649.4457
#
# Epoch 00486: val_loss did not improve from 3657.35040
# Epoch 487/500
# 585/585 [==============================] - 0s 155us/step - loss: 3001.5447 - mean_absolute_error: 3001.5447 - val_loss: 4566.0816 - val_mean_absolute_error: 4566.0816
#
# Epoch 00487: val_loss did not improve from 3657.35040
# Epoch 488/500
# 585/585 [==============================] - 0s 167us/step - loss: 3051.4030 - mean_absolute_error: 3051.4030 - val_loss: 5654.3257 - val_mean_absolute_error: 5654.3257
#
# Epoch 00488: val_loss did not improve from 3657.35040
# Epoch 489/500
# 585/585 [==============================] - 0s 160us/step - loss: 2983.9589 - mean_absolute_error: 2983.9589 - val_loss: 4637.0291 - val_mean_absolute_error: 4637.0291
#
# Epoch 00489: val_loss did not improve from 3657.35040
# Epoch 490/500
# 585/585 [==============================] - 0s 160us/step - loss: 3073.2480 - mean_absolute_error: 3073.2480 - val_loss: 6427.0567 - val_mean_absolute_error: 6427.0567
#
# Epoch 00490: val_loss did not improve from 3657.35040
# Epoch 491/500
# 585/585 [==============================] - 0s 157us/step - loss: 3325.8020 - mean_absolute_error: 3325.8020 - val_loss: 6364.3349 - val_mean_absolute_error: 6364.3349
#
# Epoch 00491: val_loss did not improve from 3657.35040
# Epoch 492/500
# 585/585 [==============================] - 0s 164us/step - loss: 3127.6014 - mean_absolute_error: 3127.6014 - val_loss: 5048.5567 - val_mean_absolute_error: 5048.5567
#
# Epoch 00492: val_loss did not improve from 3657.35040
# Epoch 493/500
# 585/585 [==============================] - 0s 159us/step - loss: 3076.6242 - mean_absolute_error: 3076.6242 - val_loss: 4523.4111 - val_mean_absolute_error: 4523.4111
#
# Epoch 00493: val_loss did not improve from 3657.35040
# Epoch 494/500
# 585/585 [==============================] - 0s 169us/step - loss: 3002.7746 - mean_absolute_error: 3002.7746 - val_loss: 4366.1519 - val_mean_absolute_error: 4366.1519
#
# Epoch 00494: val_loss did not improve from 3657.35040
# Epoch 495/500
# 585/585 [==============================] - 0s 160us/step - loss: 3196.9895 - mean_absolute_error: 3196.9895 - val_loss: 4259.9968 - val_mean_absolute_error: 4259.9968
#
# Epoch 00495: val_loss did not improve from 3657.35040
# Epoch 496/500
# 585/585 [==============================] - 0s 172us/step - loss: 3076.8200 - mean_absolute_error: 3076.8200 - val_loss: 4850.3628 - val_mean_absolute_error: 4850.3628
#
# Epoch 00496: val_loss did not improve from 3657.35040
# Epoch 497/500
# 585/585 [==============================] - 0s 182us/step - loss: 2995.9467 - mean_absolute_error: 2995.9467 - val_loss: 5255.3814 - val_mean_absolute_error: 5255.3814
#
# Epoch 00497: val_loss did not improve from 3657.35040
# Epoch 498/500
# 585/585 [==============================] - 0s 160us/step - loss: 2996.2845 - mean_absolute_error: 2996.2845 - val_loss: 4704.9990 - val_mean_absolute_error: 4704.9990
#
# Epoch 00498: val_loss did not improve from 3657.35040
# Epoch 499/500
# 585/585 [==============================] - 0s 162us/step - loss: 2997.2049 - mean_absolute_error: 2997.2049 - val_loss: 5509.5836 - val_mean_absolute_error: 5509.5836
#
# Epoch 00499: val_loss did not improve from 3657.35040
# Epoch 500/500
# 585/585 [==============================] - 0s 177us/step - loss: 3004.9931 - mean_absolute_error: 3004.9931 - val_loss: 4289.7998 - val_mean_absolute_error: 4289.7998
#
# Epoch 00500: val_loss did not improve from 3657.35040

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = '아이스크림date-Weights-394--3850.32151-cat02-vf05.hdf5'
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']

print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

columns_in_data = list(train_X.columns)
customF = formulaGen(target='qty',ind_features=columns_in_data)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
print('검증세트점수 : {:.3f}'.format( r2_score(val_y, olsModel.predict(val_X))   ) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.976
# 검증세트점수 : 0.808
# XGBoost을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.926
# 검증세트점수 : 0.835
# LinearRegression을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.751
# 검증세트점수 : 0.713
# RidgeRegression을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.742
# 검증세트점수 : 0.711
# LassoRegression을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.751
# 검증세트점수 : 0.713
# OLS을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.751
# 검증세트점수 : 0.713

# %%
print(item, 'ols model')
# ind_features = 넣고 싶은 독립변수를 리스트로 넣어주면 알아서 formula생성해 준다.
# customF = formulaGen(target='qty',ind_features=['temp'])
# print(customF) qty ~ temp
# customF = formulaGen(target='qty',ind_features=['temp','cloud'])
# print(customF) # qty ~ temp + cloud
columns_in_data

# formulaGen은 단순 1차 다항식을 제조해준다.
# customF = formulaGen(target='qty',ind_features=columns_in_data)
customF = 'qty ~ temp + I((temp)**2) + cloud + 공기상태_0 + 공기상태_1'


olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()

print('사람이 직접 식을 때려 박았을때 검증세트 점수: {:.3f}'.format(r2_score(val_y, olsModel.predict(val_X))) )

print(olsModel.summary())
# Out:
# 아이스크림 ols model
# 사람이 직접 식을 때려 박았을때 검증세트 점수: 0.812
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     803.5
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          5.07e-293
# Time:                        21:07:16   Log-Likelihood:                -7255.5
# No. Observations:                 732   AIC:                         1.452e+04
# Df Residuals:                     726   BIC:                         1.455e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       1.132e+04    506.212     22.353      0.000    1.03e+04    1.23e+04
# temp             120.2834     45.114      2.666      0.008      31.714     208.853
# I((temp) ** 2)    38.2637      1.744     21.937      0.000      34.839      41.688
# cloud           -333.6439     63.417     -5.261      0.000    -458.147    -209.141
# 공기상태_0         -6637.0081    624.069    -10.635      0.000   -7862.203   -5411.813
# 공기상태_1         -2237.5281    466.698     -4.794      0.000   -3153.767   -1321.289
# ==============================================================================
# Omnibus:                        9.132   Durbin-Watson:                   0.724
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               10.533
# Skew:                           0.181   Prob(JB):                      0.00516
# Kurtosis:                       3.463   Cond. No.                     1.76e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
#             '공기상태_0', '공기상태_1', '공기상태_2']
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
            '공기상태']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = gs_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 예측률 계산
# https://yamalab.tistory.com/46
# RMSE (Root Mean Squared Error) : 
# OLS 추정에서 일반적인 표준 오차이다. 예측 대상의 scale(단위 크기)에 주의해야하는 단점이 있다. 
# MSE는 root를 수식에서 제외, SSE는 root와 분모를 제외한 수식으로, SE가 붙은 척도들은 거기서 거기인 척도들이라고 보면 된다.
# 다만 디테일한 사용법에 차이가 있을 뿐.

# MAPE (Mean Absolute Percentage Error) :

# 위 방법의 단점을 보완한 것이다. 
# At는 실제값, Ft는 예측값인데, 이를 At로 나누어서 오차를 절대적 크기로 보는것이 아닌 비율의 크기로 보고자 하는 것이 핵심이다.
# 이 방법은 At가 0에 가까울수록 비정상적인 값이 나온다는 단점이 있다.

# mre가 0에 가까울수록 좋은 모델
result_df['mape_keras'] = abs((result_df.qty - result_df.keras_qty) / result_df.qty )
result_df['mape_rf'] = abs((result_df.qty - result_df.rf_qty) / result_df.qty )
result_df['mape_xgb'] = abs((result_df.qty - result_df.xgb_qty) / result_df.qty )
result_df['mape_lin'] = abs((result_df.qty - result_df.lin_qty) / result_df.qty )
result_df['mape_ridge'] = abs((result_df.qty - result_df.ridge_qty) / result_df.qty )
result_df['mape_lasso'] = abs((result_df.qty - result_df.lasso_qty) / result_df.qty )
result_df['mape_ols'] = abs((result_df.qty - result_df.ols_qty) / result_df.qty )

print('Keras 인공 신경망 모델 MAPE \t: {:<.2f}'.format(result_df['mape_keras'].sum() / result_df.shape[0] ))
# print('RandomForest 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_rf'].sum() / result_df.shape[0] ))
# print('XGBoosting  모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_xgb'].sum() / result_df.shape[0] ))
print('Linear 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lin'].sum() / result_df.shape[0] ))
print('Ridge 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_ridge'].sum() / result_df.shape[0] ))
print('Lasso 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lasso'].sum() / result_df.shape[0] ))
print('OLS 모델 MAPE \t\t\t: {:<.2f}'.format(result_df['mape_ols'].sum() / result_df.shape[0] ))
# Out:
# Keras 인공 신경망 모델 MAPE 	: 0.23
# Linear 모델 MAPE 		: 0.38
# Ridge 모델 MAPE 		: 0.37
# Lasso 모델 MAPE 		: 0.38
# OLS 모델 MAPE 			: 0.27

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not','snow_or_not', 
#                                                   '공기상태_0', '공기상태_1', '공기상태_2']

# 숫자를 바꾸면 (1~9) : 각 날씨 변수에 다른 판매량 변화량을 보여준다.
# 예: n = 1 # 'temp' 온도변화량 vs 판매량
n=1
# alpha 값 0~1
alp = 0.8
# scatter plot 점 크기
dot_size = 10

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# # 1~106 / 106~156
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
