# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# R2 값, 결정계수 계산
from sklearn.metrics import r2_score

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
# w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
w = pd.read_csv('d:/project/contest/data/processed/날씨_ver071915.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
lv_grouped = lv_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_lv_grouped = lv_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '선케어'만 빼서 df생성
item = '선케어'
grouped_by = 'date'
day_lv_grouped_w_item = pd.merge(day_lv_grouped.loc[day_lv_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_lv_grouped_w_sns_item = pd.merge(day_lv_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not','미세', '초미세', '공기상태',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
lv_day_w = day_lv_grouped_w_sns_item[selected_cols]

# %%
# MAD적용
lv_day_w['outlier'] = pd.DataFrame(mad_based_outlier(lv_day_w['qty']))
lv_day_w = lv_day_w.loc[lv_day_w.outlier==False]

# %%
# list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
list_col = ['temp', 'cloud', 'wind','lgt_time',
            'rain_or_not', 'snow_or_not', '공기상태'] #+'rain_or_not', 'snow_or_not'
lowVIF(w,20,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239620  snow_or_not
# 1    2.479988  rain_or_not
# 2    3.114369         공기상태
# 3    4.013218         temp
# 4    6.725926        cloud
# 5    8.084050     lgt_time
# 6    9.334878         wind

# %%
train_data = lv_day_w.loc[lv_day_w.date.between('2016-01-01','2017-12-31')]
test_data = lv_day_w.loc[lv_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만
combined = lv_day_w.loc[:,list_col]
target = lv_day_w.loc[:,'qty']
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 7
# 오브젝트형 자료 컬럼 갯수 : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
#### 내가 '공기상태'라는 컬럼이 사실은 category형이라는것을 알기에 직접 dummy컬럼 생성
airCondition_dummies = pd.get_dummies(combined['공기상태'],prefix='공기상태')
combined = pd.concat([combined, airCondition_dummies], axis=1)
combined.drop(['공기상태'],axis = 1 , inplace=True)
######################################################################################
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 10 개의 columns이 있었습니다.

# %%
# 공기상태_0,공기상태_1,공기상태_2가 전부 0이면,   공기상태_3이 1이란 소리고
#                                                               공기상태가 '매우나쁨' 임을 추정할수 있다.
# 그런이유로 공기상태_3삭제
combined.drop(['공기상태_3'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
#
#    공기상태_2
# 0       1

# %%
Xy = pd.concat([target,combined], axis=1)
# Xy.head(1)

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 9)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 18:55:14.241524  2312 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 18:55:14.264463  2312 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 18:55:14.268451  2312 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 18:55:14.361203  2312 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,145
# Trainable params: 166,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat04-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 17:13:45.174556  9512 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 17:13:45.293253  9512 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 547us/step - loss: 3188.2715 - mean_absolute_error: 3188.2715 - val_loss: 1266.7955 - val_mean_absolute_error: 1266.7955
#
# Epoch 00001: val_loss improved from inf to 1266.79545, saving model to 선케어선케어-Weights-001--1266.79545-cat04-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 84us/step - loss: 2545.4938 - mean_absolute_error: 2545.4938 - val_loss: 584.3408 - val_mean_absolute_error: 584.3408
#
# Epoch 00002: val_loss improved from 1266.79545 to 584.34081, saving model to 선케어선케어-Weights-002--584.34081-cat04-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 81us/step - loss: 1435.8066 - mean_absolute_error: 1435.8066 - val_loss: 602.9346 - val_mean_absolute_error: 602.9346
#
# Epoch 00003: val_loss did not improve from 584.34081
# Epoch 4/500
# 585/585 [==============================] - 0s 80us/step - loss: 1339.0637 - mean_absolute_error: 1339.0637 - val_loss: 831.4785 - val_mean_absolute_error: 831.4785
#
# Epoch 00004: val_loss did not improve from 584.34081
# Epoch 5/500
# 585/585 [==============================] - 0s 70us/step - loss: 1308.3560 - mean_absolute_error: 1308.3560 - val_loss: 689.7079 - val_mean_absolute_error: 689.7079
#
# Epoch 00005: val_loss did not improve from 584.34081
# Epoch 6/500
# 585/585 [==============================] - 0s 85us/step - loss: 1283.9643 - mean_absolute_error: 1283.9643 - val_loss: 721.6359 - val_mean_absolute_error: 721.6359
#
# Epoch 00006: val_loss did not improve from 584.34081
# Epoch 7/500
# 585/585 [==============================] - 0s 82us/step - loss: 1263.1833 - mean_absolute_error: 1263.1833 - val_loss: 685.0352 - val_mean_absolute_error: 685.0352
#
# Epoch 00007: val_loss did not improve from 584.34081
# Epoch 8/500
# 585/585 [==============================] - 0s 97us/step - loss: 1251.9922 - mean_absolute_error: 1251.9922 - val_loss: 679.0874 - val_mean_absolute_error: 679.0874
#
# Epoch 00008: val_loss did not improve from 584.34081
# Epoch 9/500
# 585/585 [==============================] - 0s 76us/step - loss: 1246.3131 - mean_absolute_error: 1246.3131 - val_loss: 715.2151 - val_mean_absolute_error: 715.2151
#
# Epoch 00009: val_loss did not improve from 584.34081
# Epoch 10/500
# 585/585 [==============================] - 0s 82us/step - loss: 1234.7958 - mean_absolute_error: 1234.7958 - val_loss: 720.8110 - val_mean_absolute_error: 720.8110
#
# Epoch 00010: val_loss did not improve from 584.34081
# Epoch 11/500
# 585/585 [==============================] - 0s 82us/step - loss: 1241.2734 - mean_absolute_error: 1241.2734 - val_loss: 694.5150 - val_mean_absolute_error: 694.5150
#
# Epoch 00011: val_loss did not improve from 584.34081
# Epoch 12/500
# 585/585 [==============================] - 0s 78us/step - loss: 1227.4245 - mean_absolute_error: 1227.4245 - val_loss: 634.3846 - val_mean_absolute_error: 634.3846
#
# Epoch 00012: val_loss did not improve from 584.34081
# Epoch 13/500
# 585/585 [==============================] - 0s 83us/step - loss: 1220.5416 - mean_absolute_error: 1220.5416 - val_loss: 759.1637 - val_mean_absolute_error: 759.1637
#
# Epoch 00013: val_loss did not improve from 584.34081
# Epoch 14/500
# 585/585 [==============================] - 0s 84us/step - loss: 1220.8293 - mean_absolute_error: 1220.8293 - val_loss: 768.8263 - val_mean_absolute_error: 768.8263
#
# Epoch 00014: val_loss did not improve from 584.34081
# Epoch 15/500
# 585/585 [==============================] - 0s 70us/step - loss: 1243.0551 - mean_absolute_error: 1243.0551 - val_loss: 661.0540 - val_mean_absolute_error: 661.0540
#
# Epoch 00015: val_loss did not improve from 584.34081
# Epoch 16/500
# 585/585 [==============================] - 0s 82us/step - loss: 1212.0354 - mean_absolute_error: 1212.0354 - val_loss: 622.5582 - val_mean_absolute_error: 622.5582
#
# Epoch 00016: val_loss did not improve from 584.34081
# Epoch 17/500
# 585/585 [==============================] - 0s 87us/step - loss: 1219.9629 - mean_absolute_error: 1219.9629 - val_loss: 653.3034 - val_mean_absolute_error: 653.3034
#
# Epoch 00017: val_loss did not improve from 584.34081
# Epoch 18/500
# 585/585 [==============================] - 0s 84us/step - loss: 1201.0270 - mean_absolute_error: 1201.0270 - val_loss: 638.4631 - val_mean_absolute_error: 638.4631
#
# Epoch 00018: val_loss did not improve from 584.34081
# Epoch 19/500
# 585/585 [==============================] - 0s 89us/step - loss: 1205.9145 - mean_absolute_error: 1205.9145 - val_loss: 672.9296 - val_mean_absolute_error: 672.9296
#
# Epoch 00019: val_loss did not improve from 584.34081
# Epoch 20/500
# 585/585 [==============================] - 0s 82us/step - loss: 1204.8702 - mean_absolute_error: 1204.8702 - val_loss: 673.0562 - val_mean_absolute_error: 673.0562
#
# Epoch 00020: val_loss did not improve from 584.34081
# Epoch 21/500
# 585/585 [==============================] - 0s 80us/step - loss: 1180.9912 - mean_absolute_error: 1180.9912 - val_loss: 704.6720 - val_mean_absolute_error: 704.6720
#
# Epoch 00021: val_loss did not improve from 584.34081
# Epoch 22/500
# 585/585 [==============================] - 0s 90us/step - loss: 1185.7794 - mean_absolute_error: 1185.7794 - val_loss: 782.0574 - val_mean_absolute_error: 782.0574
#
# Epoch 00022: val_loss did not improve from 584.34081
# Epoch 23/500
# 585/585 [==============================] - 0s 85us/step - loss: 1181.3729 - mean_absolute_error: 1181.3729 - val_loss: 650.4046 - val_mean_absolute_error: 650.4046
#
# Epoch 00023: val_loss did not improve from 584.34081
# Epoch 24/500
# 585/585 [==============================] - 0s 80us/step - loss: 1161.3669 - mean_absolute_error: 1161.3669 - val_loss: 668.3223 - val_mean_absolute_error: 668.3223
#
# Epoch 00024: val_loss did not improve from 584.34081
# Epoch 25/500
# 585/585 [==============================] - 0s 82us/step - loss: 1164.4213 - mean_absolute_error: 1164.4213 - val_loss: 662.5260 - val_mean_absolute_error: 662.5260
#
# Epoch 00025: val_loss did not improve from 584.34081
# Epoch 26/500
# 585/585 [==============================] - 0s 85us/step - loss: 1173.6914 - mean_absolute_error: 1173.6914 - val_loss: 653.0385 - val_mean_absolute_error: 653.0385
#
# Epoch 00026: val_loss did not improve from 584.34081
# Epoch 27/500
# 585/585 [==============================] - 0s 85us/step - loss: 1191.4583 - mean_absolute_error: 1191.4583 - val_loss: 667.0885 - val_mean_absolute_error: 667.0885
#
# Epoch 00027: val_loss did not improve from 584.34081
# Epoch 28/500
# 585/585 [==============================] - 0s 87us/step - loss: 1173.5482 - mean_absolute_error: 1173.5482 - val_loss: 611.1093 - val_mean_absolute_error: 611.1093
#
# Epoch 00028: val_loss did not improve from 584.34081
# Epoch 29/500
# 585/585 [==============================] - 0s 97us/step - loss: 1159.8490 - mean_absolute_error: 1159.8490 - val_loss: 651.1437 - val_mean_absolute_error: 651.1437
#
# Epoch 00029: val_loss did not improve from 584.34081
# Epoch 30/500
# 585/585 [==============================] - 0s 101us/step - loss: 1150.2478 - mean_absolute_error: 1150.2478 - val_loss: 652.4609 - val_mean_absolute_error: 652.4609
#
# Epoch 00030: val_loss did not improve from 584.34081
# Epoch 31/500
# 585/585 [==============================] - 0s 98us/step - loss: 1150.0957 - mean_absolute_error: 1150.0957 - val_loss: 717.2520 - val_mean_absolute_error: 717.2520
#
# Epoch 00031: val_loss did not improve from 584.34081
# Epoch 32/500
# 585/585 [==============================] - 0s 75us/step - loss: 1169.7564 - mean_absolute_error: 1169.7564 - val_loss: 706.6240 - val_mean_absolute_error: 706.6240
#
# Epoch 00032: val_loss did not improve from 584.34081
# Epoch 33/500
# 585/585 [==============================] - 0s 94us/step - loss: 1158.1137 - mean_absolute_error: 1158.1137 - val_loss: 639.1267 - val_mean_absolute_error: 639.1267
#
# Epoch 00033: val_loss did not improve from 584.34081
# Epoch 34/500
# 585/585 [==============================] - 0s 84us/step - loss: 1140.1381 - mean_absolute_error: 1140.1381 - val_loss: 743.1754 - val_mean_absolute_error: 743.1754
#
# Epoch 00034: val_loss did not improve from 584.34081
# Epoch 35/500
# 585/585 [==============================] - 0s 87us/step - loss: 1170.0003 - mean_absolute_error: 1170.0003 - val_loss: 744.2219 - val_mean_absolute_error: 744.2219
# Epoch 00035: val_loss did not improve from 584.34081
# Epoch 36/500
# 585/585 [==============================] - 0s 89us/step - loss: 1173.5899 - mean_absolute_error: 1173.5899 - val_loss: 714.1026 - val_mean_absolute_error: 714.1026
#
# Epoch 00036: val_loss did not improve from 584.34081
# Epoch 37/500
# 585/585 [==============================] - 0s 106us/step - loss: 1168.8317 - mean_absolute_error: 1168.8317 - val_loss: 635.8657 - val_mean_absolute_error: 635.8657
#
# Epoch 00037: val_loss did not improve from 584.34081
# Epoch 38/500
# 585/585 [==============================] - 0s 89us/step - loss: 1146.2284 - mean_absolute_error: 1146.2284 - val_loss: 700.9144 - val_mean_absolute_error: 700.9144
#
# Epoch 00038: val_loss did not improve from 584.34081
# Epoch 39/500
# 585/585 [==============================] - 0s 84us/step - loss: 1151.1325 - mean_absolute_error: 1151.1325 - val_loss: 688.5490 - val_mean_absolute_error: 688.5490
#
# Epoch 00039: val_loss did not improve from 584.34081
# Epoch 40/500
# 585/585 [==============================] - 0s 84us/step - loss: 1152.0749 - mean_absolute_error: 1152.0749 - val_loss: 669.1305 - val_mean_absolute_error: 669.1305
#
# Epoch 00040: val_loss did not improve from 584.34081
# Epoch 41/500
# 585/585 [==============================] - 0s 83us/step - loss: 1148.1622 - mean_absolute_error: 1148.1622 - val_loss: 744.3055 - val_mean_absolute_error: 744.3055
#
# Epoch 00041: val_loss did not improve from 584.34081
# Epoch 42/500
# 585/585 [==============================] - 0s 84us/step - loss: 1147.2090 - mean_absolute_error: 1147.2090 - val_loss: 659.8210 - val_mean_absolute_error: 659.8210
#
# Epoch 00042: val_loss did not improve from 584.34081
# Epoch 43/500
# 585/585 [==============================] - 0s 83us/step - loss: 1136.6001 - mean_absolute_error: 1136.6001 - val_loss: 627.5151 - val_mean_absolute_error: 627.5151
#
# Epoch 00043: val_loss did not improve from 584.34081
# Epoch 44/500
# 585/585 [==============================] - 0s 82us/step - loss: 1135.1674 - mean_absolute_error: 1135.1674 - val_loss: 642.2739 - val_mean_absolute_error: 642.2739
#
# Epoch 00044: val_loss did not improve from 584.34081
# Epoch 45/500
# 585/585 [==============================] - 0s 84us/step - loss: 1134.1405 - mean_absolute_error: 1134.1405 - val_loss: 663.1262 - val_mean_absolute_error: 663.1262
#
# Epoch 00045: val_loss did not improve from 584.34081
# Epoch 46/500
# 585/585 [==============================] - 0s 87us/step - loss: 1132.5145 - mean_absolute_error: 1132.5145 - val_loss: 657.4816 - val_mean_absolute_error: 657.4816
#
# Epoch 00046: val_loss did not improve from 584.34081
# Epoch 47/500
# 585/585 [==============================] - 0s 92us/step - loss: 1133.4657 - mean_absolute_error: 1133.4657 - val_loss: 623.7494 - val_mean_absolute_error: 623.7494
#
# Epoch 00047: val_loss did not improve from 584.34081
# Epoch 48/500
# 585/585 [==============================] - 0s 85us/step - loss: 1129.2993 - mean_absolute_error: 1129.2993 - val_loss: 605.2695 - val_mean_absolute_error: 605.2695
#
# Epoch 00048: val_loss did not improve from 584.34081
# Epoch 49/500
# 585/585 [==============================] - 0s 142us/step - loss: 1157.3739 - mean_absolute_error: 1157.3739 - val_loss: 672.7285 - val_mean_absolute_error: 672.7285
#
# Epoch 00049: val_loss did not improve from 584.34081
# Epoch 50/500
# 585/585 [==============================] - 0s 90us/step - loss: 1134.6277 - mean_absolute_error: 1134.6277 - val_loss: 742.1907 - val_mean_absolute_error: 742.1907
#
# Epoch 00050: val_loss did not improve from 584.34081
# Epoch 51/500
# 585/585 [==============================] - 0s 80us/step - loss: 1146.2039 - mean_absolute_error: 1146.2039 - val_loss: 685.0638 - val_mean_absolute_error: 685.0638
#
# Epoch 00051: val_loss did not improve from 584.34081
# Epoch 52/500
# 585/585 [==============================] - 0s 89us/step - loss: 1131.7419 - mean_absolute_error: 1131.7419 - val_loss: 624.2315 - val_mean_absolute_error: 624.2315
#
# Epoch 00052: val_loss did not improve from 584.34081
# Epoch 53/500
# 585/585 [==============================] - 0s 90us/step - loss: 1120.9795 - mean_absolute_error: 1120.9795 - val_loss: 675.3698 - val_mean_absolute_error: 675.3698
#
# Epoch 00053: val_loss did not improve from 584.34081
# Epoch 54/500
# 585/585 [==============================] - 0s 92us/step - loss: 1120.8137 - mean_absolute_error: 1120.8137 - val_loss: 664.4587 - val_mean_absolute_error: 664.4587
#
# Epoch 00054: val_loss did not improve from 584.34081
# Epoch 55/500
# 585/585 [==============================] - 0s 92us/step - loss: 1118.9330 - mean_absolute_error: 1118.9330 - val_loss: 663.1265 - val_mean_absolute_error: 663.1265
#
# Epoch 00055: val_loss did not improve from 584.34081
# Epoch 56/500
# 585/585 [==============================] - 0s 92us/step - loss: 1118.1039 - mean_absolute_error: 1118.1039 - val_loss: 687.8105 - val_mean_absolute_error: 687.8105
#
# Epoch 00056: val_loss did not improve from 584.34081
# Epoch 57/500
# 585/585 [==============================] - 0s 80us/step - loss: 1123.5016 - mean_absolute_error: 1123.5016 - val_loss: 775.2047 - val_mean_absolute_error: 775.2047
#
# Epoch 00057: val_loss did not improve from 584.34081
# Epoch 58/500
# 585/585 [==============================] - 0s 94us/step - loss: 1146.8076 - mean_absolute_error: 1146.8076 - val_loss: 638.4952 - val_mean_absolute_error: 638.4952
#
# Epoch 00058: val_loss did not improve from 584.34081
# Epoch 59/500
# 585/585 [==============================] - 0s 94us/step - loss: 1117.1081 - mean_absolute_error: 1117.1081 - val_loss: 675.4355 - val_mean_absolute_error: 675.4355
#
# Epoch 00059: val_loss did not improve from 584.34081
# Epoch 60/500
# 585/585 [==============================] - 0s 84us/step - loss: 1117.5251 - mean_absolute_error: 1117.5251 - val_loss: 609.1866 - val_mean_absolute_error: 609.1866
#
# Epoch 00060: val_loss did not improve from 584.34081
# Epoch 61/500
# 585/585 [==============================] - 0s 87us/step - loss: 1116.5427 - mean_absolute_error: 1116.5427 - val_loss: 722.0981 - val_mean_absolute_error: 722.0981
#
# Epoch 00061: val_loss did not improve from 584.34081
# Epoch 62/500
# 585/585 [==============================] - 0s 97us/step - loss: 1131.3576 - mean_absolute_error: 1131.3576 - val_loss: 737.4839 - val_mean_absolute_error: 737.4839
#
# Epoch 00062: val_loss did not improve from 584.34081
# Epoch 63/500
# 585/585 [==============================] - 0s 82us/step - loss: 1135.8881 - mean_absolute_error: 1135.8881 - val_loss: 683.9083 - val_mean_absolute_error: 683.9083
#
# Epoch 00063: val_loss did not improve from 584.34081
# Epoch 64/500
# 585/585 [==============================] - 0s 90us/step - loss: 1156.6285 - mean_absolute_error: 1156.6285 - val_loss: 702.2658 - val_mean_absolute_error: 702.2658
#
# Epoch 00064: val_loss did not improve from 584.34081
# Epoch 65/500
# 585/585 [==============================] - 0s 92us/step - loss: 1108.8055 - mean_absolute_error: 1108.8055 - val_loss: 619.7458 - val_mean_absolute_error: 619.7458
#
# Epoch 00065: val_loss did not improve from 584.34081
# Epoch 66/500
# 585/585 [==============================] - 0s 80us/step - loss: 1135.7029 - mean_absolute_error: 1135.7029 - val_loss: 625.8893 - val_mean_absolute_error: 625.8893
#
# Epoch 00066: val_loss did not improve from 584.34081
# Epoch 67/500
# 585/585 [==============================] - 0s 109us/step - loss: 1113.0439 - mean_absolute_error: 1113.0439 - val_loss: 672.5561 - val_mean_absolute_error: 672.5561
#
# Epoch 00067: val_loss did not improve from 584.34081
# Epoch 68/500
# 585/585 [==============================] - 0s 99us/step - loss: 1106.7686 - mean_absolute_error: 1106.7686 - val_loss: 671.6585 - val_mean_absolute_error: 671.6585
#
# Epoch 00068: val_loss did not improve from 584.34081
# Epoch 69/500
# 585/585 [==============================] - 0s 93us/step - loss: 1113.2418 - mean_absolute_error: 1113.2418 - val_loss: 661.3897 - val_mean_absolute_error: 661.3897
#
# Epoch 00069: val_loss did not improve from 584.34081
# Epoch 70/500
# 585/585 [==============================] - 0s 95us/step - loss: 1097.2717 - mean_absolute_error: 1097.2717 - val_loss: 669.7112 - val_mean_absolute_error: 669.7112
#
# Epoch 00070: val_loss did not improve from 584.34081
# Epoch 71/500
# 585/585 [==============================] - 0s 95us/step - loss: 1102.0788 - mean_absolute_error: 1102.0788 - val_loss: 591.8610 - val_mean_absolute_error: 591.8610
#
# Epoch 00071: val_loss did not improve from 584.34081
# Epoch 72/500
# 585/585 [==============================] - 0s 113us/step - loss: 1114.3702 - mean_absolute_error: 1114.3702 - val_loss: 634.4327 - val_mean_absolute_error: 634.4327
#
# Epoch 00072: val_loss did not improve from 584.34081
# Epoch 73/500
# 585/585 [==============================] - 0s 90us/step - loss: 1122.2446 - mean_absolute_error: 1122.2446 - val_loss: 621.2171 - val_mean_absolute_error: 621.2171
#
# Epoch 00073: val_loss did not improve from 584.34081
# Epoch 74/500
# 585/585 [==============================] - 0s 84us/step - loss: 1094.8806 - mean_absolute_error: 1094.8806 - val_loss: 649.2391 - val_mean_absolute_error: 649.2391
#
# Epoch 00074: val_loss did not improve from 584.34081
# Epoch 75/500
# 585/585 [==============================] - 0s 85us/step - loss: 1097.5365 - mean_absolute_error: 1097.5365 - val_loss: 591.9282 - val_mean_absolute_error: 591.9282
#
# Epoch 00075: val_loss did not improve from 584.34081
# Epoch 76/500
# 585/585 [==============================] - 0s 84us/step - loss: 1198.4217 - mean_absolute_error: 1198.4217 - val_loss: 677.3711 - val_mean_absolute_error: 677.3711
#
# Epoch 00076: val_loss did not improve from 584.34081
# Epoch 77/500
# 585/585 [==============================] - 0s 85us/step - loss: 1112.5267 - mean_absolute_error: 1112.5267 - val_loss: 678.9930 - val_mean_absolute_error: 678.9930
#
# Epoch 00077: val_loss did not improve from 584.34081
# Epoch 78/500
# 585/585 [==============================] - 0s 84us/step - loss: 1122.0710 - mean_absolute_error: 1122.0710 - val_loss: 861.0050 - val_mean_absolute_error: 861.0050
#
# Epoch 00078: val_loss did not improve from 584.34081
# Epoch 79/500
# 585/585 [==============================] - 0s 85us/step - loss: 1176.4858 - mean_absolute_error: 1176.4858 - val_loss: 722.3859 - val_mean_absolute_error: 722.3859
#
# Epoch 00079: val_loss did not improve from 584.34081
# Epoch 80/500
# 585/585 [==============================] - 0s 85us/step - loss: 1096.8916 - mean_absolute_error: 1096.8916 - val_loss: 632.3653 - val_mean_absolute_error: 632.3653
#
# Epoch 00080: val_loss did not improve from 584.34081
# Epoch 81/500
# 585/585 [==============================] - 0s 85us/step - loss: 1088.9335 - mean_absolute_error: 1088.9335 - val_loss: 616.8958 - val_mean_absolute_error: 616.8958
#
# Epoch 00081: val_loss did not improve from 584.34081
# Epoch 82/500
# 585/585 [==============================] - 0s 95us/step - loss: 1105.1704 - mean_absolute_error: 1105.1704 - val_loss: 621.6579 - val_mean_absolute_error: 621.6579
#
# Epoch 00082: val_loss did not improve from 584.34081
# Epoch 83/500
# 585/585 [==============================] - 0s 112us/step - loss: 1091.3213 - mean_absolute_error: 1091.3213 - val_loss: 703.1383 - val_mean_absolute_error: 703.1383
#
# Epoch 00083: val_loss did not improve from 584.34081
# Epoch 84/500
# 585/585 [==============================] - 0s 97us/step - loss: 1106.1643 - mean_absolute_error: 1106.1643 - val_loss: 650.5674 - val_mean_absolute_error: 650.5674
#
# Epoch 00084: val_loss did not improve from 584.34081
# Epoch 85/500
# 585/585 [==============================] - 0s 97us/step - loss: 1094.2972 - mean_absolute_error: 1094.2972 - val_loss: 623.9763 - val_mean_absolute_error: 623.9763
#
# Epoch 00085: val_loss did not improve from 584.34081
# Epoch 86/500
# 585/585 [==============================] - 0s 89us/step - loss: 1088.2479 - mean_absolute_error: 1088.2479 - val_loss: 611.7315 - val_mean_absolute_error: 611.7315
#
# Epoch 00086: val_loss did not improve from 584.34081
# Epoch 87/500
# 585/585 [==============================] - 0s 92us/step - loss: 1084.2270 - mean_absolute_error: 1084.2270 - val_loss: 665.6518 - val_mean_absolute_error: 665.6518
#
# Epoch 00087: val_loss did not improve from 584.34081
# Epoch 88/500
# 585/585 [==============================] - 0s 99us/step - loss: 1087.6380 - mean_absolute_error: 1087.6380 - val_loss: 620.4558 - val_mean_absolute_error: 620.4558
#
# Epoch 00088: val_loss did not improve from 584.34081
# Epoch 89/500
# 585/585 [==============================] - 0s 92us/step - loss: 1083.6085 - mean_absolute_error: 1083.6085 - val_loss: 652.8843 - val_mean_absolute_error: 652.8843
#
# Epoch 00089: val_loss did not improve from 584.34081
# Epoch 90/500
# 585/585 [==============================] - 0s 92us/step - loss: 1080.5704 - mean_absolute_error: 1080.5704 - val_loss: 674.1879 - val_mean_absolute_error: 674.1879
#
# Epoch 00090: val_loss did not improve from 584.34081
# Epoch 91/500
# 585/585 [==============================] - 0s 137us/step - loss: 1077.7070 - mean_absolute_error: 1077.7070 - val_loss: 621.1071 - val_mean_absolute_error: 621.1071
#
# Epoch 00091: val_loss did not improve from 584.34081
# Epoch 92/500
# 585/585 [==============================] - 0s 113us/step - loss: 1086.0709 - mean_absolute_error: 1086.0709 - val_loss: 603.1856 - val_mean_absolute_error: 603.1856
#
# Epoch 00092: val_loss did not improve from 584.34081
# Epoch 93/500
# 585/585 [==============================] - 0s 104us/step - loss: 1090.8151 - mean_absolute_error: 1090.8151 - val_loss: 690.2827 - val_mean_absolute_error: 690.2827
#
# Epoch 00093: val_loss did not improve from 584.34081
# Epoch 94/500
# 585/585 [==============================] - 0s 114us/step - loss: 1070.3287 - mean_absolute_error: 1070.3287 - val_loss: 627.1469 - val_mean_absolute_error: 627.1469
#
# Epoch 00094: val_loss did not improve from 584.34081
# Epoch 95/500
# 585/585 [==============================] - 0s 113us/step - loss: 1084.6209 - mean_absolute_error: 1084.6209 - val_loss: 672.0043 - val_mean_absolute_error: 672.0043
#
# Epoch 00095: val_loss did not improve from 584.34081
# Epoch 96/500
# 585/585 [==============================] - 0s 107us/step - loss: 1081.7634 - mean_absolute_error: 1081.7634 - val_loss: 663.4491 - val_mean_absolute_error: 663.4491
#
# Epoch 00096: val_loss did not improve from 584.34081
# Epoch 97/500
# 585/585 [==============================] - 0s 99us/step - loss: 1105.1008 - mean_absolute_error: 1105.1008 - val_loss: 683.2254 - val_mean_absolute_error: 683.2254
#
# Epoch 00097: val_loss did not improve from 584.34081
# Epoch 98/500
# 585/585 [==============================] - 0s 95us/step - loss: 1081.5130 - mean_absolute_error: 1081.5130 - val_loss: 678.1787 - val_mean_absolute_error: 678.1787
#
# Epoch 00098: val_loss did not improve from 584.34081
# Epoch 99/500
# 585/585 [==============================] - 0s 116us/step - loss: 1104.6834 - mean_absolute_error: 1104.6834 - val_loss: 641.0373 - val_mean_absolute_error: 641.0373
#
# Epoch 00099: val_loss did not improve from 584.34081
# Epoch 100/500
# 585/585 [==============================] - 0s 123us/step - loss: 1078.7819 - mean_absolute_error: 1078.7819 - val_loss: 639.0555 - val_mean_absolute_error: 639.0555
#
# Epoch 00100: val_loss did not improve from 584.34081
# Epoch 101/500
# 585/585 [==============================] - 0s 130us/step - loss: 1072.1079 - mean_absolute_error: 1072.1079 - val_loss: 673.0065 - val_mean_absolute_error: 673.0065
#
# Epoch 00101: val_loss did not improve from 584.34081
# Epoch 102/500
# 585/585 [==============================] - 0s 118us/step - loss: 1083.8148 - mean_absolute_error: 1083.8148 - val_loss: 658.3384 - val_mean_absolute_error: 658.3384
#
# Epoch 00102: val_loss did not improve from 584.34081
# Epoch 103/500
# 585/585 [==============================] - 0s 107us/step - loss: 1065.2712 - mean_absolute_error: 1065.2712 - val_loss: 634.7963 - val_mean_absolute_error: 634.7963
#
# Epoch 00103: val_loss did not improve from 584.34081
# Epoch 104/500
# 585/585 [==============================] - 0s 121us/step - loss: 1066.8678 - mean_absolute_error: 1066.8678 - val_loss: 623.9023 - val_mean_absolute_error: 623.9023
#
# Epoch 00104: val_loss did not improve from 584.34081
# Epoch 105/500
# 585/585 [==============================] - 0s 101us/step - loss: 1064.3906 - mean_absolute_error: 1064.3906 - val_loss: 616.5615 - val_mean_absolute_error: 616.5615
#
# Epoch 00105: val_loss did not improve from 584.34081
# Epoch 106/500
# 585/585 [==============================] - 0s 102us/step - loss: 1066.6575 - mean_absolute_error: 1066.6575 - val_loss: 633.5010 - val_mean_absolute_error: 633.5010
#
# Epoch 00106: val_loss did not improve from 584.34081
# Epoch 107/500
# 585/585 [==============================] - 0s 123us/step - loss: 1061.4268 - mean_absolute_error: 1061.4268 - val_loss: 646.0449 - val_mean_absolute_error: 646.0449
#
# Epoch 00107: val_loss did not improve from 584.34081
# Epoch 108/500
# 585/585 [==============================] - 0s 124us/step - loss: 1063.9023 - mean_absolute_error: 1063.9023 - val_loss: 654.2757 - val_mean_absolute_error: 654.2757
#
# Epoch 00108: val_loss did not improve from 584.34081
# Epoch 109/500
# 585/585 [==============================] - 0s 128us/step - loss: 1059.6670 - mean_absolute_error: 1059.6670 - val_loss: 643.0155 - val_mean_absolute_error: 643.0155
#
# Epoch 00109: val_loss did not improve from 584.34081
# Epoch 110/500
# 585/585 [==============================] - 0s 109us/step - loss: 1055.1804 - mean_absolute_error: 1055.1804 - val_loss: 634.7358 - val_mean_absolute_error: 634.7358
#
# Epoch 00110: val_loss did not improve from 584.34081
# Epoch 111/500
# 585/585 [==============================] - 0s 104us/step - loss: 1059.1337 - mean_absolute_error: 1059.1337 - val_loss: 640.0892 - val_mean_absolute_error: 640.0892
#
# Epoch 00111: val_loss did not improve from 584.34081
# Epoch 112/500
# 585/585 [==============================] - 0s 119us/step - loss: 1055.2347 - mean_absolute_error: 1055.2347 - val_loss: 693.8431 - val_mean_absolute_error: 693.8431
#
# Epoch 00112: val_loss did not improve from 584.34081
# Epoch 113/500
# 585/585 [==============================] - 0s 102us/step - loss: 1067.7202 - mean_absolute_error: 1067.7202 - val_loss: 662.8827 - val_mean_absolute_error: 662.8827
#
# Epoch 00113: val_loss did not improve from 584.34081
# Epoch 114/500
# 585/585 [==============================] - 0s 115us/step - loss: 1047.9955 - mean_absolute_error: 1047.9955 - val_loss: 716.1454 - val_mean_absolute_error: 716.1454
#
# Epoch 00114: val_loss did not improve from 584.34081
# Epoch 115/500
# 585/585 [==============================] - 0s 111us/step - loss: 1078.5742 - mean_absolute_error: 1078.5742 - val_loss: 674.1383 - val_mean_absolute_error: 674.1383
#
# Epoch 00115: val_loss did not improve from 584.34081
# Epoch 116/500
# 585/585 [==============================] - 0s 122us/step - loss: 1042.4311 - mean_absolute_error: 1042.4311 - val_loss: 612.4689 - val_mean_absolute_error: 612.4689
#
# Epoch 00116: val_loss did not improve from 584.34081
# Epoch 117/500
# 585/585 [==============================] - 0s 118us/step - loss: 1063.0731 - mean_absolute_error: 1063.0731 - val_loss: 615.7027 - val_mean_absolute_error: 615.7027
#
# Epoch 00117: val_loss did not improve from 584.34081
# Epoch 118/500
# 585/585 [==============================] - 0s 135us/step - loss: 1078.3486 - mean_absolute_error: 1078.3486 - val_loss: 593.9834 - val_mean_absolute_error: 593.9834
#
# Epoch 00118: val_loss did not improve from 584.34081
# Epoch 119/500
# 585/585 [==============================] - 0s 121us/step - loss: 1054.9871 - mean_absolute_error: 1054.9871 - val_loss: 639.8329 - val_mean_absolute_error: 639.8329
#
# Epoch 00119: val_loss did not improve from 584.34081
# Epoch 120/500
# 585/585 [==============================] - 0s 124us/step - loss: 1068.2877 - mean_absolute_error: 1068.2877 - val_loss: 630.9608 - val_mean_absolute_error: 630.9608
#
# Epoch 00120: val_loss did not improve from 584.34081
# Epoch 121/500
# 585/585 [==============================] - 0s 121us/step - loss: 1054.7305 - mean_absolute_error: 1054.7305 - val_loss: 634.2128 - val_mean_absolute_error: 634.2128
#
# Epoch 00121: val_loss did not improve from 584.34081
# Epoch 122/500
# 585/585 [==============================] - 0s 150us/step - loss: 1093.6449 - mean_absolute_error: 1093.6449 - val_loss: 585.1337 - val_mean_absolute_error: 585.1337
#
# Epoch 00122: val_loss did not improve from 584.34081
# Epoch 123/500
# 585/585 [==============================] - 0s 153us/step - loss: 1097.1641 - mean_absolute_error: 1097.1641 - val_loss: 626.0874 - val_mean_absolute_error: 626.0874
#
# Epoch 00123: val_loss did not improve from 584.34081
# Epoch 124/500
# 585/585 [==============================] - 0s 218us/step - loss: 1052.4944 - mean_absolute_error: 1052.4944 - val_loss: 591.7748 - val_mean_absolute_error: 591.7748
#
# Epoch 00124: val_loss did not improve from 584.34081
# Epoch 125/500
# 585/585 [==============================] - 0s 147us/step - loss: 1055.5684 - mean_absolute_error: 1055.5684 - val_loss: 610.2257 - val_mean_absolute_error: 610.2257
#
# Epoch 00125: val_loss did not improve from 584.34081
# Epoch 126/500
# 585/585 [==============================] - 0s 155us/step - loss: 1035.8045 - mean_absolute_error: 1035.8045 - val_loss: 644.7276 - val_mean_absolute_error: 644.7276
#
# Epoch 00126: val_loss did not improve from 584.34081
# Epoch 127/500
# 585/585 [==============================] - 0s 116us/step - loss: 1045.1546 - mean_absolute_error: 1045.1546 - val_loss: 625.7417 - val_mean_absolute_error: 625.7417
#
# Epoch 00127: val_loss did not improve from 584.34081
# Epoch 128/500
# 585/585 [==============================] - 0s 126us/step - loss: 1038.0798 - mean_absolute_error: 1038.0798 - val_loss: 622.4767 - val_mean_absolute_error: 622.4767
#
# Epoch 00128: val_loss did not improve from 584.34081
# Epoch 129/500
# 585/585 [==============================] - 0s 119us/step - loss: 1044.9337 - mean_absolute_error: 1044.9337 - val_loss: 657.3264 - val_mean_absolute_error: 657.3264
#
# Epoch 00129: val_loss did not improve from 584.34081
# Epoch 130/500
# 585/585 [==============================] - 0s 106us/step - loss: 1071.1216 - mean_absolute_error: 1071.1216 - val_loss: 663.2310 - val_mean_absolute_error: 663.2310
#
# Epoch 00130: val_loss did not improve from 584.34081
# Epoch 131/500
# 585/585 [==============================] - 0s 119us/step - loss: 1053.5420 - mean_absolute_error: 1053.5420 - val_loss: 689.5072 - val_mean_absolute_error: 689.5072
#
# Epoch 00131: val_loss did not improve from 584.34081
# Epoch 132/500
# 585/585 [==============================] - 0s 128us/step - loss: 1043.8916 - mean_absolute_error: 1043.8916 - val_loss: 615.1112 - val_mean_absolute_error: 615.1112
#
# Epoch 00132: val_loss did not improve from 584.34081
# Epoch 133/500
# 585/585 [==============================] - 0s 150us/step - loss: 1047.8545 - mean_absolute_error: 1047.8545 - val_loss: 630.3590 - val_mean_absolute_error: 630.3590
#
# Epoch 00133: val_loss did not improve from 584.34081
# Epoch 134/500
# 585/585 [==============================] - 0s 136us/step - loss: 1051.3159 - mean_absolute_error: 1051.3159 - val_loss: 635.0845 - val_mean_absolute_error: 635.0845
#
# Epoch 00134: val_loss did not improve from 584.34081
# Epoch 135/500
# 585/585 [==============================] - 0s 136us/step - loss: 1033.2901 - mean_absolute_error: 1033.2901 - val_loss: 604.4665 - val_mean_absolute_error: 604.4665
#
# Epoch 00135: val_loss did not improve from 584.34081
# Epoch 136/500
# 585/585 [==============================] - 0s 104us/step - loss: 1024.6211 - mean_absolute_error: 1024.6211 - val_loss: 622.4868 - val_mean_absolute_error: 622.4868
#
# Epoch 00136: val_loss did not improve from 584.34081
# Epoch 137/500
# 585/585 [==============================] - 0s 114us/step - loss: 1026.3645 - mean_absolute_error: 1026.3645 - val_loss: 674.6255 - val_mean_absolute_error: 674.6255
#
# Epoch 00137: val_loss did not improve from 584.34081
# Epoch 138/500
# 585/585 [==============================] - 0s 113us/step - loss: 1034.2553 - mean_absolute_error: 1034.2553 - val_loss: 631.5218 - val_mean_absolute_error: 631.5218
#
# Epoch 00138: val_loss did not improve from 584.34081
# Epoch 139/500
# 585/585 [==============================] - 0s 128us/step - loss: 1032.0153 - mean_absolute_error: 1032.0153 - val_loss: 633.0595 - val_mean_absolute_error: 633.0595
#
# Epoch 00139: val_loss did not improve from 584.34081
# Epoch 140/500
# 585/585 [==============================] - 0s 130us/step - loss: 1038.5218 - mean_absolute_error: 1038.5218 - val_loss: 623.0698 - val_mean_absolute_error: 623.0698
#
# Epoch 00140: val_loss did not improve from 584.34081
# Epoch 141/500
# 585/585 [==============================] - 0s 118us/step - loss: 1045.4444 - mean_absolute_error: 1045.4444 - val_loss: 651.6043 - val_mean_absolute_error: 651.6043
#
# Epoch 00141: val_loss did not improve from 584.34081
# Epoch 142/500
# 585/585 [==============================] - 0s 119us/step - loss: 1064.1136 - mean_absolute_error: 1064.1136 - val_loss: 608.9017 - val_mean_absolute_error: 608.9017
#
# Epoch 00142: val_loss did not improve from 584.34081
# Epoch 143/500
# 585/585 [==============================] - 0s 140us/step - loss: 1031.5776 - mean_absolute_error: 1031.5776 - val_loss: 652.4743 - val_mean_absolute_error: 652.4743
#
# Epoch 00143: val_loss did not improve from 584.34081
# Epoch 144/500
# 585/585 [==============================] - 0s 132us/step - loss: 1015.3450 - mean_absolute_error: 1015.3450 - val_loss: 607.4417 - val_mean_absolute_error: 607.4417
#
# Epoch 00144: val_loss did not improve from 584.34081
# Epoch 145/500
# 585/585 [==============================] - 0s 121us/step - loss: 1007.5965 - mean_absolute_error: 1007.5965 - val_loss: 639.3202 - val_mean_absolute_error: 639.3202
#
# Epoch 00145: val_loss did not improve from 584.34081
# Epoch 146/500
# 585/585 [==============================] - 0s 127us/step - loss: 1017.6342 - mean_absolute_error: 1017.6342 - val_loss: 633.6148 - val_mean_absolute_error: 633.6148
#
# Epoch 00146: val_loss did not improve from 584.34081
# Epoch 147/500
# 585/585 [==============================] - 0s 137us/step - loss: 1015.3442 - mean_absolute_error: 1015.3442 - val_loss: 616.7511 - val_mean_absolute_error: 616.7511
#
# Epoch 00147: val_loss did not improve from 584.34081
# Epoch 148/500
# 585/585 [==============================] - 0s 131us/step - loss: 1022.1267 - mean_absolute_error: 1022.1267 - val_loss: 617.8535 - val_mean_absolute_error: 617.8535
#
# Epoch 00148: val_loss did not improve from 584.34081
# Epoch 149/500
# 585/585 [==============================] - 0s 140us/step - loss: 1016.9091 - mean_absolute_error: 1016.9091 - val_loss: 586.6520 - val_mean_absolute_error: 586.6520
#
# Epoch 00149: val_loss did not improve from 584.34081
# Epoch 150/500
# 585/585 [==============================] - 0s 140us/step - loss: 1005.2763 - mean_absolute_error: 1005.2763 - val_loss: 650.1349 - val_mean_absolute_error: 650.1349
#
# Epoch 00150: val_loss did not improve from 584.34081
# Epoch 151/500
# 585/585 [==============================] - 0s 150us/step - loss: 1010.8065 - mean_absolute_error: 1010.8065 - val_loss: 634.6376 - val_mean_absolute_error: 634.6376
#
# Epoch 00151: val_loss did not improve from 584.34081
# Epoch 152/500
# 585/585 [==============================] - 0s 135us/step - loss: 1015.8941 - mean_absolute_error: 1015.8941 - val_loss: 691.3982 - val_mean_absolute_error: 691.3982
#
# Epoch 00152: val_loss did not improve from 584.34081
# Epoch 153/500
# 585/585 [==============================] - 0s 130us/step - loss: 1017.6773 - mean_absolute_error: 1017.6773 - val_loss: 611.9292 - val_mean_absolute_error: 611.9292
#
# Epoch 00153: val_loss did not improve from 584.34081
# Epoch 154/500
# 585/585 [==============================] - 0s 142us/step - loss: 1018.3859 - mean_absolute_error: 1018.3859 - val_loss: 595.3804 - val_mean_absolute_error: 595.3804
#
# Epoch 00154: val_loss did not improve from 584.34081
# Epoch 155/500
# 585/585 [==============================] - 0s 131us/step - loss: 1024.4353 - mean_absolute_error: 1024.4353 - val_loss: 576.4815 - val_mean_absolute_error: 576.4815
#
# Epoch 00155: val_loss improved from 584.34081 to 576.48149, saving model to 선케어선케어-Weights-155--576.48149-cat04-vf05.hdf5
# Epoch 156/500
# 585/585 [==============================] - 0s 128us/step - loss: 1058.5874 - mean_absolute_error: 1058.5874 - val_loss: 613.4602 - val_mean_absolute_error: 613.4602
#
# Epoch 00156: val_loss did not improve from 576.48149
# Epoch 157/500
# 585/585 [==============================] - 0s 121us/step - loss: 1039.1299 - mean_absolute_error: 1039.1299 - val_loss: 601.9992 - val_mean_absolute_error: 601.9992
#
# Epoch 00157: val_loss did not improve from 576.48149
# Epoch 158/500
# 585/585 [==============================] - 0s 118us/step - loss: 1026.7982 - mean_absolute_error: 1026.7982 - val_loss: 673.6653 - val_mean_absolute_error: 673.6653
#
# Epoch 00158: val_loss did not improve from 576.48149
# Epoch 159/500
# 585/585 [==============================] - 0s 119us/step - loss: 1050.3226 - mean_absolute_error: 1050.3226 - val_loss: 712.1812 - val_mean_absolute_error: 712.1812
#
# Epoch 00159: val_loss did not improve from 576.48149
# Epoch 160/500
# 585/585 [==============================] - 0s 114us/step - loss: 1006.5402 - mean_absolute_error: 1006.5402 - val_loss: 641.6961 - val_mean_absolute_error: 641.6961
#
# Epoch 00160: val_loss did not improve from 576.48149
# Epoch 161/500
# 585/585 [==============================] - 0s 133us/step - loss: 1013.6832 - mean_absolute_error: 1013.6832 - val_loss: 632.8744 - val_mean_absolute_error: 632.8744
#
# Epoch 00161: val_loss did not improve from 576.48149
# Epoch 162/500
# 585/585 [==============================] - 0s 130us/step - loss: 987.7570 - mean_absolute_error: 987.7570 - val_loss: 601.8681 - val_mean_absolute_error: 601.8681
#
# Epoch 00162: val_loss did not improve from 576.48149
# Epoch 163/500
# 585/585 [==============================] - 0s 121us/step - loss: 989.2099 - mean_absolute_error: 989.2099 - val_loss: 591.5530 - val_mean_absolute_error: 591.5530
#
# Epoch 00163: val_loss did not improve from 576.48149
# Epoch 164/500
# 585/585 [==============================] - 0s 116us/step - loss: 998.0948 - mean_absolute_error: 998.0948 - val_loss: 589.7780 - val_mean_absolute_error: 589.7780
#
# Epoch 00164: val_loss did not improve from 576.48149
# Epoch 165/500
# 585/585 [==============================] - 0s 120us/step - loss: 993.5752 - mean_absolute_error: 993.5752 - val_loss: 643.9053 - val_mean_absolute_error: 643.9053
#
# Epoch 00165: val_loss did not improve from 576.48149
# Epoch 166/500
# 585/585 [==============================] - 0s 115us/step - loss: 987.6326 - mean_absolute_error: 987.6326 - val_loss: 613.0383 - val_mean_absolute_error: 613.0383
#
# Epoch 00166: val_loss did not improve from 576.48149
# Epoch 167/500
# 585/585 [==============================] - 0s 128us/step - loss: 982.4970 - mean_absolute_error: 982.4970 - val_loss: 726.1775 - val_mean_absolute_error: 726.1775
#
# Epoch 00167: val_loss did not improve from 576.48149
# Epoch 168/500
# 585/585 [==============================] - 0s 119us/step - loss: 1032.3068 - mean_absolute_error: 1032.3068 - val_loss: 731.7926 - val_mean_absolute_error: 731.7926
#
# Epoch 00168: val_loss did not improve from 576.48149
# Epoch 169/500
# 585/585 [==============================] - 0s 140us/step - loss: 1014.1636 - mean_absolute_error: 1014.1636 - val_loss: 614.6132 - val_mean_absolute_error: 614.6132
#
# Epoch 00169: val_loss did not improve from 576.48149
# Epoch 170/500
# 585/585 [==============================] - 0s 135us/step - loss: 1010.4316 - mean_absolute_error: 1010.4316 - val_loss: 589.5833 - val_mean_absolute_error: 589.5833
#
# Epoch 00170: val_loss did not improve from 576.48149
# Epoch 171/500
# 585/585 [==============================] - 0s 143us/step - loss: 1009.8460 - mean_absolute_error: 1009.8460 - val_loss: 616.7970 - val_mean_absolute_error: 616.7970
#
# Epoch 00171: val_loss did not improve from 576.48149
# Epoch 172/500
# 585/585 [==============================] - 0s 131us/step - loss: 997.7115 - mean_absolute_error: 997.7115 - val_loss: 672.2599 - val_mean_absolute_error: 672.2599
#
# Epoch 00172: val_loss did not improve from 576.48149
# Epoch 173/500
# 585/585 [==============================] - 0s 128us/step - loss: 991.3280 - mean_absolute_error: 991.3280 - val_loss: 650.1962 - val_mean_absolute_error: 650.1962
#
# Epoch 00173: val_loss did not improve from 576.48149
# Epoch 174/500
# 585/585 [==============================] - 0s 128us/step - loss: 996.0213 - mean_absolute_error: 996.0213 - val_loss: 601.1487 - val_mean_absolute_error: 601.1487
#
# Epoch 00174: val_loss did not improve from 576.48149
# Epoch 175/500
# 585/585 [==============================] - 0s 145us/step - loss: 1001.0777 - mean_absolute_error: 1001.0777 - val_loss: 607.7066 - val_mean_absolute_error: 607.7066
#
# Epoch 00175: val_loss did not improve from 576.48149
# Epoch 176/500
# 585/585 [==============================] - 0s 153us/step - loss: 987.9050 - mean_absolute_error: 987.9050 - val_loss: 585.0462 - val_mean_absolute_error: 585.0462
#
# Epoch 00176: val_loss did not improve from 576.48149
# Epoch 177/500
# 585/585 [==============================] - 0s 131us/step - loss: 990.4200 - mean_absolute_error: 990.4200 - val_loss: 614.4591 - val_mean_absolute_error: 614.4591
#
# Epoch 00177: val_loss did not improve from 576.48149
# Epoch 178/500
# 585/585 [==============================] - 0s 140us/step - loss: 982.1079 - mean_absolute_error: 982.1079 - val_loss: 658.5462 - val_mean_absolute_error: 658.5462
#
# Epoch 00178: val_loss did not improve from 576.48149
# Epoch 179/500
# 585/585 [==============================] - 0s 138us/step - loss: 987.9389 - mean_absolute_error: 987.9389 - val_loss: 655.0901 - val_mean_absolute_error: 655.0901
#
# Epoch 00179: val_loss did not improve from 576.48149
# Epoch 180/500
# 585/585 [==============================] - 0s 145us/step - loss: 986.7169 - mean_absolute_error: 986.7169 - val_loss: 598.1041 - val_mean_absolute_error: 598.1041
#
# Epoch 00180: val_loss did not improve from 576.48149
# Epoch 181/500
# 585/585 [==============================] - 0s 139us/step - loss: 975.1846 - mean_absolute_error: 975.1846 - val_loss: 590.8960 - val_mean_absolute_error: 590.8960
#
# Epoch 00181: val_loss did not improve from 576.48149
# Epoch 182/500
# 585/585 [==============================] - 0s 147us/step - loss: 994.5538 - mean_absolute_error: 994.5538 - val_loss: 609.2785 - val_mean_absolute_error: 609.2785
#
# Epoch 00182: val_loss did not improve from 576.48149
# Epoch 183/500
# 585/585 [==============================] - 0s 130us/step - loss: 973.4693 - mean_absolute_error: 973.4693 - val_loss: 603.5513 - val_mean_absolute_error: 603.5513
#
# Epoch 00183: val_loss did not improve from 576.48149
# Epoch 184/500
# 585/585 [==============================] - 0s 136us/step - loss: 973.7687 - mean_absolute_error: 973.7687 - val_loss: 612.3496 - val_mean_absolute_error: 612.3496
#
# Epoch 00184: val_loss did not improve from 576.48149
# Epoch 185/500
# 585/585 [==============================] - 0s 140us/step - loss: 975.0054 - mean_absolute_error: 975.0054 - val_loss: 607.5668 - val_mean_absolute_error: 607.5668
#
# Epoch 00185: val_loss did not improve from 576.48149
# Epoch 186/500
# 585/585 [==============================] - 0s 155us/step - loss: 968.5110 - mean_absolute_error: 968.5110 - val_loss: 614.9403 - val_mean_absolute_error: 614.9403
#
# Epoch 00186: val_loss did not improve from 576.48149
# Epoch 187/500
# 585/585 [==============================] - 0s 153us/step - loss: 960.5058 - mean_absolute_error: 960.5058 - val_loss: 667.3286 - val_mean_absolute_error: 667.3286
#
# Epoch 00187: val_loss did not improve from 576.48149
# Epoch 188/500
# 585/585 [==============================] - 0s 143us/step - loss: 960.8984 - mean_absolute_error: 960.8984 - val_loss: 623.3655 - val_mean_absolute_error: 623.3655
#
# Epoch 00188: val_loss did not improve from 576.48149
# Epoch 189/500
# 585/585 [==============================] - 0s 160us/step - loss: 959.3030 - mean_absolute_error: 959.3030 - val_loss: 611.1499 - val_mean_absolute_error: 611.1499
#
# Epoch 00189: val_loss did not improve from 576.48149
# Epoch 190/500
# 585/585 [==============================] - 0s 147us/step - loss: 967.5304 - mean_absolute_error: 967.5304 - val_loss: 575.2937 - val_mean_absolute_error: 575.2937
#
# Epoch 00190: val_loss improved from 576.48149 to 575.29372, saving model to 선케어선케어-Weights-190--575.29372-cat04-vf05.hdf5
# Epoch 191/500
# 585/585 [==============================] - 0s 153us/step - loss: 965.5159 - mean_absolute_error: 965.5159 - val_loss: 631.2945 - val_mean_absolute_error: 631.2945
#
# Epoch 00191: val_loss did not improve from 575.29372
# Epoch 192/500
# 585/585 [==============================] - 0s 150us/step - loss: 977.3261 - mean_absolute_error: 977.3261 - val_loss: 696.5017 - val_mean_absolute_error: 696.5017
#
# Epoch 00192: val_loss did not improve from 575.29372
# Epoch 193/500
# 585/585 [==============================] - 0s 145us/step - loss: 991.0721 - mean_absolute_error: 991.0721 - val_loss: 604.2683 - val_mean_absolute_error: 604.2683
#
# Epoch 00193: val_loss did not improve from 575.29372
# Epoch 194/500
# 585/585 [==============================] - 0s 159us/step - loss: 967.5490 - mean_absolute_error: 967.5490 - val_loss: 552.7864 - val_mean_absolute_error: 552.7864
#
# Epoch 00194: val_loss improved from 575.29372 to 552.78638, saving model to 선케어선케어-Weights-194--552.78638-cat04-vf05.hdf5
# Epoch 195/500
# 585/585 [==============================] - 0s 143us/step - loss: 1021.7527 - mean_absolute_error: 1021.7527 - val_loss: 568.3530 - val_mean_absolute_error: 568.3530
#
# Epoch 00195: val_loss did not improve from 552.78638
# Epoch 196/500
# 585/585 [==============================] - 0s 133us/step - loss: 968.0194 - mean_absolute_error: 968.0194 - val_loss: 583.7728 - val_mean_absolute_error: 583.7728
#
# Epoch 00196: val_loss did not improve from 552.78638
# Epoch 197/500
# 585/585 [==============================] - 0s 137us/step - loss: 957.7902 - mean_absolute_error: 957.7902 - val_loss: 621.5709 - val_mean_absolute_error: 621.5709
#
# Epoch 00197: val_loss did not improve from 552.78638
# Epoch 198/500
# 585/585 [==============================] - 0s 141us/step - loss: 949.2227 - mean_absolute_error: 949.2227 - val_loss: 617.1463 - val_mean_absolute_error: 617.1463
#
# Epoch 00198: val_loss did not improve from 552.78638
# Epoch 199/500
# 585/585 [==============================] - 0s 140us/step - loss: 943.4954 - mean_absolute_error: 943.4954 - val_loss: 581.6712 - val_mean_absolute_error: 581.6712
#
# Epoch 00199: val_loss did not improve from 552.78638
# Epoch 200/500
# 585/585 [==============================] - 0s 159us/step - loss: 943.9289 - mean_absolute_error: 943.9289 - val_loss: 620.1850 - val_mean_absolute_error: 620.1850
#
# Epoch 00200: val_loss did not improve from 552.78638
# Epoch 201/500
# 585/585 [==============================] - 0s 164us/step - loss: 959.2376 - mean_absolute_error: 959.2376 - val_loss: 583.5814 - val_mean_absolute_error: 583.5814
#
# Epoch 00201: val_loss did not improve from 552.78638
# Epoch 202/500
# 585/585 [==============================] - 0s 138us/step - loss: 942.9860 - mean_absolute_error: 942.9860 - val_loss: 597.8492 - val_mean_absolute_error: 597.8492
#
# Epoch 00202: val_loss did not improve from 552.78638
# Epoch 203/500
# 585/585 [==============================] - 0s 164us/step - loss: 945.4172 - mean_absolute_error: 945.4172 - val_loss: 600.8742 - val_mean_absolute_error: 600.8742
#
# Epoch 00203: val_loss did not improve from 552.78638
# Epoch 204/500
# ...
# Epoch 432/500
# 585/585 [==============================] - 0s 177us/step - loss: 817.4019 - mean_absolute_error: 817.4019 - val_loss: 762.6737 - val_mean_absolute_error: 762.6737
#
# Epoch 00432: val_loss did not improve from 529.65846
# Epoch 433/500
# 585/585 [==============================] - 0s 170us/step - loss: 810.6751 - mean_absolute_error: 810.6751 - val_loss: 644.9189 - val_mean_absolute_error: 644.9189
#
# Epoch 00433: val_loss did not improve from 529.65846
# Epoch 434/500
# 585/585 [==============================] - 0s 184us/step - loss: 820.6187 - mean_absolute_error: 820.6187 - val_loss: 713.6877 - val_mean_absolute_error: 713.6877
#
# Epoch 00434: val_loss did not improve from 529.65846
# Epoch 435/500
# 585/585 [==============================] - 0s 157us/step - loss: 798.4812 - mean_absolute_error: 798.4812 - val_loss: 649.5824 - val_mean_absolute_error: 649.5824
#
# Epoch 00435: val_loss did not improve from 529.65846
# Epoch 436/500
# 585/585 [==============================] - 0s 176us/step - loss: 802.9731 - mean_absolute_error: 802.9731 - val_loss: 703.3866 - val_mean_absolute_error: 703.3866
#
# Epoch 00436: val_loss did not improve from 529.65846
# Epoch 437/500
# 585/585 [==============================] - 0s 181us/step - loss: 791.4128 - mean_absolute_error: 791.4128 - val_loss: 702.3573 - val_mean_absolute_error: 702.3573
#
# Epoch 00437: val_loss did not improve from 529.65846
# Epoch 438/500
# 585/585 [==============================] - 0s 182us/step - loss: 812.5789 - mean_absolute_error: 812.5789 - val_loss: 678.1691 - val_mean_absolute_error: 678.1691
#
# Epoch 00438: val_loss did not improve from 529.65846
# Epoch 439/500
# 585/585 [==============================] - 0s 186us/step - loss: 795.4076 - mean_absolute_error: 795.4076 - val_loss: 704.6959 - val_mean_absolute_error: 704.6959
#
# Epoch 00439: val_loss did not improve from 529.65846
# Epoch 440/500
# 585/585 [==============================] - 0s 172us/step - loss: 791.1696 - mean_absolute_error: 791.1696 - val_loss: 653.8233 - val_mean_absolute_error: 653.8233
#
# Epoch 00440: val_loss did not improve from 529.65846
# Epoch 441/500
# 585/585 [==============================] - 0s 160us/step - loss: 804.1183 - mean_absolute_error: 804.1183 - val_loss: 684.2113 - val_mean_absolute_error: 684.2113
#
# Epoch 00441: val_loss did not improve from 529.65846
# Epoch 442/500
# 585/585 [==============================] - 0s 165us/step - loss: 802.1546 - mean_absolute_error: 802.1546 - val_loss: 645.2816 - val_mean_absolute_error: 645.2816
#
# Epoch 00442: val_loss did not improve from 529.65846
# Epoch 443/500
# 585/585 [==============================] - 0s 157us/step - loss: 816.1568 - mean_absolute_error: 816.1568 - val_loss: 689.3777 - val_mean_absolute_error: 689.3777
#
# Epoch 00443: val_loss did not improve from 529.65846
# Epoch 444/500
# 585/585 [==============================] - 0s 170us/step - loss: 826.2915 - mean_absolute_error: 826.2915 - val_loss: 774.5228 - val_mean_absolute_error: 774.5228
#
# Epoch 00444: val_loss did not improve from 529.65846
# Epoch 445/500
# 585/585 [==============================] - 0s 158us/step - loss: 792.1374 - mean_absolute_error: 792.1374 - val_loss: 698.4212 - val_mean_absolute_error: 698.4212
#
# Epoch 00445: val_loss did not improve from 529.65846
# Epoch 446/500
# 585/585 [==============================] - 0s 155us/step - loss: 811.0302 - mean_absolute_error: 811.0302 - val_loss: 699.5703 - val_mean_absolute_error: 699.5703
#
# Epoch 00446: val_loss did not improve from 529.65846
# Epoch 447/500
# 585/585 [==============================] - 0s 164us/step - loss: 793.0869 - mean_absolute_error: 793.0869 - val_loss: 647.9204 - val_mean_absolute_error: 647.9204
#
# Epoch 00447: val_loss did not improve from 529.65846
# Epoch 448/500
# 585/585 [==============================] - 0s 164us/step - loss: 805.4609 - mean_absolute_error: 805.4609 - val_loss: 725.0067 - val_mean_absolute_error: 725.0067
#
# Epoch 00448: val_loss did not improve from 529.65846
# Epoch 449/500
# 585/585 [==============================] - 0s 164us/step - loss: 809.7105 - mean_absolute_error: 809.7105 - val_loss: 695.0693 - val_mean_absolute_error: 695.0693
#
# Epoch 00449: val_loss did not improve from 529.65846
# Epoch 450/500
# 585/585 [==============================] - 0s 153us/step - loss: 800.9266 - mean_absolute_error: 800.9266 - val_loss: 681.5749 - val_mean_absolute_error: 681.5749
#
# Epoch 00450: val_loss did not improve from 529.65846
# Epoch 451/500
# 585/585 [==============================] - 0s 148us/step - loss: 785.3526 - mean_absolute_error: 785.3526 - val_loss: 752.6334 - val_mean_absolute_error: 752.6334
#
# Epoch 00451: val_loss did not improve from 529.65846
# Epoch 452/500
# 585/585 [==============================] - 0s 147us/step - loss: 809.6506 - mean_absolute_error: 809.6506 - val_loss: 659.7581 - val_mean_absolute_error: 659.7581
#
# Epoch 00452: val_loss did not improve from 529.65846
# Epoch 453/500
# 585/585 [==============================] - 0s 162us/step - loss: 799.2878 - mean_absolute_error: 799.2878 - val_loss: 682.3724 - val_mean_absolute_error: 682.3724
#
# Epoch 00453: val_loss did not improve from 529.65846
# Epoch 454/500
# 585/585 [==============================] - ETA: 0s - loss: 725.9758 - mean_absolute_error: 725.975 - 0s 145us/step - loss: 772.9925 - mean_absolute_error: 772.9925 - val_loss: 707.0977 - val_mean_absolute_error: 707.0977
#
# Epoch 00454: val_loss did not improve from 529.65846
# Epoch 455/500
# 585/585 [==============================] - 0s 138us/step - loss: 786.3087 - mean_absolute_error: 786.3087 - val_loss: 752.5633 - val_mean_absolute_error: 752.5633
#
# Epoch 00455: val_loss did not improve from 529.65846
# Epoch 456/500
# 585/585 [==============================] - 0s 146us/step - loss: 817.8616 - mean_absolute_error: 817.8616 - val_loss: 682.5448 - val_mean_absolute_error: 682.5448
#
# Epoch 00456: val_loss did not improve from 529.65846
# Epoch 457/500
# 585/585 [==============================] - 0s 142us/step - loss: 824.8711 - mean_absolute_error: 824.8711 - val_loss: 723.4908 - val_mean_absolute_error: 723.4908
#
# Epoch 00457: val_loss did not improve from 529.65846
# Epoch 458/500
# 585/585 [==============================] - 0s 152us/step - loss: 792.3252 - mean_absolute_error: 792.3252 - val_loss: 633.7740 - val_mean_absolute_error: 633.7740
#
# Epoch 00458: val_loss did not improve from 529.65846
# Epoch 459/500
# 585/585 [==============================] - 0s 156us/step - loss: 806.0371 - mean_absolute_error: 806.0371 - val_loss: 745.3815 - val_mean_absolute_error: 745.3815
#
# Epoch 00459: val_loss did not improve from 529.65846
# Epoch 460/500
# 585/585 [==============================] - 0s 181us/step - loss: 793.7191 - mean_absolute_error: 793.7191 - val_loss: 724.4690 - val_mean_absolute_error: 724.4690
#
# Epoch 00460: val_loss did not improve from 529.65846
# Epoch 461/500
# 585/585 [==============================] - 0s 176us/step - loss: 818.3903 - mean_absolute_error: 818.3903 - val_loss: 648.4256 - val_mean_absolute_error: 648.4256
#
# Epoch 00461: val_loss did not improve from 529.65846
# Epoch 462/500
# 585/585 [==============================] - 0s 153us/step - loss: 793.6799 - mean_absolute_error: 793.6799 - val_loss: 708.7821 - val_mean_absolute_error: 708.7821
#
# Epoch 00462: val_loss did not improve from 529.65846
# Epoch 463/500
# 585/585 [==============================] - 0s 177us/step - loss: 794.7361 - mean_absolute_error: 794.7361 - val_loss: 667.0313 - val_mean_absolute_error: 667.0313
#
# Epoch 00463: val_loss did not improve from 529.65846
# Epoch 464/500
# 585/585 [==============================] - 0s 164us/step - loss: 843.1346 - mean_absolute_error: 843.1346 - val_loss: 660.3646 - val_mean_absolute_error: 660.3646
#
# Epoch 00464: val_loss did not improve from 529.65846
# Epoch 465/500
# 585/585 [==============================] - 0s 184us/step - loss: 785.2590 - mean_absolute_error: 785.2590 - val_loss: 687.4739 - val_mean_absolute_error: 687.4739
#
# Epoch 00465: val_loss did not improve from 529.65846
# Epoch 466/500
# 585/585 [==============================] - 0s 169us/step - loss: 778.9359 - mean_absolute_error: 778.9359 - val_loss: 656.4206 - val_mean_absolute_error: 656.4206
#
# Epoch 00466: val_loss did not improve from 529.65846
# Epoch 467/500
# 585/585 [==============================] - 0s 185us/step - loss: 790.7700 - mean_absolute_error: 790.7700 - val_loss: 718.8587 - val_mean_absolute_error: 718.8587
#
# Epoch 00467: val_loss did not improve from 529.65846
# Epoch 468/500
# 585/585 [==============================] - 0s 186us/step - loss: 792.0423 - mean_absolute_error: 792.0423 - val_loss: 663.5925 - val_mean_absolute_error: 663.5925
#
# Epoch 00468: val_loss did not improve from 529.65846
# Epoch 469/500
# 585/585 [==============================] - 0s 182us/step - loss: 781.1068 - mean_absolute_error: 781.1068 - val_loss: 699.2945 - val_mean_absolute_error: 699.2945
#
# Epoch 00469: val_loss did not improve from 529.65846
# Epoch 470/500
# 585/585 [==============================] - 0s 227us/step - loss: 813.5022 - mean_absolute_error: 813.5022 - val_loss: 619.3048 - val_mean_absolute_error: 619.3048
#
# Epoch 00470: val_loss did not improve from 529.65846
# Epoch 471/500
# 585/585 [==============================] - 0s 189us/step - loss: 834.0332 - mean_absolute_error: 834.0332 - val_loss: 706.1694 - val_mean_absolute_error: 706.1694
#
# Epoch 00471: val_loss did not improve from 529.65846
# Epoch 472/500
# 585/585 [==============================] - 0s 202us/step - loss: 782.5842 - mean_absolute_error: 782.5842 - val_loss: 731.2832 - val_mean_absolute_error: 731.2832
#
# Epoch 00472: val_loss did not improve from 529.65846
# Epoch 473/500
# 585/585 [==============================] - 0s 162us/step - loss: 785.3386 - mean_absolute_error: 785.3386 - val_loss: 664.8024 - val_mean_absolute_error: 664.8024
#
# Epoch 00473: val_loss did not improve from 529.65846
# Epoch 474/500
# 585/585 [==============================] - 0s 179us/step - loss: 796.9621 - mean_absolute_error: 796.9621 - val_loss: 720.4964 - val_mean_absolute_error: 720.4964
#
# Epoch 00474: val_loss did not improve from 529.65846
# Epoch 475/500
# 585/585 [==============================] - 0s 186us/step - loss: 789.4115 - mean_absolute_error: 789.4115 - val_loss: 694.4436 - val_mean_absolute_error: 694.4436
#
# Epoch 00475: val_loss did not improve from 529.65846
# Epoch 476/500
# 585/585 [==============================] - 0s 164us/step - loss: 798.9759 - mean_absolute_error: 798.9759 - val_loss: 700.8769 - val_mean_absolute_error: 700.8769
#
# Epoch 00476: val_loss did not improve from 529.65846
# Epoch 477/500
# 585/585 [==============================] - 0s 176us/step - loss: 779.9726 - mean_absolute_error: 779.9726 - val_loss: 737.1462 - val_mean_absolute_error: 737.1462
#
# Epoch 00477: val_loss did not improve from 529.65846
# Epoch 478/500
# 585/585 [==============================] - 0s 176us/step - loss: 802.9905 - mean_absolute_error: 802.9905 - val_loss: 691.9506 - val_mean_absolute_error: 691.9506
#
# Epoch 00478: val_loss did not improve from 529.65846
# Epoch 479/500
# 585/585 [==============================] - 0s 164us/step - loss: 808.9752 - mean_absolute_error: 808.9752 - val_loss: 714.2669 - val_mean_absolute_error: 714.2669
#
# Epoch 00479: val_loss did not improve from 529.65846
# Epoch 480/500
# 585/585 [==============================] - 0s 167us/step - loss: 781.8603 - mean_absolute_error: 781.8603 - val_loss: 680.3576 - val_mean_absolute_error: 680.3576
#
# Epoch 00480: val_loss did not improve from 529.65846
# Epoch 481/500
# 585/585 [==============================] - 0s 176us/step - loss: 818.0291 - mean_absolute_error: 818.0291 - val_loss: 630.5577 - val_mean_absolute_error: 630.5577
#
# Epoch 00481: val_loss did not improve from 529.65846
# Epoch 482/500
# 585/585 [==============================] - 0s 177us/step - loss: 806.5660 - mean_absolute_error: 806.5660 - val_loss: 690.5174 - val_mean_absolute_error: 690.5174
#
# Epoch 00482: val_loss did not improve from 529.65846
# Epoch 483/500
# 585/585 [==============================] - 0s 188us/step - loss: 781.9708 - mean_absolute_error: 781.9708 - val_loss: 665.7039 - val_mean_absolute_error: 665.7039
#
# Epoch 00483: val_loss did not improve from 529.65846
# Epoch 484/500
# 585/585 [==============================] - 0s 185us/step - loss: 785.2632 - mean_absolute_error: 785.2632 - val_loss: 669.0806 - val_mean_absolute_error: 669.0806
#
# Epoch 00484: val_loss did not improve from 529.65846
# Epoch 485/500
# 585/585 [==============================] - 0s 187us/step - loss: 784.7355 - mean_absolute_error: 784.7355 - val_loss: 678.2642 - val_mean_absolute_error: 678.2642
#
# Epoch 00485: val_loss did not improve from 529.65846
# Epoch 486/500
# 585/585 [==============================] - 0s 201us/step - loss: 777.8466 - mean_absolute_error: 777.8466 - val_loss: 745.7776 - val_mean_absolute_error: 745.7776
#
# Epoch 00486: val_loss did not improve from 529.65846
# Epoch 487/500
# 585/585 [==============================] - 0s 184us/step - loss: 800.0074 - mean_absolute_error: 800.0074 - val_loss: 703.3688 - val_mean_absolute_error: 703.3688
#
# Epoch 00487: val_loss did not improve from 529.65846
# Epoch 488/500
# 585/585 [==============================] - 0s 188us/step - loss: 776.5442 - mean_absolute_error: 776.5442 - val_loss: 663.4463 - val_mean_absolute_error: 663.4463
#
# Epoch 00488: val_loss did not improve from 529.65846
# Epoch 489/500
# 585/585 [==============================] - 0s 201us/step - loss: 777.5781 - mean_absolute_error: 777.5781 - val_loss: 671.7431 - val_mean_absolute_error: 671.7431
#
# Epoch 00489: val_loss did not improve from 529.65846
# Epoch 490/500
# 585/585 [==============================] - 0s 182us/step - loss: 807.5627 - mean_absolute_error: 807.5627 - val_loss: 667.8822 - val_mean_absolute_error: 667.8822
#
# Epoch 00490: val_loss did not improve from 529.65846
# Epoch 491/500
# 585/585 [==============================] - 0s 181us/step - loss: 785.6819 - mean_absolute_error: 785.6819 - val_loss: 708.5572 - val_mean_absolute_error: 708.5572
#
# Epoch 00491: val_loss did not improve from 529.65846
# Epoch 492/500
# 585/585 [==============================] - 0s 170us/step - loss: 797.5514 - mean_absolute_error: 797.5514 - val_loss: 669.9854 - val_mean_absolute_error: 669.9854
# Epoch 00492: val_loss did not improve from 529.65846
# Epoch 493/500
# 585/585 [==============================] - 0s 196us/step - loss: 777.9676 - mean_absolute_error: 777.9676 - val_loss: 684.2925 - val_mean_absolute_error: 684.2925
#
# Epoch 00493: val_loss did not improve from 529.65846
# Epoch 494/500
# 585/585 [==============================] - 0s 170us/step - loss: 787.2882 - mean_absolute_error: 787.2882 - val_loss: 708.4961 - val_mean_absolute_error: 708.4961
#
# Epoch 00494: val_loss did not improve from 529.65846
# Epoch 495/500
# 585/585 [==============================] - 0s 228us/step - loss: 767.1831 - mean_absolute_error: 767.1831 - val_loss: 691.1273 - val_mean_absolute_error: 691.1273
#
# Epoch 00495: val_loss did not improve from 529.65846
# Epoch 496/500
# 585/585 [==============================] - 0s 204us/step - loss: 814.5806 - mean_absolute_error: 814.5806 - val_loss: 720.0140 - val_mean_absolute_error: 720.0140
#
# Epoch 00496: val_loss did not improve from 529.65846
# Epoch 497/500
# 585/585 [==============================] - 0s 186us/step - loss: 799.8728 - mean_absolute_error: 799.8728 - val_loss: 713.0258 - val_mean_absolute_error: 713.0258
#
# Epoch 00497: val_loss did not improve from 529.65846
# Epoch 498/500
# 585/585 [==============================] - 0s 187us/step - loss: 779.1878 - mean_absolute_error: 779.1878 - val_loss: 665.4972 - val_mean_absolute_error: 665.4972
#
# Epoch 00498: val_loss did not improve from 529.65846
# Epoch 499/500
# 585/585 [==============================] - 0s 196us/step - loss: 789.8712 - mean_absolute_error: 789.8712 - val_loss: 742.1618 - val_mean_absolute_error: 742.1618
#
# Epoch 00499: val_loss did not improve from 529.65846
# Epoch 500/500
# 585/585 [==============================] - 0s 205us/step - loss: 827.5611 - mean_absolute_error: 827.5611 - val_loss: 776.6785 - val_mean_absolute_error: 776.6785
#
# Epoch 00500: val_loss did not improve from 529.65846

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = '선케어date-Weights-245--529.65846-cat04-vf05.hdf5'
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# Out:
# W0719 18:55:17.871878  2312 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0719 18:55:17.872846  2312 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']

print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

columns_in_data = list(train_X.columns)
customF = formulaGen(target='qty',ind_features=columns_in_data)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
print('검증세트점수 : {:.3f}'.format( r2_score(val_y, olsModel.predict(val_X))   ) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 선케어의 회귀분석 결과 :
# 훈련세트점수 : 0.920
# 검증세트점수 : 0.528
# XGBoost을 이용한 선케어의 회귀분석 결과 :
# 훈련세트점수 : 0.796
# 검증세트점수 : 0.522
# LinearRegression을 이용한 선케어의 회귀분석 결과 :
# 훈련세트점수 : 0.527
# 검증세트점수 : 0.466
# RidgeRegression을 이용한 선케어의 회귀분석 결과 :
# 훈련세트점수 : 0.518
# 검증세트점수 : 0.469
# LassoRegression을 이용한 선케어의 회귀분석 결과 :
# 훈련세트점수 : 0.527
# 검증세트점수 : 0.466
# OLS을 이용한 선케어의 회귀분석 결과 :
# 훈련세트점수 : 0.527
# 검증세트점수 : 0.466

# %%
# columns_in_data = ['temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not', 'snow_or_not',
#                     '공기상태_0', '공기상태_1', '공기상태_2']

# formulaGen은 단순 1차 다항식을 제조해준다.
# customF = formulaGen(target='qty',ind_features=columns_in_data)
# customF = formulaGen(target='qty',ind_features=['temp', 'wind','lgt_time','rain_or_not'])
customF = 'qty ~ I(temp**2) + cloud + wind + lgt_time + rain_or_not + snow_or_not'

olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('사람이 직접 식을 때려 박았을때 : {:.3f}'.format(r2_score(val_y, olsModel.predict(val_X))) )
print(olsModel.summary())
# Out:
# 사람이 직접 식을 때려 박았을때 : 0.526
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     143.9
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          6.21e-120
# Time:                        18:55:19   Log-Likelihood:                -6387.0
# No. Observations:                 732   AIC:                         1.279e+04
# Df Residuals:                     725   BIC:                         1.282e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -751.5701    359.723     -2.089      0.037   -1457.794     -45.346
# I(temp ** 2)     5.2232      0.230     22.667      0.000       4.771       5.676
# cloud          156.6730     34.853      4.495      0.000      88.248     225.098
# wind           106.8038     82.385      1.296      0.195     -54.938     268.546
# lgt_time       178.6105     27.932      6.394      0.000     123.773     233.448
# rain_or_not    290.5965    161.701      1.797      0.073     -26.861     608.054
# snow_or_not   -324.6933    297.002     -1.093      0.275    -907.780     258.394
# ==============================================================================
# Omnibus:                       52.370   Durbin-Watson:                   0.469
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.786
# Skew:                           0.587   Prob(JB):                     4.26e-16
# Kurtosis:                       3.972   Cond. No.                     2.48e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
#             '공기상태_0', '공기상태_1', '공기상태_2']
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
            '공기상태']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = lv_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 예측률 계산
# https://yamalab.tistory.com/46

# RMSE (Root Mean Squared Error) : 
# OLS 추정에서 일반적인 표준 오차이다. 예측 대상의 scale(단위 크기)에 주의해야하는 단점이 있다. 
# MSE는 root를 수식에서 제외, SSE는 root와 분모를 제외한 수식으로, SE가 붙은 척도들은 거기서 거기인 척도들이라고 보면 된다.
# 다만 디테일한 사용법에 차이가 있을 뿐.

# MAPE (Mean Absolute Percentage Error) :

# 위 방법의 단점을 보완한 것이다. 
# At는 실제값, Ft는 예측값인데, 이를 At로 나누어서 오차를 절대적 크기로 보는것이 아닌
# 비율의 크기로 보고자 하는 것이 핵심이다.
# 이 방법은 At가 0에 가까울수록 비정상적인 값이 나온다는 단점이 있다.

# MAPE가 0에 가까울수록 좋은 모델
result_df['mape_keras'] = abs((result_df.qty - result_df.keras_qty) / result_df.qty )
result_df['mape_rf'] = abs((result_df.qty - result_df.rf_qty) / result_df.qty )
result_df['mape_xgb'] = abs((result_df.qty - result_df.xgb_qty) / result_df.qty )
result_df['mape_lin'] = abs((result_df.qty - result_df.lin_qty) / result_df.qty )
result_df['mape_ridge'] = abs((result_df.qty - result_df.ridge_qty) / result_df.qty )
result_df['mape_lasso'] = abs((result_df.qty - result_df.lasso_qty) / result_df.qty )
result_df['mape_ols'] = abs((result_df.qty - result_df.ols_qty) / result_df.qty )

print('Keras 인공 신경망 모델 MAPE \t: {:<.2f}'.format(result_df['mape_keras'].sum() / result_df.shape[0] ))
print('RandomForest 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_rf'].sum() / result_df.shape[0] ))
print('XGBoosting  모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_xgb'].sum() / result_df.shape[0] ))
print('Linear 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lin'].sum() / result_df.shape[0] ))
print('Ridge 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_ridge'].sum() / result_df.shape[0] ))
print('Lasso 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lasso'].sum() / result_df.shape[0] ))
print('OLS 모델 MAPE \t\t\t: {:<.2f}'.format(result_df['mape_ols'].sum() / result_df.shape[0] ))
# Out:
# Keras 인공 신경망 모델 MAPE 	: 0.36
# RandomForest 모델 MAPE 		: 0.23
# XGBoosting  모델 MAPE 		: 0.37
# Linear 모델 MAPE 		: 0.59
# Ridge 모델 MAPE 		: 0.59
# Lasso 모델 MAPE 		: 0.59
# OLS 모델 MAPE 			: 0.52

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not','snow_or_not', 
#                                                   '공기상태_0', '공기상태_1', '공기상태_2']

# 1~9 : 1 temp ~ 9 공기상태_2
n= 1
# alpha 값 0~1
alp = 1
# scatter plot 점 크기
dot_size = 20

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# # 1~106 / 106~156
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
