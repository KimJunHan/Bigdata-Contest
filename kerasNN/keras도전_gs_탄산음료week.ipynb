# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor


# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1))
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula


#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '탄산음료'만 빼서 df생성
item = '탄산음료'
grouped_by = 'week'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %% [markdown]
# # 주단위로 종합해보기

# %%
gs_week_w = gs_day_w.copy()
gs_week_w = addDayWeek(gs_week_w)

cols_Ineed = ['week','category', 'qty', 'temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
gs_week_w = gs_week_w[cols_Ineed]

# %%
list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
lowVIF(gs_week_w,40,list_col)

list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',]
gs_week_w = gs_week_w[['week','qty']+list_col].groupby('week').mean().reset_index()
# gs_week_w.tail(2)

# week: 1~105 = 2016~2017년
# week: 106~157 = 2018년
train_data = gs_week_w.loc[gs_week_w.week <=105]
test_date = gs_week_w.loc[gs_week_w.week >105]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
combined = gs_week_w.loc[:,'temp':'PM25']
target = gs_week_w.loc[:,'qty']

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 15
# Number of nun-numerical columns with no nan values : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 15 columns before encoding categorical features
# There are 15 columns after encoding categorical features

# %%
# 여기서 이코드으 제작자는 수동으로 훈련/검증셋을 나눔
# 105주 기준으로 나누겠음
cut_line = 106
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()
train.shape
# Out:
# (106, 15)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 15:42:56.025587  8000 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 15:42:56.040546  8000 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 15:42:56.042542  8000 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0717 15:42:56.099390  8000 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,913
# Trainable params: 166,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### =========='GS-탄산음료date-Weights-258--595.10015.hdf5'파일이 안주어지면 실행.(있으면 실행 필요없음)==========

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'GS-'+item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=106을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Train on 84 samples, validate on 22 samples
# Epoch 1/500
# 84/84 [==============================] - 0s 3ms/step - loss: 5959.7236 - mean_absolute_error: 5959.7236 - val_loss: 5813.9595 - val_mean_absolute_error: 5813.9595
#
# Epoch 00001: val_loss improved from inf to 5813.95947, saving model to GS-탄산음료week-Weights-001--5813.95947.hdf5
# Epoch 2/500
# 84/84 [==============================] - 0s 107us/step - loss: 5918.0086 - mean_absolute_error: 5918.0086 - val_loss: 5753.3062 - val_mean_absolute_error: 5753.3062
#
# Epoch 00002: val_loss improved from 5813.95947 to 5753.30615, saving model to GS-탄산음료week-Weights-002--5753.30615.hdf5
# Epoch 3/500
# 84/84 [==============================] - 0s 131us/step - loss: 5842.4896 - mean_absolute_error: 5842.4896 - val_loss: 5630.7847 - val_mean_absolute_error: 5630.7847
#
# Epoch 00003: val_loss improved from 5753.30615 to 5630.78467, saving model to GS-탄산음료week-Weights-003--5630.78467.hdf5
# Epoch 4/500
# 84/84 [==============================] - 0s 107us/step - loss: 5690.8526 - mean_absolute_error: 5690.8526 - val_loss: 5390.9141 - val_mean_absolute_error: 5390.9141
#
# Epoch 00004: val_loss improved from 5630.78467 to 5390.91406, saving model to GS-탄산음료week-Weights-004--5390.91406.hdf5
# Epoch 5/500
# 84/84 [==============================] - 0s 105us/step - loss: 5399.7091 - mean_absolute_error: 5399.7091 - val_loss: 4948.8374 - val_mean_absolute_error: 4948.8374
#
# Epoch 00005: val_loss improved from 5390.91406 to 4948.83740, saving model to GS-탄산음료week-Weights-005--4948.83740.hdf5
# Epoch 6/500
# 84/84 [==============================] - 0s 95us/step - loss: 4871.0103 - mean_absolute_error: 4871.0103 - val_loss: 4173.2119 - val_mean_absolute_error: 4173.2119
#
# Epoch 00006: val_loss improved from 4948.83740 to 4173.21191, saving model to GS-탄산음료week-Weights-006--4173.21191.hdf5
# Epoch 7/500
# 84/84 [==============================] - 0s 107us/step - loss: 3955.8080 - mean_absolute_error: 3955.8080 - val_loss: 2864.9072 - val_mean_absolute_error: 2864.9072
#
# Epoch 00007: val_loss improved from 4173.21191 to 2864.90723, saving model to GS-탄산음료week-Weights-007--2864.90723.hdf5
# Epoch 8/500
# 84/84 [==============================] - 0s 107us/step - loss: 2537.2437 - mean_absolute_error: 2537.2437 - val_loss: 779.3229 - val_mean_absolute_error: 779.3229
#
# Epoch 00008: val_loss improved from 2864.90723 to 779.32288, saving model to GS-탄산음료week-Weights-008--779.32288.hdf5
# Epoch 9/500
# 84/84 [==============================] - 0s 107us/step - loss: 1437.2468 - mean_absolute_error: 1437.2468 - val_loss: 1974.4155 - val_mean_absolute_error: 1974.4155
#
# Epoch 00009: val_loss did not improve from 779.32288
# Epoch 10/500
# 84/84 [==============================] - 0s 153us/step - loss: 2071.3713 - mean_absolute_error: 2071.3713 - val_loss: 1712.4657 - val_mean_absolute_error: 1712.4657
#
# Epoch 00010: val_loss did not improve from 779.32288
# Epoch 11/500
# 84/84 [==============================] - 0s 142us/step - loss: 1531.9616 - mean_absolute_error: 1531.9616 - val_loss: 658.6854 - val_mean_absolute_error: 658.6854
#
# Epoch 00011: val_loss improved from 779.32288 to 658.68536, saving model to GS-탄산음료week-Weights-011--658.68536.hdf5
# Epoch 12/500
# 84/84 [==============================] - 0s 119us/step - loss: 1326.4175 - mean_absolute_error: 1326.4175 - val_loss: 707.6018 - val_mean_absolute_error: 707.6018
#
# Epoch 00012: val_loss did not improve from 658.68536
# Epoch 13/500
# 84/84 [==============================] - 0s 154us/step - loss: 1513.2773 - mean_absolute_error: 1513.2773 - val_loss: 760.6477 - val_mean_absolute_error: 760.6477
#
# Epoch 00013: val_loss did not improve from 658.68536
# Epoch 14/500
# 84/84 [==============================] - 0s 154us/step - loss: 1489.1322 - mean_absolute_error: 1489.1322 - val_loss: 615.4247 - val_mean_absolute_error: 615.4247
#
# Epoch 00014: val_loss improved from 658.68536 to 615.42474, saving model to GS-탄산음료week-Weights-014--615.42474.hdf5
# Epoch 15/500
# 84/84 [==============================] - 0s 107us/step - loss: 1309.1007 - mean_absolute_error: 1309.1007 - val_loss: 768.5242 - val_mean_absolute_error: 768.5242
#
# Epoch 00015: val_loss did not improve from 615.42474
# Epoch 16/500
# 84/84 [==============================] - 0s 119us/step - loss: 1260.4836 - mean_absolute_error: 1260.4836 - val_loss: 1187.0956 - val_mean_absolute_error: 1187.0956
#
# Epoch 00016: val_loss did not improve from 615.42474
# Epoch 17/500
# 84/84 [==============================] - 0s 107us/step - loss: 1333.8991 - mean_absolute_error: 1333.8991 - val_loss: 936.7645 - val_mean_absolute_error: 936.7645
#
# Epoch 00017: val_loss did not improve from 615.42474
# Epoch 18/500
# 84/84 [==============================] - 0s 107us/step - loss: 1205.3757 - mean_absolute_error: 1205.3757 - val_loss: 696.6760 - val_mean_absolute_error: 696.6760
#
# Epoch 00018: val_loss did not improve from 615.42474
# Epoch 19/500
# 84/84 [==============================] - 0s 95us/step - loss: 1233.8931 - mean_absolute_error: 1233.8931 - val_loss: 630.0889 - val_mean_absolute_error: 630.0889
#
# Epoch 00019: val_loss did not improve from 615.42474
# Epoch 20/500
# 84/84 [==============================] - 0s 107us/step - loss: 1258.1589 - mean_absolute_error: 1258.1589 - val_loss: 651.2230 - val_mean_absolute_error: 651.2230
#
# Epoch 00020: val_loss did not improve from 615.42474
# Epoch 21/500
# 84/84 [==============================] - 0s 107us/step - loss: 1238.9944 - mean_absolute_error: 1238.9944 - val_loss: 791.7848 - val_mean_absolute_error: 791.7848
#
# Epoch 00021: val_loss did not improve from 615.42474
# Epoch 22/500
# 84/84 [==============================] - 0s 101us/step - loss: 1216.3935 - mean_absolute_error: 1216.3935 - val_loss: 892.6429 - val_mean_absolute_error: 892.6429
#
# Epoch 00022: val_loss did not improve from 615.42474
# Epoch 23/500
# 84/84 [==============================] - 0s 131us/step - loss: 1225.3452 - mean_absolute_error: 1225.3452 - val_loss: 824.0227 - val_mean_absolute_error: 824.0227
#
# Epoch 00023: val_loss did not improve from 615.42474
# Epoch 24/500
# 84/84 [==============================] - 0s 107us/step - loss: 1204.8861 - mean_absolute_error: 1204.8861 - val_loss: 764.6131 - val_mean_absolute_error: 764.6131
#
# Epoch 00024: val_loss did not improve from 615.42474
# Epoch 25/500
# 84/84 [==============================] - 0s 107us/step - loss: 1197.4637 - mean_absolute_error: 1197.4637 - val_loss: 705.2448 - val_mean_absolute_error: 705.2448
#
# Epoch 00025: val_loss did not improve from 615.42474
# Epoch 26/500
# 84/84 [==============================] - 0s 107us/step - loss: 1217.6656 - mean_absolute_error: 1217.6656 - val_loss: 682.6744 - val_mean_absolute_error: 682.6744
#
# Epoch 00026: val_loss did not improve from 615.42474
# Epoch 27/500
# 84/84 [==============================] - 0s 107us/step - loss: 1212.1299 - mean_absolute_error: 1212.1299 - val_loss: 728.8256 - val_mean_absolute_error: 728.8256
#
# Epoch 00027: val_loss did not improve from 615.42474
# Epoch 28/500
# 84/84 [==============================] - 0s 119us/step - loss: 1206.0445 - mean_absolute_error: 1206.0445 - val_loss: 850.8127 - val_mean_absolute_error: 850.8127
#
# Epoch 00028: val_loss did not improve from 615.42474
# Epoch 29/500
# 84/84 [==============================] - 0s 154us/step - loss: 1205.8897 - mean_absolute_error: 1205.8897 - val_loss: 849.7520 - val_mean_absolute_error: 849.7520
#
# Epoch 00029: val_loss did not improve from 615.42474
# Epoch 30/500
# 84/84 [==============================] - 0s 107us/step - loss: 1208.0051 - mean_absolute_error: 1208.0051 - val_loss: 721.4291 - val_mean_absolute_error: 721.4291
#
# Epoch 00030: val_loss did not improve from 615.42474
# Epoch 31/500
# 84/84 [==============================] - 0s 107us/step - loss: 1195.2978 - mean_absolute_error: 1195.2978 - val_loss: 757.8059 - val_mean_absolute_error: 757.8059
#
# Epoch 00031: val_loss did not improve from 615.42474
# Epoch 32/500
# 84/84 [==============================] - 0s 98us/step - loss: 1188.8591 - mean_absolute_error: 1188.8591 - val_loss: 801.3832 - val_mean_absolute_error: 801.3832
#
# Epoch 00032: val_loss did not improve from 615.42474
# Epoch 33/500
# 84/84 [==============================] - 0s 107us/step - loss: 1188.6798 - mean_absolute_error: 1188.6798 - val_loss: 760.2285 - val_mean_absolute_error: 760.2285
# Epoch 00033: val_loss did not improve from 615.42474
# Epoch 34/500
# 84/84 [==============================] - 0s 95us/step - loss: 1200.5190 - mean_absolute_error: 1200.5190 - val_loss: 701.9036 - val_mean_absolute_error: 701.9036
#
# Epoch 00034: val_loss did not improve from 615.42474
# Epoch 35/500
# 84/84 [==============================] - 0s 95us/step - loss: 1192.7500 - mean_absolute_error: 1192.7500 - val_loss: 771.4859 - val_mean_absolute_error: 771.4859
#
# Epoch 00035: val_loss did not improve from 615.42474
# Epoch 36/500
# 84/84 [==============================] - 0s 142us/step - loss: 1186.9640 - mean_absolute_error: 1186.9640 - val_loss: 748.8596 - val_mean_absolute_error: 748.8596
#
# Epoch 00036: val_loss did not improve from 615.42474
# Epoch 37/500
# 84/84 [==============================] - 0s 107us/step - loss: 1180.3697 - mean_absolute_error: 1180.3697 - val_loss: 771.9797 - val_mean_absolute_error: 771.9797
#
# Epoch 00037: val_loss did not improve from 615.42474
# Epoch 38/500
# 84/84 [==============================] - 0s 95us/step - loss: 1184.1284 - mean_absolute_error: 1184.1284 - val_loss: 777.2941 - val_mean_absolute_error: 777.2941
#
# Epoch 00038: val_loss did not improve from 615.42474
# Epoch 39/500
# 84/84 [==============================] - 0s 95us/step - loss: 1178.4880 - mean_absolute_error: 1178.4880 - val_loss: 755.5195 - val_mean_absolute_error: 755.5195
#
# Epoch 00039: val_loss did not improve from 615.42474
# Epoch 40/500
# 84/84 [==============================] - 0s 119us/step - loss: 1176.5064 - mean_absolute_error: 1176.5064 - val_loss: 713.6594 - val_mean_absolute_error: 713.6594
#
# Epoch 00040: val_loss did not improve from 615.42474
# Epoch 41/500
# 84/84 [==============================] - 0s 107us/step - loss: 1178.1761 - mean_absolute_error: 1178.1761 - val_loss: 736.0662 - val_mean_absolute_error: 736.0662
#
# Epoch 00041: val_loss did not improve from 615.42474
# Epoch 42/500
# 84/84 [==============================] - 0s 95us/step - loss: 1170.2548 - mean_absolute_error: 1170.2548 - val_loss: 816.9055 - val_mean_absolute_error: 816.9055
#
# Epoch 00042: val_loss did not improve from 615.42474
# Epoch 43/500
# 84/84 [==============================] - 0s 107us/step - loss: 1176.2598 - mean_absolute_error: 1176.2598 - val_loss: 843.2535 - val_mean_absolute_error: 843.2535
#
# Epoch 00043: val_loss did not improve from 615.42474
# Epoch 44/500
# 84/84 [==============================] - 0s 95us/step - loss: 1179.9495 - mean_absolute_error: 1179.9495 - val_loss: 784.2930 - val_mean_absolute_error: 784.2930
#
# Epoch 00044: val_loss did not improve from 615.42474
# Epoch 45/500
# 84/84 [==============================] - 0s 155us/step - loss: 1172.0938 - mean_absolute_error: 1172.0938 - val_loss: 739.0266 - val_mean_absolute_error: 739.0266
#
# Epoch 00045: val_loss did not improve from 615.42474
# Epoch 46/500
# 84/84 [==============================] - 0s 130us/step - loss: 1172.9265 - mean_absolute_error: 1172.9265 - val_loss: 709.7424 - val_mean_absolute_error: 709.7424
#
# Epoch 00046: val_loss did not improve from 615.42474
# Epoch 47/500
# 84/84 [==============================] - 0s 119us/step - loss: 1164.1865 - mean_absolute_error: 1164.1865 - val_loss: 814.0136 - val_mean_absolute_error: 814.0136
#
# Epoch 00047: val_loss did not improve from 615.42474
# Epoch 48/500
# 84/84 [==============================] - 0s 142us/step - loss: 1171.1760 - mean_absolute_error: 1171.1760 - val_loss: 832.4998 - val_mean_absolute_error: 832.4998
#
# Epoch 00048: val_loss did not improve from 615.42474
# Epoch 49/500
# 84/84 [==============================] - 0s 166us/step - loss: 1167.6228 - mean_absolute_error: 1167.6228 - val_loss: 779.7258 - val_mean_absolute_error: 779.7258
#
# Epoch 00049: val_loss did not improve from 615.42474
# Epoch 50/500
# 84/84 [==============================] - 0s 142us/step - loss: 1164.2785 - mean_absolute_error: 1164.2785 - val_loss: 728.5214 - val_mean_absolute_error: 728.5214
#
# Epoch 00050: val_loss did not improve from 615.42474
# Epoch 51/500
# 84/84 [==============================] - 0s 107us/step - loss: 1161.9908 - mean_absolute_error: 1161.9908 - val_loss: 683.5742 - val_mean_absolute_error: 683.5742
#
# Epoch 00051: val_loss did not improve from 615.42474
# Epoch 52/500
# 84/84 [==============================] - 0s 154us/step - loss: 1162.2101 - mean_absolute_error: 1162.2101 - val_loss: 675.2394 - val_mean_absolute_error: 675.2394
#
# Epoch 00052: val_loss did not improve from 615.42474
# Epoch 53/500
# 84/84 [==============================] - 0s 131us/step - loss: 1161.2624 - mean_absolute_error: 1161.2624 - val_loss: 707.2346 - val_mean_absolute_error: 707.2346
#
# Epoch 00053: val_loss did not improve from 615.42474
# Epoch 54/500
# 84/84 [==============================] - 0s 131us/step - loss: 1161.0805 - mean_absolute_error: 1161.0805 - val_loss: 737.9094 - val_mean_absolute_error: 737.9094
#
# Epoch 00054: val_loss did not improve from 615.42474
# Epoch 55/500
# 84/84 [==============================] - 0s 107us/step - loss: 1163.6989 - mean_absolute_error: 1163.6989 - val_loss: 876.3328 - val_mean_absolute_error: 876.3328
#
# Epoch 00055: val_loss did not improve from 615.42474
# Epoch 56/500
# 84/84 [==============================] - 0s 166us/step - loss: 1171.9246 - mean_absolute_error: 1171.9246 - val_loss: 795.2932 - val_mean_absolute_error: 795.2932
#
# Epoch 00056: val_loss did not improve from 615.42474
# Epoch 57/500
# 84/84 [==============================] - 0s 178us/step - loss: 1154.3921 - mean_absolute_error: 1154.3921 - val_loss: 779.2691 - val_mean_absolute_error: 779.2691
#
# Epoch 00057: val_loss did not improve from 615.42474
# Epoch 58/500
# 84/84 [==============================] - 0s 154us/step - loss: 1156.8861 - mean_absolute_error: 1156.8861 - val_loss: 733.3616 - val_mean_absolute_error: 733.3616
#
# Epoch 00058: val_loss did not improve from 615.42474
# Epoch 59/500
# 84/84 [==============================] - 0s 131us/step - loss: 1150.6217 - mean_absolute_error: 1150.6217 - val_loss: 727.1241 - val_mean_absolute_error: 727.1241
#
# Epoch 00059: val_loss did not improve from 615.42474
# Epoch 60/500
# 84/84 [==============================] - 0s 131us/step - loss: 1143.8728 - mean_absolute_error: 1143.8728 - val_loss: 783.3546 - val_mean_absolute_error: 783.3546
#
# Epoch 00060: val_loss did not improve from 615.42474
# Epoch 61/500
# 84/84 [==============================] - 0s 142us/step - loss: 1146.2076 - mean_absolute_error: 1146.2076 - val_loss: 834.3230 - val_mean_absolute_error: 834.3230
#
# Epoch 00061: val_loss did not improve from 615.42474
# Epoch 62/500
# 84/84 [==============================] - 0s 142us/step - loss: 1153.2028 - mean_absolute_error: 1153.2028 - val_loss: 773.5261 - val_mean_absolute_error: 773.5261
#
# Epoch 00062: val_loss did not improve from 615.42474
# Epoch 63/500
# 84/84 [==============================] - 0s 107us/step - loss: 1155.6908 - mean_absolute_error: 1155.6908 - val_loss: 621.1862 - val_mean_absolute_error: 621.1862
#
# Epoch 00063: val_loss did not improve from 615.42474
# Epoch 64/500
# 84/84 [==============================] - 0s 107us/step - loss: 1148.3355 - mean_absolute_error: 1148.3355 - val_loss: 669.4605 - val_mean_absolute_error: 669.4605
#
# Epoch 00064: val_loss did not improve from 615.42474
# Epoch 65/500
# 84/84 [==============================] - 0s 166us/step - loss: 1131.9524 - mean_absolute_error: 1131.9524 - val_loss: 782.4500 - val_mean_absolute_error: 782.4500
#
# Epoch 00065: val_loss did not improve from 615.42474
# Epoch 66/500
# 84/84 [==============================] - 0s 119us/step - loss: 1138.5413 - mean_absolute_error: 1138.5413 - val_loss: 854.9769 - val_mean_absolute_error: 854.9769
#
# Epoch 00066: val_loss did not improve from 615.42474
# Epoch 67/500
# 84/84 [==============================] - 0s 107us/step - loss: 1143.7414 - mean_absolute_error: 1143.7414 - val_loss: 758.1262 - val_mean_absolute_error: 758.1262
#
# Epoch 00067: val_loss did not improve from 615.42474
# Epoch 68/500
# 84/84 [==============================] - 0s 154us/step - loss: 1128.5348 - mean_absolute_error: 1128.5348 - val_loss: 651.9610 - val_mean_absolute_error: 651.9610
#
# Epoch 00068: val_loss did not improve from 615.42474
# Epoch 69/500
# 84/84 [==============================] - 0s 154us/step - loss: 1131.9709 - mean_absolute_error: 1131.9709 - val_loss: 626.4393 - val_mean_absolute_error: 626.4393
#
# Epoch 00069: val_loss did not improve from 615.42474
# Epoch 70/500
# 84/84 [==============================] - 0s 154us/step - loss: 1136.7392 - mean_absolute_error: 1136.7392 - val_loss: 661.6611 - val_mean_absolute_error: 661.6611
#
# Epoch 00070: val_loss did not improve from 615.42474
# Epoch 71/500
# 84/84 [==============================] - 0s 142us/step - loss: 1127.7129 - mean_absolute_error: 1127.7129 - val_loss: 658.6074 - val_mean_absolute_error: 658.6074
#
# Epoch 00071: val_loss did not improve from 615.42474
# Epoch 72/500
# 84/84 [==============================] - 0s 154us/step - loss: 1126.9570 - mean_absolute_error: 1126.9570 - val_loss: 676.6365 - val_mean_absolute_error: 676.6365
#
# Epoch 00072: val_loss did not improve from 615.42474
# Epoch 73/500
# 84/84 [==============================] - 0s 142us/step - loss: 1121.5639 - mean_absolute_error: 1121.5639 - val_loss: 698.5676 - val_mean_absolute_error: 698.5676
#
# Epoch 00073: val_loss did not improve from 615.42474
# Epoch 74/500
# 84/84 [==============================] - 0s 107us/step - loss: 1140.0873 - mean_absolute_error: 1140.0873 - val_loss: 747.0903 - val_mean_absolute_error: 747.0903
#
# Epoch 00074: val_loss did not improve from 615.42474
# Epoch 75/500
# 84/84 [==============================] - 0s 119us/step - loss: 1116.3073 - mean_absolute_error: 1116.3073 - val_loss: 627.7120 - val_mean_absolute_error: 627.7120
#
# Epoch 00075: val_loss did not improve from 615.42474
# Epoch 76/500
# 84/84 [==============================] - 0s 166us/step - loss: 1122.2116 - mean_absolute_error: 1122.2116 - val_loss: 643.5677 - val_mean_absolute_error: 643.5677
#
# Epoch 00076: val_loss did not improve from 615.42474
# Epoch 77/500
# 84/84 [==============================] - 0s 154us/step - loss: 1120.7287 - mean_absolute_error: 1120.7287 - val_loss: 732.8291 - val_mean_absolute_error: 732.8291
#
# Epoch 00077: val_loss did not improve from 615.42474
# Epoch 78/500
# 84/84 [==============================] - 0s 119us/step - loss: 1112.9178 - mean_absolute_error: 1112.9178 - val_loss: 721.9510 - val_mean_absolute_error: 721.9510
#
# Epoch 00078: val_loss did not improve from 615.42474
# Epoch 79/500
# 84/84 [==============================] - 0s 119us/step - loss: 1111.5212 - mean_absolute_error: 1111.5212 - val_loss: 694.4141 - val_mean_absolute_error: 694.4141
#
# Epoch 00079: val_loss did not improve from 615.42474
# Epoch 80/500
# 84/84 [==============================] - 0s 142us/step - loss: 1110.7807 - mean_absolute_error: 1110.7807 - val_loss: 660.1870 - val_mean_absolute_error: 660.1870
#
# Epoch 00080: val_loss did not improve from 615.42474
# Epoch 81/500
# 84/84 [==============================] - 0s 120us/step - loss: 1109.6671 - mean_absolute_error: 1109.6671 - val_loss: 655.2789 - val_mean_absolute_error: 655.2789
#
# Epoch 00081: val_loss did not improve from 615.42474
# Epoch 82/500
# 84/84 [==============================] - 0s 119us/step - loss: 1105.6508 - mean_absolute_error: 1105.6508 - val_loss: 622.7769 - val_mean_absolute_error: 622.7769
#
# Epoch 00082: val_loss did not improve from 615.42474
# Epoch 83/500
# 84/84 [==============================] - 0s 119us/step - loss: 1110.1533 - mean_absolute_error: 1110.1533 - val_loss: 614.2629 - val_mean_absolute_error: 614.2629
#
# Epoch 00083: val_loss improved from 615.42474 to 614.26288, saving model to GS-탄산음료week-Weights-083--614.26288.hdf5
# Epoch 84/500
# 84/84 [==============================] - 0s 131us/step - loss: 1103.9011 - mean_absolute_error: 1103.9011 - val_loss: 677.6904 - val_mean_absolute_error: 677.6904
#
# Epoch 00084: val_loss did not improve from 614.26288
# Epoch 85/500
# 84/84 [==============================] - 0s 107us/step - loss: 1095.7162 - mean_absolute_error: 1095.7162 - val_loss: 773.9557 - val_mean_absolute_error: 773.9557
#
# Epoch 00085: val_loss did not improve from 614.26288
# Epoch 86/500
# 84/84 [==============================] - 0s 142us/step - loss: 1128.5724 - mean_absolute_error: 1128.5724 - val_loss: 783.6577 - val_mean_absolute_error: 783.6577
#
# Epoch 00086: val_loss did not improve from 614.26288
# Epoch 87/500
# 84/84 [==============================] - 0s 166us/step - loss: 1120.2821 - mean_absolute_error: 1120.2821 - val_loss: 569.4255 - val_mean_absolute_error: 569.4255
#
# Epoch 00087: val_loss improved from 614.26288 to 569.42554, saving model to GS-탄산음료week-Weights-087--569.42554.hdf5
# Epoch 88/500
# 84/84 [==============================] - 0s 107us/step - loss: 1106.6990 - mean_absolute_error: 1106.6990 - val_loss: 615.1508 - val_mean_absolute_error: 615.1508
#
# Epoch 00088: val_loss did not improve from 569.42554
# Epoch 89/500
# 84/84 [==============================] - 0s 131us/step - loss: 1096.1374 - mean_absolute_error: 1096.1374 - val_loss: 688.3467 - val_mean_absolute_error: 688.3467
#
# Epoch 00089: val_loss did not improve from 569.42554
# Epoch 90/500
# 84/84 [==============================] - 0s 107us/step - loss: 1089.9837 - mean_absolute_error: 1089.9837 - val_loss: 687.9124 - val_mean_absolute_error: 687.9124
#
# Epoch 00090: val_loss did not improve from 569.42554
# Epoch 91/500
# 84/84 [==============================] - 0s 131us/step - loss: 1095.1501 - mean_absolute_error: 1095.1501 - val_loss: 648.1500 - val_mean_absolute_error: 648.1500
#
# Epoch 00091: val_loss did not improve from 569.42554
# Epoch 92/500
# 84/84 [==============================] - 0s 166us/step - loss: 1082.9715 - mean_absolute_error: 1082.9715 - val_loss: 725.6002 - val_mean_absolute_error: 725.6002
#
# Epoch 00092: val_loss did not improve from 569.42554
# Epoch 93/500
# 84/84 [==============================] - 0s 142us/step - loss: 1104.0147 - mean_absolute_error: 1104.0147 - val_loss: 756.4303 - val_mean_absolute_error: 756.4303
#
# Epoch 00093: val_loss did not improve from 569.42554
# Epoch 94/500
# 84/84 [==============================] - 0s 190us/step - loss: 1085.2050 - mean_absolute_error: 1085.2050 - val_loss: 614.1563 - val_mean_absolute_error: 614.1563
#
# Epoch 00094: val_loss did not improve from 569.42554
# Epoch 95/500
# 84/84 [==============================] - 0s 190us/step - loss: 1090.0933 - mean_absolute_error: 1090.0933 - val_loss: 507.2087 - val_mean_absolute_error: 507.2087
#
# Epoch 00095: val_loss improved from 569.42554 to 507.20868, saving model to GS-탄산음료week-Weights-095--507.20868.hdf5
# Epoch 96/500
# 84/84 [==============================] - 0s 107us/step - loss: 1124.4417 - mean_absolute_error: 1124.4417 - val_loss: 529.8417 - val_mean_absolute_error: 529.8417
#
# Epoch 00096: val_loss did not improve from 507.20868
# Epoch 97/500
# 84/84 [==============================] - 0s 95us/step - loss: 1060.7835 - mean_absolute_error: 1060.7835 - val_loss: 838.2866 - val_mean_absolute_error: 838.2866
#
# Epoch 00097: val_loss did not improve from 507.20868
# Epoch 98/500
# 84/84 [==============================] - 0s 119us/step - loss: 1150.3438 - mean_absolute_error: 1150.3438 - val_loss: 874.9436 - val_mean_absolute_error: 874.9436
#
# Epoch 00098: val_loss did not improve from 507.20868
# Epoch 99/500
# 84/84 [==============================] - 0s 142us/step - loss: 1076.9321 - mean_absolute_error: 1076.9321 - val_loss: 512.8748 - val_mean_absolute_error: 512.8748
#
# Epoch 00099: val_loss did not improve from 507.20868
# Epoch 100/500
# 84/84 [==============================] - 0s 119us/step - loss: 1130.1714 - mean_absolute_error: 1130.1714 - val_loss: 525.5908 - val_mean_absolute_error: 525.5908
#
# Epoch 00100: val_loss did not improve from 507.20868
# Epoch 101/500
# 84/84 [==============================] - 0s 107us/step - loss: 1160.9130 - mean_absolute_error: 1160.9130 - val_loss: 536.5731 - val_mean_absolute_error: 536.5731
#
# Epoch 00101: val_loss did not improve from 507.20868
# Epoch 102/500
# 84/84 [==============================] - 0s 107us/step - loss: 1056.5949 - mean_absolute_error: 1056.5949 - val_loss: 814.0526 - val_mean_absolute_error: 814.0526
#
# Epoch 00102: val_loss did not improve from 507.20868
# Epoch 103/500
# 84/84 [==============================] - 0s 107us/step - loss: 1109.1521 - mean_absolute_error: 1109.1521 - val_loss: 882.0115 - val_mean_absolute_error: 882.0115
#
# Epoch 00103: val_loss did not improve from 507.20868
# Epoch 104/500
# 84/84 [==============================] - 0s 142us/step - loss: 1090.6375 - mean_absolute_error: 1090.6375 - val_loss: 613.4586 - val_mean_absolute_error: 613.4586
#
# Epoch 00104: val_loss did not improve from 507.20868
# Epoch 105/500
# 84/84 [==============================] - 0s 142us/step - loss: 1079.1223 - mean_absolute_error: 1079.1223 - val_loss: 494.4807 - val_mean_absolute_error: 494.4807
#
# Epoch 00105: val_loss improved from 507.20868 to 494.48065, saving model to GS-탄산음료week-Weights-105--494.48065.hdf5
# Epoch 106/500
# 84/84 [==============================] - 0s 119us/step - loss: 1093.6984 - mean_absolute_error: 1093.6984 - val_loss: 528.5571 - val_mean_absolute_error: 528.5571
#
# Epoch 00106: val_loss did not improve from 494.48065
# Epoch 107/500
# 84/84 [==============================] - 0s 130us/step - loss: 1058.3533 - mean_absolute_error: 1058.3533 - val_loss: 635.4600 - val_mean_absolute_error: 635.4600
#
# Epoch 00107: val_loss did not improve from 494.48065
# Epoch 108/500
# 84/84 [==============================] - 0s 119us/step - loss: 1052.6178 - mean_absolute_error: 1052.6178 - val_loss: 754.9471 - val_mean_absolute_error: 754.9471
#
# Epoch 00108: val_loss did not improve from 494.48065
# Epoch 109/500
# 84/84 [==============================] - 0s 119us/step - loss: 1076.3783 - mean_absolute_error: 1076.3783 - val_loss: 677.0558 - val_mean_absolute_error: 677.0558
#
# Epoch 00109: val_loss did not improve from 494.48065
# Epoch 110/500
# 84/84 [==============================] - 0s 119us/step - loss: 1056.2168 - mean_absolute_error: 1056.2168 - val_loss: 573.7293 - val_mean_absolute_error: 573.7293
#
# Epoch 00110: val_loss did not improve from 494.48065
# Epoch 111/500
# 84/84 [==============================] - 0s 119us/step - loss: 1054.0918 - mean_absolute_error: 1054.0918 - val_loss: 532.5938 - val_mean_absolute_error: 532.5938
#
# Epoch 00111: val_loss did not improve from 494.48065
# Epoch 112/500
# 84/84 [==============================] - 0s 107us/step - loss: 1052.9092 - mean_absolute_error: 1052.9092 - val_loss: 602.2335 - val_mean_absolute_error: 602.2335
#
# Epoch 00112: val_loss did not improve from 494.48065
# Epoch 113/500
# 84/84 [==============================] - 0s 131us/step - loss: 1043.2941 - mean_absolute_error: 1043.2941 - val_loss: 646.7699 - val_mean_absolute_error: 646.7699
#
# Epoch 00113: val_loss did not improve from 494.48065
# Epoch 114/500
# 84/84 [==============================] - 0s 131us/step - loss: 1050.0035 - mean_absolute_error: 1050.0035 - val_loss: 587.9507 - val_mean_absolute_error: 587.9507
#
# Epoch 00114: val_loss did not improve from 494.48065
# Epoch 115/500
# 84/84 [==============================] - 0s 131us/step - loss: 1056.6981 - mean_absolute_error: 1056.6981 - val_loss: 555.7515 - val_mean_absolute_error: 555.7515
#
# Epoch 00115: val_loss did not improve from 494.48065
# Epoch 116/500
# 84/84 [==============================] - 0s 115us/step - loss: 1050.6347 - mean_absolute_error: 1050.6347 - val_loss: 481.4455 - val_mean_absolute_error: 481.4455
#
# Epoch 00116: val_loss improved from 494.48065 to 481.44553, saving model to GS-탄산음료week-Weights-116--481.44553.hdf5
# Epoch 117/500
# 84/84 [==============================] - 0s 131us/step - loss: 1050.6753 - mean_absolute_error: 1050.6753 - val_loss: 520.6629 - val_mean_absolute_error: 520.6629
#
# Epoch 00117: val_loss did not improve from 481.44553
# Epoch 118/500
# 84/84 [==============================] - 0s 131us/step - loss: 1038.8915 - mean_absolute_error: 1038.8915 - val_loss: 585.8137 - val_mean_absolute_error: 585.8137
#
# Epoch 00118: val_loss did not improve from 481.44553
# Epoch 119/500
# 84/84 [==============================] - 0s 107us/step - loss: 1032.1511 - mean_absolute_error: 1032.1511 - val_loss: 539.3793 - val_mean_absolute_error: 539.3793
#
# Epoch 00119: val_loss did not improve from 481.44553
# Epoch 120/500
# 84/84 [==============================] - 0s 154us/step - loss: 1031.7864 - mean_absolute_error: 1031.7864 - val_loss: 530.7177 - val_mean_absolute_error: 530.7177
#
# Epoch 00120: val_loss did not improve from 481.44553
# Epoch 121/500
# 84/84 [==============================] - 0s 131us/step - loss: 1024.5865 - mean_absolute_error: 1024.5865 - val_loss: 571.2357 - val_mean_absolute_error: 571.2357
#
# Epoch 00121: val_loss did not improve from 481.44553
# Epoch 122/500
# 84/84 [==============================] - 0s 107us/step - loss: 1022.8528 - mean_absolute_error: 1022.8528 - val_loss: 544.8755 - val_mean_absolute_error: 544.8755
#
# Epoch 00122: val_loss did not improve from 481.44553
# Epoch 123/500
# 84/84 [==============================] - 0s 107us/step - loss: 1017.3014 - mean_absolute_error: 1017.3014 - val_loss: 550.3843 - val_mean_absolute_error: 550.3843
#
# Epoch 00123: val_loss did not improve from 481.44553
# Epoch 124/500
# 84/84 [==============================] - 0s 107us/step - loss: 1016.9812 - mean_absolute_error: 1016.9812 - val_loss: 548.6225 - val_mean_absolute_error: 548.6225
#
# Epoch 00124: val_loss did not improve from 481.44553
# Epoch 125/500
# 84/84 [==============================] - 0s 142us/step - loss: 1017.3130 - mean_absolute_error: 1017.3130 - val_loss: 526.3653 - val_mean_absolute_error: 526.3653
#
# Epoch 00125: val_loss did not improve from 481.44553
# Epoch 126/500
# 84/84 [==============================] - 0s 142us/step - loss: 1022.2402 - mean_absolute_error: 1022.2402 - val_loss: 597.0769 - val_mean_absolute_error: 597.0769
#
# Epoch 00126: val_loss did not improve from 481.44553
# Epoch 127/500
# 84/84 [==============================] - 0s 107us/step - loss: 1010.3330 - mean_absolute_error: 1010.3330 - val_loss: 472.7749 - val_mean_absolute_error: 472.7749
#
# Epoch 00127: val_loss improved from 481.44553 to 472.77493, saving model to GS-탄산음료week-Weights-127--472.77493.hdf5
# Epoch 128/500
# 84/84 [==============================] - 0s 137us/step - loss: 1043.1170 - mean_absolute_error: 1043.1170 - val_loss: 473.9296 - val_mean_absolute_error: 473.9296
#
# Epoch 00128: val_loss did not improve from 472.77493
# Epoch 129/500
# 84/84 [==============================] - 0s 166us/step - loss: 1020.0124 - mean_absolute_error: 1020.0124 - val_loss: 572.3567 - val_mean_absolute_error: 572.3567
#
# Epoch 00129: val_loss did not improve from 472.77493
# Epoch 130/500
# 84/84 [==============================] - 0s 107us/step - loss: 1007.0041 - mean_absolute_error: 1007.0041 - val_loss: 618.7628 - val_mean_absolute_error: 618.7628
#
# Epoch 00130: val_loss did not improve from 472.77493
# Epoch 131/500
# 84/84 [==============================] - 0s 119us/step - loss: 1011.4969 - mean_absolute_error: 1011.4969 - val_loss: 491.4439 - val_mean_absolute_error: 491.4439
#
# Epoch 00131: val_loss did not improve from 472.77493
# Epoch 132/500
# 84/84 [==============================] - 0s 131us/step - loss: 1007.9009 - mean_absolute_error: 1007.9009 - val_loss: 480.3506 - val_mean_absolute_error: 480.3506
#
# Epoch 00132: val_loss did not improve from 472.77493
# Epoch 133/500
# 84/84 [==============================] - 0s 154us/step - loss: 1024.6117 - mean_absolute_error: 1024.6117 - val_loss: 595.8552 - val_mean_absolute_error: 595.8552
#
# Epoch 00133: val_loss did not improve from 472.77493
# Epoch 134/500
# 84/84 [==============================] - 0s 107us/step - loss: 997.1013 - mean_absolute_error: 997.1013 - val_loss: 477.7788 - val_mean_absolute_error: 477.7788
#
# Epoch 00134: val_loss did not improve from 472.77493
# Epoch 135/500
# 84/84 [==============================] - 0s 107us/step - loss: 994.2128 - mean_absolute_error: 994.2128 - val_loss: 514.3776 - val_mean_absolute_error: 514.3776
#
# Epoch 00135: val_loss did not improve from 472.77493
# Epoch 136/500
# 84/84 [==============================] - 0s 107us/step - loss: 1004.2749 - mean_absolute_error: 1004.2749 - val_loss: 492.4162 - val_mean_absolute_error: 492.4162
#
# Epoch 00136: val_loss did not improve from 472.77493
# Epoch 137/500
# 84/84 [==============================] - 0s 125us/step - loss: 988.3477 - mean_absolute_error: 988.3477 - val_loss: 563.9921 - val_mean_absolute_error: 563.9921
#
# Epoch 00137: val_loss did not improve from 472.77493
# Epoch 138/500
# 84/84 [==============================] - 0s 154us/step - loss: 986.1811 - mean_absolute_error: 986.1811 - val_loss: 489.9546 - val_mean_absolute_error: 489.9546
# Epoch 00138: val_loss did not improve from 472.77493
# Epoch 139/500
# 84/84 [==============================] - 0s 142us/step - loss: 984.8783 - mean_absolute_error: 984.8783 - val_loss: 493.1824 - val_mean_absolute_error: 493.1824
#
# Epoch 00139: val_loss did not improve from 472.77493
# Epoch 140/500
# 84/84 [==============================] - 0s 95us/step - loss: 977.0374 - mean_absolute_error: 977.0374 - val_loss: 491.8506 - val_mean_absolute_error: 491.8506
#
# Epoch 00140: val_loss did not improve from 472.77493
# Epoch 141/500
# 84/84 [==============================] - 0s 107us/step - loss: 976.3665 - mean_absolute_error: 976.3665 - val_loss: 514.1752 - val_mean_absolute_error: 514.1752
#
# Epoch 00141: val_loss did not improve from 472.77493
# Epoch 142/500
# 84/84 [==============================] - 0s 107us/step - loss: 974.8470 - mean_absolute_error: 974.8470 - val_loss: 523.8210 - val_mean_absolute_error: 523.8210
#
# Epoch 00142: val_loss did not improve from 472.77493
# Epoch 143/500
# 84/84 [==============================] - 0s 107us/step - loss: 990.0239 - mean_absolute_error: 990.0239 - val_loss: 516.9570 - val_mean_absolute_error: 516.9570
#
# Epoch 00143: val_loss did not improve from 472.77493
# Epoch 144/500
# 84/84 [==============================] - 0s 119us/step - loss: 966.7259 - mean_absolute_error: 966.7259 - val_loss: 508.6442 - val_mean_absolute_error: 508.6442
#
# Epoch 00144: val_loss did not improve from 472.77493
# Epoch 145/500
# 84/84 [==============================] - 0s 107us/step - loss: 966.1452 - mean_absolute_error: 966.1452 - val_loss: 515.8747 - val_mean_absolute_error: 515.8747
#
# Epoch 00145: val_loss did not improve from 472.77493
# Epoch 146/500
# 84/84 [==============================] - 0s 107us/step - loss: 997.3799 - mean_absolute_error: 997.3799 - val_loss: 542.7695 - val_mean_absolute_error: 542.7695
#
# Epoch 00146: val_loss did not improve from 472.77493
# Epoch 147/500
# 84/84 [==============================] - 0s 154us/step - loss: 963.8955 - mean_absolute_error: 963.8955 - val_loss: 596.7382 - val_mean_absolute_error: 596.7382
#
# Epoch 00147: val_loss did not improve from 472.77493
# Epoch 148/500
# 84/84 [==============================] - 0s 119us/step - loss: 992.4169 - mean_absolute_error: 992.4169 - val_loss: 563.8108 - val_mean_absolute_error: 563.8108
#
# Epoch 00148: val_loss did not improve from 472.77493
# Epoch 149/500
# 84/84 [==============================] - 0s 131us/step - loss: 942.9384 - mean_absolute_error: 942.9384 - val_loss: 592.2350 - val_mean_absolute_error: 592.2350
#
# Epoch 00149: val_loss did not improve from 472.77493
# Epoch 150/500
# 84/84 [==============================] - 0s 107us/step - loss: 986.9253 - mean_absolute_error: 986.9253 - val_loss: 541.6650 - val_mean_absolute_error: 541.6650
#
# Epoch 00150: val_loss did not improve from 472.77493
# Epoch 151/500
# 84/84 [==============================] - 0s 107us/step - loss: 948.3475 - mean_absolute_error: 948.3475 - val_loss: 590.7999 - val_mean_absolute_error: 590.7999
#
# Epoch 00151: val_loss did not improve from 472.77493
# Epoch 152/500
# 84/84 [==============================] - 0s 167us/step - loss: 955.2881 - mean_absolute_error: 955.2881 - val_loss: 555.0476 - val_mean_absolute_error: 555.0476
#
# Epoch 00152: val_loss did not improve from 472.77493
# Epoch 153/500
# 84/84 [==============================] - 0s 119us/step - loss: 942.9311 - mean_absolute_error: 942.9311 - val_loss: 565.2901 - val_mean_absolute_error: 565.2901
#
# Epoch 00153: val_loss did not improve from 472.77493
# Epoch 154/500
# 84/84 [==============================] - 0s 119us/step - loss: 972.7338 - mean_absolute_error: 972.7338 - val_loss: 572.9886 - val_mean_absolute_error: 572.9886
#
# Epoch 00154: val_loss did not improve from 472.77493
# Epoch 155/500
# 84/84 [==============================] - 0s 131us/step - loss: 938.0511 - mean_absolute_error: 938.0511 - val_loss: 624.1981 - val_mean_absolute_error: 624.1981
#
# Epoch 00155: val_loss did not improve from 472.77493
# Epoch 156/500
# 84/84 [==============================] - 0s 131us/step - loss: 951.5020 - mean_absolute_error: 951.5020 - val_loss: 604.5325 - val_mean_absolute_error: 604.5325
#
# Epoch 00156: val_loss did not improve from 472.77493
# Epoch 157/500
# 84/84 [==============================] - 0s 131us/step - loss: 938.7151 - mean_absolute_error: 938.7151 - val_loss: 568.5757 - val_mean_absolute_error: 568.5757
#
# Epoch 00157: val_loss did not improve from 472.77493
# Epoch 158/500
# 84/84 [==============================] - 0s 131us/step - loss: 940.4625 - mean_absolute_error: 940.4625 - val_loss: 572.1248 - val_mean_absolute_error: 572.1248
#
# Epoch 00158: val_loss did not improve from 472.77493
# Epoch 159/500
# 84/84 [==============================] - 0s 119us/step - loss: 944.3314 - mean_absolute_error: 944.3314 - val_loss: 593.5285 - val_mean_absolute_error: 593.5285
#
# Epoch 00159: val_loss did not improve from 472.77493
# Epoch 160/500
# 84/84 [==============================] - 0s 119us/step - loss: 931.8530 - mean_absolute_error: 931.8530 - val_loss: 615.6111 - val_mean_absolute_error: 615.6111
#
# Epoch 00160: val_loss did not improve from 472.77493
# Epoch 161/500
# 84/84 [==============================] - 0s 119us/step - loss: 953.8009 - mean_absolute_error: 953.8009 - val_loss: 576.9337 - val_mean_absolute_error: 576.9337
#
# Epoch 00161: val_loss did not improve from 472.77493
# Epoch 162/500
# 84/84 [==============================] - 0s 166us/step - loss: 940.3871 - mean_absolute_error: 940.3871 - val_loss: 666.7267 - val_mean_absolute_error: 666.7267
#
# Epoch 00162: val_loss did not improve from 472.77493
# Epoch 163/500
# 84/84 [==============================] - 0s 131us/step - loss: 943.1754 - mean_absolute_error: 943.1754 - val_loss: 596.6326 - val_mean_absolute_error: 596.6326
#
# Epoch 00163: val_loss did not improve from 472.77493
# Epoch 164/500
# 84/84 [==============================] - 0s 107us/step - loss: 956.5192 - mean_absolute_error: 956.5192 - val_loss: 575.7753 - val_mean_absolute_error: 575.7753
#
# Epoch 00164: val_loss did not improve from 472.77493
# Epoch 165/500
# 84/84 [==============================] - 0s 131us/step - loss: 923.1392 - mean_absolute_error: 923.1392 - val_loss: 678.6744 - val_mean_absolute_error: 678.6744
#
# Epoch 00165: val_loss did not improve from 472.77493
# Epoch 166/500
# 84/84 [==============================] - 0s 154us/step - loss: 960.4260 - mean_absolute_error: 960.4260 - val_loss: 638.2570 - val_mean_absolute_error: 638.2570
#
# Epoch 00166: val_loss did not improve from 472.77493
# Epoch 167/500
# 84/84 [==============================] - 0s 119us/step - loss: 948.0074 - mean_absolute_error: 948.0074 - val_loss: 587.0831 - val_mean_absolute_error: 587.0831
#
# Epoch 00167: val_loss did not improve from 472.77493
# Epoch 168/500
# 84/84 [==============================] - 0s 131us/step - loss: 952.5653 - mean_absolute_error: 952.5653 - val_loss: 669.8284 - val_mean_absolute_error: 669.8284
#
# Epoch 00168: val_loss did not improve from 472.77493
# Epoch 169/500
# 84/84 [==============================] - 0s 119us/step - loss: 928.4090 - mean_absolute_error: 928.4090 - val_loss: 615.6264 - val_mean_absolute_error: 615.6264
#
# Epoch 00169: val_loss did not improve from 472.77493
# Epoch 170/500
# 84/84 [==============================] - 0s 178us/step - loss: 921.3223 - mean_absolute_error: 921.3223 - val_loss: 599.1484 - val_mean_absolute_error: 599.1484
#
# Epoch 00170: val_loss did not improve from 472.77493
# Epoch 171/500
# 84/84 [==============================] - 0s 154us/step - loss: 921.5605 - mean_absolute_error: 921.5605 - val_loss: 621.7830 - val_mean_absolute_error: 621.7830
#
# Epoch 00171: val_loss did not improve from 472.77493
# Epoch 172/500
# 84/84 [==============================] - 0s 154us/step - loss: 920.0219 - mean_absolute_error: 920.0219 - val_loss: 662.9474 - val_mean_absolute_error: 662.9474
#
# Epoch 00172: val_loss did not improve from 472.77493
# Epoch 173/500
# 84/84 [==============================] - 0s 154us/step - loss: 921.4809 - mean_absolute_error: 921.4809 - val_loss: 636.5615 - val_mean_absolute_error: 636.5615
#
# Epoch 00173: val_loss did not improve from 472.77493
# Epoch 174/500
# 84/84 [==============================] - 0s 107us/step - loss: 950.4082 - mean_absolute_error: 950.4082 - val_loss: 616.7307 - val_mean_absolute_error: 616.7307
# Epoch 00174: val_loss did not improve from 472.77493
# Epoch 175/500
# 84/84 [==============================] - 0s 154us/step - loss: 927.7365 - mean_absolute_error: 927.7365 - val_loss: 748.3762 - val_mean_absolute_error: 748.3762
#
# Epoch 00175: val_loss did not improve from 472.77493
# Epoch 176/500
# 84/84 [==============================] - 0s 119us/step - loss: 965.6280 - mean_absolute_error: 965.6280 - val_loss: 653.1983 - val_mean_absolute_error: 653.1983
#
# Epoch 00176: val_loss did not improve from 472.77493
# Epoch 177/500
# 84/84 [==============================] - 0s 107us/step - loss: 917.3713 - mean_absolute_error: 917.3713 - val_loss: 600.4617 - val_mean_absolute_error: 600.4617
#
# Epoch 00177: val_loss did not improve from 472.77493
# Epoch 178/500
# 84/84 [==============================] - 0s 131us/step - loss: 915.9946 - mean_absolute_error: 915.9946 - val_loss: 664.4445 - val_mean_absolute_error: 664.4445
#
# Epoch 00178: val_loss did not improve from 472.77493
# Epoch 179/500
# 84/84 [==============================] - 0s 119us/step - loss: 921.2047 - mean_absolute_error: 921.2047 - val_loss: 687.4492 - val_mean_absolute_error: 687.4492
#
# Epoch 00179: val_loss did not improve from 472.77493
# Epoch 180/500
# 84/84 [==============================] - 0s 131us/step - loss: 914.4045 - mean_absolute_error: 914.4045 - val_loss: 640.0125 - val_mean_absolute_error: 640.0125
#
# Epoch 00180: val_loss did not improve from 472.77493
# Epoch 181/500
# 84/84 [==============================] - 0s 131us/step - loss: 904.8384 - mean_absolute_error: 904.8384 - val_loss: 649.5312 - val_mean_absolute_error: 649.5312
#
# Epoch 00181: val_loss did not improve from 472.77493
# Epoch 182/500
# 84/84 [==============================] - 0s 119us/step - loss: 906.4824 - mean_absolute_error: 906.4824 - val_loss: 661.1329 - val_mean_absolute_error: 661.1329
#
# Epoch 00182: val_loss did not improve from 472.77493
# Epoch 183/500
# 84/84 [==============================] - 0s 107us/step - loss: 909.8941 - mean_absolute_error: 909.8941 - val_loss: 692.1497 - val_mean_absolute_error: 692.1497
#
# Epoch 00183: val_loss did not improve from 472.77493
# Epoch 184/500
# 84/84 [==============================] - 0s 142us/step - loss: 900.2896 - mean_absolute_error: 900.2896 - val_loss: 663.2952 - val_mean_absolute_error: 663.2952
#
# Epoch 00184: val_loss did not improve from 472.77493
# Epoch 185/500
# 84/84 [==============================] - 0s 119us/step - loss: 901.8585 - mean_absolute_error: 901.8585 - val_loss: 642.7039 - val_mean_absolute_error: 642.7039
#
# Epoch 00185: val_loss did not improve from 472.77493
# Epoch 186/500
# 84/84 [==============================] - 0s 119us/step - loss: 906.7215 - mean_absolute_error: 906.7215 - val_loss: 720.0090 - val_mean_absolute_error: 720.0090
#
# Epoch 00186: val_loss did not improve from 472.77493
# Epoch 187/500
# 84/84 [==============================] - 0s 131us/step - loss: 934.4596 - mean_absolute_error: 934.4596 - val_loss: 702.3601 - val_mean_absolute_error: 702.3601
#
# Epoch 00187: val_loss did not improve from 472.77493
# Epoch 188/500
# 84/84 [==============================] - 0s 107us/step - loss: 896.9653 - mean_absolute_error: 896.9653 - val_loss: 626.9559 - val_mean_absolute_error: 626.9559
#
# Epoch 00188: val_loss did not improve from 472.77493
# Epoch 189/500
# 84/84 [==============================] - 0s 142us/step - loss: 921.5236 - mean_absolute_error: 921.5236 - val_loss: 695.3116 - val_mean_absolute_error: 695.3116
#
# Epoch 00189: val_loss did not improve from 472.77493
# Epoch 190/500
# 84/84 [==============================] - 0s 142us/step - loss: 900.5511 - mean_absolute_error: 900.5511 - val_loss: 681.6462 - val_mean_absolute_error: 681.6462
#
# Epoch 00190: val_loss did not improve from 472.77493
# Epoch 191/500
# 84/84 [==============================] - 0s 131us/step - loss: 921.6042 - mean_absolute_error: 921.6042 - val_loss: 653.4652 - val_mean_absolute_error: 653.4652
#
# Epoch 00191: val_loss did not improve from 472.77493
# Epoch 192/500
# 84/84 [==============================] - 0s 119us/step - loss: 900.0638 - mean_absolute_error: 900.0638 - val_loss: 736.9576 - val_mean_absolute_error: 736.9576
#
# Epoch 00192: val_loss did not improve from 472.77493
# Epoch 193/500
# 84/84 [==============================] - 0s 119us/step - loss: 927.0959 - mean_absolute_error: 927.0959 - val_loss: 696.3760 - val_mean_absolute_error: 696.3760
#
# Epoch 00193: val_loss did not improve from 472.77493
# Epoch 194/500
# 84/84 [==============================] - ETA: 0s - loss: 895.6682 - mean_absolute_error: 895.668 - 0s 154us/step - loss: 918.7244 - mean_absolute_error: 918.7244 - val_loss: 647.1714 - val_mean_absolute_error: 647.1714
#
# Epoch 00194: val_loss did not improve from 472.77493
# Epoch 195/500
# 84/84 [==============================] - 0s 131us/step - loss: 914.7715 - mean_absolute_error: 914.7715 - val_loss: 713.0986 - val_mean_absolute_error: 713.0986
#
# Epoch 00195: val_loss did not improve from 472.77493
# Epoch 196/500
# 84/84 [==============================] - 0s 131us/step - loss: 902.9024 - mean_absolute_error: 902.9024 - val_loss: 681.7991 - val_mean_absolute_error: 681.7991
#
# Epoch 00196: val_loss did not improve from 472.77493
# Epoch 197/500
# 84/84 [==============================] - 0s 131us/step - loss: 890.2040 - mean_absolute_error: 890.2040 - val_loss: 659.7984 - val_mean_absolute_error: 659.7984
#
# Epoch 00197: val_loss did not improve from 472.77493
# Epoch 198/500
# 84/84 [==============================] - 0s 107us/step - loss: 899.6306 - mean_absolute_error: 899.6306 - val_loss: 697.0154 - val_mean_absolute_error: 697.0154
#
# Epoch 00198: val_loss did not improve from 472.77493
# Epoch 199/500
# 84/84 [==============================] - 0s 142us/step - loss: 901.7938 - mean_absolute_error: 901.7938 - val_loss: 711.5532 - val_mean_absolute_error: 711.5532
#
# Epoch 00199: val_loss did not improve from 472.77493
# Epoch 200/500
# 84/84 [==============================] - 0s 131us/step - loss: 897.5065 - mean_absolute_error: 897.5065 - val_loss: 674.7750 - val_mean_absolute_error: 674.7750
#
# Epoch 00200: val_loss did not improve from 472.77493
# Epoch 201/500
# 84/84 [==============================] - 0s 154us/step - loss: 899.1668 - mean_absolute_error: 899.1668 - val_loss: 681.6407 - val_mean_absolute_error: 681.6407
#
# Epoch 00201: val_loss did not improve from 472.77493
# Epoch 202/500
# 84/84 [==============================] - 0s 107us/step - loss: 892.2649 - mean_absolute_error: 892.2649 - val_loss: 719.4211 - val_mean_absolute_error: 719.4211
#
# Epoch 00202: val_loss did not improve from 472.77493
# Epoch 203/500
# 84/84 [==============================] - 0s 131us/step - loss: 897.3732 - mean_absolute_error: 897.3732 - val_loss: 702.7748 - val_mean_absolute_error: 702.7748
#
# Epoch 00203: val_loss did not improve from 472.77493
# Epoch 204/500
# 84/84 [==============================] - 0s 142us/step - loss: 890.5609 - mean_absolute_error: 890.5609 - val_loss: 708.6226 - val_mean_absolute_error: 708.6226
#
# ...
#
# Epoch 00431: val_loss did not improve from 472.77493
# Epoch 432/500
# 84/84 [==============================] - 0s 131us/step - loss: 844.5371 - mean_absolute_error: 844.5371 - val_loss: 722.4250 - val_mean_absolute_error: 722.4250
#
# Epoch 00432: val_loss did not improve from 472.77493
# Epoch 433/500
# 84/84 [==============================] - 0s 107us/step - loss: 843.3003 - mean_absolute_error: 843.3003 - val_loss: 742.0685 - val_mean_absolute_error: 742.0685
#
# Epoch 00433: val_loss did not improve from 472.77493
# Epoch 434/500
# 84/84 [==============================] - 0s 154us/step - loss: 839.4577 - mean_absolute_error: 839.4577 - val_loss: 750.0543 - val_mean_absolute_error: 750.0543
#
# Epoch 00434: val_loss did not improve from 472.77493
# Epoch 435/500
# 84/84 [==============================] - 0s 131us/step - loss: 833.4060 - mean_absolute_error: 833.4060 - val_loss: 824.3054 - val_mean_absolute_error: 824.3054
#
# Epoch 00435: val_loss did not improve from 472.77493
# Epoch 436/500
# 84/84 [==============================] - 0s 119us/step - loss: 849.6399 - mean_absolute_error: 849.6399 - val_loss: 792.3019 - val_mean_absolute_error: 792.3019
#
# Epoch 00436: val_loss did not improve from 472.77493
# Epoch 437/500
# 84/84 [==============================] - 0s 131us/step - loss: 843.5586 - mean_absolute_error: 843.5586 - val_loss: 787.5631 - val_mean_absolute_error: 787.5631
#
# Epoch 00437: val_loss did not improve from 472.77493
# Epoch 438/500
# 84/84 [==============================] - 0s 142us/step - loss: 861.2282 - mean_absolute_error: 861.2282 - val_loss: 883.0137 - val_mean_absolute_error: 883.0137
#
# Epoch 00438: val_loss did not improve from 472.77493
# Epoch 439/500
# 84/84 [==============================] - 0s 119us/step - loss: 839.1472 - mean_absolute_error: 839.1472 - val_loss: 768.6264 - val_mean_absolute_error: 768.6264
#
# Epoch 00439: val_loss did not improve from 472.77493
# Epoch 440/500
# 84/84 [==============================] - 0s 142us/step - loss: 853.9834 - mean_absolute_error: 853.9834 - val_loss: 801.0786 - val_mean_absolute_error: 801.0786
#
# Epoch 00440: val_loss did not improve from 472.77493
# Epoch 441/500
# 84/84 [==============================] - 0s 131us/step - loss: 852.8033 - mean_absolute_error: 852.8033 - val_loss: 842.1417 - val_mean_absolute_error: 842.1417
#
# Epoch 00441: val_loss did not improve from 472.77493
# Epoch 442/500
# 84/84 [==============================] - 0s 119us/step - loss: 842.5307 - mean_absolute_error: 842.5307 - val_loss: 759.0117 - val_mean_absolute_error: 759.0117
#
# Epoch 00442: val_loss did not improve from 472.77493
# Epoch 443/500
# 84/84 [==============================] - 0s 119us/step - loss: 831.5811 - mean_absolute_error: 831.5811 - val_loss: 803.4516 - val_mean_absolute_error: 803.4516
#
# Epoch 00443: val_loss did not improve from 472.77493
# Epoch 444/500
# 84/84 [==============================] - 0s 119us/step - loss: 853.7442 - mean_absolute_error: 853.7442 - val_loss: 795.7292 - val_mean_absolute_error: 795.7292
#
# Epoch 00444: val_loss did not improve from 472.77493
# Epoch 445/500
# 84/84 [==============================] - 0s 154us/step - loss: 843.9813 - mean_absolute_error: 843.9813 - val_loss: 733.2070 - val_mean_absolute_error: 733.2070
#
# Epoch 00445: val_loss did not improve from 472.77493
# Epoch 446/500
# 84/84 [==============================] - 0s 131us/step - loss: 855.0793 - mean_absolute_error: 855.0793 - val_loss: 817.8223 - val_mean_absolute_error: 817.8223
#
# Epoch 00446: val_loss did not improve from 472.77493
# Epoch 447/500
# 84/84 [==============================] - 0s 131us/step - loss: 834.3718 - mean_absolute_error: 834.3718 - val_loss: 755.6282 - val_mean_absolute_error: 755.6282
#
# Epoch 00447: val_loss did not improve from 472.77493
# Epoch 448/500
# 84/84 [==============================] - 0s 107us/step - loss: 844.0020 - mean_absolute_error: 844.0020 - val_loss: 756.7506 - val_mean_absolute_error: 756.7506
#
# Epoch 00448: val_loss did not improve from 472.77493
# Epoch 449/500
# 84/84 [==============================] - 0s 131us/step - loss: 850.7308 - mean_absolute_error: 850.7308 - val_loss: 796.5705 - val_mean_absolute_error: 796.5705
#
# Epoch 00449: val_loss did not improve from 472.77493
# Epoch 450/500
# 84/84 [==============================] - 0s 154us/step - loss: 839.1032 - mean_absolute_error: 839.1032 - val_loss: 841.5977 - val_mean_absolute_error: 841.5977
#
# Epoch 00450: val_loss did not improve from 472.77493
# Epoch 451/500
# 84/84 [==============================] - 0s 131us/step - loss: 844.9565 - mean_absolute_error: 844.9565 - val_loss: 789.6260 - val_mean_absolute_error: 789.6260
#
# Epoch 00451: val_loss did not improve from 472.77493
# Epoch 452/500
# 84/84 [==============================] - 0s 95us/step - loss: 832.2354 - mean_absolute_error: 832.2354 - val_loss: 792.6877 - val_mean_absolute_error: 792.6877
#
# Epoch 00452: val_loss did not improve from 472.77493
# Epoch 453/500
# 84/84 [==============================] - 0s 131us/step - loss: 830.4668 - mean_absolute_error: 830.4668 - val_loss: 824.0010 - val_mean_absolute_error: 824.0010
#
# Epoch 00453: val_loss did not improve from 472.77493
# Epoch 454/500
# 84/84 [==============================] - 0s 154us/step - loss: 825.1859 - mean_absolute_error: 825.1859 - val_loss: 798.1498 - val_mean_absolute_error: 798.1498
#
# Epoch 00454: val_loss did not improve from 472.77493
# Epoch 455/500
# 84/84 [==============================] - 0s 107us/step - loss: 838.9329 - mean_absolute_error: 838.9329 - val_loss: 863.8535 - val_mean_absolute_error: 863.8535
#
# Epoch 00455: val_loss did not improve from 472.77493
# Epoch 456/500
# 84/84 [==============================] - 0s 131us/step - loss: 827.3081 - mean_absolute_error: 827.3081 - val_loss: 812.2299 - val_mean_absolute_error: 812.2299
#
# Epoch 00456: val_loss did not improve from 472.77493
# Epoch 457/500
# 84/84 [==============================] - 0s 142us/step - loss: 848.2485 - mean_absolute_error: 848.2485 - val_loss: 836.2512 - val_mean_absolute_error: 836.2512
#
# Epoch 00457: val_loss did not improve from 472.77493
# Epoch 458/500
# 84/84 [==============================] - 0s 119us/step - loss: 830.2832 - mean_absolute_error: 830.2832 - val_loss: 802.2169 - val_mean_absolute_error: 802.2169
#
# Epoch 00458: val_loss did not improve from 472.77493
# Epoch 459/500
# 84/84 [==============================] - 0s 107us/step - loss: 826.9918 - mean_absolute_error: 826.9918 - val_loss: 829.7108 - val_mean_absolute_error: 829.7108
#
# Epoch 00459: val_loss did not improve from 472.77493
# Epoch 460/500
# 84/84 [==============================] - 0s 131us/step - loss: 834.5332 - mean_absolute_error: 834.5332 - val_loss: 801.0865 - val_mean_absolute_error: 801.0865
#
# Epoch 00460: val_loss did not improve from 472.77493
# Epoch 461/500
# 84/84 [==============================] - 0s 154us/step - loss: 842.9332 - mean_absolute_error: 842.9332 - val_loss: 855.1625 - val_mean_absolute_error: 855.1625
# Epoch 00461: val_loss did not improve from 472.77493
# Epoch 462/500
# 84/84 [==============================] - 0s 131us/step - loss: 823.6017 - mean_absolute_error: 823.6017 - val_loss: 770.0009 - val_mean_absolute_error: 770.0009
#
# Epoch 00462: val_loss did not improve from 472.77493
# Epoch 463/500
# 84/84 [==============================] - 0s 131us/step - loss: 879.0130 - mean_absolute_error: 879.0130 - val_loss: 764.6965 - val_mean_absolute_error: 764.6965
#
# Epoch 00463: val_loss did not improve from 472.77493
# Epoch 464/500
# 84/84 [==============================] - 0s 154us/step - loss: 856.0344 - mean_absolute_error: 856.0344 - val_loss: 906.2067 - val_mean_absolute_error: 906.2067
#
# Epoch 00464: val_loss did not improve from 472.77493
# Epoch 465/500
# 84/84 [==============================] - 0s 131us/step - loss: 850.6966 - mean_absolute_error: 850.6966 - val_loss: 799.9549 - val_mean_absolute_error: 799.9549
#
# Epoch 00465: val_loss did not improve from 472.77493
# Epoch 466/500
# 84/84 [==============================] - 0s 119us/step - loss: 838.3430 - mean_absolute_error: 838.3430 - val_loss: 777.4579 - val_mean_absolute_error: 777.4579
#
# Epoch 00466: val_loss did not improve from 472.77493
# Epoch 467/500
# 84/84 [==============================] - 0s 131us/step - loss: 827.2091 - mean_absolute_error: 827.2091 - val_loss: 853.8926 - val_mean_absolute_error: 853.8926
#
# Epoch 00467: val_loss did not improve from 472.77493
# Epoch 468/500
# 84/84 [==============================] - 0s 131us/step - loss: 847.2543 - mean_absolute_error: 847.2543 - val_loss: 808.7200 - val_mean_absolute_error: 808.7200
#
# Epoch 00468: val_loss did not improve from 472.77493
# Epoch 469/500
# 84/84 [==============================] - 0s 119us/step - loss: 820.5127 - mean_absolute_error: 820.5127 - val_loss: 908.4039 - val_mean_absolute_error: 908.4039
#
# Epoch 00469: val_loss did not improve from 472.77493
# Epoch 470/500
# 84/84 [==============================] - 0s 143us/step - loss: 828.2623 - mean_absolute_error: 828.2623 - val_loss: 858.6492 - val_mean_absolute_error: 858.6492
#
# Epoch 00470: val_loss did not improve from 472.77493
# Epoch 471/500
# 84/84 [==============================] - 0s 130us/step - loss: 831.0822 - mean_absolute_error: 831.0822 - val_loss: 822.7438 - val_mean_absolute_error: 822.7438
#
# Epoch 00471: val_loss did not improve from 472.77493
# Epoch 472/500
# 84/84 [==============================] - 0s 119us/step - loss: 838.4901 - mean_absolute_error: 838.4901 - val_loss: 891.1044 - val_mean_absolute_error: 891.1044
#
# Epoch 00472: val_loss did not improve from 472.77493
# Epoch 473/500
# 84/84 [==============================] - 0s 119us/step - loss: 830.2827 - mean_absolute_error: 830.2827 - val_loss: 794.2587 - val_mean_absolute_error: 794.2587
#
# Epoch 00473: val_loss did not improve from 472.77493
# Epoch 474/500
# 84/84 [==============================] - 0s 119us/step - loss: 834.7366 - mean_absolute_error: 834.7366 - val_loss: 807.4375 - val_mean_absolute_error: 807.4375
#
# Epoch 00474: val_loss did not improve from 472.77493
# Epoch 475/500
# 84/84 [==============================] - 0s 119us/step - loss: 855.4157 - mean_absolute_error: 855.4157 - val_loss: 859.4305 - val_mean_absolute_error: 859.4305
#
# Epoch 00475: val_loss did not improve from 472.77493
# Epoch 476/500
# 84/84 [==============================] - 0s 131us/step - loss: 867.9455 - mean_absolute_error: 867.9455 - val_loss: 692.0205 - val_mean_absolute_error: 692.0205
#
# Epoch 00476: val_loss did not improve from 472.77493
# Epoch 477/500
# 84/84 [==============================] - 0s 119us/step - loss: 824.9807 - mean_absolute_error: 824.9807 - val_loss: 786.0892 - val_mean_absolute_error: 786.0892
#
# Epoch 00477: val_loss did not improve from 472.77493
# Epoch 478/500
# 84/84 [==============================] - 0s 107us/step - loss: 840.6259 - mean_absolute_error: 840.6259 - val_loss: 831.7585 - val_mean_absolute_error: 831.7585
#
# Epoch 00478: val_loss did not improve from 472.77493
# Epoch 479/500
# 84/84 [==============================] - 0s 142us/step - loss: 853.2062 - mean_absolute_error: 853.2062 - val_loss: 750.3306 - val_mean_absolute_error: 750.3306
#
# Epoch 00479: val_loss did not improve from 472.77493
# Epoch 480/500
# 84/84 [==============================] - 0s 131us/step - loss: 862.6340 - mean_absolute_error: 862.6340 - val_loss: 893.0369 - val_mean_absolute_error: 893.0369
#
# Epoch 00480: val_loss did not improve from 472.77493
# Epoch 481/500
# 84/84 [==============================] - 0s 119us/step - loss: 820.6227 - mean_absolute_error: 820.6227 - val_loss: 886.4160 - val_mean_absolute_error: 886.4160
#
# Epoch 00481: val_loss did not improve from 472.77493
# Epoch 482/500
# 84/84 [==============================] - 0s 107us/step - loss: 827.5539 - mean_absolute_error: 827.5539 - val_loss: 843.5877 - val_mean_absolute_error: 843.5877
#
# Epoch 00482: val_loss did not improve from 472.77493
# Epoch 483/500
# 84/84 [==============================] - 0s 131us/step - loss: 822.7920 - mean_absolute_error: 822.7920 - val_loss: 826.4879 - val_mean_absolute_error: 826.4879
#
# Epoch 00483: val_loss did not improve from 472.77493
# Epoch 484/500
# 84/84 [==============================] - 0s 154us/step - loss: 826.5335 - mean_absolute_error: 826.5335 - val_loss: 750.4846 - val_mean_absolute_error: 750.4846
#
# Epoch 00484: val_loss did not improve from 472.77493
# Epoch 485/500
# 84/84 [==============================] - 0s 131us/step - loss: 834.0897 - mean_absolute_error: 834.0897 - val_loss: 756.5543 - val_mean_absolute_error: 756.5543
#
# Epoch 00485: val_loss did not improve from 472.77493
# Epoch 486/500
# 84/84 [==============================] - 0s 95us/step - loss: 822.9982 - mean_absolute_error: 822.9982 - val_loss: 747.7598 - val_mean_absolute_error: 747.7598
#
# Epoch 00486: val_loss did not improve from 472.77493
# Epoch 487/500
# 84/84 [==============================] - 0s 107us/step - loss: 830.6357 - mean_absolute_error: 830.6357 - val_loss: 834.4027 - val_mean_absolute_error: 834.4027
#
# Epoch 00487: val_loss did not improve from 472.77493
# Epoch 488/500
# 84/84 [==============================] - 0s 131us/step - loss: 820.2584 - mean_absolute_error: 820.2584 - val_loss: 960.6184 - val_mean_absolute_error: 960.6184
#
# Epoch 00488: val_loss did not improve from 472.77493
# Epoch 489/500
# 84/84 [==============================] - 0s 131us/step - loss: 837.8981 - mean_absolute_error: 837.8981 - val_loss: 855.8824 - val_mean_absolute_error: 855.8824
#
# Epoch 00489: val_loss did not improve from 472.77493
# Epoch 490/500
# 84/84 [==============================] - 0s 119us/step - loss: 825.0565 - mean_absolute_error: 825.0565 - val_loss: 790.1537 - val_mean_absolute_error: 790.1537
#
# Epoch 00490: val_loss did not improve from 472.77493
# Epoch 491/500
# 84/84 [==============================] - 0s 95us/step - loss: 832.8242 - mean_absolute_error: 832.8242 - val_loss: 777.5305 - val_mean_absolute_error: 777.5305
#
# Epoch 00491: val_loss did not improve from 472.77493
# Epoch 492/500
# 84/84 [==============================] - 0s 119us/step - loss: 818.9734 - mean_absolute_error: 818.9734 - val_loss: 799.7929 - val_mean_absolute_error: 799.7929
#
# Epoch 00492: val_loss did not improve from 472.77493
# Epoch 493/500
# 84/84 [==============================] - 0s 166us/step - loss: 822.0596 - mean_absolute_error: 822.0596 - val_loss: 702.6584 - val_mean_absolute_error: 702.6584
#
# Epoch 00493: val_loss did not improve from 472.77493
# Epoch 494/500
# 84/84 [==============================] - 0s 142us/step - loss: 822.9200 - mean_absolute_error: 822.9200 - val_loss: 697.1733 - val_mean_absolute_error: 697.1733
#
# Epoch 00494: val_loss did not improve from 472.77493
# Epoch 495/500
# 84/84 [==============================] - 0s 131us/step - loss: 830.9560 - mean_absolute_error: 830.9560 - val_loss: 795.9977 - val_mean_absolute_error: 795.9977
#
# Epoch 00495: val_loss did not improve from 472.77493
# Epoch 496/500
# 84/84 [==============================] - 0s 143us/step - loss: 810.6612 - mean_absolute_error: 810.6612 - val_loss: 858.7817 - val_mean_absolute_error: 858.7817
#
# Epoch 00496: val_loss did not improve from 472.77493
# Epoch 497/500
# 84/84 [==============================] - 0s 137us/step - loss: 806.5347 - mean_absolute_error: 806.5347 - val_loss: 800.8672 - val_mean_absolute_error: 800.8672
# Epoch 00497: val_loss did not improve from 472.77493
# Epoch 498/500
# 84/84 [==============================] - 0s 95us/step - loss: 867.7688 - mean_absolute_error: 867.7688 - val_loss: 855.4973 - val_mean_absolute_error: 855.4973
#
# Epoch 00498: val_loss did not improve from 472.77493
# Epoch 499/500
# 84/84 [==============================] - 0s 107us/step - loss: 836.1137 - mean_absolute_error: 836.1137 - val_loss: 929.9787 - val_mean_absolute_error: 929.9787
#
# Epoch 00499: val_loss did not improve from 472.77493
# Epoch 500/500
# 84/84 [==============================] - 0s 119us/step - loss: 806.2266 - mean_absolute_error: 806.2266 - val_loss: 769.5111 - val_mean_absolute_error: 769.5111
#
# Epoch 00500: val_loss did not improve from 472.77493

# %% [markdown]
# #### ====================================================================================================

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
wights_file = 'GS-탄산음료week-Weights-127--472.77493.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# Out:
# W0717 15:43:07.610063  8000 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0717 15:43:07.611082  8000 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
# rf나,XGB회귀 분석을위한 훈련/검증 dataset생산
train_X, val_X, train_y, val_y = train_test_split(train, target[:cut_line], test_size = 0.25, random_state = 14)

# %%
# RandomForest 회귀분석
model = RandomForestRegressor()
model.fit(train_X,train_y)

# Get the mean absolute error on the validation data
RFpredicted = model.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  804.3703703703701

# %%
# XGBRegressor 회귀분석
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# [15:43:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  799.4550548735118

# %%
# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)

combined = gs_week_w.loc[:,'temp':'PM25']
target = gs_week_w.loc[:,'qty']
# RandomForest 회귀분석 예측 qty생산
RFpredicted = model.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)

result_df = pd.DataFrame()
result_df['week'] = gs_week_w['week']
result_df['qty'] = gs_week_w.loc[:,'qty']

print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions
# Out:
# keras 신경망 predictions (157, 1)
# randomforest 예상 (157,)
# XGBpredictions (157,)

# %%
df_graph = result_df.loc[:,['week','keras_qty','rf_qty','xgb_qty','qty']]
df_graph['week'] = pd.to_datetime(df_graph['week'])

# %%
df_graph = result_df.copy()
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actual', color='green', alpha=0.3, lw=9)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf', color='orange')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb', color='b')
plt.legend()
plt.show()

# %%
df_graph = result_df.loc[result_df.week <=53]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actual', color='green', alpha=0.3, lw=9)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf', color='orange')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb', color='b')
plt.legend()
plt.show()

# %%
df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actual', color='green', alpha=0.3, lw=9)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf', color='orange')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb', color='b')
plt.show()

# %%
df_graph = result_df.loc[(result_df.week >=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actual', color='green', alpha=0.3, lw=9)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf', color='orange')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb', color='b')
plt.legend()
plt.show()

# %%
# 2016~2018
plt.figure(figsize=(15.5, 10))
plt.plot(result_df.week,result_df.qty, ls='-', label='actual', color='green', alpha=0.3, lw=9)
plt.plot(result_df.week,result_df.keras_qty, label='keras', color='r')
plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf', color='orange')
plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb', color='b')
plt.legend()
plt.show()

# %%
# 날씨+sns와 '생수' 을 사용하면 2017까진 적당하고 2018년도는 예측율 급락
#  -> 과적합화 발생
# 날씨와 '생수' 판매량만 이용하니 ㅇㅋ

# %%
orginal_mean = np.mean(result_df.qty)
result_df['qtyMinusMean'] = (result_df.qty - orginal_mean )
result_df['qtyMinusMeanSquared'] = (result_df.qty - orginal_mean )**2

result_df['kerasMiunsMeanSquared'] = (result_df.keras_qty - orginal_mean)**2
result_df['rfMiunsMeanSquared'] = (result_df.rf_qty - orginal_mean)**2
result_df['xgbMiunsMeanSquared'] = (result_df.xgb_qty - orginal_mean)**2

print('kreas R-sq',(sum(result_df['kerasMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
print('rf R-sq',(sum(result_df['rfMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
print('xgb R-sq',(sum(result_df['xgbMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
# Out:
# kreas R-sq 0.24018079787397995
# rf R-sq 0.7110702693402513
# xgb R-sq 0.8705256083271529

# %%
path = 'D:/project/contest/data/result/'
result_df.to_csv(path+item+'_'+grouped_by+'_predict.csv', encoding='utf-8', index=False)
