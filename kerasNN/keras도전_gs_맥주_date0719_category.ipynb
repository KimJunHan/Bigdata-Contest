# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '맥주'만 빼서 df생성
item = '맥주'
grouped_by = 'date'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %%
list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
lowVIF(w,40,list_col)
# Out:
#    VIF_Factor  features
# 0    3.715302      temp
# 1    4.682044      PM10
# 2    6.314379     cloud
# 3    7.886587  lgt_time
# 4    8.692697      wind

# %%
train_data = gs_day_w.loc[gs_day_w.date.between('2016-01-01','2017-12-31')]
test_data = gs_day_w.loc[gs_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만, 
# 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
# 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not',
# 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
combined = gs_day_w.loc[:,list_col+['rain_or_not','snow_or_not']]
target = gs_day_w.loc[:,'qty']

# %%
combined.head(2)
# Out:
#    temp  cloud  wind  lgt_time       PM10 rain_or_not snow_or_not
# 0   1.2    7.0   1.6       2.1  68.696500          비x          눈x
# 1   5.7    7.8   2.0       3.6  53.618667          비x          눈x

# %%
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 5
# 오브젝트형 자료 컬럼 갯수 : 2

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 9 개의 columns이 있었습니다.

# %%
# 비o,비x는 하나가 1이면 다른하나는 0은 완저히 베타적인 관계이므로 한개를 삭제
# 눈o눈x,도 비와 같다.
combined.drop(['rain_or_not_비x'],axis = 1 , inplace=True)
combined.drop(['snow_or_not_눈x'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time     PM10  rain_or_not_비o  snow_or_not_눈o
# 0   1.2    7.0   1.6       2.1  68.6965               0               0

# %%
combined.columns = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o',
       'snow_or_not_o']
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time     PM10  rain_or_not_o  snow_or_not_o
# 0   1.2    7.0   1.6       2.1  68.6965              0              0

# %%
Xy = pd.concat([target,combined], axis=1)
Xy.head(1)
# Out:
#      qty  temp  cloud  wind  lgt_time     PM10  rain_or_not_o  snow_or_not_o
# 0  12811   1.2    7.0   1.6       2.1  68.6965              0              0

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 7)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 12:02:36.119991 10160 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 12:02:36.134945 10160 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 12:02:36.137916 10160 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 12:02:36.194763 10160 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 165,889
# Trainable params: 165,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'GS-'+item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 12:04:48.933071 10160 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 12:04:49.054726 10160 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 546us/step - loss: 11580.0205 - mean_absolute_error: 11580.0205 - val_loss: 11503.2984 - val_mean_absolute_error: 11503.2984
#
# Epoch 00001: val_loss improved from inf to 11503.29843, saving model to GS-맥주date-Weights-001--11503.29843-cat02-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 82us/step - loss: 10411.7088 - mean_absolute_error: 10411.7088 - val_loss: 8246.4966 - val_mean_absolute_error: 8246.4966
#
# Epoch 00002: val_loss improved from 11503.29843 to 8246.49661, saving model to GS-맥주date-Weights-002--8246.49661-cat02-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 77us/step - loss: 4372.9309 - mean_absolute_error: 4372.9309 - val_loss: 3371.5062 - val_mean_absolute_error: 3371.5062
#
# Epoch 00003: val_loss improved from 8246.49661 to 3371.50617, saving model to GS-맥주date-Weights-003--3371.50617-cat02-vf05.hdf5
# Epoch 4/500
# 585/585 [==============================] - 0s 84us/step - loss: 3120.3543 - mean_absolute_error: 3120.3543 - val_loss: 2620.3458 - val_mean_absolute_error: 2620.3458
#
# Epoch 00004: val_loss improved from 3371.50617 to 2620.34576, saving model to GS-맥주date-Weights-004--2620.34576-cat02-vf05.hdf5
# Epoch 5/500
# 585/585 [==============================] - 0s 74us/step - loss: 2781.1816 - mean_absolute_error: 2781.1816 - val_loss: 2331.6559 - val_mean_absolute_error: 2331.6559
#
# Epoch 00005: val_loss improved from 2620.34576 to 2331.65592, saving model to GS-맥주date-Weights-005--2331.65592-cat02-vf05.hdf5
# Epoch 6/500
# 585/585 [==============================] - 0s 82us/step - loss: 2580.7134 - mean_absolute_error: 2580.7134 - val_loss: 2218.5238 - val_mean_absolute_error: 2218.5238
#
# Epoch 00006: val_loss improved from 2331.65592 to 2218.52383, saving model to GS-맥주date-Weights-006--2218.52383-cat02-vf05.hdf5
# Epoch 7/500
# 585/585 [==============================] - 0s 73us/step - loss: 2443.7109 - mean_absolute_error: 2443.7109 - val_loss: 2343.4544 - val_mean_absolute_error: 2343.4544
#
# Epoch 00007: val_loss did not improve from 2218.52383
# Epoch 8/500
# 585/585 [==============================] - 0s 73us/step - loss: 2341.1380 - mean_absolute_error: 2341.1380 - val_loss: 2588.8817 - val_mean_absolute_error: 2588.8817
#
# Epoch 00008: val_loss did not improve from 2218.52383
# Epoch 9/500
# 585/585 [==============================] - 0s 77us/step - loss: 2266.3475 - mean_absolute_error: 2266.3475 - val_loss: 2502.7905 - val_mean_absolute_error: 2502.7905
#
# Epoch 00009: val_loss did not improve from 2218.52383
# Epoch 10/500
# 585/585 [==============================] - 0s 85us/step - loss: 2233.2034 - mean_absolute_error: 2233.2034 - val_loss: 2548.6463 - val_mean_absolute_error: 2548.6463
#
# Epoch 00010: val_loss did not improve from 2218.52383
# Epoch 11/500
# 585/585 [==============================] - 0s 80us/step - loss: 2121.5548 - mean_absolute_error: 2121.5548 - val_loss: 2201.1630 - val_mean_absolute_error: 2201.1630
#
# Epoch 00011: val_loss improved from 2218.52383 to 2201.16301, saving model to GS-맥주date-Weights-011--2201.16301-cat02-vf05.hdf5
# Epoch 12/500
# 585/585 [==============================] - 0s 77us/step - loss: 2090.1169 - mean_absolute_error: 2090.1169 - val_loss: 1821.0531 - val_mean_absolute_error: 1821.0531
#
# Epoch 00012: val_loss improved from 2201.16301 to 1821.05314, saving model to GS-맥주date-Weights-012--1821.05314-cat02-vf05.hdf5
# Epoch 13/500
# 585/585 [==============================] - 0s 68us/step - loss: 2084.1431 - mean_absolute_error: 2084.1431 - val_loss: 1918.7482 - val_mean_absolute_error: 1918.7482
#
# Epoch 00013: val_loss did not improve from 1821.05314
# Epoch 14/500
# 585/585 [==============================] - 0s 78us/step - loss: 1990.2553 - mean_absolute_error: 1990.2553 - val_loss: 1861.4414 - val_mean_absolute_error: 1861.4414
#
# Epoch 00014: val_loss did not improve from 1821.05314
# Epoch 15/500
# 585/585 [==============================] - 0s 75us/step - loss: 1951.4886 - mean_absolute_error: 1951.4886 - val_loss: 1777.8206 - val_mean_absolute_error: 1777.8206
#
# Epoch 00015: val_loss improved from 1821.05314 to 1777.82064, saving model to GS-맥주date-Weights-015--1777.82064-cat02-vf05.hdf5
# Epoch 16/500
# 585/585 [==============================] - 0s 73us/step - loss: 1917.0248 - mean_absolute_error: 1917.0248 - val_loss: 1763.5575 - val_mean_absolute_error: 1763.5575
#
# Epoch 00016: val_loss improved from 1777.82064 to 1763.55754, saving model to GS-맥주date-Weights-016--1763.55754-cat02-vf05.hdf5
# Epoch 17/500
# 585/585 [==============================] - 0s 92us/step - loss: 1871.0220 - mean_absolute_error: 1871.0220 - val_loss: 1758.1794 - val_mean_absolute_error: 1758.1794
#
# Epoch 00017: val_loss improved from 1763.55754 to 1758.17943, saving model to GS-맥주date-Weights-017--1758.17943-cat02-vf05.hdf5
# Epoch 18/500
# 585/585 [==============================] - 0s 73us/step - loss: 1859.2380 - mean_absolute_error: 1859.2380 - val_loss: 1687.6617 - val_mean_absolute_error: 1687.6617
#
# Epoch 00018: val_loss improved from 1758.17943 to 1687.66165, saving model to GS-맥주date-Weights-018--1687.66165-cat02-vf05.hdf5
# Epoch 19/500
# 585/585 [==============================] - 0s 68us/step - loss: 1892.4581 - mean_absolute_error: 1892.4581 - val_loss: 1615.7226 - val_mean_absolute_error: 1615.7226
#
# Epoch 00019: val_loss improved from 1687.66165 to 1615.72259, saving model to GS-맥주date-Weights-019--1615.72259-cat02-vf05.hdf5
# Epoch 20/500
# 585/585 [==============================] - 0s 82us/step - loss: 1890.2345 - mean_absolute_error: 1890.2345 - val_loss: 1674.5437 - val_mean_absolute_error: 1674.5437
#
# Epoch 00020: val_loss did not improve from 1615.72259
# Epoch 21/500
# 585/585 [==============================] - 0s 68us/step - loss: 1857.1871 - mean_absolute_error: 1857.1871 - val_loss: 1839.9658 - val_mean_absolute_error: 1839.9658
#
# Epoch 00021: val_loss did not improve from 1615.72259
# Epoch 22/500
# 585/585 [==============================] - 0s 75us/step - loss: 1848.9730 - mean_absolute_error: 1848.9730 - val_loss: 1651.7811 - val_mean_absolute_error: 1651.7811
#
# Epoch 00022: val_loss did not improve from 1615.72259
# Epoch 23/500
# 585/585 [==============================] - 0s 70us/step - loss: 1826.5449 - mean_absolute_error: 1826.5449 - val_loss: 1786.6723 - val_mean_absolute_error: 1786.6723
#
# Epoch 00023: val_loss did not improve from 1615.72259
# Epoch 24/500
# 585/585 [==============================] - 0s 68us/step - loss: 1813.7157 - mean_absolute_error: 1813.7157 - val_loss: 1912.2768 - val_mean_absolute_error: 1912.2768
#
# Epoch 00024: val_loss did not improve from 1615.72259
# Epoch 25/500
# 585/585 [==============================] - 0s 97us/step - loss: 1815.5028 - mean_absolute_error: 1815.5028 - val_loss: 1798.9746 - val_mean_absolute_error: 1798.9746
#
# Epoch 00025: val_loss did not improve from 1615.72259
# Epoch 26/500
# 585/585 [==============================] - 0s 90us/step - loss: 1831.1089 - mean_absolute_error: 1831.1089 - val_loss: 1779.4770 - val_mean_absolute_error: 1779.4770
#
# Epoch 00026: val_loss did not improve from 1615.72259
# Epoch 27/500
# 585/585 [==============================] - 0s 80us/step - loss: 1822.5467 - mean_absolute_error: 1822.5467 - val_loss: 1956.6290 - val_mean_absolute_error: 1956.6290
#
# Epoch 00027: val_loss did not improve from 1615.72259
# Epoch 28/500
# 585/585 [==============================] - 0s 80us/step - loss: 1835.5861 - mean_absolute_error: 1835.5861 - val_loss: 1712.6009 - val_mean_absolute_error: 1712.6009
#
# Epoch 00028: val_loss did not improve from 1615.72259
# Epoch 29/500
# 585/585 [==============================] - 0s 111us/step - loss: 1870.3183 - mean_absolute_error: 1870.3183 - val_loss: 1659.2396 - val_mean_absolute_error: 1659.2396
#
# Epoch 00029: val_loss did not improve from 1615.72259
# Epoch 30/500
# 585/585 [==============================] - 0s 113us/step - loss: 1809.3258 - mean_absolute_error: 1809.3258 - val_loss: 1696.3600 - val_mean_absolute_error: 1696.3600
#
# Epoch 00030: val_loss did not improve from 1615.72259
# Epoch 31/500
# 585/585 [==============================] - 0s 91us/step - loss: 1844.3728 - mean_absolute_error: 1844.3728 - val_loss: 1780.0244 - val_mean_absolute_error: 1780.0244
# Epoch 00031: val_loss did not improve from 1615.72259
# Epoch 32/500
# 585/585 [==============================] - 0s 72us/step - loss: 1793.3974 - mean_absolute_error: 1793.3974 - val_loss: 1762.8300 - val_mean_absolute_error: 1762.8300
#
# Epoch 00032: val_loss did not improve from 1615.72259
# Epoch 33/500
# 585/585 [==============================] - 0s 73us/step - loss: 1798.1081 - mean_absolute_error: 1798.1081 - val_loss: 1807.8738 - val_mean_absolute_error: 1807.8738
#
# Epoch 00033: val_loss did not improve from 1615.72259
# Epoch 34/500
# 585/585 [==============================] - 0s 72us/step - loss: 1797.9035 - mean_absolute_error: 1797.9035 - val_loss: 1808.4472 - val_mean_absolute_error: 1808.4472
#
# Epoch 00034: val_loss did not improve from 1615.72259
# Epoch 35/500
# 585/585 [==============================] - 0s 82us/step - loss: 1783.1720 - mean_absolute_error: 1783.1720 - val_loss: 1707.5575 - val_mean_absolute_error: 1707.5575
#
# Epoch 00035: val_loss did not improve from 1615.72259
# Epoch 36/500
# 585/585 [==============================] - 0s 82us/step - loss: 1789.6988 - mean_absolute_error: 1789.6988 - val_loss: 1754.0487 - val_mean_absolute_error: 1754.0487
#
# Epoch 00036: val_loss did not improve from 1615.72259
# Epoch 37/500
# 585/585 [==============================] - 0s 80us/step - loss: 1778.5064 - mean_absolute_error: 1778.5064 - val_loss: 1646.4718 - val_mean_absolute_error: 1646.4718
#
# Epoch 00037: val_loss did not improve from 1615.72259
# Epoch 38/500
# 585/585 [==============================] - 0s 82us/step - loss: 1771.1095 - mean_absolute_error: 1771.1095 - val_loss: 1645.6873 - val_mean_absolute_error: 1645.6873
#
# Epoch 00038: val_loss did not improve from 1615.72259
# Epoch 39/500
# 585/585 [==============================] - 0s 78us/step - loss: 1773.5500 - mean_absolute_error: 1773.5500 - val_loss: 1735.1777 - val_mean_absolute_error: 1735.1777
#
# Epoch 00039: val_loss did not improve from 1615.72259
# Epoch 40/500
# 585/585 [==============================] - 0s 77us/step - loss: 1776.0806 - mean_absolute_error: 1776.0806 - val_loss: 1567.8550 - val_mean_absolute_error: 1567.8550
#
# Epoch 00040: val_loss improved from 1615.72259 to 1567.85496, saving model to GS-맥주date-Weights-040--1567.85496-cat02-vf05.hdf5
# Epoch 41/500
# 585/585 [==============================] - 0s 84us/step - loss: 1855.6918 - mean_absolute_error: 1855.6918 - val_loss: 1644.3123 - val_mean_absolute_error: 1644.3123
#
# Epoch 00041: val_loss did not improve from 1567.85496
# Epoch 42/500
# 585/585 [==============================] - 0s 80us/step - loss: 1800.0945 - mean_absolute_error: 1800.0945 - val_loss: 1718.5356 - val_mean_absolute_error: 1718.5356
#
# Epoch 00042: val_loss did not improve from 1567.85496
# Epoch 43/500
# 585/585 [==============================] - 0s 73us/step - loss: 1780.1552 - mean_absolute_error: 1780.1552 - val_loss: 1811.2994 - val_mean_absolute_error: 1811.2994
#
# Epoch 00043: val_loss did not improve from 1567.85496
# Epoch 44/500
# 585/585 [==============================] - 0s 109us/step - loss: 1783.9604 - mean_absolute_error: 1783.9604 - val_loss: 1709.5316 - val_mean_absolute_error: 1709.5316
#
# Epoch 00044: val_loss did not improve from 1567.85496
# Epoch 45/500
# 585/585 [==============================] - 0s 92us/step - loss: 1749.9851 - mean_absolute_error: 1749.9851 - val_loss: 1644.8750 - val_mean_absolute_error: 1644.8750
#
# Epoch 00045: val_loss did not improve from 1567.85496
# Epoch 46/500
# 585/585 [==============================] - 0s 75us/step - loss: 1802.7615 - mean_absolute_error: 1802.7615 - val_loss: 1726.3986 - val_mean_absolute_error: 1726.3986
#
# Epoch 00046: val_loss did not improve from 1567.85496
# Epoch 47/500
# 585/585 [==============================] - 0s 73us/step - loss: 1807.5450 - mean_absolute_error: 1807.5450 - val_loss: 1844.9405 - val_mean_absolute_error: 1844.9405
#
# Epoch 00047: val_loss did not improve from 1567.85496
# Epoch 48/500
# 585/585 [==============================] - 0s 77us/step - loss: 1763.3660 - mean_absolute_error: 1763.3660 - val_loss: 1765.3882 - val_mean_absolute_error: 1765.3882
#
# Epoch 00048: val_loss did not improve from 1567.85496
# Epoch 49/500
# 585/585 [==============================] - 0s 77us/step - loss: 1776.6470 - mean_absolute_error: 1776.6470 - val_loss: 1888.7116 - val_mean_absolute_error: 1888.7116
#
# Epoch 00049: val_loss did not improve from 1567.85496
# Epoch 50/500
# 585/585 [==============================] - 0s 80us/step - loss: 1818.8001 - mean_absolute_error: 1818.8001 - val_loss: 1742.8706 - val_mean_absolute_error: 1742.8706
#
# Epoch 00050: val_loss did not improve from 1567.85496
# Epoch 51/500
# 585/585 [==============================] - 0s 82us/step - loss: 1749.7073 - mean_absolute_error: 1749.7073 - val_loss: 1748.2335 - val_mean_absolute_error: 1748.2335
#
# Epoch 00051: val_loss did not improve from 1567.85496
# Epoch 52/500
# 585/585 [==============================] - 0s 80us/step - loss: 1814.4481 - mean_absolute_error: 1814.4481 - val_loss: 1735.6941 - val_mean_absolute_error: 1735.6941
#
# Epoch 00052: val_loss did not improve from 1567.85496
# Epoch 53/500
# 585/585 [==============================] - 0s 82us/step - loss: 1752.4484 - mean_absolute_error: 1752.4484 - val_loss: 1848.4904 - val_mean_absolute_error: 1848.4904
#
# Epoch 00053: val_loss did not improve from 1567.85496
# Epoch 54/500
# 585/585 [==============================] - 0s 85us/step - loss: 1787.8594 - mean_absolute_error: 1787.8594 - val_loss: 1710.3787 - val_mean_absolute_error: 1710.3787
#
# Epoch 00054: val_loss did not improve from 1567.85496
# Epoch 55/500
# 585/585 [==============================] - 0s 85us/step - loss: 1741.2438 - mean_absolute_error: 1741.2438 - val_loss: 1697.3477 - val_mean_absolute_error: 1697.3477
#
# Epoch 00055: val_loss did not improve from 1567.85496
# Epoch 56/500
# 585/585 [==============================] - 0s 85us/step - loss: 1742.3954 - mean_absolute_error: 1742.3954 - val_loss: 1579.9440 - val_mean_absolute_error: 1579.9440
#
# Epoch 00056: val_loss did not improve from 1567.85496
# Epoch 57/500
# 585/585 [==============================] - 0s 80us/step - loss: 1755.5940 - mean_absolute_error: 1755.5940 - val_loss: 1588.4955 - val_mean_absolute_error: 1588.4955
#
# Epoch 00057: val_loss did not improve from 1567.85496
# Epoch 58/500
# 585/585 [==============================] - 0s 74us/step - loss: 1763.5343 - mean_absolute_error: 1763.5343 - val_loss: 1692.8013 - val_mean_absolute_error: 1692.8013
#
# Epoch 00058: val_loss did not improve from 1567.85496
# Epoch 59/500
# 585/585 [==============================] - 0s 73us/step - loss: 1733.7386 - mean_absolute_error: 1733.7386 - val_loss: 1625.2154 - val_mean_absolute_error: 1625.2154
#
# Epoch 00059: val_loss did not improve from 1567.85496
# Epoch 60/500
# 585/585 [==============================] - 0s 77us/step - loss: 1745.1156 - mean_absolute_error: 1745.1156 - val_loss: 1628.2172 - val_mean_absolute_error: 1628.2172
#
# Epoch 00060: val_loss did not improve from 1567.85496
# Epoch 61/500
# 585/585 [==============================] - 0s 80us/step - loss: 1760.7018 - mean_absolute_error: 1760.7018 - val_loss: 1976.6390 - val_mean_absolute_error: 1976.6390
#
# Epoch 00061: val_loss did not improve from 1567.85496
# Epoch 62/500
# 585/585 [==============================] - 0s 82us/step - loss: 1809.6454 - mean_absolute_error: 1809.6454 - val_loss: 1611.9534 - val_mean_absolute_error: 1611.9534
#
# Epoch 00062: val_loss did not improve from 1567.85496
# Epoch 63/500
# 585/585 [==============================] - 0s 78us/step - loss: 1770.5057 - mean_absolute_error: 1770.5057 - val_loss: 1549.5604 - val_mean_absolute_error: 1549.5604
#
# Epoch 00063: val_loss improved from 1567.85496 to 1549.56038, saving model to GS-맥주date-Weights-063--1549.56038-cat02-vf05.hdf5
# Epoch 64/500
# 585/585 [==============================] - 0s 119us/step - loss: 1753.4717 - mean_absolute_error: 1753.4717 - val_loss: 1538.9671 - val_mean_absolute_error: 1538.9671
#
# Epoch 00064: val_loss improved from 1549.56038 to 1538.96706, saving model to GS-맥주date-Weights-064--1538.96706-cat02-vf05.hdf5
# Epoch 65/500
# 585/585 [==============================] - 0s 87us/step - loss: 1725.8931 - mean_absolute_error: 1725.8931 - val_loss: 1601.4780 - val_mean_absolute_error: 1601.4780
#
# Epoch 00065: val_loss did not improve from 1538.96706
# Epoch 66/500
# 585/585 [==============================] - 0s 72us/step - loss: 1723.5984 - mean_absolute_error: 1723.5984 - val_loss: 1628.4642 - val_mean_absolute_error: 1628.4642
#
# Epoch 00066: val_loss did not improve from 1538.96706
# Epoch 67/500
# 585/585 [==============================] - 0s 89us/step - loss: 1916.9269 - mean_absolute_error: 1916.9269 - val_loss: 1536.1735 - val_mean_absolute_error: 1536.1735
#
# Epoch 00067: val_loss improved from 1538.96706 to 1536.17355, saving model to GS-맥주date-Weights-067--1536.17355-cat02-vf05.hdf5
# Epoch 68/500
# 585/585 [==============================] - 0s 75us/step - loss: 1786.6172 - mean_absolute_error: 1786.6172 - val_loss: 1651.4082 - val_mean_absolute_error: 1651.4082
#
# Epoch 00068: val_loss did not improve from 1536.17355
# Epoch 69/500
# 585/585 [==============================] - 0s 73us/step - loss: 1714.3149 - mean_absolute_error: 1714.3149 - val_loss: 1619.1651 - val_mean_absolute_error: 1619.1651
#
# Epoch 00069: val_loss did not improve from 1536.17355
# Epoch 70/500
# 585/585 [==============================] - 0s 75us/step - loss: 1713.1479 - mean_absolute_error: 1713.1479 - val_loss: 1876.3460 - val_mean_absolute_error: 1876.3460
#
# Epoch 00070: val_loss did not improve from 1536.17355
# Epoch 71/500
# 585/585 [==============================] - 0s 73us/step - loss: 1709.3907 - mean_absolute_error: 1709.3907 - val_loss: 1557.3690 - val_mean_absolute_error: 1557.3690
#
# Epoch 00071: val_loss did not improve from 1536.17355
# Epoch 72/500
# 585/585 [==============================] - 0s 80us/step - loss: 1712.6217 - mean_absolute_error: 1712.6217 - val_loss: 1622.4055 - val_mean_absolute_error: 1622.4055
#
# Epoch 00072: val_loss did not improve from 1536.17355
# Epoch 73/500
# 585/585 [==============================] - 0s 80us/step - loss: 1759.0272 - mean_absolute_error: 1759.0272 - val_loss: 1960.8790 - val_mean_absolute_error: 1960.8790
#
# Epoch 00073: val_loss did not improve from 1536.17355
# Epoch 74/500
# 585/585 [==============================] - 0s 80us/step - loss: 1737.2968 - mean_absolute_error: 1737.2968 - val_loss: 1570.0137 - val_mean_absolute_error: 1570.0137
#
# Epoch 00074: val_loss did not improve from 1536.17355
# Epoch 75/500
# 585/585 [==============================] - 0s 78us/step - loss: 1737.1083 - mean_absolute_error: 1737.1083 - val_loss: 1605.4329 - val_mean_absolute_error: 1605.4329
#
# Epoch 00075: val_loss did not improve from 1536.17355
# Epoch 76/500
# 585/585 [==============================] - 0s 80us/step - loss: 1709.9510 - mean_absolute_error: 1709.9510 - val_loss: 1621.0387 - val_mean_absolute_error: 1621.0387
#
# Epoch 00076: val_loss did not improve from 1536.17355
# Epoch 77/500
# 585/585 [==============================] - 0s 73us/step - loss: 1700.7653 - mean_absolute_error: 1700.7653 - val_loss: 1581.9078 - val_mean_absolute_error: 1581.9078
#
# Epoch 00077: val_loss did not improve from 1536.17355
# Epoch 78/500
# 585/585 [==============================] - 0s 73us/step - loss: 1692.2380 - mean_absolute_error: 1692.2380 - val_loss: 1755.0068 - val_mean_absolute_error: 1755.0068
#
# Epoch 00078: val_loss did not improve from 1536.17355
# Epoch 79/500
# 585/585 [==============================] - 0s 84us/step - loss: 1698.5931 - mean_absolute_error: 1698.5931 - val_loss: 1552.0594 - val_mean_absolute_error: 1552.0594
#
# Epoch 00079: val_loss did not improve from 1536.17355
# Epoch 80/500
# 585/585 [==============================] - 0s 87us/step - loss: 1695.5680 - mean_absolute_error: 1695.5680 - val_loss: 1686.2054 - val_mean_absolute_error: 1686.2054
#
# Epoch 00080: val_loss did not improve from 1536.17355
# Epoch 81/500
# 585/585 [==============================] - 0s 78us/step - loss: 1759.2035 - mean_absolute_error: 1759.2035 - val_loss: 1759.3728 - val_mean_absolute_error: 1759.3728
#
# Epoch 00081: val_loss did not improve from 1536.17355
# Epoch 82/500
# 585/585 [==============================] - 0s 84us/step - loss: 1732.6843 - mean_absolute_error: 1732.6843 - val_loss: 1561.8871 - val_mean_absolute_error: 1561.8871
#
# Epoch 00082: val_loss did not improve from 1536.17355
# Epoch 83/500
# 585/585 [==============================] - 0s 90us/step - loss: 1678.8262 - mean_absolute_error: 1678.8262 - val_loss: 1708.2334 - val_mean_absolute_error: 1708.2334
#
# Epoch 00083: val_loss did not improve from 1536.17355
# Epoch 84/500
# 585/585 [==============================] - 0s 95us/step - loss: 1710.1008 - mean_absolute_error: 1710.1008 - val_loss: 1560.8730 - val_mean_absolute_error: 1560.8730
#
# Epoch 00084: val_loss did not improve from 1536.17355
# Epoch 85/500
# 585/585 [==============================] - 0s 90us/step - loss: 1711.1972 - mean_absolute_error: 1711.1972 - val_loss: 1551.0092 - val_mean_absolute_error: 1551.0092
#
# Epoch 00085: val_loss did not improve from 1536.17355
# Epoch 86/500
# 585/585 [==============================] - 0s 80us/step - loss: 1719.2363 - mean_absolute_error: 1719.2363 - val_loss: 1544.0328 - val_mean_absolute_error: 1544.0328
#
# Epoch 00086: val_loss did not improve from 1536.17355
# Epoch 87/500
# 585/585 [==============================] - 0s 82us/step - loss: 1686.3901 - mean_absolute_error: 1686.3901 - val_loss: 1570.7685 - val_mean_absolute_error: 1570.7685
#
# Epoch 00087: val_loss did not improve from 1536.17355
# Epoch 88/500
# 585/585 [==============================] - 0s 82us/step - loss: 1701.6655 - mean_absolute_error: 1701.6655 - val_loss: 1551.3513 - val_mean_absolute_error: 1551.3513
#
# Epoch 00088: val_loss did not improve from 1536.17355
# Epoch 89/500
# 585/585 [==============================] - 0s 80us/step - loss: 1743.8090 - mean_absolute_error: 1743.8090 - val_loss: 1576.5401 - val_mean_absolute_error: 1576.5401
#
# Epoch 00089: val_loss did not improve from 1536.17355
# Epoch 90/500
# 585/585 [==============================] - 0s 70us/step - loss: 1730.1313 - mean_absolute_error: 1730.1313 - val_loss: 1587.4518 - val_mean_absolute_error: 1587.4518
#
# Epoch 00090: val_loss did not improve from 1536.17355
# Epoch 91/500
# 585/585 [==============================] - 0s 75us/step - loss: 1709.7681 - mean_absolute_error: 1709.7681 - val_loss: 1659.5001 - val_mean_absolute_error: 1659.5001
#
# Epoch 00091: val_loss did not improve from 1536.17355
# Epoch 92/500
# 585/585 [==============================] - 0s 85us/step - loss: 1681.4670 - mean_absolute_error: 1681.4670 - val_loss: 1770.1517 - val_mean_absolute_error: 1770.1517
#
# Epoch 00092: val_loss did not improve from 1536.17355
# Epoch 93/500
# 585/585 [==============================] - 0s 95us/step - loss: 1712.5690 - mean_absolute_error: 1712.5690 - val_loss: 1653.5346 - val_mean_absolute_error: 1653.5346
#
# Epoch 00093: val_loss did not improve from 1536.17355
# Epoch 94/500
# 585/585 [==============================] - 0s 92us/step - loss: 1698.5936 - mean_absolute_error: 1698.5936 - val_loss: 1508.7475 - val_mean_absolute_error: 1508.7475
#
# Epoch 00094: val_loss improved from 1536.17355 to 1508.74745, saving model to GS-맥주date-Weights-094--1508.74745-cat02-vf05.hdf5
# Epoch 95/500
# 585/585 [==============================] - 0s 82us/step - loss: 1684.2605 - mean_absolute_error: 1684.2605 - val_loss: 1525.0124 - val_mean_absolute_error: 1525.0124
#
# Epoch 00095: val_loss did not improve from 1508.74745
# Epoch 96/500
# 585/585 [==============================] - 0s 95us/step - loss: 1733.9651 - mean_absolute_error: 1733.9651 - val_loss: 1532.9034 - val_mean_absolute_error: 1532.9034
#
# Epoch 00096: val_loss did not improve from 1508.74745
# Epoch 97/500
# 585/585 [==============================] - 0s 82us/step - loss: 1669.6417 - mean_absolute_error: 1669.6417 - val_loss: 1576.3976 - val_mean_absolute_error: 1576.3976
#
# Epoch 00097: val_loss did not improve from 1508.74745
# Epoch 98/500
# 585/585 [==============================] - 0s 75us/step - loss: 1661.8924 - mean_absolute_error: 1661.8924 - val_loss: 1537.5686 - val_mean_absolute_error: 1537.5686
#
# Epoch 00098: val_loss did not improve from 1508.74745
# Epoch 99/500
# 585/585 [==============================] - 0s 78us/step - loss: 1681.8651 - mean_absolute_error: 1681.8651 - val_loss: 1536.0556 - val_mean_absolute_error: 1536.0556
#
# Epoch 00099: val_loss did not improve from 1508.74745
# Epoch 100/500
# 585/585 [==============================] - 0s 77us/step - loss: 1691.4281 - mean_absolute_error: 1691.4281 - val_loss: 1715.6680 - val_mean_absolute_error: 1715.6680
#
# Epoch 00100: val_loss did not improve from 1508.74745
# Epoch 101/500
# 585/585 [==============================] - 0s 73us/step - loss: 1732.1573 - mean_absolute_error: 1732.1573 - val_loss: 1790.7026 - val_mean_absolute_error: 1790.7026
#
# Epoch 00101: val_loss did not improve from 1508.74745
# Epoch 102/500
# 585/585 [==============================] - 0s 77us/step - loss: 1719.4996 - mean_absolute_error: 1719.4996 - val_loss: 1640.3711 - val_mean_absolute_error: 1640.3711
#
# Epoch 00102: val_loss did not improve from 1508.74745
# Epoch 103/500
# 585/585 [==============================] - 0s 94us/step - loss: 1677.6749 - mean_absolute_error: 1677.6749 - val_loss: 1543.7782 - val_mean_absolute_error: 1543.7782
#
# Epoch 00103: val_loss did not improve from 1508.74745
# Epoch 104/500
# 585/585 [==============================] - 0s 82us/step - loss: 1688.2930 - mean_absolute_error: 1688.2930 - val_loss: 1565.8436 - val_mean_absolute_error: 1565.8436
#
# Epoch 00104: val_loss did not improve from 1508.74745
# Epoch 105/500
# 585/585 [==============================] - 0s 85us/step - loss: 1679.7959 - mean_absolute_error: 1679.7959 - val_loss: 1564.3582 - val_mean_absolute_error: 1564.3582
#
# Epoch 00105: val_loss did not improve from 1508.74745
# Epoch 106/500
# 585/585 [==============================] - 0s 80us/step - loss: 1656.1819 - mean_absolute_error: 1656.1819 - val_loss: 1535.7858 - val_mean_absolute_error: 1535.7858
#
# Epoch 00106: val_loss did not improve from 1508.74745
# Epoch 107/500
# 585/585 [==============================] - 0s 82us/step - loss: 1680.8443 - mean_absolute_error: 1680.8443 - val_loss: 1672.1525 - val_mean_absolute_error: 1672.1525
#
# Epoch 00107: val_loss did not improve from 1508.74745
# Epoch 108/500
# 585/585 [==============================] - 0s 80us/step - loss: 1733.9772 - mean_absolute_error: 1733.9772 - val_loss: 1710.8579 - val_mean_absolute_error: 1710.8579
#
# Epoch 00108: val_loss did not improve from 1508.74745
# Epoch 109/500
# 585/585 [==============================] - 0s 80us/step - loss: 1676.4849 - mean_absolute_error: 1676.4849 - val_loss: 1540.1577 - val_mean_absolute_error: 1540.1577
#
# Epoch 00109: val_loss did not improve from 1508.74745
# Epoch 110/500
# 585/585 [==============================] - 0s 77us/step - loss: 1657.7068 - mean_absolute_error: 1657.7068 - val_loss: 1608.6620 - val_mean_absolute_error: 1608.6620
#
# Epoch 00110: val_loss did not improve from 1508.74745
# Epoch 111/500
# 585/585 [==============================] - 0s 81us/step - loss: 1656.9892 - mean_absolute_error: 1656.9892 - val_loss: 1601.1961 - val_mean_absolute_error: 1601.1961
#
# Epoch 00111: val_loss did not improve from 1508.74745
# Epoch 112/500
# 585/585 [==============================] - 0s 77us/step - loss: 1668.4189 - mean_absolute_error: 1668.4189 - val_loss: 1647.4502 - val_mean_absolute_error: 1647.4502
#
# Epoch 00112: val_loss did not improve from 1508.74745
# Epoch 113/500
# 585/585 [==============================] - 0s 81us/step - loss: 1653.1881 - mean_absolute_error: 1653.1881 - val_loss: 1538.7189 - val_mean_absolute_error: 1538.7189
#
# Epoch 00113: val_loss did not improve from 1508.74745
# Epoch 114/500
# 585/585 [==============================] - 0s 101us/step - loss: 1657.5030 - mean_absolute_error: 1657.5030 - val_loss: 1542.8746 - val_mean_absolute_error: 1542.8746
#
# Epoch 00114: val_loss did not improve from 1508.74745
# Epoch 115/500
# 585/585 [==============================] - 0s 84us/step - loss: 1671.6616 - mean_absolute_error: 1671.6616 - val_loss: 1553.9525 - val_mean_absolute_error: 1553.9525
#
# Epoch 00115: val_loss did not improve from 1508.74745
# Epoch 116/500
# 585/585 [==============================] - 0s 77us/step - loss: 1670.3856 - mean_absolute_error: 1670.3856 - val_loss: 1698.1028 - val_mean_absolute_error: 1698.1028
#
# Epoch 00116: val_loss did not improve from 1508.74745
# Epoch 117/500
# 585/585 [==============================] - 0s 82us/step - loss: 1668.1185 - mean_absolute_error: 1668.1185 - val_loss: 1580.0652 - val_mean_absolute_error: 1580.0652
#
# Epoch 00117: val_loss did not improve from 1508.74745
# Epoch 118/500
# 585/585 [==============================] - 0s 78us/step - loss: 1707.5996 - mean_absolute_error: 1707.5996 - val_loss: 1765.3442 - val_mean_absolute_error: 1765.3442
#
# Epoch 00118: val_loss did not improve from 1508.74745
# Epoch 119/500
# 585/585 [==============================] - 0s 75us/step - loss: 1708.5683 - mean_absolute_error: 1708.5683 - val_loss: 1792.3288 - val_mean_absolute_error: 1792.3288
#
# Epoch 00119: val_loss did not improve from 1508.74745
# Epoch 120/500
# 585/585 [==============================] - 0s 73us/step - loss: 1727.2939 - mean_absolute_error: 1727.2939 - val_loss: 1539.1277 - val_mean_absolute_error: 1539.1277
#
# Epoch 00120: val_loss did not improve from 1508.74745
# Epoch 121/500
# 585/585 [==============================] - 0s 78us/step - loss: 1713.0863 - mean_absolute_error: 1713.0863 - val_loss: 1533.3806 - val_mean_absolute_error: 1533.3806
#
# Epoch 00121: val_loss did not improve from 1508.74745
# Epoch 122/500
# 585/585 [==============================] - 0s 75us/step - loss: 1737.5724 - mean_absolute_error: 1737.5724 - val_loss: 1603.0105 - val_mean_absolute_error: 1603.0105
#
# Epoch 00122: val_loss did not improve from 1508.74745
# Epoch 123/500
# 585/585 [==============================] - 0s 72us/step - loss: 1649.3615 - mean_absolute_error: 1649.3615 - val_loss: 1687.8170 - val_mean_absolute_error: 1687.8170
#
# Epoch 00123: val_loss did not improve from 1508.74745
# Epoch 124/500
# 585/585 [==============================] - 0s 84us/step - loss: 1660.7385 - mean_absolute_error: 1660.7385 - val_loss: 1649.0616 - val_mean_absolute_error: 1649.0616
#
# Epoch 00124: val_loss did not improve from 1508.74745
# Epoch 125/500
# 585/585 [==============================] - 0s 82us/step - loss: 1679.1460 - mean_absolute_error: 1679.1460 - val_loss: 1503.9466 - val_mean_absolute_error: 1503.9466
#
# Epoch 00125: val_loss improved from 1508.74745 to 1503.94658, saving model to GS-맥주date-Weights-125--1503.94658-cat02-vf05.hdf5
# Epoch 126/500
# 585/585 [==============================] - 0s 78us/step - loss: 1649.3361 - mean_absolute_error: 1649.3361 - val_loss: 1608.7972 - val_mean_absolute_error: 1608.7972
#
# Epoch 00126: val_loss did not improve from 1503.94658
# Epoch 127/500
# 585/585 [==============================] - 0s 85us/step - loss: 1681.2778 - mean_absolute_error: 1681.2778 - val_loss: 1545.4626 - val_mean_absolute_error: 1545.4626
#
# Epoch 00127: val_loss did not improve from 1503.94658
# Epoch 128/500
# 585/585 [==============================] - 0s 85us/step - loss: 1662.2942 - mean_absolute_error: 1662.2942 - val_loss: 1591.1060 - val_mean_absolute_error: 1591.1060
#
# Epoch 00128: val_loss did not improve from 1503.94658
# Epoch 129/500
# 585/585 [==============================] - 0s 80us/step - loss: 1652.2414 - mean_absolute_error: 1652.2414 - val_loss: 1638.0699 - val_mean_absolute_error: 1638.0699
#
# Epoch 00129: val_loss did not improve from 1503.94658
# Epoch 130/500
# 585/585 [==============================] - 0s 95us/step - loss: 1660.0942 - mean_absolute_error: 1660.0942 - val_loss: 1485.3399 - val_mean_absolute_error: 1485.3399
#
# Epoch 00130: val_loss improved from 1503.94658 to 1485.33989, saving model to GS-맥주date-Weights-130--1485.33989-cat02-vf05.hdf5
# Epoch 131/500
# 585/585 [==============================] - 0s 77us/step - loss: 1652.9789 - mean_absolute_error: 1652.9789 - val_loss: 1507.5179 - val_mean_absolute_error: 1507.5179
#
# Epoch 00131: val_loss did not improve from 1485.33989
# Epoch 132/500
# 585/585 [==============================] - 0s 82us/step - loss: 1660.5354 - mean_absolute_error: 1660.5354 - val_loss: 1533.3183 - val_mean_absolute_error: 1533.3183
#
# Epoch 00132: val_loss did not improve from 1485.33989
# Epoch 133/500
# 585/585 [==============================] - 0s 84us/step - loss: 1667.3445 - mean_absolute_error: 1667.3445 - val_loss: 1537.0613 - val_mean_absolute_error: 1537.0613
#
# Epoch 00133: val_loss did not improve from 1485.33989
# Epoch 134/500
# 585/585 [==============================] - 0s 75us/step - loss: 1662.5815 - mean_absolute_error: 1662.5815 - val_loss: 1564.6174 - val_mean_absolute_error: 1564.6174
#
# Epoch 00134: val_loss did not improve from 1485.33989
# Epoch 135/500
# 585/585 [==============================] - 0s 82us/step - loss: 1628.7832 - mean_absolute_error: 1628.7832 - val_loss: 1529.1325 - val_mean_absolute_error: 1529.1325
#
# Epoch 00135: val_loss did not improve from 1485.33989
# Epoch 136/500
# 585/585 [==============================] - 0s 82us/step - loss: 1643.2043 - mean_absolute_error: 1643.2043 - val_loss: 1540.1449 - val_mean_absolute_error: 1540.1449
#
# Epoch 00136: val_loss did not improve from 1485.33989
# Epoch 137/500
# 585/585 [==============================] - 0s 73us/step - loss: 1640.4979 - mean_absolute_error: 1640.4979 - val_loss: 1528.7558 - val_mean_absolute_error: 1528.7558
#
# Epoch 00137: val_loss did not improve from 1485.33989
# Epoch 138/500
# 585/585 [==============================] - 0s 73us/step - loss: 1633.1970 - mean_absolute_error: 1633.1970 - val_loss: 1571.5062 - val_mean_absolute_error: 1571.5062
#
# Epoch 00138: val_loss did not improve from 1485.33989
# Epoch 139/500
# 585/585 [==============================] - 0s 77us/step - loss: 1696.3330 - mean_absolute_error: 1696.3330 - val_loss: 1777.0999 - val_mean_absolute_error: 1777.0999
#
# Epoch 00139: val_loss did not improve from 1485.33989
# Epoch 140/500
# 585/585 [==============================] - 0s 82us/step - loss: 1692.7241 - mean_absolute_error: 1692.7241 - val_loss: 1546.3350 - val_mean_absolute_error: 1546.3350
#
# Epoch 00140: val_loss did not improve from 1485.33989
# Epoch 141/500
# 585/585 [==============================] - 0s 79us/step - loss: 1658.1365 - mean_absolute_error: 1658.1365 - val_loss: 1623.8528 - val_mean_absolute_error: 1623.8528
#
# Epoch 00141: val_loss did not improve from 1485.33989
# Epoch 142/500
# 585/585 [==============================] - 0s 78us/step - loss: 1702.7580 - mean_absolute_error: 1702.7580 - val_loss: 1642.2111 - val_mean_absolute_error: 1642.2111
#
# Epoch 00142: val_loss did not improve from 1485.33989
# Epoch 143/500
# 585/585 [==============================] - ETA: 0s - loss: 1337.7985 - mean_absolute_error: 1337.798 - 0s 79us/step - loss: 1669.3694 - mean_absolute_error: 1669.3694 - val_loss: 1568.3794 - val_mean_absolute_error: 1568.3794
#
# Epoch 00143: val_loss did not improve from 1485.33989
# Epoch 144/500
# 585/585 [==============================] - 0s 82us/step - loss: 1642.8091 - mean_absolute_error: 1642.8091 - val_loss: 1574.1784 - val_mean_absolute_error: 1574.1784
#
# Epoch 00144: val_loss did not improve from 1485.33989
# Epoch 145/500
# 585/585 [==============================] - 0s 80us/step - loss: 1657.6779 - mean_absolute_error: 1657.6779 - val_loss: 1732.5571 - val_mean_absolute_error: 1732.5571
#
# Epoch 00145: val_loss did not improve from 1485.33989
# Epoch 146/500
# 585/585 [==============================] - 0s 77us/step - loss: 1716.9216 - mean_absolute_error: 1716.9216 - val_loss: 1866.6968 - val_mean_absolute_error: 1866.6968
#
# Epoch 00146: val_loss did not improve from 1485.33989
# Epoch 147/500
# 585/585 [==============================] - 0s 78us/step - loss: 1684.7806 - mean_absolute_error: 1684.7806 - val_loss: 1583.3888 - val_mean_absolute_error: 1583.3888
#
# Epoch 00147: val_loss did not improve from 1485.33989
# Epoch 148/500
# 585/585 [==============================] - 0s 79us/step - loss: 1622.1896 - mean_absolute_error: 1622.1896 - val_loss: 1585.7268 - val_mean_absolute_error: 1585.7268
#
# Epoch 00148: val_loss did not improve from 1485.33989
# Epoch 149/500
# 585/585 [==============================] - 0s 78us/step - loss: 1668.2851 - mean_absolute_error: 1668.2851 - val_loss: 1648.6719 - val_mean_absolute_error: 1648.6719
#
# Epoch 00149: val_loss did not improve from 1485.33989
# Epoch 150/500
# 585/585 [==============================] - 0s 80us/step - loss: 1714.7756 - mean_absolute_error: 1714.7756 - val_loss: 1704.3830 - val_mean_absolute_error: 1704.3830
#
# Epoch 00150: val_loss did not improve from 1485.33989
# Epoch 151/500
# 585/585 [==============================] - 0s 82us/step - loss: 1620.8431 - mean_absolute_error: 1620.8431 - val_loss: 1552.2067 - val_mean_absolute_error: 1552.2067
#
# Epoch 00151: val_loss did not improve from 1485.33989
# Epoch 152/500
# 585/585 [==============================] - 0s 82us/step - loss: 1670.3182 - mean_absolute_error: 1670.3182 - val_loss: 1542.0482 - val_mean_absolute_error: 1542.0482
#
# Epoch 00152: val_loss did not improve from 1485.33989
# Epoch 153/500
# 585/585 [==============================] - 0s 77us/step - loss: 1650.4501 - mean_absolute_error: 1650.4501 - val_loss: 1609.6834 - val_mean_absolute_error: 1609.6834
#
# Epoch 00153: val_loss did not improve from 1485.33989
# Epoch 154/500
# 585/585 [==============================] - 0s 80us/step - loss: 1631.3058 - mean_absolute_error: 1631.3058 - val_loss: 1562.2033 - val_mean_absolute_error: 1562.2033
#
# Epoch 00154: val_loss did not improve from 1485.33989
# Epoch 155/500
# 585/585 [==============================] - 0s 94us/step - loss: 1627.1781 - mean_absolute_error: 1627.1781 - val_loss: 1508.5933 - val_mean_absolute_error: 1508.5933
#
# Epoch 00155: val_loss did not improve from 1485.33989
# Epoch 156/500
# 585/585 [==============================] - 0s 126us/step - loss: 1635.8129 - mean_absolute_error: 1635.8129 - val_loss: 1516.0851 - val_mean_absolute_error: 1516.0851
#
# Epoch 00156: val_loss did not improve from 1485.33989
# Epoch 157/500
# 585/585 [==============================] - 0s 85us/step - loss: 1605.5952 - mean_absolute_error: 1605.5952 - val_loss: 1626.2784 - val_mean_absolute_error: 1626.2784
#
# Epoch 00157: val_loss did not improve from 1485.33989
# Epoch 158/500
# 585/585 [==============================] - 0s 90us/step - loss: 1626.5863 - mean_absolute_error: 1626.5863 - val_loss: 1582.3646 - val_mean_absolute_error: 1582.3646
#
# Epoch 00158: val_loss did not improve from 1485.33989
# Epoch 159/500
# 585/585 [==============================] - 0s 78us/step - loss: 1621.2289 - mean_absolute_error: 1621.2289 - val_loss: 1560.0143 - val_mean_absolute_error: 1560.0143
#
# Epoch 00159: val_loss did not improve from 1485.33989
# Epoch 160/500
# 585/585 [==============================] - 0s 75us/step - loss: 1640.9976 - mean_absolute_error: 1640.9976 - val_loss: 1615.3992 - val_mean_absolute_error: 1615.3992
#
# Epoch 00160: val_loss did not improve from 1485.33989
# Epoch 161/500
# 585/585 [==============================] - 0s 72us/step - loss: 1632.1672 - mean_absolute_error: 1632.1672 - val_loss: 1557.2860 - val_mean_absolute_error: 1557.2860
#
# Epoch 00161: val_loss did not improve from 1485.33989
# Epoch 162/500
# 585/585 [==============================] - 0s 84us/step - loss: 1631.7840 - mean_absolute_error: 1631.7840 - val_loss: 1556.4492 - val_mean_absolute_error: 1556.4492
#
# Epoch 00162: val_loss did not improve from 1485.33989
# Epoch 163/500
# 585/585 [==============================] - 0s 84us/step - loss: 1632.5512 - mean_absolute_error: 1632.5512 - val_loss: 1583.8012 - val_mean_absolute_error: 1583.8012
#
# Epoch 00163: val_loss did not improve from 1485.33989
# Epoch 164/500
# 585/585 [==============================] - 0s 87us/step - loss: 1642.4143 - mean_absolute_error: 1642.4143 - val_loss: 1547.6773 - val_mean_absolute_error: 1547.6773
#
# Epoch 00164: val_loss did not improve from 1485.33989
# Epoch 165/500
# 585/585 [==============================] - 0s 85us/step - loss: 1614.0459 - mean_absolute_error: 1614.0459 - val_loss: 1511.8623 - val_mean_absolute_error: 1511.8623
#
# Epoch 00165: val_loss did not improve from 1485.33989
# Epoch 166/500
# 585/585 [==============================] - 0s 80us/step - loss: 1619.2856 - mean_absolute_error: 1619.2856 - val_loss: 1596.1307 - val_mean_absolute_error: 1596.1307
#
# Epoch 00166: val_loss did not improve from 1485.33989
# Epoch 167/500
# 585/585 [==============================] - 0s 77us/step - loss: 1613.1467 - mean_absolute_error: 1613.1467 - val_loss: 1557.7093 - val_mean_absolute_error: 1557.7093
#
# Epoch 00167: val_loss did not improve from 1485.33989
# Epoch 168/500
# 585/585 [==============================] - 0s 89us/step - loss: 1614.8226 - mean_absolute_error: 1614.8226 - val_loss: 1661.5312 - val_mean_absolute_error: 1661.5312
# Epoch 00168: val_loss did not improve from 1485.33989
# Epoch 169/500
# 585/585 [==============================] - 0s 80us/step - loss: 1611.5976 - mean_absolute_error: 1611.5976 - val_loss: 1681.0016 - val_mean_absolute_error: 1681.0016
#
# Epoch 00169: val_loss did not improve from 1485.33989
# Epoch 170/500
# 585/585 [==============================] - 0s 80us/step - loss: 1621.2315 - mean_absolute_error: 1621.2315 - val_loss: 1523.3766 - val_mean_absolute_error: 1523.3766
#
# Epoch 00170: val_loss did not improve from 1485.33989
# Epoch 171/500
# 585/585 [==============================] - 0s 78us/step - loss: 1607.5534 - mean_absolute_error: 1607.5534 - val_loss: 1517.9988 - val_mean_absolute_error: 1517.9988
#
# Epoch 00171: val_loss did not improve from 1485.33989
# Epoch 172/500
# 585/585 [==============================] - 0s 84us/step - loss: 1625.4965 - mean_absolute_error: 1625.4965 - val_loss: 1578.4446 - val_mean_absolute_error: 1578.4446
#
# Epoch 00172: val_loss did not improve from 1485.33989
# Epoch 173/500
# 585/585 [==============================] - 0s 82us/step - loss: 1601.9018 - mean_absolute_error: 1601.9018 - val_loss: 1556.8151 - val_mean_absolute_error: 1556.8151
#
# Epoch 00173: val_loss did not improve from 1485.33989
# Epoch 174/500
# 585/585 [==============================] - 0s 82us/step - loss: 1607.9853 - mean_absolute_error: 1607.9853 - val_loss: 1536.6780 - val_mean_absolute_error: 1536.6780
#
# Epoch 00174: val_loss did not improve from 1485.33989
# Epoch 175/500
# 585/585 [==============================] - 0s 87us/step - loss: 1604.9423 - mean_absolute_error: 1604.9423 - val_loss: 1575.2204 - val_mean_absolute_error: 1575.2204
#
# Epoch 00175: val_loss did not improve from 1485.33989
# Epoch 176/500
# 585/585 [==============================] - 0s 82us/step - loss: 1627.3798 - mean_absolute_error: 1627.3798 - val_loss: 1773.3103 - val_mean_absolute_error: 1773.3103
#
# Epoch 00176: val_loss did not improve from 1485.33989
# Epoch 177/500
# 585/585 [==============================] - 0s 89us/step - loss: 1617.4894 - mean_absolute_error: 1617.4894 - val_loss: 1609.0974 - val_mean_absolute_error: 1609.0974
#
# Epoch 00177: val_loss did not improve from 1485.33989
# Epoch 178/500
# 585/585 [==============================] - 0s 83us/step - loss: 1653.8537 - mean_absolute_error: 1653.8537 - val_loss: 1601.5110 - val_mean_absolute_error: 1601.5110
#
# Epoch 00178: val_loss did not improve from 1485.33989
# Epoch 179/500
# 585/585 [==============================] - 0s 78us/step - loss: 1613.4094 - mean_absolute_error: 1613.4094 - val_loss: 1591.8579 - val_mean_absolute_error: 1591.8579
#
# Epoch 00179: val_loss did not improve from 1485.33989
# Epoch 180/500
# 585/585 [==============================] - 0s 84us/step - loss: 1597.4481 - mean_absolute_error: 1597.4481 - val_loss: 1617.3133 - val_mean_absolute_error: 1617.3133
#
# Epoch 00180: val_loss did not improve from 1485.33989
# Epoch 181/500
# 585/585 [==============================] - 0s 85us/step - loss: 1620.6144 - mean_absolute_error: 1620.6144 - val_loss: 1500.6990 - val_mean_absolute_error: 1500.6990
#
# Epoch 00181: val_loss did not improve from 1485.33989
# Epoch 182/500
# 585/585 [==============================] - 0s 87us/step - loss: 1607.3202 - mean_absolute_error: 1607.3202 - val_loss: 1538.3708 - val_mean_absolute_error: 1538.3708
#
# Epoch 00182: val_loss did not improve from 1485.33989
# Epoch 183/500
# 585/585 [==============================] - 0s 89us/step - loss: 1737.3540 - mean_absolute_error: 1737.3540 - val_loss: 1561.7243 - val_mean_absolute_error: 1561.7243
#
# Epoch 00183: val_loss did not improve from 1485.33989
# Epoch 184/500
# 585/585 [==============================] - 0s 78us/step - loss: 1628.4410 - mean_absolute_error: 1628.4410 - val_loss: 1591.2307 - val_mean_absolute_error: 1591.2307
#
# Epoch 00184: val_loss did not improve from 1485.33989
# Epoch 185/500
# 585/585 [==============================] - 0s 80us/step - loss: 1616.2711 - mean_absolute_error: 1616.2711 - val_loss: 1679.7070 - val_mean_absolute_error: 1679.7070
#
# Epoch 00185: val_loss did not improve from 1485.33989
# Epoch 186/500
# 585/585 [==============================] - 0s 84us/step - loss: 1673.0536 - mean_absolute_error: 1673.0536 - val_loss: 1513.4858 - val_mean_absolute_error: 1513.4858
#
# Epoch 00186: val_loss did not improve from 1485.33989
# Epoch 187/500
# 585/585 [==============================] - 0s 89us/step - loss: 1608.3087 - mean_absolute_error: 1608.3087 - val_loss: 1616.6170 - val_mean_absolute_error: 1616.6170
#
# Epoch 00187: val_loss did not improve from 1485.33989
# Epoch 188/500
# 585/585 [==============================] - 0s 80us/step - loss: 1619.4963 - mean_absolute_error: 1619.4963 - val_loss: 1604.2412 - val_mean_absolute_error: 1604.2412
#
# Epoch 00188: val_loss did not improve from 1485.33989
# Epoch 189/500
# 585/585 [==============================] - 0s 87us/step - loss: 1617.4283 - mean_absolute_error: 1617.4283 - val_loss: 1661.1933 - val_mean_absolute_error: 1661.1933
#
# Epoch 00189: val_loss did not improve from 1485.33989
# Epoch 190/500
# 585/585 [==============================] - 0s 90us/step - loss: 1635.6086 - mean_absolute_error: 1635.6086 - val_loss: 1596.8290 - val_mean_absolute_error: 1596.8290
#
# Epoch 00190: val_loss did not improve from 1485.33989
# Epoch 191/500
# 585/585 [==============================] - 0s 89us/step - loss: 1601.9491 - mean_absolute_error: 1601.9491 - val_loss: 1651.7478 - val_mean_absolute_error: 1651.7478
#
# Epoch 00191: val_loss did not improve from 1485.33989
# Epoch 192/500
# 585/585 [==============================] - 0s 89us/step - loss: 1597.8051 - mean_absolute_error: 1597.8051 - val_loss: 1541.5344 - val_mean_absolute_error: 1541.5344
#
# Epoch 00192: val_loss did not improve from 1485.33989
# Epoch 193/500
# 585/585 [==============================] - 0s 84us/step - loss: 1648.6691 - mean_absolute_error: 1648.6691 - val_loss: 1515.0308 - val_mean_absolute_error: 1515.0308
#
# Epoch 00193: val_loss did not improve from 1485.33989
# Epoch 194/500
# 585/585 [==============================] - 0s 82us/step - loss: 1599.4026 - mean_absolute_error: 1599.4026 - val_loss: 1607.1882 - val_mean_absolute_error: 1607.1882
#
# Epoch 00194: val_loss did not improve from 1485.33989
# Epoch 195/500
# 585/585 [==============================] - 0s 82us/step - loss: 1581.1348 - mean_absolute_error: 1581.1348 - val_loss: 1594.4990 - val_mean_absolute_error: 1594.4990
#
# Epoch 00195: val_loss did not improve from 1485.33989
# Epoch 196/500
# 585/585 [==============================] - 0s 82us/step - loss: 1586.2252 - mean_absolute_error: 1586.2252 - val_loss: 1662.3114 - val_mean_absolute_error: 1662.3114
#
# Epoch 00196: val_loss did not improve from 1485.33989
# Epoch 197/500
# ...
#
# Epoch 00433: val_loss did not improve from 1391.87220
# Epoch 434/500
# 585/585 [==============================] - 0s 133us/step - loss: 1507.5412 - mean_absolute_error: 1507.5412 - val_loss: 1481.5739 - val_mean_absolute_error: 1481.5739
#
# Epoch 00434: val_loss did not improve from 1391.87220
# Epoch 435/500
# 585/585 [==============================] - 0s 143us/step - loss: 1444.7727 - mean_absolute_error: 1444.7727 - val_loss: 1528.7793 - val_mean_absolute_error: 1528.7793
#
# Epoch 00435: val_loss did not improve from 1391.87220
# Epoch 436/500
# 585/585 [==============================] - 0s 138us/step - loss: 1444.7974 - mean_absolute_error: 1444.7974 - val_loss: 1507.9608 - val_mean_absolute_error: 1507.9608
#
# Epoch 00436: val_loss did not improve from 1391.87220
# Epoch 437/500
# 585/585 [==============================] - 0s 136us/step - loss: 1426.4441 - mean_absolute_error: 1426.4441 - val_loss: 1421.9560 - val_mean_absolute_error: 1421.9560
#
# Epoch 00437: val_loss did not improve from 1391.87220
# Epoch 438/500
# 585/585 [==============================] - 0s 140us/step - loss: 1433.7529 - mean_absolute_error: 1433.7529 - val_loss: 1522.7397 - val_mean_absolute_error: 1522.7397
#
# Epoch 00438: val_loss did not improve from 1391.87220
# Epoch 439/500
# 585/585 [==============================] - 0s 128us/step - loss: 1439.1667 - mean_absolute_error: 1439.1667 - val_loss: 1468.0910 - val_mean_absolute_error: 1468.0910
#
# Epoch 00439: val_loss did not improve from 1391.87220
# Epoch 440/500
# 585/585 [==============================] - 0s 126us/step - loss: 1471.1398 - mean_absolute_error: 1471.1398 - val_loss: 1482.8610 - val_mean_absolute_error: 1482.8610
#
# Epoch 00440: val_loss did not improve from 1391.87220
# Epoch 441/500
# 585/585 [==============================] - 0s 148us/step - loss: 1423.6543 - mean_absolute_error: 1423.6543 - val_loss: 1454.6442 - val_mean_absolute_error: 1454.6442
#
# Epoch 00441: val_loss did not improve from 1391.87220
# Epoch 442/500
# 585/585 [==============================] - 0s 162us/step - loss: 1453.5027 - mean_absolute_error: 1453.5027 - val_loss: 1493.8980 - val_mean_absolute_error: 1493.8980
#
# Epoch 00442: val_loss did not improve from 1391.87220
# Epoch 443/500
# 585/585 [==============================] - 0s 147us/step - loss: 1456.6242 - mean_absolute_error: 1456.6242 - val_loss: 1528.5847 - val_mean_absolute_error: 1528.5847
#
# Epoch 00443: val_loss did not improve from 1391.87220
# Epoch 444/500
# 585/585 [==============================] - 0s 151us/step - loss: 1462.6023 - mean_absolute_error: 1462.6023 - val_loss: 1483.0676 - val_mean_absolute_error: 1483.0676
#
# Epoch 00444: val_loss did not improve from 1391.87220
# Epoch 445/500
# 585/585 [==============================] - 0s 122us/step - loss: 1429.3511 - mean_absolute_error: 1429.3511 - val_loss: 1471.2602 - val_mean_absolute_error: 1471.2602
#
# Epoch 00445: val_loss did not improve from 1391.87220
# Epoch 446/500
# 585/585 [==============================] - 0s 127us/step - loss: 1447.4564 - mean_absolute_error: 1447.4564 - val_loss: 1425.8561 - val_mean_absolute_error: 1425.8561
#
# Epoch 00446: val_loss did not improve from 1391.87220
# Epoch 447/500
# 585/585 [==============================] - 0s 143us/step - loss: 1474.1700 - mean_absolute_error: 1474.1700 - val_loss: 1517.3136 - val_mean_absolute_error: 1517.3136
#
# Epoch 00447: val_loss did not improve from 1391.87220
# Epoch 448/500
# 585/585 [==============================] - 0s 203us/step - loss: 1420.6098 - mean_absolute_error: 1420.6098 - val_loss: 1673.7107 - val_mean_absolute_error: 1673.7107
#
# Epoch 00448: val_loss did not improve from 1391.87220
# Epoch 449/500
# 585/585 [==============================] - 0s 170us/step - loss: 1457.3018 - mean_absolute_error: 1457.3018 - val_loss: 1466.8902 - val_mean_absolute_error: 1466.8902
#
# Epoch 00449: val_loss did not improve from 1391.87220
# Epoch 450/500
# 585/585 [==============================] - 0s 142us/step - loss: 1463.1068 - mean_absolute_error: 1463.1068 - val_loss: 1485.0565 - val_mean_absolute_error: 1485.0565
#
# Epoch 00450: val_loss did not improve from 1391.87220
# Epoch 451/500
# 585/585 [==============================] - 0s 136us/step - loss: 1474.4901 - mean_absolute_error: 1474.4901 - val_loss: 1453.9101 - val_mean_absolute_error: 1453.9101
#
# Epoch 00451: val_loss did not improve from 1391.87220
# Epoch 452/500
# 585/585 [==============================] - 0s 136us/step - loss: 1443.1759 - mean_absolute_error: 1443.1759 - val_loss: 1512.8581 - val_mean_absolute_error: 1512.8581
#
# Epoch 00452: val_loss did not improve from 1391.87220
# Epoch 453/500
# 585/585 [==============================] - 0s 153us/step - loss: 1435.7798 - mean_absolute_error: 1435.7798 - val_loss: 1478.1190 - val_mean_absolute_error: 1478.1190
#
# Epoch 00453: val_loss did not improve from 1391.87220
# Epoch 454/500
# 585/585 [==============================] - 0s 208us/step - loss: 1453.2521 - mean_absolute_error: 1453.2521 - val_loss: 1505.1235 - val_mean_absolute_error: 1505.1235
#
# Epoch 00454: val_loss did not improve from 1391.87220
# Epoch 455/500
# 585/585 [==============================] - 0s 145us/step - loss: 1497.8202 - mean_absolute_error: 1497.8202 - val_loss: 1570.4743 - val_mean_absolute_error: 1570.4743
#
# Epoch 00455: val_loss did not improve from 1391.87220
# Epoch 456/500
# 585/585 [==============================] - 0s 139us/step - loss: 1467.8654 - mean_absolute_error: 1467.8654 - val_loss: 1469.3711 - val_mean_absolute_error: 1469.3711
#
# Epoch 00456: val_loss did not improve from 1391.87220
# Epoch 457/500
# 585/585 [==============================] - 0s 128us/step - loss: 1430.1930 - mean_absolute_error: 1430.1930 - val_loss: 1468.3308 - val_mean_absolute_error: 1468.3308
#
# Epoch 00457: val_loss did not improve from 1391.87220
# Epoch 458/500
# 585/585 [==============================] - 0s 181us/step - loss: 1493.7055 - mean_absolute_error: 1493.7055 - val_loss: 1541.7077 - val_mean_absolute_error: 1541.7077
#
# Epoch 00458: val_loss did not improve from 1391.87220
# Epoch 459/500
# 585/585 [==============================] - 0s 160us/step - loss: 1470.8018 - mean_absolute_error: 1470.8018 - val_loss: 1440.9057 - val_mean_absolute_error: 1440.9057
#
# Epoch 00459: val_loss did not improve from 1391.87220
# Epoch 460/500
# 585/585 [==============================] - 0s 133us/step - loss: 1412.5805 - mean_absolute_error: 1412.5805 - val_loss: 1478.2947 - val_mean_absolute_error: 1478.2947
#
# Epoch 00460: val_loss did not improve from 1391.87220
# Epoch 461/500
# 585/585 [==============================] - 0s 133us/step - loss: 1442.8563 - mean_absolute_error: 1442.8563 - val_loss: 1487.1460 - val_mean_absolute_error: 1487.1460
#
# Epoch 00461: val_loss did not improve from 1391.87220
# Epoch 462/500
# 585/585 [==============================] - 0s 156us/step - loss: 1427.3995 - mean_absolute_error: 1427.3995 - val_loss: 1509.2274 - val_mean_absolute_error: 1509.2274
#
# Epoch 00462: val_loss did not improve from 1391.87220
# Epoch 463/500
# 585/585 [==============================] - 0s 130us/step - loss: 1420.7707 - mean_absolute_error: 1420.7707 - val_loss: 1549.5307 - val_mean_absolute_error: 1549.5307
#
# Epoch 00463: val_loss did not improve from 1391.87220
# Epoch 464/500
# 585/585 [==============================] - 0s 146us/step - loss: 1425.0439 - mean_absolute_error: 1425.0439 - val_loss: 1503.3567 - val_mean_absolute_error: 1503.3567
#
# Epoch 00464: val_loss did not improve from 1391.87220
# Epoch 465/500
# 585/585 [==============================] - 0s 180us/step - loss: 1429.3607 - mean_absolute_error: 1429.3607 - val_loss: 1592.8043 - val_mean_absolute_error: 1592.8043
#
# Epoch 00465: val_loss did not improve from 1391.87220
# Epoch 466/500
# 585/585 [==============================] - 0s 164us/step - loss: 1476.5431 - mean_absolute_error: 1476.5431 - val_loss: 1488.7554 - val_mean_absolute_error: 1488.7554
#
# Epoch 00466: val_loss did not improve from 1391.87220
# Epoch 467/500
# 585/585 [==============================] - 0s 128us/step - loss: 1456.1136 - mean_absolute_error: 1456.1136 - val_loss: 1483.2352 - val_mean_absolute_error: 1483.2352
#
# Epoch 00467: val_loss did not improve from 1391.87220
# Epoch 468/500
# 585/585 [==============================] - 0s 148us/step - loss: 1430.3358 - mean_absolute_error: 1430.3358 - val_loss: 1510.4321 - val_mean_absolute_error: 1510.4321
#
# Epoch 00468: val_loss did not improve from 1391.87220
# Epoch 469/500
# 585/585 [==============================] - 0s 143us/step - loss: 1444.1847 - mean_absolute_error: 1444.1847 - val_loss: 1460.3629 - val_mean_absolute_error: 1460.3629
#
# Epoch 00469: val_loss did not improve from 1391.87220
# Epoch 470/500
# 585/585 [==============================] - 0s 176us/step - loss: 1442.3230 - mean_absolute_error: 1442.3230 - val_loss: 1596.8256 - val_mean_absolute_error: 1596.8256
#
# Epoch 00470: val_loss did not improve from 1391.87220
# Epoch 471/500
# 585/585 [==============================] - 0s 143us/step - loss: 1432.8118 - mean_absolute_error: 1432.8118 - val_loss: 1487.4024 - val_mean_absolute_error: 1487.4024
#
# Epoch 00471: val_loss did not improve from 1391.87220
# Epoch 472/500
# 585/585 [==============================] - 0s 140us/step - loss: 1437.0438 - mean_absolute_error: 1437.0438 - val_loss: 1462.0717 - val_mean_absolute_error: 1462.0717
#
# Epoch 00472: val_loss did not improve from 1391.87220
# Epoch 473/500
# 585/585 [==============================] - 0s 140us/step - loss: 1463.4781 - mean_absolute_error: 1463.4781 - val_loss: 1513.6299 - val_mean_absolute_error: 1513.6299
#
# Epoch 00473: val_loss did not improve from 1391.87220
# Epoch 474/500
# 585/585 [==============================] - 0s 165us/step - loss: 1447.1158 - mean_absolute_error: 1447.1158 - val_loss: 1529.8117 - val_mean_absolute_error: 1529.8117
#
# Epoch 00474: val_loss did not improve from 1391.87220
# Epoch 475/500
# 585/585 [==============================] - 0s 136us/step - loss: 1461.3846 - mean_absolute_error: 1461.3846 - val_loss: 1453.8854 - val_mean_absolute_error: 1453.8854
#
# Epoch 00475: val_loss did not improve from 1391.87220
# Epoch 476/500
# 585/585 [==============================] - 0s 142us/step - loss: 1412.1523 - mean_absolute_error: 1412.1523 - val_loss: 1517.2992 - val_mean_absolute_error: 1517.2992
#
# Epoch 00476: val_loss did not improve from 1391.87220
# Epoch 477/500
# 585/585 [==============================] - 0s 131us/step - loss: 1433.5554 - mean_absolute_error: 1433.5554 - val_loss: 1418.2126 - val_mean_absolute_error: 1418.2126
#
# Epoch 00477: val_loss did not improve from 1391.87220
# Epoch 478/500
# 585/585 [==============================] - 0s 128us/step - loss: 1422.2313 - mean_absolute_error: 1422.2313 - val_loss: 1581.1950 - val_mean_absolute_error: 1581.1950
#
# Epoch 00478: val_loss did not improve from 1391.87220
# Epoch 479/500
# 585/585 [==============================] - 0s 140us/step - loss: 1431.1912 - mean_absolute_error: 1431.1912 - val_loss: 1477.4067 - val_mean_absolute_error: 1477.4067
#
# Epoch 00479: val_loss did not improve from 1391.87220
# Epoch 480/500
# 585/585 [==============================] - 0s 135us/step - loss: 1415.6563 - mean_absolute_error: 1415.6563 - val_loss: 1497.8727 - val_mean_absolute_error: 1497.8727
#
# Epoch 00480: val_loss did not improve from 1391.87220
# Epoch 481/500
# 585/585 [==============================] - 0s 147us/step - loss: 1419.9372 - mean_absolute_error: 1419.9372 - val_loss: 1473.9947 - val_mean_absolute_error: 1473.9947
#
# Epoch 00481: val_loss did not improve from 1391.87220
# Epoch 482/500
# 585/585 [==============================] - 0s 152us/step - loss: 1450.1856 - mean_absolute_error: 1450.1856 - val_loss: 1481.6204 - val_mean_absolute_error: 1481.6204
#
# Epoch 00482: val_loss did not improve from 1391.87220
# Epoch 483/500
# 585/585 [==============================] - 0s 143us/step - loss: 1413.4769 - mean_absolute_error: 1413.4769 - val_loss: 1643.5840 - val_mean_absolute_error: 1643.5840
#
# Epoch 00483: val_loss did not improve from 1391.87220
# Epoch 484/500
# 585/585 [==============================] - 0s 175us/step - loss: 1496.9935 - mean_absolute_error: 1496.9935 - val_loss: 1493.2244 - val_mean_absolute_error: 1493.2244
#
# Epoch 00484: val_loss did not improve from 1391.87220
# Epoch 485/500
# 585/585 [==============================] - 0s 184us/step - loss: 1443.7175 - mean_absolute_error: 1443.7175 - val_loss: 1465.1627 - val_mean_absolute_error: 1465.1627
#
# Epoch 00485: val_loss did not improve from 1391.87220
# Epoch 486/500
# 585/585 [==============================] - 0s 116us/step - loss: 1427.0045 - mean_absolute_error: 1427.0045 - val_loss: 1501.0489 - val_mean_absolute_error: 1501.0489
#
# Epoch 00486: val_loss did not improve from 1391.87220
# Epoch 487/500
# 585/585 [==============================] - 0s 121us/step - loss: 1426.1077 - mean_absolute_error: 1426.1077 - val_loss: 1484.1078 - val_mean_absolute_error: 1484.1078
#
# Epoch 00487: val_loss did not improve from 1391.87220
# Epoch 488/500
# 585/585 [==============================] - 0s 119us/step - loss: 1417.4240 - mean_absolute_error: 1417.4240 - val_loss: 1601.1720 - val_mean_absolute_error: 1601.1720
#
# Epoch 00488: val_loss did not improve from 1391.87220
# Epoch 489/500
# 585/585 [==============================] - 0s 138us/step - loss: 1460.1511 - mean_absolute_error: 1460.1511 - val_loss: 1485.6822 - val_mean_absolute_error: 1485.6822
#
# Epoch 00489: val_loss did not improve from 1391.87220
# Epoch 490/500
# 585/585 [==============================] - 0s 145us/step - loss: 1445.0729 - mean_absolute_error: 1445.0729 - val_loss: 1494.8636 - val_mean_absolute_error: 1494.8636
#
# Epoch 00490: val_loss did not improve from 1391.87220
# Epoch 491/500
# 585/585 [==============================] - 0s 119us/step - loss: 1417.0645 - mean_absolute_error: 1417.0645 - val_loss: 1545.6503 - val_mean_absolute_error: 1545.6503
#
# Epoch 00491: val_loss did not improve from 1391.87220
# Epoch 492/500
# 585/585 [==============================] - 0s 119us/step - loss: 1427.4572 - mean_absolute_error: 1427.4572 - val_loss: 1520.8984 - val_mean_absolute_error: 1520.8984
#
# Epoch 00492: val_loss did not improve from 1391.87220
# Epoch 493/500
# 585/585 [==============================] - 0s 140us/step - loss: 1407.4503 - mean_absolute_error: 1407.4503 - val_loss: 1493.5010 - val_mean_absolute_error: 1493.5010
#
# Epoch 00493: val_loss did not improve from 1391.87220
# Epoch 494/500
# 585/585 [==============================] - 0s 165us/step - loss: 1427.9396 - mean_absolute_error: 1427.9396 - val_loss: 1523.0423 - val_mean_absolute_error: 1523.0423
#
# Epoch 00494: val_loss did not improve from 1391.87220
# Epoch 495/500
# 585/585 [==============================] - 0s 145us/step - loss: 1414.6735 - mean_absolute_error: 1414.6735 - val_loss: 1536.3149 - val_mean_absolute_error: 1536.3149
#
# Epoch 00495: val_loss did not improve from 1391.87220
# Epoch 496/500
# 585/585 [==============================] - 0s 138us/step - loss: 1422.1871 - mean_absolute_error: 1422.1871 - val_loss: 1443.6512 - val_mean_absolute_error: 1443.6512
#
# Epoch 00496: val_loss did not improve from 1391.87220
# Epoch 497/500
# 585/585 [==============================] - 0s 119us/step - loss: 1490.9203 - mean_absolute_error: 1490.9203 - val_loss: 1543.1323 - val_mean_absolute_error: 1543.1323
#
# Epoch 00497: val_loss did not improve from 1391.87220
# Epoch 498/500
# 585/585 [==============================] - 0s 145us/step - loss: 1442.4890 - mean_absolute_error: 1442.4890 - val_loss: 1516.8377 - val_mean_absolute_error: 1516.8377
#
# Epoch 00498: val_loss did not improve from 1391.87220
# Epoch 499/500
# 585/585 [==============================] - ETA: 0s - loss: 1393.6835 - mean_absolute_error: 1393.683 - 0s 150us/step - loss: 1414.0820 - mean_absolute_error: 1414.0820 - val_loss: 1514.5771 - val_mean_absolute_error: 1514.5771
#
# Epoch 00499: val_loss did not improve from 1391.87220
# Epoch 500/500
# 585/585 [==============================] - 0s 192us/step - loss: 1389.7716 - mean_absolute_error: 1389.7716 - val_loss: 1599.8591 - val_mean_absolute_error: 1599.8591
#
# Epoch 00500: val_loss did not improve from 1391.87220

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = 'GS-맥주date-Weights-336--1391.87220-cat02-vf05.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']



print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

customF = formulaGen(target='qty',ind_features=list_col)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 맥주의 회귀분석 결과 :
# 훈련세트점수 : 0.888
# 검증세트점수 : -0.950
# XGBoost을 이용한 맥주의 회귀분석 결과 :
# 훈련세트점수 : 0.683
# 검증세트점수 : -0.918
# LinearRegression을 이용한 맥주의 회귀분석 결과 :
# 훈련세트점수 : 0.452
# 검증세트점수 : -0.780
# RidgeRegression을 이용한 맥주의 회귀분석 결과 :
# 훈련세트점수 : 0.445
# 검증세트점수 : -0.752
# LassoRegression을 이용한 맥주의 회귀분석 결과 :
# 훈련세트점수 : 0.452
# 검증세트점수 : -0.780
# OLS을 이용한 맥주의 회귀분석 결과 :
# 훈련세트점수 : 0.445

# %%
trainXy.columns
# Out:
# Index(['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o',
#        'snow_or_not_o'],
#       dtype='object')

# %%
print(item, 'ols model')
# ind_features = 넣고 싶은 독립변수를 리스트로 넣어주면 알아서 formula생성해 준다.
# customF = formulaGen(target='qty',ind_features=['temp'])
# print(customF) qty ~ temp
# customF = formulaGen(target='qty',ind_features=['temp','cloud'])
# print(customF) # qty ~ temp + cloud
list_col = ['temp', 'lgt_time', 'PM10', 'snow_or_not_o', 'rain_or_not_o']

customF = formulaGen(target='qty',ind_features=list_col)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
olsModel.summary()
# Out:
# 맥주 ols model
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     116.3
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):           2.86e-90
# Time:                        12:06:39   Log-Likelihood:                -6565.7
# No. Observations:                 732   AIC:                         1.314e+04
# Df Residuals:                     726   BIC:                         1.317e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.065e+04    275.238     38.709      0.000    1.01e+04    1.12e+04
# temp            156.2965      6.865     22.767      0.000     142.819     169.774
# lgt_time        -77.6683     21.388     -3.631      0.000    -119.658     -35.679
# PM10             -8.5463      3.204     -2.667      0.008     -14.837      -2.256
# snow_or_not_o  1210.1079    440.555      2.747      0.006     345.194    2075.022
# rain_or_not_o  -689.3405    196.539     -3.507      0.000   -1075.192    -303.489
# ==============================================================================
# Omnibus:                        6.315   Durbin-Watson:                   0.847
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):                6.372
# Skew:                           0.211   Prob(JB):                       0.0413
# Kurtosis:                       2.825   Cond. No.                         346.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = gs_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
print(Xy.columns)
# Out:
# Index(['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o',
#        'snow_or_not_o'],
#       dtype='object')

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_비o', 'snow_or_not_눈o']
n=1
# alpha 값 0~1
alp = 0.8
# scatter plot 점 크기
dot_size = 10

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~106 / 106~156
trainXy = gs_week_w.loc[:cut_line]
testXy = gs_week_w.loc[cut_line:]
train_X =pd.DataFrame(trainXy.loc[:,'temp'])
train_y = trainXy.loc[:,'qty']
val_X = pd.DataFrame(testXy.loc[:,'temp'])
val_y = testXy.loc[:,'qty']



print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

customF = formulaGen(target='qty',ind_features=['temp'])
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
target = gs_week_w.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['week'] = gs_week_w['week']
result_df['qty'] = gs_week_w.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
# result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
qty_columns = list(df_graph.columns)[1:9]
weather_columns = list(df_graph.columns)[9:]
print(qty_columns)
print(weather_columns)

# %%
x_temp = pd.DataFrame()
# x_temp['temp'] = list(range(-10,35,1))
x_temp['temp'] = np.arange(-9,35,0.5)
combined = x_temp
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

# 2016~2018, 일조시간
df_graph = df.copy()
plt.figure(figsize=(15.5, 10))
plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
plt.plot(x_temp, RFpredicted, label = 'rf')
plt.plot(x_temp, XGBpredictions, label = 'xgb')
plt.plot(x_temp, linPred, label = 'line')
plt.plot(x_temp, ridPred, label = 'ridge')
plt.plot(x_temp, lassoPred, label = 'lasso')
plt.plot(x_temp, olsPred, label = 'ols')
plt.plot()
plt.legend()
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
plt.xlabel(weather_columns[0])
plt.ylabel('판매량 (단위 : 1개)')
plt.show()

# %% [markdown]
# # 실험

# %%
intercept_lin = linReg.intercept_
coef_line = linReg.coef_
# list_col
linePredict = list()
x_temp = list(range(-10,38,1))
for temperature in x_temp:
    linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# 2016~2018, 일조시간
df_graph = df.copy()
plt.figure(figsize=(15.5, 10))
plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# for q_name in qty_columns:
#     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
#     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
#     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
#     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
#     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
#     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
#     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
#     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
#     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

plt.legend()
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
plt.xlabel(weather_columns[0])
plt.ylabel('판매량 (단위 : 1개)')
plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# 2016
df_graph = result_df.loc[result_df.week <=53]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
plt.legend()
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
plt.show()

# %%
# 2017
df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
plt.legend()
plt.show()

# %%
# 2018
df_graph = result_df.loc[(result_df.week >=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
plt.legend()
plt.show()

# %%
# 2016~2018
plt.figure(figsize=(15.5, 10))
plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
plt.legend()
plt.show()

# %%
def r2_score(v_true, v_pred):
    ssr = np.sum(np.square(v_pred - np.mean(v_true)))
    sst = np.sum(np.square(v_true - np.mean(v_true)))
    return ( ssr / sst)

# %%
checked_for = '2016~2017'
combined = aaaaa.loc[:106,'temp':'PM10']
target = aaaaa.loc[:106,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)
qty = target

print(checked_for)
print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
checked_for = '2018'
combined = aaaaa.loc[106:,'temp':'PM10']
target = aaaaa.loc[106:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

qty = target

print(checked_for)
print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
checked_for = '2016~2018'
combined = aaaaa.loc[:,'temp':'PM10']
target = aaaaa.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

qty = target

print(checked_for)
print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
path = 'D:/project/contest/data/result/'
result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)

# %%
# 날씨+sns와 아이스크림 을 사용하면 2017까진 적당하고 2018년도는 예측율 급락
#  -> 과적합화 발생
# 날씨와 아이스크림 판매량만 이용하니 ㅇㅋ
