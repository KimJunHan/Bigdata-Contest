# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# R2 값, 결정계수 계산
from sklearn.metrics import r2_score

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
# w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
w = pd.read_csv('d:/project/contest/data/processed/날씨_ver071915.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '생수'만 빼서 df생성
item = '생수'
grouped_by = 'date'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not','미세', '초미세', '공기상태',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %%
# MAD적용
gs_day_w['outlier'] = pd.DataFrame(mad_based_outlier(gs_day_w['qty']))
gs_day_w = gs_day_w.loc[gs_day_w.outlier==False]

# %%
# list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
list_col = ['temp', 'cloud', 'wind','lgt_time',
            'rain_or_not', 'snow_or_not', '공기상태'] #+'rain_or_not', 'snow_or_not'
lowVIF(w,20,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239620  snow_or_not
# 1    2.479988  rain_or_not
# 2    3.114369         공기상태
# 3    4.013218         temp
# 4    6.725926        cloud
# 5    8.084050     lgt_time
# 6    9.334878         wind

# %%
train_data = gs_day_w.loc[gs_day_w.date.between('2016-01-01','2017-12-31')]
test_data = gs_day_w.loc[gs_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만
combined = gs_day_w.loc[:,list_col]
target = gs_day_w.loc[:,'qty']
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 7
# 오브젝트형 자료 컬럼 갯수 : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
#### 내가 '공기상태'라는 컬럼이 사실은 category형이라는것을 알기에 직접 dummy컬럼 생성
airCondition_dummies = pd.get_dummies(combined['공기상태'],prefix='공기상태')
combined = pd.concat([combined, airCondition_dummies], axis=1)
combined.drop(['공기상태'],axis = 1 , inplace=True)
######################################################################################
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 10 개의 columns이 있었습니다.

# %%
combined.head(2)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
# 1   5.7    7.8   2.0       3.6            0            0       0       1
#
#    공기상태_2  공기상태_3
# 0       1       0
# 1       0       0

# %%
# 공기상태_0,공기상태_1,공기상태_2가 전부 0이면,   공기상태_3이 1이란 소리고
#                                                               공기상태가 '매우나쁨' 임을 추정할수 있다.
# 그런이유로 공기상태_3삭제
combined.drop(['공기상태_3'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
#
#    공기상태_2
# 0       1

# %%
Xy = pd.concat([target,combined], axis=1)
# Xy.head(1)

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 9)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 18:54:11.823581  1636 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 18:54:11.838565  1636 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 18:54:11.840535  1636 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 18:54:11.908354  1636 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,145
# Trainable params: 166,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 16:49:47.511141  6416 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 16:49:47.621874  6416 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 515us/step - loss: 10279.3458 - mean_absolute_error: 10279.3458 - val_loss: 9017.7030 - val_mean_absolute_error: 9017.7030
#
# Epoch 00001: val_loss improved from inf to 9017.70301, saving model to 생수date-Weights-001--9017.70301-cat02-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 95us/step - loss: 9705.9302 - mean_absolute_error: 9705.9302 - val_loss: 7108.3110 - val_mean_absolute_error: 7108.3110
#
# Epoch 00002: val_loss improved from 9017.70301 to 7108.31099, saving model to 생수date-Weights-002--7108.31099-cat02-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 78us/step - loss: 4614.0634 - mean_absolute_error: 4614.0634 - val_loss: 2540.8023 - val_mean_absolute_error: 2540.8023
#
# Epoch 00003: val_loss improved from 7108.31099 to 2540.80228, saving model to 생수date-Weights-003--2540.80228-cat02-vf05.hdf5
# Epoch 4/500
# 585/585 [==============================] - 0s 73us/step - loss: 2007.3241 - mean_absolute_error: 2007.3241 - val_loss: 1663.6306 - val_mean_absolute_error: 1663.6306
#
# Epoch 00004: val_loss improved from 2540.80228 to 1663.63064, saving model to 생수date-Weights-004--1663.63064-cat02-vf05.hdf5
# Epoch 5/500
# 585/585 [==============================] - 0s 75us/step - loss: 1693.1199 - mean_absolute_error: 1693.1199 - val_loss: 1465.8001 - val_mean_absolute_error: 1465.8001
#
# Epoch 00005: val_loss improved from 1663.63064 to 1465.80013, saving model to 생수date-Weights-005--1465.80013-cat02-vf05.hdf5
# Epoch 6/500
# 585/585 [==============================] - 0s 82us/step - loss: 1631.3696 - mean_absolute_error: 1631.3696 - val_loss: 1465.2307 - val_mean_absolute_error: 1465.2307
#
# Epoch 00006: val_loss improved from 1465.80013 to 1465.23066, saving model to 생수date-Weights-006--1465.23066-cat02-vf05.hdf5
# Epoch 7/500
# 585/585 [==============================] - 0s 77us/step - loss: 1607.7452 - mean_absolute_error: 1607.7452 - val_loss: 1470.0517 - val_mean_absolute_error: 1470.0517
#
# Epoch 00007: val_loss did not improve from 1465.23066
# Epoch 8/500
# 585/585 [==============================] - 0s 73us/step - loss: 1570.5803 - mean_absolute_error: 1570.5803 - val_loss: 1399.1757 - val_mean_absolute_error: 1399.1757
#
# Epoch 00008: val_loss improved from 1465.23066 to 1399.17570, saving model to 생수date-Weights-008--1399.17570-cat02-vf05.hdf5
# Epoch 9/500
# 585/585 [==============================] - 0s 82us/step - loss: 1565.6904 - mean_absolute_error: 1565.6904 - val_loss: 1394.6595 - val_mean_absolute_error: 1394.6595
#
# Epoch 00009: val_loss improved from 1399.17570 to 1394.65953, saving model to 생수date-Weights-009--1394.65953-cat02-vf05.hdf5
# Epoch 10/500
# 585/585 [==============================] - 0s 84us/step - loss: 1617.7850 - mean_absolute_error: 1617.7850 - val_loss: 1383.8172 - val_mean_absolute_error: 1383.8172
#
# Epoch 00010: val_loss improved from 1394.65953 to 1383.81724, saving model to 생수date-Weights-010--1383.81724-cat02-vf05.hdf5
# Epoch 11/500
# 585/585 [==============================] - 0s 72us/step - loss: 1562.5308 - mean_absolute_error: 1562.5308 - val_loss: 1375.0660 - val_mean_absolute_error: 1375.0660
#
# Epoch 00011: val_loss improved from 1383.81724 to 1375.06598, saving model to 생수date-Weights-011--1375.06598-cat02-vf05.hdf5
# Epoch 12/500
# 585/585 [==============================] - 0s 78us/step - loss: 1553.0797 - mean_absolute_error: 1553.0797 - val_loss: 1432.4669 - val_mean_absolute_error: 1432.4669
#
# Epoch 00012: val_loss did not improve from 1375.06598
# Epoch 13/500
# 585/585 [==============================] - 0s 85us/step - loss: 1557.9917 - mean_absolute_error: 1557.9917 - val_loss: 1390.2102 - val_mean_absolute_error: 1390.2102
#
# Epoch 00013: val_loss did not improve from 1375.06598
# Epoch 14/500
# 585/585 [==============================] - 0s 107us/step - loss: 1559.0191 - mean_absolute_error: 1559.0191 - val_loss: 1387.0398 - val_mean_absolute_error: 1387.0398
#
# Epoch 00014: val_loss did not improve from 1375.06598
# Epoch 15/500
# 585/585 [==============================] - 0s 111us/step - loss: 1540.6426 - mean_absolute_error: 1540.6426 - val_loss: 1351.2286 - val_mean_absolute_error: 1351.2286
#
# Epoch 00015: val_loss improved from 1375.06598 to 1351.22856, saving model to 생수date-Weights-015--1351.22856-cat02-vf05.hdf5
# Epoch 16/500
# 585/585 [==============================] - 0s 82us/step - loss: 1541.6706 - mean_absolute_error: 1541.6706 - val_loss: 1351.0535 - val_mean_absolute_error: 1351.0535
#
# Epoch 00016: val_loss improved from 1351.22856 to 1351.05348, saving model to 생수date-Weights-016--1351.05348-cat02-vf05.hdf5
# Epoch 17/500
# 585/585 [==============================] - 0s 68us/step - loss: 1535.7408 - mean_absolute_error: 1535.7408 - val_loss: 1348.9749 - val_mean_absolute_error: 1348.9749
#
# Epoch 00017: val_loss improved from 1351.05348 to 1348.97489, saving model to 생수date-Weights-017--1348.97489-cat02-vf05.hdf5
# Epoch 18/500
# 585/585 [==============================] - 0s 77us/step - loss: 1516.6275 - mean_absolute_error: 1516.6275 - val_loss: 1374.5955 - val_mean_absolute_error: 1374.5955
#
# Epoch 00018: val_loss did not improve from 1348.97489
# Epoch 19/500
# 585/585 [==============================] - 0s 78us/step - loss: 1551.9033 - mean_absolute_error: 1551.9033 - val_loss: 1362.2226 - val_mean_absolute_error: 1362.2226
#
# Epoch 00019: val_loss did not improve from 1348.97489
# Epoch 20/500
# 585/585 [==============================] - 0s 78us/step - loss: 1522.7669 - mean_absolute_error: 1522.7669 - val_loss: 1339.5637 - val_mean_absolute_error: 1339.5637
#
# Epoch 00020: val_loss improved from 1348.97489 to 1339.56367, saving model to 생수date-Weights-020--1339.56367-cat02-vf05.hdf5
# Epoch 21/500
# 585/585 [==============================] - 0s 102us/step - loss: 1507.8160 - mean_absolute_error: 1507.8160 - val_loss: 1333.3266 - val_mean_absolute_error: 1333.3266
#
# Epoch 00021: val_loss improved from 1339.56367 to 1333.32659, saving model to 생수date-Weights-021--1333.32659-cat02-vf05.hdf5
# Epoch 22/500
# 585/585 [==============================] - 0s 77us/step - loss: 1500.5181 - mean_absolute_error: 1500.5181 - val_loss: 1456.7740 - val_mean_absolute_error: 1456.7740
#
# Epoch 00022: val_loss did not improve from 1333.32659
# Epoch 23/500
# 585/585 [==============================] - 0s 77us/step - loss: 1519.5421 - mean_absolute_error: 1519.5421 - val_loss: 1453.3141 - val_mean_absolute_error: 1453.3141
#
# Epoch 00023: val_loss did not improve from 1333.32659
# Epoch 24/500
# 585/585 [==============================] - 0s 75us/step - loss: 1508.2750 - mean_absolute_error: 1508.2750 - val_loss: 1358.2194 - val_mean_absolute_error: 1358.2194
#
# Epoch 00024: val_loss did not improve from 1333.32659
# Epoch 25/500
# 585/585 [==============================] - 0s 80us/step - loss: 1519.7049 - mean_absolute_error: 1519.7049 - val_loss: 1315.1772 - val_mean_absolute_error: 1315.1772
#
# Epoch 00025: val_loss improved from 1333.32659 to 1315.17720, saving model to 생수date-Weights-025--1315.17720-cat02-vf05.hdf5
# Epoch 26/500
# 585/585 [==============================] - 0s 73us/step - loss: 1519.5802 - mean_absolute_error: 1519.5802 - val_loss: 1336.1217 - val_mean_absolute_error: 1336.1217
#
# Epoch 00026: val_loss did not improve from 1315.17720
# Epoch 27/500
# 585/585 [==============================] - 0s 75us/step - loss: 1506.1877 - mean_absolute_error: 1506.1877 - val_loss: 1428.5825 - val_mean_absolute_error: 1428.5825
#
# Epoch 00027: val_loss did not improve from 1315.17720
# Epoch 28/500
# 585/585 [==============================] - 0s 73us/step - loss: 1524.9647 - mean_absolute_error: 1524.9647 - val_loss: 1289.2160 - val_mean_absolute_error: 1289.2160
#
# Epoch 00028: val_loss improved from 1315.17720 to 1289.21597, saving model to 생수date-Weights-028--1289.21597-cat02-vf05.hdf5
# Epoch 29/500
# 585/585 [==============================] - 0s 78us/step - loss: 1536.2442 - mean_absolute_error: 1536.2442 - val_loss: 1291.6415 - val_mean_absolute_error: 1291.6415
#
# Epoch 00029: val_loss did not improve from 1289.21597
# Epoch 30/500
# 585/585 [==============================] - 0s 99us/step - loss: 1491.8907 - mean_absolute_error: 1491.8907 - val_loss: 1360.6908 - val_mean_absolute_error: 1360.6908
# Epoch 00030: val_loss did not improve from 1289.21597
# Epoch 31/500
# 585/585 [==============================] - 0s 82us/step - loss: 1477.2019 - mean_absolute_error: 1477.2019 - val_loss: 1301.1286 - val_mean_absolute_error: 1301.1286
#
# Epoch 00031: val_loss did not improve from 1289.21597
# Epoch 32/500
# 585/585 [==============================] - 0s 80us/step - loss: 1484.1180 - mean_absolute_error: 1484.1180 - val_loss: 1340.6425 - val_mean_absolute_error: 1340.6425
#
# Epoch 00032: val_loss did not improve from 1289.21597
# Epoch 33/500
# 585/585 [==============================] - 0s 77us/step - loss: 1472.5809 - mean_absolute_error: 1472.5809 - val_loss: 1273.1101 - val_mean_absolute_error: 1273.1101
#
# Epoch 00033: val_loss improved from 1289.21597 to 1273.11006, saving model to 생수date-Weights-033--1273.11006-cat02-vf05.hdf5
# Epoch 34/500
# 585/585 [==============================] - 0s 72us/step - loss: 1527.6031 - mean_absolute_error: 1527.6031 - val_loss: 1278.5582 - val_mean_absolute_error: 1278.5582
#
# Epoch 00034: val_loss did not improve from 1273.11006
# Epoch 35/500
# 585/585 [==============================] - 0s 73us/step - loss: 1490.2180 - mean_absolute_error: 1490.2180 - val_loss: 1452.9178 - val_mean_absolute_error: 1452.9178
#
# Epoch 00035: val_loss did not improve from 1273.11006
# Epoch 36/500
# 585/585 [==============================] - 0s 78us/step - loss: 1474.5985 - mean_absolute_error: 1474.5985 - val_loss: 1318.3689 - val_mean_absolute_error: 1318.3689
#
# Epoch 00036: val_loss did not improve from 1273.11006
# Epoch 37/500
# 585/585 [==============================] - 0s 78us/step - loss: 1466.8336 - mean_absolute_error: 1466.8336 - val_loss: 1370.7091 - val_mean_absolute_error: 1370.7091
#
# Epoch 00037: val_loss did not improve from 1273.11006
# Epoch 38/500
# 585/585 [==============================] - 0s 75us/step - loss: 1475.2685 - mean_absolute_error: 1475.2685 - val_loss: 1407.9449 - val_mean_absolute_error: 1407.9449
#
# Epoch 00038: val_loss did not improve from 1273.11006
# Epoch 39/500
# 585/585 [==============================] - 0s 73us/step - loss: 1451.0878 - mean_absolute_error: 1451.0878 - val_loss: 1273.2356 - val_mean_absolute_error: 1273.2356
#
# Epoch 00039: val_loss did not improve from 1273.11006
# Epoch 40/500
# 585/585 [==============================] - 0s 92us/step - loss: 1508.0896 - mean_absolute_error: 1508.0896 - val_loss: 1283.4983 - val_mean_absolute_error: 1283.4983
#
# Epoch 00040: val_loss did not improve from 1273.11006
# Epoch 41/500
# 585/585 [==============================] - 0s 77us/step - loss: 1487.6384 - mean_absolute_error: 1487.6384 - val_loss: 1371.3736 - val_mean_absolute_error: 1371.3736
#
# Epoch 00041: val_loss did not improve from 1273.11006
# Epoch 42/500
# 585/585 [==============================] - 0s 80us/step - loss: 1443.8708 - mean_absolute_error: 1443.8708 - val_loss: 1378.3306 - val_mean_absolute_error: 1378.3306
#
# Epoch 00042: val_loss did not improve from 1273.11006
# Epoch 43/500
# 585/585 [==============================] - 0s 78us/step - loss: 1445.6204 - mean_absolute_error: 1445.6204 - val_loss: 1312.4447 - val_mean_absolute_error: 1312.4447
#
# Epoch 00043: val_loss did not improve from 1273.11006
# Epoch 44/500
# 585/585 [==============================] - 0s 78us/step - loss: 1439.6444 - mean_absolute_error: 1439.6444 - val_loss: 1260.8704 - val_mean_absolute_error: 1260.8704
#
# Epoch 00044: val_loss improved from 1273.11006 to 1260.87044, saving model to 생수date-Weights-044--1260.87044-cat02-vf05.hdf5
# Epoch 45/500
# 585/585 [==============================] - 0s 70us/step - loss: 1489.3437 - mean_absolute_error: 1489.3437 - val_loss: 1242.2984 - val_mean_absolute_error: 1242.2984
#
# Epoch 00045: val_loss improved from 1260.87044 to 1242.29840, saving model to 생수date-Weights-045--1242.29840-cat02-vf05.hdf5
# Epoch 46/500
# 585/585 [==============================] - 0s 78us/step - loss: 1433.0929 - mean_absolute_error: 1433.0929 - val_loss: 1361.2895 - val_mean_absolute_error: 1361.2895
#
# Epoch 00046: val_loss did not improve from 1242.29840
# Epoch 47/500
# 585/585 [==============================] - 0s 80us/step - loss: 1431.0654 - mean_absolute_error: 1431.0654 - val_loss: 1416.4288 - val_mean_absolute_error: 1416.4288
#
# Epoch 00047: val_loss did not improve from 1242.29840
# Epoch 48/500
# 585/585 [==============================] - 0s 77us/step - loss: 1439.2502 - mean_absolute_error: 1439.2502 - val_loss: 1377.6750 - val_mean_absolute_error: 1377.6750
#
# Epoch 00048: val_loss did not improve from 1242.29840
# Epoch 49/500
# 585/585 [==============================] - 0s 92us/step - loss: 1454.4598 - mean_absolute_error: 1454.4598 - val_loss: 1209.3300 - val_mean_absolute_error: 1209.3300
#
# Epoch 00049: val_loss improved from 1242.29840 to 1209.33004, saving model to 생수date-Weights-049--1209.33004-cat02-vf05.hdf5
# Epoch 50/500
# 585/585 [==============================] - 0s 92us/step - loss: 1424.4699 - mean_absolute_error: 1424.4699 - val_loss: 1240.2254 - val_mean_absolute_error: 1240.2254
#
# Epoch 00050: val_loss did not improve from 1209.33004
# Epoch 51/500
# 585/585 [==============================] - 0s 82us/step - loss: 1423.0051 - mean_absolute_error: 1423.0051 - val_loss: 1395.0017 - val_mean_absolute_error: 1395.0017
#
# Epoch 00051: val_loss did not improve from 1209.33004
# Epoch 52/500
# 585/585 [==============================] - 0s 77us/step - loss: 1443.5091 - mean_absolute_error: 1443.5091 - val_loss: 1375.1564 - val_mean_absolute_error: 1375.1564
#
# Epoch 00052: val_loss did not improve from 1209.33004
# Epoch 53/500
# 585/585 [==============================] - 0s 75us/step - loss: 1417.9318 - mean_absolute_error: 1417.9318 - val_loss: 1234.0800 - val_mean_absolute_error: 1234.0800
#
# Epoch 00053: val_loss did not improve from 1209.33004
# Epoch 54/500
# 585/585 [==============================] - 0s 78us/step - loss: 1417.7280 - mean_absolute_error: 1417.7280 - val_loss: 1253.1800 - val_mean_absolute_error: 1253.1800
#
# Epoch 00054: val_loss did not improve from 1209.33004
# Epoch 55/500
# 585/585 [==============================] - 0s 82us/step - loss: 1404.6853 - mean_absolute_error: 1404.6853 - val_loss: 1192.5926 - val_mean_absolute_error: 1192.5926
#
# Epoch 00055: val_loss improved from 1209.33004 to 1192.59260, saving model to 생수date-Weights-055--1192.59260-cat02-vf05.hdf5
# Epoch 56/500
# 585/585 [==============================] - 0s 85us/step - loss: 1458.0425 - mean_absolute_error: 1458.0425 - val_loss: 1200.6096 - val_mean_absolute_error: 1200.6096
#
# Epoch 00056: val_loss did not improve from 1192.59260
# Epoch 57/500
# 585/585 [==============================] - 0s 78us/step - loss: 1402.0817 - mean_absolute_error: 1402.0817 - val_loss: 1242.1876 - val_mean_absolute_error: 1242.1876
#
# Epoch 00057: val_loss did not improve from 1192.59260
# Epoch 58/500
# 585/585 [==============================] - 0s 99us/step - loss: 1397.9788 - mean_absolute_error: 1397.9788 - val_loss: 1386.4393 - val_mean_absolute_error: 1386.4393
#
# Epoch 00058: val_loss did not improve from 1192.59260
# Epoch 59/500
# 585/585 [==============================] - 0s 82us/step - loss: 1407.6503 - mean_absolute_error: 1407.6503 - val_loss: 1186.7336 - val_mean_absolute_error: 1186.7336
#
# Epoch 00059: val_loss improved from 1192.59260 to 1186.73363, saving model to 생수date-Weights-059--1186.73363-cat02-vf05.hdf5
# Epoch 60/500
# 585/585 [==============================] - 0s 70us/step - loss: 1437.3596 - mean_absolute_error: 1437.3596 - val_loss: 1242.7302 - val_mean_absolute_error: 1242.7302
#
# Epoch 00060: val_loss did not improve from 1186.73363
# Epoch 61/500
# 585/585 [==============================] - 0s 82us/step - loss: 1394.9356 - mean_absolute_error: 1394.9356 - val_loss: 1289.9905 - val_mean_absolute_error: 1289.9905
#
# Epoch 00061: val_loss did not improve from 1186.73363
# Epoch 62/500
# 585/585 [==============================] - 0s 72us/step - loss: 1405.6370 - mean_absolute_error: 1405.6370 - val_loss: 1296.4390 - val_mean_absolute_error: 1296.4390
#
# Epoch 00062: val_loss did not improve from 1186.73363
# Epoch 63/500
# 585/585 [==============================] - 0s 78us/step - loss: 1410.1573 - mean_absolute_error: 1410.1573 - val_loss: 1242.4838 - val_mean_absolute_error: 1242.4838
#
# Epoch 00063: val_loss did not improve from 1186.73363
# Epoch 64/500
# 585/585 [==============================] - 0s 77us/step - loss: 1392.2789 - mean_absolute_error: 1392.2789 - val_loss: 1530.4034 - val_mean_absolute_error: 1530.4034
#
# Epoch 00064: val_loss did not improve from 1186.73363
# Epoch 65/500
# 585/585 [==============================] - 0s 75us/step - loss: 1450.6459 - mean_absolute_error: 1450.6459 - val_loss: 1238.0494 - val_mean_absolute_error: 1238.0494
#
# Epoch 00065: val_loss did not improve from 1186.73363
# Epoch 66/500
# 585/585 [==============================] - 0s 84us/step - loss: 1428.4595 - mean_absolute_error: 1428.4595 - val_loss: 1188.3377 - val_mean_absolute_error: 1188.3377
#
# Epoch 00066: val_loss did not improve from 1186.73363
# Epoch 67/500
# 585/585 [==============================] - 0s 72us/step - loss: 1412.7106 - mean_absolute_error: 1412.7106 - val_loss: 1507.3108 - val_mean_absolute_error: 1507.3108
#
# Epoch 00067: val_loss did not improve from 1186.73363
# Epoch 68/500
# 585/585 [==============================] - 0s 85us/step - loss: 1426.2783 - mean_absolute_error: 1426.2783 - val_loss: 1651.6755 - val_mean_absolute_error: 1651.6755
#
# Epoch 00068: val_loss did not improve from 1186.73363
# Epoch 69/500
# 585/585 [==============================] - 0s 92us/step - loss: 1467.2114 - mean_absolute_error: 1467.2114 - val_loss: 1424.5840 - val_mean_absolute_error: 1424.5840
#
# Epoch 00069: val_loss did not improve from 1186.73363
# Epoch 70/500
# 585/585 [==============================] - 0s 80us/step - loss: 1403.5169 - mean_absolute_error: 1403.5169 - val_loss: 1187.8212 - val_mean_absolute_error: 1187.8212
#
# Epoch 00070: val_loss did not improve from 1186.73363
# Epoch 71/500
# 585/585 [==============================] - 0s 70us/step - loss: 1384.6400 - mean_absolute_error: 1384.6400 - val_loss: 1230.2833 - val_mean_absolute_error: 1230.2833
#
# Epoch 00071: val_loss did not improve from 1186.73363
# Epoch 72/500
# 585/585 [==============================] - 0s 73us/step - loss: 1396.9990 - mean_absolute_error: 1396.9990 - val_loss: 1255.5908 - val_mean_absolute_error: 1255.5908
#
# Epoch 00072: val_loss did not improve from 1186.73363
# Epoch 73/500
# 585/585 [==============================] - 0s 72us/step - loss: 1421.5640 - mean_absolute_error: 1421.5640 - val_loss: 1159.3077 - val_mean_absolute_error: 1159.3077
#
# Epoch 00073: val_loss improved from 1186.73363 to 1159.30772, saving model to 생수date-Weights-073--1159.30772-cat02-vf05.hdf5
# Epoch 74/500
# 585/585 [==============================] - 0s 73us/step - loss: 1410.0819 - mean_absolute_error: 1410.0819 - val_loss: 1230.9058 - val_mean_absolute_error: 1230.9058
#
# Epoch 00074: val_loss did not improve from 1159.30772
# Epoch 75/500
# 585/585 [==============================] - 0s 80us/step - loss: 1405.6990 - mean_absolute_error: 1405.6990 - val_loss: 1475.0063 - val_mean_absolute_error: 1475.0063
#
# Epoch 00075: val_loss did not improve from 1159.30772
# Epoch 76/500
# 585/585 [==============================] - 0s 72us/step - loss: 1389.7577 - mean_absolute_error: 1389.7577 - val_loss: 1271.5385 - val_mean_absolute_error: 1271.5385
#
# Epoch 00076: val_loss did not improve from 1159.30772
# Epoch 77/500
# 585/585 [==============================] - 0s 84us/step - loss: 1382.2916 - mean_absolute_error: 1382.2916 - val_loss: 1344.1483 - val_mean_absolute_error: 1344.1483
#
# Epoch 00077: val_loss did not improve from 1159.30772
# Epoch 78/500
# 585/585 [==============================] - 0s 90us/step - loss: 1400.8673 - mean_absolute_error: 1400.8673 - val_loss: 1336.6594 - val_mean_absolute_error: 1336.6594
#
# Epoch 00078: val_loss did not improve from 1159.30772
# Epoch 79/500
# 585/585 [==============================] - 0s 90us/step - loss: 1356.9227 - mean_absolute_error: 1356.9227 - val_loss: 1472.0174 - val_mean_absolute_error: 1472.0174
#
# Epoch 00079: val_loss did not improve from 1159.30772
# Epoch 80/500
# 585/585 [==============================] - 0s 80us/step - loss: 1423.7586 - mean_absolute_error: 1423.7586 - val_loss: 1298.6500 - val_mean_absolute_error: 1298.6500
#
# Epoch 00080: val_loss did not improve from 1159.30772
# Epoch 81/500
# 585/585 [==============================] - 0s 80us/step - loss: 1366.6307 - mean_absolute_error: 1366.6307 - val_loss: 1181.5548 - val_mean_absolute_error: 1181.5548
#
# Epoch 00081: val_loss did not improve from 1159.30772
# Epoch 82/500
# 585/585 [==============================] - 0s 82us/step - loss: 1376.1293 - mean_absolute_error: 1376.1293 - val_loss: 1370.5239 - val_mean_absolute_error: 1370.5239
#
# Epoch 00082: val_loss did not improve from 1159.30772
# Epoch 83/500
# 585/585 [==============================] - 0s 84us/step - loss: 1358.1725 - mean_absolute_error: 1358.1725 - val_loss: 1224.3073 - val_mean_absolute_error: 1224.3073
#
# Epoch 00083: val_loss did not improve from 1159.30772
# Epoch 84/500
# 585/585 [==============================] - 0s 82us/step - loss: 1356.0995 - mean_absolute_error: 1356.0995 - val_loss: 1208.3669 - val_mean_absolute_error: 1208.3669
#
# Epoch 00084: val_loss did not improve from 1159.30772
# Epoch 85/500
# 585/585 [==============================] - 0s 85us/step - loss: 1361.4250 - mean_absolute_error: 1361.4250 - val_loss: 1246.7673 - val_mean_absolute_error: 1246.7673
#
# Epoch 00085: val_loss did not improve from 1159.30772
# Epoch 86/500
# 585/585 [==============================] - 0s 84us/step - loss: 1375.0940 - mean_absolute_error: 1375.0940 - val_loss: 1428.6033 - val_mean_absolute_error: 1428.6033
#
# Epoch 00086: val_loss did not improve from 1159.30772
# Epoch 87/500
# 585/585 [==============================] - 0s 82us/step - loss: 1365.6365 - mean_absolute_error: 1365.6365 - val_loss: 1443.1431 - val_mean_absolute_error: 1443.1431
#
# Epoch 00087: val_loss did not improve from 1159.30772
# Epoch 88/500
# 585/585 [==============================] - 0s 85us/step - loss: 1356.7008 - mean_absolute_error: 1356.7008 - val_loss: 1306.6029 - val_mean_absolute_error: 1306.6029
#
# Epoch 00088: val_loss did not improve from 1159.30772
# Epoch 89/500
# 585/585 [==============================] - 0s 70us/step - loss: 1376.8208 - mean_absolute_error: 1376.8208 - val_loss: 1585.5690 - val_mean_absolute_error: 1585.5690
#
# Epoch 00089: val_loss did not improve from 1159.30772
# Epoch 90/500
# 585/585 [==============================] - 0s 77us/step - loss: 1353.0477 - mean_absolute_error: 1353.0477 - val_loss: 1408.3534 - val_mean_absolute_error: 1408.3534
#
# Epoch 00090: val_loss did not improve from 1159.30772
# Epoch 91/500
# 585/585 [==============================] - 0s 80us/step - loss: 1361.9976 - mean_absolute_error: 1361.9976 - val_loss: 1213.7130 - val_mean_absolute_error: 1213.7130
#
# Epoch 00091: val_loss did not improve from 1159.30772
# Epoch 92/500
# 585/585 [==============================] - 0s 84us/step - loss: 1350.5710 - mean_absolute_error: 1350.5710 - val_loss: 1134.3730 - val_mean_absolute_error: 1134.3730
#
# Epoch 00092: val_loss improved from 1159.30772 to 1134.37295, saving model to 생수date-Weights-092--1134.37295-cat02-vf05.hdf5
# Epoch 93/500
# 585/585 [==============================] - 0s 73us/step - loss: 1372.8996 - mean_absolute_error: 1372.8996 - val_loss: 1335.3637 - val_mean_absolute_error: 1335.3637
#
# Epoch 00093: val_loss did not improve from 1134.37295
# Epoch 94/500
# 585/585 [==============================] - 0s 75us/step - loss: 1367.4748 - mean_absolute_error: 1367.4748 - val_loss: 1289.9181 - val_mean_absolute_error: 1289.9181
#
# Epoch 00094: val_loss did not improve from 1134.37295
# Epoch 95/500
# 585/585 [==============================] - 0s 82us/step - loss: 1353.6902 - mean_absolute_error: 1353.6902 - val_loss: 1179.4353 - val_mean_absolute_error: 1179.4353
#
# Epoch 00095: val_loss did not improve from 1134.37295
# Epoch 96/500
# 585/585 [==============================] - 0s 78us/step - loss: 1362.8520 - mean_absolute_error: 1362.8520 - val_loss: 1295.7796 - val_mean_absolute_error: 1295.7796
#
# Epoch 00096: val_loss did not improve from 1134.37295
# Epoch 97/500
# 585/585 [==============================] - 0s 77us/step - loss: 1340.2269 - mean_absolute_error: 1340.2269 - val_loss: 1317.5010 - val_mean_absolute_error: 1317.5010
#
# Epoch 00097: val_loss did not improve from 1134.37295
# Epoch 98/500
# 585/585 [==============================] - 0s 106us/step - loss: 1340.1123 - mean_absolute_error: 1340.1123 - val_loss: 1216.4924 - val_mean_absolute_error: 1216.4924
#
# Epoch 00098: val_loss did not improve from 1134.37295
# Epoch 99/500
# 585/585 [==============================] - 0s 85us/step - loss: 1336.3027 - mean_absolute_error: 1336.3027 - val_loss: 1280.0082 - val_mean_absolute_error: 1280.0082
#
# Epoch 00099: val_loss did not improve from 1134.37295
# Epoch 100/500
# 585/585 [==============================] - 0s 78us/step - loss: 1336.9194 - mean_absolute_error: 1336.9194 - val_loss: 1318.2335 - val_mean_absolute_error: 1318.2335
#
# Epoch 00100: val_loss did not improve from 1134.37295
# Epoch 101/500
# 585/585 [==============================] - 0s 75us/step - loss: 1365.1137 - mean_absolute_error: 1365.1137 - val_loss: 1412.2228 - val_mean_absolute_error: 1412.2228
#
# Epoch 00101: val_loss did not improve from 1134.37295
# Epoch 102/500
# 585/585 [==============================] - 0s 73us/step - loss: 1370.1604 - mean_absolute_error: 1370.1604 - val_loss: 1293.8850 - val_mean_absolute_error: 1293.8850
#
# Epoch 00102: val_loss did not improve from 1134.37295
# Epoch 103/500
# 585/585 [==============================] - 0s 70us/step - loss: 1345.2261 - mean_absolute_error: 1345.2261 - val_loss: 1179.3771 - val_mean_absolute_error: 1179.3771
#
# Epoch 00103: val_loss did not improve from 1134.37295
# Epoch 104/500
# 585/585 [==============================] - 0s 75us/step - loss: 1351.6896 - mean_absolute_error: 1351.6896 - val_loss: 1486.1901 - val_mean_absolute_error: 1486.1901
#
# Epoch 00104: val_loss did not improve from 1134.37295
# Epoch 105/500
# 585/585 [==============================] - 0s 73us/step - loss: 1372.7434 - mean_absolute_error: 1372.7434 - val_loss: 1213.1022 - val_mean_absolute_error: 1213.1022
#
# Epoch 00105: val_loss did not improve from 1134.37295
# Epoch 106/500
# 585/585 [==============================] - 0s 80us/step - loss: 1355.3673 - mean_absolute_error: 1355.3673 - val_loss: 1250.7655 - val_mean_absolute_error: 1250.7655
#
# Epoch 00106: val_loss did not improve from 1134.37295
# Epoch 107/500
# 585/585 [==============================] - 0s 78us/step - loss: 1313.6278 - mean_absolute_error: 1313.6278 - val_loss: 1178.9388 - val_mean_absolute_error: 1178.9388
#
# Epoch 00107: val_loss did not improve from 1134.37295
# Epoch 108/500
# 585/585 [==============================] - 0s 78us/step - loss: 1339.9203 - mean_absolute_error: 1339.9203 - val_loss: 1312.9306 - val_mean_absolute_error: 1312.9306
#
# Epoch 00108: val_loss did not improve from 1134.37295
# Epoch 109/500
# 585/585 [==============================] - 0s 72us/step - loss: 1332.0967 - mean_absolute_error: 1332.0967 - val_loss: 1375.7087 - val_mean_absolute_error: 1375.7087
#
# Epoch 00109: val_loss did not improve from 1134.37295
# Epoch 110/500
# 585/585 [==============================] - 0s 77us/step - loss: 1337.5788 - mean_absolute_error: 1337.5788 - val_loss: 1217.2755 - val_mean_absolute_error: 1217.2755
#
# Epoch 00110: val_loss did not improve from 1134.37295
# Epoch 111/500
# 585/585 [==============================] - 0s 80us/step - loss: 1324.9545 - mean_absolute_error: 1324.9545 - val_loss: 1141.5634 - val_mean_absolute_error: 1141.5634
#
# Epoch 00111: val_loss did not improve from 1134.37295
# Epoch 112/500
# 585/585 [==============================] - 0s 78us/step - loss: 1338.8306 - mean_absolute_error: 1338.8306 - val_loss: 1190.7252 - val_mean_absolute_error: 1190.7252
#
# Epoch 00112: val_loss did not improve from 1134.37295
# Epoch 113/500
# 585/585 [==============================] - 0s 73us/step - loss: 1334.8695 - mean_absolute_error: 1334.8695 - val_loss: 1357.5264 - val_mean_absolute_error: 1357.5264
#
# Epoch 00113: val_loss did not improve from 1134.37295
# Epoch 114/500
# 585/585 [==============================] - 0s 78us/step - loss: 1351.9659 - mean_absolute_error: 1351.9659 - val_loss: 1272.6329 - val_mean_absolute_error: 1272.6329
#
# Epoch 00114: val_loss did not improve from 1134.37295
# Epoch 115/500
# 585/585 [==============================] - 0s 82us/step - loss: 1330.1421 - mean_absolute_error: 1330.1421 - val_loss: 1134.7858 - val_mean_absolute_error: 1134.7858
#
# Epoch 00115: val_loss did not improve from 1134.37295
# Epoch 116/500
# 585/585 [==============================] - 0s 77us/step - loss: 1318.3006 - mean_absolute_error: 1318.3006 - val_loss: 1334.6095 - val_mean_absolute_error: 1334.6095
#
# Epoch 00116: val_loss did not improve from 1134.37295
# Epoch 117/500
# 585/585 [==============================] - 0s 73us/step - loss: 1320.1548 - mean_absolute_error: 1320.1548 - val_loss: 1536.6966 - val_mean_absolute_error: 1536.6966
#
# Epoch 00117: val_loss did not improve from 1134.37295
# Epoch 118/500
# 585/585 [==============================] - 0s 84us/step - loss: 1331.7903 - mean_absolute_error: 1331.7903 - val_loss: 1290.8717 - val_mean_absolute_error: 1290.8717
#
# Epoch 00118: val_loss did not improve from 1134.37295
# Epoch 119/500
# 585/585 [==============================] - 0s 87us/step - loss: 1317.0860 - mean_absolute_error: 1317.0860 - val_loss: 1243.0855 - val_mean_absolute_error: 1243.0855
#
# Epoch 00119: val_loss did not improve from 1134.37295
# Epoch 120/500
# 585/585 [==============================] - 0s 78us/step - loss: 1313.5039 - mean_absolute_error: 1313.5039 - val_loss: 1414.7308 - val_mean_absolute_error: 1414.7308
#
# Epoch 00120: val_loss did not improve from 1134.37295
# Epoch 121/500
# 585/585 [==============================] - 0s 78us/step - loss: 1325.5541 - mean_absolute_error: 1325.5541 - val_loss: 1337.2722 - val_mean_absolute_error: 1337.2722
#
# Epoch 00121: val_loss did not improve from 1134.37295
# Epoch 122/500
# 585/585 [==============================] - ETA: 0s - loss: 1232.2957 - mean_absolute_error: 1232.295 - 0s 82us/step - loss: 1309.0174 - mean_absolute_error: 1309.0174 - val_loss: 1268.5112 - val_mean_absolute_error: 1268.5112
#
# Epoch 00122: val_loss did not improve from 1134.37295
# Epoch 123/500
# 585/585 [==============================] - 0s 87us/step - loss: 1341.2734 - mean_absolute_error: 1341.2734 - val_loss: 1183.1909 - val_mean_absolute_error: 1183.1909
#
# Epoch 00123: val_loss did not improve from 1134.37295
# Epoch 124/500
# 585/585 [==============================] - 0s 80us/step - loss: 1347.0062 - mean_absolute_error: 1347.0062 - val_loss: 1258.7450 - val_mean_absolute_error: 1258.7450
#
# Epoch 00124: val_loss did not improve from 1134.37295
# Epoch 125/500
# 585/585 [==============================] - 0s 82us/step - loss: 1334.8299 - mean_absolute_error: 1334.8299 - val_loss: 1223.4890 - val_mean_absolute_error: 1223.4890
#
# Epoch 00125: val_loss did not improve from 1134.37295
# Epoch 126/500
# 585/585 [==============================] - 0s 84us/step - loss: 1304.2946 - mean_absolute_error: 1304.2946 - val_loss: 1412.8666 - val_mean_absolute_error: 1412.8666
#
# Epoch 00126: val_loss did not improve from 1134.37295
# Epoch 127/500
# 585/585 [==============================] - 0s 82us/step - loss: 1324.0688 - mean_absolute_error: 1324.0688 - val_loss: 1283.9597 - val_mean_absolute_error: 1283.9597
#
# Epoch 00127: val_loss did not improve from 1134.37295
# Epoch 128/500
# 585/585 [==============================] - 0s 84us/step - loss: 1317.0801 - mean_absolute_error: 1317.0801 - val_loss: 1183.0888 - val_mean_absolute_error: 1183.0888
#
# Epoch 00128: val_loss did not improve from 1134.37295
# Epoch 129/500
# 585/585 [==============================] - 0s 90us/step - loss: 1338.4195 - mean_absolute_error: 1338.4195 - val_loss: 1540.8113 - val_mean_absolute_error: 1540.8113
#
# Epoch 00129: val_loss did not improve from 1134.37295
# Epoch 130/500
# 585/585 [==============================] - 0s 66us/step - loss: 1357.8879 - mean_absolute_error: 1357.8879 - val_loss: 1222.0573 - val_mean_absolute_error: 1222.0573
#
# Epoch 00130: val_loss did not improve from 1134.37295
# Epoch 131/500
# 585/585 [==============================] - 0s 84us/step - loss: 1333.6774 - mean_absolute_error: 1333.6774 - val_loss: 1417.3157 - val_mean_absolute_error: 1417.3157
#
# Epoch 00131: val_loss did not improve from 1134.37295
# Epoch 132/500
# 585/585 [==============================] - 0s 77us/step - loss: 1306.8978 - mean_absolute_error: 1306.8978 - val_loss: 1288.5376 - val_mean_absolute_error: 1288.5376
# Epoch 00132: val_loss did not improve from 1134.37295
# Epoch 133/500
# 585/585 [==============================] - 0s 84us/step - loss: 1310.8237 - mean_absolute_error: 1310.8237 - val_loss: 1239.6923 - val_mean_absolute_error: 1239.6923
#
# Epoch 00133: val_loss did not improve from 1134.37295
# Epoch 134/500
# 585/585 [==============================] - 0s 72us/step - loss: 1300.8099 - mean_absolute_error: 1300.8099 - val_loss: 1237.9290 - val_mean_absolute_error: 1237.9290
#
# Epoch 00134: val_loss did not improve from 1134.37295
# Epoch 135/500
# 585/585 [==============================] - 0s 70us/step - loss: 1297.0849 - mean_absolute_error: 1297.0849 - val_loss: 1492.1992 - val_mean_absolute_error: 1492.1992
#
# Epoch 00135: val_loss did not improve from 1134.37295
# Epoch 136/500
# 585/585 [==============================] - 0s 80us/step - loss: 1373.0226 - mean_absolute_error: 1373.0226 - val_loss: 1208.7356 - val_mean_absolute_error: 1208.7356
#
# Epoch 00136: val_loss did not improve from 1134.37295
# Epoch 137/500
# 585/585 [==============================] - 0s 75us/step - loss: 1324.9986 - mean_absolute_error: 1324.9986 - val_loss: 1452.0736 - val_mean_absolute_error: 1452.0736
#
# Epoch 00137: val_loss did not improve from 1134.37295
# Epoch 138/500
# 585/585 [==============================] - 0s 77us/step - loss: 1291.8510 - mean_absolute_error: 1291.8510 - val_loss: 1392.2698 - val_mean_absolute_error: 1392.2698
#
# Epoch 00138: val_loss did not improve from 1134.37295
# Epoch 139/500
# 585/585 [==============================] - 0s 80us/step - loss: 1297.5444 - mean_absolute_error: 1297.5444 - val_loss: 1230.1899 - val_mean_absolute_error: 1230.1899
#
# Epoch 00139: val_loss did not improve from 1134.37295
# Epoch 140/500
# 585/585 [==============================] - 0s 78us/step - loss: 1300.6719 - mean_absolute_error: 1300.6719 - val_loss: 1297.9265 - val_mean_absolute_error: 1297.9265
#
# Epoch 00140: val_loss did not improve from 1134.37295
# Epoch 141/500
# 585/585 [==============================] - 0s 80us/step - loss: 1298.9147 - mean_absolute_error: 1298.9147 - val_loss: 1215.2463 - val_mean_absolute_error: 1215.2463
#
# Epoch 00141: val_loss did not improve from 1134.37295
# Epoch 142/500
# 585/585 [==============================] - 0s 77us/step - loss: 1302.1772 - mean_absolute_error: 1302.1772 - val_loss: 1135.9770 - val_mean_absolute_error: 1135.9770
#
# Epoch 00142: val_loss did not improve from 1134.37295
# Epoch 143/500
# 585/585 [==============================] - 0s 80us/step - loss: 1329.9077 - mean_absolute_error: 1329.9077 - val_loss: 1354.0168 - val_mean_absolute_error: 1354.0168
#
# Epoch 00143: val_loss did not improve from 1134.37295
# Epoch 144/500
# 585/585 [==============================] - 0s 77us/step - loss: 1311.5642 - mean_absolute_error: 1311.5642 - val_loss: 1246.9938 - val_mean_absolute_error: 1246.9938
#
# Epoch 00144: val_loss did not improve from 1134.37295
# Epoch 145/500
# 585/585 [==============================] - 0s 73us/step - loss: 1312.7532 - mean_absolute_error: 1312.7532 - val_loss: 1121.6486 - val_mean_absolute_error: 1121.6486
#
# Epoch 00145: val_loss improved from 1134.37295 to 1121.64858, saving model to 생수date-Weights-145--1121.64858-cat02-vf05.hdf5
# Epoch 146/500
# 585/585 [==============================] - 0s 73us/step - loss: 1312.6317 - mean_absolute_error: 1312.6317 - val_loss: 1526.5642 - val_mean_absolute_error: 1526.5642
#
# Epoch 00146: val_loss did not improve from 1121.64858
# Epoch 147/500
# 585/585 [==============================] - 0s 75us/step - loss: 1289.1261 - mean_absolute_error: 1289.1261 - val_loss: 1201.4469 - val_mean_absolute_error: 1201.4469
#
# Epoch 00147: val_loss did not improve from 1121.64858
# Epoch 148/500
# 585/585 [==============================] - 0s 80us/step - loss: 1297.9341 - mean_absolute_error: 1297.9341 - val_loss: 1300.4485 - val_mean_absolute_error: 1300.4485
#
# Epoch 00148: val_loss did not improve from 1121.64858
# Epoch 149/500
# 585/585 [==============================] - 0s 80us/step - loss: 1299.8243 - mean_absolute_error: 1299.8243 - val_loss: 1273.0835 - val_mean_absolute_error: 1273.0835
#
# Epoch 00149: val_loss did not improve from 1121.64858
# Epoch 150/500
# 585/585 [==============================] - 0s 84us/step - loss: 1316.6846 - mean_absolute_error: 1316.6846 - val_loss: 1424.4725 - val_mean_absolute_error: 1424.4725
#
# Epoch 00150: val_loss did not improve from 1121.64858
# Epoch 151/500
# 585/585 [==============================] - 0s 78us/step - loss: 1306.2994 - mean_absolute_error: 1306.2994 - val_loss: 1271.7603 - val_mean_absolute_error: 1271.7603
#
# Epoch 00151: val_loss did not improve from 1121.64858
# Epoch 152/500
# 585/585 [==============================] - 0s 80us/step - loss: 1278.4192 - mean_absolute_error: 1278.4192 - val_loss: 1291.4643 - val_mean_absolute_error: 1291.4643
#
# Epoch 00152: val_loss did not improve from 1121.64858
# Epoch 153/500
# 585/585 [==============================] - 0s 68us/step - loss: 1293.5765 - mean_absolute_error: 1293.5765 - val_loss: 1427.3303 - val_mean_absolute_error: 1427.3303
#
# Epoch 00153: val_loss did not improve from 1121.64858
# Epoch 154/500
# 585/585 [==============================] - 0s 77us/step - loss: 1292.0440 - mean_absolute_error: 1292.0440 - val_loss: 1418.1259 - val_mean_absolute_error: 1418.1259
#
# Epoch 00154: val_loss did not improve from 1121.64858
# Epoch 155/500
# 585/585 [==============================] - 0s 78us/step - loss: 1300.9297 - mean_absolute_error: 1300.9297 - val_loss: 1226.7525 - val_mean_absolute_error: 1226.7525
#
# Epoch 00155: val_loss did not improve from 1121.64858
# Epoch 156/500
# 585/585 [==============================] - 0s 78us/step - loss: 1306.9132 - mean_absolute_error: 1306.9132 - val_loss: 1430.9955 - val_mean_absolute_error: 1430.9955
#
# Epoch 00156: val_loss did not improve from 1121.64858
# Epoch 157/500
# 585/585 [==============================] - 0s 77us/step - loss: 1287.6384 - mean_absolute_error: 1287.6384 - val_loss: 1384.8644 - val_mean_absolute_error: 1384.8644
#
# Epoch 00157: val_loss did not improve from 1121.64858
# Epoch 158/500
# 585/585 [==============================] - 0s 68us/step - loss: 1303.7764 - mean_absolute_error: 1303.7764 - val_loss: 1409.9190 - val_mean_absolute_error: 1409.9190
#
# Epoch 00158: val_loss did not improve from 1121.64858
# Epoch 159/500
# 585/585 [==============================] - 0s 77us/step - loss: 1322.2421 - mean_absolute_error: 1322.2421 - val_loss: 1155.5187 - val_mean_absolute_error: 1155.5187
#
# Epoch 00159: val_loss did not improve from 1121.64858
# Epoch 160/500
# 585/585 [==============================] - 0s 70us/step - loss: 1291.1810 - mean_absolute_error: 1291.1810 - val_loss: 1412.8741 - val_mean_absolute_error: 1412.8741
#
# Epoch 00160: val_loss did not improve from 1121.64858
# Epoch 161/500
# 585/585 [==============================] - 0s 66us/step - loss: 1269.5675 - mean_absolute_error: 1269.5675 - val_loss: 1498.2282 - val_mean_absolute_error: 1498.2282
#
# Epoch 00161: val_loss did not improve from 1121.64858
# Epoch 162/500
# 585/585 [==============================] - 0s 72us/step - loss: 1319.3137 - mean_absolute_error: 1319.3137 - val_loss: 1185.0379 - val_mean_absolute_error: 1185.0379
#
# Epoch 00162: val_loss did not improve from 1121.64858
# Epoch 163/500
# 585/585 [==============================] - 0s 75us/step - loss: 1307.4152 - mean_absolute_error: 1307.4152 - val_loss: 1462.2058 - val_mean_absolute_error: 1462.2058
#
# Epoch 00163: val_loss did not improve from 1121.64858
# Epoch 164/500
# 585/585 [==============================] - 0s 82us/step - loss: 1288.4604 - mean_absolute_error: 1288.4604 - val_loss: 1383.2111 - val_mean_absolute_error: 1383.2111
#
# Epoch 00164: val_loss did not improve from 1121.64858
# Epoch 165/500
# 585/585 [==============================] - 0s 78us/step - loss: 1271.7363 - mean_absolute_error: 1271.7363 - val_loss: 1541.1631 - val_mean_absolute_error: 1541.1631
#
# Epoch 00165: val_loss did not improve from 1121.64858
# Epoch 166/500
# 585/585 [==============================] - 0s 66us/step - loss: 1288.2878 - mean_absolute_error: 1288.2878 - val_loss: 1371.9196 - val_mean_absolute_error: 1371.9196
#
# Epoch 00166: val_loss did not improve from 1121.64858
# Epoch 167/500
# 585/585 [==============================] - 0s 92us/step - loss: 1292.0031 - mean_absolute_error: 1292.0031 - val_loss: 1100.8625 - val_mean_absolute_error: 1100.8625
#
# Epoch 00167: val_loss improved from 1121.64858 to 1100.86249, saving model to 생수date-Weights-167--1100.86249-cat02-vf05.hdf5
# Epoch 168/500
# 585/585 [==============================] - 0s 75us/step - loss: 1379.0484 - mean_absolute_error: 1379.0484 - val_loss: 1663.0467 - val_mean_absolute_error: 1663.0467
#
# Epoch 00168: val_loss did not improve from 1100.86249
# Epoch 169/500
# 585/585 [==============================] - 0s 75us/step - loss: 1337.2829 - mean_absolute_error: 1337.2829 - val_loss: 1270.0961 - val_mean_absolute_error: 1270.0961
#
# Epoch 00169: val_loss did not improve from 1100.86249
# Epoch 170/500
# 585/585 [==============================] - 0s 84us/step - loss: 1291.2387 - mean_absolute_error: 1291.2387 - val_loss: 1356.8731 - val_mean_absolute_error: 1356.8731
#
# Epoch 00170: val_loss did not improve from 1100.86249
# Epoch 171/500
# 585/585 [==============================] - 0s 78us/step - loss: 1281.4829 - mean_absolute_error: 1281.4829 - val_loss: 1476.9074 - val_mean_absolute_error: 1476.9074
#
# Epoch 00171: val_loss did not improve from 1100.86249
# Epoch 172/500
# 585/585 [==============================] - 0s 77us/step - loss: 1302.8983 - mean_absolute_error: 1302.8983 - val_loss: 1107.0662 - val_mean_absolute_error: 1107.0662
#
# Epoch 00172: val_loss did not improve from 1100.86249
# Epoch 173/500
# 585/585 [==============================] - 0s 77us/step - loss: 1414.8258 - mean_absolute_error: 1414.8258 - val_loss: 1235.4699 - val_mean_absolute_error: 1235.4699
#
# Epoch 00173: val_loss did not improve from 1100.86249
# Epoch 174/500
# 585/585 [==============================] - 0s 75us/step - loss: 1288.8499 - mean_absolute_error: 1288.8499 - val_loss: 1395.9776 - val_mean_absolute_error: 1395.9776
#
# Epoch 00174: val_loss did not improve from 1100.86249
# Epoch 175/500
# 585/585 [==============================] - 0s 77us/step - loss: 1273.6619 - mean_absolute_error: 1273.6619 - val_loss: 1325.3777 - val_mean_absolute_error: 1325.3777
#
# Epoch 00175: val_loss did not improve from 1100.86249
# Epoch 176/500
# 585/585 [==============================] - 0s 77us/step - loss: 1289.1581 - mean_absolute_error: 1289.1581 - val_loss: 1174.1855 - val_mean_absolute_error: 1174.1855
#
# Epoch 00176: val_loss did not improve from 1100.86249
# Epoch 177/500
# 585/585 [==============================] - 0s 97us/step - loss: 1317.1854 - mean_absolute_error: 1317.1854 - val_loss: 1822.0475 - val_mean_absolute_error: 1822.0475
#
# Epoch 00177: val_loss did not improve from 1100.86249
# Epoch 178/500
# 585/585 [==============================] - 0s 89us/step - loss: 1334.0245 - mean_absolute_error: 1334.0245 - val_loss: 1095.8448 - val_mean_absolute_error: 1095.8448
#
# Epoch 00178: val_loss improved from 1100.86249 to 1095.84476, saving model to 생수date-Weights-178--1095.84476-cat02-vf05.hdf5
# Epoch 179/500
# 585/585 [==============================] - 0s 80us/step - loss: 1432.5009 - mean_absolute_error: 1432.5009 - val_loss: 1221.1479 - val_mean_absolute_error: 1221.1479
#
# Epoch 00179: val_loss did not improve from 1095.84476
# Epoch 180/500
# 585/585 [==============================] - 0s 87us/step - loss: 1274.9406 - mean_absolute_error: 1274.9406 - val_loss: 1391.6528 - val_mean_absolute_error: 1391.6528
#
# Epoch 00180: val_loss did not improve from 1095.84476
# Epoch 181/500
# 585/585 [==============================] - 0s 80us/step - loss: 1282.2409 - mean_absolute_error: 1282.2409 - val_loss: 1327.0414 - val_mean_absolute_error: 1327.0414
#
# Epoch 00181: val_loss did not improve from 1095.84476
# Epoch 182/500
# 585/585 [==============================] - 0s 68us/step - loss: 1266.7783 - mean_absolute_error: 1266.7783 - val_loss: 1491.7664 - val_mean_absolute_error: 1491.7664
#
# Epoch 00182: val_loss did not improve from 1095.84476
# Epoch 183/500
# 585/585 [==============================] - 0s 77us/step - loss: 1275.4134 - mean_absolute_error: 1275.4134 - val_loss: 1228.9186 - val_mean_absolute_error: 1228.9186
#
# Epoch 00183: val_loss did not improve from 1095.84476
# Epoch 184/500
# 585/585 [==============================] - 0s 80us/step - loss: 1286.1208 - mean_absolute_error: 1286.1208 - val_loss: 1350.5526 - val_mean_absolute_error: 1350.5526
#
# Epoch 00184: val_loss did not improve from 1095.84476
# Epoch 185/500
# 585/585 [==============================] - 0s 82us/step - loss: 1265.4986 - mean_absolute_error: 1265.4986 - val_loss: 1592.6443 - val_mean_absolute_error: 1592.6443
#
# Epoch 00185: val_loss did not improve from 1095.84476
# Epoch 186/500
# 585/585 [==============================] - 0s 84us/step - loss: 1271.3704 - mean_absolute_error: 1271.3704 - val_loss: 1434.4510 - val_mean_absolute_error: 1434.4510
#
# Epoch 00186: val_loss did not improve from 1095.84476
# Epoch 187/500
# 585/585 [==============================] - 0s 113us/step - loss: 1258.6295 - mean_absolute_error: 1258.6295 - val_loss: 1222.0148 - val_mean_absolute_error: 1222.0148
#
# Epoch 00187: val_loss did not improve from 1095.84476
# Epoch 188/500
# 585/585 [==============================] - 0s 77us/step - loss: 1289.2015 - mean_absolute_error: 1289.2015 - val_loss: 1391.9583 - val_mean_absolute_error: 1391.9583
#
# Epoch 00188: val_loss did not improve from 1095.84476
# Epoch 189/500
# 585/585 [==============================] - 0s 73us/step - loss: 1264.7188 - mean_absolute_error: 1264.7188 - val_loss: 1418.5207 - val_mean_absolute_error: 1418.5207
#
# Epoch 00189: val_loss did not improve from 1095.84476
# Epoch 190/500
# 585/585 [==============================] - 0s 75us/step - loss: 1265.6824 - mean_absolute_error: 1265.6824 - val_loss: 1542.3588 - val_mean_absolute_error: 1542.3588
#
# Epoch 00190: val_loss did not improve from 1095.84476
# Epoch 191/500
# 585/585 [==============================] - 0s 82us/step - loss: 1266.1776 - mean_absolute_error: 1266.1776 - val_loss: 1262.0795 - val_mean_absolute_error: 1262.0795
#
# Epoch 00191: val_loss did not improve from 1095.84476
# Epoch 192/500
# 585/585 [==============================] - 0s 75us/step - loss: 1290.1523 - mean_absolute_error: 1290.1523 - val_loss: 1233.7568 - val_mean_absolute_error: 1233.7568
#
# Epoch 00192: val_loss did not improve from 1095.84476
# Epoch 193/500
# 585/585 [==============================] - 0s 124us/step - loss: 1263.6105 - mean_absolute_error: 1263.6105 - val_loss: 1199.9832 - val_mean_absolute_error: 1199.9832
#
# Epoch 00193: val_loss did not improve from 1095.84476
# Epoch 194/500
# 585/585 [==============================] - 0s 73us/step - loss: 1319.2435 - mean_absolute_error: 1319.2435 - val_loss: 1365.1793 - val_mean_absolute_error: 1365.1793
#
# Epoch 00194: val_loss did not improve from 1095.84476
# ...
#
# Epoch 00433: val_loss did not improve from 1095.84476
# Epoch 434/500
# 585/585 [==============================] - 0s 135us/step - loss: 1153.9149 - mean_absolute_error: 1153.9149 - val_loss: 1649.0153 - val_mean_absolute_error: 1649.0153
#
# Epoch 00434: val_loss did not improve from 1095.84476
# Epoch 435/500
# 585/585 [==============================] - 0s 121us/step - loss: 1129.6911 - mean_absolute_error: 1129.6911 - val_loss: 1488.3260 - val_mean_absolute_error: 1488.3260
#
# Epoch 00435: val_loss did not improve from 1095.84476
# Epoch 436/500
# 585/585 [==============================] - 0s 135us/step - loss: 1127.4250 - mean_absolute_error: 1127.4250 - val_loss: 1714.7748 - val_mean_absolute_error: 1714.7748
#
# Epoch 00436: val_loss did not improve from 1095.84476
# Epoch 437/500
# 585/585 [==============================] - 0s 121us/step - loss: 1158.2703 - mean_absolute_error: 1158.2703 - val_loss: 1469.9301 - val_mean_absolute_error: 1469.9301
#
# Epoch 00437: val_loss did not improve from 1095.84476
# Epoch 438/500
# 585/585 [==============================] - 0s 118us/step - loss: 1137.6851 - mean_absolute_error: 1137.6851 - val_loss: 1637.4008 - val_mean_absolute_error: 1637.4008
#
# Epoch 00438: val_loss did not improve from 1095.84476
# Epoch 439/500
# 585/585 [==============================] - 0s 126us/step - loss: 1135.9974 - mean_absolute_error: 1135.9974 - val_loss: 1519.9526 - val_mean_absolute_error: 1519.9526
#
# Epoch 00439: val_loss did not improve from 1095.84476
# Epoch 440/500
# 585/585 [==============================] - 0s 130us/step - loss: 1134.4923 - mean_absolute_error: 1134.4923 - val_loss: 1435.1592 - val_mean_absolute_error: 1435.1592
#
# Epoch 00440: val_loss did not improve from 1095.84476
# Epoch 441/500
# 585/585 [==============================] - 0s 119us/step - loss: 1154.3374 - mean_absolute_error: 1154.3374 - val_loss: 1621.1733 - val_mean_absolute_error: 1621.1733
#
# Epoch 00441: val_loss did not improve from 1095.84476
# Epoch 442/500
# 585/585 [==============================] - 0s 119us/step - loss: 1127.4438 - mean_absolute_error: 1127.4438 - val_loss: 1610.5478 - val_mean_absolute_error: 1610.5478
#
# Epoch 00442: val_loss did not improve from 1095.84476
# Epoch 443/500
# 585/585 [==============================] - 0s 107us/step - loss: 1126.8973 - mean_absolute_error: 1126.8973 - val_loss: 1564.7787 - val_mean_absolute_error: 1564.7787
#
# Epoch 00443: val_loss did not improve from 1095.84476
# Epoch 444/500
# 585/585 [==============================] - 0s 131us/step - loss: 1124.5606 - mean_absolute_error: 1124.5606 - val_loss: 1620.0344 - val_mean_absolute_error: 1620.0344
#
# Epoch 00444: val_loss did not improve from 1095.84476
# Epoch 445/500
# 585/585 [==============================] - 0s 130us/step - loss: 1142.2260 - mean_absolute_error: 1142.2260 - val_loss: 1490.7631 - val_mean_absolute_error: 1490.7631
#
# Epoch 00445: val_loss did not improve from 1095.84476
# Epoch 446/500
# 585/585 [==============================] - 0s 128us/step - loss: 1159.7445 - mean_absolute_error: 1159.7445 - val_loss: 1527.0191 - val_mean_absolute_error: 1527.0191
#
# Epoch 00446: val_loss did not improve from 1095.84476
# Epoch 447/500
# 585/585 [==============================] - 0s 121us/step - loss: 1173.4989 - mean_absolute_error: 1173.4989 - val_loss: 1550.3514 - val_mean_absolute_error: 1550.3514
#
# Epoch 00447: val_loss did not improve from 1095.84476
# Epoch 448/500
# 585/585 [==============================] - 0s 121us/step - loss: 1139.8790 - mean_absolute_error: 1139.8790 - val_loss: 1388.5820 - val_mean_absolute_error: 1388.5820
#
# Epoch 00448: val_loss did not improve from 1095.84476
# Epoch 449/500
# 585/585 [==============================] - 0s 111us/step - loss: 1187.1479 - mean_absolute_error: 1187.1479 - val_loss: 1669.4745 - val_mean_absolute_error: 1669.4745
#
# Epoch 00449: val_loss did not improve from 1095.84476
# Epoch 450/500
# 585/585 [==============================] - 0s 123us/step - loss: 1130.9364 - mean_absolute_error: 1130.9364 - val_loss: 1524.0170 - val_mean_absolute_error: 1524.0170
#
# Epoch 00450: val_loss did not improve from 1095.84476
# Epoch 451/500
# 585/585 [==============================] - 0s 138us/step - loss: 1123.0124 - mean_absolute_error: 1123.0124 - val_loss: 1512.6435 - val_mean_absolute_error: 1512.6435
#
# Epoch 00451: val_loss did not improve from 1095.84476
# Epoch 452/500
# 585/585 [==============================] - 0s 130us/step - loss: 1122.3950 - mean_absolute_error: 1122.3950 - val_loss: 1684.8192 - val_mean_absolute_error: 1684.8192
#
# Epoch 00452: val_loss did not improve from 1095.84476
# Epoch 453/500
# 585/585 [==============================] - 0s 113us/step - loss: 1138.3401 - mean_absolute_error: 1138.3401 - val_loss: 1446.7961 - val_mean_absolute_error: 1446.7961
#
# Epoch 00453: val_loss did not improve from 1095.84476
# Epoch 454/500
# 585/585 [==============================] - 0s 124us/step - loss: 1161.2260 - mean_absolute_error: 1161.2260 - val_loss: 1774.7157 - val_mean_absolute_error: 1774.7157
#
# Epoch 00454: val_loss did not improve from 1095.84476
# Epoch 455/500
# 585/585 [==============================] - 0s 119us/step - loss: 1170.6415 - mean_absolute_error: 1170.6415 - val_loss: 1514.9963 - val_mean_absolute_error: 1514.9963
#
# Epoch 00455: val_loss did not improve from 1095.84476
# Epoch 456/500
# 585/585 [==============================] - 0s 123us/step - loss: 1172.3255 - mean_absolute_error: 1172.3255 - val_loss: 1514.9971 - val_mean_absolute_error: 1514.9971
#
# Epoch 00456: val_loss did not improve from 1095.84476
# Epoch 457/500
# 585/585 [==============================] - 0s 124us/step - loss: 1133.2649 - mean_absolute_error: 1133.2649 - val_loss: 1400.9146 - val_mean_absolute_error: 1400.9146
#
# Epoch 00457: val_loss did not improve from 1095.84476
# Epoch 458/500
# 585/585 [==============================] - 0s 126us/step - loss: 1146.5937 - mean_absolute_error: 1146.5937 - val_loss: 1597.8404 - val_mean_absolute_error: 1597.8404
#
# Epoch 00458: val_loss did not improve from 1095.84476
# Epoch 459/500
# 585/585 [==============================] - 0s 119us/step - loss: 1159.1852 - mean_absolute_error: 1159.1852 - val_loss: 1570.3338 - val_mean_absolute_error: 1570.3338
#
# Epoch 00459: val_loss did not improve from 1095.84476
# Epoch 460/500
# 585/585 [==============================] - 0s 116us/step - loss: 1120.3687 - mean_absolute_error: 1120.3687 - val_loss: 1502.9342 - val_mean_absolute_error: 1502.9342
#
# Epoch 00460: val_loss did not improve from 1095.84476
# Epoch 461/500
# 585/585 [==============================] - 0s 128us/step - loss: 1122.2302 - mean_absolute_error: 1122.2302 - val_loss: 1658.0867 - val_mean_absolute_error: 1658.0867
#
# Epoch 00461: val_loss did not improve from 1095.84476
# Epoch 462/500
# 585/585 [==============================] - 0s 109us/step - loss: 1115.6396 - mean_absolute_error: 1115.6396 - val_loss: 1574.9275 - val_mean_absolute_error: 1574.9275
#
# Epoch 00462: val_loss did not improve from 1095.84476
# Epoch 463/500
# 585/585 [==============================] - 0s 126us/step - loss: 1146.8654 - mean_absolute_error: 1146.8654 - val_loss: 1367.5881 - val_mean_absolute_error: 1367.5881
#
# Epoch 00463: val_loss did not improve from 1095.84476
# Epoch 464/500
# 585/585 [==============================] - 0s 118us/step - loss: 1136.1197 - mean_absolute_error: 1136.1197 - val_loss: 1937.3101 - val_mean_absolute_error: 1937.3101
#
# Epoch 00464: val_loss did not improve from 1095.84476
# Epoch 465/500
# 585/585 [==============================] - 0s 116us/step - loss: 1155.0180 - mean_absolute_error: 1155.0180 - val_loss: 1405.4759 - val_mean_absolute_error: 1405.4759
#
# Epoch 00465: val_loss did not improve from 1095.84476
# Epoch 466/500
# 585/585 [==============================] - 0s 123us/step - loss: 1123.4548 - mean_absolute_error: 1123.4548 - val_loss: 1780.8694 - val_mean_absolute_error: 1780.8694
#
# Epoch 00466: val_loss did not improve from 1095.84476
# Epoch 467/500
# 585/585 [==============================] - 0s 116us/step - loss: 1141.2039 - mean_absolute_error: 1141.2039 - val_loss: 1478.3966 - val_mean_absolute_error: 1478.3966
#
# Epoch 00467: val_loss did not improve from 1095.84476
# Epoch 468/500
# 585/585 [==============================] - 0s 111us/step - loss: 1113.0168 - mean_absolute_error: 1113.0168 - val_loss: 1612.2082 - val_mean_absolute_error: 1612.2082
#
# Epoch 00468: val_loss did not improve from 1095.84476
# Epoch 469/500
# 585/585 [==============================] - 0s 124us/step - loss: 1130.4608 - mean_absolute_error: 1130.4608 - val_loss: 1637.7175 - val_mean_absolute_error: 1637.7175
#
# Epoch 00469: val_loss did not improve from 1095.84476
# Epoch 470/500
# 585/585 [==============================] - 0s 131us/step - loss: 1118.7199 - mean_absolute_error: 1118.7199 - val_loss: 1574.0384 - val_mean_absolute_error: 1574.0384
#
# Epoch 00470: val_loss did not improve from 1095.84476
# Epoch 471/500
# 585/585 [==============================] - 0s 126us/step - loss: 1130.4882 - mean_absolute_error: 1130.4882 - val_loss: 1439.9756 - val_mean_absolute_error: 1439.9756
#
# Epoch 00471: val_loss did not improve from 1095.84476
# Epoch 472/500
# 585/585 [==============================] - 0s 116us/step - loss: 1131.8453 - mean_absolute_error: 1131.8453 - val_loss: 1625.4836 - val_mean_absolute_error: 1625.4836
#
# Epoch 00472: val_loss did not improve from 1095.84476
# Epoch 473/500
# 585/585 [==============================] - 0s 109us/step - loss: 1130.8866 - mean_absolute_error: 1130.8866 - val_loss: 1635.7267 - val_mean_absolute_error: 1635.7267
#
# Epoch 00473: val_loss did not improve from 1095.84476
# Epoch 474/500
# 585/585 [==============================] - 0s 124us/step - loss: 1117.7685 - mean_absolute_error: 1117.7685 - val_loss: 1573.2078 - val_mean_absolute_error: 1573.2078
#
# Epoch 00474: val_loss did not improve from 1095.84476
# Epoch 475/500
# 585/585 [==============================] - 0s 124us/step - loss: 1136.1007 - mean_absolute_error: 1136.1007 - val_loss: 1690.3066 - val_mean_absolute_error: 1690.3066
#
# Epoch 00475: val_loss did not improve from 1095.84476
# Epoch 476/500
# 585/585 [==============================] - 0s 116us/step - loss: 1131.0024 - mean_absolute_error: 1131.0024 - val_loss: 1524.9775 - val_mean_absolute_error: 1524.9775
#
# Epoch 00476: val_loss did not improve from 1095.84476
# Epoch 477/500
# 585/585 [==============================] - 0s 124us/step - loss: 1107.4110 - mean_absolute_error: 1107.4110 - val_loss: 1539.6179 - val_mean_absolute_error: 1539.6179
#
# Epoch 00477: val_loss did not improve from 1095.84476
# Epoch 478/500
# 585/585 [==============================] - 0s 130us/step - loss: 1120.4146 - mean_absolute_error: 1120.4146 - val_loss: 1501.9451 - val_mean_absolute_error: 1501.9451
#
# Epoch 00478: val_loss did not improve from 1095.84476
# Epoch 479/500
# 585/585 [==============================] - 0s 128us/step - loss: 1177.5769 - mean_absolute_error: 1177.5769 - val_loss: 1531.6489 - val_mean_absolute_error: 1531.6489
#
# Epoch 00479: val_loss did not improve from 1095.84476
# Epoch 480/500
# 585/585 [==============================] - 0s 128us/step - loss: 1112.8105 - mean_absolute_error: 1112.8105 - val_loss: 2036.2235 - val_mean_absolute_error: 2036.2235
#
# Epoch 00480: val_loss did not improve from 1095.84476
# Epoch 481/500
# 585/585 [==============================] - 0s 119us/step - loss: 1194.1794 - mean_absolute_error: 1194.1794 - val_loss: 1604.8097 - val_mean_absolute_error: 1604.8097
#
# Epoch 00481: val_loss did not improve from 1095.84476
# Epoch 482/500
# 585/585 [==============================] - 0s 107us/step - loss: 1124.1299 - mean_absolute_error: 1124.1299 - val_loss: 1619.4995 - val_mean_absolute_error: 1619.4995
#
# Epoch 00482: val_loss did not improve from 1095.84476
# Epoch 483/500
# 585/585 [==============================] - 0s 111us/step - loss: 1147.5783 - mean_absolute_error: 1147.5783 - val_loss: 1566.6646 - val_mean_absolute_error: 1566.6646
#
# Epoch 00483: val_loss did not improve from 1095.84476
# Epoch 484/500
# 585/585 [==============================] - 0s 126us/step - loss: 1117.1890 - mean_absolute_error: 1117.1890 - val_loss: 1544.7249 - val_mean_absolute_error: 1544.7249
#
# Epoch 00484: val_loss did not improve from 1095.84476
# Epoch 485/500
# 585/585 [==============================] - 0s 118us/step - loss: 1116.7225 - mean_absolute_error: 1116.7225 - val_loss: 1549.3776 - val_mean_absolute_error: 1549.3776
#
# Epoch 00485: val_loss did not improve from 1095.84476
# Epoch 486/500
# 585/585 [==============================] - 0s 126us/step - loss: 1118.3272 - mean_absolute_error: 1118.3272 - val_loss: 1720.1500 - val_mean_absolute_error: 1720.1500
#
# Epoch 00486: val_loss did not improve from 1095.84476
# Epoch 487/500
# 585/585 [==============================] - 0s 113us/step - loss: 1119.6507 - mean_absolute_error: 1119.6507 - val_loss: 1554.7084 - val_mean_absolute_error: 1554.7084
#
# Epoch 00487: val_loss did not improve from 1095.84476
# Epoch 488/500
# 585/585 [==============================] - 0s 123us/step - loss: 1106.3161 - mean_absolute_error: 1106.3161 - val_loss: 1560.6973 - val_mean_absolute_error: 1560.6973
#
# Epoch 00488: val_loss did not improve from 1095.84476
# Epoch 489/500
# 585/585 [==============================] - 0s 126us/step - loss: 1105.3053 - mean_absolute_error: 1105.3053 - val_loss: 1551.2533 - val_mean_absolute_error: 1551.2533
#
# Epoch 00489: val_loss did not improve from 1095.84476
# Epoch 490/500
# 585/585 [==============================] - 0s 114us/step - loss: 1101.0132 - mean_absolute_error: 1101.0132 - val_loss: 1485.2182 - val_mean_absolute_error: 1485.2182
#
# Epoch 00490: val_loss did not improve from 1095.84476
# Epoch 491/500
# 585/585 [==============================] - 0s 121us/step - loss: 1111.1005 - mean_absolute_error: 1111.1005 - val_loss: 1585.6807 - val_mean_absolute_error: 1585.6807
#
# Epoch 00491: val_loss did not improve from 1095.84476
# Epoch 492/500
# 585/585 [==============================] - 0s 102us/step - loss: 1121.0726 - mean_absolute_error: 1121.0726 - val_loss: 1711.6718 - val_mean_absolute_error: 1711.6718
#
# Epoch 00492: val_loss did not improve from 1095.84476
# Epoch 493/500
# 585/585 [==============================] - 0s 116us/step - loss: 1135.0839 - mean_absolute_error: 1135.0839 - val_loss: 1622.6997 - val_mean_absolute_error: 1622.6997
#
# Epoch 00493: val_loss did not improve from 1095.84476
# Epoch 494/500
# 585/585 [==============================] - 0s 111us/step - loss: 1138.1859 - mean_absolute_error: 1138.1859 - val_loss: 1354.3254 - val_mean_absolute_error: 1354.3254
#
# Epoch 00494: val_loss did not improve from 1095.84476
# Epoch 495/500
# 585/585 [==============================] - 0s 109us/step - loss: 1123.8678 - mean_absolute_error: 1123.8678 - val_loss: 1572.2343 - val_mean_absolute_error: 1572.2343
#
# Epoch 00495: val_loss did not improve from 1095.84476
# Epoch 496/500
# 585/585 [==============================] - 0s 116us/step - loss: 1101.8392 - mean_absolute_error: 1101.8392 - val_loss: 1465.9225 - val_mean_absolute_error: 1465.9225
#
# Epoch 00496: val_loss did not improve from 1095.84476
# Epoch 497/500
# 585/585 [==============================] - 0s 116us/step - loss: 1111.3420 - mean_absolute_error: 1111.3420 - val_loss: 1659.8654 - val_mean_absolute_error: 1659.8654
#
# Epoch 00497: val_loss did not improve from 1095.84476
# Epoch 498/500
# 585/585 [==============================] - 0s 124us/step - loss: 1119.2841 - mean_absolute_error: 1119.2841 - val_loss: 1362.4953 - val_mean_absolute_error: 1362.4953
#
# Epoch 00498: val_loss did not improve from 1095.84476
# Epoch 499/500
# 585/585 [==============================] - 0s 123us/step - loss: 1138.0202 - mean_absolute_error: 1138.0202 - val_loss: 1694.9123 - val_mean_absolute_error: 1694.9123
#
# Epoch 00499: val_loss did not improve from 1095.84476
# Epoch 500/500
# 585/585 [==============================] - 0s 119us/step - loss: 1098.0249 - mean_absolute_error: 1098.0249 - val_loss: 1433.1884 - val_mean_absolute_error: 1433.1884
#
# Epoch 00500: val_loss did not improve from 1095.84476

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = '생수date-Weights-178--1095.84476-cat02-vf05.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# Out:
# W0719 18:54:24.744735  1636 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0719 18:54:24.744735  1636 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']

print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

columns_in_data = list(train_X.columns)
customF = formulaGen(target='qty',ind_features=columns_in_data)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
print('검증세트점수 : {:.3f}'.format( r2_score(val_y, olsModel.predict(val_X))   ) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.922
# 검증세트점수 : 0.024
# XGBoost을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.753
# 검증세트점수 : 0.277
# LinearRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.607
# 검증세트점수 : 0.262
# RidgeRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.600
# 검증세트점수 : 0.253
# LassoRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.607
# 검증세트점수 : 0.261
# OLS을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.607
# 검증세트점수 : 0.262

# %%
print(item, 'ols model')

# columns_in_data = ['temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not', 'snow_or_not',
#                     '공기상태_0', '공기상태_1', '공기상태_2']

# formulaGen은 단순 1차 다항식을 제조해준다.
# customF = formulaGen(target='qty',ind_features=columns_in_data)
customF = formulaGen(target='qty',ind_features=['temp', 'wind','lgt_time','rain_or_not'])
# customF = 'qty ~ temp + cloud  + rain_or_not + 공기상태_0 + 공기상태_1+공기상태_2'

olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()

print('사람이 직접 식을 때려 박았을때 : {:.3f}'.format(r2_score(val_y, olsModel.predict(val_X))) )

olsModel.summary()
# Out:
# 생수 ols model
# 사람이 직접 식을 때려 박았을때 : 0.176
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.599
# Model:                            OLS   Adj. R-squared:                  0.597
# Method:                 Least Squares   F-statistic:                     271.5
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          1.19e-142
# Time:                        18:54:25   Log-Likelihood:                -6506.8
# No. Observations:                 732   AIC:                         1.302e+04
# Df Residuals:                     727   BIC:                         1.305e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    7613.4165    274.438     27.742      0.000    7074.630    8152.203
# temp          184.4513      6.102     30.230      0.000     172.472     196.430
# wind         -298.8762    100.603     -2.971      0.003    -496.384    -101.368
# lgt_time      113.1948     20.254      5.589      0.000      73.431     152.959
# rain_or_not  -485.5637    177.625     -2.734      0.006    -834.283    -136.844
# ==============================================================================
# Omnibus:                      146.139   Durbin-Watson:                   1.257
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              360.660
# Skew:                           1.039   Prob(JB):                     4.83e-79
# Kurtosis:                       5.740   Cond. No.                         80.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
#             '공기상태_0', '공기상태_1', '공기상태_2']
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
            '공기상태']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = gs_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 예측률 계산
# https://yamalab.tistory.com/46

# RMSE (Root Mean Squared Error) : 
# OLS 추정에서 일반적인 표준 오차이다. 예측 대상의 scale(단위 크기)에 주의해야하는 단점이 있다. 
# MSE는 root를 수식에서 제외, SSE는 root와 분모를 제외한 수식으로, SE가 붙은 척도들은 거기서 거기인 척도들이라고 보면 된다.
# 다만 디테일한 사용법에 차이가 있을 뿐.

# MAPE (Mean Absolute Percentage Error) :

# 위 방법의 단점을 보완한 것이다. 
# At는 실제값, Ft는 예측값인데, 이를 At로 나누어서 오차를 절대적 크기로 보는것이 아닌
# 비율의 크기로 보고자 하는 것이 핵심이다.
# 이 방법은 At가 0에 가까울수록 비정상적인 값이 나온다는 단점이 있다.

# MAPE가 0에 가까울수록 좋은 모델
result_df['mape_keras'] = abs((result_df.qty - result_df.keras_qty) / result_df.qty )
result_df['mape_rf'] = abs((result_df.qty - result_df.rf_qty) / result_df.qty )
result_df['mape_xgb'] = abs((result_df.qty - result_df.xgb_qty) / result_df.qty )
result_df['mape_lin'] = abs((result_df.qty - result_df.lin_qty) / result_df.qty )
result_df['mape_ridge'] = abs((result_df.qty - result_df.ridge_qty) / result_df.qty )
result_df['mape_lasso'] = abs((result_df.qty - result_df.lasso_qty) / result_df.qty )
result_df['mape_ols'] = abs((result_df.qty - result_df.ols_qty) / result_df.qty )

print('Keras 인공 신경망 모델 MAPE \t: {:<.2f}'.format(result_df['mape_keras'].sum() / result_df.shape[0] ))
print('RandomForest 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_rf'].sum() / result_df.shape[0] ))
print('XGBoosting  모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_xgb'].sum() / result_df.shape[0] ))
print('Linear 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lin'].sum() / result_df.shape[0] ))
print('Ridge 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_ridge'].sum() / result_df.shape[0] ))
print('Lasso 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lasso'].sum() / result_df.shape[0] ))
print('OLS 모델 MAPE \t\t\t: {:<.2f}'.format(result_df['mape_ols'].sum() / result_df.shape[0] ))
# Out:
# Keras 인공 신경망 모델 MAPE 	: 0.14
# RandomForest 모델 MAPE 		: 0.11
# XGBoosting  모델 MAPE 		: 0.13
# Linear 모델 MAPE 		: 0.15
# Ridge 모델 MAPE 		: 0.16
# Lasso 모델 MAPE 		: 0.15
# OLS 모델 MAPE 			: 0.16

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not','snow_or_not', 
#                                                   '공기상태_0', '공기상태_1', '공기상태_2']

# 1~9 : 1 temp ~ 9 공기상태_2
n= 1
# alpha 값 0~1
alp = 0.8
# scatter plot 점 크기
dot_size = 10

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# # 1~106 / 106~156
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
