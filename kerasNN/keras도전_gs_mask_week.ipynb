# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor


# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1))
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df

# %%
# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '마스크'만 빼서 df생성
item = '마스크'
gruoped_by = 'week'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %% [markdown]
# # 주단위로 종합해보기

# %%
gs_week_w = gs_day_w.copy()
gs_week_w = addDayWeek(gs_week_w)

cols_Ineed = ['week','category', 'qty', 'temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
gs_week_w = gs_week_w[cols_Ineed]

# %%
gs_week_w = gs_week_w.groupby('week').mean().reset_index()
gs_week_w.tail(2)
# week: 1~105 = 2016~2017년
# week: 106~157 = 2018년
train_data = gs_week_w.loc[gs_week_w.week <=105]
test_date = gs_week_w.loc[gs_week_w.week >105]

# %%
# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
combined = gs_week_w.iloc[:,3:]
target = gs_week_w.iloc[:,2]

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 34
# Number of nun-numerical columns with no nan values : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 34 columns before encoding categorical features
# There are 34 columns after encoding categorical features

# %%
# 여기서 이코드으 제작자는 수동으로 훈련/검증셋을 나눔
# 105주 기준으로 나누겠음
cut_line = 106
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

# %%
train.shape
# Out:
# (106, 34)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 10:27:07.048184  6836 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 10:27:07.064141  6836 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 10:27:07.066112  6836 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0717 10:27:07.119990  6836 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               4480
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 169,345
# Trainable params: 169,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'GS-maskWeek-Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로, 자료의 record수가 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=106을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0717 10:27:22.518944  6836 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0717 10:27:22.626657  6836 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 84 samples, validate on 22 samples
# Epoch 1/500
# 84/84 [==============================] - 0s 3ms/step - loss: 100.1828 - mean_absolute_error: 100.1828 - val_loss: 11.7148 - val_mean_absolute_error: 11.7148
#
# Epoch 00001: val_loss improved from inf to 11.71478, saving model to GS-maskWeek-Weights-001--11.71478.hdf5
# Epoch 2/500
# 84/84 [==============================] - 0s 95us/step - loss: 47.2540 - mean_absolute_error: 47.2540 - val_loss: 41.3998 - val_mean_absolute_error: 41.3998
#
# Epoch 00002: val_loss did not improve from 11.71478
# Epoch 3/500
# 84/84 [==============================] - 0s 154us/step - loss: 28.6580 - mean_absolute_error: 28.6580 - val_loss: 28.6303 - val_mean_absolute_error: 28.6303
#
# Epoch 00003: val_loss did not improve from 11.71478
# Epoch 4/500
# 84/84 [==============================] - 0s 142us/step - loss: 21.2919 - mean_absolute_error: 21.2919 - val_loss: 21.3054 - val_mean_absolute_error: 21.3054
#
# Epoch 00004: val_loss did not improve from 11.71478
# Epoch 5/500
# 84/84 [==============================] - 0s 107us/step - loss: 16.3236 - mean_absolute_error: 16.3236 - val_loss: 11.5271 - val_mean_absolute_error: 11.5271
#
# Epoch 00005: val_loss improved from 11.71478 to 11.52712, saving model to GS-maskWeek-Weights-005--11.52712.hdf5
# Epoch 6/500
# 84/84 [==============================] - 0s 107us/step - loss: 12.5918 - mean_absolute_error: 12.5918 - val_loss: 9.8340 - val_mean_absolute_error: 9.8340
#
# Epoch 00006: val_loss improved from 11.52712 to 9.83399, saving model to GS-maskWeek-Weights-006--9.83399.hdf5
# Epoch 7/500
# 84/84 [==============================] - 0s 131us/step - loss: 9.9012 - mean_absolute_error: 9.9012 - val_loss: 10.5466 - val_mean_absolute_error: 10.5466
#
# Epoch 00007: val_loss did not improve from 9.83399
# Epoch 8/500
# 84/84 [==============================] - 0s 95us/step - loss: 9.0484 - mean_absolute_error: 9.0484 - val_loss: 10.4500 - val_mean_absolute_error: 10.4500
#
# Epoch 00008: val_loss did not improve from 9.83399
# Epoch 9/500
# 84/84 [==============================] - 0s 107us/step - loss: 9.4549 - mean_absolute_error: 9.4549 - val_loss: 9.6038 - val_mean_absolute_error: 9.6038
#
# Epoch 00009: val_loss improved from 9.83399 to 9.60380, saving model to GS-maskWeek-Weights-009--9.60380.hdf5
# Epoch 10/500
# 84/84 [==============================] - 0s 95us/step - loss: 8.8712 - mean_absolute_error: 8.8712 - val_loss: 9.5218 - val_mean_absolute_error: 9.5218
#
# Epoch 00010: val_loss improved from 9.60380 to 9.52180, saving model to GS-maskWeek-Weights-010--9.52180.hdf5
# Epoch 11/500
# 84/84 [==============================] - 0s 119us/step - loss: 8.8647 - mean_absolute_error: 8.8647 - val_loss: 9.3974 - val_mean_absolute_error: 9.3974
#
# Epoch 00011: val_loss improved from 9.52180 to 9.39736, saving model to GS-maskWeek-Weights-011--9.39736.hdf5
# Epoch 12/500
# 84/84 [==============================] - 0s 107us/step - loss: 9.2267 - mean_absolute_error: 9.2267 - val_loss: 9.3091 - val_mean_absolute_error: 9.3091
#
# Epoch 00012: val_loss improved from 9.39736 to 9.30910, saving model to GS-maskWeek-Weights-012--9.30910.hdf5
# Epoch 13/500
# 84/84 [==============================] - 0s 119us/step - loss: 8.4519 - mean_absolute_error: 8.4519 - val_loss: 9.6300 - val_mean_absolute_error: 9.6300
#
# Epoch 00013: val_loss did not improve from 9.30910
# Epoch 14/500
# 84/84 [==============================] - 0s 119us/step - loss: 8.3304 - mean_absolute_error: 8.3304 - val_loss: 9.9365 - val_mean_absolute_error: 9.9365
#
# Epoch 00014: val_loss did not improve from 9.30910
# Epoch 15/500
# 84/84 [==============================] - 0s 142us/step - loss: 9.0069 - mean_absolute_error: 9.0069 - val_loss: 9.4910 - val_mean_absolute_error: 9.4910
#
# Epoch 00015: val_loss did not improve from 9.30910
# Epoch 16/500
# 84/84 [==============================] - 0s 107us/step - loss: 8.6657 - mean_absolute_error: 8.6657 - val_loss: 8.8823 - val_mean_absolute_error: 8.8823
#
# Epoch 00016: val_loss improved from 9.30910 to 8.88231, saving model to GS-maskWeek-Weights-016--8.88231.hdf5
# Epoch 17/500
# 84/84 [==============================] - 0s 95us/step - loss: 7.9927 - mean_absolute_error: 7.9927 - val_loss: 8.9061 - val_mean_absolute_error: 8.9061
#
# Epoch 00017: val_loss did not improve from 8.88231
# Epoch 18/500
# 84/84 [==============================] - 0s 107us/step - loss: 7.8452 - mean_absolute_error: 7.8452 - val_loss: 8.7560 - val_mean_absolute_error: 8.7560
#
# Epoch 00018: val_loss improved from 8.88231 to 8.75596, saving model to GS-maskWeek-Weights-018--8.75596.hdf5
# Epoch 19/500
# 84/84 [==============================] - 0s 95us/step - loss: 7.8467 - mean_absolute_error: 7.8467 - val_loss: 8.7754 - val_mean_absolute_error: 8.7754
#
# Epoch 00019: val_loss did not improve from 8.75596
# Epoch 20/500
# 84/84 [==============================] - 0s 119us/step - loss: 8.4696 - mean_absolute_error: 8.4696 - val_loss: 8.7334 - val_mean_absolute_error: 8.7334
#
# Epoch 00020: val_loss improved from 8.75596 to 8.73338, saving model to GS-maskWeek-Weights-020--8.73338.hdf5
# Epoch 21/500
# 84/84 [==============================] - 0s 131us/step - loss: 9.0927 - mean_absolute_error: 9.0927 - val_loss: 8.6913 - val_mean_absolute_error: 8.6913
#
# Epoch 00021: val_loss improved from 8.73338 to 8.69130, saving model to GS-maskWeek-Weights-021--8.69130.hdf5
# Epoch 22/500
# 84/84 [==============================] - 0s 107us/step - loss: 12.3164 - mean_absolute_error: 12.3164 - val_loss: 9.4865 - val_mean_absolute_error: 9.4865
#
# Epoch 00022: val_loss did not improve from 8.69130
# Epoch 23/500
# 84/84 [==============================] - 0s 95us/step - loss: 11.5859 - mean_absolute_error: 11.5859 - val_loss: 11.6146 - val_mean_absolute_error: 11.6146
#
# Epoch 00023: val_loss did not improve from 8.69130
# Epoch 24/500
# 84/84 [==============================] - 0s 166us/step - loss: 9.4529 - mean_absolute_error: 9.4529 - val_loss: 11.9174 - val_mean_absolute_error: 11.9174
#
# Epoch 00024: val_loss did not improve from 8.69130
# Epoch 25/500
# 84/84 [==============================] - 0s 142us/step - loss: 12.3829 - mean_absolute_error: 12.3829 - val_loss: 10.3970 - val_mean_absolute_error: 10.3970
#
# Epoch 00025: val_loss did not improve from 8.69130
# Epoch 26/500
# 84/84 [==============================] - 0s 142us/step - loss: 8.5462 - mean_absolute_error: 8.5462 - val_loss: 10.8068 - val_mean_absolute_error: 10.8068
#
# Epoch 00026: val_loss did not improve from 8.69130
# Epoch 27/500
# 84/84 [==============================] - 0s 142us/step - loss: 10.3614 - mean_absolute_error: 10.3614 - val_loss: 10.0108 - val_mean_absolute_error: 10.0108
#
# Epoch 00027: val_loss did not improve from 8.69130
# Epoch 28/500
# 84/84 [==============================] - 0s 131us/step - loss: 9.1959 - mean_absolute_error: 9.1959 - val_loss: 10.6342 - val_mean_absolute_error: 10.6342
#
# Epoch 00028: val_loss did not improve from 8.69130
# Epoch 29/500
# 84/84 [==============================] - 0s 131us/step - loss: 8.8458 - mean_absolute_error: 8.8458 - val_loss: 9.6956 - val_mean_absolute_error: 9.6956
#
# Epoch 00029: val_loss did not improve from 8.69130
# Epoch 30/500
# 84/84 [==============================] - 0s 95us/step - loss: 8.3965 - mean_absolute_error: 8.3965 - val_loss: 9.7442 - val_mean_absolute_error: 9.7442
#
# Epoch 00030: val_loss did not improve from 8.69130
# Epoch 31/500
# 84/84 [==============================] - 0s 107us/step - loss: 8.3792 - mean_absolute_error: 8.3792 - val_loss: 9.3208 - val_mean_absolute_error: 9.3208
#
# Epoch 00031: val_loss did not improve from 8.69130
# Epoch 32/500
# 84/84 [==============================] - 0s 142us/step - loss: 7.8520 - mean_absolute_error: 7.8520 - val_loss: 9.1637 - val_mean_absolute_error: 9.1637
#
# Epoch 00032: val_loss did not improve from 8.69130
# Epoch 33/500
# 84/84 [==============================] - 0s 142us/step - loss: 7.8556 - mean_absolute_error: 7.8556 - val_loss: 9.0680 - val_mean_absolute_error: 9.0680
#
# Epoch 00033: val_loss did not improve from 8.69130
# Epoch 34/500
# 84/84 [==============================] - 0s 107us/step - loss: 7.6421 - mean_absolute_error: 7.6421 - val_loss: 9.2298 - val_mean_absolute_error: 9.2298
#
# Epoch 00034: val_loss did not improve from 8.69130
# Epoch 35/500
# 84/84 [==============================] - 0s 107us/step - loss: 7.8326 - mean_absolute_error: 7.8326 - val_loss: 8.7250 - val_mean_absolute_error: 8.7250
#
# Epoch 00035: val_loss did not improve from 8.69130
# Epoch 36/500
# 84/84 [==============================] - 0s 142us/step - loss: 7.1120 - mean_absolute_error: 7.1120 - val_loss: 8.7772 - val_mean_absolute_error: 8.7772
#
# Epoch 00036: val_loss did not improve from 8.69130
# Epoch 37/500
# 84/84 [==============================] - 0s 142us/step - loss: 7.1214 - mean_absolute_error: 7.1214 - val_loss: 8.6061 - val_mean_absolute_error: 8.6061
#
# Epoch 00037: val_loss improved from 8.69130 to 8.60608, saving model to GS-maskWeek-Weights-037--8.60608.hdf5
# Epoch 38/500
# 84/84 [==============================] - 0s 119us/step - loss: 7.0022 - mean_absolute_error: 7.0022 - val_loss: 8.1038 - val_mean_absolute_error: 8.1038
#
# Epoch 00038: val_loss improved from 8.60608 to 8.10378, saving model to GS-maskWeek-Weights-038--8.10378.hdf5
# Epoch 39/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.5068 - mean_absolute_error: 6.5068 - val_loss: 8.1325 - val_mean_absolute_error: 8.1325
#
# Epoch 00039: val_loss did not improve from 8.10378
# Epoch 40/500
# 84/84 [==============================] - 0s 119us/step - loss: 6.4245 - mean_absolute_error: 6.4245 - val_loss: 8.0123 - val_mean_absolute_error: 8.0123
#
# Epoch 00040: val_loss improved from 8.10378 to 8.01233, saving model to GS-maskWeek-Weights-040--8.01233.hdf5
# Epoch 41/500
# 84/84 [==============================] - 0s 119us/step - loss: 6.2807 - mean_absolute_error: 6.2807 - val_loss: 7.9096 - val_mean_absolute_error: 7.9096
#
# Epoch 00041: val_loss improved from 8.01233 to 7.90956, saving model to GS-maskWeek-Weights-041--7.90956.hdf5
# Epoch 42/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.6945 - mean_absolute_error: 6.6945 - val_loss: 7.6914 - val_mean_absolute_error: 7.6914
#
# Epoch 00042: val_loss improved from 7.90956 to 7.69144, saving model to GS-maskWeek-Weights-042--7.69144.hdf5
# Epoch 43/500
# 84/84 [==============================] - 0s 131us/step - loss: 6.5550 - mean_absolute_error: 6.5550 - val_loss: 7.8636 - val_mean_absolute_error: 7.8636
#
# Epoch 00043: val_loss did not improve from 7.69144
# Epoch 44/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.5659 - mean_absolute_error: 6.5659 - val_loss: 8.8876 - val_mean_absolute_error: 8.8876
#
# Epoch 00044: val_loss did not improve from 7.69144
# Epoch 45/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.6492 - mean_absolute_error: 6.6492 - val_loss: 8.6506 - val_mean_absolute_error: 8.6506
#
# Epoch 00045: val_loss did not improve from 7.69144
# Epoch 46/500
# 84/84 [==============================] - 0s 131us/step - loss: 6.3360 - mean_absolute_error: 6.3360 - val_loss: 7.9186 - val_mean_absolute_error: 7.9186
#
# Epoch 00046: val_loss did not improve from 7.69144
# Epoch 47/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.9066 - mean_absolute_error: 5.9066 - val_loss: 7.6289 - val_mean_absolute_error: 7.6289
#
# Epoch 00047: val_loss improved from 7.69144 to 7.62886, saving model to GS-maskWeek-Weights-047--7.62886.hdf5
# Epoch 48/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.2131 - mean_absolute_error: 6.2131 - val_loss: 8.2682 - val_mean_absolute_error: 8.2682
#
# Epoch 00048: val_loss did not improve from 7.62886
# Epoch 49/500
# 84/84 [==============================] - 0s 107us/step - loss: 8.0341 - mean_absolute_error: 8.0341 - val_loss: 12.1787 - val_mean_absolute_error: 12.1787
#
# Epoch 00049: val_loss did not improve from 7.62886
# Epoch 50/500
# 84/84 [==============================] - 0s 131us/step - loss: 8.8020 - mean_absolute_error: 8.8020 - val_loss: 9.3536 - val_mean_absolute_error: 9.3536
#
# Epoch 00050: val_loss did not improve from 7.62886
# Epoch 51/500
# 84/84 [==============================] - 0s 119us/step - loss: 8.8617 - mean_absolute_error: 8.8617 - val_loss: 10.0430 - val_mean_absolute_error: 10.0430
#
# Epoch 00051: val_loss did not improve from 7.62886
# Epoch 52/500
# 84/84 [==============================] - 0s 131us/step - loss: 8.2588 - mean_absolute_error: 8.2588 - val_loss: 9.5010 - val_mean_absolute_error: 9.5010
#
# Epoch 00052: val_loss did not improve from 7.62886
# Epoch 53/500
# 84/84 [==============================] - 0s 107us/step - loss: 7.3751 - mean_absolute_error: 7.3751 - val_loss: 8.8986 - val_mean_absolute_error: 8.8986
#
# Epoch 00053: val_loss did not improve from 7.62886
# Epoch 54/500
# 84/84 [==============================] - 0s 119us/step - loss: 6.7060 - mean_absolute_error: 6.7060 - val_loss: 9.0927 - val_mean_absolute_error: 9.0927
#
# Epoch 00054: val_loss did not improve from 7.62886
# Epoch 55/500
# 84/84 [==============================] - 0s 131us/step - loss: 7.0522 - mean_absolute_error: 7.0522 - val_loss: 8.5506 - val_mean_absolute_error: 8.5506
#
# Epoch 00055: val_loss did not improve from 7.62886
# Epoch 56/500
# 84/84 [==============================] - 0s 143us/step - loss: 6.5701 - mean_absolute_error: 6.5701 - val_loss: 8.3967 - val_mean_absolute_error: 8.3967
#
# Epoch 00056: val_loss did not improve from 7.62886
# Epoch 57/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.3858 - mean_absolute_error: 6.3858 - val_loss: 8.4325 - val_mean_absolute_error: 8.4325
#
# Epoch 00057: val_loss did not improve from 7.62886
# Epoch 58/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.8212 - mean_absolute_error: 5.8212 - val_loss: 8.5789 - val_mean_absolute_error: 8.5789
#
# Epoch 00058: val_loss did not improve from 7.62886
# Epoch 59/500
# 84/84 [==============================] - 0s 154us/step - loss: 6.0461 - mean_absolute_error: 6.0461 - val_loss: 8.4125 - val_mean_absolute_error: 8.4125
#
# Epoch 00059: val_loss did not improve from 7.62886
# Epoch 60/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.7980 - mean_absolute_error: 5.7980 - val_loss: 8.4236 - val_mean_absolute_error: 8.4236
#
# Epoch 00060: val_loss did not improve from 7.62886
# Epoch 61/500
# 84/84 [==============================] - 0s 119us/step - loss: 5.6532 - mean_absolute_error: 5.6532 - val_loss: 8.2756 - val_mean_absolute_error: 8.2756
#
# Epoch 00061: val_loss did not improve from 7.62886
# Epoch 62/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.5298 - mean_absolute_error: 5.5298 - val_loss: 8.9470 - val_mean_absolute_error: 8.9470
#
# Epoch 00062: val_loss did not improve from 7.62886
# Epoch 63/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.5150 - mean_absolute_error: 5.5150 - val_loss: 8.4291 - val_mean_absolute_error: 8.4291
#
# Epoch 00063: val_loss did not improve from 7.62886
# Epoch 64/500
# 84/84 [==============================] - 0s 154us/step - loss: 5.4552 - mean_absolute_error: 5.4552 - val_loss: 8.2630 - val_mean_absolute_error: 8.2630
#
# Epoch 00064: val_loss did not improve from 7.62886
# Epoch 65/500
# 84/84 [==============================] - 0s 142us/step - loss: 5.1879 - mean_absolute_error: 5.1879 - val_loss: 8.3286 - val_mean_absolute_error: 8.3286
#
# Epoch 00065: val_loss did not improve from 7.62886
# Epoch 66/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.3663 - mean_absolute_error: 5.3663 - val_loss: 12.8475 - val_mean_absolute_error: 12.8475
#
# Epoch 00066: val_loss did not improve from 7.62886
# Epoch 67/500
# 84/84 [==============================] - 0s 95us/step - loss: 6.5489 - mean_absolute_error: 6.5489 - val_loss: 9.9421 - val_mean_absolute_error: 9.9421
#
# Epoch 00067: val_loss did not improve from 7.62886
# Epoch 68/500
# 84/84 [==============================] - 0s 119us/step - loss: 9.1482 - mean_absolute_error: 9.1482 - val_loss: 9.5621 - val_mean_absolute_error: 9.5621
#
# Epoch 00068: val_loss did not improve from 7.62886
# Epoch 69/500
# 84/84 [==============================] - 0s 119us/step - loss: 6.6929 - mean_absolute_error: 6.6929 - val_loss: 8.8430 - val_mean_absolute_error: 8.8430
#
# Epoch 00069: val_loss did not improve from 7.62886
# Epoch 70/500
# 84/84 [==============================] - 0s 95us/step - loss: 6.6732 - mean_absolute_error: 6.6732 - val_loss: 8.5469 - val_mean_absolute_error: 8.5469
#
# Epoch 00070: val_loss did not improve from 7.62886
# Epoch 71/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.8226 - mean_absolute_error: 5.8226 - val_loss: 11.1470 - val_mean_absolute_error: 11.1470
#
# Epoch 00071: val_loss did not improve from 7.62886
# Epoch 72/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.9636 - mean_absolute_error: 6.9636 - val_loss: 8.9535 - val_mean_absolute_error: 8.9535
#
# Epoch 00072: val_loss did not improve from 7.62886
# Epoch 73/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.8240 - mean_absolute_error: 5.8240 - val_loss: 8.5432 - val_mean_absolute_error: 8.5432
#
# Epoch 00073: val_loss did not improve from 7.62886
# Epoch 74/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.0512 - mean_absolute_error: 6.0512 - val_loss: 9.0942 - val_mean_absolute_error: 9.0942
#
# Epoch 00074: val_loss did not improve from 7.62886
# Epoch 75/500
# 84/84 [==============================] - 0s 107us/step - loss: 6.1708 - mean_absolute_error: 6.1708 - val_loss: 8.8440 - val_mean_absolute_error: 8.8440
#
# Epoch 00075: val_loss did not improve from 7.62886
# Epoch 76/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.9392 - mean_absolute_error: 5.9392 - val_loss: 8.5875 - val_mean_absolute_error: 8.5875
#
# Epoch 00076: val_loss did not improve from 7.62886
# Epoch 77/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.2702 - mean_absolute_error: 5.2702 - val_loss: 8.5062 - val_mean_absolute_error: 8.5062
#
# Epoch 00077: val_loss did not improve from 7.62886
# Epoch 78/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.9960 - mean_absolute_error: 5.9960 - val_loss: 8.3764 - val_mean_absolute_error: 8.3764
#
# Epoch 00078: val_loss did not improve from 7.62886
# Epoch 79/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.1575 - mean_absolute_error: 5.1575 - val_loss: 9.1251 - val_mean_absolute_error: 9.1251
#
# Epoch 00079: val_loss did not improve from 7.62886
# Epoch 80/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.0684 - mean_absolute_error: 5.0684 - val_loss: 8.9164 - val_mean_absolute_error: 8.9164
#
# Epoch 00080: val_loss did not improve from 7.62886
# Epoch 81/500
# 84/84 [==============================] - 0s 142us/step - loss: 5.2607 - mean_absolute_error: 5.2607 - val_loss: 8.2472 - val_mean_absolute_error: 8.2472
#
# Epoch 00081: val_loss did not improve from 7.62886
# Epoch 82/500
# 84/84 [==============================] - 0s 119us/step - loss: 5.7428 - mean_absolute_error: 5.7428 - val_loss: 10.6317 - val_mean_absolute_error: 10.6317
#
# Epoch 00082: val_loss did not improve from 7.62886
# Epoch 83/500
# 84/84 [==============================] - 0s 119us/step - loss: 6.3391 - mean_absolute_error: 6.3391 - val_loss: 9.0847 - val_mean_absolute_error: 9.0847
#
# Epoch 00083: val_loss did not improve from 7.62886
# Epoch 84/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.0361 - mean_absolute_error: 5.0361 - val_loss: 7.5563 - val_mean_absolute_error: 7.5563
#
# Epoch 00084: val_loss improved from 7.62886 to 7.55627, saving model to GS-maskWeek-Weights-084--7.55627.hdf5
# Epoch 85/500
# 84/84 [==============================] - 0s 119us/step - loss: 4.4577 - mean_absolute_error: 4.4577 - val_loss: 7.6450 - val_mean_absolute_error: 7.6450
#
# Epoch 00085: val_loss did not improve from 7.55627
# Epoch 86/500
# 84/84 [==============================] - 0s 107us/step - loss: 4.6058 - mean_absolute_error: 4.6058 - val_loss: 11.6768 - val_mean_absolute_error: 11.6768
#
# Epoch 00086: val_loss did not improve from 7.55627
# Epoch 87/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.7917 - mean_absolute_error: 5.7917 - val_loss: 9.7395 - val_mean_absolute_error: 9.7395
#
# Epoch 00087: val_loss did not improve from 7.55627
# Epoch 88/500
# 84/84 [==============================] - 0s 131us/step - loss: 6.0741 - mean_absolute_error: 6.0741 - val_loss: 11.3772 - val_mean_absolute_error: 11.3772
#
# Epoch 00088: val_loss did not improve from 7.55627
# Epoch 89/500
# 84/84 [==============================] - 0s 131us/step - loss: 7.0761 - mean_absolute_error: 7.0761 - val_loss: 7.9052 - val_mean_absolute_error: 7.9052
#
# Epoch 00089: val_loss did not improve from 7.55627
# Epoch 90/500
# 84/84 [==============================] - 0s 95us/step - loss: 4.8866 - mean_absolute_error: 4.8866 - val_loss: 8.4018 - val_mean_absolute_error: 8.4018
#
# Epoch 00090: val_loss did not improve from 7.55627
# Epoch 91/500
# 84/84 [==============================] - 0s 131us/step - loss: 4.3327 - mean_absolute_error: 4.3327 - val_loss: 8.6942 - val_mean_absolute_error: 8.6942
#
# Epoch 00091: val_loss did not improve from 7.55627
# Epoch 92/500
# 84/84 [==============================] - 0s 131us/step - loss: 4.8341 - mean_absolute_error: 4.8341 - val_loss: 11.4904 - val_mean_absolute_error: 11.4904
#
# Epoch 00092: val_loss did not improve from 7.55627
# Epoch 93/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.2604 - mean_absolute_error: 5.2604 - val_loss: 8.8944 - val_mean_absolute_error: 8.8944
#
# Epoch 00093: val_loss did not improve from 7.55627
# Epoch 94/500
# 84/84 [==============================] - 0s 119us/step - loss: 5.1076 - mean_absolute_error: 5.1076 - val_loss: 9.8607 - val_mean_absolute_error: 9.8607
#
# Epoch 00094: val_loss did not improve from 7.55627
# Epoch 95/500
# 84/84 [==============================] - 0s 119us/step - loss: 5.5163 - mean_absolute_error: 5.5163 - val_loss: 8.1474 - val_mean_absolute_error: 8.1474
#
# Epoch 00095: val_loss did not improve from 7.55627
# Epoch 96/500
# 84/84 [==============================] - 0s 107us/step - loss: 4.5588 - mean_absolute_error: 4.5588 - val_loss: 13.9359 - val_mean_absolute_error: 13.9359
#
# Epoch 00096: val_loss did not improve from 7.55627
# Epoch 97/500
# 84/84 [==============================] - 0s 142us/step - loss: 6.8835 - mean_absolute_error: 6.8835 - val_loss: 9.2281 - val_mean_absolute_error: 9.2281
#
# Epoch 00097: val_loss did not improve from 7.55627
# Epoch 98/500
# 84/84 [==============================] - 0s 119us/step - loss: 6.7475 - mean_absolute_error: 6.7475 - val_loss: 9.0097 - val_mean_absolute_error: 9.0097
#
# Epoch 00098: val_loss did not improve from 7.55627
# Epoch 99/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.7387 - mean_absolute_error: 5.7387 - val_loss: 9.0343 - val_mean_absolute_error: 9.0343
#
# Epoch 00099: val_loss did not improve from 7.55627
# Epoch 100/500
# 84/84 [==============================] - 0s 154us/step - loss: 4.8039 - mean_absolute_error: 4.8039 - val_loss: 8.7432 - val_mean_absolute_error: 8.7432
#
# Epoch 00100: val_loss did not improve from 7.55627
# Epoch 101/500
# 84/84 [==============================] - 0s 131us/step - loss: 5.0298 - mean_absolute_error: 5.0298 - val_loss: 11.8190 - val_mean_absolute_error: 11.8190
#
# Epoch 00101: val_loss did not improve from 7.55627
# Epoch 102/500
# 84/84 [==============================] - 0s 95us/step - loss: 4.7028 - mean_absolute_error: 4.7028 - val_loss: 9.4044 - val_mean_absolute_error: 9.4044
#
# Epoch 00102: val_loss did not improve from 7.55627
# Epoch 103/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.9628 - mean_absolute_error: 3.9628 - val_loss: 10.2177 - val_mean_absolute_error: 10.2177
#
# Epoch 00103: val_loss did not improve from 7.55627
# Epoch 104/500
# 84/84 [==============================] - 0s 131us/step - loss: 4.6506 - mean_absolute_error: 4.6506 - val_loss: 8.6018 - val_mean_absolute_error: 8.6018
#
# Epoch 00104: val_loss did not improve from 7.55627
# Epoch 105/500
# 84/84 [==============================] - 0s 142us/step - loss: 4.0012 - mean_absolute_error: 4.0012 - val_loss: 8.7735 - val_mean_absolute_error: 8.7735
#
# Epoch 00105: val_loss did not improve from 7.55627
# Epoch 106/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.7742 - mean_absolute_error: 3.7742 - val_loss: 11.1241 - val_mean_absolute_error: 11.1241
#
# Epoch 00106: val_loss did not improve from 7.55627
# Epoch 107/500
# 84/84 [==============================] - 0s 107us/step - loss: 4.2727 - mean_absolute_error: 4.2727 - val_loss: 8.4988 - val_mean_absolute_error: 8.4988
#
# Epoch 00107: val_loss did not improve from 7.55627
# Epoch 108/500
# 84/84 [==============================] - 0s 95us/step - loss: 4.9307 - mean_absolute_error: 4.9307 - val_loss: 10.6477 - val_mean_absolute_error: 10.6477
#
# Epoch 00108: val_loss did not improve from 7.55627
# Epoch 109/500
# 84/84 [==============================] - 0s 95us/step - loss: 5.1052 - mean_absolute_error: 5.1052 - val_loss: 8.0025 - val_mean_absolute_error: 8.0025
#
# Epoch 00109: val_loss did not improve from 7.55627
# Epoch 110/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.5262 - mean_absolute_error: 5.5262 - val_loss: 10.3879 - val_mean_absolute_error: 10.3879
#
# Epoch 00110: val_loss did not improve from 7.55627
# Epoch 111/500
# 84/84 [==============================] - 0s 119us/step - loss: 5.7832 - mean_absolute_error: 5.7832 - val_loss: 10.3012 - val_mean_absolute_error: 10.3012
#
# Epoch 00111: val_loss did not improve from 7.55627
# Epoch 112/500
# 84/84 [==============================] - 0s 95us/step - loss: 4.6061 - mean_absolute_error: 4.6061 - val_loss: 8.5274 - val_mean_absolute_error: 8.5274
#
# Epoch 00112: val_loss did not improve from 7.55627
# Epoch 113/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.7968 - mean_absolute_error: 3.7968 - val_loss: 7.3519 - val_mean_absolute_error: 7.3519
#
# Epoch 00113: val_loss improved from 7.55627 to 7.35190, saving model to GS-maskWeek-Weights-113--7.35190.hdf5
# Epoch 114/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.8514 - mean_absolute_error: 3.8514 - val_loss: 8.1477 - val_mean_absolute_error: 8.1477
#
# Epoch 00114: val_loss did not improve from 7.35190
# Epoch 115/500
# 84/84 [==============================] - 0s 95us/step - loss: 3.6467 - mean_absolute_error: 3.6467 - val_loss: 11.8277 - val_mean_absolute_error: 11.8277
#
# Epoch 00115: val_loss did not improve from 7.35190
# Epoch 116/500
# 84/84 [==============================] - 0s 95us/step - loss: 4.1332 - mean_absolute_error: 4.1332 - val_loss: 9.5680 - val_mean_absolute_error: 9.5680
#
# Epoch 00116: val_loss did not improve from 7.35190
# Epoch 117/500
# 84/84 [==============================] - 0s 131us/step - loss: 4.9594 - mean_absolute_error: 4.9594 - val_loss: 11.0913 - val_mean_absolute_error: 11.0913
#
# Epoch 00117: val_loss did not improve from 7.35190
# Epoch 118/500
# 84/84 [==============================] - 0s 95us/step - loss: 4.3399 - mean_absolute_error: 4.3399 - val_loss: 8.2520 - val_mean_absolute_error: 8.2520
#
# Epoch 00118: val_loss did not improve from 7.35190
# Epoch 119/500
# 84/84 [==============================] - 0s 95us/step - loss: 3.6851 - mean_absolute_error: 3.6851 - val_loss: 8.1819 - val_mean_absolute_error: 8.1819
#
# Epoch 00119: val_loss did not improve from 7.35190
# Epoch 120/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.2018 - mean_absolute_error: 3.2018 - val_loss: 9.0812 - val_mean_absolute_error: 9.0812
#
# Epoch 00120: val_loss did not improve from 7.35190
# Epoch 121/500
# 84/84 [==============================] - 0s 154us/step - loss: 2.9312 - mean_absolute_error: 2.9312 - val_loss: 8.7577 - val_mean_absolute_error: 8.7577
#
# Epoch 00121: val_loss did not improve from 7.35190
# Epoch 122/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.1117 - mean_absolute_error: 3.1117 - val_loss: 9.0547 - val_mean_absolute_error: 9.0547
#
# Epoch 00122: val_loss did not improve from 7.35190
# Epoch 123/500
# 84/84 [==============================] - 0s 95us/step - loss: 3.0729 - mean_absolute_error: 3.0729 - val_loss: 8.6807 - val_mean_absolute_error: 8.6807
#
# Epoch 00123: val_loss did not improve from 7.35190
# Epoch 124/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.5319 - mean_absolute_error: 3.5319 - val_loss: 11.4681 - val_mean_absolute_error: 11.4681
#
# Epoch 00124: val_loss did not improve from 7.35190
# Epoch 125/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.4579 - mean_absolute_error: 3.4579 - val_loss: 8.3936 - val_mean_absolute_error: 8.3936
#
# Epoch 00125: val_loss did not improve from 7.35190
# Epoch 126/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.9910 - mean_absolute_error: 3.9910 - val_loss: 10.8540 - val_mean_absolute_error: 10.8540
#
# Epoch 00126: val_loss did not improve from 7.35190
# Epoch 127/500
# 84/84 [==============================] - 0s 154us/step - loss: 4.1756 - mean_absolute_error: 4.1756 - val_loss: 8.2108 - val_mean_absolute_error: 8.2108
#
# Epoch 00127: val_loss did not improve from 7.35190
# Epoch 128/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.2337 - mean_absolute_error: 3.2337 - val_loss: 7.1066 - val_mean_absolute_error: 7.1066
#
# Epoch 00128: val_loss improved from 7.35190 to 7.10657, saving model to GS-maskWeek-Weights-128--7.10657.hdf5
# Epoch 129/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.4003 - mean_absolute_error: 3.4003 - val_loss: 10.6105 - val_mean_absolute_error: 10.6105
#
# Epoch 00129: val_loss did not improve from 7.10657
# Epoch 130/500
# 84/84 [==============================] - 0s 142us/step - loss: 3.3325 - mean_absolute_error: 3.3325 - val_loss: 10.6699 - val_mean_absolute_error: 10.6699
#
# Epoch 00130: val_loss did not improve from 7.10657
# Epoch 131/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.4348 - mean_absolute_error: 3.4348 - val_loss: 9.7311 - val_mean_absolute_error: 9.7311
#
# Epoch 00131: val_loss did not improve from 7.10657
# Epoch 132/500
# 84/84 [==============================] - 0s 142us/step - loss: 2.9267 - mean_absolute_error: 2.9267 - val_loss: 9.0337 - val_mean_absolute_error: 9.0337
#
# Epoch 00132: val_loss did not improve from 7.10657
# Epoch 133/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.9308 - mean_absolute_error: 2.9308 - val_loss: 8.5815 - val_mean_absolute_error: 8.5815
#
# Epoch 00133: val_loss did not improve from 7.10657
# Epoch 134/500
# 84/84 [==============================] - 0s 130us/step - loss: 3.3841 - mean_absolute_error: 3.3841 - val_loss: 13.3825 - val_mean_absolute_error: 13.3825
#
# Epoch 00134: val_loss did not improve from 7.10657
# Epoch 135/500
# 84/84 [==============================] - 0s 142us/step - loss: 4.5402 - mean_absolute_error: 4.5402 - val_loss: 9.7123 - val_mean_absolute_error: 9.7123
#
# Epoch 00135: val_loss did not improve from 7.10657
# Epoch 136/500
# 84/84 [==============================] - 0s 107us/step - loss: 4.8985 - mean_absolute_error: 4.8985 - val_loss: 9.3340 - val_mean_absolute_error: 9.3340
#
# Epoch 00136: val_loss did not improve from 7.10657
# Epoch 137/500
# 84/84 [==============================] - 0s 142us/step - loss: 4.3478 - mean_absolute_error: 4.3478 - val_loss: 7.6344 - val_mean_absolute_error: 7.6344
#
# Epoch 00137: val_loss did not improve from 7.10657
# Epoch 138/500
# 84/84 [==============================] - 0s 142us/step - loss: 3.3738 - mean_absolute_error: 3.3738 - val_loss: 9.9596 - val_mean_absolute_error: 9.9596
#
# Epoch 00138: val_loss did not improve from 7.10657
# Epoch 139/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.7878 - mean_absolute_error: 3.7878 - val_loss: 13.1199 - val_mean_absolute_error: 13.1199
#
# Epoch 00139: val_loss did not improve from 7.10657
# Epoch 140/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.8344 - mean_absolute_error: 3.8344 - val_loss: 8.6579 - val_mean_absolute_error: 8.6579
#
# Epoch 00140: val_loss did not improve from 7.10657
# Epoch 141/500
# 84/84 [==============================] - 0s 131us/step - loss: 6.2740 - mean_absolute_error: 6.2740 - val_loss: 8.6710 - val_mean_absolute_error: 8.6710
#
# Epoch 00141: val_loss did not improve from 7.10657
# Epoch 142/500
# 84/84 [==============================] - 0s 137us/step - loss: 5.7347 - mean_absolute_error: 5.7347 - val_loss: 12.6666 - val_mean_absolute_error: 12.6666
#
# Epoch 00142: val_loss did not improve from 7.10657
# Epoch 143/500
# 84/84 [==============================] - 0s 95us/step - loss: 5.3201 - mean_absolute_error: 5.3201 - val_loss: 10.4912 - val_mean_absolute_error: 10.4912
#
# Epoch 00143: val_loss did not improve from 7.10657
# Epoch 144/500
# 84/84 [==============================] - 0s 107us/step - loss: 5.0895 - mean_absolute_error: 5.0895 - val_loss: 9.1856 - val_mean_absolute_error: 9.1856
#
# Epoch 00144: val_loss did not improve from 7.10657
# Epoch 145/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.9906 - mean_absolute_error: 3.9906 - val_loss: 6.8490 - val_mean_absolute_error: 6.8490
#
# Epoch 00145: val_loss improved from 7.10657 to 6.84900, saving model to GS-maskWeek-Weights-145--6.84900.hdf5
# Epoch 146/500
# 84/84 [==============================] - 0s 142us/step - loss: 3.8011 - mean_absolute_error: 3.8011 - val_loss: 8.3090 - val_mean_absolute_error: 8.3090
#
# Epoch 00146: val_loss did not improve from 6.84900
# Epoch 147/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.4749 - mean_absolute_error: 3.4749 - val_loss: 10.8724 - val_mean_absolute_error: 10.8724
#
# Epoch 00147: val_loss did not improve from 6.84900
# Epoch 148/500
# 84/84 [==============================] - 0s 109us/step - loss: 3.6055 - mean_absolute_error: 3.6055 - val_loss: 10.8008 - val_mean_absolute_error: 10.8008
#
# Epoch 00148: val_loss did not improve from 6.84900
# Epoch 149/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.6791 - mean_absolute_error: 3.6791 - val_loss: 9.7834 - val_mean_absolute_error: 9.7834
#
# Epoch 00149: val_loss did not improve from 6.84900
# Epoch 150/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.0603 - mean_absolute_error: 3.0603 - val_loss: 8.8872 - val_mean_absolute_error: 8.8872
#
# Epoch 00150: val_loss did not improve from 6.84900
# Epoch 151/500
# 84/84 [==============================] - 0s 142us/step - loss: 3.1065 - mean_absolute_error: 3.1065 - val_loss: 8.5049 - val_mean_absolute_error: 8.5049
#
# Epoch 00151: val_loss did not improve from 6.84900
# Epoch 152/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.9997 - mean_absolute_error: 2.9997 - val_loss: 9.5210 - val_mean_absolute_error: 9.5210
#
# Epoch 00152: val_loss did not improve from 6.84900
# Epoch 153/500
# 84/84 [==============================] - 0s 107us/step - loss: 2.5385 - mean_absolute_error: 2.5385 - val_loss: 9.6753 - val_mean_absolute_error: 9.6753
#
# Epoch 00153: val_loss did not improve from 6.84900
# Epoch 154/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.6039 - mean_absolute_error: 2.6039 - val_loss: 10.5292 - val_mean_absolute_error: 10.5292
#
# Epoch 00154: val_loss did not improve from 6.84900
# Epoch 155/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.0522 - mean_absolute_error: 3.0522 - val_loss: 8.8565 - val_mean_absolute_error: 8.8565
#
# Epoch 00155: val_loss did not improve from 6.84900
# Epoch 156/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.9441 - mean_absolute_error: 3.9441 - val_loss: 10.1202 - val_mean_absolute_error: 10.1202
#
# Epoch 00156: val_loss did not improve from 6.84900
# Epoch 157/500
# 84/84 [==============================] - 0s 125us/step - loss: 3.0120 - mean_absolute_error: 3.0120 - val_loss: 8.2409 - val_mean_absolute_error: 8.2409
#
# Epoch 00157: val_loss did not improve from 6.84900
# Epoch 158/500
# 84/84 [==============================] - 0s 131us/step - loss: 4.3627 - mean_absolute_error: 4.3627 - val_loss: 9.6399 - val_mean_absolute_error: 9.6399
#
# Epoch 00158: val_loss did not improve from 6.84900
# Epoch 159/500
# 84/84 [==============================] - 0s 131us/step - loss: 4.1126 - mean_absolute_error: 4.1126 - val_loss: 9.3396 - val_mean_absolute_error: 9.3396
#
# Epoch 00159: val_loss did not improve from 6.84900
# Epoch 160/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.8076 - mean_absolute_error: 3.8076 - val_loss: 12.2892 - val_mean_absolute_error: 12.2892
#
# Epoch 00160: val_loss did not improve from 6.84900
# Epoch 161/500
# 84/84 [==============================] - 0s 119us/step - loss: 4.1325 - mean_absolute_error: 4.1325 - val_loss: 8.2743 - val_mean_absolute_error: 8.2743
#
# Epoch 00161: val_loss did not improve from 6.84900
# Epoch 162/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.5531 - mean_absolute_error: 3.5531 - val_loss: 11.8052 - val_mean_absolute_error: 11.8052
#
# Epoch 00162: val_loss did not improve from 6.84900
# Epoch 163/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.1973 - mean_absolute_error: 3.1973 - val_loss: 9.5098 - val_mean_absolute_error: 9.5098
#
# Epoch 00163: val_loss did not improve from 6.84900
# Epoch 164/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.4723 - mean_absolute_error: 3.4723 - val_loss: 8.2162 - val_mean_absolute_error: 8.2162
#
# Epoch 00164: val_loss did not improve from 6.84900
# Epoch 165/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.2573 - mean_absolute_error: 3.2573 - val_loss: 8.7868 - val_mean_absolute_error: 8.7868
#
# Epoch 00165: val_loss did not improve from 6.84900
# Epoch 166/500
# 84/84 [==============================] - 0s 125us/step - loss: 2.8245 - mean_absolute_error: 2.8245 - val_loss: 10.1005 - val_mean_absolute_error: 10.1005
#
# Epoch 00166: val_loss did not improve from 6.84900
# Epoch 167/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.5126 - mean_absolute_error: 2.5126 - val_loss: 8.7647 - val_mean_absolute_error: 8.7647
#
# Epoch 00167: val_loss did not improve from 6.84900
# Epoch 168/500
# 84/84 [==============================] - 0s 119us/step - loss: 3.4569 - mean_absolute_error: 3.4569 - val_loss: 11.1423 - val_mean_absolute_error: 11.1423
#
# Epoch 00168: val_loss did not improve from 6.84900
# Epoch 169/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.9498 - mean_absolute_error: 2.9498 - val_loss: 8.4670 - val_mean_absolute_error: 8.4670
#
# Epoch 00169: val_loss did not improve from 6.84900
# Epoch 170/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.4660 - mean_absolute_error: 2.4660 - val_loss: 10.7813 - val_mean_absolute_error: 10.7813
#
# Epoch 00170: val_loss did not improve from 6.84900
# Epoch 171/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.1845 - mean_absolute_error: 2.1845 - val_loss: 10.2603 - val_mean_absolute_error: 10.2603
#
# Epoch 00171: val_loss did not improve from 6.84900
# Epoch 172/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.3291 - mean_absolute_error: 2.3291 - val_loss: 9.7664 - val_mean_absolute_error: 9.7664
#
# Epoch 00172: val_loss did not improve from 6.84900
# Epoch 173/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.0308 - mean_absolute_error: 2.0308 - val_loss: 9.6022 - val_mean_absolute_error: 9.6022
#
# Epoch 00173: val_loss did not improve from 6.84900
# Epoch 174/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.8972 - mean_absolute_error: 1.8972 - val_loss: 8.0014 - val_mean_absolute_error: 8.0014
#
# Epoch 00174: val_loss did not improve from 6.84900
# Epoch 175/500
# 84/84 [==============================] - 0s 134us/step - loss: 2.2046 - mean_absolute_error: 2.2046 - val_loss: 12.3255 - val_mean_absolute_error: 12.3255
#
# Epoch 00175: val_loss did not improve from 6.84900
# Epoch 176/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.6444 - mean_absolute_error: 2.6444 - val_loss: 9.4940 - val_mean_absolute_error: 9.4940
#
# Epoch 00176: val_loss did not improve from 6.84900
# Epoch 177/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.4191 - mean_absolute_error: 3.4191 - val_loss: 10.9718 - val_mean_absolute_error: 10.9718
#
# Epoch 00177: val_loss did not improve from 6.84900
# Epoch 178/500
# 84/84 [==============================] - 0s 95us/step - loss: 2.6191 - mean_absolute_error: 2.6191 - val_loss: 8.4986 - val_mean_absolute_error: 8.4986
#
# Epoch 00178: val_loss did not improve from 6.84900
# Epoch 179/500
# 84/84 [==============================] - 0s 107us/step - loss: 2.7260 - mean_absolute_error: 2.7260 - val_loss: 9.9948 - val_mean_absolute_error: 9.9948
#
# Epoch 00179: val_loss did not improve from 6.84900
# Epoch 180/500
# 84/84 [==============================] - 0s 107us/step - loss: 2.2456 - mean_absolute_error: 2.2456 - val_loss: 9.1665 - val_mean_absolute_error: 9.1665
#
# Epoch 00180: val_loss did not improve from 6.84900
# Epoch 181/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.4958 - mean_absolute_error: 2.4958 - val_loss: 8.9435 - val_mean_absolute_error: 8.9435
#
# Epoch 00181: val_loss did not improve from 6.84900
# Epoch 182/500
# 84/84 [==============================] - 0s 107us/step - loss: 2.8888 - mean_absolute_error: 2.8888 - val_loss: 9.4895 - val_mean_absolute_error: 9.4895
#
# Epoch 00182: val_loss did not improve from 6.84900
# Epoch 183/500
# 84/84 [==============================] - 0s 95us/step - loss: 3.0874 - mean_absolute_error: 3.0874 - val_loss: 9.0959 - val_mean_absolute_error: 9.0959
#
# Epoch 00183: val_loss did not improve from 6.84900
# Epoch 184/500
# 84/84 [==============================] - 0s 95us/step - loss: 2.9063 - mean_absolute_error: 2.9063 - val_loss: 8.7860 - val_mean_absolute_error: 8.7860
#
# Epoch 00184: val_loss did not improve from 6.84900
# Epoch 185/500
# 84/84 [==============================] - 0s 137us/step - loss: 2.8585 - mean_absolute_error: 2.8585 - val_loss: 10.3126 - val_mean_absolute_error: 10.3126
#
# Epoch 00185: val_loss did not improve from 6.84900
# Epoch 186/500
# 84/84 [==============================] - 0s 142us/step - loss: 2.8264 - mean_absolute_error: 2.8264 - val_loss: 8.1898 - val_mean_absolute_error: 8.1898
#
# Epoch 00186: val_loss did not improve from 6.84900
# Epoch 187/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.3917 - mean_absolute_error: 3.3917 - val_loss: 11.1976 - val_mean_absolute_error: 11.1976
#
# Epoch 00187: val_loss did not improve from 6.84900
# Epoch 188/500
# 84/84 [==============================] - 0s 95us/step - loss: 3.2950 - mean_absolute_error: 3.2950 - val_loss: 8.3565 - val_mean_absolute_error: 8.3565
#
# Epoch 00188: val_loss did not improve from 6.84900
# Epoch 189/500
# 84/84 [==============================] - 0s 154us/step - loss: 2.3070 - mean_absolute_error: 2.3070 - val_loss: 13.4390 - val_mean_absolute_error: 13.4390
#
# Epoch 00189: val_loss did not improve from 6.84900
# Epoch 190/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.5473 - mean_absolute_error: 3.5473 - val_loss: 9.9039 - val_mean_absolute_error: 9.9039
#
# Epoch 00190: val_loss did not improve from 6.84900
# Epoch 191/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.6860 - mean_absolute_error: 2.6860 - val_loss: 8.5367 - val_mean_absolute_error: 8.5367
#
# Epoch 00191: val_loss did not improve from 6.84900
# Epoch 192/500
# 84/84 [==============================] - 0s 107us/step - loss: 3.1340 - mean_absolute_error: 3.1340 - val_loss: 9.9036 - val_mean_absolute_error: 9.9036
#
# Epoch 00192: val_loss did not improve from 6.84900
# Epoch 193/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.9310 - mean_absolute_error: 2.9310 - val_loss: 9.6372 - val_mean_absolute_error: 9.6372
#
# Epoch 00193: val_loss did not improve from 6.84900
# Epoch 194/500
# 84/84 [==============================] - 0s 131us/step - loss: 3.3448 - mean_absolute_error: 3.3448 - val_loss: 10.0091 - val_mean_absolute_error: 10.0091
#
# Epoch 00194: val_loss did not improve from 6.84900
# Epoch 195/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.2352 - mean_absolute_error: 2.2352 - val_loss: 8.2916 - val_mean_absolute_error: 8.2916
#
# Epoch 00195: val_loss did not improve from 6.84900
# Epoch 196/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.0043 - mean_absolute_error: 2.0043 - val_loss: 9.6845 - val_mean_absolute_error: 9.6845
#
# Epoch 00196: val_loss did not improve from 6.84900
# Epoch 197/500
# 84/84 [==============================] - 0s 107us/step - loss: 2.0366 - mean_absolute_error: 2.0366 - val_loss: 10.8767 - val_mean_absolute_error: 10.8767
#
# Epoch 00197: val_loss did not improve from 6.84900
# Epoch 198/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.8542 - mean_absolute_error: 1.8542 - val_loss: 8.9710 - val_mean_absolute_error: 8.9710
#
# Epoch 00198: val_loss did not improve from 6.84900
# Epoch 199/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.1338 - mean_absolute_error: 2.1338 - val_loss: 10.7091 - val_mean_absolute_error: 10.7091
#
# Epoch 00199: val_loss did not improve from 6.84900
# Epoch 200/500
# 84/84 [==============================] - 0s 142us/step - loss: 2.0018 - mean_absolute_error: 2.0018 - val_loss: 10.1197 - val_mean_absolute_error: 10.1197
#
# Epoch 00200: val_loss did not improve from 6.84900
# Epoch 201/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.9642 - mean_absolute_error: 1.9642 - val_loss: 11.5037 - val_mean_absolute_error: 11.5037
#
# Epoch 00201: val_loss did not improve from 6.84900
# Epoch 202/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.5999 - mean_absolute_error: 2.5999 - val_loss: 8.6190 - val_mean_absolute_error: 8.6190
#
# Epoch 00202: val_loss did not improve from 6.84900
# Epoch 203/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.2050 - mean_absolute_error: 2.2050 - val_loss: 10.6359 - val_mean_absolute_error: 10.6359
#
# Epoch 00203: val_loss did not improve from 6.84900
# Epoch 204/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.4467 - mean_absolute_error: 2.4467 - val_loss: 9.7619 - val_mean_absolute_error: 9.7619
#
# Epoch 00204: val_loss did not improve from 6.84900
# Epoch 205/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.9596 - mean_absolute_error: 1.9596 - val_loss: 8.8746 - val_mean_absolute_error: 8.8746
#
# Epoch 00205: val_loss did not improve from 6.84900
# Epoch 206/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.1341 - mean_absolute_error: 2.1341 - val_loss: 10.0918 - val_mean_absolute_error: 10.0918
#
# Epoch 00206: val_loss did not improve from 6.84900
# Epoch 207/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.0485 - mean_absolute_error: 2.0485 - val_loss: 9.3960 - val_mean_absolute_error: 9.3960
#
# Epoch 00207: val_loss did not improve from 6.84900
# Epoch 208/500
# 84/84 [==============================] - 0s 119us/step - loss: 2.4697 - mean_absolute_error: 2.4697 - val_loss: 11.0859 - val_mean_absolute_error: 11.0859
#
# Epoch 00208: val_loss did not improve from 6.84900
# Epoch 209/500
# 84/84 [==============================] - 0s 131us/step - loss: 2.2252 - mean_absolute_error: 2.2252 - val_loss: 8.1460 - val_mean_absolute_error: 8.1460
#
# Epoch 00209: val_loss did not improve from 6.84900
# Epoch 210/500
# 84/84 [==============================] - 0s 95us/step - loss: 2.3525 - mean_absolute_error: 2.3525 - val_loss: 11.1874 - val_mean_absolute_error: 11.1874
#
# Epoch 00210: val_loss did not improve from 6.84900
# Epoch 211/500
# 84/84 [==============================] - 0s 166us/step - loss: 2.6786 - mean_absolute_error: 2.6786 - val_loss: 9.4196 - val_mean_absolute_error: 9.4196
#
# Epoch 00211: val_loss did not improve from 6.84900
# Epoch 212/500
# ...
#
# Epoch 00428: val_loss did not improve from 6.84900
# Epoch 429/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.9615 - mean_absolute_error: 0.9615 - val_loss: 11.2336 - val_mean_absolute_error: 11.2336
#
# Epoch 00429: val_loss did not improve from 6.84900
# Epoch 430/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.9442 - mean_absolute_error: 0.9442 - val_loss: 10.0447 - val_mean_absolute_error: 10.0447
#
# Epoch 00430: val_loss did not improve from 6.84900
# Epoch 431/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.0351 - mean_absolute_error: 1.0351 - val_loss: 9.7298 - val_mean_absolute_error: 9.7298
#
# Epoch 00431: val_loss did not improve from 6.84900
# Epoch 432/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.1779 - mean_absolute_error: 1.1779 - val_loss: 11.2776 - val_mean_absolute_error: 11.2776
#
# Epoch 00432: val_loss did not improve from 6.84900
# Epoch 433/500
# 84/84 [==============================] - 0s 142us/step - loss: 1.4315 - mean_absolute_error: 1.4315 - val_loss: 9.6205 - val_mean_absolute_error: 9.6205
#
# Epoch 00433: val_loss did not improve from 6.84900
# Epoch 434/500
# 84/84 [==============================] - 0s 142us/step - loss: 1.4517 - mean_absolute_error: 1.4517 - val_loss: 9.0634 - val_mean_absolute_error: 9.0634
#
# Epoch 00434: val_loss did not improve from 6.84900
# Epoch 435/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.5092 - mean_absolute_error: 1.5092 - val_loss: 10.3193 - val_mean_absolute_error: 10.3193
#
# Epoch 00435: val_loss did not improve from 6.84900
# Epoch 436/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.2480 - mean_absolute_error: 1.2480 - val_loss: 10.9061 - val_mean_absolute_error: 10.9061
#
# Epoch 00436: val_loss did not improve from 6.84900
# Epoch 437/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0758 - mean_absolute_error: 1.0758 - val_loss: 9.5218 - val_mean_absolute_error: 9.5218
#
# Epoch 00437: val_loss did not improve from 6.84900
# Epoch 438/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.1363 - mean_absolute_error: 1.1363 - val_loss: 9.9354 - val_mean_absolute_error: 9.9354
#
# Epoch 00438: val_loss did not improve from 6.84900
# Epoch 439/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.9372 - mean_absolute_error: 0.9372 - val_loss: 10.0038 - val_mean_absolute_error: 10.0038
#
# Epoch 00439: val_loss did not improve from 6.84900
# Epoch 440/500
# 84/84 [==============================] - 0s 119us/step - loss: 0.8074 - mean_absolute_error: 0.8074 - val_loss: 10.6370 - val_mean_absolute_error: 10.6370
#
# Epoch 00440: val_loss did not improve from 6.84900
# Epoch 441/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0034 - mean_absolute_error: 1.0034 - val_loss: 10.3402 - val_mean_absolute_error: 10.3402
#
# Epoch 00441: val_loss did not improve from 6.84900
# Epoch 442/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.7895 - mean_absolute_error: 0.7895 - val_loss: 10.8411 - val_mean_absolute_error: 10.8411
#
# Epoch 00442: val_loss did not improve from 6.84900
# Epoch 443/500
# 84/84 [==============================] - 0s 154us/step - loss: 1.1227 - mean_absolute_error: 1.1227 - val_loss: 8.8444 - val_mean_absolute_error: 8.8444
#
# Epoch 00443: val_loss did not improve from 6.84900
# Epoch 444/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0178 - mean_absolute_error: 1.0178 - val_loss: 9.1451 - val_mean_absolute_error: 9.1451
#
# Epoch 00444: val_loss did not improve from 6.84900
# Epoch 445/500
# 84/84 [==============================] - 0s 95us/step - loss: 1.1154 - mean_absolute_error: 1.1154 - val_loss: 10.8764 - val_mean_absolute_error: 10.8764
#
# Epoch 00445: val_loss did not improve from 6.84900
# Epoch 446/500
# 84/84 [==============================] - 0s 107us/step - loss: 0.9577 - mean_absolute_error: 0.9577 - val_loss: 8.7906 - val_mean_absolute_error: 8.7906
#
# Epoch 00446: val_loss did not improve from 6.84900
# Epoch 447/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.6211 - mean_absolute_error: 1.6211 - val_loss: 11.0864 - val_mean_absolute_error: 11.0864
#
# Epoch 00447: val_loss did not improve from 6.84900
# Epoch 448/500
# 84/84 [==============================] - 0s 142us/step - loss: 1.3786 - mean_absolute_error: 1.3786 - val_loss: 9.5650 - val_mean_absolute_error: 9.5650
#
# Epoch 00448: val_loss did not improve from 6.84900
# Epoch 449/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.3164 - mean_absolute_error: 1.3164 - val_loss: 10.5014 - val_mean_absolute_error: 10.5014
#
# Epoch 00449: val_loss did not improve from 6.84900
# Epoch 450/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.4353 - mean_absolute_error: 1.4353 - val_loss: 9.5182 - val_mean_absolute_error: 9.5182
#
# Epoch 00450: val_loss did not improve from 6.84900
# Epoch 451/500
# 84/84 [==============================] - 0s 142us/step - loss: 1.3210 - mean_absolute_error: 1.3210 - val_loss: 12.7554 - val_mean_absolute_error: 12.7554
#
# Epoch 00451: val_loss did not improve from 6.84900
# Epoch 452/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.8181 - mean_absolute_error: 1.8181 - val_loss: 10.2178 - val_mean_absolute_error: 10.2178
#
# Epoch 00452: val_loss did not improve from 6.84900
# Epoch 453/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.6563 - mean_absolute_error: 1.6563 - val_loss: 10.2068 - val_mean_absolute_error: 10.2068
#
# Epoch 00453: val_loss did not improve from 6.84900
# Epoch 454/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.1069 - mean_absolute_error: 1.1069 - val_loss: 10.0179 - val_mean_absolute_error: 10.0179
#
# Epoch 00454: val_loss did not improve from 6.84900
# Epoch 455/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.2715 - mean_absolute_error: 1.2715 - val_loss: 9.8643 - val_mean_absolute_error: 9.8643
#
# Epoch 00455: val_loss did not improve from 6.84900
# Epoch 456/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.0992 - mean_absolute_error: 1.0992 - val_loss: 10.3070 - val_mean_absolute_error: 10.3070
#
# Epoch 00456: val_loss did not improve from 6.84900
# Epoch 457/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.1550 - mean_absolute_error: 1.1550 - val_loss: 12.2171 - val_mean_absolute_error: 12.2171
#
# Epoch 00457: val_loss did not improve from 6.84900
# Epoch 458/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.3386 - mean_absolute_error: 1.3386 - val_loss: 9.5062 - val_mean_absolute_error: 9.5062
#
# Epoch 00458: val_loss did not improve from 6.84900
# Epoch 459/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.9890 - mean_absolute_error: 1.9890 - val_loss: 11.7068 - val_mean_absolute_error: 11.7068
#
# Epoch 00459: val_loss did not improve from 6.84900
# Epoch 460/500
# 84/84 [==============================] - 0s 154us/step - loss: 1.6733 - mean_absolute_error: 1.6733 - val_loss: 9.2691 - val_mean_absolute_error: 9.2691
#
# Epoch 00460: val_loss did not improve from 6.84900
# Epoch 461/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.4815 - mean_absolute_error: 1.4815 - val_loss: 10.8500 - val_mean_absolute_error: 10.8500
#
# Epoch 00461: val_loss did not improve from 6.84900
# Epoch 462/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.1640 - mean_absolute_error: 1.1640 - val_loss: 9.1442 - val_mean_absolute_error: 9.1442
#
# Epoch 00462: val_loss did not improve from 6.84900
# Epoch 463/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.2755 - mean_absolute_error: 1.2755 - val_loss: 10.5860 - val_mean_absolute_error: 10.5860
#
# Epoch 00463: val_loss did not improve from 6.84900
# Epoch 464/500
# 84/84 [==============================] - 0s 142us/step - loss: 1.4871 - mean_absolute_error: 1.4871 - val_loss: 9.6817 - val_mean_absolute_error: 9.6817
#
# Epoch 00464: val_loss did not improve from 6.84900
# Epoch 465/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.1477 - mean_absolute_error: 1.1477 - val_loss: 9.9358 - val_mean_absolute_error: 9.9358
#
# Epoch 00465: val_loss did not improve from 6.84900
# Epoch 466/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.1852 - mean_absolute_error: 1.1852 - val_loss: 9.4113 - val_mean_absolute_error: 9.4113
#
# Epoch 00466: val_loss did not improve from 6.84900
# Epoch 467/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.0753 - mean_absolute_error: 1.0753 - val_loss: 11.3490 - val_mean_absolute_error: 11.3490
#
# Epoch 00467: val_loss did not improve from 6.84900
# Epoch 468/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.2522 - mean_absolute_error: 1.2522 - val_loss: 9.2931 - val_mean_absolute_error: 9.2931
#
# Epoch 00468: val_loss did not improve from 6.84900
# Epoch 469/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.2749 - mean_absolute_error: 1.2749 - val_loss: 10.7064 - val_mean_absolute_error: 10.7064
#
# Epoch 00469: val_loss did not improve from 6.84900
# Epoch 470/500
# 84/84 [==============================] - 0s 142us/step - loss: 0.8152 - mean_absolute_error: 0.8152 - val_loss: 9.4996 - val_mean_absolute_error: 9.4996
#
# Epoch 00470: val_loss did not improve from 6.84900
# Epoch 471/500
# 84/84 [==============================] - 0s 119us/step - loss: 0.9365 - mean_absolute_error: 0.9365 - val_loss: 9.0626 - val_mean_absolute_error: 9.0626
#
# Epoch 00471: val_loss did not improve from 6.84900
# Epoch 472/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.9011 - mean_absolute_error: 0.9011 - val_loss: 11.7667 - val_mean_absolute_error: 11.7667
#
# Epoch 00472: val_loss did not improve from 6.84900
# Epoch 473/500
# 84/84 [==============================] - 0s 166us/step - loss: 0.9502 - mean_absolute_error: 0.9502 - val_loss: 10.3979 - val_mean_absolute_error: 10.3979
#
# Epoch 00473: val_loss did not improve from 6.84900
# Epoch 474/500
# 84/84 [==============================] - 0s 119us/step - loss: 0.8551 - mean_absolute_error: 0.8551 - val_loss: 10.6109 - val_mean_absolute_error: 10.6109
#
# Epoch 00474: val_loss did not improve from 6.84900
# Epoch 475/500
# 84/84 [==============================] - 0s 95us/step - loss: 1.1156 - mean_absolute_error: 1.1156 - val_loss: 10.3681 - val_mean_absolute_error: 10.3681
#
# Epoch 00475: val_loss did not improve from 6.84900
# Epoch 476/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0109 - mean_absolute_error: 1.0109 - val_loss: 9.4120 - val_mean_absolute_error: 9.4120
#
# Epoch 00476: val_loss did not improve from 6.84900
# Epoch 477/500
# 84/84 [==============================] - 0s 95us/step - loss: 0.8245 - mean_absolute_error: 0.8245 - val_loss: 10.9146 - val_mean_absolute_error: 10.9146
#
# Epoch 00477: val_loss did not improve from 6.84900
# Epoch 478/500
# 84/84 [==============================] - 0s 119us/step - loss: 1.1543 - mean_absolute_error: 1.1543 - val_loss: 10.6043 - val_mean_absolute_error: 10.6043
#
# Epoch 00478: val_loss did not improve from 6.84900
# Epoch 479/500
# 84/84 [==============================] - 0s 107us/step - loss: 0.9418 - mean_absolute_error: 0.9418 - val_loss: 9.2077 - val_mean_absolute_error: 9.2077
#
# Epoch 00479: val_loss did not improve from 6.84900
# Epoch 480/500
# 84/84 [==============================] - 0s 95us/step - loss: 0.8606 - mean_absolute_error: 0.8606 - val_loss: 10.4941 - val_mean_absolute_error: 10.4941
#
# Epoch 00480: val_loss did not improve from 6.84900
# Epoch 481/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.2857 - mean_absolute_error: 1.2857 - val_loss: 9.9344 - val_mean_absolute_error: 9.9344
#
# Epoch 00481: val_loss did not improve from 6.84900
# Epoch 482/500
# 84/84 [==============================] - 0s 131us/step - loss: 1.1162 - mean_absolute_error: 1.1162 - val_loss: 10.3470 - val_mean_absolute_error: 10.3470
#
# Epoch 00482: val_loss did not improve from 6.84900
# Epoch 483/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.8974 - mean_absolute_error: 0.8974 - val_loss: 10.9233 - val_mean_absolute_error: 10.9233
#
# Epoch 00483: val_loss did not improve from 6.84900
# Epoch 484/500
# 84/84 [==============================] - 0s 155us/step - loss: 0.7968 - mean_absolute_error: 0.7968 - val_loss: 9.5649 - val_mean_absolute_error: 9.5649
#
# Epoch 00484: val_loss did not improve from 6.84900
# Epoch 485/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0097 - mean_absolute_error: 1.0097 - val_loss: 10.1954 - val_mean_absolute_error: 10.1954
#
# Epoch 00485: val_loss did not improve from 6.84900
# Epoch 486/500
# 84/84 [==============================] - 0s 95us/step - loss: 1.3615 - mean_absolute_error: 1.3615 - val_loss: 9.1437 - val_mean_absolute_error: 9.1437
#
# Epoch 00486: val_loss did not improve from 6.84900
# Epoch 487/500
# 84/84 [==============================] - 0s 142us/step - loss: 0.9948 - mean_absolute_error: 0.9948 - val_loss: 9.8691 - val_mean_absolute_error: 9.8691
#
# Epoch 00487: val_loss did not improve from 6.84900
# Epoch 488/500
# 84/84 [==============================] - 0s 154us/step - loss: 0.8908 - mean_absolute_error: 0.8908 - val_loss: 11.1368 - val_mean_absolute_error: 11.1368
#
# Epoch 00488: val_loss did not improve from 6.84900
# Epoch 489/500
# 84/84 [==============================] - 0s 107us/step - loss: 0.9022 - mean_absolute_error: 0.9022 - val_loss: 9.7403 - val_mean_absolute_error: 9.7403
#
# Epoch 00489: val_loss did not improve from 6.84900
# Epoch 490/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0883 - mean_absolute_error: 1.0883 - val_loss: 10.0391 - val_mean_absolute_error: 10.0391
#
# Epoch 00490: val_loss did not improve from 6.84900
# Epoch 491/500
# 84/84 [==============================] - 0s 154us/step - loss: 0.8191 - mean_absolute_error: 0.8191 - val_loss: 10.6299 - val_mean_absolute_error: 10.6299
#
# Epoch 00491: val_loss did not improve from 6.84900
# Epoch 492/500
# 84/84 [==============================] - 0s 142us/step - loss: 0.9515 - mean_absolute_error: 0.9515 - val_loss: 9.7308 - val_mean_absolute_error: 9.7308
#
# Epoch 00492: val_loss did not improve from 6.84900
# Epoch 493/500
# 84/84 [==============================] - 0s 107us/step - loss: 0.7081 - mean_absolute_error: 0.7081 - val_loss: 9.8073 - val_mean_absolute_error: 9.8073
#
# Epoch 00493: val_loss did not improve from 6.84900
# Epoch 494/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.6756 - mean_absolute_error: 0.6756 - val_loss: 10.2047 - val_mean_absolute_error: 10.2047
#
# Epoch 00494: val_loss did not improve from 6.84900
# Epoch 495/500
# 84/84 [==============================] - 0s 142us/step - loss: 0.7112 - mean_absolute_error: 0.7112 - val_loss: 9.5733 - val_mean_absolute_error: 9.5733
#
# Epoch 00495: val_loss did not improve from 6.84900
# Epoch 496/500
# 84/84 [==============================] - 0s 107us/step - loss: 0.8569 - mean_absolute_error: 0.8569 - val_loss: 9.5322 - val_mean_absolute_error: 9.5322
#
# Epoch 00496: val_loss did not improve from 6.84900
# Epoch 497/500
# 84/84 [==============================] - 0s 142us/step - loss: 0.8152 - mean_absolute_error: 0.8152 - val_loss: 11.5240 - val_mean_absolute_error: 11.5240
#
# Epoch 00497: val_loss did not improve from 6.84900
# Epoch 498/500
# 84/84 [==============================] - 0s 131us/step - loss: 0.9630 - mean_absolute_error: 0.9630 - val_loss: 10.7096 - val_mean_absolute_error: 10.7096
#
# Epoch 00498: val_loss did not improve from 6.84900
# Epoch 499/500
# 84/84 [==============================] - 0s 142us/step - loss: 1.2716 - mean_absolute_error: 1.2716 - val_loss: 10.5576 - val_mean_absolute_error: 10.5576
#
# Epoch 00499: val_loss did not improve from 6.84900
# Epoch 500/500
# 84/84 [==============================] - 0s 107us/step - loss: 1.0867 - mean_absolute_error: 1.0867 - val_loss: 9.0179 - val_mean_absolute_error: 9.0179
#
# Epoch 00500: val_loss did not improve from 6.84900

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
wights_file = 'GS-maskWeek-Weights-145--6.84900.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
# rf나,XGB회귀 분석을위한 훈련/검증 dataset생산
train_X, val_X, train_y, val_y = train_test_split(train, target[:cut_line], test_size = 0.25, random_state = 14)

# %%
# RandomForest 회귀분석
model = RandomForestRegressor()
model.fit(train_X,train_y)

# Get the mean absolute error on the validation data
RFpredicted = model.predict(val_X)
MAE = mean_absolute_error(val_y , predicted_prices)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  3.0146031746031743

# %%
# XGBRegressor 회귀분석

XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# [10:28:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  2.6370732743273333

# %%
# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)

combined = gs_week_w.iloc[:,3:38]
target = gs_week_w.iloc[:,2]
# RandomForest 회귀분석 예측 qty생산
RFpredicted = model.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)

result_df = pd.DataFrame()
result_df['week'] = gs_week_w['week']
result_df['qty'] = gs_week_w.iloc[:,2]

print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions
# Out:
# keras 신경망 predictions (157, 1)
# randomforest 예상 (157,)
# XGBpredictions (157,)

# %%
df_graph = result_df.loc[:,['week','keras_qty','rf_qty','xgb_qty','qty']]
df_graph['week'] = pd.to_datetime(df_graph['week'])

# %%
df_graph = result_df.copy()
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actural', color='k', alpha=0.3)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r', alpha=0.3)
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf', color='orange')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb', color='green')
plt.legend()
plt.show()

# %%
df_graph = result_df.loc[result_df.week <=53]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actural', color='green')
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='--', label='rf', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='--', label='xgb', color='green')
plt.legend()
plt.show()

# %%
df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actural', color='green')
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='--', label='rf', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='--', label='xgb', color='green')
plt.legend()
plt.show()

# %%
df_graph = result_df.loc[(result_df.week >=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='actural', color='green')
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='--', label='rf', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='--', label='xgb', color='green')
plt.legend()
plt.show()

# %%
path = 'D:/project/contest/data/result/'
result_df.to_csv(path+item+'_'+gruoped_by+'_predict.csv', encoding='utf-8', index=False)
