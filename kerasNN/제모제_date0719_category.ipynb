# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# R2 값, 결정계수 계산
from sklearn.metrics import r2_score

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
# w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
w = pd.read_csv('d:/project/contest/data/processed/날씨_ver071915.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
lv_grouped = lv_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_lv_grouped = lv_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '제모제'만 빼서 df생성
item = '제모제'
grouped_by = 'date'
day_lv_grouped_w_item = pd.merge(day_lv_grouped.loc[day_lv_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_lv_grouped_w_sns_item = pd.merge(day_lv_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not','미세', '초미세', '공기상태',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
lv_day_w = day_lv_grouped_w_sns_item[selected_cols]

# %%
# MAD적용
lv_day_w['outlier'] = pd.DataFrame(mad_based_outlier(lv_day_w['qty']))
lv_day_w = lv_day_w.loc[lv_day_w.outlier==False]

# %%
# list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
list_col = ['temp', 'cloud', 'wind','lgt_time',
            'rain_or_not', 'snow_or_not', '공기상태'] #+'rain_or_not', 'snow_or_not'
lowVIF(w,20,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239620  snow_or_not
# 1    2.479988  rain_or_not
# 2    3.114369         공기상태
# 3    4.013218         temp
# 4    6.725926        cloud
# 5    8.084050     lgt_time
# 6    9.334878         wind

# %%
train_data = lv_day_w.loc[lv_day_w.date.between('2016-01-01','2017-12-31')]
test_data = lv_day_w.loc[lv_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만
combined = lv_day_w.loc[:,list_col]
target = lv_day_w.loc[:,'qty']
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 7
# 오브젝트형 자료 컬럼 갯수 : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
#### 내가 '공기상태'라는 컬럼이 사실은 category형이라는것을 알기에 직접 dummy컬럼 생성
airCondition_dummies = pd.get_dummies(combined['공기상태'],prefix='공기상태')
combined = pd.concat([combined, airCondition_dummies], axis=1)
combined.drop(['공기상태'],axis = 1 , inplace=True)
######################################################################################
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 10 개의 columns이 있었습니다.

# %%
# 공기상태_0,공기상태_1,공기상태_2가 전부 0이면,   공기상태_3이 1이란 소리고
#                                                               공기상태가 '매우나쁨' 임을 추정할수 있다.
# 그런이유로 공기상태_3삭제
combined.drop(['공기상태_3'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
#
#    공기상태_2
# 0       1

# %%
Xy = pd.concat([target,combined], axis=1)
# Xy.head(1)

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 9)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 18:55:58.224026  6768 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 18:55:58.240982  6768 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 18:55:58.244971  6768 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 18:55:58.321791  6768 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,145
# Trainable params: 166,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat04-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 17:35:18.909374  9668 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 17:35:19.030052  9668 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 561us/step - loss: 1348.1129 - mean_absolute_error: 1348.1129 - val_loss: 613.8654 - val_mean_absolute_error: 613.8654
#
# Epoch 00001: val_loss improved from inf to 613.86537, saving model to 제모제date-Weights-001--613.86537-cat04-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 84us/step - loss: 934.8222 - mean_absolute_error: 934.8222 - val_loss: 587.6087 - val_mean_absolute_error: 587.6087
#
# Epoch 00002: val_loss improved from 613.86537 to 587.60867, saving model to 제모제date-Weights-002--587.60867-cat04-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 78us/step - loss: 596.7883 - mean_absolute_error: 596.7883 - val_loss: 472.6357 - val_mean_absolute_error: 472.6357
#
# Epoch 00003: val_loss improved from 587.60867 to 472.63568, saving model to 제모제date-Weights-003--472.63568-cat04-vf05.hdf5
# Epoch 4/500
# 585/585 [==============================] - 0s 73us/step - loss: 566.1508 - mean_absolute_error: 566.1508 - val_loss: 479.0086 - val_mean_absolute_error: 479.0086
#
# Epoch 00004: val_loss did not improve from 472.63568
# Epoch 5/500
# 585/585 [==============================] - 0s 84us/step - loss: 560.9284 - mean_absolute_error: 560.9284 - val_loss: 506.3991 - val_mean_absolute_error: 506.3991
#
# Epoch 00005: val_loss did not improve from 472.63568
# Epoch 6/500
# 585/585 [==============================] - 0s 85us/step - loss: 554.6324 - mean_absolute_error: 554.6324 - val_loss: 533.0937 - val_mean_absolute_error: 533.0937
#
# Epoch 00006: val_loss did not improve from 472.63568
# Epoch 7/500
# 585/585 [==============================] - 0s 101us/step - loss: 545.6152 - mean_absolute_error: 545.6152 - val_loss: 534.6907 - val_mean_absolute_error: 534.6907
#
# Epoch 00007: val_loss did not improve from 472.63568
# Epoch 8/500
# 585/585 [==============================] - 0s 80us/step - loss: 537.6523 - mean_absolute_error: 537.6523 - val_loss: 529.6157 - val_mean_absolute_error: 529.6157
#
# Epoch 00008: val_loss did not improve from 472.63568
# Epoch 9/500
# 585/585 [==============================] - 0s 78us/step - loss: 534.4292 - mean_absolute_error: 534.4292 - val_loss: 533.5812 - val_mean_absolute_error: 533.5812
#
# Epoch 00009: val_loss did not improve from 472.63568
# Epoch 10/500
# 585/585 [==============================] - 0s 80us/step - loss: 530.9505 - mean_absolute_error: 530.9505 - val_loss: 492.7272 - val_mean_absolute_error: 492.7272
#
# Epoch 00010: val_loss did not improve from 472.63568
# Epoch 11/500
# 585/585 [==============================] - 0s 89us/step - loss: 533.3283 - mean_absolute_error: 533.3283 - val_loss: 481.5387 - val_mean_absolute_error: 481.5387
#
# Epoch 00011: val_loss did not improve from 472.63568
# Epoch 12/500
# 585/585 [==============================] - 0s 85us/step - loss: 532.6871 - mean_absolute_error: 532.6871 - val_loss: 462.9305 - val_mean_absolute_error: 462.9305
#
# Epoch 00012: val_loss improved from 472.63568 to 462.93046, saving model to 제모제date-Weights-012--462.93046-cat04-vf05.hdf5
# Epoch 13/500
# 585/585 [==============================] - 0s 89us/step - loss: 522.9411 - mean_absolute_error: 522.9411 - val_loss: 494.6889 - val_mean_absolute_error: 494.6889
#
# Epoch 00013: val_loss did not improve from 462.93046
# Epoch 14/500
# 585/585 [==============================] - 0s 92us/step - loss: 518.5389 - mean_absolute_error: 518.5389 - val_loss: 469.8044 - val_mean_absolute_error: 469.8044
#
# Epoch 00014: val_loss did not improve from 462.93046
# Epoch 15/500
# 585/585 [==============================] - 0s 92us/step - loss: 516.0460 - mean_absolute_error: 516.0460 - val_loss: 472.4823 - val_mean_absolute_error: 472.4823
#
# Epoch 00015: val_loss did not improve from 462.93046
# Epoch 16/500
# 585/585 [==============================] - 0s 94us/step - loss: 519.9716 - mean_absolute_error: 519.9716 - val_loss: 533.5308 - val_mean_absolute_error: 533.5308
#
# Epoch 00016: val_loss did not improve from 462.93046
# Epoch 17/500
# 585/585 [==============================] - 0s 102us/step - loss: 527.2365 - mean_absolute_error: 527.2365 - val_loss: 474.8962 - val_mean_absolute_error: 474.8962
#
# Epoch 00017: val_loss did not improve from 462.93046
# Epoch 18/500
# 585/585 [==============================] - 0s 109us/step - loss: 513.4737 - mean_absolute_error: 513.4737 - val_loss: 497.4631 - val_mean_absolute_error: 497.4631
#
# Epoch 00018: val_loss did not improve from 462.93046
# Epoch 19/500
# 585/585 [==============================] - 0s 99us/step - loss: 531.9029 - mean_absolute_error: 531.9029 - val_loss: 490.4064 - val_mean_absolute_error: 490.4064
#
# Epoch 00019: val_loss did not improve from 462.93046
# Epoch 20/500
# 585/585 [==============================] - 0s 95us/step - loss: 512.2441 - mean_absolute_error: 512.2441 - val_loss: 430.8105 - val_mean_absolute_error: 430.8105
#
# Epoch 00020: val_loss improved from 462.93046 to 430.81054, saving model to 제모제date-Weights-020--430.81054-cat04-vf05.hdf5
# Epoch 21/500
# 585/585 [==============================] - 0s 87us/step - loss: 506.6356 - mean_absolute_error: 506.6356 - val_loss: 473.7943 - val_mean_absolute_error: 473.7943
#
# Epoch 00021: val_loss did not improve from 430.81054
# Epoch 22/500
# 585/585 [==============================] - 0s 92us/step - loss: 500.0277 - mean_absolute_error: 500.0277 - val_loss: 421.0139 - val_mean_absolute_error: 421.0139
#
# Epoch 00022: val_loss improved from 430.81054 to 421.01388, saving model to 제모제date-Weights-022--421.01388-cat04-vf05.hdf5
# Epoch 23/500
# 585/585 [==============================] - 0s 87us/step - loss: 506.5045 - mean_absolute_error: 506.5045 - val_loss: 439.6709 - val_mean_absolute_error: 439.6709
#
# Epoch 00023: val_loss did not improve from 421.01388
# Epoch 24/500
# 585/585 [==============================] - 0s 78us/step - loss: 503.7795 - mean_absolute_error: 503.7795 - val_loss: 445.3657 - val_mean_absolute_error: 445.3657
#
# Epoch 00024: val_loss did not improve from 421.01388
# Epoch 25/500
# 585/585 [==============================] - 0s 121us/step - loss: 503.4797 - mean_absolute_error: 503.4797 - val_loss: 416.7558 - val_mean_absolute_error: 416.7558
#
# Epoch 00025: val_loss improved from 421.01388 to 416.75579, saving model to 제모제date-Weights-025--416.75579-cat04-vf05.hdf5
# Epoch 26/500
# 585/585 [==============================] - 0s 97us/step - loss: 505.8914 - mean_absolute_error: 505.8914 - val_loss: 485.0746 - val_mean_absolute_error: 485.0746
#
# Epoch 00026: val_loss did not improve from 416.75579
# Epoch 27/500
# 585/585 [==============================] - 0s 99us/step - loss: 498.0805 - mean_absolute_error: 498.0805 - val_loss: 457.2254 - val_mean_absolute_error: 457.2254
#
# Epoch 00027: val_loss did not improve from 416.75579
# Epoch 28/500
# 585/585 [==============================] - 0s 94us/step - loss: 507.3680 - mean_absolute_error: 507.3680 - val_loss: 488.4989 - val_mean_absolute_error: 488.4989
#
# Epoch 00028: val_loss did not improve from 416.75579
# Epoch 29/500
# 585/585 [==============================] - 0s 97us/step - loss: 498.5097 - mean_absolute_error: 498.5097 - val_loss: 437.8863 - val_mean_absolute_error: 437.8863
#
# Epoch 00029: val_loss did not improve from 416.75579
# Epoch 30/500
# 585/585 [==============================] - 0s 89us/step - loss: 495.4769 - mean_absolute_error: 495.4769 - val_loss: 454.6016 - val_mean_absolute_error: 454.6016
#
# Epoch 00030: val_loss did not improve from 416.75579
# Epoch 31/500
# 585/585 [==============================] - 0s 89us/step - loss: 501.8433 - mean_absolute_error: 501.8433 - val_loss: 480.8985 - val_mean_absolute_error: 480.8985
#
# Epoch 00031: val_loss did not improve from 416.75579
# Epoch 32/500
# 585/585 [==============================] - 0s 95us/step - loss: 500.1207 - mean_absolute_error: 500.1207 - val_loss: 438.9174 - val_mean_absolute_error: 438.9174
#
# Epoch 00032: val_loss did not improve from 416.75579
# Epoch 33/500
# 585/585 [==============================] - 0s 143us/step - loss: 492.0673 - mean_absolute_error: 492.0673 - val_loss: 438.0430 - val_mean_absolute_error: 438.0430
#
# Epoch 00033: val_loss did not improve from 416.75579
# Epoch 34/500
# 585/585 [==============================] - 0s 99us/step - loss: 496.0914 - mean_absolute_error: 496.0914 - val_loss: 445.9893 - val_mean_absolute_error: 445.9893
#
# Epoch 00034: val_loss did not improve from 416.75579
# Epoch 35/500
# 585/585 [==============================] - 0s 114us/step - loss: 496.7312 - mean_absolute_error: 496.7312 - val_loss: 433.1653 - val_mean_absolute_error: 433.1653
#
# Epoch 00035: val_loss did not improve from 416.75579
# Epoch 36/500
# 585/585 [==============================] - 0s 114us/step - loss: 487.4662 - mean_absolute_error: 487.4662 - val_loss: 456.3797 - val_mean_absolute_error: 456.3797
#
# Epoch 00036: val_loss did not improve from 416.75579
# Epoch 37/500
# 585/585 [==============================] - 0s 109us/step - loss: 503.0455 - mean_absolute_error: 503.0455 - val_loss: 437.2342 - val_mean_absolute_error: 437.2342
#
# Epoch 00037: val_loss did not improve from 416.75579
# Epoch 38/500
# 585/585 [==============================] - 0s 106us/step - loss: 496.7067 - mean_absolute_error: 496.7067 - val_loss: 448.0404 - val_mean_absolute_error: 448.0404
#
# Epoch 00038: val_loss did not improve from 416.75579
# Epoch 39/500
# 585/585 [==============================] - 0s 97us/step - loss: 493.2468 - mean_absolute_error: 493.2468 - val_loss: 445.7394 - val_mean_absolute_error: 445.7394
#
# Epoch 00039: val_loss did not improve from 416.75579
# Epoch 40/500
# 585/585 [==============================] - 0s 107us/step - loss: 486.8404 - mean_absolute_error: 486.8404 - val_loss: 435.9043 - val_mean_absolute_error: 435.9043
#
# Epoch 00040: val_loss did not improve from 416.75579
# Epoch 41/500
# 585/585 [==============================] - 0s 101us/step - loss: 485.4819 - mean_absolute_error: 485.4819 - val_loss: 414.7344 - val_mean_absolute_error: 414.7344
#
# Epoch 00041: val_loss improved from 416.75579 to 414.73439, saving model to 제모제date-Weights-041--414.73439-cat04-vf05.hdf5
# Epoch 42/500
# 585/585 [==============================] - 0s 92us/step - loss: 491.4656 - mean_absolute_error: 491.4656 - val_loss: 431.7804 - val_mean_absolute_error: 431.7804
#
# Epoch 00042: val_loss did not improve from 414.73439
# Epoch 43/500
# 585/585 [==============================] - 0s 109us/step - loss: 487.6113 - mean_absolute_error: 487.6113 - val_loss: 426.9823 - val_mean_absolute_error: 426.9823
#
# Epoch 00043: val_loss did not improve from 414.73439
# Epoch 44/500
# 585/585 [==============================] - 0s 107us/step - loss: 482.1798 - mean_absolute_error: 482.1798 - val_loss: 420.6787 - val_mean_absolute_error: 420.6787
#
# Epoch 00044: val_loss did not improve from 414.73439
# Epoch 45/500
# 585/585 [==============================] - 0s 107us/step - loss: 485.2721 - mean_absolute_error: 485.2721 - val_loss: 455.0624 - val_mean_absolute_error: 455.0624
#
# Epoch 00045: val_loss did not improve from 414.73439
# Epoch 46/500
# 585/585 [==============================] - 0s 111us/step - loss: 500.3532 - mean_absolute_error: 500.3532 - val_loss: 398.8974 - val_mean_absolute_error: 398.8974
#
# Epoch 00046: val_loss improved from 414.73439 to 398.89743, saving model to 제모제date-Weights-046--398.89743-cat04-vf05.hdf5
# Epoch 47/500
# 585/585 [==============================] - 0s 96us/step - loss: 485.3060 - mean_absolute_error: 485.3060 - val_loss: 468.6193 - val_mean_absolute_error: 468.6193
#
# Epoch 00047: val_loss did not improve from 398.89743
# Epoch 48/500
# 585/585 [==============================] - 0s 104us/step - loss: 478.6747 - mean_absolute_error: 478.6747 - val_loss: 428.3043 - val_mean_absolute_error: 428.3043
#
# Epoch 00048: val_loss did not improve from 398.89743
# Epoch 49/500
# 585/585 [==============================] - 0s 130us/step - loss: 478.9542 - mean_absolute_error: 478.9542 - val_loss: 447.6134 - val_mean_absolute_error: 447.6134
#
# Epoch 00049: val_loss did not improve from 398.89743
# Epoch 50/500
# 585/585 [==============================] - 0s 99us/step - loss: 477.0031 - mean_absolute_error: 477.0031 - val_loss: 449.7655 - val_mean_absolute_error: 449.7655
#
# Epoch 00050: val_loss did not improve from 398.89743
# Epoch 51/500
# 585/585 [==============================] - 0s 107us/step - loss: 474.6073 - mean_absolute_error: 474.6073 - val_loss: 399.5656 - val_mean_absolute_error: 399.5656
#
# Epoch 00051: val_loss did not improve from 398.89743
# Epoch 52/500
# 585/585 [==============================] - 0s 116us/step - loss: 481.1434 - mean_absolute_error: 481.1434 - val_loss: 435.1316 - val_mean_absolute_error: 435.1316
#
# Epoch 00052: val_loss did not improve from 398.89743
# Epoch 53/500
# 585/585 [==============================] - 0s 111us/step - loss: 477.7685 - mean_absolute_error: 477.7685 - val_loss: 405.9027 - val_mean_absolute_error: 405.9027
#
# Epoch 00053: val_loss did not improve from 398.89743
# Epoch 54/500
# 585/585 [==============================] - 0s 111us/step - loss: 479.7720 - mean_absolute_error: 479.7720 - val_loss: 428.9896 - val_mean_absolute_error: 428.9896
#
# Epoch 00054: val_loss did not improve from 398.89743
# Epoch 55/500
# 585/585 [==============================] - 0s 111us/step - loss: 474.0900 - mean_absolute_error: 474.0900 - val_loss: 463.7181 - val_mean_absolute_error: 463.7181
#
# Epoch 00055: val_loss did not improve from 398.89743
# Epoch 56/500
# 585/585 [==============================] - 0s 135us/step - loss: 470.0582 - mean_absolute_error: 470.0582 - val_loss: 406.4187 - val_mean_absolute_error: 406.4187
#
# Epoch 00056: val_loss did not improve from 398.89743
# Epoch 57/500
# 585/585 [==============================] - 0s 124us/step - loss: 472.5927 - mean_absolute_error: 472.5927 - val_loss: 424.3923 - val_mean_absolute_error: 424.3923
#
# Epoch 00057: val_loss did not improve from 398.89743
# Epoch 58/500
# 585/585 [==============================] - 0s 180us/step - loss: 485.1069 - mean_absolute_error: 485.1069 - val_loss: 485.5826 - val_mean_absolute_error: 485.5826
#
# Epoch 00058: val_loss did not improve from 398.89743
# Epoch 59/500
# 585/585 [==============================] - 0s 140us/step - loss: 477.4503 - mean_absolute_error: 477.4503 - val_loss: 422.6107 - val_mean_absolute_error: 422.6107
#
# Epoch 00059: val_loss did not improve from 398.89743
# Epoch 60/500
# 585/585 [==============================] - 0s 147us/step - loss: 468.5927 - mean_absolute_error: 468.5927 - val_loss: 475.2739 - val_mean_absolute_error: 475.2739
#
# Epoch 00060: val_loss did not improve from 398.89743
# Epoch 61/500
# 585/585 [==============================] - 0s 113us/step - loss: 478.5416 - mean_absolute_error: 478.5416 - val_loss: 473.1195 - val_mean_absolute_error: 473.1195
#
# Epoch 00061: val_loss did not improve from 398.89743
# Epoch 62/500
# 585/585 [==============================] - 0s 123us/step - loss: 479.3740 - mean_absolute_error: 479.3740 - val_loss: 436.8099 - val_mean_absolute_error: 436.8099
#
# Epoch 00062: val_loss did not improve from 398.89743
# Epoch 63/500
# 585/585 [==============================] - 0s 153us/step - loss: 466.2276 - mean_absolute_error: 466.2276 - val_loss: 446.6570 - val_mean_absolute_error: 446.6570
#
# Epoch 00063: val_loss did not improve from 398.89743
# Epoch 64/500
# 585/585 [==============================] - 0s 129us/step - loss: 480.3558 - mean_absolute_error: 480.3558 - val_loss: 451.1210 - val_mean_absolute_error: 451.1210
#
# Epoch 00064: val_loss did not improve from 398.89743
# Epoch 65/500
# 585/585 [==============================] - 0s 128us/step - loss: 473.5653 - mean_absolute_error: 473.5653 - val_loss: 447.8816 - val_mean_absolute_error: 447.8816
#
# Epoch 00065: val_loss did not improve from 398.89743
# Epoch 66/500
# 585/585 [==============================] - 0s 115us/step - loss: 470.3132 - mean_absolute_error: 470.3132 - val_loss: 440.4645 - val_mean_absolute_error: 440.4645
#
# Epoch 00066: val_loss did not improve from 398.89743
# Epoch 67/500
# 585/585 [==============================] - 0s 109us/step - loss: 464.8885 - mean_absolute_error: 464.8885 - val_loss: 446.1085 - val_mean_absolute_error: 446.1085
#
# Epoch 00067: val_loss did not improve from 398.89743
# Epoch 68/500
# 585/585 [==============================] - 0s 118us/step - loss: 462.4016 - mean_absolute_error: 462.4016 - val_loss: 412.9941 - val_mean_absolute_error: 412.9941
#
# Epoch 00068: val_loss did not improve from 398.89743
# Epoch 69/500
# 585/585 [==============================] - 0s 114us/step - loss: 474.1561 - mean_absolute_error: 474.1561 - val_loss: 430.1724 - val_mean_absolute_error: 430.1724
#
# Epoch 00069: val_loss did not improve from 398.89743
# Epoch 70/500
# 585/585 [==============================] - 0s 136us/step - loss: 459.6092 - mean_absolute_error: 459.6092 - val_loss: 429.2659 - val_mean_absolute_error: 429.2659
#
# Epoch 00070: val_loss did not improve from 398.89743
# Epoch 71/500
# 585/585 [==============================] - 0s 118us/step - loss: 457.2518 - mean_absolute_error: 457.2518 - val_loss: 437.3243 - val_mean_absolute_error: 437.3243
#
# Epoch 00071: val_loss did not improve from 398.89743
# Epoch 72/500
# 585/585 [==============================] - 0s 130us/step - loss: 459.7323 - mean_absolute_error: 459.7323 - val_loss: 428.8308 - val_mean_absolute_error: 428.8308
#
# Epoch 00072: val_loss did not improve from 398.89743
# Epoch 73/500
# 585/585 [==============================] - 0s 119us/step - loss: 452.7981 - mean_absolute_error: 452.7981 - val_loss: 450.1792 - val_mean_absolute_error: 450.1792
#
# Epoch 00073: val_loss did not improve from 398.89743
# Epoch 74/500
# 585/585 [==============================] - 0s 143us/step - loss: 456.4617 - mean_absolute_error: 456.4617 - val_loss: 463.9050 - val_mean_absolute_error: 463.9050
#
# Epoch 00074: val_loss did not improve from 398.89743
# Epoch 75/500
# 585/585 [==============================] - 0s 130us/step - loss: 456.1426 - mean_absolute_error: 456.1426 - val_loss: 436.1131 - val_mean_absolute_error: 436.1131
#
# Epoch 00075: val_loss did not improve from 398.89743
# Epoch 76/500
# 585/585 [==============================] - 0s 121us/step - loss: 450.8672 - mean_absolute_error: 450.8672 - val_loss: 444.5616 - val_mean_absolute_error: 444.5616
#
# Epoch 00076: val_loss did not improve from 398.89743
# Epoch 77/500
# 585/585 [==============================] - 0s 133us/step - loss: 461.1451 - mean_absolute_error: 461.1451 - val_loss: 426.7506 - val_mean_absolute_error: 426.7506
#
# Epoch 00077: val_loss did not improve from 398.89743
# Epoch 78/500
# 585/585 [==============================] - 0s 123us/step - loss: 470.6936 - mean_absolute_error: 470.6936 - val_loss: 441.3306 - val_mean_absolute_error: 441.3306
#
# Epoch 00078: val_loss did not improve from 398.89743
# Epoch 79/500
# 585/585 [==============================] - 0s 133us/step - loss: 480.4468 - mean_absolute_error: 480.4468 - val_loss: 388.0177 - val_mean_absolute_error: 388.0177
#
# Epoch 00079: val_loss improved from 398.89743 to 388.01772, saving model to 제모제date-Weights-079--388.01772-cat04-vf05.hdf5
# Epoch 80/500
# 585/585 [==============================] - 0s 126us/step - loss: 462.5466 - mean_absolute_error: 462.5466 - val_loss: 448.4447 - val_mean_absolute_error: 448.4447
#
# Epoch 00080: val_loss did not improve from 388.01772
# Epoch 81/500
# 585/585 [==============================] - 0s 159us/step - loss: 454.4474 - mean_absolute_error: 454.4474 - val_loss: 410.5133 - val_mean_absolute_error: 410.5133
#
# Epoch 00081: val_loss did not improve from 388.01772
# Epoch 82/500
# 585/585 [==============================] - 0s 146us/step - loss: 455.6269 - mean_absolute_error: 455.6269 - val_loss: 445.2558 - val_mean_absolute_error: 445.2558
#
# Epoch 00082: val_loss did not improve from 388.01772
# Epoch 83/500
# 585/585 [==============================] - 0s 131us/step - loss: 450.5933 - mean_absolute_error: 450.5933 - val_loss: 473.2871 - val_mean_absolute_error: 473.2871
#
# Epoch 00083: val_loss did not improve from 388.01772
# Epoch 84/500
# 585/585 [==============================] - 0s 142us/step - loss: 477.2162 - mean_absolute_error: 477.2162 - val_loss: 462.6655 - val_mean_absolute_error: 462.6655
#
# Epoch 00084: val_loss did not improve from 388.01772
# Epoch 85/500
# 585/585 [==============================] - 0s 131us/step - loss: 450.9092 - mean_absolute_error: 450.9092 - val_loss: 468.6487 - val_mean_absolute_error: 468.6487
#
# Epoch 00085: val_loss did not improve from 388.01772
# Epoch 86/500
# 585/585 [==============================] - 0s 142us/step - loss: 452.0561 - mean_absolute_error: 452.0561 - val_loss: 450.5944 - val_mean_absolute_error: 450.5944
#
# Epoch 00086: val_loss did not improve from 388.01772
# Epoch 87/500
# 585/585 [==============================] - 0s 124us/step - loss: 442.6710 - mean_absolute_error: 442.6710 - val_loss: 419.8670 - val_mean_absolute_error: 419.8670
#
# Epoch 00087: val_loss did not improve from 388.01772
# Epoch 88/500
# 585/585 [==============================] - 0s 123us/step - loss: 446.6339 - mean_absolute_error: 446.6339 - val_loss: 460.1406 - val_mean_absolute_error: 460.1406
#
# Epoch 00088: val_loss did not improve from 388.01772
# Epoch 89/500
# 585/585 [==============================] - 0s 123us/step - loss: 444.3792 - mean_absolute_error: 444.3792 - val_loss: 415.2935 - val_mean_absolute_error: 415.2935
#
# Epoch 00089: val_loss did not improve from 388.01772
# Epoch 90/500
# 585/585 [==============================] - 0s 130us/step - loss: 441.9801 - mean_absolute_error: 441.9801 - val_loss: 442.7235 - val_mean_absolute_error: 442.7235
#
# Epoch 00090: val_loss did not improve from 388.01772
# Epoch 91/500
# 585/585 [==============================] - 0s 133us/step - loss: 439.6948 - mean_absolute_error: 439.6948 - val_loss: 402.0130 - val_mean_absolute_error: 402.0130
#
# Epoch 00091: val_loss did not improve from 388.01772
# Epoch 92/500
# 585/585 [==============================] - 0s 147us/step - loss: 449.1949 - mean_absolute_error: 449.1949 - val_loss: 431.5084 - val_mean_absolute_error: 431.5084
#
# Epoch 00092: val_loss did not improve from 388.01772
# Epoch 93/500
# 585/585 [==============================] - 0s 140us/step - loss: 433.4060 - mean_absolute_error: 433.4060 - val_loss: 460.1641 - val_mean_absolute_error: 460.1641
#
# Epoch 00093: val_loss did not improve from 388.01772
# Epoch 94/500
# 585/585 [==============================] - 0s 128us/step - loss: 464.6778 - mean_absolute_error: 464.6778 - val_loss: 442.4287 - val_mean_absolute_error: 442.4287
#
# Epoch 00094: val_loss did not improve from 388.01772
# Epoch 95/500
# 585/585 [==============================] - 0s 130us/step - loss: 437.9919 - mean_absolute_error: 437.9919 - val_loss: 419.2244 - val_mean_absolute_error: 419.2244
#
# Epoch 00095: val_loss did not improve from 388.01772
# Epoch 96/500
# 585/585 [==============================] - 0s 131us/step - loss: 439.4555 - mean_absolute_error: 439.4555 - val_loss: 451.3527 - val_mean_absolute_error: 451.3527
#
# Epoch 00096: val_loss did not improve from 388.01772
# Epoch 97/500
# 585/585 [==============================] - 0s 133us/step - loss: 445.4955 - mean_absolute_error: 445.4955 - val_loss: 411.5157 - val_mean_absolute_error: 411.5157
#
# Epoch 00097: val_loss did not improve from 388.01772
# Epoch 98/500
# 585/585 [==============================] - 0s 213us/step - loss: 438.0409 - mean_absolute_error: 438.0409 - val_loss: 421.5621 - val_mean_absolute_error: 421.5621
#
# Epoch 00098: val_loss did not improve from 388.01772
# Epoch 99/500
# 585/585 [==============================] - 0s 126us/step - loss: 437.2956 - mean_absolute_error: 437.2956 - val_loss: 412.9720 - val_mean_absolute_error: 412.9720
#
# Epoch 00099: val_loss did not improve from 388.01772
# Epoch 100/500
# 585/585 [==============================] - 0s 137us/step - loss: 449.7151 - mean_absolute_error: 449.7151 - val_loss: 455.2492 - val_mean_absolute_error: 455.2492
#
# Epoch 00100: val_loss did not improve from 388.01772
# Epoch 101/500
# 585/585 [==============================] - 0s 130us/step - loss: 445.9486 - mean_absolute_error: 445.9486 - val_loss: 470.4079 - val_mean_absolute_error: 470.4079
#
# Epoch 00101: val_loss did not improve from 388.01772
# Epoch 102/500
# 585/585 [==============================] - 0s 121us/step - loss: 446.6609 - mean_absolute_error: 446.6609 - val_loss: 427.8386 - val_mean_absolute_error: 427.8386
#
# Epoch 00102: val_loss did not improve from 388.01772
# Epoch 103/500
# 585/585 [==============================] - 0s 131us/step - loss: 442.6486 - mean_absolute_error: 442.6486 - val_loss: 405.0486 - val_mean_absolute_error: 405.0486
#
# Epoch 00103: val_loss did not improve from 388.01772
# Epoch 104/500
# 585/585 [==============================] - 0s 130us/step - loss: 453.4306 - mean_absolute_error: 453.4306 - val_loss: 414.7705 - val_mean_absolute_error: 414.7705
#
# Epoch 00104: val_loss did not improve from 388.01772
# Epoch 105/500
# 585/585 [==============================] - 0s 124us/step - loss: 445.9597 - mean_absolute_error: 445.9597 - val_loss: 391.8755 - val_mean_absolute_error: 391.8755
#
# Epoch 00105: val_loss did not improve from 388.01772
# Epoch 106/500
# 585/585 [==============================] - 0s 121us/step - loss: 432.3908 - mean_absolute_error: 432.3908 - val_loss: 430.0062 - val_mean_absolute_error: 430.0062
#
# Epoch 00106: val_loss did not improve from 388.01772
# Epoch 107/500
# 585/585 [==============================] - 0s 145us/step - loss: 435.8632 - mean_absolute_error: 435.8632 - val_loss: 398.8154 - val_mean_absolute_error: 398.8154
#
# Epoch 00107: val_loss did not improve from 388.01772
# Epoch 108/500
# 585/585 [==============================] - 0s 128us/step - loss: 432.0899 - mean_absolute_error: 432.0899 - val_loss: 429.1932 - val_mean_absolute_error: 429.1932
#
# Epoch 00108: val_loss did not improve from 388.01772
# Epoch 109/500
# 585/585 [==============================] - 0s 133us/step - loss: 435.5396 - mean_absolute_error: 435.5396 - val_loss: 430.3986 - val_mean_absolute_error: 430.3986
#
# Epoch 00109: val_loss did not improve from 388.01772
# Epoch 110/500
# 585/585 [==============================] - 0s 142us/step - loss: 448.9213 - mean_absolute_error: 448.9213 - val_loss: 443.9150 - val_mean_absolute_error: 443.9150
#
# Epoch 00110: val_loss did not improve from 388.01772
# Epoch 111/500
# 585/585 [==============================] - 0s 133us/step - loss: 438.5548 - mean_absolute_error: 438.5548 - val_loss: 441.4556 - val_mean_absolute_error: 441.4556
#
# Epoch 00111: val_loss did not improve from 388.01772
# Epoch 112/500
# 585/585 [==============================] - 0s 140us/step - loss: 430.0688 - mean_absolute_error: 430.0688 - val_loss: 456.6617 - val_mean_absolute_error: 456.6617
#
# Epoch 00112: val_loss did not improve from 388.01772
# Epoch 113/500
# 585/585 [==============================] - 0s 138us/step - loss: 430.7420 - mean_absolute_error: 430.7420 - val_loss: 416.0803 - val_mean_absolute_error: 416.0803
#
# Epoch 00113: val_loss did not improve from 388.01772
# Epoch 114/500
# 585/585 [==============================] - 0s 148us/step - loss: 432.9279 - mean_absolute_error: 432.9279 - val_loss: 455.5999 - val_mean_absolute_error: 455.5999
#
# Epoch 00114: val_loss did not improve from 388.01772
# Epoch 115/500
# 585/585 [==============================] - 0s 147us/step - loss: 431.3014 - mean_absolute_error: 431.3014 - val_loss: 397.6478 - val_mean_absolute_error: 397.6478
#
# Epoch 00115: val_loss did not improve from 388.01772
# Epoch 116/500
# 585/585 [==============================] - 0s 149us/step - loss: 436.8048 - mean_absolute_error: 436.8048 - val_loss: 438.8652 - val_mean_absolute_error: 438.8652
#
# Epoch 00116: val_loss did not improve from 388.01772
# Epoch 117/500
# 585/585 [==============================] - 0s 152us/step - loss: 430.7293 - mean_absolute_error: 430.7293 - val_loss: 396.2167 - val_mean_absolute_error: 396.2167
#
# Epoch 00117: val_loss did not improve from 388.01772
# Epoch 118/500
# 585/585 [==============================] - 0s 147us/step - loss: 428.0971 - mean_absolute_error: 428.0971 - val_loss: 446.5140 - val_mean_absolute_error: 446.5140
#
# Epoch 00118: val_loss did not improve from 388.01772
# Epoch 119/500
# 585/585 [==============================] - 0s 143us/step - loss: 428.0569 - mean_absolute_error: 428.0569 - val_loss: 444.0046 - val_mean_absolute_error: 444.0046
#
# Epoch 00119: val_loss did not improve from 388.01772
# Epoch 120/500
# 585/585 [==============================] - 0s 150us/step - loss: 425.9630 - mean_absolute_error: 425.9630 - val_loss: 417.7874 - val_mean_absolute_error: 417.7874
#
# Epoch 00120: val_loss did not improve from 388.01772
# Epoch 121/500
# 585/585 [==============================] - 0s 136us/step - loss: 426.6754 - mean_absolute_error: 426.6754 - val_loss: 441.9081 - val_mean_absolute_error: 441.9081
#
# Epoch 00121: val_loss did not improve from 388.01772
# Epoch 122/500
# 585/585 [==============================] - 0s 152us/step - loss: 430.5994 - mean_absolute_error: 430.5994 - val_loss: 375.5688 - val_mean_absolute_error: 375.5688
#
# Epoch 00122: val_loss improved from 388.01772 to 375.56878, saving model to 제모제date-Weights-122--375.56878-cat04-vf05.hdf5
# Epoch 123/500
# 585/585 [==============================] - 0s 142us/step - loss: 440.9655 - mean_absolute_error: 440.9655 - val_loss: 407.1199 - val_mean_absolute_error: 407.1199
#
# Epoch 00123: val_loss did not improve from 375.56878
# Epoch 124/500
# 585/585 [==============================] - 0s 140us/step - loss: 447.5403 - mean_absolute_error: 447.5403 - val_loss: 380.6690 - val_mean_absolute_error: 380.6690
#
# Epoch 00124: val_loss did not improve from 375.56878
# Epoch 125/500
# 585/585 [==============================] - 0s 140us/step - loss: 429.7600 - mean_absolute_error: 429.7600 - val_loss: 424.2077 - val_mean_absolute_error: 424.2077
#
# Epoch 00125: val_loss did not improve from 375.56878
# Epoch 126/500
# 585/585 [==============================] - 0s 152us/step - loss: 438.1978 - mean_absolute_error: 438.1978 - val_loss: 421.2022 - val_mean_absolute_error: 421.2022
#
# Epoch 00126: val_loss did not improve from 375.56878
# Epoch 127/500
# 585/585 [==============================] - 0s 131us/step - loss: 429.3156 - mean_absolute_error: 429.3156 - val_loss: 433.3386 - val_mean_absolute_error: 433.3386
#
# Epoch 00127: val_loss did not improve from 375.56878
# Epoch 128/500
# 585/585 [==============================] - 0s 140us/step - loss: 422.3197 - mean_absolute_error: 422.3197 - val_loss: 418.0085 - val_mean_absolute_error: 418.0085
#
# Epoch 00128: val_loss did not improve from 375.56878
# Epoch 129/500
# 585/585 [==============================] - 0s 138us/step - loss: 424.2611 - mean_absolute_error: 424.2611 - val_loss: 408.1981 - val_mean_absolute_error: 408.1981
#
# Epoch 00129: val_loss did not improve from 375.56878
# Epoch 130/500
# 585/585 [==============================] - 0s 128us/step - loss: 426.8651 - mean_absolute_error: 426.8651 - val_loss: 451.4051 - val_mean_absolute_error: 451.4051
#
# Epoch 00130: val_loss did not improve from 375.56878
# Epoch 131/500
# 585/585 [==============================] - 0s 131us/step - loss: 427.5542 - mean_absolute_error: 427.5542 - val_loss: 436.3846 - val_mean_absolute_error: 436.3846
#
# Epoch 00131: val_loss did not improve from 375.56878
# Epoch 132/500
# 585/585 [==============================] - 0s 129us/step - loss: 429.3033 - mean_absolute_error: 429.3033 - val_loss: 442.6395 - val_mean_absolute_error: 442.6395
#
# Epoch 00132: val_loss did not improve from 375.56878
# Epoch 133/500
# 585/585 [==============================] - 0s 137us/step - loss: 438.2963 - mean_absolute_error: 438.2963 - val_loss: 402.6895 - val_mean_absolute_error: 402.6895
#
# Epoch 00133: val_loss did not improve from 375.56878
# Epoch 134/500
# 585/585 [==============================] - 0s 142us/step - loss: 424.3103 - mean_absolute_error: 424.3103 - val_loss: 392.7031 - val_mean_absolute_error: 392.7031
#
# Epoch 00134: val_loss did not improve from 375.56878
# Epoch 135/500
# 585/585 [==============================] - 0s 131us/step - loss: 434.3717 - mean_absolute_error: 434.3717 - val_loss: 461.7234 - val_mean_absolute_error: 461.7234
#
# Epoch 00135: val_loss did not improve from 375.56878
# Epoch 136/500
# 585/585 [==============================] - 0s 133us/step - loss: 432.3772 - mean_absolute_error: 432.3772 - val_loss: 422.0066 - val_mean_absolute_error: 422.0066
#
# Epoch 00136: val_loss did not improve from 375.56878
# Epoch 137/500
# 585/585 [==============================] - 0s 136us/step - loss: 428.7919 - mean_absolute_error: 428.7919 - val_loss: 428.0767 - val_mean_absolute_error: 428.0767
#
# Epoch 00137: val_loss did not improve from 375.56878
# Epoch 138/500
# 585/585 [==============================] - 0s 153us/step - loss: 425.2690 - mean_absolute_error: 425.2690 - val_loss: 408.3404 - val_mean_absolute_error: 408.3404
#
# Epoch 00138: val_loss did not improve from 375.56878
# Epoch 139/500
# 585/585 [==============================] - 0s 131us/step - loss: 421.2245 - mean_absolute_error: 421.2245 - val_loss: 462.4919 - val_mean_absolute_error: 462.4919
#
# Epoch 00139: val_loss did not improve from 375.56878
# Epoch 140/500
# 585/585 [==============================] - 0s 153us/step - loss: 423.2120 - mean_absolute_error: 423.2120 - val_loss: 396.3755 - val_mean_absolute_error: 396.3755
#
# Epoch 00140: val_loss did not improve from 375.56878
# Epoch 141/500
# 585/585 [==============================] - 0s 169us/step - loss: 418.0384 - mean_absolute_error: 418.0384 - val_loss: 426.5424 - val_mean_absolute_error: 426.5424
#
# Epoch 00141: val_loss did not improve from 375.56878
# Epoch 142/500
# 585/585 [==============================] - 0s 172us/step - loss: 419.1608 - mean_absolute_error: 419.1608 - val_loss: 448.0955 - val_mean_absolute_error: 448.0955
#
# Epoch 00142: val_loss did not improve from 375.56878
# Epoch 143/500
# 585/585 [==============================] - 0s 159us/step - loss: 421.6651 - mean_absolute_error: 421.6651 - val_loss: 459.6319 - val_mean_absolute_error: 459.6319
#
# Epoch 00143: val_loss did not improve from 375.56878
# Epoch 144/500
# 585/585 [==============================] - 0s 506us/step - loss: 425.3137 - mean_absolute_error: 425.3137 - val_loss: 431.2672 - val_mean_absolute_error: 431.2672
#
# Epoch 00144: val_loss did not improve from 375.56878
# Epoch 145/500
# 585/585 [==============================] - 0s 189us/step - loss: 436.1025 - mean_absolute_error: 436.1025 - val_loss: 416.6032 - val_mean_absolute_error: 416.6032
#
# Epoch 00145: val_loss did not improve from 375.56878
# Epoch 146/500
# 585/585 [==============================] - 0s 205us/step - loss: 426.2775 - mean_absolute_error: 426.2775 - val_loss: 473.5303 - val_mean_absolute_error: 473.5303
#
# Epoch 00146: val_loss did not improve from 375.56878
# Epoch 147/500
# 585/585 [==============================] - 0s 177us/step - loss: 433.0935 - mean_absolute_error: 433.0935 - val_loss: 438.2747 - val_mean_absolute_error: 438.2747
#
# Epoch 00147: val_loss did not improve from 375.56878
# Epoch 148/500
# 585/585 [==============================] - 0s 150us/step - loss: 419.1436 - mean_absolute_error: 419.1436 - val_loss: 439.3567 - val_mean_absolute_error: 439.3567
#
# Epoch 00148: val_loss did not improve from 375.56878
# Epoch 149/500
# 585/585 [==============================] - 0s 198us/step - loss: 428.6679 - mean_absolute_error: 428.6679 - val_loss: 426.0858 - val_mean_absolute_error: 426.0858
#
# Epoch 00149: val_loss did not improve from 375.56878
# Epoch 150/500
# 585/585 [==============================] - 0s 189us/step - loss: 423.4035 - mean_absolute_error: 423.4035 - val_loss: 422.8865 - val_mean_absolute_error: 422.8865
#
# Epoch 00150: val_loss did not improve from 375.56878
# Epoch 151/500
# 585/585 [==============================] - 0s 156us/step - loss: 417.4921 - mean_absolute_error: 417.4921 - val_loss: 404.1886 - val_mean_absolute_error: 404.1886
#
# Epoch 00151: val_loss did not improve from 375.56878
# Epoch 152/500
# 585/585 [==============================] - 0s 200us/step - loss: 427.9275 - mean_absolute_error: 427.9275 - val_loss: 405.3884 - val_mean_absolute_error: 405.3884
#
# Epoch 00152: val_loss did not improve from 375.56878
# Epoch 153/500
# 585/585 [==============================] - 0s 162us/step - loss: 414.6804 - mean_absolute_error: 414.6804 - val_loss: 406.4133 - val_mean_absolute_error: 406.4133
#
# Epoch 00153: val_loss did not improve from 375.56878
# Epoch 154/500
# 585/585 [==============================] - 0s 138us/step - loss: 424.0814 - mean_absolute_error: 424.0814 - val_loss: 431.0728 - val_mean_absolute_error: 431.0728
#
# Epoch 00154: val_loss did not improve from 375.56878
# Epoch 155/500
# 585/585 [==============================] - 0s 177us/step - loss: 417.4088 - mean_absolute_error: 417.4088 - val_loss: 458.8371 - val_mean_absolute_error: 458.8371
#
# Epoch 00155: val_loss did not improve from 375.56878
# Epoch 156/500
# 585/585 [==============================] - 0s 170us/step - loss: 423.5431 - mean_absolute_error: 423.5431 - val_loss: 403.3239 - val_mean_absolute_error: 403.3239
#
# Epoch 00156: val_loss did not improve from 375.56878
# Epoch 157/500
# 585/585 [==============================] - 0s 172us/step - loss: 421.3454 - mean_absolute_error: 421.3454 - val_loss: 422.7912 - val_mean_absolute_error: 422.7912
#
# Epoch 00157: val_loss did not improve from 375.56878
# Epoch 158/500
# 585/585 [==============================] - 0s 167us/step - loss: 421.0872 - mean_absolute_error: 421.0872 - val_loss: 387.4616 - val_mean_absolute_error: 387.4616
#
# Epoch 00158: val_loss did not improve from 375.56878
# Epoch 159/500
# 585/585 [==============================] - 0s 153us/step - loss: 411.2937 - mean_absolute_error: 411.2937 - val_loss: 407.2705 - val_mean_absolute_error: 407.2705
#
# Epoch 00159: val_loss did not improve from 375.56878
# Epoch 160/500
# 585/585 [==============================] - 0s 162us/step - loss: 412.1246 - mean_absolute_error: 412.1246 - val_loss: 413.0577 - val_mean_absolute_error: 413.0577
#
# Epoch 00160: val_loss did not improve from 375.56878
# Epoch 161/500
# 585/585 [==============================] - 0s 179us/step - loss: 411.8219 - mean_absolute_error: 411.8219 - val_loss: 426.4310 - val_mean_absolute_error: 426.4310
#
# Epoch 00161: val_loss did not improve from 375.56878
# Epoch 162/500
# 585/585 [==============================] - 0s 165us/step - loss: 423.7357 - mean_absolute_error: 423.7357 - val_loss: 416.4613 - val_mean_absolute_error: 416.4613
#
# Epoch 00162: val_loss did not improve from 375.56878
# Epoch 163/500
# 585/585 [==============================] - 0s 160us/step - loss: 416.3998 - mean_absolute_error: 416.3998 - val_loss: 425.5139 - val_mean_absolute_error: 425.5139
#
# Epoch 00163: val_loss did not improve from 375.56878
# Epoch 164/500
# 585/585 [==============================] - 0s 165us/step - loss: 412.8566 - mean_absolute_error: 412.8566 - val_loss: 429.8453 - val_mean_absolute_error: 429.8453
#
# Epoch 00164: val_loss did not improve from 375.56878
# Epoch 165/500
# 585/585 [==============================] - 0s 153us/step - loss: 416.2520 - mean_absolute_error: 416.2520 - val_loss: 435.2889 - val_mean_absolute_error: 435.2889
#
# Epoch 00165: val_loss did not improve from 375.56878
# Epoch 166/500
# 585/585 [==============================] - 0s 174us/step - loss: 413.3606 - mean_absolute_error: 413.3606 - val_loss: 454.4163 - val_mean_absolute_error: 454.4163
#
# Epoch 00166: val_loss did not improve from 375.56878
# Epoch 167/500
# 585/585 [==============================] - 0s 152us/step - loss: 407.8159 - mean_absolute_error: 407.8159 - val_loss: 494.0587 - val_mean_absolute_error: 494.0587
#
# Epoch 00167: val_loss did not improve from 375.56878
# Epoch 168/500
# 585/585 [==============================] - 0s 160us/step - loss: 455.0080 - mean_absolute_error: 455.0080 - val_loss: 450.6467 - val_mean_absolute_error: 450.6467
#
# Epoch 00168: val_loss did not improve from 375.56878
# Epoch 169/500
# 585/585 [==============================] - 0s 143us/step - loss: 423.0825 - mean_absolute_error: 423.0825 - val_loss: 445.3873 - val_mean_absolute_error: 445.3873
#
# Epoch 00169: val_loss did not improve from 375.56878
# Epoch 170/500
# 585/585 [==============================] - 0s 147us/step - loss: 418.5774 - mean_absolute_error: 418.5774 - val_loss: 437.2712 - val_mean_absolute_error: 437.2712
#
# Epoch 00170: val_loss did not improve from 375.56878
# Epoch 171/500
# 585/585 [==============================] - ETA: 0s - loss: 409.0634 - mean_absolute_error: 409.063 - 0s 191us/step - loss: 410.0226 - mean_absolute_error: 410.0226 - val_loss: 442.0539 - val_mean_absolute_error: 442.0539
#
# Epoch 00171: val_loss did not improve from 375.56878
# Epoch 172/500
# 585/585 [==============================] - 0s 167us/step - loss: 412.1060 - mean_absolute_error: 412.1060 - val_loss: 423.3844 - val_mean_absolute_error: 423.3844
#
# Epoch 00172: val_loss did not improve from 375.56878
# Epoch 173/500
# 585/585 [==============================] - 0s 150us/step - loss: 412.5583 - mean_absolute_error: 412.5583 - val_loss: 423.4761 - val_mean_absolute_error: 423.4761
#
# Epoch 00173: val_loss did not improve from 375.56878
# Epoch 174/500
# 585/585 [==============================] - 0s 143us/step - loss: 413.6582 - mean_absolute_error: 413.6582 - val_loss: 415.0417 - val_mean_absolute_error: 415.0417
#
# Epoch 00174: val_loss did not improve from 375.56878
# Epoch 175/500
# 585/585 [==============================] - 0s 148us/step - loss: 410.6615 - mean_absolute_error: 410.6615 - val_loss: 451.4550 - val_mean_absolute_error: 451.4550
#
# Epoch 00175: val_loss did not improve from 375.56878
# Epoch 176/500
# 585/585 [==============================] - 0s 177us/step - loss: 437.9998 - mean_absolute_error: 437.9998 - val_loss: 469.0145 - val_mean_absolute_error: 469.0145
#
# Epoch 00176: val_loss did not improve from 375.56878
# Epoch 177/500
# 585/585 [==============================] - 0s 162us/step - loss: 420.9692 - mean_absolute_error: 420.9692 - val_loss: 460.7693 - val_mean_absolute_error: 460.7693
#
# Epoch 00177: val_loss did not improve from 375.56878
# Epoch 178/500
# 585/585 [==============================] - 0s 167us/step - loss: 414.4731 - mean_absolute_error: 414.4731 - val_loss: 415.1673 - val_mean_absolute_error: 415.1673
#
# Epoch 00178: val_loss did not improve from 375.56878
# Epoch 179/500
# 585/585 [==============================] - 0s 159us/step - loss: 404.8639 - mean_absolute_error: 404.8639 - val_loss: 408.1853 - val_mean_absolute_error: 408.1853
#
# Epoch 00179: val_loss did not improve from 375.56878
# Epoch 180/500
# 585/585 [==============================] - 0s 148us/step - loss: 410.7797 - mean_absolute_error: 410.7797 - val_loss: 466.7347 - val_mean_absolute_error: 466.7347
#
# Epoch 00180: val_loss did not improve from 375.56878
# Epoch 181/500
# 585/585 [==============================] - 0s 159us/step - loss: 409.4743 - mean_absolute_error: 409.4743 - val_loss: 450.3698 - val_mean_absolute_error: 450.3698
#
# Epoch 00181: val_loss did not improve from 375.56878
# Epoch 182/500
# 585/585 [==============================] - 0s 167us/step - loss: 409.6513 - mean_absolute_error: 409.6513 - val_loss: 433.7211 - val_mean_absolute_error: 433.7211
#
# Epoch 00182: val_loss did not improve from 375.56878
# Epoch 183/500
# 585/585 [==============================] - 0s 162us/step - loss: 407.5610 - mean_absolute_error: 407.5610 - val_loss: 414.0030 - val_mean_absolute_error: 414.0030
#
# Epoch 00183: val_loss did not improve from 375.56878
# Epoch 184/500
# 585/585 [==============================] - 0s 147us/step - loss: 406.2558 - mean_absolute_error: 406.2558 - val_loss: 411.8105 - val_mean_absolute_error: 411.8105
#
# Epoch 00184: val_loss did not improve from 375.56878
# Epoch 185/500
# 585/585 [==============================] - 0s 155us/step - loss: 420.3913 - mean_absolute_error: 420.3913 - val_loss: 417.0296 - val_mean_absolute_error: 417.0296
#
# Epoch 00185: val_loss did not improve from 375.56878
# Epoch 186/500
# 585/585 [==============================] - 0s 145us/step - loss: 407.1701 - mean_absolute_error: 407.1701 - val_loss: 444.1409 - val_mean_absolute_error: 444.1409
#
# Epoch 00186: val_loss did not improve from 375.56878
# Epoch 187/500
# 585/585 [==============================] - 0s 152us/step - loss: 414.1779 - mean_absolute_error: 414.1779 - val_loss: 383.9819 - val_mean_absolute_error: 383.9819
#
# Epoch 00187: val_loss did not improve from 375.56878
# Epoch 188/500
# 585/585 [==============================] - 0s 138us/step - loss: 416.7509 - mean_absolute_error: 416.7509 - val_loss: 430.2504 - val_mean_absolute_error: 430.2504
#
# Epoch 00188: val_loss did not improve from 375.56878
# Epoch 189/500
# 585/585 [==============================] - 0s 160us/step - loss: 410.3863 - mean_absolute_error: 410.3863 - val_loss: 483.9075 - val_mean_absolute_error: 483.9075
#
# Epoch 00189: val_loss did not improve from 375.56878
# Epoch 190/500
# 585/585 [==============================] - 0s 162us/step - loss: 454.0598 - mean_absolute_error: 454.0598 - val_loss: 428.7574 - val_mean_absolute_error: 428.7574
#
# Epoch 00190: val_loss did not improve from 375.56878
# Epoch 191/500
# 585/585 [==============================] - 0s 133us/step - loss: 440.5765 - mean_absolute_error: 440.5765 - val_loss: 402.6591 - val_mean_absolute_error: 402.6591
#
# Epoch 00191: val_loss did not improve from 375.56878
# Epoch 192/500
# 585/585 [==============================] - 0s 159us/step - loss: 407.8285 - mean_absolute_error: 407.8285 - val_loss: 423.8511 - val_mean_absolute_error: 423.8511
#
# Epoch 00192: val_loss did not improve from 375.56878
# Epoch 193/500
# 585/585 [==============================] - 0s 145us/step - loss: 407.1038 - mean_absolute_error: 407.1038 - val_loss: 425.4944 - val_mean_absolute_error: 425.4944
#
# Epoch 00193: val_loss did not improve from 375.56878
# Epoch 194/500
# 585/585 [==============================] - 0s 155us/step - loss: 404.5411 - mean_absolute_error: 404.5411 - val_loss: 415.2717 - val_mean_absolute_error: 415.2717
#
# Epoch 00194: val_loss did not improve from 375.56878
# Epoch 195/500
# 585/585 [==============================] - 0s 139us/step - loss: 403.6315 - mean_absolute_error: 403.6315 - val_loss: 446.5019 - val_mean_absolute_error: 446.5019
#
# Epoch 00195: val_loss did not improve from 375.56878
# Epoch 196/500
# 585/585 [==============================] - 0s 153us/step - loss: 402.5895 - mean_absolute_error: 402.5895 - val_loss: 416.4284 - val_mean_absolute_error: 416.4284
#
# Epoch 00196: val_loss did not improve from 375.56878
# Epoch 197/500
# 585/585 [==============================] - 0s 153us/step - loss: 403.4268 - mean_absolute_error: 403.4268 - val_loss: 428.3078 - val_mean_absolute_error: 428.3078
#
# Epoch 00197: val_loss did not improve from 375.56878
# Epoch 198/500
# 585/585 [==============================] - ETA: 0s - loss: 409.7253 - mean_absolute_error: 409.725 - 0s 158us/step - loss: 409.9590 - mean_absolute_error: 409.9590 - val_loss: 442.1277 - val_mean_absolute_error: 442.1277
#
# Epoch 00198: val_loss did not improve from 375.56878
# Epoch 199/500
# 585/585 [==============================] - 0s 155us/step - loss: 405.4294 - mean_absolute_error: 405.4294 - val_loss: 402.0642 - val_mean_absolute_error: 402.0642
#
# Epoch 00199: val_loss did not improve from 375.56878
# Epoch 200/500
# 585/585 [==============================] - 0s 155us/step - loss: 415.8394 - mean_absolute_error: 415.8394 - val_loss: 372.5223 - val_mean_absolute_error: 372.5223
#
# Epoch 00200: val_loss improved from 375.56878 to 372.52235, saving model to 제모제date-Weights-200--372.52235-cat04-vf05.hdf5
# Epoch 201/500
# 585/585 [==============================] - 0s 172us/step - loss: 439.8131 - mean_absolute_error: 439.8131 - val_loss: 405.1185 - val_mean_absolute_error: 405.1185
#
# Epoch 00201: val_loss did not improve from 372.52235
# Epoch 202/500
# 585/585 [==============================] - 0s 164us/step - loss: 432.8987 - mean_absolute_error: 432.8987 - val_loss: 466.5573 - val_mean_absolute_error: 466.5573
#
# Epoch 00202: val_loss did not improve from 372.52235
# Epoch 203/500
# ...
#
# Epoch 00431: val_loss did not improve from 365.57752
# Epoch 432/500
# 585/585 [==============================] - 0s 223us/step - loss: 374.2632 - mean_absolute_error: 374.2632 - val_loss: 431.1883 - val_mean_absolute_error: 431.1883
#
# Epoch 00432: val_loss did not improve from 365.57752
# Epoch 433/500
# 585/585 [==============================] - 0s 189us/step - loss: 360.1099 - mean_absolute_error: 360.1099 - val_loss: 415.8678 - val_mean_absolute_error: 415.8678
#
# Epoch 00433: val_loss did not improve from 365.57752
# Epoch 434/500
# 585/585 [==============================] - 0s 203us/step - loss: 353.5863 - mean_absolute_error: 353.5863 - val_loss: 424.1195 - val_mean_absolute_error: 424.1195
#
# Epoch 00434: val_loss did not improve from 365.57752
# Epoch 435/500
# 585/585 [==============================] - 0s 194us/step - loss: 349.8816 - mean_absolute_error: 349.8816 - val_loss: 374.7530 - val_mean_absolute_error: 374.7530
#
# Epoch 00435: val_loss did not improve from 365.57752
# Epoch 436/500
# 585/585 [==============================] - 0s 206us/step - loss: 368.1890 - mean_absolute_error: 368.1890 - val_loss: 414.7310 - val_mean_absolute_error: 414.7310
#
# Epoch 00436: val_loss did not improve from 365.57752
# Epoch 437/500
# 585/585 [==============================] - 0s 182us/step - loss: 352.4021 - mean_absolute_error: 352.4021 - val_loss: 423.5527 - val_mean_absolute_error: 423.5527
#
# Epoch 00437: val_loss did not improve from 365.57752
# Epoch 438/500
# 585/585 [==============================] - 0s 148us/step - loss: 348.0332 - mean_absolute_error: 348.0332 - val_loss: 422.7364 - val_mean_absolute_error: 422.7364
#
# Epoch 00438: val_loss did not improve from 365.57752
# Epoch 439/500
# 585/585 [==============================] - 0s 164us/step - loss: 343.9396 - mean_absolute_error: 343.9396 - val_loss: 458.7744 - val_mean_absolute_error: 458.7744
#
# Epoch 00439: val_loss did not improve from 365.57752
# Epoch 440/500
# 585/585 [==============================] - 0s 162us/step - loss: 354.5043 - mean_absolute_error: 354.5043 - val_loss: 411.6581 - val_mean_absolute_error: 411.6581
#
# Epoch 00440: val_loss did not improve from 365.57752
# Epoch 441/500
# 585/585 [==============================] - 0s 148us/step - loss: 358.3789 - mean_absolute_error: 358.3789 - val_loss: 417.2327 - val_mean_absolute_error: 417.2327
#
# Epoch 00441: val_loss did not improve from 365.57752
# Epoch 442/500
# 585/585 [==============================] - 0s 143us/step - loss: 343.0719 - mean_absolute_error: 343.0719 - val_loss: 430.0829 - val_mean_absolute_error: 430.0829
#
# Epoch 00442: val_loss did not improve from 365.57752
# Epoch 443/500
# 585/585 [==============================] - 0s 159us/step - loss: 350.7537 - mean_absolute_error: 350.7537 - val_loss: 419.4873 - val_mean_absolute_error: 419.4873
#
# Epoch 00443: val_loss did not improve from 365.57752
# Epoch 444/500
# 585/585 [==============================] - 0s 158us/step - loss: 341.0387 - mean_absolute_error: 341.0387 - val_loss: 450.4238 - val_mean_absolute_error: 450.4238
#
# Epoch 00444: val_loss did not improve from 365.57752
# Epoch 445/500
# 585/585 [==============================] - 0s 153us/step - loss: 360.5926 - mean_absolute_error: 360.5926 - val_loss: 417.7803 - val_mean_absolute_error: 417.7803
#
# Epoch 00445: val_loss did not improve from 365.57752
# Epoch 446/500
# 585/585 [==============================] - 0s 169us/step - loss: 355.7335 - mean_absolute_error: 355.7335 - val_loss: 467.7892 - val_mean_absolute_error: 467.7892
#
# Epoch 00446: val_loss did not improve from 365.57752
# Epoch 447/500
# 585/585 [==============================] - 0s 167us/step - loss: 360.7438 - mean_absolute_error: 360.7438 - val_loss: 392.8024 - val_mean_absolute_error: 392.8024
#
# Epoch 00447: val_loss did not improve from 365.57752
# Epoch 448/500
# 585/585 [==============================] - 0s 177us/step - loss: 355.1407 - mean_absolute_error: 355.1407 - val_loss: 411.4791 - val_mean_absolute_error: 411.4791
#
# Epoch 00448: val_loss did not improve from 365.57752
# Epoch 449/500
# 585/585 [==============================] - 0s 160us/step - loss: 345.2416 - mean_absolute_error: 345.2416 - val_loss: 446.6106 - val_mean_absolute_error: 446.6106
#
# Epoch 00449: val_loss did not improve from 365.57752
# Epoch 450/500
# 585/585 [==============================] - 0s 172us/step - loss: 354.3729 - mean_absolute_error: 354.3729 - val_loss: 397.2883 - val_mean_absolute_error: 397.2883
#
# Epoch 00450: val_loss did not improve from 365.57752
# Epoch 451/500
# 585/585 [==============================] - 0s 153us/step - loss: 366.1958 - mean_absolute_error: 366.1958 - val_loss: 444.4523 - val_mean_absolute_error: 444.4523
#
# Epoch 00451: val_loss did not improve from 365.57752
# Epoch 452/500
# 585/585 [==============================] - 0s 164us/step - loss: 370.5843 - mean_absolute_error: 370.5843 - val_loss: 412.4995 - val_mean_absolute_error: 412.4995
#
# Epoch 00452: val_loss did not improve from 365.57752
# Epoch 453/500
# 585/585 [==============================] - 0s 158us/step - loss: 342.9223 - mean_absolute_error: 342.9223 - val_loss: 411.7741 - val_mean_absolute_error: 411.7741
#
# Epoch 00453: val_loss did not improve from 365.57752
# Epoch 454/500
# 585/585 [==============================] - 0s 133us/step - loss: 354.2723 - mean_absolute_error: 354.2723 - val_loss: 419.1784 - val_mean_absolute_error: 419.1784
#
# Epoch 00454: val_loss did not improve from 365.57752
# Epoch 455/500
# 585/585 [==============================] - 0s 138us/step - loss: 347.5916 - mean_absolute_error: 347.5916 - val_loss: 429.8366 - val_mean_absolute_error: 429.8366
#
# Epoch 00455: val_loss did not improve from 365.57752
# Epoch 456/500
# 585/585 [==============================] - 0s 135us/step - loss: 345.9852 - mean_absolute_error: 345.9852 - val_loss: 419.9314 - val_mean_absolute_error: 419.9314
# Epoch 00456: val_loss did not improve from 365.57752
# Epoch 457/500
# 585/585 [==============================] - 0s 131us/step - loss: 338.2377 - mean_absolute_error: 338.2377 - val_loss: 444.6878 - val_mean_absolute_error: 444.6878
#
# Epoch 00457: val_loss did not improve from 365.57752
# Epoch 458/500
# 585/585 [==============================] - 0s 234us/step - loss: 333.6692 - mean_absolute_error: 333.6692 - val_loss: 426.8965 - val_mean_absolute_error: 426.8965
#
# Epoch 00458: val_loss did not improve from 365.57752
# Epoch 459/500
# 585/585 [==============================] - 0s 182us/step - loss: 340.8630 - mean_absolute_error: 340.8630 - val_loss: 407.2346 - val_mean_absolute_error: 407.2346
#
# Epoch 00459: val_loss did not improve from 365.57752
# Epoch 460/500
# 585/585 [==============================] - 0s 150us/step - loss: 356.0380 - mean_absolute_error: 356.0380 - val_loss: 443.6602 - val_mean_absolute_error: 443.6602
#
# Epoch 00460: val_loss did not improve from 365.57752
# Epoch 461/500
# 585/585 [==============================] - 0s 179us/step - loss: 348.0932 - mean_absolute_error: 348.0932 - val_loss: 432.3847 - val_mean_absolute_error: 432.3847
#
# Epoch 00461: val_loss did not improve from 365.57752
# Epoch 462/500
# 585/585 [==============================] - 0s 174us/step - loss: 357.4234 - mean_absolute_error: 357.4234 - val_loss: 406.7863 - val_mean_absolute_error: 406.7863
#
# Epoch 00462: val_loss did not improve from 365.57752
# Epoch 463/500
# 585/585 [==============================] - 0s 159us/step - loss: 357.6806 - mean_absolute_error: 357.6806 - val_loss: 421.7886 - val_mean_absolute_error: 421.7886
#
# Epoch 00463: val_loss did not improve from 365.57752
# Epoch 464/500
# 585/585 [==============================] - 0s 148us/step - loss: 350.8785 - mean_absolute_error: 350.8785 - val_loss: 424.9715 - val_mean_absolute_error: 424.9715
#
# Epoch 00464: val_loss did not improve from 365.57752
# Epoch 465/500
# 585/585 [==============================] - 0s 167us/step - loss: 347.2212 - mean_absolute_error: 347.2212 - val_loss: 421.2263 - val_mean_absolute_error: 421.2263
#
# Epoch 00465: val_loss did not improve from 365.57752
# Epoch 466/500
# 585/585 [==============================] - 0s 138us/step - loss: 338.7691 - mean_absolute_error: 338.7691 - val_loss: 419.2681 - val_mean_absolute_error: 419.2681
#
# Epoch 00466: val_loss did not improve from 365.57752
# Epoch 467/500
# 585/585 [==============================] - 0s 136us/step - loss: 342.4597 - mean_absolute_error: 342.4597 - val_loss: 419.4470 - val_mean_absolute_error: 419.4470
#
# Epoch 00467: val_loss did not improve from 365.57752
# Epoch 468/500
# 585/585 [==============================] - 0s 147us/step - loss: 335.8381 - mean_absolute_error: 335.8381 - val_loss: 436.3179 - val_mean_absolute_error: 436.3179
#
# Epoch 00468: val_loss did not improve from 365.57752
# Epoch 469/500
# 585/585 [==============================] - 0s 164us/step - loss: 347.6364 - mean_absolute_error: 347.6364 - val_loss: 442.9529 - val_mean_absolute_error: 442.9529
#
# Epoch 00469: val_loss did not improve from 365.57752
# Epoch 470/500
# 585/585 [==============================] - 0s 153us/step - loss: 349.8232 - mean_absolute_error: 349.8232 - val_loss: 399.0644 - val_mean_absolute_error: 399.0644
#
# Epoch 00470: val_loss did not improve from 365.57752
# Epoch 471/500
# 585/585 [==============================] - 0s 148us/step - loss: 337.3896 - mean_absolute_error: 337.3896 - val_loss: 428.6593 - val_mean_absolute_error: 428.6593
#
# Epoch 00471: val_loss did not improve from 365.57752
# Epoch 472/500
# 585/585 [==============================] - 0s 145us/step - loss: 336.8234 - mean_absolute_error: 336.8234 - val_loss: 405.3155 - val_mean_absolute_error: 405.3155
#
# Epoch 00472: val_loss did not improve from 365.57752
# Epoch 473/500
# 585/585 [==============================] - 0s 165us/step - loss: 348.9376 - mean_absolute_error: 348.9376 - val_loss: 446.3041 - val_mean_absolute_error: 446.3041
#
# Epoch 00473: val_loss did not improve from 365.57752
# Epoch 474/500
# 585/585 [==============================] - 0s 154us/step - loss: 339.9177 - mean_absolute_error: 339.9177 - val_loss: 433.5109 - val_mean_absolute_error: 433.5109
#
# Epoch 00474: val_loss did not improve from 365.57752
# Epoch 475/500
# 585/585 [==============================] - 0s 141us/step - loss: 334.5364 - mean_absolute_error: 334.5364 - val_loss: 408.4508 - val_mean_absolute_error: 408.4508
#
# Epoch 00475: val_loss did not improve from 365.57752
# Epoch 476/500
# 585/585 [==============================] - 0s 150us/step - loss: 330.4275 - mean_absolute_error: 330.4275 - val_loss: 402.7967 - val_mean_absolute_error: 402.7967
#
# Epoch 00476: val_loss did not improve from 365.57752
# Epoch 477/500
# 585/585 [==============================] - 0s 142us/step - loss: 340.4237 - mean_absolute_error: 340.4237 - val_loss: 413.7916 - val_mean_absolute_error: 413.7916
#
# Epoch 00477: val_loss did not improve from 365.57752
# Epoch 478/500
# 585/585 [==============================] - 0s 157us/step - loss: 356.2068 - mean_absolute_error: 356.2068 - val_loss: 439.4250 - val_mean_absolute_error: 439.4250
#
# Epoch 00478: val_loss did not improve from 365.57752
# Epoch 479/500
# 585/585 [==============================] - 0s 189us/step - loss: 344.7288 - mean_absolute_error: 344.7288 - val_loss: 423.8777 - val_mean_absolute_error: 423.8777
#
# Epoch 00479: val_loss did not improve from 365.57752
# Epoch 480/500
# 585/585 [==============================] - 0s 184us/step - loss: 344.2412 - mean_absolute_error: 344.2412 - val_loss: 434.8358 - val_mean_absolute_error: 434.8358
#
# Epoch 00480: val_loss did not improve from 365.57752
# Epoch 481/500
# 585/585 [==============================] - 0s 193us/step - loss: 342.2141 - mean_absolute_error: 342.2141 - val_loss: 450.7464 - val_mean_absolute_error: 450.7464
#
# Epoch 00481: val_loss did not improve from 365.57752
# Epoch 482/500
# 585/585 [==============================] - 0s 235us/step - loss: 331.0843 - mean_absolute_error: 331.0843 - val_loss: 441.3735 - val_mean_absolute_error: 441.3735
#
# Epoch 00482: val_loss did not improve from 365.57752
# Epoch 483/500
# 585/585 [==============================] - 0s 184us/step - loss: 342.9446 - mean_absolute_error: 342.9446 - val_loss: 448.1582 - val_mean_absolute_error: 448.1582
#
# Epoch 00483: val_loss did not improve from 365.57752
# Epoch 484/500
# 585/585 [==============================] - 0s 205us/step - loss: 344.5359 - mean_absolute_error: 344.5359 - val_loss: 420.7585 - val_mean_absolute_error: 420.7585
#
# Epoch 00484: val_loss did not improve from 365.57752
# Epoch 485/500
# 585/585 [==============================] - 0s 172us/step - loss: 335.9816 - mean_absolute_error: 335.9816 - val_loss: 422.3339 - val_mean_absolute_error: 422.3339
#
# Epoch 00485: val_loss did not improve from 365.57752
# Epoch 486/500
# 585/585 [==============================] - 0s 167us/step - loss: 340.0590 - mean_absolute_error: 340.0590 - val_loss: 390.5147 - val_mean_absolute_error: 390.5147
#
# Epoch 00486: val_loss did not improve from 365.57752
# Epoch 487/500
# 585/585 [==============================] - 0s 157us/step - loss: 329.4463 - mean_absolute_error: 329.4463 - val_loss: 432.5977 - val_mean_absolute_error: 432.5977
#
# Epoch 00487: val_loss did not improve from 365.57752
# Epoch 488/500
# 585/585 [==============================] - 0s 168us/step - loss: 331.9276 - mean_absolute_error: 331.9276 - val_loss: 394.6301 - val_mean_absolute_error: 394.6301
#
# Epoch 00488: val_loss did not improve from 365.57752
# Epoch 489/500
# 585/585 [==============================] - 0s 170us/step - loss: 339.6196 - mean_absolute_error: 339.6196 - val_loss: 436.9189 - val_mean_absolute_error: 436.9189
#
# Epoch 00489: val_loss did not improve from 365.57752
# Epoch 490/500
# 585/585 [==============================] - 0s 160us/step - loss: 327.8359 - mean_absolute_error: 327.8359 - val_loss: 447.8748 - val_mean_absolute_error: 447.8748
#
# Epoch 00490: val_loss did not improve from 365.57752
# Epoch 491/500
# 585/585 [==============================] - 0s 176us/step - loss: 335.9243 - mean_absolute_error: 335.9243 - val_loss: 388.7434 - val_mean_absolute_error: 388.7434
#
# Epoch 00491: val_loss did not improve from 365.57752
# Epoch 492/500
# 585/585 [==============================] - 0s 169us/step - loss: 329.9817 - mean_absolute_error: 329.9817 - val_loss: 410.0412 - val_mean_absolute_error: 410.0412
#
# Epoch 00492: val_loss did not improve from 365.57752
# Epoch 493/500
# 585/585 [==============================] - 0s 176us/step - loss: 330.5619 - mean_absolute_error: 330.5619 - val_loss: 440.0234 - val_mean_absolute_error: 440.0234
#
# Epoch 00493: val_loss did not improve from 365.57752
# Epoch 494/500
# 585/585 [==============================] - 0s 159us/step - loss: 333.8489 - mean_absolute_error: 333.8489 - val_loss: 416.1850 - val_mean_absolute_error: 416.1850
#
# Epoch 00494: val_loss did not improve from 365.57752
# Epoch 495/500
# 585/585 [==============================] - 0s 172us/step - loss: 362.5792 - mean_absolute_error: 362.5792 - val_loss: 414.3020 - val_mean_absolute_error: 414.3020
#
# Epoch 00495: val_loss did not improve from 365.57752
# Epoch 496/500
# 585/585 [==============================] - 0s 186us/step - loss: 344.6619 - mean_absolute_error: 344.6619 - val_loss: 430.7276 - val_mean_absolute_error: 430.7276
#
# Epoch 00496: val_loss did not improve from 365.57752
# Epoch 497/500
# 585/585 [==============================] - 0s 201us/step - loss: 329.6684 - mean_absolute_error: 329.6684 - val_loss: 418.7019 - val_mean_absolute_error: 418.7019
#
# Epoch 00497: val_loss did not improve from 365.57752
# Epoch 498/500
# 585/585 [==============================] - 0s 220us/step - loss: 331.0007 - mean_absolute_error: 331.0007 - val_loss: 381.8741 - val_mean_absolute_error: 381.8741
#
# Epoch 00498: val_loss did not improve from 365.57752
# Epoch 499/500
# 585/585 [==============================] - 0s 198us/step - loss: 339.6948 - mean_absolute_error: 339.6948 - val_loss: 452.1158 - val_mean_absolute_error: 452.1158
#
# Epoch 00499: val_loss did not improve from 365.57752
# Epoch 500/500
# 585/585 [==============================] - 0s 225us/step - loss: 339.8775 - mean_absolute_error: 339.8775 - val_loss: 452.2587 - val_mean_absolute_error: 452.2587
#
# Epoch 00500: val_loss did not improve from 365.57752

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = '제모제date-Weights-412--365.57752-cat04-vf05.hdf5'
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# Out:
# W0719 18:56:03.471520  6768 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0719 18:56:03.472517  6768 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']

print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

columns_in_data = list(train_X.columns)
customF = formulaGen(target='qty',ind_features=columns_in_data)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
print('검증세트점수 : {:.3f}'.format( r2_score(val_y, olsModel.predict(val_X))   ) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 제모제의 회귀분석 결과 :
# 훈련세트점수 : 0.932
# 검증세트점수 : 0.333
# XGBoost을 이용한 제모제의 회귀분석 결과 :
# 훈련세트점수 : 0.799
# 검증세트점수 : 0.425
# LinearRegression을 이용한 제모제의 회귀분석 결과 :
# 훈련세트점수 : 0.516
# 검증세트점수 : 0.423
# RidgeRegression을 이용한 제모제의 회귀분석 결과 :
# 훈련세트점수 : 0.509
# 검증세트점수 : 0.435
# LassoRegression을 이용한 제모제의 회귀분석 결과 :
# 훈련세트점수 : 0.516
# 검증세트점수 : 0.423
# OLS을 이용한 제모제의 회귀분석 결과 :
# 훈련세트점수 : 0.516
# 검증세트점수 : 0.423

# %%
# columns_in_data = ['temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not', 'snow_or_not',
#                     '공기상태_0', '공기상태_1', '공기상태_2']

# formulaGen은 단순 1차 다항식을 제조해준다.
# customF = formulaGen(target='qty',ind_features=columns_in_data)
# customF = formulaGen(target='qty',ind_features=['temp', 'wind','lgt_time','rain_or_not'])
customF = 'qty ~ I(temp**2) + cloud + wind + lgt_time + rain_or_not + snow_or_not'

olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('사람이 직접 식을 때려 박았을때 : {:.3f}'.format(r2_score(val_y, olsModel.predict(val_X))) )
print(olsModel.summary())
# Out:
# 사람이 직접 식을 때려 박았을때 : 0.215
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.540
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     141.6
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          1.46e-118
# Time:                        18:56:05   Log-Likelihood:                -5789.7
# No. Observations:                 732   AIC:                         1.159e+04
# Df Residuals:                     725   BIC:                         1.163e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -103.7622    157.556     -0.659      0.510    -413.083     205.559
# I(temp ** 2)     2.4426      0.104     23.556      0.000       2.239       2.646
# cloud           41.7243     15.421      2.706      0.007      11.448      72.000
# wind            51.4245     36.635      1.404      0.161     -20.499     123.348
# lgt_time        48.5913     12.199      3.983      0.000      24.642      72.540
# rain_or_not    107.1213     71.022      1.508      0.132     -32.313     246.556
# snow_or_not    -12.4969    136.750     -0.091      0.927    -280.970     255.977
# ==============================================================================
# Omnibus:                       45.279   Durbin-Watson:                   0.539
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.416
# Skew:                           0.595   Prob(JB):                     2.52e-12
# Kurtosis:                       3.579   Cond. No.                     2.51e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.51e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
#             '공기상태_0', '공기상태_1', '공기상태_2']
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
            '공기상태']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = lv_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 예측률 계산
# https://yamalab.tistory.com/46

# RMSE (Root Mean Squared Error) : 
# OLS 추정에서 일반적인 표준 오차이다. 예측 대상의 scale(단위 크기)에 주의해야하는 단점이 있다. 
# MSE는 root를 수식에서 제외, SSE는 root와 분모를 제외한 수식으로, SE가 붙은 척도들은 거기서 거기인 척도들이라고 보면 된다.
# 다만 디테일한 사용법에 차이가 있을 뿐.

# MAPE (Mean Absolute Percentage Error) :

# 위 방법의 단점을 보완한 것이다. 
# At는 실제값, Ft는 예측값인데, 이를 At로 나누어서 오차를 절대적 크기로 보는것이 아닌
# 비율의 크기로 보고자 하는 것이 핵심이다.
# 이 방법은 At가 0에 가까울수록 비정상적인 값이 나온다는 단점이 있다.

# MAPE가 0에 가까울수록 좋은 모델
result_df['mape_keras'] = abs((result_df.qty - result_df.keras_qty) / result_df.qty )
result_df['mape_rf'] = abs((result_df.qty - result_df.rf_qty) / result_df.qty )
result_df['mape_xgb'] = abs((result_df.qty - result_df.xgb_qty) / result_df.qty )
result_df['mape_lin'] = abs((result_df.qty - result_df.lin_qty) / result_df.qty )
result_df['mape_ridge'] = abs((result_df.qty - result_df.ridge_qty) / result_df.qty )
result_df['mape_lasso'] = abs((result_df.qty - result_df.lasso_qty) / result_df.qty )
result_df['mape_ols'] = abs((result_df.qty - result_df.ols_qty) / result_df.qty )

print('Keras 인공 신경망 모델 MAPE \t: {:<.2f}'.format(result_df['mape_keras'].sum() / result_df.shape[0] ))
print('RandomForest 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_rf'].sum() / result_df.shape[0] ))
print('XGBoosting  모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_xgb'].sum() / result_df.shape[0] ))
print('Linear 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lin'].sum() / result_df.shape[0] ))
print('Ridge 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_ridge'].sum() / result_df.shape[0] ))
print('Lasso 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lasso'].sum() / result_df.shape[0] ))
print('OLS 모델 MAPE \t\t\t: {:<.2f}'.format(result_df['mape_ols'].sum() / result_df.shape[0] ))
# Out:
# Keras 인공 신경망 모델 MAPE 	: 0.49
# RandomForest 모델 MAPE 		: 0.44
# XGBoosting  모델 MAPE 		: 0.60
# Linear 모델 MAPE 		: 0.89
# Ridge 모델 MAPE 		: 0.91
# Lasso 모델 MAPE 		: 0.89
# OLS 모델 MAPE 			: 0.83

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not','snow_or_not', 
#                                                   '공기상태_0', '공기상태_1', '공기상태_2']

# 1~9 : 1 temp ~ 9 공기상태_2
n= 1
# alpha 값 0~1
alp = 1
# scatter plot 점 크기
dot_size = 20

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# # 1~106 / 106~156
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
