# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor


# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1))
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula


#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
lv_grouped = lv_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_lv_grouped = lv_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '선케어'만 빼서 df생성
item = '선케어'
grouped_by = 'week'
day_lv_grouped_w_item = pd.merge(day_lv_grouped.loc[day_lv_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_lv_grouped_w_sns_item = pd.merge(day_lv_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
lv_day_w = day_lv_grouped_w_sns_item[selected_cols]

# %% [markdown]
# # 주단위로 종합해보기

# %%
lv_week_w = lv_day_w.copy()
lv_week_w = addDayWeek(lv_week_w)

cols_Ineed = ['week','category', 'qty', 'temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
lv_week_w = lv_week_w[cols_Ineed]

# %%
list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
lowVIF(lv_week_w,40,list_col)

list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',]
lv_week_w = lv_week_w[['week','qty']+list_col].groupby('week').mean().reset_index()
# gs_week_w.tail(2)

# week: 1~105 = 2016~2017년
# week: 106~157 = 2018년
train_data = lv_week_w.loc[lv_week_w.week <=105]
test_date = lv_week_w.loc[lv_week_w.week >105]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
combined = lv_week_w.loc[:,'temp':'PM25']
target = lv_week_w.loc[:,'qty']

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 15
# Number of nun-numerical columns with no nan values : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 15 columns before encoding categorical features
# There are 15 columns after encoding categorical features

# %%
# 여기서 이코드으 제작자는 수동으로 훈련/검증셋을 나눔
# 105주 기준으로 나누겠음
cut_line = 106
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()
train.shape
# Out:
# (106, 15)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 15:25:24.856685  7588 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 15:25:24.872665  7588 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 15:25:24.875633  7588 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0717 15:25:24.931484  7588 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,913
# Trainable params: 166,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### =========='xxxxyyyyzzzz.hdf5'파일이 안주어지면 실행.(있으면 실행 필요없음)==========

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'LV-'+item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=106을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0717 15:25:31.545755  7588 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0717 15:25:31.661118  7588 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 84 samples, validate on 22 samples
# Epoch 1/500
# 84/84 [==============================] - 0s 3ms/step - loss: 4528.5204 - mean_absolute_error: 4528.5204 - val_loss: 1757.7672 - val_mean_absolute_error: 1757.7672
#
# Epoch 00001: val_loss improved from inf to 1757.76721, saving model to LV-선케어week-Weights-001--1757.76721.hdf5
# Epoch 2/500
# 84/84 [==============================] - 0s 95us/step - loss: 4485.2627 - mean_absolute_error: 4485.2627 - val_loss: 1692.5649 - val_mean_absolute_error: 1692.5649
#
# Epoch 00002: val_loss improved from 1757.76721 to 1692.56494, saving model to LV-선케어week-Weights-002--1692.56494.hdf5
# Epoch 3/500
# 84/84 [==============================] - 0s 95us/step - loss: 4404.6888 - mean_absolute_error: 4404.6888 - val_loss: 1562.5155 - val_mean_absolute_error: 1562.5155
#
# Epoch 00003: val_loss improved from 1692.56494 to 1562.51550, saving model to LV-선케어week-Weights-003--1562.51550.hdf5
# Epoch 4/500
# 84/84 [==============================] - 0s 119us/step - loss: 4245.4874 - mean_absolute_error: 4245.4874 - val_loss: 1313.4764 - val_mean_absolute_error: 1313.4764
#
# Epoch 00004: val_loss improved from 1562.51550 to 1313.47644, saving model to LV-선케어week-Weights-004--1313.47644.hdf5
# Epoch 5/500
# 84/84 [==============================] - 0s 107us/step - loss: 3945.4069 - mean_absolute_error: 3945.4069 - val_loss: 870.4444 - val_mean_absolute_error: 870.4444
#
# Epoch 00005: val_loss improved from 1313.47644 to 870.44440, saving model to LV-선케어week-Weights-005--870.44440.hdf5
# Epoch 6/500
# 84/84 [==============================] - 0s 107us/step - loss: 3492.7078 - mean_absolute_error: 3492.7078 - val_loss: 776.0302 - val_mean_absolute_error: 776.0302
#
# Epoch 00006: val_loss improved from 870.44440 to 776.03021, saving model to LV-선케어week-Weights-006--776.03021.hdf5
# Epoch 7/500
# 84/84 [==============================] - 0s 107us/step - loss: 3102.7746 - mean_absolute_error: 3102.7746 - val_loss: 1374.5540 - val_mean_absolute_error: 1374.5540
#
# Epoch 00007: val_loss did not improve from 776.03021
# Epoch 8/500
# 84/84 [==============================] - 0s 119us/step - loss: 2981.4422 - mean_absolute_error: 2981.4422 - val_loss: 2228.8909 - val_mean_absolute_error: 2228.8909
#
# Epoch 00008: val_loss did not improve from 776.03021
# Epoch 9/500
# 84/84 [==============================] - 0s 142us/step - loss: 3047.8791 - mean_absolute_error: 3047.8791 - val_loss: 2512.8562 - val_mean_absolute_error: 2512.8562
#
# Epoch 00009: val_loss did not improve from 776.03021
# Epoch 10/500
# 84/84 [==============================] - 0s 95us/step - loss: 3108.9140 - mean_absolute_error: 3108.9140 - val_loss: 2346.8271 - val_mean_absolute_error: 2346.8271
#
# Epoch 00010: val_loss did not improve from 776.03021
# Epoch 11/500
# 84/84 [==============================] - 0s 143us/step - loss: 3035.7991 - mean_absolute_error: 3035.7991 - val_loss: 1872.1884 - val_mean_absolute_error: 1872.1884
#
# Epoch 00011: val_loss did not improve from 776.03021
# Epoch 12/500
# 84/84 [==============================] - 0s 119us/step - loss: 2955.1504 - mean_absolute_error: 2955.1504 - val_loss: 1443.4207 - val_mean_absolute_error: 1443.4207
#
# Epoch 00012: val_loss did not improve from 776.03021
# Epoch 13/500
# 84/84 [==============================] - 0s 142us/step - loss: 3008.2706 - mean_absolute_error: 3008.2706 - val_loss: 1185.0927 - val_mean_absolute_error: 1185.0927
#
# Epoch 00013: val_loss did not improve from 776.03021
# Epoch 14/500
# 84/84 [==============================] - 0s 107us/step - loss: 2993.3179 - mean_absolute_error: 2993.3179 - val_loss: 1147.5103 - val_mean_absolute_error: 1147.5103
#
# Epoch 00014: val_loss did not improve from 776.03021
# Epoch 15/500
# 84/84 [==============================] - 0s 107us/step - loss: 2995.0098 - mean_absolute_error: 2995.0098 - val_loss: 1179.3839 - val_mean_absolute_error: 1179.3839
#
# Epoch 00015: val_loss did not improve from 776.03021
# Epoch 16/500
# 84/84 [==============================] - 0s 107us/step - loss: 2990.6980 - mean_absolute_error: 2990.6980 - val_loss: 1319.6034 - val_mean_absolute_error: 1319.6034
#
# Epoch 00016: val_loss did not improve from 776.03021
# Epoch 17/500
# 84/84 [==============================] - 0s 107us/step - loss: 2968.2775 - mean_absolute_error: 2968.2775 - val_loss: 1449.5073 - val_mean_absolute_error: 1449.5073
#
# Epoch 00017: val_loss did not improve from 776.03021
# Epoch 18/500
# 84/84 [==============================] - 0s 107us/step - loss: 2953.9257 - mean_absolute_error: 2953.9257 - val_loss: 1501.8997 - val_mean_absolute_error: 1501.8997
#
# Epoch 00018: val_loss did not improve from 776.03021
# Epoch 19/500
# 84/84 [==============================] - 0s 107us/step - loss: 2954.5085 - mean_absolute_error: 2954.5085 - val_loss: 1530.2554 - val_mean_absolute_error: 1530.2554
#
# Epoch 00019: val_loss did not improve from 776.03021
# Epoch 20/500
# 84/84 [==============================] - 0s 107us/step - loss: 2966.8440 - mean_absolute_error: 2966.8440 - val_loss: 1630.2993 - val_mean_absolute_error: 1630.2993
#
# Epoch 00020: val_loss did not improve from 776.03021
# Epoch 21/500
# 84/84 [==============================] - 0s 95us/step - loss: 2956.9883 - mean_absolute_error: 2956.9883 - val_loss: 1566.5468 - val_mean_absolute_error: 1566.5468
#
# Epoch 00021: val_loss did not improve from 776.03021
# Epoch 22/500
# 84/84 [==============================] - 0s 119us/step - loss: 2951.3856 - mean_absolute_error: 2951.3856 - val_loss: 1472.6616 - val_mean_absolute_error: 1472.6616
#
# Epoch 00022: val_loss did not improve from 776.03021
# Epoch 23/500
# 84/84 [==============================] - 0s 95us/step - loss: 2950.3798 - mean_absolute_error: 2950.3798 - val_loss: 1412.6309 - val_mean_absolute_error: 1412.6309
#
# Epoch 00023: val_loss did not improve from 776.03021
# Epoch 24/500
# 84/84 [==============================] - 0s 107us/step - loss: 2942.9796 - mean_absolute_error: 2942.9796 - val_loss: 1413.1371 - val_mean_absolute_error: 1413.1371
#
# Epoch 00024: val_loss did not improve from 776.03021
# Epoch 25/500
# 84/84 [==============================] - 0s 119us/step - loss: 2940.9930 - mean_absolute_error: 2940.9930 - val_loss: 1443.4897 - val_mean_absolute_error: 1443.4897
#
# Epoch 00025: val_loss did not improve from 776.03021
# Epoch 26/500
# 84/84 [==============================] - 0s 142us/step - loss: 2940.1334 - mean_absolute_error: 2940.1334 - val_loss: 1453.6456 - val_mean_absolute_error: 1453.6456
#
# Epoch 00026: val_loss did not improve from 776.03021
# Epoch 27/500
# 84/84 [==============================] - 0s 119us/step - loss: 2937.1904 - mean_absolute_error: 2937.1904 - val_loss: 1427.2456 - val_mean_absolute_error: 1427.2456
#
# Epoch 00027: val_loss did not improve from 776.03021
# Epoch 28/500
# 84/84 [==============================] - 0s 107us/step - loss: 2934.8784 - mean_absolute_error: 2934.8784 - val_loss: 1354.1581 - val_mean_absolute_error: 1354.1581
#
# Epoch 00028: val_loss did not improve from 776.03021
# Epoch 29/500
# 84/84 [==============================] - 0s 107us/step - loss: 2937.5135 - mean_absolute_error: 2937.5135 - val_loss: 1334.5140 - val_mean_absolute_error: 1334.5140
#
# Epoch 00029: val_loss did not improve from 776.03021
# Epoch 30/500
# 84/84 [==============================] - 0s 119us/step - loss: 2936.4880 - mean_absolute_error: 2936.4880 - val_loss: 1367.1620 - val_mean_absolute_error: 1367.1620
#
# Epoch 00030: val_loss did not improve from 776.03021
# Epoch 31/500
# 84/84 [==============================] - 0s 107us/step - loss: 2937.8957 - mean_absolute_error: 2937.8957 - val_loss: 1332.4951 - val_mean_absolute_error: 1332.4951
#
# Epoch 00031: val_loss did not improve from 776.03021
# Epoch 32/500
# 84/84 [==============================] - 0s 119us/step - loss: 2929.6076 - mean_absolute_error: 2929.6076 - val_loss: 1438.2731 - val_mean_absolute_error: 1438.2731
#
# Epoch 00032: val_loss did not improve from 776.03021
# Epoch 33/500
# 84/84 [==============================] - 0s 119us/step - loss: 2920.6685 - mean_absolute_error: 2920.6685 - val_loss: 1501.3278 - val_mean_absolute_error: 1501.3278
#
# Epoch 00033: val_loss did not improve from 776.03021
# Epoch 34/500
# 84/84 [==============================] - 0s 107us/step - loss: 2922.9052 - mean_absolute_error: 2922.9052 - val_loss: 1586.3973 - val_mean_absolute_error: 1586.3973
# Epoch 00034: val_loss did not improve from 776.03021
# Epoch 35/500
# 84/84 [==============================] - 0s 107us/step - loss: 2919.6727 - mean_absolute_error: 2919.6727 - val_loss: 1620.7841 - val_mean_absolute_error: 1620.7841
#
# Epoch 00035: val_loss did not improve from 776.03021
# Epoch 36/500
# 84/84 [==============================] - 0s 107us/step - loss: 2917.8230 - mean_absolute_error: 2917.8230 - val_loss: 1598.0057 - val_mean_absolute_error: 1598.0057
#
# Epoch 00036: val_loss did not improve from 776.03021
# Epoch 37/500
# 84/84 [==============================] - 0s 107us/step - loss: 2917.3061 - mean_absolute_error: 2917.3061 - val_loss: 1557.2358 - val_mean_absolute_error: 1557.2358
#
# Epoch 00037: val_loss did not improve from 776.03021
# Epoch 38/500
# 84/84 [==============================] - 0s 107us/step - loss: 2909.7344 - mean_absolute_error: 2909.7344 - val_loss: 1459.0317 - val_mean_absolute_error: 1459.0317
#
# Epoch 00038: val_loss did not improve from 776.03021
# Epoch 39/500
# 84/84 [==============================] - 0s 95us/step - loss: 2906.5508 - mean_absolute_error: 2906.5508 - val_loss: 1383.1788 - val_mean_absolute_error: 1383.1788
#
# Epoch 00039: val_loss did not improve from 776.03021
# Epoch 40/500
# 84/84 [==============================] - 0s 107us/step - loss: 2913.6556 - mean_absolute_error: 2913.6556 - val_loss: 1378.2848 - val_mean_absolute_error: 1378.2848
#
# Epoch 00040: val_loss did not improve from 776.03021
# Epoch 41/500
# 84/84 [==============================] - 0s 107us/step - loss: 2901.5731 - mean_absolute_error: 2901.5731 - val_loss: 1432.1641 - val_mean_absolute_error: 1432.1641
#
# Epoch 00041: val_loss did not improve from 776.03021
# Epoch 42/500
# 84/84 [==============================] - 0s 107us/step - loss: 2898.1574 - mean_absolute_error: 2898.1574 - val_loss: 1519.6932 - val_mean_absolute_error: 1519.6932
#
# Epoch 00042: val_loss did not improve from 776.03021
# Epoch 43/500
# 84/84 [==============================] - 0s 119us/step - loss: 2893.5883 - mean_absolute_error: 2893.5883 - val_loss: 1562.9093 - val_mean_absolute_error: 1562.9093
#
# Epoch 00043: val_loss did not improve from 776.03021
# Epoch 44/500
# 84/84 [==============================] - 0s 107us/step - loss: 2893.4564 - mean_absolute_error: 2893.4564 - val_loss: 1550.7557 - val_mean_absolute_error: 1550.7557
#
# Epoch 00044: val_loss did not improve from 776.03021
# Epoch 45/500
# 84/84 [==============================] - 0s 119us/step - loss: 2887.6783 - mean_absolute_error: 2887.6783 - val_loss: 1506.9130 - val_mean_absolute_error: 1506.9130
#
# Epoch 00045: val_loss did not improve from 776.03021
# Epoch 46/500
# 84/84 [==============================] - 0s 107us/step - loss: 2882.8900 - mean_absolute_error: 2882.8900 - val_loss: 1435.0555 - val_mean_absolute_error: 1435.0555
#
# Epoch 00046: val_loss did not improve from 776.03021
# Epoch 47/500
# 84/84 [==============================] - 0s 95us/step - loss: 2880.2429 - mean_absolute_error: 2880.2429 - val_loss: 1423.5043 - val_mean_absolute_error: 1423.5043
#
# Epoch 00047: val_loss did not improve from 776.03021
# Epoch 48/500
# 84/84 [==============================] - 0s 107us/step - loss: 2871.2982 - mean_absolute_error: 2871.2982 - val_loss: 1489.0765 - val_mean_absolute_error: 1489.0765
#
# Epoch 00048: val_loss did not improve from 776.03021
# Epoch 49/500
# 84/84 [==============================] - 0s 95us/step - loss: 2868.7866 - mean_absolute_error: 2868.7866 - val_loss: 1546.4386 - val_mean_absolute_error: 1546.4386
#
# Epoch 00049: val_loss did not improve from 776.03021
# Epoch 50/500
# 84/84 [==============================] - 0s 131us/step - loss: 2861.6261 - mean_absolute_error: 2861.6261 - val_loss: 1544.3984 - val_mean_absolute_error: 1544.3984
#
# Epoch 00050: val_loss did not improve from 776.03021
# Epoch 51/500
# 84/84 [==============================] - 0s 156us/step - loss: 2856.4154 - mean_absolute_error: 2856.4154 - val_loss: 1549.1176 - val_mean_absolute_error: 1549.1176
#
# Epoch 00051: val_loss did not improve from 776.03021
# Epoch 52/500
# 84/84 [==============================] - 0s 142us/step - loss: 2850.2294 - mean_absolute_error: 2850.2294 - val_loss: 1502.4755 - val_mean_absolute_error: 1502.4755
#
# Epoch 00052: val_loss did not improve from 776.03021
# Epoch 53/500
# 84/84 [==============================] - 0s 119us/step - loss: 2850.9454 - mean_absolute_error: 2850.9454 - val_loss: 1466.1708 - val_mean_absolute_error: 1466.1708
#
# Epoch 00053: val_loss did not improve from 776.03021
# Epoch 54/500
# 84/84 [==============================] - 0s 119us/step - loss: 2839.3872 - mean_absolute_error: 2839.3872 - val_loss: 1592.7599 - val_mean_absolute_error: 1592.7599
#
# Epoch 00054: val_loss did not improve from 776.03021
# Epoch 55/500
# 84/84 [==============================] - 0s 119us/step - loss: 2828.1353 - mean_absolute_error: 2828.1353 - val_loss: 1642.9204 - val_mean_absolute_error: 1642.9204
#
# Epoch 00055: val_loss did not improve from 776.03021
# Epoch 56/500
# 84/84 [==============================] - 0s 107us/step - loss: 2819.3657 - mean_absolute_error: 2819.3657 - val_loss: 1723.9609 - val_mean_absolute_error: 1723.9609
#
# Epoch 00056: val_loss did not improve from 776.03021
# Epoch 57/500
# 84/84 [==============================] - 0s 119us/step - loss: 2810.8899 - mean_absolute_error: 2810.8899 - val_loss: 1667.5073 - val_mean_absolute_error: 1667.5073
#
# Epoch 00057: val_loss did not improve from 776.03021
# Epoch 58/500
# 84/84 [==============================] - 0s 119us/step - loss: 2796.7158 - mean_absolute_error: 2796.7158 - val_loss: 1681.0973 - val_mean_absolute_error: 1681.0973
#
# Epoch 00058: val_loss did not improve from 776.03021
# Epoch 59/500
# 84/84 [==============================] - 0s 119us/step - loss: 2786.6114 - mean_absolute_error: 2786.6114 - val_loss: 1733.8079 - val_mean_absolute_error: 1733.8079
#
# Epoch 00059: val_loss did not improve from 776.03021
# Epoch 60/500
# 84/84 [==============================] - 0s 142us/step - loss: 2772.6521 - mean_absolute_error: 2772.6521 - val_loss: 1673.0000 - val_mean_absolute_error: 1673.0000
#
# Epoch 00060: val_loss did not improve from 776.03021
# Epoch 61/500
# 84/84 [==============================] - 0s 107us/step - loss: 2745.1774 - mean_absolute_error: 2745.1774 - val_loss: 1542.5093 - val_mean_absolute_error: 1542.5093
#
# Epoch 00061: val_loss did not improve from 776.03021
# Epoch 62/500
# 84/84 [==============================] - 0s 119us/step - loss: 2738.9637 - mean_absolute_error: 2738.9637 - val_loss: 1382.6776 - val_mean_absolute_error: 1382.6776
#
# Epoch 00062: val_loss did not improve from 776.03021
# Epoch 63/500
# 84/84 [==============================] - 0s 166us/step - loss: 2756.9823 - mean_absolute_error: 2756.9823 - val_loss: 1366.5103 - val_mean_absolute_error: 1366.5103
#
# Epoch 00063: val_loss did not improve from 776.03021
# Epoch 64/500
# 84/84 [==============================] - 0s 154us/step - loss: 2677.8341 - mean_absolute_error: 2677.8341 - val_loss: 1867.1840 - val_mean_absolute_error: 1867.1840
#
# Epoch 00064: val_loss did not improve from 776.03021
# Epoch 65/500
# 84/84 [==============================] - 0s 119us/step - loss: 2708.7277 - mean_absolute_error: 2708.7277 - val_loss: 2491.0850 - val_mean_absolute_error: 2491.0850
#
# Epoch 00065: val_loss did not improve from 776.03021
# Epoch 66/500
# 84/84 [==============================] - 0s 119us/step - loss: 2694.1257 - mean_absolute_error: 2694.1257 - val_loss: 2323.3357 - val_mean_absolute_error: 2323.3357
#
# Epoch 00066: val_loss did not improve from 776.03021
# Epoch 67/500
# 84/84 [==============================] - 0s 119us/step - loss: 2630.1131 - mean_absolute_error: 2630.1131 - val_loss: 1813.8995 - val_mean_absolute_error: 1813.8995
#
# Epoch 00067: val_loss did not improve from 776.03021
# Epoch 68/500
# 84/84 [==============================] - 0s 107us/step - loss: 2566.0366 - mean_absolute_error: 2566.0366 - val_loss: 1424.9833 - val_mean_absolute_error: 1424.9833
#
# Epoch 00068: val_loss did not improve from 776.03021
# Epoch 69/500
# 84/84 [==============================] - 0s 142us/step - loss: 2552.9751 - mean_absolute_error: 2552.9751 - val_loss: 1481.2902 - val_mean_absolute_error: 1481.2902
#
# Epoch 00069: val_loss did not improve from 776.03021
# Epoch 70/500
# 84/84 [==============================] - 0s 107us/step - loss: 2486.7173 - mean_absolute_error: 2486.7173 - val_loss: 1972.6625 - val_mean_absolute_error: 1972.6625
#
# Epoch 00070: val_loss did not improve from 776.03021
# Epoch 71/500
# 84/84 [==============================] - 0s 119us/step - loss: 2456.8314 - mean_absolute_error: 2456.8314 - val_loss: 2096.4470 - val_mean_absolute_error: 2096.4470
#
# Epoch 00071: val_loss did not improve from 776.03021
# Epoch 72/500
# 84/84 [==============================] - 0s 226us/step - loss: 2370.9998 - mean_absolute_error: 2370.9998 - val_loss: 1578.8949 - val_mean_absolute_error: 1578.8949
#
# Epoch 00072: val_loss did not improve from 776.03021
# Epoch 73/500
# 84/84 [==============================] - 0s 107us/step - loss: 2342.1403 - mean_absolute_error: 2342.1403 - val_loss: 1436.9525 - val_mean_absolute_error: 1436.9525
#
# Epoch 00073: val_loss did not improve from 776.03021
# Epoch 74/500
# 84/84 [==============================] - 0s 119us/step - loss: 2281.9670 - mean_absolute_error: 2281.9670 - val_loss: 2175.1052 - val_mean_absolute_error: 2175.1052
#
# Epoch 00074: val_loss did not improve from 776.03021
# Epoch 75/500
# 84/84 [==============================] - 0s 119us/step - loss: 2181.1785 - mean_absolute_error: 2181.1785 - val_loss: 1775.7616 - val_mean_absolute_error: 1775.7616
#
# Epoch 00075: val_loss did not improve from 776.03021
# Epoch 76/500
# 84/84 [==============================] - 0s 166us/step - loss: 2114.5619 - mean_absolute_error: 2114.5619 - val_loss: 1690.4551 - val_mean_absolute_error: 1690.4551
#
# Epoch 00076: val_loss did not improve from 776.03021
# Epoch 77/500
# 84/84 [==============================] - 0s 142us/step - loss: 2097.8453 - mean_absolute_error: 2097.8453 - val_loss: 2142.4011 - val_mean_absolute_error: 2142.4011
#
# Epoch 00077: val_loss did not improve from 776.03021
# Epoch 78/500
# 84/84 [==============================] - 0s 154us/step - loss: 2050.0136 - mean_absolute_error: 2050.0136 - val_loss: 2325.1448 - val_mean_absolute_error: 2325.1448
#
# Epoch 00078: val_loss did not improve from 776.03021
# Epoch 79/500
# 84/84 [==============================] - 0s 142us/step - loss: 2062.3312 - mean_absolute_error: 2062.3312 - val_loss: 2060.9482 - val_mean_absolute_error: 2060.9482
#
# Epoch 00079: val_loss did not improve from 776.03021
# Epoch 80/500
# 84/84 [==============================] - 0s 142us/step - loss: 2152.5057 - mean_absolute_error: 2152.5057 - val_loss: 1995.7925 - val_mean_absolute_error: 1995.7925
#
# Epoch 00080: val_loss did not improve from 776.03021
# Epoch 81/500
# 84/84 [==============================] - 0s 131us/step - loss: 2050.4289 - mean_absolute_error: 2050.4289 - val_loss: 2740.9375 - val_mean_absolute_error: 2740.9375
#
# Epoch 00081: val_loss did not improve from 776.03021
# Epoch 82/500
# 84/84 [==============================] - 0s 154us/step - loss: 2064.7764 - mean_absolute_error: 2064.7764 - val_loss: 1843.2195 - val_mean_absolute_error: 1843.2195
#
# Epoch 00082: val_loss did not improve from 776.03021
# Epoch 83/500
# 84/84 [==============================] - 0s 131us/step - loss: 2150.8660 - mean_absolute_error: 2150.8660 - val_loss: 1409.7505 - val_mean_absolute_error: 1409.7505
#
# Epoch 00083: val_loss did not improve from 776.03021
# Epoch 84/500
# 84/84 [==============================] - 0s 138us/step - loss: 2124.6193 - mean_absolute_error: 2124.6193 - val_loss: 2153.0947 - val_mean_absolute_error: 2153.0947
#
# Epoch 00084: val_loss did not improve from 776.03021
# Epoch 85/500
# 84/84 [==============================] - 0s 142us/step - loss: 1983.9194 - mean_absolute_error: 1983.9194 - val_loss: 2403.2463 - val_mean_absolute_error: 2403.2463
#
# Epoch 00085: val_loss did not improve from 776.03021
# Epoch 86/500
# 84/84 [==============================] - 0s 119us/step - loss: 2031.5759 - mean_absolute_error: 2031.5759 - val_loss: 2014.1694 - val_mean_absolute_error: 2014.1694
#
# Epoch 00086: val_loss did not improve from 776.03021
# Epoch 87/500
# 84/84 [==============================] - 0s 119us/step - loss: 1953.4909 - mean_absolute_error: 1953.4909 - val_loss: 1562.1011 - val_mean_absolute_error: 1562.1011
#
# Epoch 00087: val_loss did not improve from 776.03021
# Epoch 88/500
# 84/84 [==============================] - 0s 131us/step - loss: 2048.2020 - mean_absolute_error: 2048.2020 - val_loss: 1784.8356 - val_mean_absolute_error: 1784.8356
#
# Epoch 00088: val_loss did not improve from 776.03021
# Epoch 89/500
# 84/84 [==============================] - 0s 166us/step - loss: 1945.1148 - mean_absolute_error: 1945.1148 - val_loss: 2305.3521 - val_mean_absolute_error: 2305.3521
#
# Epoch 00089: val_loss did not improve from 776.03021
# Epoch 90/500
# 84/84 [==============================] - 0s 119us/step - loss: 1985.3819 - mean_absolute_error: 1985.3819 - val_loss: 2166.0505 - val_mean_absolute_error: 2166.0505
#
# Epoch 00090: val_loss did not improve from 776.03021
# Epoch 91/500
# 84/84 [==============================] - 0s 119us/step - loss: 1942.2849 - mean_absolute_error: 1942.2849 - val_loss: 1956.2933 - val_mean_absolute_error: 1956.2933
#
# Epoch 00091: val_loss did not improve from 776.03021
# Epoch 92/500
# 84/84 [==============================] - 0s 107us/step - loss: 1920.3275 - mean_absolute_error: 1920.3275 - val_loss: 2005.1421 - val_mean_absolute_error: 2005.1421
#
# Epoch 00092: val_loss did not improve from 776.03021
# Epoch 93/500
# 84/84 [==============================] - 0s 166us/step - loss: 1925.3324 - mean_absolute_error: 1925.3324 - val_loss: 2103.8811 - val_mean_absolute_error: 2103.8811
#
# Epoch 00093: val_loss did not improve from 776.03021
# Epoch 94/500
# 84/84 [==============================] - 0s 131us/step - loss: 1919.3715 - mean_absolute_error: 1919.3715 - val_loss: 1886.0552 - val_mean_absolute_error: 1886.0552
#
# Epoch 00094: val_loss did not improve from 776.03021
# Epoch 95/500
# 84/84 [==============================] - 0s 178us/step - loss: 1922.2849 - mean_absolute_error: 1922.2849 - val_loss: 1889.1992 - val_mean_absolute_error: 1889.1992
#
# Epoch 00095: val_loss did not improve from 776.03021
# Epoch 96/500
# 84/84 [==============================] - 0s 154us/step - loss: 1896.4379 - mean_absolute_error: 1896.4379 - val_loss: 2028.8124 - val_mean_absolute_error: 2028.8124
#
# Epoch 00096: val_loss did not improve from 776.03021
# Epoch 97/500
# 84/84 [==============================] - 0s 107us/step - loss: 1899.2562 - mean_absolute_error: 1899.2562 - val_loss: 2113.5500 - val_mean_absolute_error: 2113.5500
#
# Epoch 00097: val_loss did not improve from 776.03021
# Epoch 98/500
# 84/84 [==============================] - 0s 119us/step - loss: 1905.6405 - mean_absolute_error: 1905.6405 - val_loss: 1743.5854 - val_mean_absolute_error: 1743.5854
#
# Epoch 00098: val_loss did not improve from 776.03021
# Epoch 99/500
# 84/84 [==============================] - 0s 154us/step - loss: 1902.2252 - mean_absolute_error: 1902.2252 - val_loss: 1883.7632 - val_mean_absolute_error: 1883.7632
#
# Epoch 00099: val_loss did not improve from 776.03021
# Epoch 100/500
# 84/84 [==============================] - 0s 166us/step - loss: 1868.0050 - mean_absolute_error: 1868.0050 - val_loss: 2044.8732 - val_mean_absolute_error: 2044.8732
#
# Epoch 00100: val_loss did not improve from 776.03021
# Epoch 101/500
# 84/84 [==============================] - 0s 119us/step - loss: 1865.7740 - mean_absolute_error: 1865.7740 - val_loss: 2132.1826 - val_mean_absolute_error: 2132.1826
#
# Epoch 00101: val_loss did not improve from 776.03021
# Epoch 102/500
# 84/84 [==============================] - 0s 154us/step - loss: 1872.2034 - mean_absolute_error: 1872.2034 - val_loss: 1942.8651 - val_mean_absolute_error: 1942.8651
#
# Epoch 00102: val_loss did not improve from 776.03021
# Epoch 103/500
# 84/84 [==============================] - 0s 131us/step - loss: 1852.9871 - mean_absolute_error: 1852.9871 - val_loss: 1628.7301 - val_mean_absolute_error: 1628.7301
#
# Epoch 00103: val_loss did not improve from 776.03021
# Epoch 104/500
# 84/84 [==============================] - 0s 131us/step - loss: 1876.0831 - mean_absolute_error: 1876.0831 - val_loss: 1815.1978 - val_mean_absolute_error: 1815.1978
#
# Epoch 00104: val_loss did not improve from 776.03021
# Epoch 105/500
# 84/84 [==============================] - 0s 119us/step - loss: 1849.6634 - mean_absolute_error: 1849.6634 - val_loss: 2203.1714 - val_mean_absolute_error: 2203.1714
#
# Epoch 00105: val_loss did not improve from 776.03021
# Epoch 106/500
# 84/84 [==============================] - 0s 119us/step - loss: 1855.5801 - mean_absolute_error: 1855.5801 - val_loss: 1912.6312 - val_mean_absolute_error: 1912.6312
#
# Epoch 00106: val_loss did not improve from 776.03021
# Epoch 107/500
# 84/84 [==============================] - 0s 119us/step - loss: 1807.8876 - mean_absolute_error: 1807.8876 - val_loss: 1852.9155 - val_mean_absolute_error: 1852.9155
#
# Epoch 00107: val_loss did not improve from 776.03021
# Epoch 108/500
# 84/84 [==============================] - 0s 154us/step - loss: 1809.1010 - mean_absolute_error: 1809.1010 - val_loss: 1921.1167 - val_mean_absolute_error: 1921.1167
#
# Epoch 00108: val_loss did not improve from 776.03021
# Epoch 109/500
# 84/84 [==============================] - 0s 142us/step - loss: 1801.2590 - mean_absolute_error: 1801.2590 - val_loss: 1857.0118 - val_mean_absolute_error: 1857.0118
#
# Epoch 00109: val_loss did not improve from 776.03021
# Epoch 110/500
# 84/84 [==============================] - 0s 154us/step - loss: 1812.4838 - mean_absolute_error: 1812.4838 - val_loss: 1766.5000 - val_mean_absolute_error: 1766.5000
#
# Epoch 00110: val_loss did not improve from 776.03021
# Epoch 111/500
# 84/84 [==============================] - 0s 202us/step - loss: 1804.3933 - mean_absolute_error: 1804.3933 - val_loss: 1958.1573 - val_mean_absolute_error: 1958.1573
#
# Epoch 00111: val_loss did not improve from 776.03021
# Epoch 112/500
# 84/84 [==============================] - 0s 154us/step - loss: 1789.9713 - mean_absolute_error: 1789.9713 - val_loss: 1960.9781 - val_mean_absolute_error: 1960.9781
#
# Epoch 00112: val_loss did not improve from 776.03021
# Epoch 113/500
# 84/84 [==============================] - 0s 190us/step - loss: 1819.0461 - mean_absolute_error: 1819.0461 - val_loss: 1630.5101 - val_mean_absolute_error: 1630.5101
#
# Epoch 00113: val_loss did not improve from 776.03021
# Epoch 114/500
# 84/84 [==============================] - 0s 190us/step - loss: 1770.2666 - mean_absolute_error: 1770.2666 - val_loss: 1963.7030 - val_mean_absolute_error: 1963.7030
#
# Epoch 00114: val_loss did not improve from 776.03021
# Epoch 115/500
# 84/84 [==============================] - 0s 119us/step - loss: 1763.7456 - mean_absolute_error: 1763.7456 - val_loss: 2064.3591 - val_mean_absolute_error: 2064.3591
#
# Epoch 00115: val_loss did not improve from 776.03021
# Epoch 116/500
# 84/84 [==============================] - 0s 107us/step - loss: 1860.9308 - mean_absolute_error: 1860.9308 - val_loss: 1939.8618 - val_mean_absolute_error: 1939.8618
#
# Epoch 00116: val_loss did not improve from 776.03021
# Epoch 117/500
# 84/84 [==============================] - 0s 154us/step - loss: 1760.0993 - mean_absolute_error: 1760.0993 - val_loss: 1374.5580 - val_mean_absolute_error: 1374.5580
#
# Epoch 00117: val_loss did not improve from 776.03021
# Epoch 118/500
# 84/84 [==============================] - 0s 131us/step - loss: 1830.6309 - mean_absolute_error: 1830.6309 - val_loss: 1783.7050 - val_mean_absolute_error: 1783.7050
#
# Epoch 00118: val_loss did not improve from 776.03021
# Epoch 119/500
# 84/84 [==============================] - 0s 166us/step - loss: 1810.5287 - mean_absolute_error: 1810.5287 - val_loss: 2161.0891 - val_mean_absolute_error: 2161.0891
#
# Epoch 00119: val_loss did not improve from 776.03021
# Epoch 120/500
# 84/84 [==============================] - 0s 142us/step - loss: 1742.5668 - mean_absolute_error: 1742.5668 - val_loss: 1487.8116 - val_mean_absolute_error: 1487.8116
#
# Epoch 00120: val_loss did not improve from 776.03021
# Epoch 121/500
# 84/84 [==============================] - 0s 142us/step - loss: 1880.3097 - mean_absolute_error: 1880.3097 - val_loss: 1335.4846 - val_mean_absolute_error: 1335.4846
#
# Epoch 00121: val_loss did not improve from 776.03021
# Epoch 122/500
# 84/84 [==============================] - 0s 154us/step - loss: 1782.6229 - mean_absolute_error: 1782.6229 - val_loss: 2258.8977 - val_mean_absolute_error: 2258.8977
#
# Epoch 00122: val_loss did not improve from 776.03021
# Epoch 123/500
# 84/84 [==============================] - 0s 154us/step - loss: 1829.9937 - mean_absolute_error: 1829.9937 - val_loss: 1994.5540 - val_mean_absolute_error: 1994.5540
#
# Epoch 00123: val_loss did not improve from 776.03021
# Epoch 124/500
# 84/84 [==============================] - 0s 142us/step - loss: 1727.0941 - mean_absolute_error: 1727.0941 - val_loss: 1581.0909 - val_mean_absolute_error: 1581.0909
#
# Epoch 00124: val_loss did not improve from 776.03021
# Epoch 125/500
# 84/84 [==============================] - 0s 119us/step - loss: 1735.5884 - mean_absolute_error: 1735.5884 - val_loss: 1614.2443 - val_mean_absolute_error: 1614.2443
#
# Epoch 00125: val_loss did not improve from 776.03021
# Epoch 126/500
# 84/84 [==============================] - 0s 119us/step - loss: 1725.6702 - mean_absolute_error: 1725.6702 - val_loss: 1996.4148 - val_mean_absolute_error: 1996.4148
#
# Epoch 00126: val_loss did not improve from 776.03021
# Epoch 127/500
# 84/84 [==============================] - 0s 131us/step - loss: 1722.7550 - mean_absolute_error: 1722.7550 - val_loss: 1605.2980 - val_mean_absolute_error: 1605.2980
#
# Epoch 00127: val_loss did not improve from 776.03021
# Epoch 128/500
# 84/84 [==============================] - 0s 154us/step - loss: 1701.7380 - mean_absolute_error: 1701.7380 - val_loss: 1607.8535 - val_mean_absolute_error: 1607.8535
#
# Epoch 00128: val_loss did not improve from 776.03021
# Epoch 129/500
# 84/84 [==============================] - 0s 119us/step - loss: 1703.7732 - mean_absolute_error: 1703.7732 - val_loss: 1848.3938 - val_mean_absolute_error: 1848.3938
#
# Epoch 00129: val_loss did not improve from 776.03021
# Epoch 130/500
# 84/84 [==============================] - 0s 119us/step - loss: 1694.9059 - mean_absolute_error: 1694.9059 - val_loss: 1597.3345 - val_mean_absolute_error: 1597.3345
#
# Epoch 00130: val_loss did not improve from 776.03021
# Epoch 131/500
# 84/84 [==============================] - 0s 166us/step - loss: 1684.2251 - mean_absolute_error: 1684.2251 - val_loss: 1564.4910 - val_mean_absolute_error: 1564.4910
#
# Epoch 00131: val_loss did not improve from 776.03021
# Epoch 132/500
# 84/84 [==============================] - 0s 131us/step - loss: 1685.2085 - mean_absolute_error: 1685.2085 - val_loss: 1734.3300 - val_mean_absolute_error: 1734.3300
#
# Epoch 00132: val_loss did not improve from 776.03021
# Epoch 133/500
# 84/84 [==============================] - 0s 166us/step - loss: 1658.8215 - mean_absolute_error: 1658.8215 - val_loss: 1605.7122 - val_mean_absolute_error: 1605.7122
#
# Epoch 00133: val_loss did not improve from 776.03021
# Epoch 134/500
# 84/84 [==============================] - 0s 178us/step - loss: 1661.7426 - mean_absolute_error: 1661.7426 - val_loss: 1572.4083 - val_mean_absolute_error: 1572.4083
#
# Epoch 00134: val_loss did not improve from 776.03021
# Epoch 135/500
# 84/84 [==============================] - 0s 131us/step - loss: 1684.0461 - mean_absolute_error: 1684.0461 - val_loss: 1854.3781 - val_mean_absolute_error: 1854.3781
#
# Epoch 00135: val_loss did not improve from 776.03021
# Epoch 136/500
# 84/84 [==============================] - 0s 119us/step - loss: 1679.3699 - mean_absolute_error: 1679.3699 - val_loss: 1387.0167 - val_mean_absolute_error: 1387.0167
#
# Epoch 00136: val_loss did not improve from 776.03021
# Epoch 137/500
# 84/84 [==============================] - 0s 119us/step - loss: 1668.9893 - mean_absolute_error: 1668.9893 - val_loss: 1697.7574 - val_mean_absolute_error: 1697.7574
#
# Epoch 00137: val_loss did not improve from 776.03021
# Epoch 138/500
# 84/84 [==============================] - 0s 166us/step - loss: 1628.1449 - mean_absolute_error: 1628.1449 - val_loss: 1840.5883 - val_mean_absolute_error: 1840.5883
#
# Epoch 00138: val_loss did not improve from 776.03021
# Epoch 139/500
# 84/84 [==============================] - 0s 142us/step - loss: 1638.0629 - mean_absolute_error: 1638.0629 - val_loss: 1514.1606 - val_mean_absolute_error: 1514.1606
#
# Epoch 00139: val_loss did not improve from 776.03021
# Epoch 140/500
# 84/84 [==============================] - 0s 107us/step - loss: 1643.9451 - mean_absolute_error: 1643.9451 - val_loss: 1396.3583 - val_mean_absolute_error: 1396.3583
#
# Epoch 00140: val_loss did not improve from 776.03021
# Epoch 141/500
# 84/84 [==============================] - 0s 119us/step - loss: 1639.1744 - mean_absolute_error: 1639.1744 - val_loss: 1666.7781 - val_mean_absolute_error: 1666.7781
#
# Epoch 00141: val_loss did not improve from 776.03021
# Epoch 142/500
# 84/84 [==============================] - 0s 142us/step - loss: 1614.3782 - mean_absolute_error: 1614.3782 - val_loss: 1605.9005 - val_mean_absolute_error: 1605.9005
#
# Epoch 00142: val_loss did not improve from 776.03021
# Epoch 143/500
# 84/84 [==============================] - 0s 154us/step - loss: 1637.5925 - mean_absolute_error: 1637.5925 - val_loss: 1508.2844 - val_mean_absolute_error: 1508.2844
#
# Epoch 00143: val_loss did not improve from 776.03021
# Epoch 144/500
# 84/84 [==============================] - 0s 107us/step - loss: 1611.3009 - mean_absolute_error: 1611.3009 - val_loss: 1766.7297 - val_mean_absolute_error: 1766.7297
#
# Epoch 00144: val_loss did not improve from 776.03021
# Epoch 145/500
# 84/84 [==============================] - 0s 131us/step - loss: 1669.1961 - mean_absolute_error: 1669.1961 - val_loss: 1580.0598 - val_mean_absolute_error: 1580.0598
#
# Epoch 00145: val_loss did not improve from 776.03021
# Epoch 146/500
# 84/84 [==============================] - 0s 119us/step - loss: 1604.6769 - mean_absolute_error: 1604.6769 - val_loss: 1229.1028 - val_mean_absolute_error: 1229.1028
#
# Epoch 00146: val_loss did not improve from 776.03021
# Epoch 147/500
# 84/84 [==============================] - 0s 119us/step - loss: 1610.1335 - mean_absolute_error: 1610.1335 - val_loss: 1621.9344 - val_mean_absolute_error: 1621.9344
#
# Epoch 00147: val_loss did not improve from 776.03021
# Epoch 148/500
# 84/84 [==============================] - 0s 119us/step - loss: 1598.9539 - mean_absolute_error: 1598.9539 - val_loss: 1711.4785 - val_mean_absolute_error: 1711.4785
#
# Epoch 00148: val_loss did not improve from 776.03021
# Epoch 149/500
# 84/84 [==============================] - 0s 154us/step - loss: 1590.8824 - mean_absolute_error: 1590.8824 - val_loss: 1312.0604 - val_mean_absolute_error: 1312.0604
#
# Epoch 00149: val_loss did not improve from 776.03021
# Epoch 150/500
# 84/84 [==============================] - 0s 166us/step - loss: 1578.4274 - mean_absolute_error: 1578.4274 - val_loss: 1318.0552 - val_mean_absolute_error: 1318.0552
#
# Epoch 00150: val_loss did not improve from 776.03021
# Epoch 151/500
# 84/84 [==============================] - 0s 202us/step - loss: 1591.0003 - mean_absolute_error: 1591.0003 - val_loss: 1525.1770 - val_mean_absolute_error: 1525.1770
#
# Epoch 00151: val_loss did not improve from 776.03021
# Epoch 152/500
# 84/84 [==============================] - 0s 119us/step - loss: 1576.1933 - mean_absolute_error: 1576.1933 - val_loss: 1647.0254 - val_mean_absolute_error: 1647.0254
#
# Epoch 00152: val_loss did not improve from 776.03021
# Epoch 153/500
# 84/84 [==============================] - 0s 226us/step - loss: 1580.4216 - mean_absolute_error: 1580.4216 - val_loss: 1177.0851 - val_mean_absolute_error: 1177.0851
#
# Epoch 00153: val_loss did not improve from 776.03021
# Epoch 154/500
# 84/84 [==============================] - 0s 154us/step - loss: 1568.9357 - mean_absolute_error: 1568.9357 - val_loss: 1688.7770 - val_mean_absolute_error: 1688.7770
#
# Epoch 00154: val_loss did not improve from 776.03021
# Epoch 155/500
# 84/84 [==============================] - 0s 131us/step - loss: 1581.3574 - mean_absolute_error: 1581.3574 - val_loss: 1344.3855 - val_mean_absolute_error: 1344.3855
#
# Epoch 00155: val_loss did not improve from 776.03021
# Epoch 156/500
# 84/84 [==============================] - 0s 142us/step - loss: 1570.8118 - mean_absolute_error: 1570.8118 - val_loss: 1134.3149 - val_mean_absolute_error: 1134.3149
#
# Epoch 00156: val_loss did not improve from 776.03021
# Epoch 157/500
# 84/84 [==============================] - 0s 178us/step - loss: 1580.7485 - mean_absolute_error: 1580.7485 - val_loss: 1751.6320 - val_mean_absolute_error: 1751.6320
#
# Epoch 00157: val_loss did not improve from 776.03021
# Epoch 158/500
# 84/84 [==============================] - 0s 142us/step - loss: 1555.1406 - mean_absolute_error: 1555.1406 - val_loss: 1196.5157 - val_mean_absolute_error: 1196.5157
#
# Epoch 00158: val_loss did not improve from 776.03021
# Epoch 159/500
# 84/84 [==============================] - 0s 226us/step - loss: 1637.0580 - mean_absolute_error: 1637.0580 - val_loss: 1301.8243 - val_mean_absolute_error: 1301.8243
#
# Epoch 00159: val_loss did not improve from 776.03021
# Epoch 160/500
# 84/84 [==============================] - 0s 166us/step - loss: 1582.7966 - mean_absolute_error: 1582.7966 - val_loss: 1765.4406 - val_mean_absolute_error: 1765.4406
#
# Epoch 00160: val_loss did not improve from 776.03021
# Epoch 161/500
# 84/84 [==============================] - ETA: 0s - loss: 2125.9458 - mean_absolute_error: 2125.945 - 0s 131us/step - loss: 1544.0761 - mean_absolute_error: 1544.0761 - val_loss: 1010.5891 - val_mean_absolute_error: 1010.5891
#
# Epoch 00161: val_loss did not improve from 776.03021
# Epoch 162/500
# 84/84 [==============================] - 0s 131us/step - loss: 1602.9840 - mean_absolute_error: 1602.9840 - val_loss: 1328.8073 - val_mean_absolute_error: 1328.8073
#
# Epoch 00162: val_loss did not improve from 776.03021
# Epoch 163/500
# 84/84 [==============================] - 0s 166us/step - loss: 1508.6483 - mean_absolute_error: 1508.6483 - val_loss: 1289.2609 - val_mean_absolute_error: 1289.2609
#
# Epoch 00163: val_loss did not improve from 776.03021
# Epoch 164/500
# 84/84 [==============================] - 0s 119us/step - loss: 1517.7879 - mean_absolute_error: 1517.7879 - val_loss: 1306.1974 - val_mean_absolute_error: 1306.1974
#
# Epoch 00164: val_loss did not improve from 776.03021
# Epoch 165/500
# 84/84 [==============================] - 0s 142us/step - loss: 1512.9503 - mean_absolute_error: 1512.9503 - val_loss: 1161.5137 - val_mean_absolute_error: 1161.5137
#
# Epoch 00165: val_loss did not improve from 776.03021
# Epoch 166/500
# 84/84 [==============================] - 0s 154us/step - loss: 1486.4548 - mean_absolute_error: 1486.4548 - val_loss: 1388.3871 - val_mean_absolute_error: 1388.3871
#
# Epoch 00166: val_loss did not improve from 776.03021
# Epoch 167/500
# 84/84 [==============================] - 0s 154us/step - loss: 1517.4094 - mean_absolute_error: 1517.4094 - val_loss: 1268.0714 - val_mean_absolute_error: 1268.0714
#
# Epoch 00167: val_loss did not improve from 776.03021
# Epoch 168/500
# 84/84 [==============================] - 0s 166us/step - loss: 1484.1333 - mean_absolute_error: 1484.1333 - val_loss: 1185.5815 - val_mean_absolute_error: 1185.5815
#
# Epoch 00168: val_loss did not improve from 776.03021
# Epoch 169/500
# 84/84 [==============================] - 0s 166us/step - loss: 1488.3889 - mean_absolute_error: 1488.3889 - val_loss: 1274.0676 - val_mean_absolute_error: 1274.0676
#
# Epoch 00169: val_loss did not improve from 776.03021
# Epoch 170/500
# 84/84 [==============================] - 0s 119us/step - loss: 1471.9881 - mean_absolute_error: 1471.9881 - val_loss: 1101.1245 - val_mean_absolute_error: 1101.1245
#
# Epoch 00170: val_loss did not improve from 776.03021
# Epoch 171/500
# 84/84 [==============================] - 0s 202us/step - loss: 1476.7026 - mean_absolute_error: 1476.7026 - val_loss: 1393.7394 - val_mean_absolute_error: 1393.7394
#
# Epoch 00171: val_loss did not improve from 776.03021
# Epoch 172/500
# 84/84 [==============================] - 0s 178us/step - loss: 1502.4112 - mean_absolute_error: 1502.4112 - val_loss: 1073.4458 - val_mean_absolute_error: 1073.4458
#
# Epoch 00172: val_loss did not improve from 776.03021
# Epoch 173/500
# 84/84 [==============================] - 0s 131us/step - loss: 1490.6041 - mean_absolute_error: 1490.6041 - val_loss: 1322.3359 - val_mean_absolute_error: 1322.3359
#
# Epoch 00173: val_loss did not improve from 776.03021
# Epoch 174/500
# 84/84 [==============================] - 0s 178us/step - loss: 1647.6309 - mean_absolute_error: 1647.6309 - val_loss: 1259.1844 - val_mean_absolute_error: 1259.1844
#
# Epoch 00174: val_loss did not improve from 776.03021
# Epoch 175/500
# 84/84 [==============================] - 0s 166us/step - loss: 1550.4703 - mean_absolute_error: 1550.4703 - val_loss: 928.9305 - val_mean_absolute_error: 928.9305
#
# Epoch 00175: val_loss did not improve from 776.03021
# Epoch 176/500
# 84/84 [==============================] - 0s 119us/step - loss: 1532.5808 - mean_absolute_error: 1532.5808 - val_loss: 1645.8456 - val_mean_absolute_error: 1645.8456
#
# Epoch 00176: val_loss did not improve from 776.03021
# Epoch 177/500
# 84/84 [==============================] - 0s 166us/step - loss: 1543.5833 - mean_absolute_error: 1543.5833 - val_loss: 907.3931 - val_mean_absolute_error: 907.3931
#
# Epoch 00177: val_loss did not improve from 776.03021
# Epoch 178/500
# 84/84 [==============================] - 0s 166us/step - loss: 1519.5843 - mean_absolute_error: 1519.5843 - val_loss: 1505.0099 - val_mean_absolute_error: 1505.0099
#
# Epoch 00178: val_loss did not improve from 776.03021
# Epoch 179/500
# 84/84 [==============================] - 0s 131us/step - loss: 1609.1444 - mean_absolute_error: 1609.1444 - val_loss: 1475.4609 - val_mean_absolute_error: 1475.4609
#
# Epoch 00179: val_loss did not improve from 776.03021
# Epoch 180/500
# 84/84 [==============================] - 0s 131us/step - loss: 1671.2759 - mean_absolute_error: 1671.2759 - val_loss: 817.5807 - val_mean_absolute_error: 817.5807
#
# Epoch 00180: val_loss did not improve from 776.03021
# Epoch 181/500
# 84/84 [==============================] - 0s 119us/step - loss: 1574.8050 - mean_absolute_error: 1574.8050 - val_loss: 1645.6348 - val_mean_absolute_error: 1645.6348
#
# Epoch 00181: val_loss did not improve from 776.03021
# Epoch 182/500
# 84/84 [==============================] - 0s 166us/step - loss: 1623.9958 - mean_absolute_error: 1623.9958 - val_loss: 1329.3521 - val_mean_absolute_error: 1329.3521
#
# Epoch 00182: val_loss did not improve from 776.03021
# Epoch 183/500
# 84/84 [==============================] - 0s 166us/step - loss: 1512.3547 - mean_absolute_error: 1512.3547 - val_loss: 883.0139 - val_mean_absolute_error: 883.0139
#
# Epoch 00183: val_loss did not improve from 776.03021
# Epoch 184/500
# 84/84 [==============================] - 0s 166us/step - loss: 1502.4526 - mean_absolute_error: 1502.4526 - val_loss: 1497.8091 - val_mean_absolute_error: 1497.8091
#
# Epoch 00184: val_loss did not improve from 776.03021
# Epoch 185/500
# 84/84 [==============================] - 0s 178us/step - loss: 1549.1837 - mean_absolute_error: 1549.1837 - val_loss: 1215.2535 - val_mean_absolute_error: 1215.2535
#
# Epoch 00185: val_loss did not improve from 776.03021
# Epoch 186/500
# 84/84 [==============================] - 0s 226us/step - loss: 1430.7591 - mean_absolute_error: 1430.7591 - val_loss: 1036.2247 - val_mean_absolute_error: 1036.2247
#
# Epoch 00186: val_loss did not improve from 776.03021
# Epoch 187/500
# 84/84 [==============================] - 0s 261us/step - loss: 1457.2878 - mean_absolute_error: 1457.2878 - val_loss: 1147.5482 - val_mean_absolute_error: 1147.5482
#
# Epoch 00187: val_loss did not improve from 776.03021
# Epoch 188/500
# 84/84 [==============================] - 0s 214us/step - loss: 1430.5203 - mean_absolute_error: 1430.5203 - val_loss: 1177.9797 - val_mean_absolute_error: 1177.9797
#
# Epoch 00188: val_loss did not improve from 776.03021
# Epoch 189/500
# 84/84 [==============================] - 0s 154us/step - loss: 1422.2823 - mean_absolute_error: 1422.2823 - val_loss: 1181.3354 - val_mean_absolute_error: 1181.3354
#
# Epoch 00189: val_loss did not improve from 776.03021
# Epoch 190/500
# 84/84 [==============================] - 0s 131us/step - loss: 1416.8467 - mean_absolute_error: 1416.8467 - val_loss: 1231.4028 - val_mean_absolute_error: 1231.4028
#
# Epoch 00190: val_loss did not improve from 776.03021
# Epoch 191/500
# 84/84 [==============================] - 0s 142us/step - loss: 1426.9197 - mean_absolute_error: 1426.9197 - val_loss: 1154.3208 - val_mean_absolute_error: 1154.3208
#
# Epoch 00191: val_loss did not improve from 776.03021
# Epoch 192/500
# 84/84 [==============================] - 0s 190us/step - loss: 1421.7504 - mean_absolute_error: 1421.7504 - val_loss: 1108.7437 - val_mean_absolute_error: 1108.7437
#
# Epoch 00192: val_loss did not improve from 776.03021
# Epoch 193/500
# 84/84 [==============================] - 0s 131us/step - loss: 1478.9552 - mean_absolute_error: 1478.9552 - val_loss: 1091.5389 - val_mean_absolute_error: 1091.5389
#
# Epoch 00193: val_loss did not improve from 776.03021
# Epoch 194/500
# 84/84 [==============================] - 0s 166us/step - loss: 1498.8502 - mean_absolute_error: 1498.8502 - val_loss: 1345.3469 - val_mean_absolute_error: 1345.3469
#
# Epoch 00194: val_loss did not improve from 776.03021
# Epoch 195/500
# 84/84 [==============================] - 0s 184us/step - loss: 1404.5524 - mean_absolute_error: 1404.5524 - val_loss: 820.2012 - val_mean_absolute_error: 820.2012
#
# Epoch 00195: val_loss did not improve from 776.03021
# Epoch 196/500
# 84/84 [==============================] - 0s 131us/step - loss: 1529.2109 - mean_absolute_error: 1529.2109 - val_loss: 1373.2860 - val_mean_absolute_error: 1373.2860
#
# Epoch 00196: val_loss did not improve from 776.03021
# Epoch 197/500
# 84/84 [==============================] - 0s 131us/step - loss: 1554.9323 - mean_absolute_error: 1554.9323 - val_loss: 1371.1749 - val_mean_absolute_error: 1371.1749
#
# Epoch 00197: val_loss did not improve from 776.03021
# Epoch 198/500
# 84/84 [==============================] - 0s 166us/step - loss: 1397.4528 - mean_absolute_error: 1397.4528 - val_loss: 885.0926 - val_mean_absolute_error: 885.0926
#
# Epoch 00198: val_loss did not improve from 776.03021
# Epoch 199/500
# 84/84 [==============================] - 0s 190us/step - loss: 1479.2592 - mean_absolute_error: 1479.2592 - val_loss: 1348.9579 - val_mean_absolute_error: 1348.9579
#
# Epoch 00199: val_loss did not improve from 776.03021
# Epoch 200/500
# 84/84 [==============================] - 0s 142us/step - loss: 1477.8841 - mean_absolute_error: 1477.8841 - val_loss: 1300.9364 - val_mean_absolute_error: 1300.9364
#
# Epoch 00200: val_loss did not improve from 776.03021
# Epoch 201/500
# 84/84 [==============================] - 0s 142us/step - loss: 1394.6092 - mean_absolute_error: 1394.6092 - val_loss: 945.9717 - val_mean_absolute_error: 945.9717
#
# Epoch 00201: val_loss did not improve from 776.03021
# Epoch 202/500
# 84/84 [==============================] - 0s 166us/step - loss: 1438.9932 - mean_absolute_error: 1438.9932 - val_loss: 1188.8934 - val_mean_absolute_error: 1188.8934
#
# Epoch 00202: val_loss did not improve from 776.03021
# Epoch 203/500
# ...
#
# Epoch 00432: val_loss did not improve from 677.49457
# Epoch 433/500
# 84/84 [==============================] - 0s 237us/step - loss: 1248.3651 - mean_absolute_error: 1248.3651 - val_loss: 944.7410 - val_mean_absolute_error: 944.7410
#
# Epoch 00433: val_loss did not improve from 677.49457
# Epoch 434/500
# 84/84 [==============================] - 0s 154us/step - loss: 1214.0487 - mean_absolute_error: 1214.0487 - val_loss: 1107.7133 - val_mean_absolute_error: 1107.7133
#
# Epoch 00434: val_loss did not improve from 677.49457
# Epoch 435/500
# 84/84 [==============================] - 0s 214us/step - loss: 1214.1651 - mean_absolute_error: 1214.1651 - val_loss: 914.4254 - val_mean_absolute_error: 914.4254
#
# Epoch 00435: val_loss did not improve from 677.49457
# Epoch 436/500
# 84/84 [==============================] - 0s 214us/step - loss: 1228.5850 - mean_absolute_error: 1228.5850 - val_loss: 1036.7902 - val_mean_absolute_error: 1036.7902
#
# Epoch 00436: val_loss did not improve from 677.49457
# Epoch 437/500
# 84/84 [==============================] - 0s 237us/step - loss: 1211.1704 - mean_absolute_error: 1211.1704 - val_loss: 1006.5408 - val_mean_absolute_error: 1006.5408
#
# Epoch 00437: val_loss did not improve from 677.49457
# Epoch 438/500
# 84/84 [==============================] - 0s 202us/step - loss: 1224.5939 - mean_absolute_error: 1224.5939 - val_loss: 898.5023 - val_mean_absolute_error: 898.5023
#
# Epoch 00438: val_loss did not improve from 677.49457
# Epoch 439/500
# 84/84 [==============================] - 0s 166us/step - loss: 1230.1366 - mean_absolute_error: 1230.1366 - val_loss: 1000.5283 - val_mean_absolute_error: 1000.5283
#
# Epoch 00439: val_loss did not improve from 677.49457
# Epoch 440/500
# 84/84 [==============================] - 0s 178us/step - loss: 1207.1960 - mean_absolute_error: 1207.1960 - val_loss: 1015.5059 - val_mean_absolute_error: 1015.5059
#
# Epoch 00440: val_loss did not improve from 677.49457
# Epoch 441/500
# 84/84 [==============================] - 0s 249us/step - loss: 1205.9830 - mean_absolute_error: 1205.9830 - val_loss: 995.2719 - val_mean_absolute_error: 995.2719
#
# Epoch 00441: val_loss did not improve from 677.49457
# Epoch 442/500
# 84/84 [==============================] - 0s 166us/step - loss: 1217.1893 - mean_absolute_error: 1217.1893 - val_loss: 970.0852 - val_mean_absolute_error: 970.0852
#
# Epoch 00442: val_loss did not improve from 677.49457
# Epoch 443/500
# 84/84 [==============================] - 0s 154us/step - loss: 1214.7654 - mean_absolute_error: 1214.7654 - val_loss: 1054.2703 - val_mean_absolute_error: 1054.2703
#
# Epoch 00443: val_loss did not improve from 677.49457
# Epoch 444/500
# 84/84 [==============================] - 0s 154us/step - loss: 1188.6021 - mean_absolute_error: 1188.6021 - val_loss: 792.5289 - val_mean_absolute_error: 792.5289
#
# Epoch 00444: val_loss did not improve from 677.49457
# Epoch 445/500
# 84/84 [==============================] - 0s 178us/step - loss: 1295.7507 - mean_absolute_error: 1295.7507 - val_loss: 1047.0725 - val_mean_absolute_error: 1047.0725
#
# Epoch 00445: val_loss did not improve from 677.49457
# Epoch 446/500
# 84/84 [==============================] - 0s 261us/step - loss: 1279.9397 - mean_absolute_error: 1279.9397 - val_loss: 1090.9022 - val_mean_absolute_error: 1090.9022
#
# Epoch 00446: val_loss did not improve from 677.49457
# Epoch 447/500
# 84/84 [==============================] - 0s 202us/step - loss: 1331.7018 - mean_absolute_error: 1331.7018 - val_loss: 692.3127 - val_mean_absolute_error: 692.3127
#
# Epoch 00447: val_loss did not improve from 677.49457
# Epoch 448/500
# 84/84 [==============================] - 0s 154us/step - loss: 1299.1681 - mean_absolute_error: 1299.1681 - val_loss: 1355.2222 - val_mean_absolute_error: 1355.2222
#
# Epoch 00448: val_loss did not improve from 677.49457
# Epoch 449/500
# 84/84 [==============================] - 0s 226us/step - loss: 1363.6490 - mean_absolute_error: 1363.6490 - val_loss: 906.6924 - val_mean_absolute_error: 906.6924
#
# Epoch 00449: val_loss did not improve from 677.49457
# Epoch 450/500
# 84/84 [==============================] - 0s 190us/step - loss: 1234.1961 - mean_absolute_error: 1234.1961 - val_loss: 773.9094 - val_mean_absolute_error: 773.9094
#
# Epoch 00450: val_loss did not improve from 677.49457
# Epoch 451/500
# 84/84 [==============================] - 0s 166us/step - loss: 1273.6341 - mean_absolute_error: 1273.6341 - val_loss: 1065.8729 - val_mean_absolute_error: 1065.8729
#
# Epoch 00451: val_loss did not improve from 677.49457
# Epoch 452/500
# 84/84 [==============================] - 0s 190us/step - loss: 1215.4822 - mean_absolute_error: 1215.4822 - val_loss: 941.9250 - val_mean_absolute_error: 941.9250
#
# Epoch 00452: val_loss did not improve from 677.49457
# Epoch 453/500
# 84/84 [==============================] - 0s 226us/step - loss: 1201.4875 - mean_absolute_error: 1201.4875 - val_loss: 946.1113 - val_mean_absolute_error: 946.1113
#
# Epoch 00453: val_loss did not improve from 677.49457
# Epoch 454/500
# 84/84 [==============================] - 0s 190us/step - loss: 1216.1546 - mean_absolute_error: 1216.1546 - val_loss: 916.1917 - val_mean_absolute_error: 916.1917
#
# Epoch 00454: val_loss did not improve from 677.49457
# Epoch 455/500
# 84/84 [==============================] - 0s 178us/step - loss: 1195.1765 - mean_absolute_error: 1195.1765 - val_loss: 1133.5580 - val_mean_absolute_error: 1133.5580
#
# Epoch 00455: val_loss did not improve from 677.49457
# Epoch 456/500
# 84/84 [==============================] - 0s 178us/step - loss: 1231.8421 - mean_absolute_error: 1231.8421 - val_loss: 853.6806 - val_mean_absolute_error: 853.6806
#
# Epoch 00456: val_loss did not improve from 677.49457
# Epoch 457/500
# 84/84 [==============================] - 0s 154us/step - loss: 1242.6747 - mean_absolute_error: 1242.6747 - val_loss: 838.5426 - val_mean_absolute_error: 838.5426
#
# Epoch 00457: val_loss did not improve from 677.49457
# Epoch 458/500
# 84/84 [==============================] - 0s 178us/step - loss: 1228.3647 - mean_absolute_error: 1228.3647 - val_loss: 1038.3162 - val_mean_absolute_error: 1038.3162
#
# Epoch 00458: val_loss did not improve from 677.49457
# Epoch 459/500
# 84/84 [==============================] - 0s 214us/step - loss: 1205.3856 - mean_absolute_error: 1205.3856 - val_loss: 981.8677 - val_mean_absolute_error: 981.8677
#
# Epoch 00459: val_loss did not improve from 677.49457
# Epoch 460/500
# 84/84 [==============================] - 0s 226us/step - loss: 1236.7789 - mean_absolute_error: 1236.7789 - val_loss: 835.1959 - val_mean_absolute_error: 835.1959
#
# Epoch 00460: val_loss did not improve from 677.49457
# Epoch 461/500
# 84/84 [==============================] - 0s 249us/step - loss: 1220.4465 - mean_absolute_error: 1220.4465 - val_loss: 1025.1156 - val_mean_absolute_error: 1025.1156
#
# Epoch 00461: val_loss did not improve from 677.49457
# Epoch 462/500
# 84/84 [==============================] - 0s 214us/step - loss: 1201.6791 - mean_absolute_error: 1201.6791 - val_loss: 977.7914 - val_mean_absolute_error: 977.7914
#
# Epoch 00462: val_loss did not improve from 677.49457
# Epoch 463/500
# 84/84 [==============================] - 0s 166us/step - loss: 1196.6152 - mean_absolute_error: 1196.6152 - val_loss: 993.5588 - val_mean_absolute_error: 993.5588
#
# Epoch 00463: val_loss did not improve from 677.49457
# Epoch 464/500
# 84/84 [==============================] - 0s 249us/step - loss: 1185.5854 - mean_absolute_error: 1185.5854 - val_loss: 849.7807 - val_mean_absolute_error: 849.7807
#
# Epoch 00464: val_loss did not improve from 677.49457
# Epoch 465/500
# 84/84 [==============================] - 0s 237us/step - loss: 1232.1126 - mean_absolute_error: 1232.1126 - val_loss: 983.1476 - val_mean_absolute_error: 983.1476
#
# Epoch 00465: val_loss did not improve from 677.49457
# Epoch 466/500
# 84/84 [==============================] - 0s 214us/step - loss: 1186.9626 - mean_absolute_error: 1186.9626 - val_loss: 892.9280 - val_mean_absolute_error: 892.9280
#
# Epoch 00466: val_loss did not improve from 677.49457
# Epoch 467/500
# 84/84 [==============================] - 0s 190us/step - loss: 1180.5734 - mean_absolute_error: 1180.5734 - val_loss: 1020.2810 - val_mean_absolute_error: 1020.2810
#
# Epoch 00467: val_loss did not improve from 677.49457
# Epoch 468/500
# 84/84 [==============================] - 0s 226us/step - loss: 1177.7199 - mean_absolute_error: 1177.7199 - val_loss: 741.9722 - val_mean_absolute_error: 741.9722
#
# Epoch 00468: val_loss did not improve from 677.49457
# Epoch 469/500
# 84/84 [==============================] - 0s 332us/step - loss: 1308.8461 - mean_absolute_error: 1308.8461 - val_loss: 943.8279 - val_mean_absolute_error: 943.8279
#
# Epoch 00469: val_loss did not improve from 677.49457
# Epoch 470/500
# 84/84 [==============================] - 0s 439us/step - loss: 1372.7676 - mean_absolute_error: 1372.7676 - val_loss: 1057.6499 - val_mean_absolute_error: 1057.6499
#
# Epoch 00470: val_loss did not improve from 677.49457
# Epoch 471/500
# 84/84 [==============================] - 0s 178us/step - loss: 1192.2164 - mean_absolute_error: 1192.2164 - val_loss: 764.6155 - val_mean_absolute_error: 764.6155
#
# Epoch 00471: val_loss did not improve from 677.49457
# Epoch 472/500
# 84/84 [==============================] - 0s 237us/step - loss: 1270.3031 - mean_absolute_error: 1270.3031 - val_loss: 1068.4673 - val_mean_absolute_error: 1068.4673
#
# Epoch 00472: val_loss did not improve from 677.49457
# Epoch 473/500
# 84/84 [==============================] - 0s 226us/step - loss: 1220.4628 - mean_absolute_error: 1220.4628 - val_loss: 903.8186 - val_mean_absolute_error: 903.8186
#
# Epoch 00473: val_loss did not improve from 677.49457
# Epoch 474/500
# 84/84 [==============================] - 0s 166us/step - loss: 1181.8907 - mean_absolute_error: 1181.8907 - val_loss: 1115.6559 - val_mean_absolute_error: 1115.6559
#
# Epoch 00474: val_loss did not improve from 677.49457
# Epoch 475/500
# 84/84 [==============================] - 0s 267us/step - loss: 1219.3528 - mean_absolute_error: 1219.3528 - val_loss: 850.0101 - val_mean_absolute_error: 850.0101
#
# Epoch 00475: val_loss did not improve from 677.49457
# Epoch 476/500
# 84/84 [==============================] - 0s 154us/step - loss: 1260.4798 - mean_absolute_error: 1260.4798 - val_loss: 806.1276 - val_mean_absolute_error: 806.1276
#
# Epoch 00476: val_loss did not improve from 677.49457
# Epoch 477/500
# 84/84 [==============================] - 0s 226us/step - loss: 1220.9660 - mean_absolute_error: 1220.9660 - val_loss: 1152.4825 - val_mean_absolute_error: 1152.4825
#
# Epoch 00477: val_loss did not improve from 677.49457
# Epoch 478/500
# 84/84 [==============================] - 0s 214us/step - loss: 1218.1451 - mean_absolute_error: 1218.1451 - val_loss: 682.2300 - val_mean_absolute_error: 682.2300
#
# Epoch 00478: val_loss did not improve from 677.49457
# Epoch 479/500
# 84/84 [==============================] - 0s 178us/step - loss: 1352.8781 - mean_absolute_error: 1352.8781 - val_loss: 1011.3969 - val_mean_absolute_error: 1011.3969
#
# Epoch 00479: val_loss did not improve from 677.49457
# Epoch 480/500
# 84/84 [==============================] - 0s 249us/step - loss: 1326.2889 - mean_absolute_error: 1326.2889 - val_loss: 1219.6968 - val_mean_absolute_error: 1219.6968
#
# Epoch 00480: val_loss did not improve from 677.49457
# Epoch 481/500
# 84/84 [==============================] - 0s 154us/step - loss: 1327.4851 - mean_absolute_error: 1327.4851 - val_loss: 593.9970 - val_mean_absolute_error: 593.9970
#
# Epoch 00481: val_loss improved from 677.49457 to 593.99701, saving model to LV-선케어week-Weights-481--593.99701.hdf5
# Epoch 482/500
# 84/84 [==============================] - 0s 190us/step - loss: 1425.5484 - mean_absolute_error: 1425.5484 - val_loss: 1061.6344 - val_mean_absolute_error: 1061.6344
#
# Epoch 00482: val_loss did not improve from 593.99701
# Epoch 483/500
# 84/84 [==============================] - 0s 142us/step - loss: 1267.3887 - mean_absolute_error: 1267.3887 - val_loss: 1104.4540 - val_mean_absolute_error: 1104.4540
#
# Epoch 00483: val_loss did not improve from 593.99701
# Epoch 484/500
# 84/84 [==============================] - 0s 154us/step - loss: 1254.1581 - mean_absolute_error: 1254.1581 - val_loss: 750.4295 - val_mean_absolute_error: 750.4295
#
# Epoch 00484: val_loss did not improve from 593.99701
# Epoch 485/500
# 84/84 [==============================] - 0s 154us/step - loss: 1288.0499 - mean_absolute_error: 1288.0499 - val_loss: 1257.4620 - val_mean_absolute_error: 1257.4620
#
# Epoch 00485: val_loss did not improve from 593.99701
# Epoch 486/500
# 84/84 [==============================] - 0s 214us/step - loss: 1265.4662 - mean_absolute_error: 1265.4662 - val_loss: 767.6905 - val_mean_absolute_error: 767.6905
#
# Epoch 00486: val_loss did not improve from 593.99701
# Epoch 487/500
# 84/84 [==============================] - 0s 154us/step - loss: 1238.4821 - mean_absolute_error: 1238.4821 - val_loss: 1071.4855 - val_mean_absolute_error: 1071.4855
#
# Epoch 00487: val_loss did not improve from 593.99701
# Epoch 488/500
# 84/84 [==============================] - 0s 202us/step - loss: 1253.5986 - mean_absolute_error: 1253.5986 - val_loss: 1092.1780 - val_mean_absolute_error: 1092.1780
#
# Epoch 00488: val_loss did not improve from 593.99701
# Epoch 489/500
# 84/84 [==============================] - 0s 190us/step - loss: 1196.9805 - mean_absolute_error: 1196.9805 - val_loss: 782.3567 - val_mean_absolute_error: 782.3567
#
# Epoch 00489: val_loss did not improve from 593.99701
# Epoch 490/500
# 84/84 [==============================] - 0s 190us/step - loss: 1228.0149 - mean_absolute_error: 1228.0149 - val_loss: 999.6516 - val_mean_absolute_error: 999.6516
#
# Epoch 00490: val_loss did not improve from 593.99701
# Epoch 491/500
# 84/84 [==============================] - 0s 226us/step - loss: 1198.6695 - mean_absolute_error: 1198.6695 - val_loss: 1004.0536 - val_mean_absolute_error: 1004.0536
#
# Epoch 00491: val_loss did not improve from 593.99701
# Epoch 492/500
# 84/84 [==============================] - 0s 261us/step - loss: 1183.3359 - mean_absolute_error: 1183.3359 - val_loss: 866.4966 - val_mean_absolute_error: 866.4966
#
# Epoch 00492: val_loss did not improve from 593.99701
# Epoch 493/500
# 84/84 [==============================] - 0s 190us/step - loss: 1267.7913 - mean_absolute_error: 1267.7913 - val_loss: 848.4830 - val_mean_absolute_error: 848.4830
#
# Epoch 00493: val_loss did not improve from 593.99701
# Epoch 494/500
# 84/84 [==============================] - 0s 166us/step - loss: 1183.1796 - mean_absolute_error: 1183.1796 - val_loss: 1125.0481 - val_mean_absolute_error: 1125.0481
#
# Epoch 00494: val_loss did not improve from 593.99701
# Epoch 495/500
# 84/84 [==============================] - ETA: 0s - loss: 1111.1766 - mean_absolute_error: 1111.176 - 0s 273us/step - loss: 1202.2608 - mean_absolute_error: 1202.2608 - val_loss: 752.7191 - val_mean_absolute_error: 752.7191
#
# Epoch 00495: val_loss did not improve from 593.99701
# Epoch 496/500
# 84/84 [==============================] - 0s 202us/step - loss: 1269.3306 - mean_absolute_error: 1269.3306 - val_loss: 1193.1450 - val_mean_absolute_error: 1193.1450
#
# Epoch 00496: val_loss did not improve from 593.99701
# Epoch 497/500
# 84/84 [==============================] - 0s 226us/step - loss: 1269.8284 - mean_absolute_error: 1269.8284 - val_loss: 926.3824 - val_mean_absolute_error: 926.3824
#
# Epoch 00497: val_loss did not improve from 593.99701
# Epoch 498/500
# 84/84 [==============================] - 0s 214us/step - loss: 1263.5699 - mean_absolute_error: 1263.5699 - val_loss: 832.5559 - val_mean_absolute_error: 832.5559
#
# Epoch 00498: val_loss did not improve from 593.99701
# Epoch 499/500
# 84/84 [==============================] - 0s 237us/step - loss: 1190.2515 - mean_absolute_error: 1190.2515 - val_loss: 1184.7252 - val_mean_absolute_error: 1184.7252
#
# Epoch 00499: val_loss did not improve from 593.99701
# Epoch 500/500
# 84/84 [==============================] - 0s 237us/step - loss: 1196.9229 - mean_absolute_error: 1196.9229 - val_loss: 689.4836 - val_mean_absolute_error: 689.4836
#
# Epoch 00500: val_loss did not improve from 593.99701

# %% [markdown]
# #### ====================================================================================================

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
wights_file = 'LV-선케어week-Weights-481--593.99701.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
# rf나,XGB회귀 분석을위한 훈련/검증 dataset생산
train_X, val_X, train_y, val_y = train_test_split(train, target[:cut_line], test_size = 0.25, random_state = 14)

# %%
# RandomForest 회귀분석
model = RandomForestRegressor()
model.fit(train_X,train_y)

# Get the mean absolute error on the validation data
RFpredicted = model.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  934.0846560846563

# %%
# XGBRegressor 회귀분석
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# [15:26:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  901.7867425181877

# %%
# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)

combined = lv_week_w.loc[:,'temp':'PM25']
target = lv_week_w.loc[:,'qty']
# RandomForest 회귀분석 예측 qty생산
RFpredicted = model.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)

result_df = pd.DataFrame()
result_df['week'] = lv_week_w['week']
result_df['qty'] = lv_week_w.loc[:,'qty']

print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions
# Out:
# keras 신경망 predictions (157, 1)
# randomforest 예상 (157,)
# XGBpredictions (157,)

# %%
df_graph = result_df.loc[:,['week','keras_qty','rf_qty','xgb_qty','qty']]
df_graph['week'] = pd.to_datetime(df_graph['week'])

# %%
# 2016
df_graph = result_df.loc[result_df.week <=53]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.legend()
plt.title('2016년도 '+ item +' 판매량 실제/예측')
plt.show()

# %%
# 2017
df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('2017년도 '+ item +' 판매량 실제/예측')
plt.legend()
plt.show()

# %%
# 2018
df_graph = result_df.loc[(result_df.week >=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('2018년도 '+ item +' 판매량 실제/예측')
plt.legend()
plt.show()

# %%
# 2016~2018
plt.figure(figsize=(15.5, 10))
plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('2016~2018년도 '+ item +' 판매량 실제/예측')
plt.legend()
plt.show()

# %%
# 날씨+sns와 '생수' 을 사용하면 2017까진 적당하고 2018년도는 예측율 급락
#  -> 과적합화 발생
# 날씨와 '생수' 판매량만 이용하니 ㅇㅋ

# %%
orginal_mean = np.mean(result_df.qty)
result_df['qtyMinusMean'] = (result_df.qty - orginal_mean )
result_df['qtyMinusMeanSquared'] = (result_df.qty - orginal_mean )**2

result_df['kerasMiunsMeanSquared'] = (result_df.keras_qty - orginal_mean)**2
result_df['rfMiunsMeanSquared'] = (result_df.rf_qty - orginal_mean)**2
result_df['xgbMiunsMeanSquared'] = (result_df.xgb_qty - orginal_mean)**2

print('kreas R-sq',(sum(result_df['kerasMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
print('rf R-sq',(sum(result_df['rfMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
print('xgb R-sq',(sum(result_df['xgbMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
# Out:
# kreas R-sq 0.49782614408692694
# rf R-sq 1.3049592644579644
# xgb R-sq 1.1235983583289595

# %%
path = 'D:/project/contest/data/result/'
result_df.to_csv(path+item+'_'+grouped_by+'_predict.csv', encoding='utf-8', index=False)
