# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '생수'만 빼서 df생성
item = '생수'
grouped_by = 'date'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %% [markdown]
# # MAD기법 적용할꺼면.....

# %%
# MAD적용
gs_day_w['outlier'] = pd.DataFrame(mad_based_outlier(gs_day_w['qty']))
gs_day_w = gs_day_w.loc[gs_day_w.outlier==False]

# %% [markdown]
# # ↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑

# %%
list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
lowVIF(w,40,list_col)
# Out:
#    VIF_Factor  features
# 0    3.715302      temp
# 1    4.682044      PM10
# 2    6.314379     cloud
# 3    7.886587  lgt_time
# 4    8.692697      wind

# %%
train_data = gs_day_w.loc[gs_day_w.date.between('2016-01-01','2017-12-31')]
test_data = gs_day_w.loc[gs_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만, 
# 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
# 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not',
# 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
combined = gs_day_w.loc[:,list_col+['rain_or_not','snow_or_not']]
target = gs_day_w.loc[:,'qty']

# %%
combined.head(2)
# Out:
#    temp  cloud  wind  lgt_time       PM10 rain_or_not snow_or_not
# 0   1.2    7.0   1.6       2.1  68.696500          비x          눈x
# 1   5.7    7.8   2.0       3.6  53.618667          비x          눈x

# %%
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 5
# 오브젝트형 자료 컬럼 갯수 : 2

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 9 개의 columns이 있었습니다.

# %%
# 비o,비x는 하나가 1이면 다른하나는 0은 완저히 베타적인 관계이므로 한개를 삭제
# 눈o눈x,도 비와 같다.
combined.drop(['rain_or_not_비x'],axis = 1 , inplace=True)
combined.drop(['snow_or_not_눈x'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time     PM10  rain_or_not_비o  snow_or_not_눈o
# 0   1.2    7.0   1.6       2.1  68.6965               0               0

# %%
combined.columns = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o',
       'snow_or_not_o']

# %%
Xy = pd.concat([target,combined], axis=1)
Xy.head(1)
# Out:
#     qty  temp  cloud  wind  lgt_time     PM10  rain_or_not_o  snow_or_not_o
# 0  6269   1.2    7.0   1.6       2.1  68.6965              0              0

# %%
# (combined.shape[0] * 2)//3 첫 2/3 : 730
# 하루정도 차이 있겠지만, 2년/1년
cut_line = (combined.shape[0] * 2)//3
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (730, 7)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 12:32:58.159380  9660 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 12:32:58.175337  9660 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 12:32:58.178329  9660 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 12:32:58.235205  9660 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 165,889
# Trainable params: 165,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'GS-'+item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

checkpoint_name
# Out:
# 'GS-생수date-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5'

# %% [markdown]
# # xxxyyzzz.hdf5 자료가 주워 졌음 ↓ 요건 실행 안해도 된다.

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 12:33:09.215734  9660 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 12:33:09.331454  9660 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 584 samples, validate on 146 samples
# Epoch 1/500
# 584/584 [==============================] - 0s 542us/step - loss: 10371.8078 - mean_absolute_error: 10371.8078 - val_loss: 9122.2305 - val_mean_absolute_error: 9122.2305
#
# Epoch 00001: val_loss improved from inf to 9122.23047, saving model to GS-생수date-Weights-001--9122.23047-cat02-vf05.hdf5
# Epoch 2/500
# 584/584 [==============================] - 0s 80us/step - loss: 9518.1791 - mean_absolute_error: 9518.1791 - val_loss: 6639.3632 - val_mean_absolute_error: 6639.3632
#
# Epoch 00002: val_loss improved from 9122.23047 to 6639.36318, saving model to GS-생수date-Weights-002--6639.36318-cat02-vf05.hdf5
# Epoch 3/500
# 584/584 [==============================] - 0s 87us/step - loss: 4094.9012 - mean_absolute_error: 4094.9012 - val_loss: 2373.6190 - val_mean_absolute_error: 2373.6190
#
# Epoch 00003: val_loss improved from 6639.36318 to 2373.61901, saving model to GS-생수date-Weights-003--2373.61901-cat02-vf05.hdf5
# Epoch 4/500
# 584/584 [==============================] - 0s 77us/step - loss: 2555.8844 - mean_absolute_error: 2555.8844 - val_loss: 1827.3519 - val_mean_absolute_error: 1827.3519
#
# Epoch 00004: val_loss improved from 2373.61901 to 1827.35190, saving model to GS-생수date-Weights-004--1827.35190-cat02-vf05.hdf5
# Epoch 5/500
# 584/584 [==============================] - 0s 84us/step - loss: 2215.5118 - mean_absolute_error: 2215.5118 - val_loss: 1644.2012 - val_mean_absolute_error: 1644.2012
#
# Epoch 00005: val_loss improved from 1827.35190 to 1644.20120, saving model to GS-생수date-Weights-005--1644.20120-cat02-vf05.hdf5
# Epoch 6/500
# 584/584 [==============================] - 0s 75us/step - loss: 2031.9149 - mean_absolute_error: 2031.9149 - val_loss: 1574.4408 - val_mean_absolute_error: 1574.4408
#
# Epoch 00006: val_loss improved from 1644.20120 to 1574.44084, saving model to GS-생수date-Weights-006--1574.44084-cat02-vf05.hdf5
# Epoch 7/500
# 584/584 [==============================] - 0s 80us/step - loss: 1945.4251 - mean_absolute_error: 1945.4251 - val_loss: 1632.4859 - val_mean_absolute_error: 1632.4859
#
# Epoch 00007: val_loss did not improve from 1574.44084
# Epoch 8/500
# 584/584 [==============================] - 0s 77us/step - loss: 1909.6649 - mean_absolute_error: 1909.6649 - val_loss: 1452.2325 - val_mean_absolute_error: 1452.2325
#
# Epoch 00008: val_loss improved from 1574.44084 to 1452.23255, saving model to GS-생수date-Weights-008--1452.23255-cat02-vf05.hdf5
# Epoch 9/500
# 584/584 [==============================] - 0s 80us/step - loss: 1882.5934 - mean_absolute_error: 1882.5934 - val_loss: 1416.8855 - val_mean_absolute_error: 1416.8855
#
# Epoch 00009: val_loss improved from 1452.23255 to 1416.88546, saving model to GS-생수date-Weights-009--1416.88546-cat02-vf05.hdf5
# Epoch 10/500
# 584/584 [==============================] - 0s 80us/step - loss: 1824.3215 - mean_absolute_error: 1824.3215 - val_loss: 1369.9915 - val_mean_absolute_error: 1369.9915
#
# Epoch 00010: val_loss improved from 1416.88546 to 1369.99154, saving model to GS-생수date-Weights-010--1369.99154-cat02-vf05.hdf5
# Epoch 11/500
# 584/584 [==============================] - 0s 68us/step - loss: 1765.5346 - mean_absolute_error: 1765.5346 - val_loss: 1357.1440 - val_mean_absolute_error: 1357.1440
#
# Epoch 00011: val_loss improved from 1369.99154 to 1357.14404, saving model to GS-생수date-Weights-011--1357.14404-cat02-vf05.hdf5
# Epoch 12/500
# 584/584 [==============================] - 0s 73us/step - loss: 1754.6876 - mean_absolute_error: 1754.6876 - val_loss: 1325.9636 - val_mean_absolute_error: 1325.9636
#
# Epoch 00012: val_loss improved from 1357.14404 to 1325.96359, saving model to GS-생수date-Weights-012--1325.96359-cat02-vf05.hdf5
# Epoch 13/500
# 584/584 [==============================] - 0s 77us/step - loss: 1737.1587 - mean_absolute_error: 1737.1587 - val_loss: 1327.2420 - val_mean_absolute_error: 1327.2420
#
# Epoch 00013: val_loss did not improve from 1325.96359
# Epoch 14/500
# 584/584 [==============================] - 0s 106us/step - loss: 1702.6483 - mean_absolute_error: 1702.6483 - val_loss: 1316.0730 - val_mean_absolute_error: 1316.0730
#
# Epoch 00014: val_loss improved from 1325.96359 to 1316.07295, saving model to GS-생수date-Weights-014--1316.07295-cat02-vf05.hdf5
# Epoch 15/500
# 584/584 [==============================] - 0s 92us/step - loss: 1693.7436 - mean_absolute_error: 1693.7436 - val_loss: 1324.5596 - val_mean_absolute_error: 1324.5596
#
# Epoch 00015: val_loss did not improve from 1316.07295
# Epoch 16/500
# 584/584 [==============================] - 0s 79us/step - loss: 1693.1240 - mean_absolute_error: 1693.1240 - val_loss: 1317.4844 - val_mean_absolute_error: 1317.4844
#
# Epoch 00016: val_loss did not improve from 1316.07295
# Epoch 17/500
# 584/584 [==============================] - 0s 87us/step - loss: 1678.2153 - mean_absolute_error: 1678.2153 - val_loss: 1301.3484 - val_mean_absolute_error: 1301.3484
#
# Epoch 00017: val_loss improved from 1316.07295 to 1301.34841, saving model to GS-생수date-Weights-017--1301.34841-cat02-vf05.hdf5
# Epoch 18/500
# 584/584 [==============================] - 0s 74us/step - loss: 1676.9540 - mean_absolute_error: 1676.9540 - val_loss: 1318.1870 - val_mean_absolute_error: 1318.1870
#
# Epoch 00018: val_loss did not improve from 1301.34841
# Epoch 19/500
# 584/584 [==============================] - 0s 73us/step - loss: 1678.5747 - mean_absolute_error: 1678.5747 - val_loss: 1303.2850 - val_mean_absolute_error: 1303.2850
#
# Epoch 00019: val_loss did not improve from 1301.34841
# Epoch 20/500
# 584/584 [==============================] - 0s 69us/step - loss: 1708.9908 - mean_absolute_error: 1708.9908 - val_loss: 1335.6695 - val_mean_absolute_error: 1335.6695
#
# Epoch 00020: val_loss did not improve from 1301.34841
# Epoch 21/500
# 584/584 [==============================] - 0s 72us/step - loss: 1713.3758 - mean_absolute_error: 1713.3758 - val_loss: 1483.8310 - val_mean_absolute_error: 1483.8310
#
# Epoch 00021: val_loss did not improve from 1301.34841
# Epoch 22/500
# 584/584 [==============================] - 0s 70us/step - loss: 1754.3223 - mean_absolute_error: 1754.3223 - val_loss: 1425.7256 - val_mean_absolute_error: 1425.7256
#
# Epoch 00022: val_loss did not improve from 1301.34841
# Epoch 23/500
# 584/584 [==============================] - 0s 83us/step - loss: 1739.5782 - mean_absolute_error: 1739.5782 - val_loss: 1313.2061 - val_mean_absolute_error: 1313.2061
#
# Epoch 00023: val_loss did not improve from 1301.34841
# Epoch 24/500
# 584/584 [==============================] - 0s 102us/step - loss: 1726.4388 - mean_absolute_error: 1726.4388 - val_loss: 1316.0946 - val_mean_absolute_error: 1316.0946
#
# Epoch 00024: val_loss did not improve from 1301.34841
# Epoch 25/500
# 584/584 [==============================] - 0s 80us/step - loss: 1671.0267 - mean_absolute_error: 1671.0267 - val_loss: 1307.7495 - val_mean_absolute_error: 1307.7495
#
# Epoch 00025: val_loss did not improve from 1301.34841
# Epoch 26/500
# 584/584 [==============================] - 0s 72us/step - loss: 1656.7412 - mean_absolute_error: 1656.7412 - val_loss: 1295.9876 - val_mean_absolute_error: 1295.9876
#
# Epoch 00026: val_loss improved from 1301.34841 to 1295.98765, saving model to GS-생수date-Weights-026--1295.98765-cat02-vf05.hdf5
# Epoch 27/500
# 584/584 [==============================] - 0s 79us/step - loss: 1658.3581 - mean_absolute_error: 1658.3581 - val_loss: 1367.8768 - val_mean_absolute_error: 1367.8768
#
# Epoch 00027: val_loss did not improve from 1295.98765
# Epoch 28/500
# 584/584 [==============================] - 0s 79us/step - loss: 1675.3710 - mean_absolute_error: 1675.3710 - val_loss: 1337.2644 - val_mean_absolute_error: 1337.2644
#
# Epoch 00028: val_loss did not improve from 1295.98765
# Epoch 29/500
# 584/584 [==============================] - 0s 87us/step - loss: 1742.8332 - mean_absolute_error: 1742.8332 - val_loss: 1399.5555 - val_mean_absolute_error: 1399.5555
#
# Epoch 00029: val_loss did not improve from 1295.98765
# Epoch 30/500
# 584/584 [==============================] - 0s 85us/step - loss: 1688.6849 - mean_absolute_error: 1688.6849 - val_loss: 1311.3951 - val_mean_absolute_error: 1311.3951
#
# Epoch 00030: val_loss did not improve from 1295.98765
# Epoch 31/500
# 584/584 [==============================] - 0s 73us/step - loss: 1649.7384 - mean_absolute_error: 1649.7384 - val_loss: 1328.4829 - val_mean_absolute_error: 1328.4829
#
# Epoch 00031: val_loss did not improve from 1295.98765
# Epoch 32/500
# 584/584 [==============================] - 0s 84us/step - loss: 1674.0204 - mean_absolute_error: 1674.0204 - val_loss: 1317.8096 - val_mean_absolute_error: 1317.8096
#
# Epoch 00032: val_loss did not improve from 1295.98765
# Epoch 33/500
# 584/584 [==============================] - 0s 77us/step - loss: 1663.0132 - mean_absolute_error: 1663.0132 - val_loss: 1359.3248 - val_mean_absolute_error: 1359.3248
#
# Epoch 00033: val_loss did not improve from 1295.98765
# Epoch 34/500
# 584/584 [==============================] - 0s 73us/step - loss: 1653.9513 - mean_absolute_error: 1653.9513 - val_loss: 1394.5058 - val_mean_absolute_error: 1394.5058
#
# Epoch 00034: val_loss did not improve from 1295.98765
# Epoch 35/500
# 584/584 [==============================] - 0s 77us/step - loss: 1662.8066 - mean_absolute_error: 1662.8066 - val_loss: 1333.2192 - val_mean_absolute_error: 1333.2192
#
# Epoch 00035: val_loss did not improve from 1295.98765
# Epoch 36/500
# 584/584 [==============================] - 0s 75us/step - loss: 1660.5661 - mean_absolute_error: 1660.5661 - val_loss: 1321.8346 - val_mean_absolute_error: 1321.8346
#
# Epoch 00036: val_loss did not improve from 1295.98765
# Epoch 37/500
# 584/584 [==============================] - 0s 87us/step - loss: 1660.6956 - mean_absolute_error: 1660.6956 - val_loss: 1326.1341 - val_mean_absolute_error: 1326.1341
#
# Epoch 00037: val_loss did not improve from 1295.98765
# Epoch 38/500
# 584/584 [==============================] - 0s 84us/step - loss: 1644.1524 - mean_absolute_error: 1644.1524 - val_loss: 1326.8171 - val_mean_absolute_error: 1326.8171
#
# Epoch 00038: val_loss did not improve from 1295.98765
# Epoch 39/500
# 584/584 [==============================] - 0s 80us/step - loss: 1627.3148 - mean_absolute_error: 1627.3148 - val_loss: 1413.4797 - val_mean_absolute_error: 1413.4797
#
# Epoch 00039: val_loss did not improve from 1295.98765
# Epoch 40/500
# 584/584 [==============================] - 0s 75us/step - loss: 1665.8583 - mean_absolute_error: 1665.8583 - val_loss: 1378.1532 - val_mean_absolute_error: 1378.1532
#
# Epoch 00040: val_loss did not improve from 1295.98765
# Epoch 41/500
# 584/584 [==============================] - 0s 77us/step - loss: 1637.7389 - mean_absolute_error: 1637.7389 - val_loss: 1311.2997 - val_mean_absolute_error: 1311.2997
#
# Epoch 00041: val_loss did not improve from 1295.98765
# Epoch 42/500
# 584/584 [==============================] - 0s 82us/step - loss: 1628.4513 - mean_absolute_error: 1628.4513 - val_loss: 1304.8392 - val_mean_absolute_error: 1304.8392
#
# Epoch 00042: val_loss did not improve from 1295.98765
# Epoch 43/500
# 584/584 [==============================] - 0s 99us/step - loss: 1625.5744 - mean_absolute_error: 1625.5744 - val_loss: 1339.9673 - val_mean_absolute_error: 1339.9673
#
# Epoch 00043: val_loss did not improve from 1295.98765
# Epoch 44/500
# 584/584 [==============================] - 0s 125us/step - loss: 1672.8599 - mean_absolute_error: 1672.8599 - val_loss: 1337.4521 - val_mean_absolute_error: 1337.4521
#
# Epoch 00044: val_loss did not improve from 1295.98765
# Epoch 45/500
# 584/584 [==============================] - 0s 109us/step - loss: 1646.4994 - mean_absolute_error: 1646.4994 - val_loss: 1290.2018 - val_mean_absolute_error: 1290.2018
#
# Epoch 00045: val_loss improved from 1295.98765 to 1290.20181, saving model to GS-생수date-Weights-045--1290.20181-cat02-vf05.hdf5
# Epoch 46/500
# 584/584 [==============================] - 0s 84us/step - loss: 1623.7837 - mean_absolute_error: 1623.7837 - val_loss: 1288.3094 - val_mean_absolute_error: 1288.3094
#
# Epoch 00046: val_loss improved from 1290.20181 to 1288.30944, saving model to GS-생수date-Weights-046--1288.30944-cat02-vf05.hdf5
# Epoch 47/500
# 584/584 [==============================] - 0s 88us/step - loss: 1662.7056 - mean_absolute_error: 1662.7056 - val_loss: 1335.2589 - val_mean_absolute_error: 1335.2589
#
# Epoch 00047: val_loss did not improve from 1288.30944
# Epoch 48/500
# 584/584 [==============================] - 0s 79us/step - loss: 1640.5562 - mean_absolute_error: 1640.5562 - val_loss: 1299.7558 - val_mean_absolute_error: 1299.7558
#
# Epoch 00048: val_loss did not improve from 1288.30944
# Epoch 49/500
# 584/584 [==============================] - 0s 79us/step - loss: 1628.2788 - mean_absolute_error: 1628.2788 - val_loss: 1296.6857 - val_mean_absolute_error: 1296.6857
#
# Epoch 00049: val_loss did not improve from 1288.30944
# Epoch 50/500
# 584/584 [==============================] - 0s 94us/step - loss: 1680.1356 - mean_absolute_error: 1680.1356 - val_loss: 1292.5148 - val_mean_absolute_error: 1292.5148
#
# Epoch 00050: val_loss did not improve from 1288.30944
# Epoch 51/500
# 584/584 [==============================] - 0s 81us/step - loss: 1621.0328 - mean_absolute_error: 1621.0328 - val_loss: 1303.0018 - val_mean_absolute_error: 1303.0018
#
# Epoch 00051: val_loss did not improve from 1288.30944
# Epoch 52/500
# 584/584 [==============================] - 0s 99us/step - loss: 1626.0655 - mean_absolute_error: 1626.0655 - val_loss: 1305.5820 - val_mean_absolute_error: 1305.5820
#
# Epoch 00052: val_loss did not improve from 1288.30944
# Epoch 53/500
# 584/584 [==============================] - 0s 78us/step - loss: 1633.7633 - mean_absolute_error: 1633.7633 - val_loss: 1284.6732 - val_mean_absolute_error: 1284.6732
#
# Epoch 00053: val_loss improved from 1288.30944 to 1284.67323, saving model to GS-생수date-Weights-053--1284.67323-cat02-vf05.hdf5
# Epoch 54/500
# 584/584 [==============================] - 0s 94us/step - loss: 1663.4519 - mean_absolute_error: 1663.4519 - val_loss: 1268.9565 - val_mean_absolute_error: 1268.9565
#
# Epoch 00054: val_loss improved from 1284.67323 to 1268.95650, saving model to GS-생수date-Weights-054--1268.95650-cat02-vf05.hdf5
# Epoch 55/500
# 584/584 [==============================] - 0s 77us/step - loss: 1634.5149 - mean_absolute_error: 1634.5149 - val_loss: 1275.9450 - val_mean_absolute_error: 1275.9450
#
# Epoch 00055: val_loss did not improve from 1268.95650
# Epoch 56/500
# 584/584 [==============================] - 0s 82us/step - loss: 1618.3185 - mean_absolute_error: 1618.3185 - val_loss: 1355.3808 - val_mean_absolute_error: 1355.3808
#
# Epoch 00056: val_loss did not improve from 1268.95650
# Epoch 57/500
# 584/584 [==============================] - 0s 79us/step - loss: 1635.4333 - mean_absolute_error: 1635.4333 - val_loss: 1300.3541 - val_mean_absolute_error: 1300.3541
#
# Epoch 00057: val_loss did not improve from 1268.95650
# Epoch 58/500
# 584/584 [==============================] - 0s 79us/step - loss: 1644.4413 - mean_absolute_error: 1644.4413 - val_loss: 1289.7431 - val_mean_absolute_error: 1289.7431
#
# Epoch 00058: val_loss did not improve from 1268.95650
# Epoch 59/500
# 584/584 [==============================] - 0s 94us/step - loss: 1609.9521 - mean_absolute_error: 1609.9521 - val_loss: 1318.2506 - val_mean_absolute_error: 1318.2506
#
# Epoch 00059: val_loss did not improve from 1268.95650
# Epoch 60/500
# 584/584 [==============================] - 0s 113us/step - loss: 1624.6224 - mean_absolute_error: 1624.6224 - val_loss: 1303.3555 - val_mean_absolute_error: 1303.3555
#
# Epoch 00060: val_loss did not improve from 1268.95650
# Epoch 61/500
# 584/584 [==============================] - 0s 97us/step - loss: 1666.4721 - mean_absolute_error: 1666.4721 - val_loss: 1304.2788 - val_mean_absolute_error: 1304.2788
#
# Epoch 00061: val_loss did not improve from 1268.95650
# Epoch 62/500
# 584/584 [==============================] - 0s 91us/step - loss: 1621.9892 - mean_absolute_error: 1621.9892 - val_loss: 1560.4650 - val_mean_absolute_error: 1560.4650
#
# Epoch 00062: val_loss did not improve from 1268.95650
# Epoch 63/500
# 584/584 [==============================] - 0s 101us/step - loss: 1803.6869 - mean_absolute_error: 1803.6869 - val_loss: 1549.2157 - val_mean_absolute_error: 1549.2157
#
# Epoch 00063: val_loss did not improve from 1268.95650
# Epoch 64/500
# 584/584 [==============================] - 0s 85us/step - loss: 1639.8145 - mean_absolute_error: 1639.8145 - val_loss: 1318.6440 - val_mean_absolute_error: 1318.6440
#
# Epoch 00064: val_loss did not improve from 1268.95650
# Epoch 65/500
# 584/584 [==============================] - 0s 89us/step - loss: 1614.9654 - mean_absolute_error: 1614.9654 - val_loss: 1271.8152 - val_mean_absolute_error: 1271.8152
#
# Epoch 00065: val_loss did not improve from 1268.95650
# Epoch 66/500
# 584/584 [==============================] - 0s 94us/step - loss: 1606.2607 - mean_absolute_error: 1606.2607 - val_loss: 1296.1415 - val_mean_absolute_error: 1296.1415
#
# Epoch 00066: val_loss did not improve from 1268.95650
# Epoch 67/500
# 584/584 [==============================] - 0s 89us/step - loss: 1602.4307 - mean_absolute_error: 1602.4307 - val_loss: 1310.0489 - val_mean_absolute_error: 1310.0489
#
# Epoch 00067: val_loss did not improve from 1268.95650
# Epoch 68/500
# 584/584 [==============================] - 0s 96us/step - loss: 1606.0810 - mean_absolute_error: 1606.0810 - val_loss: 1376.9807 - val_mean_absolute_error: 1376.9807
#
# Epoch 00068: val_loss did not improve from 1268.95650
# Epoch 69/500
# 584/584 [==============================] - 0s 97us/step - loss: 1628.8787 - mean_absolute_error: 1628.8787 - val_loss: 1533.6159 - val_mean_absolute_error: 1533.6159
#
# Epoch 00069: val_loss did not improve from 1268.95650
# Epoch 70/500
# 584/584 [==============================] - 0s 116us/step - loss: 1643.8852 - mean_absolute_error: 1643.8852 - val_loss: 1300.1684 - val_mean_absolute_error: 1300.1684
#
# Epoch 00070: val_loss did not improve from 1268.95650
# Epoch 71/500
# 584/584 [==============================] - 0s 96us/step - loss: 1634.6358 - mean_absolute_error: 1634.6358 - val_loss: 1272.0487 - val_mean_absolute_error: 1272.0487
#
# Epoch 00071: val_loss did not improve from 1268.95650
# Epoch 72/500
# 584/584 [==============================] - 0s 96us/step - loss: 1610.4267 - mean_absolute_error: 1610.4267 - val_loss: 1274.1293 - val_mean_absolute_error: 1274.1293
#
# Epoch 00072: val_loss did not improve from 1268.95650
# Epoch 73/500
# 584/584 [==============================] - 0s 106us/step - loss: 1603.3210 - mean_absolute_error: 1603.3210 - val_loss: 1271.5501 - val_mean_absolute_error: 1271.5501
#
# Epoch 00073: val_loss did not improve from 1268.95650
# Epoch 74/500
# 584/584 [==============================] - 0s 97us/step - loss: 1599.2882 - mean_absolute_error: 1599.2882 - val_loss: 1306.4869 - val_mean_absolute_error: 1306.4869
#
# Epoch 00074: val_loss did not improve from 1268.95650
# Epoch 75/500
# 584/584 [==============================] - 0s 108us/step - loss: 1588.8450 - mean_absolute_error: 1588.8450 - val_loss: 1294.7647 - val_mean_absolute_error: 1294.7647
#
# Epoch 00075: val_loss did not improve from 1268.95650
# Epoch 76/500
# 584/584 [==============================] - 0s 92us/step - loss: 1607.2231 - mean_absolute_error: 1607.2231 - val_loss: 1305.9471 - val_mean_absolute_error: 1305.9471
#
# Epoch 00076: val_loss did not improve from 1268.95650
# Epoch 77/500
# 584/584 [==============================] - 0s 120us/step - loss: 1605.1985 - mean_absolute_error: 1605.1985 - val_loss: 1301.8865 - val_mean_absolute_error: 1301.8865
#
# Epoch 00077: val_loss did not improve from 1268.95650
# Epoch 78/500
# 584/584 [==============================] - 0s 117us/step - loss: 1631.0670 - mean_absolute_error: 1631.0670 - val_loss: 1271.3542 - val_mean_absolute_error: 1271.3542
#
# Epoch 00078: val_loss did not improve from 1268.95650
# Epoch 79/500
# 584/584 [==============================] - 0s 97us/step - loss: 1581.2071 - mean_absolute_error: 1581.2071 - val_loss: 1270.0968 - val_mean_absolute_error: 1270.0968
#
# Epoch 00079: val_loss did not improve from 1268.95650
# Epoch 80/500
# 584/584 [==============================] - 0s 103us/step - loss: 1594.7515 - mean_absolute_error: 1594.7515 - val_loss: 1368.9720 - val_mean_absolute_error: 1368.9720
#
# Epoch 00080: val_loss did not improve from 1268.95650
# Epoch 81/500
# 584/584 [==============================] - 0s 94us/step - loss: 1597.5354 - mean_absolute_error: 1597.5354 - val_loss: 1396.7203 - val_mean_absolute_error: 1396.7203
#
# Epoch 00081: val_loss did not improve from 1268.95650
# Epoch 82/500
# 584/584 [==============================] - 0s 104us/step - loss: 1630.7333 - mean_absolute_error: 1630.7333 - val_loss: 1276.0493 - val_mean_absolute_error: 1276.0493
#
# Epoch 00082: val_loss did not improve from 1268.95650
# Epoch 83/500
# 584/584 [==============================] - 0s 99us/step - loss: 1599.8821 - mean_absolute_error: 1599.8821 - val_loss: 1294.8275 - val_mean_absolute_error: 1294.8275
#
# Epoch 00083: val_loss did not improve from 1268.95650
# Epoch 84/500
# 584/584 [==============================] - 0s 97us/step - loss: 1611.5387 - mean_absolute_error: 1611.5387 - val_loss: 1255.9201 - val_mean_absolute_error: 1255.9201
#
# Epoch 00084: val_loss improved from 1268.95650 to 1255.92013, saving model to GS-생수date-Weights-084--1255.92013-cat02-vf05.hdf5
# Epoch 85/500
# 584/584 [==============================] - 0s 109us/step - loss: 1565.2186 - mean_absolute_error: 1565.2186 - val_loss: 1449.0124 - val_mean_absolute_error: 1449.0124
#
# Epoch 00085: val_loss did not improve from 1255.92013
# Epoch 86/500
# 584/584 [==============================] - 0s 102us/step - loss: 1614.4500 - mean_absolute_error: 1614.4500 - val_loss: 1287.5184 - val_mean_absolute_error: 1287.5184
#
# Epoch 00086: val_loss did not improve from 1255.92013
# Epoch 87/500
# 584/584 [==============================] - 0s 99us/step - loss: 1579.3308 - mean_absolute_error: 1579.3308 - val_loss: 1260.4953 - val_mean_absolute_error: 1260.4953
#
# Epoch 00087: val_loss did not improve from 1255.92013
# Epoch 88/500
# 584/584 [==============================] - 0s 118us/step - loss: 1581.8315 - mean_absolute_error: 1581.8315 - val_loss: 1303.9951 - val_mean_absolute_error: 1303.9951
#
# Epoch 00088: val_loss did not improve from 1255.92013
# Epoch 89/500
# 584/584 [==============================] - 0s 99us/step - loss: 1559.7861 - mean_absolute_error: 1559.7861 - val_loss: 1255.1902 - val_mean_absolute_error: 1255.1902
#
# Epoch 00089: val_loss improved from 1255.92013 to 1255.19017, saving model to GS-생수date-Weights-089--1255.19017-cat02-vf05.hdf5
# Epoch 90/500
# 584/584 [==============================] - 0s 89us/step - loss: 1599.3568 - mean_absolute_error: 1599.3568 - val_loss: 1284.8266 - val_mean_absolute_error: 1284.8266
#
# Epoch 00090: val_loss did not improve from 1255.19017
# Epoch 91/500
# 584/584 [==============================] - 0s 94us/step - loss: 1603.8040 - mean_absolute_error: 1603.8040 - val_loss: 1412.0890 - val_mean_absolute_error: 1412.0890
#
# Epoch 00091: val_loss did not improve from 1255.19017
# Epoch 92/500
# 584/584 [==============================] - 0s 114us/step - loss: 1572.4710 - mean_absolute_error: 1572.4710 - val_loss: 1304.9584 - val_mean_absolute_error: 1304.9584
#
# Epoch 00092: val_loss did not improve from 1255.19017
# Epoch 93/500
# 584/584 [==============================] - 0s 116us/step - loss: 1576.5926 - mean_absolute_error: 1576.5926 - val_loss: 1279.8488 - val_mean_absolute_error: 1279.8488
#
# Epoch 00093: val_loss did not improve from 1255.19017
# Epoch 94/500
# 584/584 [==============================] - 0s 104us/step - loss: 1562.4080 - mean_absolute_error: 1562.4080 - val_loss: 1248.4352 - val_mean_absolute_error: 1248.4352
#
# Epoch 00094: val_loss improved from 1255.19017 to 1248.43524, saving model to GS-생수date-Weights-094--1248.43524-cat02-vf05.hdf5
# Epoch 95/500
# 584/584 [==============================] - 0s 94us/step - loss: 1559.4088 - mean_absolute_error: 1559.4088 - val_loss: 1251.7360 - val_mean_absolute_error: 1251.7360
#
# Epoch 00095: val_loss did not improve from 1248.43524
# Epoch 96/500
# 584/584 [==============================] - 0s 106us/step - loss: 1569.4322 - mean_absolute_error: 1569.4322 - val_loss: 1242.8725 - val_mean_absolute_error: 1242.8725
#
# Epoch 00096: val_loss improved from 1248.43524 to 1242.87249, saving model to GS-생수date-Weights-096--1242.87249-cat02-vf05.hdf5
# Epoch 97/500
# 584/584 [==============================] - 0s 92us/step - loss: 1566.3192 - mean_absolute_error: 1566.3192 - val_loss: 1258.2006 - val_mean_absolute_error: 1258.2006
#
# Epoch 00097: val_loss did not improve from 1242.87249
# Epoch 98/500
# 584/584 [==============================] - 0s 94us/step - loss: 1651.0866 - mean_absolute_error: 1651.0866 - val_loss: 1273.9869 - val_mean_absolute_error: 1273.9869
# Epoch 00098: val_loss did not improve from 1242.87249
# Epoch 99/500
# 584/584 [==============================] - 0s 117us/step - loss: 1635.2177 - mean_absolute_error: 1635.2177 - val_loss: 1338.3440 - val_mean_absolute_error: 1338.3440
#
# Epoch 00099: val_loss did not improve from 1242.87249
# Epoch 100/500
# 584/584 [==============================] - 0s 119us/step - loss: 1567.3723 - mean_absolute_error: 1567.3723 - val_loss: 1306.2896 - val_mean_absolute_error: 1306.2896
#
# Epoch 00100: val_loss did not improve from 1242.87249
# Epoch 101/500
# 584/584 [==============================] - 0s 99us/step - loss: 1571.8320 - mean_absolute_error: 1571.8320 - val_loss: 1303.8143 - val_mean_absolute_error: 1303.8143
#
# Epoch 00101: val_loss did not improve from 1242.87249
# Epoch 102/500
# 584/584 [==============================] - 0s 97us/step - loss: 1560.7965 - mean_absolute_error: 1560.7965 - val_loss: 1249.0715 - val_mean_absolute_error: 1249.0715
#
# Epoch 00102: val_loss did not improve from 1242.87249
# Epoch 103/500
# 584/584 [==============================] - 0s 99us/step - loss: 1542.5371 - mean_absolute_error: 1542.5371 - val_loss: 1328.8259 - val_mean_absolute_error: 1328.8259
#
# Epoch 00103: val_loss did not improve from 1242.87249
# Epoch 104/500
# 584/584 [==============================] - 0s 101us/step - loss: 1554.0523 - mean_absolute_error: 1554.0523 - val_loss: 1261.3183 - val_mean_absolute_error: 1261.3183
#
# Epoch 00104: val_loss did not improve from 1242.87249
# Epoch 105/500
# 584/584 [==============================] - 0s 113us/step - loss: 1580.5849 - mean_absolute_error: 1580.5849 - val_loss: 1270.6935 - val_mean_absolute_error: 1270.6935
#
# Epoch 00105: val_loss did not improve from 1242.87249
# Epoch 106/500
# 584/584 [==============================] - 0s 109us/step - loss: 1545.3448 - mean_absolute_error: 1545.3448 - val_loss: 1232.4490 - val_mean_absolute_error: 1232.4490
#
# Epoch 00106: val_loss improved from 1242.87249 to 1232.44905, saving model to GS-생수date-Weights-106--1232.44905-cat02-vf05.hdf5
# Epoch 107/500
# 584/584 [==============================] - 0s 128us/step - loss: 1533.2577 - mean_absolute_error: 1533.2577 - val_loss: 1227.9756 - val_mean_absolute_error: 1227.9756
#
# Epoch 00107: val_loss improved from 1232.44905 to 1227.97555, saving model to GS-생수date-Weights-107--1227.97555-cat02-vf05.hdf5
# Epoch 108/500
# 584/584 [==============================] - 0s 116us/step - loss: 1567.7049 - mean_absolute_error: 1567.7049 - val_loss: 1304.6129 - val_mean_absolute_error: 1304.6129
#
# Epoch 00108: val_loss did not improve from 1227.97555
# Epoch 109/500
# 584/584 [==============================] - 0s 207us/step - loss: 1591.3546 - mean_absolute_error: 1591.3546 - val_loss: 1242.6848 - val_mean_absolute_error: 1242.6848
#
# Epoch 00109: val_loss did not improve from 1227.97555
# Epoch 110/500
# 584/584 [==============================] - 0s 140us/step - loss: 1562.9215 - mean_absolute_error: 1562.9215 - val_loss: 1253.8739 - val_mean_absolute_error: 1253.8739
#
# Epoch 00110: val_loss did not improve from 1227.97555
# Epoch 111/500
# 584/584 [==============================] - 0s 106us/step - loss: 1585.3736 - mean_absolute_error: 1585.3736 - val_loss: 1357.2493 - val_mean_absolute_error: 1357.2493
#
# Epoch 00111: val_loss did not improve from 1227.97555
# Epoch 112/500
# 584/584 [==============================] - 0s 155us/step - loss: 1589.5492 - mean_absolute_error: 1589.5492 - val_loss: 1263.6298 - val_mean_absolute_error: 1263.6298
#
# Epoch 00112: val_loss did not improve from 1227.97555
# Epoch 113/500
# 584/584 [==============================] - 0s 120us/step - loss: 1551.8157 - mean_absolute_error: 1551.8157 - val_loss: 1259.0018 - val_mean_absolute_error: 1259.0018
#
# Epoch 00113: val_loss did not improve from 1227.97555
# Epoch 114/500
# 584/584 [==============================] - 0s 118us/step - loss: 1531.6824 - mean_absolute_error: 1531.6824 - val_loss: 1190.7098 - val_mean_absolute_error: 1190.7098
#
# Epoch 00114: val_loss improved from 1227.97555 to 1190.70984, saving model to GS-생수date-Weights-114--1190.70984-cat02-vf05.hdf5
# Epoch 115/500
# 584/584 [==============================] - 0s 154us/step - loss: 1529.1170 - mean_absolute_error: 1529.1170 - val_loss: 1268.7241 - val_mean_absolute_error: 1268.7241
#
# Epoch 00115: val_loss did not improve from 1190.70984
# Epoch 116/500
# 584/584 [==============================] - 0s 132us/step - loss: 1526.7664 - mean_absolute_error: 1526.7664 - val_loss: 1204.9370 - val_mean_absolute_error: 1204.9370
#
# Epoch 00116: val_loss did not improve from 1190.70984
# Epoch 117/500
# 584/584 [==============================] - 0s 132us/step - loss: 1554.7266 - mean_absolute_error: 1554.7266 - val_loss: 1208.6601 - val_mean_absolute_error: 1208.6601
#
# Epoch 00117: val_loss did not improve from 1190.70984
# Epoch 118/500
# 584/584 [==============================] - 0s 158us/step - loss: 1526.1371 - mean_absolute_error: 1526.1371 - val_loss: 1210.2005 - val_mean_absolute_error: 1210.2005
#
# Epoch 00118: val_loss did not improve from 1190.70984
# Epoch 119/500
# 584/584 [==============================] - 0s 125us/step - loss: 1559.9791 - mean_absolute_error: 1559.9791 - val_loss: 1534.4849 - val_mean_absolute_error: 1534.4849
#
# Epoch 00119: val_loss did not improve from 1190.70984
# Epoch 120/500
# 584/584 [==============================] - 0s 123us/step - loss: 1599.7248 - mean_absolute_error: 1599.7248 - val_loss: 1202.8705 - val_mean_absolute_error: 1202.8705
#
# Epoch 00120: val_loss did not improve from 1190.70984
# Epoch 121/500
# 584/584 [==============================] - 0s 114us/step - loss: 1591.9546 - mean_absolute_error: 1591.9546 - val_loss: 1240.4714 - val_mean_absolute_error: 1240.4714
#
# Epoch 00121: val_loss did not improve from 1190.70984
# Epoch 122/500
# 584/584 [==============================] - 0s 137us/step - loss: 1517.9709 - mean_absolute_error: 1517.9709 - val_loss: 1261.5853 - val_mean_absolute_error: 1261.5853
#
# Epoch 00122: val_loss did not improve from 1190.70984
# Epoch 123/500
# 584/584 [==============================] - 0s 184us/step - loss: 1513.6547 - mean_absolute_error: 1513.6547 - val_loss: 1310.9173 - val_mean_absolute_error: 1310.9173
#
# Epoch 00123: val_loss did not improve from 1190.70984
# Epoch 124/500
# 584/584 [==============================] - 0s 135us/step - loss: 1503.4772 - mean_absolute_error: 1503.4772 - val_loss: 1184.0342 - val_mean_absolute_error: 1184.0342
#
# Epoch 00124: val_loss improved from 1190.70984 to 1184.03425, saving model to GS-생수date-Weights-124--1184.03425-cat02-vf05.hdf5
# Epoch 125/500
# 584/584 [==============================] - 0s 123us/step - loss: 1507.3662 - mean_absolute_error: 1507.3662 - val_loss: 1202.0440 - val_mean_absolute_error: 1202.0440
#
# Epoch 00125: val_loss did not improve from 1184.03425
# Epoch 126/500
# 584/584 [==============================] - 0s 132us/step - loss: 1535.8778 - mean_absolute_error: 1535.8778 - val_loss: 1284.2074 - val_mean_absolute_error: 1284.2074
#
# Epoch 00126: val_loss did not improve from 1184.03425
# Epoch 127/500
# 584/584 [==============================] - 0s 128us/step - loss: 1513.5416 - mean_absolute_error: 1513.5416 - val_loss: 1211.9757 - val_mean_absolute_error: 1211.9757
#
# Epoch 00127: val_loss did not improve from 1184.03425
# Epoch 128/500
# 584/584 [==============================] - 0s 111us/step - loss: 1532.7252 - mean_absolute_error: 1532.7252 - val_loss: 1200.5071 - val_mean_absolute_error: 1200.5071
#
# Epoch 00128: val_loss did not improve from 1184.03425
# Epoch 129/500
# 584/584 [==============================] - 0s 121us/step - loss: 1564.4257 - mean_absolute_error: 1564.4257 - val_loss: 1187.6150 - val_mean_absolute_error: 1187.6150
#
# Epoch 00129: val_loss did not improve from 1184.03425
# Epoch 130/500
# 584/584 [==============================] - 0s 128us/step - loss: 1517.9735 - mean_absolute_error: 1517.9735 - val_loss: 1290.2367 - val_mean_absolute_error: 1290.2367
#
# Epoch 00130: val_loss did not improve from 1184.03425
# Epoch 131/500
# 584/584 [==============================] - 0s 142us/step - loss: 1516.4381 - mean_absolute_error: 1516.4381 - val_loss: 1194.2447 - val_mean_absolute_error: 1194.2447
#
# Epoch 00131: val_loss did not improve from 1184.03425
# Epoch 132/500
# 584/584 [==============================] - 0s 126us/step - loss: 1544.7779 - mean_absolute_error: 1544.7779 - val_loss: 1175.7759 - val_mean_absolute_error: 1175.7759
#
# Epoch 00132: val_loss improved from 1184.03425 to 1175.77594, saving model to GS-생수date-Weights-132--1175.77594-cat02-vf05.hdf5
# Epoch 133/500
# 584/584 [==============================] - 0s 138us/step - loss: 1516.8234 - mean_absolute_error: 1516.8234 - val_loss: 1247.2198 - val_mean_absolute_error: 1247.2198
#
# Epoch 00133: val_loss did not improve from 1175.77594
# Epoch 134/500
# 584/584 [==============================] - 0s 130us/step - loss: 1498.6767 - mean_absolute_error: 1498.6767 - val_loss: 1215.3136 - val_mean_absolute_error: 1215.3136
#
# Epoch 00134: val_loss did not improve from 1175.77594
# Epoch 135/500
# 584/584 [==============================] - 0s 135us/step - loss: 1522.2005 - mean_absolute_error: 1522.2005 - val_loss: 1230.9427 - val_mean_absolute_error: 1230.9427
#
# Epoch 00135: val_loss did not improve from 1175.77594
# Epoch 136/500
# 584/584 [==============================] - 0s 143us/step - loss: 1579.5905 - mean_absolute_error: 1579.5905 - val_loss: 1275.1177 - val_mean_absolute_error: 1275.1177
#
# Epoch 00136: val_loss did not improve from 1175.77594
# Epoch 137/500
# 584/584 [==============================] - 0s 143us/step - loss: 1512.2819 - mean_absolute_error: 1512.2819 - val_loss: 1174.0192 - val_mean_absolute_error: 1174.0192
#
# Epoch 00137: val_loss improved from 1175.77594 to 1174.01916, saving model to GS-생수date-Weights-137--1174.01916-cat02-vf05.hdf5
# Epoch 138/500
# 584/584 [==============================] - 0s 94us/step - loss: 1502.1338 - mean_absolute_error: 1502.1338 - val_loss: 1252.3836 - val_mean_absolute_error: 1252.3836
#
# Epoch 00138: val_loss did not improve from 1174.01916
# Epoch 139/500
# 584/584 [==============================] - 0s 125us/step - loss: 1499.7021 - mean_absolute_error: 1499.7021 - val_loss: 1221.9958 - val_mean_absolute_error: 1221.9958
#
# Epoch 00139: val_loss did not improve from 1174.01916
# Epoch 140/500
# 584/584 [==============================] - 0s 131us/step - loss: 1545.4103 - mean_absolute_error: 1545.4103 - val_loss: 1281.0869 - val_mean_absolute_error: 1281.0869
#
# Epoch 00140: val_loss did not improve from 1174.01916
# Epoch 141/500
# 584/584 [==============================] - 0s 227us/step - loss: 1482.9092 - mean_absolute_error: 1482.9092 - val_loss: 1215.5735 - val_mean_absolute_error: 1215.5735
#
# Epoch 00141: val_loss did not improve from 1174.01916
# Epoch 142/500
# 584/584 [==============================] - 0s 155us/step - loss: 1491.5633 - mean_absolute_error: 1491.5633 - val_loss: 1205.4021 - val_mean_absolute_error: 1205.4021
#
# Epoch 00142: val_loss did not improve from 1174.01916
# Epoch 143/500
# 584/584 [==============================] - 0s 140us/step - loss: 1497.5066 - mean_absolute_error: 1497.5066 - val_loss: 1251.7801 - val_mean_absolute_error: 1251.7801
#
# Epoch 00143: val_loss did not improve from 1174.01916
# Epoch 144/500
# 584/584 [==============================] - 0s 140us/step - loss: 1490.2256 - mean_absolute_error: 1490.2256 - val_loss: 1215.9758 - val_mean_absolute_error: 1215.9758
#
# Epoch 00144: val_loss did not improve from 1174.01916
# Epoch 145/500
# 584/584 [==============================] - 0s 140us/step - loss: 1478.2785 - mean_absolute_error: 1478.2785 - val_loss: 1211.1357 - val_mean_absolute_error: 1211.1357
#
# Epoch 00145: val_loss did not improve from 1174.01916
# Epoch 146/500
# 584/584 [==============================] - 0s 170us/step - loss: 1500.6260 - mean_absolute_error: 1500.6260 - val_loss: 1199.2103 - val_mean_absolute_error: 1199.2103
#
# Epoch 00146: val_loss did not improve from 1174.01916
# Epoch 147/500
# 584/584 [==============================] - 0s 172us/step - loss: 1519.9751 - mean_absolute_error: 1519.9751 - val_loss: 1258.8659 - val_mean_absolute_error: 1258.8659
#
# Epoch 00147: val_loss did not improve from 1174.01916
# Epoch 148/500
# 584/584 [==============================] - 0s 122us/step - loss: 1463.1208 - mean_absolute_error: 1463.1208 - val_loss: 1171.1043 - val_mean_absolute_error: 1171.1043
#
# Epoch 00148: val_loss improved from 1174.01916 to 1171.10435, saving model to GS-생수date-Weights-148--1171.10435-cat02-vf05.hdf5
# Epoch 149/500
# 584/584 [==============================] - 0s 121us/step - loss: 1526.7023 - mean_absolute_error: 1526.7023 - val_loss: 1196.0961 - val_mean_absolute_error: 1196.0961
#
# Epoch 00149: val_loss did not improve from 1171.10435
# Epoch 150/500
# 584/584 [==============================] - 0s 134us/step - loss: 1484.3019 - mean_absolute_error: 1484.3019 - val_loss: 1191.1866 - val_mean_absolute_error: 1191.1866
#
# Epoch 00150: val_loss did not improve from 1171.10435
# Epoch 151/500
# 584/584 [==============================] - 0s 133us/step - loss: 1475.6735 - mean_absolute_error: 1475.6735 - val_loss: 1270.8894 - val_mean_absolute_error: 1270.8894
#
# Epoch 00151: val_loss did not improve from 1171.10435
# Epoch 152/500
# 584/584 [==============================] - 0s 147us/step - loss: 1496.9865 - mean_absolute_error: 1496.9865 - val_loss: 1246.6496 - val_mean_absolute_error: 1246.6496
#
# Epoch 00152: val_loss did not improve from 1171.10435
# Epoch 153/500
# 584/584 [==============================] - 0s 161us/step - loss: 1460.8911 - mean_absolute_error: 1460.8911 - val_loss: 1269.4560 - val_mean_absolute_error: 1269.4560
#
# Epoch 00153: val_loss did not improve from 1171.10435
# Epoch 154/500
# 584/584 [==============================] - 0s 155us/step - loss: 1477.2277 - mean_absolute_error: 1477.2277 - val_loss: 1179.9841 - val_mean_absolute_error: 1179.9841
#
# Epoch 00154: val_loss did not improve from 1171.10435
# Epoch 155/500
# 584/584 [==============================] - 0s 133us/step - loss: 1466.6185 - mean_absolute_error: 1466.6185 - val_loss: 1177.9987 - val_mean_absolute_error: 1177.9987
#
# Epoch 00155: val_loss did not improve from 1171.10435
# Epoch 156/500
# 584/584 [==============================] - 0s 126us/step - loss: 1479.1507 - mean_absolute_error: 1479.1507 - val_loss: 1220.0218 - val_mean_absolute_error: 1220.0218
#
# Epoch 00156: val_loss did not improve from 1171.10435
# Epoch 157/500
# 584/584 [==============================] - 0s 155us/step - loss: 1498.3176 - mean_absolute_error: 1498.3176 - val_loss: 1177.7471 - val_mean_absolute_error: 1177.7471
#
# Epoch 00157: val_loss did not improve from 1171.10435
# Epoch 158/500
# 584/584 [==============================] - 0s 155us/step - loss: 1458.1961 - mean_absolute_error: 1458.1961 - val_loss: 1158.8507 - val_mean_absolute_error: 1158.8507
#
# Epoch 00158: val_loss improved from 1171.10435 to 1158.85068, saving model to GS-생수date-Weights-158--1158.85068-cat02-vf05.hdf5
# Epoch 159/500
# 584/584 [==============================] - 0s 128us/step - loss: 1537.0662 - mean_absolute_error: 1537.0662 - val_loss: 1203.2411 - val_mean_absolute_error: 1203.2411
#
# Epoch 00159: val_loss did not improve from 1158.85068
# Epoch 160/500
# 584/584 [==============================] - 0s 160us/step - loss: 1514.8953 - mean_absolute_error: 1514.8953 - val_loss: 1302.8060 - val_mean_absolute_error: 1302.8060
#
# Epoch 00160: val_loss did not improve from 1158.85068
# Epoch 161/500
# 584/584 [==============================] - 0s 124us/step - loss: 1481.7627 - mean_absolute_error: 1481.7627 - val_loss: 1217.2569 - val_mean_absolute_error: 1217.2569
#
# Epoch 00161: val_loss did not improve from 1158.85068
# Epoch 162/500
# 584/584 [==============================] - 0s 143us/step - loss: 1460.4882 - mean_absolute_error: 1460.4882 - val_loss: 1351.7698 - val_mean_absolute_error: 1351.7698
#
# Epoch 00162: val_loss did not improve from 1158.85068
# Epoch 163/500
# 584/584 [==============================] - 0s 140us/step - loss: 1460.7520 - mean_absolute_error: 1460.7520 - val_loss: 1299.4471 - val_mean_absolute_error: 1299.4471
#
# Epoch 00163: val_loss did not improve from 1158.85068
# Epoch 164/500
# 584/584 [==============================] - 0s 149us/step - loss: 1461.8178 - mean_absolute_error: 1461.8178 - val_loss: 1228.6876 - val_mean_absolute_error: 1228.6876
#
# Epoch 00164: val_loss did not improve from 1158.85068
# Epoch 165/500
# 584/584 [==============================] - 0s 133us/step - loss: 1454.7780 - mean_absolute_error: 1454.7780 - val_loss: 1202.9989 - val_mean_absolute_error: 1202.9989
# Epoch 00165: val_loss did not improve from 1158.85068
# Epoch 166/500
# 584/584 [==============================] - 0s 132us/step - loss: 1456.1229 - mean_absolute_error: 1456.1229 - val_loss: 1359.5719 - val_mean_absolute_error: 1359.5719
#
# Epoch 00166: val_loss did not improve from 1158.85068
# Epoch 167/500
# 584/584 [==============================] - 0s 135us/step - loss: 1455.7552 - mean_absolute_error: 1455.7552 - val_loss: 1191.9947 - val_mean_absolute_error: 1191.9947
#
# Epoch 00167: val_loss did not improve from 1158.85068
# Epoch 168/500
# 584/584 [==============================] - 0s 126us/step - loss: 1434.8228 - mean_absolute_error: 1434.8228 - val_loss: 1387.4458 - val_mean_absolute_error: 1387.4458
#
# Epoch 00168: val_loss did not improve from 1158.85068
# Epoch 169/500
# 584/584 [==============================] - 0s 164us/step - loss: 1496.9017 - mean_absolute_error: 1496.9017 - val_loss: 1177.7820 - val_mean_absolute_error: 1177.7820
#
# Epoch 00169: val_loss did not improve from 1158.85068
# Epoch 170/500
# 584/584 [==============================] - 0s 166us/step - loss: 1496.0864 - mean_absolute_error: 1496.0864 - val_loss: 1433.0890 - val_mean_absolute_error: 1433.0890
#
# Epoch 00170: val_loss did not improve from 1158.85068
# Epoch 171/500
# 584/584 [==============================] - 0s 157us/step - loss: 1458.5425 - mean_absolute_error: 1458.5425 - val_loss: 1193.0474 - val_mean_absolute_error: 1193.0474
#
# Epoch 00171: val_loss did not improve from 1158.85068
# Epoch 172/500
# 584/584 [==============================] - 0s 138us/step - loss: 1450.4727 - mean_absolute_error: 1450.4727 - val_loss: 1346.9443 - val_mean_absolute_error: 1346.9443
#
# Epoch 00172: val_loss did not improve from 1158.85068
# Epoch 173/500
# 584/584 [==============================] - 0s 135us/step - loss: 1439.1191 - mean_absolute_error: 1439.1191 - val_loss: 1222.8413 - val_mean_absolute_error: 1222.8413
#
# Epoch 00173: val_loss did not improve from 1158.85068
# Epoch 174/500
# 584/584 [==============================] - 0s 154us/step - loss: 1452.9057 - mean_absolute_error: 1452.9057 - val_loss: 1368.7369 - val_mean_absolute_error: 1368.7369
#
# Epoch 00174: val_loss did not improve from 1158.85068
# Epoch 175/500
# 584/584 [==============================] - 0s 161us/step - loss: 1466.4705 - mean_absolute_error: 1466.4705 - val_loss: 1150.5866 - val_mean_absolute_error: 1150.5866
#
# Epoch 00175: val_loss improved from 1158.85068 to 1150.58662, saving model to GS-생수date-Weights-175--1150.58662-cat02-vf05.hdf5
# Epoch 176/500
# 584/584 [==============================] - 0s 135us/step - loss: 1449.3793 - mean_absolute_error: 1449.3793 - val_loss: 1222.0859 - val_mean_absolute_error: 1222.0859
#
# Epoch 00176: val_loss did not improve from 1150.58662
# Epoch 177/500
# 584/584 [==============================] - 0s 145us/step - loss: 1448.4672 - mean_absolute_error: 1448.4672 - val_loss: 1184.1070 - val_mean_absolute_error: 1184.1070
#
# Epoch 00177: val_loss did not improve from 1150.58662
# Epoch 178/500
# 584/584 [==============================] - 0s 149us/step - loss: 1454.0968 - mean_absolute_error: 1454.0968 - val_loss: 1147.5557 - val_mean_absolute_error: 1147.5557
#
# Epoch 00178: val_loss improved from 1150.58662 to 1147.55569, saving model to GS-생수date-Weights-178--1147.55569-cat02-vf05.hdf5
# Epoch 179/500
# 584/584 [==============================] - 0s 143us/step - loss: 1461.2880 - mean_absolute_error: 1461.2880 - val_loss: 1380.8635 - val_mean_absolute_error: 1380.8635
#
# Epoch 00179: val_loss did not improve from 1147.55569
# Epoch 180/500
# 584/584 [==============================] - 0s 154us/step - loss: 1434.8181 - mean_absolute_error: 1434.8181 - val_loss: 1173.9382 - val_mean_absolute_error: 1173.9382
#
# Epoch 00180: val_loss did not improve from 1147.55569
# Epoch 181/500
# 584/584 [==============================] - 0s 122us/step - loss: 1481.4725 - mean_absolute_error: 1481.4725 - val_loss: 1194.0012 - val_mean_absolute_error: 1194.0012
#
# Epoch 00181: val_loss did not improve from 1147.55569
# Epoch 182/500
# 584/584 [==============================] - 0s 137us/step - loss: 1444.8039 - mean_absolute_error: 1444.8039 - val_loss: 1248.2286 - val_mean_absolute_error: 1248.2286
#
# Epoch 00182: val_loss did not improve from 1147.55569
# Epoch 183/500
# 584/584 [==============================] - 0s 130us/step - loss: 1435.4014 - mean_absolute_error: 1435.4014 - val_loss: 1180.2454 - val_mean_absolute_error: 1180.2454
#
# Epoch 00183: val_loss did not improve from 1147.55569
# Epoch 184/500
# 584/584 [==============================] - 0s 141us/step - loss: 1464.0688 - mean_absolute_error: 1464.0688 - val_loss: 1204.5229 - val_mean_absolute_error: 1204.5229
#
# Epoch 00184: val_loss did not improve from 1147.55569
# Epoch 185/500
# 584/584 [==============================] - 0s 139us/step - loss: 1441.4750 - mean_absolute_error: 1441.4750 - val_loss: 1305.2818 - val_mean_absolute_error: 1305.2818
#
# Epoch 00185: val_loss did not improve from 1147.55569
# Epoch 186/500
# 584/584 [==============================] - 0s 164us/step - loss: 1433.3697 - mean_absolute_error: 1433.3697 - val_loss: 1166.8726 - val_mean_absolute_error: 1166.8726
#
# Epoch 00186: val_loss did not improve from 1147.55569
# Epoch 187/500
# 584/584 [==============================] - 0s 149us/step - loss: 1414.0973 - mean_absolute_error: 1414.0973 - val_loss: 1188.9605 - val_mean_absolute_error: 1188.9605
#
# Epoch 00187: val_loss did not improve from 1147.55569
# Epoch 188/500
# 584/584 [==============================] - 0s 143us/step - loss: 1414.0831 - mean_absolute_error: 1414.0831 - val_loss: 1294.6489 - val_mean_absolute_error: 1294.6489
#
# Epoch 00188: val_loss did not improve from 1147.55569
# Epoch 189/500
# 584/584 [==============================] - 0s 169us/step - loss: 1435.7419 - mean_absolute_error: 1435.7419 - val_loss: 1179.1392 - val_mean_absolute_error: 1179.1392
#
# Epoch 00189: val_loss did not improve from 1147.55569
# Epoch 190/500
# 584/584 [==============================] - 0s 152us/step - loss: 1429.8236 - mean_absolute_error: 1429.8236 - val_loss: 1212.5021 - val_mean_absolute_error: 1212.5021
#
# Epoch 00190: val_loss did not improve from 1147.55569
# Epoch 191/500
# 584/584 [==============================] - 0s 138us/step - loss: 1422.5147 - mean_absolute_error: 1422.5147 - val_loss: 1203.8313 - val_mean_absolute_error: 1203.8313
#
# Epoch 00191: val_loss did not improve from 1147.55569
# Epoch 192/500
# 584/584 [==============================] - 0s 174us/step - loss: 1428.9343 - mean_absolute_error: 1428.9343 - val_loss: 1224.6376 - val_mean_absolute_error: 1224.6376
#
# Epoch 00192: val_loss did not improve from 1147.55569
# Epoch 193/500
# ...
#
# Epoch 00433: val_loss did not improve from 1068.76549
# Epoch 434/500
# 584/584 [==============================] - 0s 172us/step - loss: 1351.7544 - mean_absolute_error: 1351.7544 - val_loss: 1302.2628 - val_mean_absolute_error: 1302.2628
#
# Epoch 00434: val_loss did not improve from 1068.76549
# Epoch 435/500
# 584/584 [==============================] - 0s 166us/step - loss: 1356.3309 - mean_absolute_error: 1356.3309 - val_loss: 1481.8389 - val_mean_absolute_error: 1481.8389
#
# Epoch 00435: val_loss did not improve from 1068.76549
# Epoch 436/500
# 584/584 [==============================] - 0s 150us/step - loss: 1291.7311 - mean_absolute_error: 1291.7311 - val_loss: 1271.5620 - val_mean_absolute_error: 1271.5620
#
# Epoch 00436: val_loss did not improve from 1068.76549
# Epoch 437/500
# 584/584 [==============================] - 0s 147us/step - loss: 1305.3605 - mean_absolute_error: 1305.3605 - val_loss: 1243.8844 - val_mean_absolute_error: 1243.8844
#
# Epoch 00437: val_loss did not improve from 1068.76549
# Epoch 438/500
# 584/584 [==============================] - 0s 157us/step - loss: 1335.2231 - mean_absolute_error: 1335.2231 - val_loss: 1595.5064 - val_mean_absolute_error: 1595.5064
#
# Epoch 00438: val_loss did not improve from 1068.76549
# Epoch 439/500
# 584/584 [==============================] - 0s 152us/step - loss: 1308.8992 - mean_absolute_error: 1308.8992 - val_loss: 1396.6090 - val_mean_absolute_error: 1396.6090
#
# Epoch 00439: val_loss did not improve from 1068.76549
# Epoch 440/500
# 584/584 [==============================] - 0s 154us/step - loss: 1337.3249 - mean_absolute_error: 1337.3249 - val_loss: 1314.1833 - val_mean_absolute_error: 1314.1833
#
# Epoch 00440: val_loss did not improve from 1068.76549
# Epoch 441/500
# 584/584 [==============================] - 0s 164us/step - loss: 1277.5545 - mean_absolute_error: 1277.5545 - val_loss: 1648.2380 - val_mean_absolute_error: 1648.2380
#
# Epoch 00441: val_loss did not improve from 1068.76549
# Epoch 442/500
# 584/584 [==============================] - 0s 162us/step - loss: 1334.4752 - mean_absolute_error: 1334.4752 - val_loss: 1163.2447 - val_mean_absolute_error: 1163.2447
#
# Epoch 00442: val_loss did not improve from 1068.76549
# Epoch 443/500
# 584/584 [==============================] - 0s 162us/step - loss: 1319.0317 - mean_absolute_error: 1319.0317 - val_loss: 1746.9685 - val_mean_absolute_error: 1746.9685
#
# Epoch 00443: val_loss did not improve from 1068.76549
# Epoch 444/500
# 584/584 [==============================] - 0s 161us/step - loss: 1306.5220 - mean_absolute_error: 1306.5220 - val_loss: 1361.1319 - val_mean_absolute_error: 1361.1319
#
# Epoch 00444: val_loss did not improve from 1068.76549
# Epoch 445/500
# 584/584 [==============================] - 0s 176us/step - loss: 1298.0716 - mean_absolute_error: 1298.0716 - val_loss: 1400.7109 - val_mean_absolute_error: 1400.7109
#
# Epoch 00445: val_loss did not improve from 1068.76549
# Epoch 446/500
# 584/584 [==============================] - 0s 155us/step - loss: 1301.7051 - mean_absolute_error: 1301.7051 - val_loss: 1369.0172 - val_mean_absolute_error: 1369.0172
#
# Epoch 00446: val_loss did not improve from 1068.76549
# Epoch 447/500
# 584/584 [==============================] - 0s 158us/step - loss: 1275.0540 - mean_absolute_error: 1275.0540 - val_loss: 1601.1382 - val_mean_absolute_error: 1601.1382
#
# Epoch 00447: val_loss did not improve from 1068.76549
# Epoch 448/500
# 584/584 [==============================] - 0s 156us/step - loss: 1319.6616 - mean_absolute_error: 1319.6616 - val_loss: 1215.9845 - val_mean_absolute_error: 1215.9845
#
# Epoch 00448: val_loss did not improve from 1068.76549
# Epoch 449/500
# 584/584 [==============================] - 0s 167us/step - loss: 1341.1119 - mean_absolute_error: 1341.1119 - val_loss: 1477.8366 - val_mean_absolute_error: 1477.8366
#
# Epoch 00449: val_loss did not improve from 1068.76549
# Epoch 450/500
# 584/584 [==============================] - 0s 163us/step - loss: 1282.7144 - mean_absolute_error: 1282.7144 - val_loss: 1249.5929 - val_mean_absolute_error: 1249.5929
#
# Epoch 00450: val_loss did not improve from 1068.76549
# Epoch 451/500
# 584/584 [==============================] - 0s 175us/step - loss: 1302.5052 - mean_absolute_error: 1302.5052 - val_loss: 1574.9942 - val_mean_absolute_error: 1574.9942
#
# Epoch 00451: val_loss did not improve from 1068.76549
# Epoch 452/500
# 584/584 [==============================] - 0s 149us/step - loss: 1312.7213 - mean_absolute_error: 1312.7213 - val_loss: 1451.6429 - val_mean_absolute_error: 1451.6429
#
# Epoch 00452: val_loss did not improve from 1068.76549
# Epoch 453/500
# 584/584 [==============================] - 0s 196us/step - loss: 1296.5774 - mean_absolute_error: 1296.5774 - val_loss: 1266.8360 - val_mean_absolute_error: 1266.8360
#
# Epoch 00453: val_loss did not improve from 1068.76549
# Epoch 454/500
# 584/584 [==============================] - 0s 183us/step - loss: 1297.4054 - mean_absolute_error: 1297.4054 - val_loss: 1363.6356 - val_mean_absolute_error: 1363.6356
#
# Epoch 00454: val_loss did not improve from 1068.76549
# Epoch 455/500
# 584/584 [==============================] - 0s 149us/step - loss: 1273.5483 - mean_absolute_error: 1273.5483 - val_loss: 1404.1364 - val_mean_absolute_error: 1404.1364
#
# Epoch 00455: val_loss did not improve from 1068.76549
# Epoch 456/500
# 584/584 [==============================] - 0s 166us/step - loss: 1303.2776 - mean_absolute_error: 1303.2776 - val_loss: 1176.4349 - val_mean_absolute_error: 1176.4349
#
# Epoch 00456: val_loss did not improve from 1068.76549
# Epoch 457/500
# 584/584 [==============================] - 0s 133us/step - loss: 1308.1354 - mean_absolute_error: 1308.1354 - val_loss: 1554.7548 - val_mean_absolute_error: 1554.7548
#
# Epoch 00457: val_loss did not improve from 1068.76549
# Epoch 458/500
# 584/584 [==============================] - 0s 149us/step - loss: 1301.6109 - mean_absolute_error: 1301.6109 - val_loss: 1236.6911 - val_mean_absolute_error: 1236.6911
#
# Epoch 00458: val_loss did not improve from 1068.76549
# Epoch 459/500
# 584/584 [==============================] - 0s 149us/step - loss: 1294.5628 - mean_absolute_error: 1294.5628 - val_loss: 1632.9852 - val_mean_absolute_error: 1632.9852
#
# Epoch 00459: val_loss did not improve from 1068.76549
# Epoch 460/500
# 584/584 [==============================] - 0s 207us/step - loss: 1276.2887 - mean_absolute_error: 1276.2887 - val_loss: 1358.8854 - val_mean_absolute_error: 1358.8854
#
# Epoch 00460: val_loss did not improve from 1068.76549
# Epoch 461/500
# 584/584 [==============================] - 0s 188us/step - loss: 1274.9570 - mean_absolute_error: 1274.9570 - val_loss: 1504.0054 - val_mean_absolute_error: 1504.0054
#
# Epoch 00461: val_loss did not improve from 1068.76549
# Epoch 462/500
# 584/584 [==============================] - 0s 157us/step - loss: 1301.9737 - mean_absolute_error: 1301.9737 - val_loss: 1327.6410 - val_mean_absolute_error: 1327.6410
#
# Epoch 00462: val_loss did not improve from 1068.76549
# Epoch 463/500
# 584/584 [==============================] - 0s 171us/step - loss: 1275.8513 - mean_absolute_error: 1275.8513 - val_loss: 1494.0789 - val_mean_absolute_error: 1494.0789
#
# Epoch 00463: val_loss did not improve from 1068.76549
# Epoch 464/500
# 584/584 [==============================] - 0s 155us/step - loss: 1277.1581 - mean_absolute_error: 1277.1581 - val_loss: 1354.3867 - val_mean_absolute_error: 1354.3867
#
# Epoch 00464: val_loss did not improve from 1068.76549
# Epoch 465/500
# 584/584 [==============================] - 0s 176us/step - loss: 1319.4039 - mean_absolute_error: 1319.4039 - val_loss: 1943.9741 - val_mean_absolute_error: 1943.9741
#
# Epoch 00465: val_loss did not improve from 1068.76549
# Epoch 466/500
# 584/584 [==============================] - 0s 232us/step - loss: 1326.3687 - mean_absolute_error: 1326.3687 - val_loss: 1278.7497 - val_mean_absolute_error: 1278.7497
#
# Epoch 00466: val_loss did not improve from 1068.76549
# Epoch 467/500
# 584/584 [==============================] - 0s 161us/step - loss: 1295.8173 - mean_absolute_error: 1295.8173 - val_loss: 1443.9605 - val_mean_absolute_error: 1443.9605
#
# Epoch 00467: val_loss did not improve from 1068.76549
# Epoch 468/500
# 584/584 [==============================] - 0s 172us/step - loss: 1288.1111 - mean_absolute_error: 1288.1111 - val_loss: 1422.4753 - val_mean_absolute_error: 1422.4753
#
# Epoch 00468: val_loss did not improve from 1068.76549
# Epoch 469/500
# 584/584 [==============================] - 0s 220us/step - loss: 1278.1016 - mean_absolute_error: 1278.1016 - val_loss: 1227.6910 - val_mean_absolute_error: 1227.6910
#
# Epoch 00469: val_loss did not improve from 1068.76549
# Epoch 470/500
# 584/584 [==============================] - 0s 285us/step - loss: 1293.2591 - mean_absolute_error: 1293.2591 - val_loss: 1585.0374 - val_mean_absolute_error: 1585.0374
#
# Epoch 00470: val_loss did not improve from 1068.76549
# Epoch 471/500
# 584/584 [==============================] - 0s 184us/step - loss: 1276.4140 - mean_absolute_error: 1276.4140 - val_loss: 1538.1008 - val_mean_absolute_error: 1538.1008
#
# Epoch 00471: val_loss did not improve from 1068.76549
# Epoch 472/500
# 584/584 [==============================] - 0s 178us/step - loss: 1280.0215 - mean_absolute_error: 1280.0215 - val_loss: 1440.4224 - val_mean_absolute_error: 1440.4224
#
# Epoch 00472: val_loss did not improve from 1068.76549
# Epoch 473/500
# 584/584 [==============================] - 0s 173us/step - loss: 1264.5702 - mean_absolute_error: 1264.5702 - val_loss: 1472.9049 - val_mean_absolute_error: 1472.9049
#
# Epoch 00473: val_loss did not improve from 1068.76549
# Epoch 474/500
# 584/584 [==============================] - 0s 178us/step - loss: 1258.8530 - mean_absolute_error: 1258.8530 - val_loss: 1692.0816 - val_mean_absolute_error: 1692.0816
#
# Epoch 00474: val_loss did not improve from 1068.76549
# Epoch 475/500
# 584/584 [==============================] - 0s 181us/step - loss: 1313.2956 - mean_absolute_error: 1313.2956 - val_loss: 1335.2107 - val_mean_absolute_error: 1335.2107
#
# Epoch 00475: val_loss did not improve from 1068.76549
# Epoch 476/500
# 584/584 [==============================] - 0s 174us/step - loss: 1275.2455 - mean_absolute_error: 1275.2455 - val_loss: 1472.0991 - val_mean_absolute_error: 1472.0991
#
# Epoch 00476: val_loss did not improve from 1068.76549
# Epoch 477/500
# 584/584 [==============================] - 0s 190us/step - loss: 1354.0176 - mean_absolute_error: 1354.0176 - val_loss: 1754.7730 - val_mean_absolute_error: 1754.7730
#
# Epoch 00477: val_loss did not improve from 1068.76549
# Epoch 478/500
# 584/584 [==============================] - 0s 183us/step - loss: 1295.9405 - mean_absolute_error: 1295.9405 - val_loss: 1464.5527 - val_mean_absolute_error: 1464.5527
#
# Epoch 00478: val_loss did not improve from 1068.76549
# Epoch 479/500
# 584/584 [==============================] - 0s 179us/step - loss: 1270.9248 - mean_absolute_error: 1270.9248 - val_loss: 1530.0046 - val_mean_absolute_error: 1530.0046
#
# Epoch 00479: val_loss did not improve from 1068.76549
# Epoch 480/500
# 584/584 [==============================] - 0s 200us/step - loss: 1303.5274 - mean_absolute_error: 1303.5274 - val_loss: 1514.6868 - val_mean_absolute_error: 1514.6868
#
# Epoch 00480: val_loss did not improve from 1068.76549
# Epoch 481/500
# 584/584 [==============================] - 0s 191us/step - loss: 1315.2267 - mean_absolute_error: 1315.2267 - val_loss: 1400.7957 - val_mean_absolute_error: 1400.7957
#
# Epoch 00481: val_loss did not improve from 1068.76549
# Epoch 482/500
# 584/584 [==============================] - 0s 192us/step - loss: 1277.4084 - mean_absolute_error: 1277.4084 - val_loss: 1568.6373 - val_mean_absolute_error: 1568.6373
#
# Epoch 00482: val_loss did not improve from 1068.76549
# Epoch 483/500
# 584/584 [==============================] - 0s 181us/step - loss: 1289.2731 - mean_absolute_error: 1289.2731 - val_loss: 1402.8368 - val_mean_absolute_error: 1402.8368
#
# Epoch 00483: val_loss did not improve from 1068.76549
# Epoch 484/500
# 584/584 [==============================] - 0s 189us/step - loss: 1274.8754 - mean_absolute_error: 1274.8754 - val_loss: 1718.2739 - val_mean_absolute_error: 1718.2739
#
# Epoch 00484: val_loss did not improve from 1068.76549
# Epoch 485/500
# 584/584 [==============================] - 0s 223us/step - loss: 1304.6207 - mean_absolute_error: 1304.6207 - val_loss: 1479.9007 - val_mean_absolute_error: 1479.9007
#
# Epoch 00485: val_loss did not improve from 1068.76549
# Epoch 486/500
# 584/584 [==============================] - 0s 196us/step - loss: 1316.1944 - mean_absolute_error: 1316.1944 - val_loss: 1395.0453 - val_mean_absolute_error: 1395.0453
#
# Epoch 00486: val_loss did not improve from 1068.76549
# Epoch 487/500
# 584/584 [==============================] - 0s 188us/step - loss: 1282.0046 - mean_absolute_error: 1282.0046 - val_loss: 1582.9464 - val_mean_absolute_error: 1582.9464
#
# Epoch 00487: val_loss did not improve from 1068.76549
# Epoch 488/500
# 584/584 [==============================] - 0s 178us/step - loss: 1289.2088 - mean_absolute_error: 1289.2088 - val_loss: 1236.5979 - val_mean_absolute_error: 1236.5979
#
# Epoch 00488: val_loss did not improve from 1068.76549
# Epoch 489/500
# 584/584 [==============================] - 0s 174us/step - loss: 1333.6909 - mean_absolute_error: 1333.6909 - val_loss: 1866.9397 - val_mean_absolute_error: 1866.9397
#
# Epoch 00489: val_loss did not improve from 1068.76549
# Epoch 490/500
# 584/584 [==============================] - 0s 190us/step - loss: 1316.6308 - mean_absolute_error: 1316.6308 - val_loss: 1531.3821 - val_mean_absolute_error: 1531.3821
#
# Epoch 00490: val_loss did not improve from 1068.76549
# Epoch 491/500
# 584/584 [==============================] - 0s 207us/step - loss: 1283.5924 - mean_absolute_error: 1283.5924 - val_loss: 1330.3130 - val_mean_absolute_error: 1330.3130
#
# Epoch 00491: val_loss did not improve from 1068.76549
# Epoch 492/500
# 584/584 [==============================] - 0s 219us/step - loss: 1264.6901 - mean_absolute_error: 1264.6901 - val_loss: 1450.4419 - val_mean_absolute_error: 1450.4419
#
# Epoch 00492: val_loss did not improve from 1068.76549
# Epoch 493/500
# 584/584 [==============================] - 0s 237us/step - loss: 1274.2109 - mean_absolute_error: 1274.2109 - val_loss: 1362.3006 - val_mean_absolute_error: 1362.3006
#
# Epoch 00493: val_loss did not improve from 1068.76549
# Epoch 494/500
# 584/584 [==============================] - 0s 290us/step - loss: 1278.2886 - mean_absolute_error: 1278.2886 - val_loss: 1546.2394 - val_mean_absolute_error: 1546.2394
#
# Epoch 00494: val_loss did not improve from 1068.76549
# Epoch 495/500
# 584/584 [==============================] - 0s 255us/step - loss: 1301.2619 - mean_absolute_error: 1301.2619 - val_loss: 1501.9206 - val_mean_absolute_error: 1501.9206
#
# Epoch 00495: val_loss did not improve from 1068.76549
# Epoch 496/500
# 584/584 [==============================] - 0s 236us/step - loss: 1321.9629 - mean_absolute_error: 1321.9629 - val_loss: 1423.3405 - val_mean_absolute_error: 1423.3405
#
# Epoch 00496: val_loss did not improve from 1068.76549
# Epoch 497/500
# 584/584 [==============================] - ETA: 0s - loss: 1242.1721 - mean_absolute_error: 1242.172 - 0s 173us/step - loss: 1272.0443 - mean_absolute_error: 1272.0443 - val_loss: 1531.9068 - val_mean_absolute_error: 1531.9068
#
# Epoch 00497: val_loss did not improve from 1068.76549
# Epoch 498/500
# 584/584 [==============================] - 0s 218us/step - loss: 1264.8516 - mean_absolute_error: 1264.8516 - val_loss: 1345.3831 - val_mean_absolute_error: 1345.3831
#
# Epoch 00498: val_loss did not improve from 1068.76549
# Epoch 499/500
# 584/584 [==============================] - 0s 211us/step - loss: 1277.6768 - mean_absolute_error: 1277.6768 - val_loss: 1502.2740 - val_mean_absolute_error: 1502.2740
#
# Epoch 00499: val_loss did not improve from 1068.76549
# Epoch 500/500
# 584/584 [==============================] - 0s 181us/step - loss: 1271.2951 - mean_absolute_error: 1271.2951 - val_loss: 1318.4351 - val_mean_absolute_error: 1318.4351
#
# Epoch 00500: val_loss did not improve from 1068.76549

# %% [markdown]
# # ↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑↑

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = 'GS-생수date-Weights-340--1068.76549-cat02-vf05.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']



print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

customF = formulaGen(target='qty',ind_features=list_col)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.880
# 검증세트점수 : -0.191
# XGBoost을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.804
# 검증세트점수 : 0.162
# LinearRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.415
# 검증세트점수 : 0.133
# RidgeRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.412
# 검증세트점수 : 0.130
# LassoRegression을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.415
# 검증세트점수 : 0.133
# OLS을 이용한 생수의 회귀분석 결과 :
# 훈련세트점수 : 0.415

# %%
print(item, 'ols model')
# ind_features = 넣고 싶은 독립변수를 리스트로 넣어주면 알아서 formula생성해 준다.
# customF = formulaGen(target='qty',ind_features=['temp'])
# print(customF) qty ~ temp
# customF = formulaGen(target='qty',ind_features=['temp','cloud'])
# print(customF) # qty ~ temp + cloud
list_col = ['temp', 'lgt_time', 'PM10', 'snow_or_not_o', 'rain_or_not_o']

customF = formulaGen(target='qty',ind_features=list_col)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
olsModel.summary()
# Out:
# 생수 ols model
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.407
# Method:                 Least Squares   F-statistic:                     100.9
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):           1.05e-80
# Time:                        12:34:25   Log-Likelihood:                -6740.8
# No. Observations:                 730   AIC:                         1.349e+04
# Df Residuals:                     724   BIC:                         1.352e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      6613.6516    359.728     18.385      0.000    5907.417    7319.886
# temp            184.9933      8.955     20.658      0.000     167.412     202.574
# lgt_time        111.9856     27.889      4.015      0.000      57.233     166.739
# PM10              7.1114      4.184      1.700      0.090      -1.102      15.325
# snow_or_not_o    79.5483    584.198      0.136      0.892   -1067.376    1226.472
# rain_or_not_o  -188.2214    256.179     -0.735      0.463    -691.164     314.721
# ==============================================================================
# Omnibus:                      988.208   Durbin-Watson:                   1.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           248036.508
# Skew:                           6.973   Prob(JB):                         0.00
# Kurtosis:                      92.219   Cond. No.                         351.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = gs_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_비o', 'snow_or_not_눈o']
n=1
# alpha 값 0~1
alp = 1
# scatter plot 점 크기
dot_size = 20

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=30, c='k', alpha = 1)
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
