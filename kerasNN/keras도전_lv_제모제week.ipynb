# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor


# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1))
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula


#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
lv_grouped = lv_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_lv_grouped = lv_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '제모제'만 빼서 df생성
item = '제모제'
grouped_by = 'week'
day_lv_grouped_w_item = pd.merge(day_lv_grouped.loc[day_lv_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_lv_grouped_w_sns_item = pd.merge(day_lv_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
lv_day_w = day_lv_grouped_w_sns_item[selected_cols]

# %% [markdown]
# # 주단위로 종합해보기

# %%
lv_week_w = lv_day_w.copy()
lv_week_w = addDayWeek(lv_week_w)

cols_Ineed = ['week','category', 'qty', 'temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
lv_week_w = lv_week_w[cols_Ineed]

# %%
list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
              'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
              'health_blog','health_twitter', 'health_news', 'health_total',
              'date_blog','date_twitter', 'date_news', 'date_total',
              'br_blog', 'br_twitter','br_news', 'br_total',
              'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
lowVIF(lv_week_w,40,list_col)

list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',]
lv_week_w = lv_week_w[['week','qty']+list_col].groupby('week').mean().reset_index()
# gs_week_w.tail(2)

# week: 1~105 = 2016~2017년
# week: 106~157 = 2018년
train_data = lv_week_w.loc[lv_week_w.week <=105]
test_date = lv_week_w.loc[lv_week_w.week >105]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
combined = lv_week_w.loc[:,'temp':'PM25']
target = lv_week_w.loc[:,'qty']

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 15
# Number of nun-numerical columns with no nan values : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 15 columns before encoding categorical features
# There are 15 columns after encoding categorical features

# %%
# 여기서 이코드으 제작자는 수동으로 훈련/검증셋을 나눔
# 105주 기준으로 나누겠음
cut_line = 106
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()
train.shape
# Out:
# (106, 15)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 15:37:45.099961  2236 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 15:37:45.114922  2236 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 15:37:45.117913  2236 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0717 15:37:45.172790  2236 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,913
# Trainable params: 166,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### =========='xxxxyyyyzzzz.hdf5'파일이 안주어지면 실행.(있으면 실행 필요없음)==========

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'LV-'+item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=106을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0717 15:37:48.259710  2236 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0717 15:37:48.373914  2236 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 84 samples, validate on 22 samples
# Epoch 1/500
# 84/84 [==============================] - 0s 3ms/step - loss: 1616.5065 - mean_absolute_error: 1616.5065 - val_loss: 867.2692 - val_mean_absolute_error: 867.2692
#
# Epoch 00001: val_loss improved from inf to 867.26917, saving model to LV-제모제week-Weights-001--867.26917.hdf5
# Epoch 2/500
# 84/84 [==============================] - 0s 107us/step - loss: 1578.5995 - mean_absolute_error: 1578.5995 - val_loss: 807.5000 - val_mean_absolute_error: 807.5000
#
# Epoch 00002: val_loss improved from 867.26917 to 807.50000, saving model to LV-제모제week-Weights-002--807.50000.hdf5
# Epoch 3/500
# 84/84 [==============================] - 0s 107us/step - loss: 1505.2231 - mean_absolute_error: 1505.2231 - val_loss: 687.6830 - val_mean_absolute_error: 687.6830
#
# Epoch 00003: val_loss improved from 807.50000 to 687.68298, saving model to LV-제모제week-Weights-003--687.68298.hdf5
# Epoch 4/500
# 84/84 [==============================] - 0s 107us/step - loss: 1380.0997 - mean_absolute_error: 1380.0997 - val_loss: 452.8523 - val_mean_absolute_error: 452.8523
#
# Epoch 00004: val_loss improved from 687.68298 to 452.85226, saving model to LV-제모제week-Weights-004--452.85226.hdf5
# Epoch 5/500
# 84/84 [==============================] - 0s 119us/step - loss: 1202.7902 - mean_absolute_error: 1202.7902 - val_loss: 319.9927 - val_mean_absolute_error: 319.9927
#
# Epoch 00005: val_loss improved from 452.85226 to 319.99274, saving model to LV-제모제week-Weights-005--319.99274.hdf5
# Epoch 6/500
# 84/84 [==============================] - 0s 119us/step - loss: 1116.5659 - mean_absolute_error: 1116.5659 - val_loss: 636.7170 - val_mean_absolute_error: 636.7170
#
# Epoch 00006: val_loss did not improve from 319.99274
# Epoch 7/500
# 84/84 [==============================] - 0s 130us/step - loss: 1136.9068 - mean_absolute_error: 1136.9068 - val_loss: 900.1243 - val_mean_absolute_error: 900.1243
#
# Epoch 00007: val_loss did not improve from 319.99274
# Epoch 8/500
# 84/84 [==============================] - 0s 142us/step - loss: 1156.5709 - mean_absolute_error: 1156.5709 - val_loss: 932.5108 - val_mean_absolute_error: 932.5108
#
# Epoch 00008: val_loss did not improve from 319.99274
# Epoch 9/500
# 84/84 [==============================] - 0s 143us/step - loss: 1154.3048 - mean_absolute_error: 1154.3048 - val_loss: 792.9733 - val_mean_absolute_error: 792.9733
#
# Epoch 00009: val_loss did not improve from 319.99274
# Epoch 10/500
# 84/84 [==============================] - 0s 178us/step - loss: 1127.0275 - mean_absolute_error: 1127.0275 - val_loss: 636.2078 - val_mean_absolute_error: 636.2078
#
# Epoch 00010: val_loss did not improve from 319.99274
# Epoch 11/500
# 84/84 [==============================] - 0s 131us/step - loss: 1111.5596 - mean_absolute_error: 1111.5596 - val_loss: 499.2104 - val_mean_absolute_error: 499.2104
#
# Epoch 00011: val_loss did not improve from 319.99274
# Epoch 12/500
# 84/84 [==============================] - 0s 95us/step - loss: 1101.0682 - mean_absolute_error: 1101.0682 - val_loss: 403.6575 - val_mean_absolute_error: 403.6575
#
# Epoch 00012: val_loss did not improve from 319.99274
# Epoch 13/500
# 84/84 [==============================] - 0s 107us/step - loss: 1099.2402 - mean_absolute_error: 1099.2402 - val_loss: 333.3405 - val_mean_absolute_error: 333.3405
#
# Epoch 00013: val_loss did not improve from 319.99274
# Epoch 14/500
# 84/84 [==============================] - 0s 154us/step - loss: 1109.6254 - mean_absolute_error: 1109.6254 - val_loss: 304.9026 - val_mean_absolute_error: 304.9026
#
# Epoch 00014: val_loss improved from 319.99274 to 304.90259, saving model to LV-제모제week-Weights-014--304.90259.hdf5
# Epoch 15/500
# 84/84 [==============================] - 0s 131us/step - loss: 1112.1302 - mean_absolute_error: 1112.1302 - val_loss: 330.7931 - val_mean_absolute_error: 330.7931
#
# Epoch 00015: val_loss did not improve from 304.90259
# Epoch 16/500
# 84/84 [==============================] - 0s 131us/step - loss: 1099.9175 - mean_absolute_error: 1099.9175 - val_loss: 370.6836 - val_mean_absolute_error: 370.6836
#
# Epoch 00016: val_loss did not improve from 304.90259
# Epoch 17/500
# 84/84 [==============================] - 0s 95us/step - loss: 1099.9662 - mean_absolute_error: 1099.9662 - val_loss: 429.7950 - val_mean_absolute_error: 429.7950
#
# Epoch 00017: val_loss did not improve from 304.90259
# Epoch 18/500
# 84/84 [==============================] - 0s 95us/step - loss: 1093.9499 - mean_absolute_error: 1093.9499 - val_loss: 466.5363 - val_mean_absolute_error: 466.5363
#
# Epoch 00018: val_loss did not improve from 304.90259
# Epoch 19/500
# 84/84 [==============================] - 0s 107us/step - loss: 1094.4606 - mean_absolute_error: 1094.4606 - val_loss: 497.8583 - val_mean_absolute_error: 497.8583
#
# Epoch 00019: val_loss did not improve from 304.90259
# Epoch 20/500
# 84/84 [==============================] - 0s 142us/step - loss: 1105.3816 - mean_absolute_error: 1105.3816 - val_loss: 554.3730 - val_mean_absolute_error: 554.3730
#
# Epoch 00020: val_loss did not improve from 304.90259
# Epoch 21/500
# 84/84 [==============================] - 0s 119us/step - loss: 1095.6300 - mean_absolute_error: 1095.6300 - val_loss: 538.0912 - val_mean_absolute_error: 538.0912
#
# Epoch 00021: val_loss did not improve from 304.90259
# Epoch 22/500
# 84/84 [==============================] - 0s 114us/step - loss: 1093.7948 - mean_absolute_error: 1093.7948 - val_loss: 517.9174 - val_mean_absolute_error: 517.9174
#
# Epoch 00022: val_loss did not improve from 304.90259
# Epoch 23/500
# 84/84 [==============================] - 0s 142us/step - loss: 1092.4658 - mean_absolute_error: 1092.4658 - val_loss: 501.7263 - val_mean_absolute_error: 501.7263
#
# Epoch 00023: val_loss did not improve from 304.90259
# Epoch 24/500
# 84/84 [==============================] - 0s 119us/step - loss: 1092.6790 - mean_absolute_error: 1092.6790 - val_loss: 469.6880 - val_mean_absolute_error: 469.6880
#
# Epoch 00024: val_loss did not improve from 304.90259
# Epoch 25/500
# 84/84 [==============================] - 0s 119us/step - loss: 1088.0067 - mean_absolute_error: 1088.0067 - val_loss: 456.3346 - val_mean_absolute_error: 456.3346
#
# Epoch 00025: val_loss did not improve from 304.90259
# Epoch 26/500
# 84/84 [==============================] - 0s 142us/step - loss: 1086.3351 - mean_absolute_error: 1086.3351 - val_loss: 450.5480 - val_mean_absolute_error: 450.5480
#
# Epoch 00026: val_loss did not improve from 304.90259
# Epoch 27/500
# 84/84 [==============================] - 0s 107us/step - loss: 1084.4189 - mean_absolute_error: 1084.4189 - val_loss: 443.0603 - val_mean_absolute_error: 443.0603
#
# Epoch 00027: val_loss did not improve from 304.90259
# Epoch 28/500
# 84/84 [==============================] - 0s 131us/step - loss: 1082.3084 - mean_absolute_error: 1082.3084 - val_loss: 441.8316 - val_mean_absolute_error: 441.8316
#
# Epoch 00028: val_loss did not improve from 304.90259
# Epoch 29/500
# 84/84 [==============================] - 0s 131us/step - loss: 1080.9795 - mean_absolute_error: 1080.9795 - val_loss: 443.8508 - val_mean_absolute_error: 443.8508
#
# Epoch 00029: val_loss did not improve from 304.90259
# Epoch 30/500
# 84/84 [==============================] - 0s 154us/step - loss: 1081.0826 - mean_absolute_error: 1081.0826 - val_loss: 419.5641 - val_mean_absolute_error: 419.5641
#
# Epoch 00030: val_loss did not improve from 304.90259
# Epoch 31/500
# 84/84 [==============================] - 0s 107us/step - loss: 1079.0885 - mean_absolute_error: 1079.0885 - val_loss: 430.9236 - val_mean_absolute_error: 430.9236
#
# Epoch 00031: val_loss did not improve from 304.90259
# Epoch 32/500
# 84/84 [==============================] - 0s 95us/step - loss: 1075.9132 - mean_absolute_error: 1075.9132 - val_loss: 403.5660 - val_mean_absolute_error: 403.5660
#
# Epoch 00032: val_loss did not improve from 304.90259
# Epoch 33/500
# 84/84 [==============================] - 0s 95us/step - loss: 1073.3258 - mean_absolute_error: 1073.3258 - val_loss: 408.1581 - val_mean_absolute_error: 408.1581
#
# Epoch 00033: val_loss did not improve from 304.90259
# Epoch 34/500
# 84/84 [==============================] - 0s 119us/step - loss: 1072.8580 - mean_absolute_error: 1072.8580 - val_loss: 394.4715 - val_mean_absolute_error: 394.4715
#
# Epoch 00034: val_loss did not improve from 304.90259
# Epoch 35/500
# 84/84 [==============================] - 0s 154us/step - loss: 1067.2012 - mean_absolute_error: 1067.2012 - val_loss: 419.8724 - val_mean_absolute_error: 419.8724
#
# Epoch 00035: val_loss did not improve from 304.90259
# Epoch 36/500
# 84/84 [==============================] - 0s 107us/step - loss: 1065.5167 - mean_absolute_error: 1065.5167 - val_loss: 471.3936 - val_mean_absolute_error: 471.3936
#
# Epoch 00036: val_loss did not improve from 304.90259
# Epoch 37/500
# 84/84 [==============================] - 0s 107us/step - loss: 1062.2403 - mean_absolute_error: 1062.2403 - val_loss: 502.1100 - val_mean_absolute_error: 502.1100
#
# Epoch 00037: val_loss did not improve from 304.90259
# Epoch 38/500
# 84/84 [==============================] - 0s 119us/step - loss: 1058.2947 - mean_absolute_error: 1058.2947 - val_loss: 522.8013 - val_mean_absolute_error: 522.8013
#
# Epoch 00038: val_loss did not improve from 304.90259
# Epoch 39/500
# 84/84 [==============================] - 0s 95us/step - loss: 1051.3765 - mean_absolute_error: 1051.3765 - val_loss: 514.2626 - val_mean_absolute_error: 514.2626
#
# Epoch 00039: val_loss did not improve from 304.90259
# Epoch 40/500
# 84/84 [==============================] - 0s 119us/step - loss: 1049.0157 - mean_absolute_error: 1049.0157 - val_loss: 500.2571 - val_mean_absolute_error: 500.2571
#
# Epoch 00040: val_loss did not improve from 304.90259
# Epoch 41/500
# 84/84 [==============================] - 0s 107us/step - loss: 1050.6372 - mean_absolute_error: 1050.6372 - val_loss: 441.9016 - val_mean_absolute_error: 441.9016
#
# Epoch 00041: val_loss did not improve from 304.90259
# Epoch 42/500
# 84/84 [==============================] - 0s 107us/step - loss: 1038.7781 - mean_absolute_error: 1038.7781 - val_loss: 481.9182 - val_mean_absolute_error: 481.9182
#
# Epoch 00042: val_loss did not improve from 304.90259
# Epoch 43/500
# 84/84 [==============================] - 0s 107us/step - loss: 1028.7675 - mean_absolute_error: 1028.7675 - val_loss: 493.6783 - val_mean_absolute_error: 493.6783
#
# Epoch 00043: val_loss did not improve from 304.90259
# Epoch 44/500
# 84/84 [==============================] - 0s 107us/step - loss: 1019.6113 - mean_absolute_error: 1019.6113 - val_loss: 495.8097 - val_mean_absolute_error: 495.8097
#
# Epoch 00044: val_loss did not improve from 304.90259
# Epoch 45/500
# 84/84 [==============================] - 0s 107us/step - loss: 1012.2107 - mean_absolute_error: 1012.2107 - val_loss: 495.1817 - val_mean_absolute_error: 495.1817
#
# Epoch 00045: val_loss did not improve from 304.90259
# Epoch 46/500
# 84/84 [==============================] - 0s 95us/step - loss: 996.6745 - mean_absolute_error: 996.6745 - val_loss: 560.7979 - val_mean_absolute_error: 560.7979
#
# Epoch 00046: val_loss did not improve from 304.90259
# Epoch 47/500
# 84/84 [==============================] - 0s 119us/step - loss: 995.5447 - mean_absolute_error: 995.5447 - val_loss: 668.0944 - val_mean_absolute_error: 668.0944
#
# Epoch 00047: val_loss did not improve from 304.90259
# Epoch 48/500
# 84/84 [==============================] - 0s 142us/step - loss: 978.9111 - mean_absolute_error: 978.9111 - val_loss: 684.8890 - val_mean_absolute_error: 684.8890
#
# Epoch 00048: val_loss did not improve from 304.90259
# Epoch 49/500
# 84/84 [==============================] - 0s 95us/step - loss: 956.2360 - mean_absolute_error: 956.2360 - val_loss: 547.6703 - val_mean_absolute_error: 547.6703
#
# Epoch 00049: val_loss did not improve from 304.90259
# Epoch 50/500
# 84/84 [==============================] - 0s 145us/step - loss: 938.8659 - mean_absolute_error: 938.8659 - val_loss: 477.2797 - val_mean_absolute_error: 477.2797
#
# Epoch 00050: val_loss did not improve from 304.90259
# Epoch 51/500
# 84/84 [==============================] - 0s 142us/step - loss: 912.0868 - mean_absolute_error: 912.0868 - val_loss: 478.6133 - val_mean_absolute_error: 478.6133
#
# Epoch 00051: val_loss did not improve from 304.90259
# Epoch 52/500
# 84/84 [==============================] - 0s 107us/step - loss: 880.6466 - mean_absolute_error: 880.6466 - val_loss: 480.1146 - val_mean_absolute_error: 480.1146
#
# Epoch 00052: val_loss did not improve from 304.90259
# Epoch 53/500
# 84/84 [==============================] - 0s 107us/step - loss: 841.6571 - mean_absolute_error: 841.6571 - val_loss: 597.6951 - val_mean_absolute_error: 597.6951
#
# Epoch 00053: val_loss did not improve from 304.90259
# Epoch 54/500
# 84/84 [==============================] - 0s 142us/step - loss: 812.1525 - mean_absolute_error: 812.1525 - val_loss: 582.4211 - val_mean_absolute_error: 582.4211
#
# Epoch 00054: val_loss did not improve from 304.90259
# Epoch 55/500
# 84/84 [==============================] - 0s 142us/step - loss: 773.3989 - mean_absolute_error: 773.3989 - val_loss: 464.3227 - val_mean_absolute_error: 464.3227
#
# Epoch 00055: val_loss did not improve from 304.90259
# Epoch 56/500
# 84/84 [==============================] - 0s 119us/step - loss: 749.6420 - mean_absolute_error: 749.6420 - val_loss: 607.3202 - val_mean_absolute_error: 607.3202
#
# Epoch 00056: val_loss did not improve from 304.90259
# Epoch 57/500
# 84/84 [==============================] - 0s 119us/step - loss: 704.6726 - mean_absolute_error: 704.6726 - val_loss: 601.3310 - val_mean_absolute_error: 601.3310
#
# Epoch 00057: val_loss did not improve from 304.90259
# Epoch 58/500
# 84/84 [==============================] - 0s 107us/step - loss: 703.3611 - mean_absolute_error: 703.3611 - val_loss: 746.4055 - val_mean_absolute_error: 746.4055
#
# Epoch 00058: val_loss did not improve from 304.90259
# Epoch 59/500
# 84/84 [==============================] - 0s 149us/step - loss: 712.7822 - mean_absolute_error: 712.7822 - val_loss: 711.9892 - val_mean_absolute_error: 711.9892
#
# Epoch 00059: val_loss did not improve from 304.90259
# Epoch 60/500
# 84/84 [==============================] - 0s 131us/step - loss: 682.3606 - mean_absolute_error: 682.3606 - val_loss: 959.6246 - val_mean_absolute_error: 959.6246
#
# Epoch 00060: val_loss did not improve from 304.90259
# Epoch 61/500
# 84/84 [==============================] - 0s 119us/step - loss: 705.2246 - mean_absolute_error: 705.2246 - val_loss: 707.2457 - val_mean_absolute_error: 707.2457
#
# Epoch 00061: val_loss did not improve from 304.90259
# Epoch 62/500
# 84/84 [==============================] - 0s 107us/step - loss: 696.8563 - mean_absolute_error: 696.8563 - val_loss: 691.5585 - val_mean_absolute_error: 691.5585
#
# Epoch 00062: val_loss did not improve from 304.90259
# Epoch 63/500
# 84/84 [==============================] - 0s 107us/step - loss: 682.0067 - mean_absolute_error: 682.0067 - val_loss: 879.2639 - val_mean_absolute_error: 879.2639
#
# Epoch 00063: val_loss did not improve from 304.90259
# Epoch 64/500
# 84/84 [==============================] - 0s 131us/step - loss: 675.0088 - mean_absolute_error: 675.0088 - val_loss: 701.8273 - val_mean_absolute_error: 701.8273
#
# Epoch 00064: val_loss did not improve from 304.90259
# Epoch 65/500
# 84/84 [==============================] - 0s 142us/step - loss: 681.9723 - mean_absolute_error: 681.9723 - val_loss: 618.4192 - val_mean_absolute_error: 618.4192
#
# Epoch 00065: val_loss did not improve from 304.90259
# Epoch 66/500
# 84/84 [==============================] - 0s 119us/step - loss: 665.2780 - mean_absolute_error: 665.2780 - val_loss: 762.6176 - val_mean_absolute_error: 762.6176
#
# Epoch 00066: val_loss did not improve from 304.90259
# Epoch 67/500
# 84/84 [==============================] - 0s 184us/step - loss: 652.6810 - mean_absolute_error: 652.6810 - val_loss: 766.9278 - val_mean_absolute_error: 766.9278
#
# Epoch 00067: val_loss did not improve from 304.90259
# Epoch 68/500
# 84/84 [==============================] - 0s 131us/step - loss: 646.0588 - mean_absolute_error: 646.0588 - val_loss: 712.2839 - val_mean_absolute_error: 712.2839
#
# Epoch 00068: val_loss did not improve from 304.90259
# Epoch 69/500
# 84/84 [==============================] - 0s 107us/step - loss: 643.4932 - mean_absolute_error: 643.4932 - val_loss: 730.7529 - val_mean_absolute_error: 730.7529
#
# Epoch 00069: val_loss did not improve from 304.90259
# Epoch 70/500
# 84/84 [==============================] - 0s 95us/step - loss: 634.1876 - mean_absolute_error: 634.1876 - val_loss: 786.8737 - val_mean_absolute_error: 786.8737
#
# Epoch 00070: val_loss did not improve from 304.90259
# Epoch 71/500
# 84/84 [==============================] - 0s 131us/step - loss: 635.6459 - mean_absolute_error: 635.6459 - val_loss: 708.0435 - val_mean_absolute_error: 708.0435
#
# Epoch 00071: val_loss did not improve from 304.90259
# Epoch 72/500
# 84/84 [==============================] - 0s 154us/step - loss: 641.4085 - mean_absolute_error: 641.4085 - val_loss: 677.6995 - val_mean_absolute_error: 677.6995
#
# Epoch 00072: val_loss did not improve from 304.90259
# Epoch 73/500
# 84/84 [==============================] - 0s 95us/step - loss: 627.2559 - mean_absolute_error: 627.2559 - val_loss: 893.9863 - val_mean_absolute_error: 893.9863
#
# Epoch 00073: val_loss did not improve from 304.90259
# Epoch 74/500
# 84/84 [==============================] - 0s 131us/step - loss: 659.2812 - mean_absolute_error: 659.2812 - val_loss: 623.5474 - val_mean_absolute_error: 623.5474
#
# Epoch 00074: val_loss did not improve from 304.90259
# Epoch 75/500
# 84/84 [==============================] - 0s 119us/step - loss: 643.7700 - mean_absolute_error: 643.7700 - val_loss: 613.9042 - val_mean_absolute_error: 613.9042
#
# Epoch 00075: val_loss did not improve from 304.90259
# Epoch 76/500
# 84/84 [==============================] - 0s 154us/step - loss: 592.3329 - mean_absolute_error: 592.3329 - val_loss: 829.9567 - val_mean_absolute_error: 829.9567
#
# Epoch 00076: val_loss did not improve from 304.90259
# Epoch 77/500
# 84/84 [==============================] - 0s 131us/step - loss: 646.2652 - mean_absolute_error: 646.2652 - val_loss: 728.7040 - val_mean_absolute_error: 728.7040
#
# Epoch 00077: val_loss did not improve from 304.90259
# Epoch 78/500
# 84/84 [==============================] - 0s 131us/step - loss: 575.0782 - mean_absolute_error: 575.0782 - val_loss: 505.1523 - val_mean_absolute_error: 505.1523
#
# Epoch 00078: val_loss did not improve from 304.90259
# Epoch 79/500
# 84/84 [==============================] - 0s 107us/step - loss: 659.0866 - mean_absolute_error: 659.0866 - val_loss: 578.0893 - val_mean_absolute_error: 578.0893
#
# Epoch 00079: val_loss did not improve from 304.90259
# Epoch 80/500
# 84/84 [==============================] - 0s 131us/step - loss: 574.6156 - mean_absolute_error: 574.6156 - val_loss: 869.8856 - val_mean_absolute_error: 869.8856
#
# Epoch 00080: val_loss did not improve from 304.90259
# Epoch 81/500
# 84/84 [==============================] - 0s 131us/step - loss: 642.6996 - mean_absolute_error: 642.6996 - val_loss: 683.0393 - val_mean_absolute_error: 683.0393
#
# Epoch 00081: val_loss did not improve from 304.90259
# Epoch 82/500
# 84/84 [==============================] - 0s 119us/step - loss: 582.6962 - mean_absolute_error: 582.6962 - val_loss: 473.8653 - val_mean_absolute_error: 473.8653
#
# Epoch 00082: val_loss did not improve from 304.90259
# Epoch 83/500
# 84/84 [==============================] - 0s 119us/step - loss: 627.1234 - mean_absolute_error: 627.1234 - val_loss: 644.0396 - val_mean_absolute_error: 644.0396
#
# Epoch 00083: val_loss did not improve from 304.90259
# Epoch 84/500
# 84/84 [==============================] - 0s 119us/step - loss: 580.4449 - mean_absolute_error: 580.4449 - val_loss: 807.5366 - val_mean_absolute_error: 807.5366
#
# Epoch 00084: val_loss did not improve from 304.90259
# Epoch 85/500
# 84/84 [==============================] - 0s 119us/step - loss: 596.9217 - mean_absolute_error: 596.9217 - val_loss: 559.8355 - val_mean_absolute_error: 559.8355
#
# Epoch 00085: val_loss did not improve from 304.90259
# Epoch 86/500
# 84/84 [==============================] - 0s 119us/step - loss: 584.1216 - mean_absolute_error: 584.1216 - val_loss: 509.9540 - val_mean_absolute_error: 509.9540
#
# Epoch 00086: val_loss did not improve from 304.90259
# Epoch 87/500
# 84/84 [==============================] - 0s 119us/step - loss: 587.0968 - mean_absolute_error: 587.0968 - val_loss: 707.9081 - val_mean_absolute_error: 707.9081
#
# Epoch 00087: val_loss did not improve from 304.90259
# Epoch 88/500
# 84/84 [==============================] - 0s 95us/step - loss: 576.1150 - mean_absolute_error: 576.1150 - val_loss: 676.7408 - val_mean_absolute_error: 676.7408
#
# Epoch 00088: val_loss did not improve from 304.90259
# Epoch 89/500
# 84/84 [==============================] - 0s 142us/step - loss: 575.6693 - mean_absolute_error: 575.6693 - val_loss: 527.9987 - val_mean_absolute_error: 527.9987
#
# Epoch 00089: val_loss did not improve from 304.90259
# Epoch 90/500
# 84/84 [==============================] - 0s 131us/step - loss: 578.4386 - mean_absolute_error: 578.4386 - val_loss: 698.6870 - val_mean_absolute_error: 698.6870
#
# Epoch 00090: val_loss did not improve from 304.90259
# Epoch 91/500
# 84/84 [==============================] - 0s 131us/step - loss: 567.0829 - mean_absolute_error: 567.0829 - val_loss: 656.0012 - val_mean_absolute_error: 656.0012
#
# Epoch 00091: val_loss did not improve from 304.90259
# Epoch 92/500
# 84/84 [==============================] - 0s 107us/step - loss: 557.9741 - mean_absolute_error: 557.9741 - val_loss: 543.1050 - val_mean_absolute_error: 543.1050
#
# Epoch 00092: val_loss did not improve from 304.90259
# Epoch 93/500
# 84/84 [==============================] - 0s 131us/step - loss: 565.7291 - mean_absolute_error: 565.7291 - val_loss: 666.9792 - val_mean_absolute_error: 666.9792
#
# Epoch 00093: val_loss did not improve from 304.90259
# Epoch 94/500
# 84/84 [==============================] - 0s 154us/step - loss: 570.9617 - mean_absolute_error: 570.9617 - val_loss: 722.9982 - val_mean_absolute_error: 722.9982
#
# Epoch 00094: val_loss did not improve from 304.90259
# Epoch 95/500
# 84/84 [==============================] - 0s 166us/step - loss: 584.5355 - mean_absolute_error: 584.5355 - val_loss: 521.7977 - val_mean_absolute_error: 521.7977
#
# Epoch 00095: val_loss did not improve from 304.90259
# Epoch 96/500
# 84/84 [==============================] - 0s 95us/step - loss: 556.6338 - mean_absolute_error: 556.6338 - val_loss: 635.6588 - val_mean_absolute_error: 635.6588
#
# Epoch 00096: val_loss did not improve from 304.90259
# Epoch 97/500
# 84/84 [==============================] - 0s 119us/step - loss: 544.2018 - mean_absolute_error: 544.2018 - val_loss: 587.0231 - val_mean_absolute_error: 587.0231
#
# Epoch 00097: val_loss did not improve from 304.90259
# Epoch 98/500
# 84/84 [==============================] - 0s 142us/step - loss: 540.7449 - mean_absolute_error: 540.7449 - val_loss: 593.0462 - val_mean_absolute_error: 593.0462
#
# Epoch 00098: val_loss did not improve from 304.90259
# Epoch 99/500
# 84/84 [==============================] - 0s 142us/step - loss: 536.6695 - mean_absolute_error: 536.6695 - val_loss: 540.8045 - val_mean_absolute_error: 540.8045
#
# Epoch 00099: val_loss did not improve from 304.90259
# Epoch 100/500
# 84/84 [==============================] - 0s 107us/step - loss: 536.7219 - mean_absolute_error: 536.7219 - val_loss: 588.0629 - val_mean_absolute_error: 588.0629
#
# Epoch 00100: val_loss did not improve from 304.90259
# Epoch 101/500
# 84/84 [==============================] - 0s 107us/step - loss: 528.4514 - mean_absolute_error: 528.4514 - val_loss: 537.7190 - val_mean_absolute_error: 537.7190
#
# Epoch 00101: val_loss did not improve from 304.90259
# Epoch 102/500
# 84/84 [==============================] - 0s 131us/step - loss: 529.1903 - mean_absolute_error: 529.1903 - val_loss: 588.1818 - val_mean_absolute_error: 588.1818
#
# Epoch 00102: val_loss did not improve from 304.90259
# Epoch 103/500
# 84/84 [==============================] - 0s 154us/step - loss: 539.5985 - mean_absolute_error: 539.5985 - val_loss: 591.9088 - val_mean_absolute_error: 591.9088
#
# Epoch 00103: val_loss did not improve from 304.90259
# Epoch 104/500
# 84/84 [==============================] - 0s 119us/step - loss: 544.0587 - mean_absolute_error: 544.0587 - val_loss: 499.0215 - val_mean_absolute_error: 499.0215
#
# Epoch 00104: val_loss did not improve from 304.90259
# Epoch 105/500
# 84/84 [==============================] - 0s 142us/step - loss: 543.8345 - mean_absolute_error: 543.8345 - val_loss: 602.4048 - val_mean_absolute_error: 602.4048
#
# Epoch 00105: val_loss did not improve from 304.90259
# Epoch 106/500
# 84/84 [==============================] - 0s 131us/step - loss: 521.0020 - mean_absolute_error: 521.0020 - val_loss: 556.7971 - val_mean_absolute_error: 556.7971
#
# Epoch 00106: val_loss did not improve from 304.90259
# Epoch 107/500
# 84/84 [==============================] - 0s 142us/step - loss: 517.8310 - mean_absolute_error: 517.8310 - val_loss: 597.5770 - val_mean_absolute_error: 597.5770
#
# Epoch 00107: val_loss did not improve from 304.90259
# Epoch 108/500
# 84/84 [==============================] - 0s 107us/step - loss: 514.3652 - mean_absolute_error: 514.3652 - val_loss: 490.6444 - val_mean_absolute_error: 490.6444
#
# Epoch 00108: val_loss did not improve from 304.90259
# Epoch 109/500
# 84/84 [==============================] - 0s 95us/step - loss: 531.4342 - mean_absolute_error: 531.4342 - val_loss: 509.5783 - val_mean_absolute_error: 509.5783
#
# Epoch 00109: val_loss did not improve from 304.90259
# Epoch 110/500
# 84/84 [==============================] - 0s 119us/step - loss: 534.5017 - mean_absolute_error: 534.5017 - val_loss: 587.7996 - val_mean_absolute_error: 587.7996
#
# Epoch 00110: val_loss did not improve from 304.90259
# Epoch 111/500
# 84/84 [==============================] - 0s 166us/step - loss: 508.5255 - mean_absolute_error: 508.5255 - val_loss: 432.0104 - val_mean_absolute_error: 432.0104
#
# Epoch 00111: val_loss did not improve from 304.90259
# Epoch 112/500
# 84/84 [==============================] - 0s 131us/step - loss: 538.7514 - mean_absolute_error: 538.7514 - val_loss: 452.0058 - val_mean_absolute_error: 452.0058
#
# Epoch 00112: val_loss did not improve from 304.90259
# Epoch 113/500
# 84/84 [==============================] - 0s 142us/step - loss: 521.8015 - mean_absolute_error: 521.8015 - val_loss: 584.3445 - val_mean_absolute_error: 584.3445
#
# Epoch 00113: val_loss did not improve from 304.90259
# Epoch 114/500
# 84/84 [==============================] - 0s 166us/step - loss: 516.6602 - mean_absolute_error: 516.6602 - val_loss: 500.6873 - val_mean_absolute_error: 500.6873
#
# Epoch 00114: val_loss did not improve from 304.90259
# Epoch 115/500
# 84/84 [==============================] - 0s 142us/step - loss: 524.7699 - mean_absolute_error: 524.7699 - val_loss: 468.3081 - val_mean_absolute_error: 468.3081
#
# Epoch 00115: val_loss did not improve from 304.90259
# Epoch 116/500
# 84/84 [==============================] - 0s 107us/step - loss: 523.4110 - mean_absolute_error: 523.4110 - val_loss: 579.0958 - val_mean_absolute_error: 579.0958
#
# Epoch 00116: val_loss did not improve from 304.90259
# Epoch 117/500
# 84/84 [==============================] - 0s 131us/step - loss: 506.7515 - mean_absolute_error: 506.7515 - val_loss: 397.3708 - val_mean_absolute_error: 397.3708
#
# Epoch 00117: val_loss did not improve from 304.90259
# Epoch 118/500
# 84/84 [==============================] - 0s 119us/step - loss: 528.0156 - mean_absolute_error: 528.0156 - val_loss: 452.5536 - val_mean_absolute_error: 452.5536
#
# Epoch 00118: val_loss did not improve from 304.90259
# Epoch 119/500
# 84/84 [==============================] - 0s 95us/step - loss: 501.1808 - mean_absolute_error: 501.1808 - val_loss: 550.0695 - val_mean_absolute_error: 550.0695
#
# Epoch 00119: val_loss did not improve from 304.90259
# Epoch 120/500
# 84/84 [==============================] - 0s 107us/step - loss: 516.2048 - mean_absolute_error: 516.2048 - val_loss: 502.0581 - val_mean_absolute_error: 502.0581
#
# Epoch 00120: val_loss did not improve from 304.90259
# Epoch 121/500
# 84/84 [==============================] - 0s 131us/step - loss: 514.2513 - mean_absolute_error: 514.2513 - val_loss: 446.4228 - val_mean_absolute_error: 446.4228
#
# Epoch 00121: val_loss did not improve from 304.90259
# Epoch 122/500
# 84/84 [==============================] - 0s 131us/step - loss: 508.1585 - mean_absolute_error: 508.1585 - val_loss: 598.7237 - val_mean_absolute_error: 598.7237
#
# Epoch 00122: val_loss did not improve from 304.90259
# Epoch 123/500
# 84/84 [==============================] - 0s 142us/step - loss: 517.2207 - mean_absolute_error: 517.2207 - val_loss: 434.3784 - val_mean_absolute_error: 434.3784
#
# Epoch 00123: val_loss did not improve from 304.90259
# Epoch 124/500
# 84/84 [==============================] - 0s 142us/step - loss: 522.3897 - mean_absolute_error: 522.3897 - val_loss: 451.5791 - val_mean_absolute_error: 451.5791
#
# Epoch 00124: val_loss did not improve from 304.90259
# Epoch 125/500
# 84/84 [==============================] - 0s 131us/step - loss: 494.1189 - mean_absolute_error: 494.1189 - val_loss: 530.2762 - val_mean_absolute_error: 530.2762
#
# Epoch 00125: val_loss did not improve from 304.90259
# Epoch 126/500
# 84/84 [==============================] - 0s 142us/step - loss: 512.9945 - mean_absolute_error: 512.9945 - val_loss: 465.9370 - val_mean_absolute_error: 465.9370
#
# Epoch 00126: val_loss did not improve from 304.90259
# Epoch 127/500
# 84/84 [==============================] - 0s 131us/step - loss: 538.6917 - mean_absolute_error: 538.6917 - val_loss: 370.8983 - val_mean_absolute_error: 370.8983
#
# Epoch 00127: val_loss did not improve from 304.90259
# Epoch 128/500
# 84/84 [==============================] - 0s 131us/step - loss: 504.4924 - mean_absolute_error: 504.4924 - val_loss: 587.9122 - val_mean_absolute_error: 587.9122
#
# Epoch 00128: val_loss did not improve from 304.90259
# Epoch 129/500
# 84/84 [==============================] - 0s 119us/step - loss: 546.9833 - mean_absolute_error: 546.9833 - val_loss: 487.5569 - val_mean_absolute_error: 487.5569
#
# Epoch 00129: val_loss did not improve from 304.90259
# Epoch 130/500
# 84/84 [==============================] - 0s 119us/step - loss: 506.0873 - mean_absolute_error: 506.0873 - val_loss: 357.2621 - val_mean_absolute_error: 357.2621
#
# Epoch 00130: val_loss did not improve from 304.90259
# Epoch 131/500
# 84/84 [==============================] - 0s 131us/step - loss: 546.1617 - mean_absolute_error: 546.1617 - val_loss: 531.5922 - val_mean_absolute_error: 531.5922
#
# Epoch 00131: val_loss did not improve from 304.90259
# Epoch 132/500
# 84/84 [==============================] - 0s 107us/step - loss: 501.7740 - mean_absolute_error: 501.7740 - val_loss: 420.5691 - val_mean_absolute_error: 420.5691
#
# Epoch 00132: val_loss did not improve from 304.90259
# Epoch 133/500
# 84/84 [==============================] - 0s 154us/step - loss: 501.8449 - mean_absolute_error: 501.8449 - val_loss: 407.4095 - val_mean_absolute_error: 407.4095
#
# Epoch 00133: val_loss did not improve from 304.90259
# Epoch 134/500
# 84/84 [==============================] - 0s 131us/step - loss: 493.6191 - mean_absolute_error: 493.6191 - val_loss: 537.2750 - val_mean_absolute_error: 537.2750
#
# Epoch 00134: val_loss did not improve from 304.90259
# Epoch 135/500
# 84/84 [==============================] - 0s 131us/step - loss: 515.3355 - mean_absolute_error: 515.3355 - val_loss: 469.2523 - val_mean_absolute_error: 469.2523
#
# Epoch 00135: val_loss did not improve from 304.90259
# Epoch 136/500
# 84/84 [==============================] - 0s 95us/step - loss: 494.0905 - mean_absolute_error: 494.0905 - val_loss: 489.9724 - val_mean_absolute_error: 489.9724
#
# Epoch 00136: val_loss did not improve from 304.90259
# Epoch 137/500
# 84/84 [==============================] - 0s 110us/step - loss: 546.1336 - mean_absolute_error: 546.1336 - val_loss: 490.6023 - val_mean_absolute_error: 490.6023
#
# Epoch 00137: val_loss did not improve from 304.90259
# Epoch 138/500
# 84/84 [==============================] - ETA: 0s - loss: 419.0677 - mean_absolute_error: 419.067 - 0s 142us/step - loss: 533.5709 - mean_absolute_error: 533.5709 - val_loss: 362.5033 - val_mean_absolute_error: 362.5033
#
# Epoch 00138: val_loss did not improve from 304.90259
# Epoch 139/500
# 84/84 [==============================] - 0s 166us/step - loss: 493.3307 - mean_absolute_error: 493.3307 - val_loss: 600.4940 - val_mean_absolute_error: 600.4940
#
# Epoch 00139: val_loss did not improve from 304.90259
# Epoch 140/500
# 84/84 [==============================] - 0s 154us/step - loss: 558.3981 - mean_absolute_error: 558.3981 - val_loss: 522.6284 - val_mean_absolute_error: 522.6284
#
# Epoch 00140: val_loss did not improve from 304.90259
# Epoch 141/500
# 84/84 [==============================] - 0s 142us/step - loss: 538.9391 - mean_absolute_error: 538.9391 - val_loss: 361.3701 - val_mean_absolute_error: 361.3701
#
# Epoch 00141: val_loss did not improve from 304.90259
# Epoch 142/500
# 84/84 [==============================] - 0s 131us/step - loss: 503.8192 - mean_absolute_error: 503.8192 - val_loss: 618.7156 - val_mean_absolute_error: 618.7156
# Epoch 00142: val_loss did not improve from 304.90259
# Epoch 143/500
# 84/84 [==============================] - 0s 107us/step - loss: 577.4148 - mean_absolute_error: 577.4148 - val_loss: 444.4885 - val_mean_absolute_error: 444.4885
#
# Epoch 00143: val_loss did not improve from 304.90259
# Epoch 144/500
# 84/84 [==============================] - 0s 107us/step - loss: 562.4715 - mean_absolute_error: 562.4715 - val_loss: 334.3602 - val_mean_absolute_error: 334.3602
#
# Epoch 00144: val_loss did not improve from 304.90259
# Epoch 145/500
# 84/84 [==============================] - 0s 107us/step - loss: 520.5130 - mean_absolute_error: 520.5130 - val_loss: 595.5611 - val_mean_absolute_error: 595.5611
#
# Epoch 00145: val_loss did not improve from 304.90259
# Epoch 146/500
# 84/84 [==============================] - 0s 107us/step - loss: 601.3341 - mean_absolute_error: 601.3341 - val_loss: 539.5718 - val_mean_absolute_error: 539.5718
#
# Epoch 00146: val_loss did not improve from 304.90259
# Epoch 147/500
# 84/84 [==============================] - 0s 142us/step - loss: 528.1569 - mean_absolute_error: 528.1569 - val_loss: 327.0148 - val_mean_absolute_error: 327.0148
#
# Epoch 00147: val_loss did not improve from 304.90259
# Epoch 148/500
# 84/84 [==============================] - 0s 95us/step - loss: 590.1300 - mean_absolute_error: 590.1300 - val_loss: 362.7946 - val_mean_absolute_error: 362.7946
#
# Epoch 00148: val_loss did not improve from 304.90259
# Epoch 149/500
# 84/84 [==============================] - 0s 95us/step - loss: 518.1153 - mean_absolute_error: 518.1153 - val_loss: 654.3188 - val_mean_absolute_error: 654.3188
#
# Epoch 00149: val_loss did not improve from 304.90259
# Epoch 150/500
# 84/84 [==============================] - 0s 131us/step - loss: 552.3155 - mean_absolute_error: 552.3155 - val_loss: 428.8958 - val_mean_absolute_error: 428.8958
#
# Epoch 00150: val_loss did not improve from 304.90259
# Epoch 151/500
# 84/84 [==============================] - 0s 154us/step - loss: 506.1446 - mean_absolute_error: 506.1446 - val_loss: 349.0225 - val_mean_absolute_error: 349.0225
#
# Epoch 00151: val_loss did not improve from 304.90259
# Epoch 152/500
# 84/84 [==============================] - 0s 142us/step - loss: 557.5498 - mean_absolute_error: 557.5498 - val_loss: 451.8035 - val_mean_absolute_error: 451.8035
#
# Epoch 00152: val_loss did not improve from 304.90259
# Epoch 153/500
# 84/84 [==============================] - 0s 154us/step - loss: 499.3118 - mean_absolute_error: 499.3118 - val_loss: 546.2501 - val_mean_absolute_error: 546.2501
#
# Epoch 00153: val_loss did not improve from 304.90259
# Epoch 154/500
# 84/84 [==============================] - 0s 131us/step - loss: 497.4081 - mean_absolute_error: 497.4081 - val_loss: 437.9949 - val_mean_absolute_error: 437.9949
#
# Epoch 00154: val_loss did not improve from 304.90259
# Epoch 155/500
# 84/84 [==============================] - 0s 119us/step - loss: 492.4820 - mean_absolute_error: 492.4820 - val_loss: 407.2429 - val_mean_absolute_error: 407.2429
#
# Epoch 00155: val_loss did not improve from 304.90259
# Epoch 156/500
# 84/84 [==============================] - 0s 107us/step - loss: 494.2295 - mean_absolute_error: 494.2295 - val_loss: 451.3690 - val_mean_absolute_error: 451.3690
#
# Epoch 00156: val_loss did not improve from 304.90259
# Epoch 157/500
# 84/84 [==============================] - 0s 142us/step - loss: 498.2657 - mean_absolute_error: 498.2657 - val_loss: 440.2225 - val_mean_absolute_error: 440.2225
#
# Epoch 00157: val_loss did not improve from 304.90259
# Epoch 158/500
# 84/84 [==============================] - 0s 142us/step - loss: 490.0597 - mean_absolute_error: 490.0597 - val_loss: 346.2186 - val_mean_absolute_error: 346.2186
#
# Epoch 00158: val_loss did not improve from 304.90259
# Epoch 159/500
# 84/84 [==============================] - 0s 119us/step - loss: 496.2937 - mean_absolute_error: 496.2937 - val_loss: 393.3695 - val_mean_absolute_error: 393.3695
#
# Epoch 00159: val_loss did not improve from 304.90259
# Epoch 160/500
# 84/84 [==============================] - 0s 131us/step - loss: 489.1910 - mean_absolute_error: 489.1910 - val_loss: 454.5221 - val_mean_absolute_error: 454.5221
#
# Epoch 00160: val_loss did not improve from 304.90259
# Epoch 161/500
# 84/84 [==============================] - 0s 119us/step - loss: 491.1244 - mean_absolute_error: 491.1244 - val_loss: 414.5618 - val_mean_absolute_error: 414.5618
#
# Epoch 00161: val_loss did not improve from 304.90259
# Epoch 162/500
# 84/84 [==============================] - 0s 119us/step - loss: 483.8873 - mean_absolute_error: 483.8873 - val_loss: 355.8429 - val_mean_absolute_error: 355.8429
#
# Epoch 00162: val_loss did not improve from 304.90259
# Epoch 163/500
# 84/84 [==============================] - 0s 142us/step - loss: 491.4470 - mean_absolute_error: 491.4470 - val_loss: 378.1763 - val_mean_absolute_error: 378.1763
#
# Epoch 00163: val_loss did not improve from 304.90259
# Epoch 164/500
# 84/84 [==============================] - 0s 131us/step - loss: 494.0829 - mean_absolute_error: 494.0829 - val_loss: 431.5035 - val_mean_absolute_error: 431.5035
#
# Epoch 00164: val_loss did not improve from 304.90259
# Epoch 165/500
# 84/84 [==============================] - 0s 119us/step - loss: 491.5056 - mean_absolute_error: 491.5056 - val_loss: 433.0052 - val_mean_absolute_error: 433.0052
#
# Epoch 00165: val_loss did not improve from 304.90259
# Epoch 166/500
# 84/84 [==============================] - 0s 131us/step - loss: 494.0217 - mean_absolute_error: 494.0217 - val_loss: 365.1389 - val_mean_absolute_error: 365.1389
#
# Epoch 00166: val_loss did not improve from 304.90259
# Epoch 167/500
# 84/84 [==============================] - 0s 131us/step - loss: 494.4742 - mean_absolute_error: 494.4742 - val_loss: 405.6690 - val_mean_absolute_error: 405.6690
#
# Epoch 00167: val_loss did not improve from 304.90259
# Epoch 168/500
# 84/84 [==============================] - 0s 154us/step - loss: 489.2019 - mean_absolute_error: 489.2019 - val_loss: 380.2883 - val_mean_absolute_error: 380.2883
#
# Epoch 00168: val_loss did not improve from 304.90259
# Epoch 169/500
# 84/84 [==============================] - 0s 95us/step - loss: 484.0194 - mean_absolute_error: 484.0194 - val_loss: 426.8495 - val_mean_absolute_error: 426.8495
#
# Epoch 00169: val_loss did not improve from 304.90259
# Epoch 170/500
# 84/84 [==============================] - 0s 142us/step - loss: 487.0692 - mean_absolute_error: 487.0692 - val_loss: 407.9670 - val_mean_absolute_error: 407.9670
#
# Epoch 00170: val_loss did not improve from 304.90259
# Epoch 171/500
# 84/84 [==============================] - 0s 149us/step - loss: 495.9444 - mean_absolute_error: 495.9444 - val_loss: 351.6421 - val_mean_absolute_error: 351.6421
#
# Epoch 00171: val_loss did not improve from 304.90259
# Epoch 172/500
# 84/84 [==============================] - 0s 142us/step - loss: 485.5582 - mean_absolute_error: 485.5582 - val_loss: 455.3541 - val_mean_absolute_error: 455.3541
#
# Epoch 00172: val_loss did not improve from 304.90259
# Epoch 173/500
# 84/84 [==============================] - 0s 131us/step - loss: 492.3782 - mean_absolute_error: 492.3782 - val_loss: 414.9530 - val_mean_absolute_error: 414.9530
#
# Epoch 00173: val_loss did not improve from 304.90259
# Epoch 174/500
# 84/84 [==============================] - 0s 131us/step - loss: 488.8581 - mean_absolute_error: 488.8581 - val_loss: 395.9300 - val_mean_absolute_error: 395.9300
#
# Epoch 00174: val_loss did not improve from 304.90259
# Epoch 175/500
# 84/84 [==============================] - 0s 131us/step - loss: 483.0886 - mean_absolute_error: 483.0886 - val_loss: 407.2770 - val_mean_absolute_error: 407.2770
#
# Epoch 00175: val_loss did not improve from 304.90259
# Epoch 176/500
# 84/84 [==============================] - 0s 95us/step - loss: 479.7055 - mean_absolute_error: 479.7055 - val_loss: 459.8324 - val_mean_absolute_error: 459.8324
#
# Epoch 00176: val_loss did not improve from 304.90259
# Epoch 177/500
# 84/84 [==============================] - 0s 119us/step - loss: 488.7695 - mean_absolute_error: 488.7695 - val_loss: 387.4213 - val_mean_absolute_error: 387.4213
#
# Epoch 00177: val_loss did not improve from 304.90259
# Epoch 178/500
# 84/84 [==============================] - 0s 107us/step - loss: 484.8396 - mean_absolute_error: 484.8396 - val_loss: 343.4358 - val_mean_absolute_error: 343.4358
# Epoch 00178: val_loss did not improve from 304.90259
# Epoch 179/500
# 84/84 [==============================] - 0s 142us/step - loss: 530.5354 - mean_absolute_error: 530.5354 - val_loss: 488.8153 - val_mean_absolute_error: 488.8153
#
# Epoch 00179: val_loss did not improve from 304.90259
# Epoch 180/500
# 84/84 [==============================] - 0s 154us/step - loss: 487.1186 - mean_absolute_error: 487.1186 - val_loss: 385.5185 - val_mean_absolute_error: 385.5185
#
# Epoch 00180: val_loss did not improve from 304.90259
# Epoch 181/500
# 84/84 [==============================] - 0s 131us/step - loss: 481.2277 - mean_absolute_error: 481.2277 - val_loss: 349.1510 - val_mean_absolute_error: 349.1510
#
# Epoch 00181: val_loss did not improve from 304.90259
# Epoch 182/500
# 84/84 [==============================] - 0s 142us/step - loss: 485.8340 - mean_absolute_error: 485.8340 - val_loss: 358.8733 - val_mean_absolute_error: 358.8733
#
# Epoch 00182: val_loss did not improve from 304.90259
# Epoch 183/500
# 84/84 [==============================] - 0s 119us/step - loss: 489.3686 - mean_absolute_error: 489.3686 - val_loss: 310.8351 - val_mean_absolute_error: 310.8351
#
# Epoch 00183: val_loss did not improve from 304.90259
# Epoch 184/500
# 84/84 [==============================] - 0s 142us/step - loss: 482.2339 - mean_absolute_error: 482.2339 - val_loss: 408.5573 - val_mean_absolute_error: 408.5573
#
# Epoch 00184: val_loss did not improve from 304.90259
# Epoch 185/500
# 84/84 [==============================] - 0s 131us/step - loss: 482.7999 - mean_absolute_error: 482.7999 - val_loss: 355.4925 - val_mean_absolute_error: 355.4925
#
# Epoch 00185: val_loss did not improve from 304.90259
# Epoch 186/500
# 84/84 [==============================] - 0s 142us/step - loss: 500.7845 - mean_absolute_error: 500.7845 - val_loss: 326.0074 - val_mean_absolute_error: 326.0074
#
# Epoch 00186: val_loss did not improve from 304.90259
# Epoch 187/500
# 84/84 [==============================] - 0s 131us/step - loss: 473.8055 - mean_absolute_error: 473.8055 - val_loss: 424.1874 - val_mean_absolute_error: 424.1874
#
# Epoch 00187: val_loss did not improve from 304.90259
# Epoch 188/500
# 84/84 [==============================] - 0s 157us/step - loss: 492.9212 - mean_absolute_error: 492.9212 - val_loss: 435.6683 - val_mean_absolute_error: 435.6683
#
# Epoch 00188: val_loss did not improve from 304.90259
# Epoch 189/500
# 84/84 [==============================] - 0s 119us/step - loss: 507.1501 - mean_absolute_error: 507.1501 - val_loss: 323.1145 - val_mean_absolute_error: 323.1145
#
# Epoch 00189: val_loss did not improve from 304.90259
# Epoch 190/500
# 84/84 [==============================] - 0s 131us/step - loss: 471.6079 - mean_absolute_error: 471.6079 - val_loss: 428.8863 - val_mean_absolute_error: 428.8863
#
# Epoch 00190: val_loss did not improve from 304.90259
# Epoch 191/500
# 84/84 [==============================] - 0s 131us/step - loss: 491.3996 - mean_absolute_error: 491.3996 - val_loss: 380.3235 - val_mean_absolute_error: 380.3235
#
# Epoch 00191: val_loss did not improve from 304.90259
# Epoch 192/500
# 84/84 [==============================] - 0s 131us/step - loss: 478.5967 - mean_absolute_error: 478.5967 - val_loss: 320.3772 - val_mean_absolute_error: 320.3772
#
# Epoch 00192: val_loss did not improve from 304.90259
# Epoch 193/500
# 84/84 [==============================] - 0s 131us/step - loss: 482.7114 - mean_absolute_error: 482.7114 - val_loss: 348.4482 - val_mean_absolute_error: 348.4482
#
# Epoch 00193: val_loss did not improve from 304.90259
# Epoch 194/500
# 84/84 [==============================] - 0s 131us/step - loss: 486.7404 - mean_absolute_error: 486.7404 - val_loss: 375.1812 - val_mean_absolute_error: 375.1812
#
# Epoch 00194: val_loss did not improve from 304.90259
# Epoch 195/500
# 84/84 [==============================] - 0s 119us/step - loss: 487.5015 - mean_absolute_error: 487.5015 - val_loss: 341.2603 - val_mean_absolute_error: 341.2603
#
# Epoch 00195: val_loss did not improve from 304.90259
# Epoch 196/500
# 84/84 [==============================] - 0s 113us/step - loss: 472.1385 - mean_absolute_error: 472.1385 - val_loss: 434.4827 - val_mean_absolute_error: 434.4827
#
# Epoch 00196: val_loss did not improve from 304.90259
# Epoch 197/500
# 84/84 [==============================] - 0s 214us/step - loss: 481.9556 - mean_absolute_error: 481.9556 - val_loss: 395.8154 - val_mean_absolute_error: 395.8154
#
# Epoch 00197: val_loss did not improve from 304.90259
# Epoch 198/500
# 84/84 [==============================] - 0s 226us/step - loss: 471.0791 - mean_absolute_error: 471.0791 - val_loss: 366.0105 - val_mean_absolute_error: 366.0105
#
# Epoch 00198: val_loss did not improve from 304.90259
# Epoch 199/500
# 84/84 [==============================] - 0s 131us/step - loss: 468.8952 - mean_absolute_error: 468.8952 - val_loss: 381.4380 - val_mean_absolute_error: 381.4380
#
# Epoch 00199: val_loss did not improve from 304.90259
# Epoch 200/500
# 84/84 [==============================] - 0s 107us/step - loss: 472.2902 - mean_absolute_error: 472.2902 - val_loss: 392.9995 - val_mean_absolute_error: 392.9995
#
# Epoch 00200: val_loss did not improve from 304.90259
# Epoch 201/500
# 84/84 [==============================] - 0s 119us/step - loss: 468.5600 - mean_absolute_error: 468.5600 - val_loss: 417.4277 - val_mean_absolute_error: 417.4277
#
# Epoch 00201: val_loss did not improve from 304.90259
# Epoch 202/500
# 84/84 [==============================] - 0s 166us/step - loss: 479.8138 - mean_absolute_error: 479.8138 - val_loss: 354.7806 - val_mean_absolute_error: 354.7806
#
# Epoch 00202: val_loss did not improve from 304.90259
# Epoch 203/500
# 84/84 [==============================] - 0s 113us/step - loss: 488.9160 - mean_absolute_error: 488.9160 - val_loss: 296.1032 - val_mean_absolute_error: 296.1032
#
# Epoch 00203: val_loss improved from 304.90259 to 296.10324, saving model to LV-제모제week-Weights-203--296.10324.hdf5
# Epoch 204/500
# 84/84 [==============================] - 0s 119us/step - loss: 479.4798 - mean_absolute_error: 479.4798 - val_loss: 405.4835 - val_mean_absolute_error: 405.4835
#
# Epoch 00204: val_loss did not improve from 296.10324
# Epoch 205/500
# 84/84 [==============================] - 0s 142us/step - loss: 502.3538 - mean_absolute_error: 502.3538 - val_loss: 408.3084 - val_mean_absolute_error: 408.3084
#
# Epoch 00205: val_loss did not improve from 296.10324
# Epoch 206/500
# ...
#
# Epoch 00431: val_loss did not improve from 230.75093
# Epoch 432/500
# 84/84 [==============================] - 0s 119us/step - loss: 417.4635 - mean_absolute_error: 417.4635 - val_loss: 333.4055 - val_mean_absolute_error: 333.4055
#
# Epoch 00432: val_loss did not improve from 230.75093
# Epoch 433/500
# 84/84 [==============================] - 0s 119us/step - loss: 404.0326 - mean_absolute_error: 404.0326 - val_loss: 393.6059 - val_mean_absolute_error: 393.6059
#
# Epoch 00433: val_loss did not improve from 230.75093
# Epoch 434/500
# 84/84 [==============================] - 0s 107us/step - loss: 465.5930 - mean_absolute_error: 465.5930 - val_loss: 312.1457 - val_mean_absolute_error: 312.1457
#
# Epoch 00434: val_loss did not improve from 230.75093
# Epoch 435/500
# 84/84 [==============================] - 0s 118us/step - loss: 438.4949 - mean_absolute_error: 438.4949 - val_loss: 275.6310 - val_mean_absolute_error: 275.6310
#
# Epoch 00435: val_loss did not improve from 230.75093
# Epoch 436/500
# 84/84 [==============================] - 0s 142us/step - loss: 398.3773 - mean_absolute_error: 398.3773 - val_loss: 306.7193 - val_mean_absolute_error: 306.7193
#
# Epoch 00436: val_loss did not improve from 230.75093
# Epoch 437/500
# 84/84 [==============================] - 0s 154us/step - loss: 436.3405 - mean_absolute_error: 436.3405 - val_loss: 302.9863 - val_mean_absolute_error: 302.9863
#
# Epoch 00437: val_loss did not improve from 230.75093
# Epoch 438/500
# 84/84 [==============================] - 0s 107us/step - loss: 385.8936 - mean_absolute_error: 385.8936 - val_loss: 256.5741 - val_mean_absolute_error: 256.5741
#
# Epoch 00438: val_loss did not improve from 230.75093
# Epoch 439/500
# 84/84 [==============================] - 0s 142us/step - loss: 393.6872 - mean_absolute_error: 393.6872 - val_loss: 273.6651 - val_mean_absolute_error: 273.6651
#
# Epoch 00439: val_loss did not improve from 230.75093
# Epoch 440/500
# 84/84 [==============================] - 0s 166us/step - loss: 377.9280 - mean_absolute_error: 377.9280 - val_loss: 270.2201 - val_mean_absolute_error: 270.2201
#
# Epoch 00440: val_loss did not improve from 230.75093
# Epoch 441/500
# 84/84 [==============================] - 0s 154us/step - loss: 367.3262 - mean_absolute_error: 367.3262 - val_loss: 269.3413 - val_mean_absolute_error: 269.3413
#
# Epoch 00441: val_loss did not improve from 230.75093
# Epoch 442/500
# 84/84 [==============================] - 0s 119us/step - loss: 397.8857 - mean_absolute_error: 397.8857 - val_loss: 339.3802 - val_mean_absolute_error: 339.3802
#
# Epoch 00442: val_loss did not improve from 230.75093
# Epoch 443/500
# 84/84 [==============================] - 0s 119us/step - loss: 395.5295 - mean_absolute_error: 395.5295 - val_loss: 308.4198 - val_mean_absolute_error: 308.4198
#
# Epoch 00443: val_loss did not improve from 230.75093
# Epoch 444/500
# 84/84 [==============================] - 0s 131us/step - loss: 371.8420 - mean_absolute_error: 371.8420 - val_loss: 286.4587 - val_mean_absolute_error: 286.4587
#
# Epoch 00444: val_loss did not improve from 230.75093
# Epoch 445/500
# 84/84 [==============================] - 0s 214us/step - loss: 375.0607 - mean_absolute_error: 375.0607 - val_loss: 276.0225 - val_mean_absolute_error: 276.0225
#
# Epoch 00445: val_loss did not improve from 230.75093
# Epoch 446/500
# 84/84 [==============================] - 0s 131us/step - loss: 366.3530 - mean_absolute_error: 366.3530 - val_loss: 294.4997 - val_mean_absolute_error: 294.4997
#
# Epoch 00446: val_loss did not improve from 230.75093
# Epoch 447/500
# 84/84 [==============================] - 0s 119us/step - loss: 368.8762 - mean_absolute_error: 368.8762 - val_loss: 271.8524 - val_mean_absolute_error: 271.8524
#
# Epoch 00447: val_loss did not improve from 230.75093
# Epoch 448/500
# 84/84 [==============================] - 0s 178us/step - loss: 363.2182 - mean_absolute_error: 363.2182 - val_loss: 291.4563 - val_mean_absolute_error: 291.4563
#
# Epoch 00448: val_loss did not improve from 230.75093
# Epoch 449/500
# 84/84 [==============================] - 0s 154us/step - loss: 358.5473 - mean_absolute_error: 358.5473 - val_loss: 302.6104 - val_mean_absolute_error: 302.6104
#
# Epoch 00449: val_loss did not improve from 230.75093
# Epoch 450/500
# 84/84 [==============================] - 0s 131us/step - loss: 388.5004 - mean_absolute_error: 388.5004 - val_loss: 297.7003 - val_mean_absolute_error: 297.7003
#
# Epoch 00450: val_loss did not improve from 230.75093
# Epoch 451/500
# 84/84 [==============================] - 0s 131us/step - loss: 418.3874 - mean_absolute_error: 418.3874 - val_loss: 270.4154 - val_mean_absolute_error: 270.4154
#
# Epoch 00451: val_loss did not improve from 230.75093
# Epoch 452/500
# 84/84 [==============================] - 0s 214us/step - loss: 384.2704 - mean_absolute_error: 384.2704 - val_loss: 310.1889 - val_mean_absolute_error: 310.1889
#
# Epoch 00452: val_loss did not improve from 230.75093
# Epoch 453/500
# 84/84 [==============================] - 0s 154us/step - loss: 403.7489 - mean_absolute_error: 403.7489 - val_loss: 283.9552 - val_mean_absolute_error: 283.9552
#
# Epoch 00453: val_loss did not improve from 230.75093
# Epoch 454/500
# 84/84 [==============================] - 0s 131us/step - loss: 440.5225 - mean_absolute_error: 440.5225 - val_loss: 294.1927 - val_mean_absolute_error: 294.1927
#
# Epoch 00454: val_loss did not improve from 230.75093
# Epoch 455/500
# 84/84 [==============================] - 0s 190us/step - loss: 393.0743 - mean_absolute_error: 393.0743 - val_loss: 310.1461 - val_mean_absolute_error: 310.1461
#
# Epoch 00455: val_loss did not improve from 230.75093
# Epoch 456/500
# 84/84 [==============================] - 0s 166us/step - loss: 409.9068 - mean_absolute_error: 409.9068 - val_loss: 310.7793 - val_mean_absolute_error: 310.7793
#
# Epoch 00456: val_loss did not improve from 230.75093
# Epoch 457/500
# 84/84 [==============================] - 0s 131us/step - loss: 445.5329 - mean_absolute_error: 445.5329 - val_loss: 296.4591 - val_mean_absolute_error: 296.4591
#
# Epoch 00457: val_loss did not improve from 230.75093
# Epoch 458/500
# 84/84 [==============================] - 0s 131us/step - loss: 423.0736 - mean_absolute_error: 423.0736 - val_loss: 323.1671 - val_mean_absolute_error: 323.1671
#
# Epoch 00458: val_loss did not improve from 230.75093
# Epoch 459/500
# 84/84 [==============================] - 0s 107us/step - loss: 401.7296 - mean_absolute_error: 401.7296 - val_loss: 311.8255 - val_mean_absolute_error: 311.8255
#
# Epoch 00459: val_loss did not improve from 230.75093
# Epoch 460/500
# 84/84 [==============================] - 0s 202us/step - loss: 421.4221 - mean_absolute_error: 421.4221 - val_loss: 316.1664 - val_mean_absolute_error: 316.1664
#
# Epoch 00460: val_loss did not improve from 230.75093
# Epoch 461/500
# 84/84 [==============================] - 0s 178us/step - loss: 395.1107 - mean_absolute_error: 395.1107 - val_loss: 276.7894 - val_mean_absolute_error: 276.7894
#
# Epoch 00461: val_loss did not improve from 230.75093
# Epoch 462/500
# 84/84 [==============================] - 0s 285us/step - loss: 370.7145 - mean_absolute_error: 370.7145 - val_loss: 308.0739 - val_mean_absolute_error: 308.0739
#
# Epoch 00462: val_loss did not improve from 230.75093
# Epoch 463/500
# 84/84 [==============================] - 0s 178us/step - loss: 406.9199 - mean_absolute_error: 406.9199 - val_loss: 307.0818 - val_mean_absolute_error: 307.0818
#
# Epoch 00463: val_loss did not improve from 230.75093
# Epoch 464/500
# 84/84 [==============================] - 0s 166us/step - loss: 389.0098 - mean_absolute_error: 389.0098 - val_loss: 301.4115 - val_mean_absolute_error: 301.4115
#
# Epoch 00464: val_loss did not improve from 230.75093
# Epoch 465/500
# 84/84 [==============================] - 0s 142us/step - loss: 372.8021 - mean_absolute_error: 372.8021 - val_loss: 246.8118 - val_mean_absolute_error: 246.8118
#
# Epoch 00465: val_loss did not improve from 230.75093
# Epoch 466/500
# 84/84 [==============================] - 0s 131us/step - loss: 360.9887 - mean_absolute_error: 360.9887 - val_loss: 309.0336 - val_mean_absolute_error: 309.0336
#
# Epoch 00466: val_loss did not improve from 230.75093
# Epoch 467/500
# 84/84 [==============================] - 0s 142us/step - loss: 366.9025 - mean_absolute_error: 366.9025 - val_loss: 303.7206 - val_mean_absolute_error: 303.7206
#
# Epoch 00467: val_loss did not improve from 230.75093
# Epoch 468/500
# 84/84 [==============================] - 0s 131us/step - loss: 373.8941 - mean_absolute_error: 373.8941 - val_loss: 244.1775 - val_mean_absolute_error: 244.1775
#
# Epoch 00468: val_loss did not improve from 230.75093
# Epoch 469/500
# 84/84 [==============================] - 0s 142us/step - loss: 369.6406 - mean_absolute_error: 369.6406 - val_loss: 303.3963 - val_mean_absolute_error: 303.3963
#
# Epoch 00469: val_loss did not improve from 230.75093
# Epoch 470/500
# 84/84 [==============================] - 0s 119us/step - loss: 372.9290 - mean_absolute_error: 372.9290 - val_loss: 301.1631 - val_mean_absolute_error: 301.1631
#
# Epoch 00470: val_loss did not improve from 230.75093
# Epoch 471/500
# 84/84 [==============================] - 0s 119us/step - loss: 414.6183 - mean_absolute_error: 414.6183 - val_loss: 262.3427 - val_mean_absolute_error: 262.3427
#
# Epoch 00471: val_loss did not improve from 230.75093
# Epoch 472/500
# 84/84 [==============================] - 0s 154us/step - loss: 373.7467 - mean_absolute_error: 373.7467 - val_loss: 246.0001 - val_mean_absolute_error: 246.0001
#
# Epoch 00472: val_loss did not improve from 230.75093
# Epoch 473/500
# 84/84 [==============================] - 0s 154us/step - loss: 401.2635 - mean_absolute_error: 401.2635 - val_loss: 256.8823 - val_mean_absolute_error: 256.8823
#
# Epoch 00473: val_loss did not improve from 230.75093
# Epoch 474/500
# 84/84 [==============================] - 0s 142us/step - loss: 377.8322 - mean_absolute_error: 377.8322 - val_loss: 313.8584 - val_mean_absolute_error: 313.8584
#
# Epoch 00474: val_loss did not improve from 230.75093
# Epoch 475/500
# 84/84 [==============================] - 0s 166us/step - loss: 376.9257 - mean_absolute_error: 376.9257 - val_loss: 249.7863 - val_mean_absolute_error: 249.7863
#
# Epoch 00475: val_loss did not improve from 230.75093
# Epoch 476/500
# 84/84 [==============================] - 0s 131us/step - loss: 380.8330 - mean_absolute_error: 380.8330 - val_loss: 280.0602 - val_mean_absolute_error: 280.0602
#
# Epoch 00476: val_loss did not improve from 230.75093
# Epoch 477/500
# 84/84 [==============================] - 0s 178us/step - loss: 356.6204 - mean_absolute_error: 356.6204 - val_loss: 305.6070 - val_mean_absolute_error: 305.6070
#
# Epoch 00477: val_loss did not improve from 230.75093
# Epoch 478/500
# 84/84 [==============================] - 0s 166us/step - loss: 354.0570 - mean_absolute_error: 354.0570 - val_loss: 264.4146 - val_mean_absolute_error: 264.4146
#
# Epoch 00478: val_loss did not improve from 230.75093
# Epoch 479/500
# 84/84 [==============================] - 0s 131us/step - loss: 353.9269 - mean_absolute_error: 353.9269 - val_loss: 272.8507 - val_mean_absolute_error: 272.8507
#
# Epoch 00479: val_loss did not improve from 230.75093
# Epoch 480/500
# 84/84 [==============================] - 0s 131us/step - loss: 349.6050 - mean_absolute_error: 349.6050 - val_loss: 322.7936 - val_mean_absolute_error: 322.7936
#
# Epoch 00480: val_loss did not improve from 230.75093
# Epoch 481/500
# 84/84 [==============================] - 0s 184us/step - loss: 356.2177 - mean_absolute_error: 356.2177 - val_loss: 254.1464 - val_mean_absolute_error: 254.1464
#
# Epoch 00481: val_loss did not improve from 230.75093
# Epoch 482/500
# 84/84 [==============================] - 0s 321us/step - loss: 373.3784 - mean_absolute_error: 373.3784 - val_loss: 277.3864 - val_mean_absolute_error: 277.3864
#
# Epoch 00482: val_loss did not improve from 230.75093
# Epoch 483/500
# 84/84 [==============================] - 0s 131us/step - loss: 364.8386 - mean_absolute_error: 364.8386 - val_loss: 279.0323 - val_mean_absolute_error: 279.0323
#
# Epoch 00483: val_loss did not improve from 230.75093
# Epoch 484/500
# 84/84 [==============================] - 0s 119us/step - loss: 356.2477 - mean_absolute_error: 356.2477 - val_loss: 279.6264 - val_mean_absolute_error: 279.6264
#
# Epoch 00484: val_loss did not improve from 230.75093
# Epoch 485/500
# 84/84 [==============================] - 0s 119us/step - loss: 350.8510 - mean_absolute_error: 350.8510 - val_loss: 267.3593 - val_mean_absolute_error: 267.3593
#
# Epoch 00485: val_loss did not improve from 230.75093
# Epoch 486/500
# 84/84 [==============================] - 0s 131us/step - loss: 358.4876 - mean_absolute_error: 358.4876 - val_loss: 293.7547 - val_mean_absolute_error: 293.7547
#
# Epoch 00486: val_loss did not improve from 230.75093
# Epoch 487/500
# 84/84 [==============================] - 0s 119us/step - loss: 360.9845 - mean_absolute_error: 360.9845 - val_loss: 244.4489 - val_mean_absolute_error: 244.4489
#
# Epoch 00487: val_loss did not improve from 230.75093
# Epoch 488/500
# 84/84 [==============================] - 0s 119us/step - loss: 376.6228 - mean_absolute_error: 376.6228 - val_loss: 275.1553 - val_mean_absolute_error: 275.1553
#
# Epoch 00488: val_loss did not improve from 230.75093
# Epoch 489/500
# 84/84 [==============================] - 0s 131us/step - loss: 351.4275 - mean_absolute_error: 351.4275 - val_loss: 294.8010 - val_mean_absolute_error: 294.8010
#
# Epoch 00489: val_loss did not improve from 230.75093
# Epoch 490/500
# 84/84 [==============================] - 0s 1ms/step - loss: 375.7717 - mean_absolute_error: 375.7717 - val_loss: 266.7314 - val_mean_absolute_error: 266.7314
#
# Epoch 00490: val_loss did not improve from 230.75093
# Epoch 491/500
# 84/84 [==============================] - 0s 178us/step - loss: 446.4364 - mean_absolute_error: 446.4364 - val_loss: 275.9317 - val_mean_absolute_error: 275.9317
#
# Epoch 00491: val_loss did not improve from 230.75093
# Epoch 492/500
# 84/84 [==============================] - 0s 202us/step - loss: 392.4703 - mean_absolute_error: 392.4703 - val_loss: 333.6511 - val_mean_absolute_error: 333.6511
#
# Epoch 00492: val_loss did not improve from 230.75093
# Epoch 493/500
# 84/84 [==============================] - 0s 119us/step - loss: 367.9028 - mean_absolute_error: 367.9028 - val_loss: 232.7966 - val_mean_absolute_error: 232.7966
#
# Epoch 00493: val_loss did not improve from 230.75093
# Epoch 494/500
# 84/84 [==============================] - 0s 119us/step - loss: 370.3601 - mean_absolute_error: 370.3601 - val_loss: 260.6176 - val_mean_absolute_error: 260.6176
#
# Epoch 00494: val_loss did not improve from 230.75093
# Epoch 495/500
# 84/84 [==============================] - 0s 190us/step - loss: 382.1588 - mean_absolute_error: 382.1588 - val_loss: 311.5439 - val_mean_absolute_error: 311.5439
#
# Epoch 00495: val_loss did not improve from 230.75093
# Epoch 496/500
# 84/84 [==============================] - 0s 160us/step - loss: 404.8290 - mean_absolute_error: 404.8290 - val_loss: 279.9779 - val_mean_absolute_error: 279.9779
#
# Epoch 00496: val_loss did not improve from 230.75093
# Epoch 497/500
# 84/84 [==============================] - 0s 142us/step - loss: 363.7175 - mean_absolute_error: 363.7175 - val_loss: 295.7860 - val_mean_absolute_error: 295.7860
#
# Epoch 00497: val_loss did not improve from 230.75093
# Epoch 498/500
# 84/84 [==============================] - 0s 131us/step - loss: 400.5044 - mean_absolute_error: 400.5044 - val_loss: 262.4150 - val_mean_absolute_error: 262.4150
#
# Epoch 00498: val_loss did not improve from 230.75093
# Epoch 499/500
# 84/84 [==============================] - 0s 119us/step - loss: 358.5726 - mean_absolute_error: 358.5726 - val_loss: 278.2448 - val_mean_absolute_error: 278.2448
#
# Epoch 00499: val_loss did not improve from 230.75093
# Epoch 500/500
# 84/84 [==============================] - 0s 119us/step - loss: 352.3442 - mean_absolute_error: 352.3442 - val_loss: 309.0593 - val_mean_absolute_error: 309.0593
#
# Epoch 00500: val_loss did not improve from 230.75093

# %% [markdown]
# #### ====================================================================================================

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
wights_file = 'LV-제모제week-Weights-421--230.75093.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
# rf나,XGB회귀 분석을위한 훈련/검증 dataset생산
train_X, val_X, train_y, val_y = train_test_split(train, target[:cut_line], test_size = 0.25, random_state = 14)

# %%
# RandomForest 회귀분석
model = RandomForestRegressor()
model.fit(train_X,train_y)

# Get the mean absolute error on the validation data
RFpredicted = model.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  318.6449735449736

# %%
# XGBRegressor 회귀분석
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# [15:38:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  340.5726652599517

# %%
# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)

combined = lv_week_w.loc[:,'temp':'PM25']
target = lv_week_w.loc[:,'qty']
# RandomForest 회귀분석 예측 qty생산
RFpredicted = model.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)

result_df = pd.DataFrame()
result_df['week'] = lv_week_w['week']
result_df['qty'] = lv_week_w.loc[:,'qty']

print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions
# Out:
# keras 신경망 predictions (157, 1)
# randomforest 예상 (157,)
# XGBpredictions (157,)

# %%
df_graph = result_df.loc[:,['week','keras_qty','rf_qty','xgb_qty','qty']]
df_graph['week'] = pd.to_datetime(df_graph['week'])

# %%
# 2016
df_graph = result_df.loc[result_df.week <=53]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='orange')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.legend()
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6cf6bdb3a1d4> in <module>()
#       1 # 2016
# ----> 2 df_graph = result_df.loc[result_df.week <=53]
#       3 plt.figure(figsize=(15.5, 10))
#       4 plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
#       5 plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
#
# NameError: name 'result_df' is not defined

# %%
# 2017
df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
plt.legend()
plt.show()

# %%
# 2018
df_graph = result_df.loc[(result_df.week >=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
plt.legend()
plt.show()

# %%
# 2016~2018
plt.figure(figsize=(15.5, 10))
plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
plt.legend()
plt.show()

# %%
# 날씨+sns와 '생수' 을 사용하면 2017까진 적당하고 2018년도는 예측율 급락
#  -> 과적합화 발생
# 날씨와 '생수' 판매량만 이용하니 ㅇㅋ

# %%
orginal_mean = np.mean(result_df.qty)
result_df['qtyMinusMean'] = (result_df.qty - orginal_mean )
result_df['qtyMinusMeanSquared'] = (result_df.qty - orginal_mean )**2

result_df['kerasMiunsMeanSquared'] = (result_df.keras_qty - orginal_mean)**2
result_df['rfMiunsMeanSquared'] = (result_df.rf_qty - orginal_mean)**2
result_df['xgbMiunsMeanSquared'] = (result_df.xgb_qty - orginal_mean)**2

print('kreas R-sq',(sum(result_df['kerasMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
print('rf R-sq',(sum(result_df['rfMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
print('xgb R-sq',(sum(result_df['xgbMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
# Out:
# kreas R-sq 0.7662173931992837
# rf R-sq 1.2242968862830463
# xgb R-sq 1.402944454347196

# %%
path = 'D:/project/contest/data/result/'
result_df.to_csv(path+item+'_'+grouped_by+'_predict.csv', encoding='utf-8', index=False)
