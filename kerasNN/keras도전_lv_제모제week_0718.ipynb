# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor


# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1))
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula


#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# 0718수정된 날씨 데이터
w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_catrogy.csv', parse_dates=['date'], index_col=0)

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
lv_grouped = lv_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_lv_grouped = lv_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '제모제'만 빼서 df생성
item = '제모제'
grouped_by = 'week'
day_lv_grouped_w_item = pd.merge(day_lv_grouped.loc[day_lv_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_lv_grouped_w_sns_item = pd.merge(day_lv_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
lv_day_w = day_lv_grouped_w_sns_item[selected_cols]

# %% [markdown]
# # 주단위로 종합해보기

# %%
lv_week_w = lv_day_w.copy()
lv_week_w = addDayWeek(lv_week_w)

cols_Ineed = ['week','category', 'qty', 'temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
              'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25','rain_or_not','snow_or_not']
#               'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
#               'health_blog','health_twitter', 'health_news', 'health_total',
#               'date_blog','date_twitter', 'date_news', 'date_total',
#               'br_blog', 'br_twitter','br_news', 'br_total',
#               'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
lv_week_w = lv_week_w[cols_Ineed]

# %%
gs_week_w = gs_week_w[['week','qty']+cols_Ineed].groupby('week').mean().reset_index()
# gs_week_w.tail(2)

# week: 1~105 = 2016~2017년
# week: 106~157 = 2018년
train_data = gs_week_w.loc[gs_week_w.week <=105]
test_date = gs_week_w.loc[gs_week_w.week >105]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
combined = gs_week_w.iloc[:,3:]
target = gs_week_w.iloc[:,2]

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e0875a1e23f1> in <module>()
# ----> 1 num_cols = get_cols_with_no_nans(combined , 'num')
#       2 cat_cols = get_cols_with_no_nans(combined , 'no_num')
#
# NameError: name 'combined' is not defined

# %%
# 전체 날씨 변수에서 하나씩 제거해 가면 가장 VIF가 낮은 7개를 추림.
list_col = ['temp', 'cloud', 'lgt_time', 'O3','rain_or_not','snow_or_not','PM25']
lowVIF(w,40,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239907  snow_or_not
# 1    2.349134  rain_or_not
# 2    4.241581         PM25
# 3    4.364179         temp
# 4    5.610354        cloud
# 5    5.886114     lgt_time
# 6    9.088412           O3

# %%
# list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
#               'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',
#               'pm_blog', 'pm_twitter', 'pm_news', 'pm_total', 
#               'health_blog','health_twitter', 'health_news', 'health_total',
#               'date_blog','date_twitter', 'date_news', 'date_total',
#               'br_blog', 'br_twitter','br_news', 'br_total',
#               'hobby_blog', 'hobby_twitter', 'hobby_news','hobby_total']
# lowVIF(lv_week_w,40,list_col)

# list_col = ['temp', 'rain', 'cloud', 'wind', 'humid','hpa', 'sun_time', 'lgt_time', 'snow',
#               'SO2', 'CO', 'O3', 'NO2', 'PM10','PM25',]
lv_week_w = lv_week_w[['week','qty']+list_col].groupby('week').mean().reset_index()
# gs_week_w.tail(2)

# week: 1~105 = 2016~2017년
# week: 106~157 = 2018년
train_data = lv_week_w.loc[lv_week_w.week <=105]
test_date = lv_week_w.loc[lv_week_w.week >105]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
combined = lv_week_w.loc[:,'temp':'PM25']
target = lv_week_w.loc[:,'qty']

# %%
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
# 여기서 이코드으 제작자는 수동으로 훈련/검증셋을 나눔
# 105주 기준으로 나누겠음
cut_line = 106
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()
train.shape
# Out:
# (106, 7)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 18:38:28.120798  6288 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 18:38:28.135757  6288 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 18:38:28.137754  6288 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0717 18:38:28.191608  6288 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 165,889
# Trainable params: 165,889
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### =========='xxxxyyyyzzzz.hdf5'파일이 안주어지면 실행.(있으면 실행 필요없음)==========

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = 'LV(lowVIF07)-'+item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
train_X, val_X, train_y, val_y = train_test_split(train, target[:cut_line], test_size = 0.25, random_state = 14)

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=106을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0717 18:38:53.790560  6288 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0717 18:38:53.895254  6288 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 84 samples, validate on 22 samples
# Epoch 1/500
# 84/84 [==============================] - 0s 3ms/step - loss: 1623.4804 - mean_absolute_error: 1623.4804 - val_loss: 897.1451 - val_mean_absolute_error: 897.1451
#
# Epoch 00001: val_loss improved from inf to 897.14514, saving model to LV(lowVIF07)-제모제week-Weights-001--897.14514.hdf5
# Epoch 2/500
# 84/84 [==============================] - 0s 95us/step - loss: 1621.4559 - mean_absolute_error: 1621.4559 - val_loss: 894.4073 - val_mean_absolute_error: 894.4073
#
# Epoch 00002: val_loss improved from 897.14514 to 894.40729, saving model to LV(lowVIF07)-제모제week-Weights-002--894.40729.hdf5
# Epoch 3/500
# 84/84 [==============================] - 0s 107us/step - loss: 1617.2948 - mean_absolute_error: 1617.2948 - val_loss: 888.6799 - val_mean_absolute_error: 888.6799
#
# Epoch 00003: val_loss improved from 894.40729 to 888.67993, saving model to LV(lowVIF07)-제모제week-Weights-003--888.67993.hdf5
# Epoch 4/500
# 84/84 [==============================] - 0s 142us/step - loss: 1608.7360 - mean_absolute_error: 1608.7360 - val_loss: 877.1284 - val_mean_absolute_error: 877.1284
#
# Epoch 00004: val_loss improved from 888.67993 to 877.12836, saving model to LV(lowVIF07)-제모제week-Weights-004--877.12836.hdf5
# Epoch 5/500
# 84/84 [==============================] - 0s 107us/step - loss: 1591.6329 - mean_absolute_error: 1591.6329 - val_loss: 855.2768 - val_mean_absolute_error: 855.2768
#
# Epoch 00005: val_loss improved from 877.12836 to 855.27679, saving model to LV(lowVIF07)-제모제week-Weights-005--855.27679.hdf5
# Epoch 6/500
# 84/84 [==============================] - 0s 95us/step - loss: 1560.5134 - mean_absolute_error: 1560.5134 - val_loss: 816.0027 - val_mean_absolute_error: 816.0027
#
# Epoch 00006: val_loss improved from 855.27679 to 816.00275, saving model to LV(lowVIF07)-제모제week-Weights-006--816.00275.hdf5
# Epoch 7/500
# 84/84 [==============================] - 0s 166us/step - loss: 1504.4800 - mean_absolute_error: 1504.4800 - val_loss: 748.1597 - val_mean_absolute_error: 748.1597
#
# Epoch 00007: val_loss improved from 816.00275 to 748.15973, saving model to LV(lowVIF07)-제모제week-Weights-007--748.15973.hdf5
# Epoch 8/500
# 84/84 [==============================] - 0s 107us/step - loss: 1412.4199 - mean_absolute_error: 1412.4199 - val_loss: 634.6967 - val_mean_absolute_error: 634.6967
#
# Epoch 00008: val_loss improved from 748.15973 to 634.69672, saving model to LV(lowVIF07)-제모제week-Weights-008--634.69672.hdf5
# Epoch 9/500
# 84/84 [==============================] - 0s 119us/step - loss: 1271.3060 - mean_absolute_error: 1271.3060 - val_loss: 452.5550 - val_mean_absolute_error: 452.5550
#
# Epoch 00009: val_loss improved from 634.69672 to 452.55499, saving model to LV(lowVIF07)-제모제week-Weights-009--452.55499.hdf5
# Epoch 10/500
# 84/84 [==============================] - 0s 131us/step - loss: 1130.5077 - mean_absolute_error: 1130.5077 - val_loss: 296.1935 - val_mean_absolute_error: 296.1935
#
# Epoch 00010: val_loss improved from 452.55499 to 296.19345, saving model to LV(lowVIF07)-제모제week-Weights-010--296.19345.hdf5
# Epoch 11/500
# 84/84 [==============================] - 0s 119us/step - loss: 974.5954 - mean_absolute_error: 974.5954 - val_loss: 409.6062 - val_mean_absolute_error: 409.6062
#
# Epoch 00011: val_loss did not improve from 296.19345
# Epoch 12/500
# 84/84 [==============================] - 0s 154us/step - loss: 947.3175 - mean_absolute_error: 947.3175 - val_loss: 665.3978 - val_mean_absolute_error: 665.3978
#
# Epoch 00012: val_loss did not improve from 296.19345
# Epoch 13/500
# 84/84 [==============================] - 0s 107us/step - loss: 923.8240 - mean_absolute_error: 923.8240 - val_loss: 818.6358 - val_mean_absolute_error: 818.6358
#
# Epoch 00013: val_loss did not improve from 296.19345
# Epoch 14/500
# 84/84 [==============================] - 0s 107us/step - loss: 920.2967 - mean_absolute_error: 920.2967 - val_loss: 704.7830 - val_mean_absolute_error: 704.7830
#
# Epoch 00014: val_loss did not improve from 296.19345
# Epoch 15/500
# 84/84 [==============================] - 0s 131us/step - loss: 849.9745 - mean_absolute_error: 849.9745 - val_loss: 526.3232 - val_mean_absolute_error: 526.3232
#
# Epoch 00015: val_loss did not improve from 296.19345
# Epoch 16/500
# 84/84 [==============================] - 0s 119us/step - loss: 815.0667 - mean_absolute_error: 815.0667 - val_loss: 425.6884 - val_mean_absolute_error: 425.6884
#
# Epoch 00016: val_loss did not improve from 296.19345
# Epoch 17/500
# 84/84 [==============================] - 0s 142us/step - loss: 784.0381 - mean_absolute_error: 784.0381 - val_loss: 408.3070 - val_mean_absolute_error: 408.3070
#
# Epoch 00017: val_loss did not improve from 296.19345
# Epoch 18/500
# 84/84 [==============================] - 0s 95us/step - loss: 753.2249 - mean_absolute_error: 753.2249 - val_loss: 460.0746 - val_mean_absolute_error: 460.0746
#
# Epoch 00018: val_loss did not improve from 296.19345
# Epoch 19/500
# 84/84 [==============================] - 0s 95us/step - loss: 709.1742 - mean_absolute_error: 709.1742 - val_loss: 533.6575 - val_mean_absolute_error: 533.6575
#
# Epoch 00019: val_loss did not improve from 296.19345
# Epoch 20/500
# 84/84 [==============================] - 0s 95us/step - loss: 679.3984 - mean_absolute_error: 679.3984 - val_loss: 593.1230 - val_mean_absolute_error: 593.1230
#
# Epoch 00020: val_loss did not improve from 296.19345
# Epoch 21/500
# 84/84 [==============================] - 0s 107us/step - loss: 661.1100 - mean_absolute_error: 661.1100 - val_loss: 581.1088 - val_mean_absolute_error: 581.1088
#
# Epoch 00021: val_loss did not improve from 296.19345
# Epoch 22/500
# 84/84 [==============================] - 0s 107us/step - loss: 640.0310 - mean_absolute_error: 640.0310 - val_loss: 557.8910 - val_mean_absolute_error: 557.8910
#
# Epoch 00022: val_loss did not improve from 296.19345
# Epoch 23/500
# 84/84 [==============================] - 0s 107us/step - loss: 624.4629 - mean_absolute_error: 624.4629 - val_loss: 586.2700 - val_mean_absolute_error: 586.2700
#
# Epoch 00023: val_loss did not improve from 296.19345
# Epoch 24/500
# 84/84 [==============================] - 0s 119us/step - loss: 615.1855 - mean_absolute_error: 615.1855 - val_loss: 633.6414 - val_mean_absolute_error: 633.6414
#
# Epoch 00024: val_loss did not improve from 296.19345
# Epoch 25/500
# 84/84 [==============================] - 0s 107us/step - loss: 610.3387 - mean_absolute_error: 610.3387 - val_loss: 665.4664 - val_mean_absolute_error: 665.4664
#
# Epoch 00025: val_loss did not improve from 296.19345
# Epoch 26/500
# 84/84 [==============================] - 0s 107us/step - loss: 611.9664 - mean_absolute_error: 611.9664 - val_loss: 696.2721 - val_mean_absolute_error: 696.2721
#
# Epoch 00026: val_loss did not improve from 296.19345
# Epoch 27/500
# 84/84 [==============================] - 0s 107us/step - loss: 602.2999 - mean_absolute_error: 602.2999 - val_loss: 692.0969 - val_mean_absolute_error: 692.0969
#
# Epoch 00027: val_loss did not improve from 296.19345
# Epoch 28/500
# 84/84 [==============================] - 0s 95us/step - loss: 603.7975 - mean_absolute_error: 603.7975 - val_loss: 683.1909 - val_mean_absolute_error: 683.1909
#
# Epoch 00028: val_loss did not improve from 296.19345
# Epoch 29/500
# 84/84 [==============================] - 0s 142us/step - loss: 600.2777 - mean_absolute_error: 600.2777 - val_loss: 724.3850 - val_mean_absolute_error: 724.3850
#
# Epoch 00029: val_loss did not improve from 296.19345
# Epoch 30/500
# 84/84 [==============================] - 0s 107us/step - loss: 592.8554 - mean_absolute_error: 592.8554 - val_loss: 777.9814 - val_mean_absolute_error: 777.9814
#
# Epoch 00030: val_loss did not improve from 296.19345
# Epoch 31/500
# 84/84 [==============================] - 0s 95us/step - loss: 613.6364 - mean_absolute_error: 613.6364 - val_loss: 840.2241 - val_mean_absolute_error: 840.2241
#
# Epoch 00031: val_loss did not improve from 296.19345
# Epoch 32/500
# 84/84 [==============================] - 0s 95us/step - loss: 600.6939 - mean_absolute_error: 600.6939 - val_loss: 761.3303 - val_mean_absolute_error: 761.3303
#
# Epoch 00032: val_loss did not improve from 296.19345
# Epoch 33/500
# 84/84 [==============================] - 0s 107us/step - loss: 596.3563 - mean_absolute_error: 596.3563 - val_loss: 687.0710 - val_mean_absolute_error: 687.0710
# Epoch 00033: val_loss did not improve from 296.19345
# Epoch 34/500
# 84/84 [==============================] - 0s 107us/step - loss: 601.4086 - mean_absolute_error: 601.4086 - val_loss: 671.7574 - val_mean_absolute_error: 671.7574
#
# Epoch 00034: val_loss did not improve from 296.19345
# Epoch 35/500
# 84/84 [==============================] - 0s 119us/step - loss: 600.7280 - mean_absolute_error: 600.7280 - val_loss: 722.9154 - val_mean_absolute_error: 722.9154
#
# Epoch 00035: val_loss did not improve from 296.19345
# Epoch 36/500
# 84/84 [==============================] - 0s 119us/step - loss: 589.9948 - mean_absolute_error: 589.9948 - val_loss: 770.0580 - val_mean_absolute_error: 770.0580
#
# Epoch 00036: val_loss did not improve from 296.19345
# Epoch 37/500
# 84/84 [==============================] - 0s 107us/step - loss: 588.2301 - mean_absolute_error: 588.2301 - val_loss: 818.2496 - val_mean_absolute_error: 818.2496
#
# Epoch 00037: val_loss did not improve from 296.19345
# Epoch 38/500
# 84/84 [==============================] - 0s 107us/step - loss: 589.2944 - mean_absolute_error: 589.2944 - val_loss: 789.6762 - val_mean_absolute_error: 789.6762
#
# Epoch 00038: val_loss did not improve from 296.19345
# Epoch 39/500
# 84/84 [==============================] - 0s 107us/step - loss: 592.9208 - mean_absolute_error: 592.9208 - val_loss: 740.1628 - val_mean_absolute_error: 740.1628
#
# Epoch 00039: val_loss did not improve from 296.19345
# Epoch 40/500
# 84/84 [==============================] - 0s 95us/step - loss: 587.7467 - mean_absolute_error: 587.7467 - val_loss: 766.5469 - val_mean_absolute_error: 766.5469
#
# Epoch 00040: val_loss did not improve from 296.19345
# Epoch 41/500
# 84/84 [==============================] - 0s 107us/step - loss: 585.5123 - mean_absolute_error: 585.5123 - val_loss: 794.7494 - val_mean_absolute_error: 794.7494
#
# Epoch 00041: val_loss did not improve from 296.19345
# Epoch 42/500
# 84/84 [==============================] - 0s 107us/step - loss: 582.4556 - mean_absolute_error: 582.4556 - val_loss: 785.4348 - val_mean_absolute_error: 785.4348
#
# Epoch 00042: val_loss did not improve from 296.19345
# Epoch 43/500
# 84/84 [==============================] - 0s 95us/step - loss: 583.1768 - mean_absolute_error: 583.1768 - val_loss: 782.7512 - val_mean_absolute_error: 782.7512
#
# Epoch 00043: val_loss did not improve from 296.19345
# Epoch 44/500
# 84/84 [==============================] - 0s 95us/step - loss: 581.4724 - mean_absolute_error: 581.4724 - val_loss: 798.4487 - val_mean_absolute_error: 798.4487
#
# Epoch 00044: val_loss did not improve from 296.19345
# Epoch 45/500
# 84/84 [==============================] - 0s 107us/step - loss: 583.6789 - mean_absolute_error: 583.6789 - val_loss: 771.5847 - val_mean_absolute_error: 771.5847
#
# Epoch 00045: val_loss did not improve from 296.19345
# Epoch 46/500
# 84/84 [==============================] - 0s 107us/step - loss: 584.4501 - mean_absolute_error: 584.4501 - val_loss: 784.2665 - val_mean_absolute_error: 784.2665
#
# Epoch 00046: val_loss did not improve from 296.19345
# Epoch 47/500
# 84/84 [==============================] - 0s 107us/step - loss: 589.8032 - mean_absolute_error: 589.8032 - val_loss: 739.9076 - val_mean_absolute_error: 739.9076
#
# Epoch 00047: val_loss did not improve from 296.19345
# Epoch 48/500
# 84/84 [==============================] - 0s 95us/step - loss: 583.9196 - mean_absolute_error: 583.9196 - val_loss: 762.5052 - val_mean_absolute_error: 762.5052
#
# Epoch 00048: val_loss did not improve from 296.19345
# Epoch 49/500
# 84/84 [==============================] - 0s 154us/step - loss: 579.3000 - mean_absolute_error: 579.3000 - val_loss: 822.3933 - val_mean_absolute_error: 822.3933
#
# Epoch 00049: val_loss did not improve from 296.19345
# Epoch 50/500
# 84/84 [==============================] - 0s 107us/step - loss: 585.6464 - mean_absolute_error: 585.6464 - val_loss: 831.1082 - val_mean_absolute_error: 831.1082
#
# Epoch 00050: val_loss did not improve from 296.19345
# Epoch 51/500
# 84/84 [==============================] - 0s 95us/step - loss: 584.4474 - mean_absolute_error: 584.4474 - val_loss: 756.8721 - val_mean_absolute_error: 756.8721
#
# Epoch 00051: val_loss did not improve from 296.19345
# Epoch 52/500
# 84/84 [==============================] - 0s 119us/step - loss: 581.0444 - mean_absolute_error: 581.0444 - val_loss: 746.3183 - val_mean_absolute_error: 746.3183
#
# Epoch 00052: val_loss did not improve from 296.19345
# Epoch 53/500
# 84/84 [==============================] - 0s 95us/step - loss: 582.4201 - mean_absolute_error: 582.4201 - val_loss: 774.5034 - val_mean_absolute_error: 774.5034
#
# Epoch 00053: val_loss did not improve from 296.19345
# Epoch 54/500
# 84/84 [==============================] - 0s 131us/step - loss: 575.0026 - mean_absolute_error: 575.0026 - val_loss: 791.4183 - val_mean_absolute_error: 791.4183
#
# Epoch 00054: val_loss did not improve from 296.19345
# Epoch 55/500
# 84/84 [==============================] - 0s 119us/step - loss: 575.6541 - mean_absolute_error: 575.6541 - val_loss: 788.0871 - val_mean_absolute_error: 788.0871
#
# Epoch 00055: val_loss did not improve from 296.19345
# Epoch 56/500
# 84/84 [==============================] - 0s 131us/step - loss: 575.1344 - mean_absolute_error: 575.1344 - val_loss: 771.8657 - val_mean_absolute_error: 771.8657
#
# Epoch 00056: val_loss did not improve from 296.19345
# Epoch 57/500
# 84/84 [==============================] - 0s 154us/step - loss: 576.2283 - mean_absolute_error: 576.2283 - val_loss: 778.4908 - val_mean_absolute_error: 778.4908
#
# Epoch 00057: val_loss did not improve from 296.19345
# Epoch 58/500
# 84/84 [==============================] - 0s 131us/step - loss: 574.9153 - mean_absolute_error: 574.9153 - val_loss: 774.4233 - val_mean_absolute_error: 774.4233
#
# Epoch 00058: val_loss did not improve from 296.19345
# Epoch 59/500
# 84/84 [==============================] - 0s 107us/step - loss: 575.6616 - mean_absolute_error: 575.6616 - val_loss: 778.6588 - val_mean_absolute_error: 778.6588
#
# Epoch 00059: val_loss did not improve from 296.19345
# Epoch 60/500
# 84/84 [==============================] - 0s 107us/step - loss: 574.0545 - mean_absolute_error: 574.0545 - val_loss: 750.4892 - val_mean_absolute_error: 750.4892
#
# Epoch 00060: val_loss did not improve from 296.19345
# Epoch 61/500
# 84/84 [==============================] - 0s 143us/step - loss: 575.8179 - mean_absolute_error: 575.8179 - val_loss: 746.9214 - val_mean_absolute_error: 746.9214
#
# Epoch 00061: val_loss did not improve from 296.19345
# Epoch 62/500
# 84/84 [==============================] - 0s 131us/step - loss: 576.3792 - mean_absolute_error: 576.3792 - val_loss: 745.2366 - val_mean_absolute_error: 745.2366
#
# Epoch 00062: val_loss did not improve from 296.19345
# Epoch 63/500
# 84/84 [==============================] - 0s 107us/step - loss: 575.4730 - mean_absolute_error: 575.4730 - val_loss: 791.1854 - val_mean_absolute_error: 791.1854
#
# Epoch 00063: val_loss did not improve from 296.19345
# Epoch 64/500
# 84/84 [==============================] - 0s 142us/step - loss: 575.9200 - mean_absolute_error: 575.9200 - val_loss: 786.6176 - val_mean_absolute_error: 786.6176
#
# Epoch 00064: val_loss did not improve from 296.19345
# Epoch 65/500
# 84/84 [==============================] - 0s 142us/step - loss: 574.8517 - mean_absolute_error: 574.8517 - val_loss: 772.5688 - val_mean_absolute_error: 772.5688
#
# Epoch 00065: val_loss did not improve from 296.19345
# Epoch 66/500
# 84/84 [==============================] - 0s 119us/step - loss: 576.1767 - mean_absolute_error: 576.1767 - val_loss: 755.0686 - val_mean_absolute_error: 755.0686
#
# Epoch 00066: val_loss did not improve from 296.19345
# Epoch 67/500
# 84/84 [==============================] - 0s 107us/step - loss: 574.4298 - mean_absolute_error: 574.4298 - val_loss: 772.6255 - val_mean_absolute_error: 772.6255
#
# Epoch 00067: val_loss did not improve from 296.19345
# Epoch 68/500
# 84/84 [==============================] - 0s 107us/step - loss: 574.1282 - mean_absolute_error: 574.1282 - val_loss: 780.4463 - val_mean_absolute_error: 780.4463
#
# Epoch 00068: val_loss did not improve from 296.19345
# Epoch 69/500
# 84/84 [==============================] - 0s 107us/step - loss: 576.7388 - mean_absolute_error: 576.7388 - val_loss: 775.8625 - val_mean_absolute_error: 775.8625
# Epoch 00069: val_loss did not improve from 296.19345
# Epoch 70/500
# 84/84 [==============================] - 0s 131us/step - loss: 572.0497 - mean_absolute_error: 572.0497 - val_loss: 744.1576 - val_mean_absolute_error: 744.1576
#
# Epoch 00070: val_loss did not improve from 296.19345
# Epoch 71/500
# 84/84 [==============================] - 0s 131us/step - loss: 574.4872 - mean_absolute_error: 574.4872 - val_loss: 753.1809 - val_mean_absolute_error: 753.1809
#
# Epoch 00071: val_loss did not improve from 296.19345
# Epoch 72/500
# 84/84 [==============================] - 0s 107us/step - loss: 572.3470 - mean_absolute_error: 572.3470 - val_loss: 758.3481 - val_mean_absolute_error: 758.3481
#
# Epoch 00072: val_loss did not improve from 296.19345
# Epoch 73/500
# 84/84 [==============================] - 0s 95us/step - loss: 572.4772 - mean_absolute_error: 572.4772 - val_loss: 761.8975 - val_mean_absolute_error: 761.8975
#
# Epoch 00073: val_loss did not improve from 296.19345
# Epoch 74/500
# 84/84 [==============================] - 0s 178us/step - loss: 576.3184 - mean_absolute_error: 576.3184 - val_loss: 783.4500 - val_mean_absolute_error: 783.4500
#
# Epoch 00074: val_loss did not improve from 296.19345
# Epoch 75/500
# 84/84 [==============================] - 0s 119us/step - loss: 575.7285 - mean_absolute_error: 575.7285 - val_loss: 742.3928 - val_mean_absolute_error: 742.3928
#
# Epoch 00075: val_loss did not improve from 296.19345
# Epoch 76/500
# 84/84 [==============================] - 0s 131us/step - loss: 575.0599 - mean_absolute_error: 575.0599 - val_loss: 753.9389 - val_mean_absolute_error: 753.9389
#
# Epoch 00076: val_loss did not improve from 296.19345
# Epoch 77/500
# 84/84 [==============================] - 0s 119us/step - loss: 570.2188 - mean_absolute_error: 570.2188 - val_loss: 787.9462 - val_mean_absolute_error: 787.9462
#
# Epoch 00077: val_loss did not improve from 296.19345
# Epoch 78/500
# 84/84 [==============================] - 0s 119us/step - loss: 574.4182 - mean_absolute_error: 574.4182 - val_loss: 800.1723 - val_mean_absolute_error: 800.1723
#
# Epoch 00078: val_loss did not improve from 296.19345
# Epoch 79/500
# 84/84 [==============================] - 0s 131us/step - loss: 574.9392 - mean_absolute_error: 574.9392 - val_loss: 762.4664 - val_mean_absolute_error: 762.4664
#
# Epoch 00079: val_loss did not improve from 296.19345
# Epoch 80/500
# 84/84 [==============================] - 0s 131us/step - loss: 570.1805 - mean_absolute_error: 570.1805 - val_loss: 732.1377 - val_mean_absolute_error: 732.1377
#
# Epoch 00080: val_loss did not improve from 296.19345
# Epoch 81/500
# 84/84 [==============================] - 0s 119us/step - loss: 578.4654 - mean_absolute_error: 578.4654 - val_loss: 726.3261 - val_mean_absolute_error: 726.3261
#
# Epoch 00081: val_loss did not improve from 296.19345
# Epoch 82/500
# 84/84 [==============================] - 0s 119us/step - loss: 573.5316 - mean_absolute_error: 573.5316 - val_loss: 794.2126 - val_mean_absolute_error: 794.2126
#
# Epoch 00082: val_loss did not improve from 296.19345
# Epoch 83/500
# 84/84 [==============================] - 0s 131us/step - loss: 574.7415 - mean_absolute_error: 574.7415 - val_loss: 811.3660 - val_mean_absolute_error: 811.3660
#
# Epoch 00083: val_loss did not improve from 296.19345
# Epoch 84/500
# 84/84 [==============================] - 0s 131us/step - loss: 577.2524 - mean_absolute_error: 577.2524 - val_loss: 799.3134 - val_mean_absolute_error: 799.3134
#
# Epoch 00084: val_loss did not improve from 296.19345
# Epoch 85/500
# 84/84 [==============================] - 0s 131us/step - loss: 574.0378 - mean_absolute_error: 574.0378 - val_loss: 740.6744 - val_mean_absolute_error: 740.6744
#
# Epoch 00085: val_loss did not improve from 296.19345
# Epoch 86/500
# 84/84 [==============================] - 0s 131us/step - loss: 570.2702 - mean_absolute_error: 570.2702 - val_loss: 729.2457 - val_mean_absolute_error: 729.2457
#
# Epoch 00086: val_loss did not improve from 296.19345
# Epoch 87/500
# 84/84 [==============================] - 0s 95us/step - loss: 575.0246 - mean_absolute_error: 575.0246 - val_loss: 754.9461 - val_mean_absolute_error: 754.9461
#
# Epoch 00087: val_loss did not improve from 296.19345
# Epoch 88/500
# 84/84 [==============================] - 0s 119us/step - loss: 571.3648 - mean_absolute_error: 571.3648 - val_loss: 732.9578 - val_mean_absolute_error: 732.9578
#
# Epoch 00088: val_loss did not improve from 296.19345
# Epoch 89/500
# 84/84 [==============================] - 0s 131us/step - loss: 571.6352 - mean_absolute_error: 571.6352 - val_loss: 740.6088 - val_mean_absolute_error: 740.6088
#
# Epoch 00089: val_loss did not improve from 296.19345
# Epoch 90/500
# 84/84 [==============================] - 0s 131us/step - loss: 570.4082 - mean_absolute_error: 570.4082 - val_loss: 737.9812 - val_mean_absolute_error: 737.9812
#
# Epoch 00090: val_loss did not improve from 296.19345
# Epoch 91/500
# 84/84 [==============================] - 0s 107us/step - loss: 570.1398 - mean_absolute_error: 570.1398 - val_loss: 739.9266 - val_mean_absolute_error: 739.9266
#
# Epoch 00091: val_loss did not improve from 296.19345
# Epoch 92/500
# 84/84 [==============================] - ETA: 0s - loss: 444.9327 - mean_absolute_error: 444.932 - 0s 107us/step - loss: 569.9820 - mean_absolute_error: 569.9820 - val_loss: 740.9991 - val_mean_absolute_error: 740.9991
#
# Epoch 00092: val_loss did not improve from 296.19345
# Epoch 93/500
# 84/84 [==============================] - 0s 107us/step - loss: 573.2758 - mean_absolute_error: 573.2758 - val_loss: 765.1506 - val_mean_absolute_error: 765.1506
#
# Epoch 00093: val_loss did not improve from 296.19345
# Epoch 94/500
# 84/84 [==============================] - 0s 107us/step - loss: 570.5714 - mean_absolute_error: 570.5714 - val_loss: 752.3028 - val_mean_absolute_error: 752.3028
#
# Epoch 00094: val_loss did not improve from 296.19345
# Epoch 95/500
# 84/84 [==============================] - 0s 131us/step - loss: 569.9460 - mean_absolute_error: 569.9460 - val_loss: 747.4354 - val_mean_absolute_error: 747.4354
#
# Epoch 00095: val_loss did not improve from 296.19345
# Epoch 96/500
# 84/84 [==============================] - 0s 142us/step - loss: 570.8837 - mean_absolute_error: 570.8837 - val_loss: 753.6534 - val_mean_absolute_error: 753.6534
#
# Epoch 00096: val_loss did not improve from 296.19345
# Epoch 97/500
# 84/84 [==============================] - 0s 107us/step - loss: 570.6310 - mean_absolute_error: 570.6310 - val_loss: 783.8047 - val_mean_absolute_error: 783.8047
#
# Epoch 00097: val_loss did not improve from 296.19345
# Epoch 98/500
# 84/84 [==============================] - 0s 95us/step - loss: 574.2870 - mean_absolute_error: 574.2870 - val_loss: 786.7113 - val_mean_absolute_error: 786.7113
#
# Epoch 00098: val_loss did not improve from 296.19345
# Epoch 99/500
# 84/84 [==============================] - 0s 130us/step - loss: 569.3277 - mean_absolute_error: 569.3277 - val_loss: 739.8536 - val_mean_absolute_error: 739.8536
#
# Epoch 00099: val_loss did not improve from 296.19345
# Epoch 100/500
# 84/84 [==============================] - 0s 142us/step - loss: 573.4301 - mean_absolute_error: 573.4301 - val_loss: 689.6645 - val_mean_absolute_error: 689.6645
#
# Epoch 00100: val_loss did not improve from 296.19345
# Epoch 101/500
# 84/84 [==============================] - 0s 154us/step - loss: 579.6626 - mean_absolute_error: 579.6626 - val_loss: 725.0201 - val_mean_absolute_error: 725.0201
#
# Epoch 00101: val_loss did not improve from 296.19345
# Epoch 102/500
# 84/84 [==============================] - 0s 131us/step - loss: 575.5588 - mean_absolute_error: 575.5588 - val_loss: 787.5474 - val_mean_absolute_error: 787.5474
#
# Epoch 00102: val_loss did not improve from 296.19345
# Epoch 103/500
# 84/84 [==============================] - 0s 131us/step - loss: 571.6814 - mean_absolute_error: 571.6814 - val_loss: 765.0135 - val_mean_absolute_error: 765.0135
#
# Epoch 00103: val_loss did not improve from 296.19345
# Epoch 104/500
# 84/84 [==============================] - 0s 107us/step - loss: 568.2014 - mean_absolute_error: 568.2014 - val_loss: 715.6868 - val_mean_absolute_error: 715.6868
#
# Epoch 00104: val_loss did not improve from 296.19345
# Epoch 105/500
# 84/84 [==============================] - 0s 95us/step - loss: 580.0510 - mean_absolute_error: 580.0510 - val_loss: 715.0322 - val_mean_absolute_error: 715.0322
#
# Epoch 00105: val_loss did not improve from 296.19345
# Epoch 106/500
# 84/84 [==============================] - 0s 154us/step - loss: 579.2785 - mean_absolute_error: 579.2785 - val_loss: 764.4495 - val_mean_absolute_error: 764.4495
#
# Epoch 00106: val_loss did not improve from 296.19345
# Epoch 107/500
# 84/84 [==============================] - 0s 142us/step - loss: 570.0091 - mean_absolute_error: 570.0091 - val_loss: 749.2368 - val_mean_absolute_error: 749.2368
#
# Epoch 00107: val_loss did not improve from 296.19345
# Epoch 108/500
# 84/84 [==============================] - 0s 95us/step - loss: 569.0049 - mean_absolute_error: 569.0049 - val_loss: 729.7245 - val_mean_absolute_error: 729.7245
#
# Epoch 00108: val_loss did not improve from 296.19345
# Epoch 109/500
# 84/84 [==============================] - 0s 107us/step - loss: 570.8923 - mean_absolute_error: 570.8923 - val_loss: 728.1497 - val_mean_absolute_error: 728.1497
#
# Epoch 00109: val_loss did not improve from 296.19345
# Epoch 110/500
# 84/84 [==============================] - 0s 142us/step - loss: 569.6953 - mean_absolute_error: 569.6953 - val_loss: 768.5444 - val_mean_absolute_error: 768.5444
#
# Epoch 00110: val_loss did not improve from 296.19345
# Epoch 111/500
# 84/84 [==============================] - 0s 142us/step - loss: 571.7530 - mean_absolute_error: 571.7530 - val_loss: 784.0334 - val_mean_absolute_error: 784.0334
#
# Epoch 00111: val_loss did not improve from 296.19345
# Epoch 112/500
# 84/84 [==============================] - 0s 154us/step - loss: 571.9971 - mean_absolute_error: 571.9971 - val_loss: 762.4522 - val_mean_absolute_error: 762.4522
#
# Epoch 00112: val_loss did not improve from 296.19345
# Epoch 113/500
# 84/84 [==============================] - 0s 119us/step - loss: 570.9250 - mean_absolute_error: 570.9250 - val_loss: 756.6342 - val_mean_absolute_error: 756.6342
#
# Epoch 00113: val_loss did not improve from 296.19345
# Epoch 114/500
# 84/84 [==============================] - 0s 107us/step - loss: 568.6457 - mean_absolute_error: 568.6457 - val_loss: 719.1644 - val_mean_absolute_error: 719.1644
#
# Epoch 00114: val_loss did not improve from 296.19345
# Epoch 115/500
# 84/84 [==============================] - 0s 166us/step - loss: 570.4690 - mean_absolute_error: 570.4690 - val_loss: 736.0845 - val_mean_absolute_error: 736.0845
#
# Epoch 00115: val_loss did not improve from 296.19345
# Epoch 116/500
# 84/84 [==============================] - 0s 131us/step - loss: 568.0958 - mean_absolute_error: 568.0958 - val_loss: 746.1064 - val_mean_absolute_error: 746.1064
#
# Epoch 00116: val_loss did not improve from 296.19345
# Epoch 117/500
# 84/84 [==============================] - 0s 119us/step - loss: 569.1546 - mean_absolute_error: 569.1546 - val_loss: 751.9965 - val_mean_absolute_error: 751.9965
#
# Epoch 00117: val_loss did not improve from 296.19345
# Epoch 118/500
# 84/84 [==============================] - 0s 95us/step - loss: 569.6006 - mean_absolute_error: 569.6006 - val_loss: 729.9291 - val_mean_absolute_error: 729.9291
#
# Epoch 00118: val_loss did not improve from 296.19345
# Epoch 119/500
# 84/84 [==============================] - 0s 142us/step - loss: 569.6558 - mean_absolute_error: 569.6558 - val_loss: 731.8969 - val_mean_absolute_error: 731.8969
#
# Epoch 00119: val_loss did not improve from 296.19345
# Epoch 120/500
# 84/84 [==============================] - 0s 107us/step - loss: 570.9418 - mean_absolute_error: 570.9418 - val_loss: 735.2794 - val_mean_absolute_error: 735.2794
#
# Epoch 00120: val_loss did not improve from 296.19345
# Epoch 121/500
# 84/84 [==============================] - 0s 131us/step - loss: 568.2396 - mean_absolute_error: 568.2396 - val_loss: 712.8420 - val_mean_absolute_error: 712.8420
#
# Epoch 00121: val_loss did not improve from 296.19345
# Epoch 122/500
# 84/84 [==============================] - 0s 119us/step - loss: 573.1484 - mean_absolute_error: 573.1484 - val_loss: 764.9890 - val_mean_absolute_error: 764.9890
#
# Epoch 00122: val_loss did not improve from 296.19345
# Epoch 123/500
# 84/84 [==============================] - 0s 142us/step - loss: 568.7175 - mean_absolute_error: 568.7175 - val_loss: 776.6322 - val_mean_absolute_error: 776.6322
#
# Epoch 00123: val_loss did not improve from 296.19345
# Epoch 124/500
# 84/84 [==============================] - 0s 131us/step - loss: 577.9858 - mean_absolute_error: 577.9858 - val_loss: 790.6918 - val_mean_absolute_error: 790.6918
#
# Epoch 00124: val_loss did not improve from 296.19345
# Epoch 125/500
# 84/84 [==============================] - 0s 131us/step - loss: 567.4805 - mean_absolute_error: 567.4805 - val_loss: 737.4290 - val_mean_absolute_error: 737.4290
#
# Epoch 00125: val_loss did not improve from 296.19345
# Epoch 126/500
# 84/84 [==============================] - 0s 142us/step - loss: 571.8539 - mean_absolute_error: 571.8539 - val_loss: 711.7256 - val_mean_absolute_error: 711.7256
#
# Epoch 00126: val_loss did not improve from 296.19345
# Epoch 127/500
# 84/84 [==============================] - 0s 107us/step - loss: 570.8969 - mean_absolute_error: 570.8969 - val_loss: 769.3268 - val_mean_absolute_error: 769.3268
#
# Epoch 00127: val_loss did not improve from 296.19345
# Epoch 128/500
# 84/84 [==============================] - 0s 131us/step - loss: 566.2609 - mean_absolute_error: 566.2609 - val_loss: 798.6783 - val_mean_absolute_error: 798.6783
#
# Epoch 00128: val_loss did not improve from 296.19345
# Epoch 129/500
# 84/84 [==============================] - 0s 142us/step - loss: 570.8308 - mean_absolute_error: 570.8308 - val_loss: 796.7783 - val_mean_absolute_error: 796.7783
#
# Epoch 00129: val_loss did not improve from 296.19345
# Epoch 130/500
# 84/84 [==============================] - 0s 131us/step - loss: 572.8195 - mean_absolute_error: 572.8195 - val_loss: 780.7715 - val_mean_absolute_error: 780.7715
#
# Epoch 00130: val_loss did not improve from 296.19345
# Epoch 131/500
# 84/84 [==============================] - 0s 107us/step - loss: 563.8431 - mean_absolute_error: 563.8431 - val_loss: 718.1945 - val_mean_absolute_error: 718.1945
#
# Epoch 00131: val_loss did not improve from 296.19345
# Epoch 132/500
# 84/84 [==============================] - 0s 107us/step - loss: 576.4262 - mean_absolute_error: 576.4262 - val_loss: 693.1553 - val_mean_absolute_error: 693.1553
#
# Epoch 00132: val_loss did not improve from 296.19345
# Epoch 133/500
# 84/84 [==============================] - 0s 131us/step - loss: 576.3528 - mean_absolute_error: 576.3528 - val_loss: 745.8604 - val_mean_absolute_error: 745.8604
#
# Epoch 00133: val_loss did not improve from 296.19345
# Epoch 134/500
# 84/84 [==============================] - 0s 142us/step - loss: 576.5502 - mean_absolute_error: 576.5502 - val_loss: 829.9545 - val_mean_absolute_error: 829.9545
#
# Epoch 00134: val_loss did not improve from 296.19345
# Epoch 135/500
# 84/84 [==============================] - 0s 107us/step - loss: 574.8980 - mean_absolute_error: 574.8980 - val_loss: 815.1537 - val_mean_absolute_error: 815.1537
#
# Epoch 00135: val_loss did not improve from 296.19345
# Epoch 136/500
# 84/84 [==============================] - ETA: 0s - loss: 594.6805 - mean_absolute_error: 594.680 - 0s 142us/step - loss: 570.9051 - mean_absolute_error: 570.9051 - val_loss: 770.1355 - val_mean_absolute_error: 770.1355
#
# Epoch 00136: val_loss did not improve from 296.19345
# Epoch 137/500
# 84/84 [==============================] - 0s 142us/step - loss: 567.3854 - mean_absolute_error: 567.3854 - val_loss: 749.8811 - val_mean_absolute_error: 749.8811
#
# Epoch 00137: val_loss did not improve from 296.19345
# Epoch 138/500
# 84/84 [==============================] - 0s 119us/step - loss: 567.3265 - mean_absolute_error: 567.3265 - val_loss: 751.8149 - val_mean_absolute_error: 751.8149
#
# Epoch 00138: val_loss did not improve from 296.19345
# Epoch 139/500
# 84/84 [==============================] - 0s 95us/step - loss: 566.3671 - mean_absolute_error: 566.3671 - val_loss: 757.8608 - val_mean_absolute_error: 757.8608
#
# Epoch 00139: val_loss did not improve from 296.19345
# Epoch 140/500
# 84/84 [==============================] - 0s 95us/step - loss: 565.6513 - mean_absolute_error: 565.6513 - val_loss: 776.8517 - val_mean_absolute_error: 776.8517
# Epoch 00140: val_loss did not improve from 296.19345
# Epoch 141/500
# 84/84 [==============================] - 0s 107us/step - loss: 565.7558 - mean_absolute_error: 565.7558 - val_loss: 777.3117 - val_mean_absolute_error: 777.3117
#
# Epoch 00141: val_loss did not improve from 296.19345
# Epoch 142/500
# 84/84 [==============================] - 0s 131us/step - loss: 566.9218 - mean_absolute_error: 566.9218 - val_loss: 764.5379 - val_mean_absolute_error: 764.5379
#
# Epoch 00142: val_loss did not improve from 296.19345
# Epoch 143/500
# 84/84 [==============================] - 0s 131us/step - loss: 565.4933 - mean_absolute_error: 565.4933 - val_loss: 752.7887 - val_mean_absolute_error: 752.7887
#
# Epoch 00143: val_loss did not improve from 296.19345
# Epoch 144/500
# 84/84 [==============================] - 0s 107us/step - loss: 565.7395 - mean_absolute_error: 565.7395 - val_loss: 736.0403 - val_mean_absolute_error: 736.0403
#
# Epoch 00144: val_loss did not improve from 296.19345
# Epoch 145/500
# 84/84 [==============================] - 0s 119us/step - loss: 566.0360 - mean_absolute_error: 566.0360 - val_loss: 745.1645 - val_mean_absolute_error: 745.1645
#
# Epoch 00145: val_loss did not improve from 296.19345
# Epoch 146/500
# 84/84 [==============================] - 0s 95us/step - loss: 565.8813 - mean_absolute_error: 565.8813 - val_loss: 761.7949 - val_mean_absolute_error: 761.7949
#
# Epoch 00146: val_loss did not improve from 296.19345
# Epoch 147/500
# 84/84 [==============================] - 0s 154us/step - loss: 566.4629 - mean_absolute_error: 566.4629 - val_loss: 756.7086 - val_mean_absolute_error: 756.7086
#
# Epoch 00147: val_loss did not improve from 296.19345
# Epoch 148/500
# 84/84 [==============================] - 0s 131us/step - loss: 565.4717 - mean_absolute_error: 565.4717 - val_loss: 764.4993 - val_mean_absolute_error: 764.4993
#
# Epoch 00148: val_loss did not improve from 296.19345
# Epoch 149/500
# 84/84 [==============================] - 0s 95us/step - loss: 566.8213 - mean_absolute_error: 566.8213 - val_loss: 753.5355 - val_mean_absolute_error: 753.5355
#
# Epoch 00149: val_loss did not improve from 296.19345
# Epoch 150/500
# 84/84 [==============================] - 0s 95us/step - loss: 564.6411 - mean_absolute_error: 564.6411 - val_loss: 763.1541 - val_mean_absolute_error: 763.1541
#
# Epoch 00150: val_loss did not improve from 296.19345
# Epoch 151/500
# 84/84 [==============================] - 0s 107us/step - loss: 566.2032 - mean_absolute_error: 566.2032 - val_loss: 764.9813 - val_mean_absolute_error: 764.9813
#
# Epoch 00151: val_loss did not improve from 296.19345
# Epoch 152/500
# 84/84 [==============================] - 0s 131us/step - loss: 565.2341 - mean_absolute_error: 565.2341 - val_loss: 734.2529 - val_mean_absolute_error: 734.2529
#
# Epoch 00152: val_loss did not improve from 296.19345
# Epoch 153/500
# 84/84 [==============================] - 0s 131us/step - loss: 564.5434 - mean_absolute_error: 564.5434 - val_loss: 733.7670 - val_mean_absolute_error: 733.7670
#
# Epoch 00153: val_loss did not improve from 296.19345
# Epoch 154/500
# 84/84 [==============================] - 0s 107us/step - loss: 565.5402 - mean_absolute_error: 565.5402 - val_loss: 749.2102 - val_mean_absolute_error: 749.2102
#
# Epoch 00154: val_loss did not improve from 296.19345
# Epoch 155/500
# 84/84 [==============================] - 0s 107us/step - loss: 565.2859 - mean_absolute_error: 565.2859 - val_loss: 738.4621 - val_mean_absolute_error: 738.4621
#
# Epoch 00155: val_loss did not improve from 296.19345
# Epoch 156/500
# 84/84 [==============================] - 0s 131us/step - loss: 564.0448 - mean_absolute_error: 564.0448 - val_loss: 738.4782 - val_mean_absolute_error: 738.4782
#
# Epoch 00156: val_loss did not improve from 296.19345
# Epoch 157/500
# 84/84 [==============================] - 0s 154us/step - loss: 565.0028 - mean_absolute_error: 565.0028 - val_loss: 745.1496 - val_mean_absolute_error: 745.1496
#
# Epoch 00157: val_loss did not improve from 296.19345
# Epoch 158/500
# 84/84 [==============================] - 0s 154us/step - loss: 564.4498 - mean_absolute_error: 564.4498 - val_loss: 760.3475 - val_mean_absolute_error: 760.3475
#
# Epoch 00158: val_loss did not improve from 296.19345
# Epoch 159/500
# 84/84 [==============================] - 0s 142us/step - loss: 564.5406 - mean_absolute_error: 564.5406 - val_loss: 741.7091 - val_mean_absolute_error: 741.7091
#
# Epoch 00159: val_loss did not improve from 296.19345
# Epoch 160/500
# 84/84 [==============================] - 0s 142us/step - loss: 565.3149 - mean_absolute_error: 565.3149 - val_loss: 724.5203 - val_mean_absolute_error: 724.5203
#
# Epoch 00160: val_loss did not improve from 296.19345
# Epoch 161/500
# 84/84 [==============================] - 0s 130us/step - loss: 569.5188 - mean_absolute_error: 569.5188 - val_loss: 755.2510 - val_mean_absolute_error: 755.2510
#
# Epoch 00161: val_loss did not improve from 296.19345
# Epoch 162/500
# 84/84 [==============================] - 0s 131us/step - loss: 575.8441 - mean_absolute_error: 575.8441 - val_loss: 726.9622 - val_mean_absolute_error: 726.9622
#
# Epoch 00162: val_loss did not improve from 296.19345
# Epoch 163/500
# 84/84 [==============================] - 0s 131us/step - loss: 568.0769 - mean_absolute_error: 568.0769 - val_loss: 766.5682 - val_mean_absolute_error: 766.5682
#
# Epoch 00163: val_loss did not improve from 296.19345
# Epoch 164/500
# 84/84 [==============================] - 0s 107us/step - loss: 564.3502 - mean_absolute_error: 564.3502 - val_loss: 752.0223 - val_mean_absolute_error: 752.0223
#
# Epoch 00164: val_loss did not improve from 296.19345
# Epoch 165/500
# 84/84 [==============================] - 0s 107us/step - loss: 562.7837 - mean_absolute_error: 562.7837 - val_loss: 736.0786 - val_mean_absolute_error: 736.0786
#
# Epoch 00165: val_loss did not improve from 296.19345
# Epoch 166/500
# 84/84 [==============================] - 0s 142us/step - loss: 566.5861 - mean_absolute_error: 566.5861 - val_loss: 726.7126 - val_mean_absolute_error: 726.7126
#
# Epoch 00166: val_loss did not improve from 296.19345
# Epoch 167/500
# 84/84 [==============================] - 0s 142us/step - loss: 563.6904 - mean_absolute_error: 563.6904 - val_loss: 771.1654 - val_mean_absolute_error: 771.1654
#
# Epoch 00167: val_loss did not improve from 296.19345
# Epoch 168/500
# 84/84 [==============================] - 0s 131us/step - loss: 565.6614 - mean_absolute_error: 565.6614 - val_loss: 782.5052 - val_mean_absolute_error: 782.5052
#
# Epoch 00168: val_loss did not improve from 296.19345
# Epoch 169/500
# 84/84 [==============================] - 0s 142us/step - loss: 566.7458 - mean_absolute_error: 566.7458 - val_loss: 733.2938 - val_mean_absolute_error: 733.2938
#
# Epoch 00169: val_loss did not improve from 296.19345
# Epoch 170/500
# 84/84 [==============================] - 0s 131us/step - loss: 568.3333 - mean_absolute_error: 568.3333 - val_loss: 714.1564 - val_mean_absolute_error: 714.1564
#
# Epoch 00170: val_loss did not improve from 296.19345
# Epoch 171/500
# 84/84 [==============================] - 0s 95us/step - loss: 568.7956 - mean_absolute_error: 568.7956 - val_loss: 773.0922 - val_mean_absolute_error: 773.0922
#
# Epoch 00171: val_loss did not improve from 296.19345
# Epoch 172/500
# 84/84 [==============================] - 0s 142us/step - loss: 567.1693 - mean_absolute_error: 567.1693 - val_loss: 757.8611 - val_mean_absolute_error: 757.8611
#
# Epoch 00172: val_loss did not improve from 296.19345
# Epoch 173/500
# 84/84 [==============================] - 0s 131us/step - loss: 562.5635 - mean_absolute_error: 562.5635 - val_loss: 773.3236 - val_mean_absolute_error: 773.3236
#
# Epoch 00173: val_loss did not improve from 296.19345
# Epoch 174/500
# 84/84 [==============================] - 0s 119us/step - loss: 564.8549 - mean_absolute_error: 564.8549 - val_loss: 747.1628 - val_mean_absolute_error: 747.1628
#
# Epoch 00174: val_loss did not improve from 296.19345
# Epoch 175/500
# 84/84 [==============================] - 0s 119us/step - loss: 562.4663 - mean_absolute_error: 562.4663 - val_loss: 742.9719 - val_mean_absolute_error: 742.9719
#
# Epoch 00175: val_loss did not improve from 296.19345
# Epoch 176/500
# 84/84 [==============================] - 0s 107us/step - loss: 564.5776 - mean_absolute_error: 564.5776 - val_loss: 722.2583 - val_mean_absolute_error: 722.2583
# Epoch 00176: val_loss did not improve from 296.19345
# Epoch 177/500
# 84/84 [==============================] - 0s 107us/step - loss: 561.6377 - mean_absolute_error: 561.6377 - val_loss: 745.0367 - val_mean_absolute_error: 745.0367
#
# Epoch 00177: val_loss did not improve from 296.19345
# Epoch 178/500
# 84/84 [==============================] - ETA: 0s - loss: 537.3221 - mean_absolute_error: 537.322 - 0s 131us/step - loss: 574.5465 - mean_absolute_error: 574.5465 - val_loss: 774.9739 - val_mean_absolute_error: 774.9739
#
# Epoch 00178: val_loss did not improve from 296.19345
# Epoch 179/500
# 84/84 [==============================] - 0s 107us/step - loss: 560.5801 - mean_absolute_error: 560.5801 - val_loss: 723.0616 - val_mean_absolute_error: 723.0616
#
# Epoch 00179: val_loss did not improve from 296.19345
# Epoch 180/500
# 84/84 [==============================] - 0s 107us/step - loss: 559.8467 - mean_absolute_error: 559.8467 - val_loss: 692.7566 - val_mean_absolute_error: 692.7566
#
# Epoch 00180: val_loss did not improve from 296.19345
# Epoch 181/500
# 84/84 [==============================] - 0s 154us/step - loss: 567.6093 - mean_absolute_error: 567.6093 - val_loss: 721.6580 - val_mean_absolute_error: 721.6580
#
# Epoch 00181: val_loss did not improve from 296.19345
# Epoch 182/500
# 84/84 [==============================] - 0s 119us/step - loss: 560.9012 - mean_absolute_error: 560.9012 - val_loss: 758.4415 - val_mean_absolute_error: 758.4415
#
# Epoch 00182: val_loss did not improve from 296.19345
# Epoch 183/500
# 84/84 [==============================] - 0s 119us/step - loss: 560.8285 - mean_absolute_error: 560.8285 - val_loss: 768.8531 - val_mean_absolute_error: 768.8531
#
# Epoch 00183: val_loss did not improve from 296.19345
# Epoch 184/500
# 84/84 [==============================] - 0s 119us/step - loss: 562.7778 - mean_absolute_error: 562.7778 - val_loss: 775.5726 - val_mean_absolute_error: 775.5726
#
# Epoch 00184: val_loss did not improve from 296.19345
# Epoch 185/500
# 84/84 [==============================] - 0s 107us/step - loss: 561.7749 - mean_absolute_error: 561.7749 - val_loss: 747.5084 - val_mean_absolute_error: 747.5084
#
# Epoch 00185: val_loss did not improve from 296.19345
# Epoch 186/500
# 84/84 [==============================] - 0s 107us/step - loss: 559.9790 - mean_absolute_error: 559.9790 - val_loss: 695.5626 - val_mean_absolute_error: 695.5626
#
# Epoch 00186: val_loss did not improve from 296.19345
# Epoch 187/500
# 84/84 [==============================] - 0s 119us/step - loss: 568.8142 - mean_absolute_error: 568.8142 - val_loss: 722.6172 - val_mean_absolute_error: 722.6172
#
# Epoch 00187: val_loss did not improve from 296.19345
# Epoch 188/500
# 84/84 [==============================] - 0s 119us/step - loss: 563.1046 - mean_absolute_error: 563.1046 - val_loss: 741.1512 - val_mean_absolute_error: 741.1512
#
# Epoch 00188: val_loss did not improve from 296.19345
# Epoch 189/500
# 84/84 [==============================] - 0s 119us/step - loss: 561.0642 - mean_absolute_error: 561.0642 - val_loss: 729.7634 - val_mean_absolute_error: 729.7634
#
# Epoch 00189: val_loss did not improve from 296.19345
# Epoch 190/500
# 84/84 [==============================] - 0s 107us/step - loss: 561.3907 - mean_absolute_error: 561.3907 - val_loss: 733.7924 - val_mean_absolute_error: 733.7924
#
# Epoch 00190: val_loss did not improve from 296.19345
# Epoch 191/500
# 84/84 [==============================] - 0s 107us/step - loss: 560.2747 - mean_absolute_error: 560.2747 - val_loss: 744.7941 - val_mean_absolute_error: 744.7941
#
# Epoch 00191: val_loss did not improve from 296.19345
# Epoch 192/500
# 84/84 [==============================] - 0s 107us/step - loss: 560.6511 - mean_absolute_error: 560.6511 - val_loss: 733.6585 - val_mean_absolute_error: 733.6585
#
# Epoch 00192: val_loss did not improve from 296.19345
# Epoch 193/500
# 84/84 [==============================] - 0s 131us/step - loss: 559.1360 - mean_absolute_error: 559.1360 - val_loss: 738.2069 - val_mean_absolute_error: 738.2069
#
# Epoch 00193: val_loss did not improve from 296.19345
# Epoch 194/500
# 84/84 [==============================] - 0s 131us/step - loss: 559.1702 - mean_absolute_error: 559.1702 - val_loss: 733.1306 - val_mean_absolute_error: 733.1306
#
# Epoch 00194: val_loss did not improve from 296.19345
# Epoch 195/500
# 84/84 [==============================] - 0s 119us/step - loss: 560.7850 - mean_absolute_error: 560.7850 - val_loss: 733.0170 - val_mean_absolute_error: 733.0170
#
# Epoch 00195: val_loss did not improve from 296.19345
# Epoch 196/500
# 84/84 [==============================] - 0s 107us/step - loss: 559.2245 - mean_absolute_error: 559.2245 - val_loss: 749.2699 - val_mean_absolute_error: 749.2699
#
# Epoch 00196: val_loss did not improve from 296.19345
# Epoch 197/500
# 84/84 [==============================] - 0s 142us/step - loss: 561.8032 - mean_absolute_error: 561.8032 - val_loss: 740.9231 - val_mean_absolute_error: 740.9231
#
# Epoch 00197: val_loss did not improve from 296.19345
# Epoch 198/500
# 84/84 [==============================] - 0s 119us/step - loss: 560.3963 - mean_absolute_error: 560.3963 - val_loss: 751.8444 - val_mean_absolute_error: 751.8444
#
# Epoch 00198: val_loss did not improve from 296.19345
# Epoch 199/500
# 84/84 [==============================] - 0s 119us/step - loss: 559.4378 - mean_absolute_error: 559.4378 - val_loss: 734.5228 - val_mean_absolute_error: 734.5228
#
# Epoch 00199: val_loss did not improve from 296.19345
# Epoch 200/500
# 84/84 [==============================] - 0s 107us/step - loss: 560.1834 - mean_absolute_error: 560.1834 - val_loss: 746.9036 - val_mean_absolute_error: 746.9036
#
# Epoch 00200: val_loss did not improve from 296.19345
# Epoch 201/500
# 84/84 [==============================] - 0s 154us/step - loss: 559.0323 - mean_absolute_error: 559.0323 - val_loss: 737.4855 - val_mean_absolute_error: 737.4855
#
# Epoch 00201: val_loss did not improve from 296.19345
# Epoch 202/500
# 84/84 [==============================] - 0s 131us/step - loss: 559.5929 - mean_absolute_error: 559.5929 - val_loss: 722.7556 - val_mean_absolute_error: 722.7556
#
# Epoch 00202: val_loss did not improve from 296.19345
# Epoch 203/500
# 84/84 [==============================] - 0s 119us/step - loss: 558.8960 - mean_absolute_error: 558.8960 - val_loss: 756.2961 - val_mean_absolute_error: 756.2961
#
# Epoch 00203: val_loss did not improve from 296.19345
# Epoch 204/500
# 84/84 [==============================] - 0s 119us/step - loss: 558.8122 - mean_absolute_error: 558.8122 - val_loss: 752.1221 - val_mean_absolute_error: 752.1221
#
# Epoch 00204: val_loss did not improve from 296.19345
# Epoch 205/500
# ...
#
# Epoch 00431: val_loss did not improve from 296.19345
# Epoch 432/500
# 84/84 [==============================] - 0s 119us/step - loss: 496.8277 - mean_absolute_error: 496.8277 - val_loss: 558.2614 - val_mean_absolute_error: 558.2614
#
# Epoch 00432: val_loss did not improve from 296.19345
# Epoch 433/500
# 84/84 [==============================] - 0s 249us/step - loss: 490.1093 - mean_absolute_error: 490.1093 - val_loss: 669.3639 - val_mean_absolute_error: 669.3639
#
# Epoch 00433: val_loss did not improve from 296.19345
# Epoch 434/500
# 84/84 [==============================] - 0s 131us/step - loss: 537.1943 - mean_absolute_error: 537.1943 - val_loss: 704.3427 - val_mean_absolute_error: 704.3427
#
# Epoch 00434: val_loss did not improve from 296.19345
# Epoch 435/500
# 84/84 [==============================] - 0s 178us/step - loss: 504.5547 - mean_absolute_error: 504.5547 - val_loss: 562.5400 - val_mean_absolute_error: 562.5400
#
# Epoch 00435: val_loss did not improve from 296.19345
# Epoch 436/500
# 84/84 [==============================] - 0s 154us/step - loss: 515.5537 - mean_absolute_error: 515.5537 - val_loss: 563.6338 - val_mean_absolute_error: 563.6338
#
# Epoch 00436: val_loss did not improve from 296.19345
# Epoch 437/500
# 84/84 [==============================] - 0s 190us/step - loss: 505.1114 - mean_absolute_error: 505.1114 - val_loss: 666.5714 - val_mean_absolute_error: 666.5714
#
# Epoch 00437: val_loss did not improve from 296.19345
# Epoch 438/500
# 84/84 [==============================] - 0s 95us/step - loss: 503.4045 - mean_absolute_error: 503.4045 - val_loss: 650.1149 - val_mean_absolute_error: 650.1149
#
# Epoch 00438: val_loss did not improve from 296.19345
# Epoch 439/500
# 84/84 [==============================] - 0s 131us/step - loss: 485.1816 - mean_absolute_error: 485.1816 - val_loss: 597.7878 - val_mean_absolute_error: 597.7878
#
# Epoch 00439: val_loss did not improve from 296.19345
# Epoch 440/500
# 84/84 [==============================] - 0s 107us/step - loss: 512.0073 - mean_absolute_error: 512.0073 - val_loss: 596.5751 - val_mean_absolute_error: 596.5751
#
# Epoch 00440: val_loss did not improve from 296.19345
# Epoch 441/500
# 84/84 [==============================] - 0s 131us/step - loss: 490.5498 - mean_absolute_error: 490.5498 - val_loss: 668.5043 - val_mean_absolute_error: 668.5043
#
# Epoch 00441: val_loss did not improve from 296.19345
# Epoch 442/500
# 84/84 [==============================] - 0s 119us/step - loss: 500.0468 - mean_absolute_error: 500.0468 - val_loss: 640.9171 - val_mean_absolute_error: 640.9171
#
# Epoch 00442: val_loss did not improve from 296.19345
# Epoch 443/500
# 84/84 [==============================] - 0s 119us/step - loss: 481.5321 - mean_absolute_error: 481.5321 - val_loss: 570.8742 - val_mean_absolute_error: 570.8742
#
# Epoch 00443: val_loss did not improve from 296.19345
# Epoch 444/500
# 84/84 [==============================] - 0s 154us/step - loss: 514.5413 - mean_absolute_error: 514.5413 - val_loss: 607.8094 - val_mean_absolute_error: 607.8094
#
# Epoch 00444: val_loss did not improve from 296.19345
# Epoch 445/500
# 84/84 [==============================] - 0s 178us/step - loss: 488.7162 - mean_absolute_error: 488.7162 - val_loss: 703.1765 - val_mean_absolute_error: 703.1765
#
# Epoch 00445: val_loss did not improve from 296.19345
# Epoch 446/500
# 84/84 [==============================] - 0s 131us/step - loss: 512.6324 - mean_absolute_error: 512.6324 - val_loss: 660.5859 - val_mean_absolute_error: 660.5859
#
# Epoch 00446: val_loss did not improve from 296.19345
# Epoch 447/500
# 84/84 [==============================] - 0s 131us/step - loss: 480.4240 - mean_absolute_error: 480.4240 - val_loss: 602.1287 - val_mean_absolute_error: 602.1287
#
# Epoch 00447: val_loss did not improve from 296.19345
# Epoch 448/500
# 84/84 [==============================] - 0s 131us/step - loss: 488.9324 - mean_absolute_error: 488.9324 - val_loss: 604.4221 - val_mean_absolute_error: 604.4221
#
# Epoch 00448: val_loss did not improve from 296.19345
# Epoch 449/500
# 84/84 [==============================] - 0s 131us/step - loss: 480.4998 - mean_absolute_error: 480.4998 - val_loss: 614.7427 - val_mean_absolute_error: 614.7427
#
# Epoch 00449: val_loss did not improve from 296.19345
# Epoch 450/500
# 84/84 [==============================] - 0s 130us/step - loss: 480.8265 - mean_absolute_error: 480.8265 - val_loss: 621.5054 - val_mean_absolute_error: 621.5054
#
# Epoch 00450: val_loss did not improve from 296.19345
# Epoch 451/500
# 84/84 [==============================] - 0s 119us/step - loss: 494.5540 - mean_absolute_error: 494.5540 - val_loss: 634.8789 - val_mean_absolute_error: 634.8789
#
# Epoch 00451: val_loss did not improve from 296.19345
# Epoch 452/500
# 84/84 [==============================] - 0s 131us/step - loss: 474.2105 - mean_absolute_error: 474.2105 - val_loss: 577.2933 - val_mean_absolute_error: 577.2933
#
# Epoch 00452: val_loss did not improve from 296.19345
# Epoch 453/500
# 84/84 [==============================] - 0s 119us/step - loss: 491.4310 - mean_absolute_error: 491.4310 - val_loss: 602.2482 - val_mean_absolute_error: 602.2482
#
# Epoch 00453: val_loss did not improve from 296.19345
# Epoch 454/500
# 84/84 [==============================] - 0s 119us/step - loss: 480.7744 - mean_absolute_error: 480.7744 - val_loss: 647.4470 - val_mean_absolute_error: 647.4470
#
# Epoch 00454: val_loss did not improve from 296.19345
# Epoch 455/500
# 84/84 [==============================] - 0s 119us/step - loss: 486.7686 - mean_absolute_error: 486.7686 - val_loss: 618.0831 - val_mean_absolute_error: 618.0831
#
# Epoch 00455: val_loss did not improve from 296.19345
# Epoch 456/500
# 84/84 [==============================] - 0s 131us/step - loss: 474.8743 - mean_absolute_error: 474.8743 - val_loss: 579.1898 - val_mean_absolute_error: 579.1898
#
# Epoch 00456: val_loss did not improve from 296.19345
# Epoch 457/500
# 84/84 [==============================] - 0s 107us/step - loss: 482.6731 - mean_absolute_error: 482.6731 - val_loss: 648.0295 - val_mean_absolute_error: 648.0295
#
# Epoch 00457: val_loss did not improve from 296.19345
# Epoch 458/500
# 84/84 [==============================] - 0s 131us/step - loss: 494.7208 - mean_absolute_error: 494.7208 - val_loss: 708.6414 - val_mean_absolute_error: 708.6414
#
# Epoch 00458: val_loss did not improve from 296.19345
# Epoch 459/500
# 84/84 [==============================] - 0s 131us/step - loss: 497.5407 - mean_absolute_error: 497.5407 - val_loss: 656.3481 - val_mean_absolute_error: 656.3481
#
# Epoch 00459: val_loss did not improve from 296.19345
# Epoch 460/500
# 84/84 [==============================] - 0s 95us/step - loss: 477.0558 - mean_absolute_error: 477.0558 - val_loss: 592.8176 - val_mean_absolute_error: 592.8176
#
# Epoch 00460: val_loss did not improve from 296.19345
# Epoch 461/500
# 84/84 [==============================] - 0s 154us/step - loss: 491.9703 - mean_absolute_error: 491.9703 - val_loss: 598.9800 - val_mean_absolute_error: 598.9800
#
# Epoch 00461: val_loss did not improve from 296.19345
# Epoch 462/500
# 84/84 [==============================] - 0s 131us/step - loss: 484.7127 - mean_absolute_error: 484.7127 - val_loss: 621.1197 - val_mean_absolute_error: 621.1197
#
# Epoch 00462: val_loss did not improve from 296.19345
# Epoch 463/500
# 84/84 [==============================] - 0s 142us/step - loss: 487.2514 - mean_absolute_error: 487.2514 - val_loss: 559.6992 - val_mean_absolute_error: 559.6992
#
# Epoch 00463: val_loss did not improve from 296.19345
# Epoch 464/500
# 84/84 [==============================] - 0s 95us/step - loss: 477.5943 - mean_absolute_error: 477.5943 - val_loss: 654.9337 - val_mean_absolute_error: 654.9337
#
# Epoch 00464: val_loss did not improve from 296.19345
# Epoch 465/500
# 84/84 [==============================] - 0s 95us/step - loss: 505.8524 - mean_absolute_error: 505.8524 - val_loss: 736.0038 - val_mean_absolute_error: 736.0038
#
# Epoch 00465: val_loss did not improve from 296.19345
# Epoch 466/500
# 84/84 [==============================] - 0s 95us/step - loss: 494.5194 - mean_absolute_error: 494.5194 - val_loss: 669.4044 - val_mean_absolute_error: 669.4044
#
# Epoch 00466: val_loss did not improve from 296.19345
# Epoch 467/500
# 84/84 [==============================] - 0s 154us/step - loss: 491.0769 - mean_absolute_error: 491.0769 - val_loss: 605.4708 - val_mean_absolute_error: 605.4708
#
# Epoch 00467: val_loss did not improve from 296.19345
# Epoch 468/500
# 84/84 [==============================] - 0s 131us/step - loss: 469.7754 - mean_absolute_error: 469.7754 - val_loss: 661.7523 - val_mean_absolute_error: 661.7523
#
# Epoch 00468: val_loss did not improve from 296.19345
# Epoch 469/500
# 84/84 [==============================] - 0s 119us/step - loss: 515.2621 - mean_absolute_error: 515.2621 - val_loss: 712.3298 - val_mean_absolute_error: 712.3298
#
# Epoch 00469: val_loss did not improve from 296.19345
# Epoch 470/500
# 84/84 [==============================] - 0s 142us/step - loss: 509.0998 - mean_absolute_error: 509.0998 - val_loss: 596.8832 - val_mean_absolute_error: 596.8832
#
# Epoch 00470: val_loss did not improve from 296.19345
# Epoch 471/500
# 84/84 [==============================] - 0s 131us/step - loss: 478.3959 - mean_absolute_error: 478.3959 - val_loss: 596.2330 - val_mean_absolute_error: 596.2330
#
# Epoch 00471: val_loss did not improve from 296.19345
# Epoch 472/500
# 84/84 [==============================] - 0s 107us/step - loss: 470.5250 - mean_absolute_error: 470.5250 - val_loss: 655.4438 - val_mean_absolute_error: 655.4438
#
# Epoch 00472: val_loss did not improve from 296.19345
# Epoch 473/500
# 84/84 [==============================] - 0s 131us/step - loss: 486.8103 - mean_absolute_error: 486.8103 - val_loss: 674.9813 - val_mean_absolute_error: 674.9813
#
# Epoch 00473: val_loss did not improve from 296.19345
# Epoch 474/500
# 84/84 [==============================] - 0s 131us/step - loss: 490.5474 - mean_absolute_error: 490.5474 - val_loss: 627.0950 - val_mean_absolute_error: 627.0950
#
# Epoch 00474: val_loss did not improve from 296.19345
# Epoch 475/500
# 84/84 [==============================] - 0s 95us/step - loss: 472.3642 - mean_absolute_error: 472.3642 - val_loss: 627.9249 - val_mean_absolute_error: 627.9249
#
# Epoch 00475: val_loss did not improve from 296.19345
# Epoch 476/500
# 84/84 [==============================] - 0s 142us/step - loss: 471.1551 - mean_absolute_error: 471.1551 - val_loss: 629.8705 - val_mean_absolute_error: 629.8705
#
# Epoch 00476: val_loss did not improve from 296.19345
# Epoch 477/500
# 84/84 [==============================] - 0s 119us/step - loss: 472.3923 - mean_absolute_error: 472.3923 - val_loss: 604.3427 - val_mean_absolute_error: 604.3427
#
# Epoch 00477: val_loss did not improve from 296.19345
# Epoch 478/500
# 84/84 [==============================] - 0s 119us/step - loss: 467.8071 - mean_absolute_error: 467.8071 - val_loss: 579.8758 - val_mean_absolute_error: 579.8758
#
# Epoch 00478: val_loss did not improve from 296.19345
# Epoch 479/500
# 84/84 [==============================] - 0s 119us/step - loss: 478.0332 - mean_absolute_error: 478.0332 - val_loss: 606.4098 - val_mean_absolute_error: 606.4098
#
# Epoch 00479: val_loss did not improve from 296.19345
# Epoch 480/500
# 84/84 [==============================] - 0s 131us/step - loss: 466.4069 - mean_absolute_error: 466.4069 - val_loss: 620.3135 - val_mean_absolute_error: 620.3135
#
# Epoch 00480: val_loss did not improve from 296.19345
# Epoch 481/500
# 84/84 [==============================] - 0s 95us/step - loss: 479.0890 - mean_absolute_error: 479.0890 - val_loss: 605.5230 - val_mean_absolute_error: 605.5230
#
# Epoch 00481: val_loss did not improve from 296.19345
# Epoch 482/500
# 84/84 [==============================] - 0s 107us/step - loss: 474.9736 - mean_absolute_error: 474.9736 - val_loss: 569.7585 - val_mean_absolute_error: 569.7585
#
# Epoch 00482: val_loss did not improve from 296.19345
# Epoch 483/500
# 84/84 [==============================] - 0s 154us/step - loss: 475.5000 - mean_absolute_error: 475.5000 - val_loss: 644.7170 - val_mean_absolute_error: 644.7170
#
# Epoch 00483: val_loss did not improve from 296.19345
# Epoch 484/500
# 84/84 [==============================] - 0s 131us/step - loss: 474.8077 - mean_absolute_error: 474.8077 - val_loss: 654.0883 - val_mean_absolute_error: 654.0883
#
# Epoch 00484: val_loss did not improve from 296.19345
# Epoch 485/500
# 84/84 [==============================] - 0s 95us/step - loss: 475.9627 - mean_absolute_error: 475.9627 - val_loss: 597.9055 - val_mean_absolute_error: 597.9055
#
# Epoch 00485: val_loss did not improve from 296.19345
# Epoch 486/500
# 84/84 [==============================] - 0s 107us/step - loss: 468.8763 - mean_absolute_error: 468.8763 - val_loss: 618.3634 - val_mean_absolute_error: 618.3634
#
# Epoch 00486: val_loss did not improve from 296.19345
# Epoch 487/500
# 84/84 [==============================] - ETA: 0s - loss: 503.6723 - mean_absolute_error: 503.672 - 0s 142us/step - loss: 466.8828 - mean_absolute_error: 466.8828 - val_loss: 633.2770 - val_mean_absolute_error: 633.2770
#
# Epoch 00487: val_loss did not improve from 296.19345
# Epoch 488/500
# 84/84 [==============================] - 0s 131us/step - loss: 468.4554 - mean_absolute_error: 468.4554 - val_loss: 593.3676 - val_mean_absolute_error: 593.3676
#
# Epoch 00488: val_loss did not improve from 296.19345
# Epoch 489/500
# 84/84 [==============================] - 0s 119us/step - loss: 465.6761 - mean_absolute_error: 465.6761 - val_loss: 595.4900 - val_mean_absolute_error: 595.4900
#
# Epoch 00489: val_loss did not improve from 296.19345
# Epoch 490/500
# 84/84 [==============================] - 0s 214us/step - loss: 465.7877 - mean_absolute_error: 465.7877 - val_loss: 578.0015 - val_mean_absolute_error: 578.0015
#
# Epoch 00490: val_loss did not improve from 296.19345
# Epoch 491/500
# 84/84 [==============================] - 0s 166us/step - loss: 468.8969 - mean_absolute_error: 468.8969 - val_loss: 631.5250 - val_mean_absolute_error: 631.5250
#
# Epoch 00491: val_loss did not improve from 296.19345
# Epoch 492/500
# 84/84 [==============================] - 0s 119us/step - loss: 469.2246 - mean_absolute_error: 469.2246 - val_loss: 629.5925 - val_mean_absolute_error: 629.5925
#
# Epoch 00492: val_loss did not improve from 296.19345
# Epoch 493/500
# 84/84 [==============================] - 0s 131us/step - loss: 461.9191 - mean_absolute_error: 461.9191 - val_loss: 595.1038 - val_mean_absolute_error: 595.1038
#
# Epoch 00493: val_loss did not improve from 296.19345
# Epoch 494/500
# 84/84 [==============================] - 0s 131us/step - loss: 465.7451 - mean_absolute_error: 465.7451 - val_loss: 615.1920 - val_mean_absolute_error: 615.1920
#
# Epoch 00494: val_loss did not improve from 296.19345
# Epoch 495/500
# 84/84 [==============================] - 0s 131us/step - loss: 467.1183 - mean_absolute_error: 467.1183 - val_loss: 615.5474 - val_mean_absolute_error: 615.5474
#
# Epoch 00495: val_loss did not improve from 296.19345
# Epoch 496/500
# 84/84 [==============================] - 0s 95us/step - loss: 465.8921 - mean_absolute_error: 465.8921 - val_loss: 582.1483 - val_mean_absolute_error: 582.1483
#
# Epoch 00496: val_loss did not improve from 296.19345
# Epoch 497/500
# 84/84 [==============================] - 0s 107us/step - loss: 463.9767 - mean_absolute_error: 463.9767 - val_loss: 611.1125 - val_mean_absolute_error: 611.1125
# Epoch 00497: val_loss did not improve from 296.19345
# Epoch 498/500
# 84/84 [==============================] - 0s 107us/step - loss: 460.0536 - mean_absolute_error: 460.0536 - val_loss: 618.4594 - val_mean_absolute_error: 618.4594
#
# Epoch 00498: val_loss did not improve from 296.19345
# Epoch 499/500
# 84/84 [==============================] - 0s 131us/step - loss: 459.4091 - mean_absolute_error: 459.4091 - val_loss: 634.9106 - val_mean_absolute_error: 634.9106
#
# Epoch 00499: val_loss did not improve from 296.19345
# Epoch 500/500
# 84/84 [==============================] - 0s 107us/step - loss: 463.5986 - mean_absolute_error: 463.5986 - val_loss: 609.9695 - val_mean_absolute_error: 609.9695
#
# Epoch 00500: val_loss did not improve from 296.19345

# %% [markdown]
# #### ====================================================================================================

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
wights_file = 'LV(lowVIF07)-제모제week-Weights-010--296.19345.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
# rf나,XGB회귀 분석을위한 훈련/검증 dataset생산
train_X, val_X, train_y, val_y = train_test_split(train, target[:cut_line], test_size = 0.25, random_state = 14)

# %%
# RandomForest 회귀분석
model = RandomForestRegressor()
model.fit(train_X,train_y)

# Get the mean absolute error on the validation data
RFpredicted = model.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  431.3820105820107

# %%
# XGBRegressor 회귀분석
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# [18:41:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  449.2639739828765

# %%
# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)

combined = lv_week_w.loc[:,'temp':'PM25']
target = lv_week_w.loc[:,'qty']
# RandomForest 회귀분석 예측 qty생산
RFpredicted = model.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)

result_df = pd.DataFrame()
result_df['week'] = lv_week_w['week']
result_df['qty'] = lv_week_w.loc[:,'qty']

print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions
# Out:
# keras 신경망 predictions (157, 1)
# randomforest 예상 (157,)
# XGBpredictions (157,)

# %%
df_graph = result_df.loc[:,['week','keras_qty','rf_qty','xgb_qty','qty']]
df_graph['week'] = pd.to_datetime(df_graph['week'])

# %%
# 2016
df_graph = result_df.loc[result_df.week <=53]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.legend()
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
plt.show()

# %%
# 2017
df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
plt.legend()
plt.show()

# %%
# 2018
df_graph = result_df.loc[(result_df.week >=105)]
plt.figure(figsize=(15.5, 10))
plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
plt.legend()
plt.show()

# %%
# 2016~2018
plt.figure(figsize=(15.5, 10))
plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
plt.legend()
plt.show()

# %%
# 날씨+sns와 '생수' 을 사용하면 2017까진 적당하고 2018년도는 예측율 급락
#  -> 과적합화 발생
# 날씨와 '생수' 판매량만 이용하니 ㅇㅋ

# %%
# orginal_mean = np.mean(result_df.qty)
# result_df['qtyMinusMean'] = (result_df.qty - orginal_mean )
# result_df['qtyMinusMeanSquared'] = (result_df.qty - orginal_mean )**2

# result_df['kerasMiunsMeanSquared'] = (result_df.keras_qty - orginal_mean)**2
# result_df['rfMiunsMeanSquared'] = (result_df.rf_qty - orginal_mean)**2
# result_df['xgbMiunsMeanSquared'] = (result_df.xgb_qty - orginal_mean)**2

# print('kreas R-sq',(sum(result_df['kerasMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
# print('rf R-sq',(sum(result_df['rfMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))
# print('xgb R-sq',(sum(result_df['xgbMiunsMeanSquared']) / sum(result_df['qtyMinusMeanSquared'])))

# %%
path = 'D:/project/contest/data/result/'
result_df.to_csv(path+item+'_'+grouped_by+'_predict_lowVIF07.csv', encoding='utf-8', index=False)
