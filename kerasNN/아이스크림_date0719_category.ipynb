# %%
# 인공신경망관련 패키지
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# 회귀분석 관련 패키지
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from xgboost import XGBRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from scipy import stats

# R2 값, 결정계수 계산
from sklearn.metrics import r2_score

# OLS회귀분석
import statsmodels.api as sm

# 시각화 패키지
from matplotlib import pyplot as plt
import seaborn as sb

# 데이터 처리를 위한 패키지
import pandas as pd
import numpy as np
import math

# 다중공선성(multicollinearity) 처리를 위한VIF 확인 패키지
from statsmodels.stats.outliers_influence import variance_inflation_factor

import matplotlib
import matplotlib.pyplot as plt
# 한글 처리
from matplotlib import rc, font_manager
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NanumGothicCoding.ttf').get_name()
rc('font',family=font_name)

# from matplotlib import rcParams
# rcParams['font.family'] = 'NanumGothicCoding'

# - 마이너스 사인 처리
matplotlib.rcParams['axes.unicode_minus'] = False

# DeprecationWarning경고 무시
# 향후 안쓰일 함수들을 이용해서 만들어져 있기 때문에 필요하다 없으면, 사방이 붉어진다.
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#########################################################################
# MAD 기반 예제코드
def mad_based_outlier(points, thresh=3.5):
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)
    modified_z_score = 0.6745 * diff / med_abs_deviation
    return modified_z_score > thresh 

# 출처: https://pythonanalysis.tistory.com/7 [Python 데이터 분석]
#########################################################################

# 소셜 데이터 처리를 위한 함수
# 1. 모든 소셜 데이터 column들의 첫번째는 : 날짜다.
# 2. 각 소셜데이터는 social_키워드.블로그/트위터/뉴스/총합 으로 되어 있다.
def changeColNames(d,before, after) : 
    # 컬럼이름 시리즈로 만들어 반환
    # 통합하기 쉽게, 모든 데이터들의 날짜컬럼 이름을 date로 통일
    new_col_names = ['date']
    new_col_names.extend(list(d.columns)[1:])
    d.columns = new_col_names
    return pd.Series(d.columns).apply(lambda x : x.replace(before,after))

#########################################################################
# modeling 함수로 만들어 처리하기
def linReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item, cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    model = LinearRegression().fit(X_train, y_train)
  
    print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(model.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(model.score(X_test, y_test)))

    
def ridgeReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(X_train, y_train)
    
    print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(ridge.score(X_train, y_train)))
    print('검증세트점수 : {:.2f}'.format(ridge.score(X_test, y_test)))


def lassoReg(df, item, cols_using):
    cols = cols_using
    X = df.loc[df['category']==item,cols]
    y = df.loc[df['category']==item,'qty']

    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

    lasso = Lasso(alpha=0.1, max_iter=1000).fit(X=X_train, y=y_train)
  
    print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
    print('훈련세트점수 : {:.2f}'.format(lasso.score(X_train, y_train)) )
    print('검증세트점수 : {:.2f}'.format(lasso.score(X_test, y_test)) )

    #사용한 특성수
    print('사용한 특성수 : {}'.format(np.sum(lasso.coef_ != 0)) )
#########################################################################

# 자료가 1일 1행이라는 전제하에
# df길이를 이용하여 날짜수를 계산, 이후 2016년 1월1일을 1번째주 1일이라 기준하에
# 몇번째 주인지 알려주는 컬럼 추가. 향후 주단위로 종합할때 스인다.
def addDayWeek(df):
    df_work = df.copy()
    df_work['day'] = pd.Series(range(1,df_work.shape[0]+1)).astype('int64')
    df_work['week'] = df_work['day'].apply(lambda x : math.ceil(x/7))
    return df_work
#########################################################################
# 자료를 병합해주는 함수, 어떤 item인지 어느 컬럼을 기준으로 할지 받아서 병합
def mergeForAnalysis(df1, df2, df3, item, on_what='date'):
    merged_df = pd.merge(df1.loc[df1.category==item], df2, on=on_what, how='left')
    merged_df = pd.merge(merged_df, df3, on=on_what, how='left')
    return merged_df


#########################################################################
def lowVIF(df, n=7, cols_using =['temp', 'cloud', 'wind','humid', 'hpa', 'sun_time', 'lgt_time', 
       'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25'] ):
    col_to_use = cols_using
    vif = pd.DataFrame()
    vif["VIF_Factor"] = [variance_inflation_factor(
        df[col_to_use].values, i) for i in range(df[col_to_use].shape[1])]
    vif["features"] = col_to_use
    vif.sort_values("VIF_Factor")
    lowest_vif = vif.sort_values("VIF_Factor")[:n].reset_index()
    lowest_vif.drop(columns='index', inplace=True)
    return lowest_vif

#########################################################################
# ols모델용 formula 생성
def formulaGen(target, ind_features):
    '''
    formulaGen(목표컬럼명,[변수컬럼명1, 변수컬럼명2,...])
    '''
    custom_formula = target + " ~ "
    for f in range(len(ind_features)):
        custom_formula += ind_features[f]
        if f!=(len(ind_features)-1):
            custom_formula += " + "
    return custom_formula
#########################################################################

# %%
# 데이터 불러오기 (전처리 된 GS, 랄라블라, 날씨)
gs = pd.read_csv('d:/project/contest/data/processed/p_gs.csv', parse_dates=['date'])
lv = pd.read_csv('d:/project/contest/data/processed/p_lavla.csv', parse_dates=['date'])
# w = pd.read_csv('d:/project/contest/data/processed/p_wUVair_seoul_category.csv', parse_dates=['date'], index_col=0)
w = pd.read_csv('d:/project/contest/data/processed/날씨_ver071915.csv', parse_dates=['date'], index_col=0)
sns_all = pd.read_csv('d:/project/contest/data/processed/social_all.csv', parse_dates=['date'])

# GS/lv 서울시만
gs_seoul = gs.loc[gs.pvn_nm =='서울특별시']
lv_seoul = lv.loc[lv.pvn_nm =='서울특별시']
w_seoul = w.loc[w['loc']==108]

cols_to_keep = ['date','bor_nm','gender','age_cd','category','qty']

# 일일, 구단위, 상품별 판매량 종합
gs_grouped = gs_seoul[cols_to_keep].groupby(by=['date','bor_nm','category']).sum().reset_index()

# 일단위로 자료 종합(qty는 일일 합계)
day_gs_grouped = gs_grouped.groupby(by=['date','category']).sum().reset_index()

# %%
# '아이스크림'만 빼서 df생성
item = '아이스크림'
grouped_by = 'date'
day_gs_grouped_w_item = pd.merge(day_gs_grouped.loc[day_gs_grouped.category==item],w_seoul,on='date',how='left')
# day_gs_grouped_w_item.head(3)
day_gs_grouped_w_sns_item = pd.merge(day_gs_grouped_w_item, sns_all,on='date',how='left')

# 일단 uv = 자외선 지수는 결측치가 많아서 제외
selected_cols = ['date', 'category', 'qty', 'temp', 'rain', 'cloud', 'wind','humid', 'hpa',
                 'sun_time', 'lgt_time', 'snow','rain_or_not','snow_or_not','미세', '초미세', '공기상태',
                 'SO2', 'CO', 'O3', 'NO2', 'PM10', 'PM25',
                 'pm_blog', 'pm_twitter', 'pm_news', 'pm_total',
                 'health_blog', 'health_twitter', 'health_news', 'health_total',
                 'date_blog', 'date_twitter', 'date_news', 'date_total',
                 'br_blog', 'br_twitter', 'br_news', 'br_total',
                 'hobby_blog', 'hobby_twitter', 'hobby_news', 'hobby_total']
gs_day_w = day_gs_grouped_w_sns_item[selected_cols]

# %%
# list_col = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10'] # +,'rain_or_not','snow_or_not'
list_col = ['temp', 'cloud', 'wind','lgt_time',
            'rain_or_not', 'snow_or_not', '공기상태'] #+'rain_or_not', 'snow_or_not'
lowVIF(w,20,list_col)
# Out:
#    VIF_Factor     features
# 0    1.239620  snow_or_not
# 1    2.479988  rain_or_not
# 2    3.114369         공기상태
# 3    4.013218         temp
# 4    6.725926        cloud
# 5    8.084050     lgt_time
# 6    9.334878         wind

# %%
train_data = gs_day_w.loc[gs_day_w.date.between('2016-01-01','2017-12-31')]
test_data = gs_day_w.loc[gs_day_w.date.between('2018-01-01','2018-12-31')]

# 3년치 데이터 분리 : 종속변수('qty': 판매량)와 독립변수(판매량 제외 나머지 전부)
# 날씨 데이터만
combined = gs_day_w.loc[:,list_col]
target = gs_day_w.loc[:,'qty']
Xy = pd.concat([target,combined], axis=1)

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

print ('수치형 자료 컬럼 갯수 :',len(num_cols))
print ('오브젝트형 자료 컬럼 갯수 :',len(cat_cols))
# Out:
# 수치형 자료 컬럼 갯수 : 7
# 오브젝트형 자료 컬럼 갯수 : 0

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        # 해당 컬럼의 데이터 타입이 object란 소리는 숫자가 아니다 = 분류형 데이터
        if( df[col].dtype == np.dtype('object')):
            # 더미 컬럼 생성
            dummies = pd.get_dummies(df[col],prefix=col)
            # 원본 데이터에 이어 붙이기 axis=1 컬럼방향으로 
            df = pd.concat([df,dummies],axis=1)

            # 기존의 str형 컬럼 삭제
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('분류형(category형) 컬럼 수정 전, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
#### 내가 '공기상태'라는 컬럼이 사실은 category형이라는것을 알기에 직접 dummy컬럼 생성
airCondition_dummies = pd.get_dummies(combined['공기상태'],prefix='공기상태')
combined = pd.concat([combined, airCondition_dummies], axis=1)
combined.drop(['공기상태'],axis = 1 , inplace=True)
######################################################################################
print('분류형(category형) 컬럼 수정 후, 총 {} 개의 columns이 있었습니다.'.format(combined.shape[1]))
# Out:
# 분류형(category형) 컬럼 수정 전, 총 7 개의 columns이 있었습니다.
# 분류형(category형) 컬럼 수정 후, 총 10 개의 columns이 있었습니다.

# %%
combined.head(2)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
# 1   5.7    7.8   2.0       3.6            0            0       0       1
#
#    공기상태_2  공기상태_3
# 0       1       0
# 1       0       0

# %%
# 공기상태_0,공기상태_1,공기상태_2가 전부 0이면,   공기상태_3이 1이란 소리고
#                                                               공기상태가 '매우나쁨' 임을 추정할수 있다.
# 그런이유로 공기상태_3삭제
combined.drop(['공기상태_3'],axis = 1 , inplace=True)
combined.head(1)
# Out:
#    temp  cloud  wind  lgt_time  rain_or_not  snow_or_not  공기상태_0  공기상태_1  \
# 0   1.2    7.0   1.6       2.1            0            0       0       0
#
#    공기상태_2
# 0       1

# %%
Xy = pd.concat([target,combined], axis=1)
# Xy.head(1)

# %%
# 첫 2년 : 732 일
cut_line = 732
def split_combined():
    global combined
    train = combined[:cut_line]
    test = combined[cut_line:]

    return train , test 
  
train, test = split_combined()

train.shape
# Out:
# (732, 9)

# %%
# 신경망 모델 생성
NN_model = Sequential()

# 인풋 레이어
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# 숨겨진 레이어
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# 출력 레이어
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
# optimizer에 여러 방식이 있다.
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 18:29:23.149062   208 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 18:29:23.164021   208 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 18:29:23.167013   208 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# W0719 18:29:23.222892   208 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1280
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 166,145
# Trainable params: 166,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 인공 신경망에 의해 생성된 weight 자료를 저장하기 위해서
checkpoint_name = item+grouped_by+'-Weights-{epoch:03d}--{val_loss:.5f}-cat02-vf05.hdf5' 

# save_best_only값이 저장되어, 모든 weight값을 저장하지 않고, val_loss값이 줄어들때마다(적을수록 좋다.) 저장
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
# 예제에서는 target을 대회에서 주는 target데이터를 기준으로 미리 train데이터와 맞춰졌있지만
# gs/lv데이터는 아니다. 그래서 위에서 나누는 기준으로 삼은cut_line=732을 이용하여 데이터 사이즈를 맞춰준다.
# 아니면 애시당초에(맨처음에) 훈련용 데이터와 타겟을 만들어 놓는것도 좋다.
NN_model.fit(train, target[:cut_line], epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# W0719 17:37:55.728432  7712 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0719 17:37:55.863609  7712 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 585 samples, validate on 147 samples
# Epoch 1/500
# 585/585 [==============================] - 0s 779us/step - loss: 21701.7053 - mean_absolute_error: 21701.7053 - val_loss: 14620.2423 - val_mean_absolute_error: 14620.2423
#
# Epoch 00001: val_loss improved from inf to 14620.24227, saving model to 아이스크림date-Weights-001--14620.24227-cat02-vf05.hdf5
# Epoch 2/500
# 585/585 [==============================] - 0s 128us/step - loss: 21179.9825 - mean_absolute_error: 21179.9825 - val_loss: 12741.0272 - val_mean_absolute_error: 12741.0272
#
# Epoch 00002: val_loss improved from 14620.24227 to 12741.02715, saving model to 아이스크림date-Weights-002--12741.02715-cat02-vf05.hdf5
# Epoch 3/500
# 585/585 [==============================] - 0s 130us/step - loss: 13895.5889 - mean_absolute_error: 13895.5889 - val_loss: 6804.5304 - val_mean_absolute_error: 6804.5304
#
# Epoch 00003: val_loss improved from 12741.02715 to 6804.53038, saving model to 아이스크림date-Weights-003--6804.53038-cat02-vf05.hdf5
# Epoch 4/500
# 585/585 [==============================] - 0s 118us/step - loss: 5634.5927 - mean_absolute_error: 5634.5927 - val_loss: 4966.1033 - val_mean_absolute_error: 4966.1033
#
# Epoch 00004: val_loss improved from 6804.53038 to 4966.10334, saving model to 아이스크림date-Weights-004--4966.10334-cat02-vf05.hdf5
# Epoch 5/500
# 585/585 [==============================] - 0s 125us/step - loss: 4915.4414 - mean_absolute_error: 4915.4414 - val_loss: 6338.9528 - val_mean_absolute_error: 6338.9528
#
# Epoch 00005: val_loss did not improve from 4966.10334
# Epoch 6/500
# 585/585 [==============================] - 0s 128us/step - loss: 4782.2774 - mean_absolute_error: 4782.2774 - val_loss: 6744.0846 - val_mean_absolute_error: 6744.0846
#
# Epoch 00006: val_loss did not improve from 4966.10334
# Epoch 7/500
# 585/585 [==============================] - 0s 204us/step - loss: 4862.0488 - mean_absolute_error: 4862.0488 - val_loss: 5405.9299 - val_mean_absolute_error: 5405.9299
#
# Epoch 00007: val_loss did not improve from 4966.10334
# Epoch 8/500
# 585/585 [==============================] - 0s 187us/step - loss: 4457.9460 - mean_absolute_error: 4457.9460 - val_loss: 5771.7293 - val_mean_absolute_error: 5771.7293
#
# Epoch 00008: val_loss did not improve from 4966.10334
# Epoch 9/500
# 585/585 [==============================] - 0s 205us/step - loss: 4313.9607 - mean_absolute_error: 4313.9607 - val_loss: 6005.3600 - val_mean_absolute_error: 6005.3600
#
# Epoch 00009: val_loss did not improve from 4966.10334
# Epoch 10/500
# 585/585 [==============================] - 0s 468us/step - loss: 4211.3279 - mean_absolute_error: 4211.3279 - val_loss: 5409.2248 - val_mean_absolute_error: 5409.2248
#
# Epoch 00010: val_loss did not improve from 4966.10334
# Epoch 11/500
# 585/585 [==============================] - 0s 189us/step - loss: 4183.5181 - mean_absolute_error: 4183.5181 - val_loss: 6726.1244 - val_mean_absolute_error: 6726.1244
#
# Epoch 00011: val_loss did not improve from 4966.10334
# Epoch 12/500
# 585/585 [==============================] - 0s 145us/step - loss: 4042.8756 - mean_absolute_error: 4042.8756 - val_loss: 6007.9950 - val_mean_absolute_error: 6007.9950
#
# Epoch 00012: val_loss did not improve from 4966.10334
# Epoch 13/500
# 585/585 [==============================] - 0s 159us/step - loss: 3940.0689 - mean_absolute_error: 3940.0689 - val_loss: 7153.9207 - val_mean_absolute_error: 7153.9207
#
# Epoch 00013: val_loss did not improve from 4966.10334
# Epoch 14/500
# 585/585 [==============================] - 0s 137us/step - loss: 3869.5500 - mean_absolute_error: 3869.5500 - val_loss: 5864.6803 - val_mean_absolute_error: 5864.6803
#
# Epoch 00014: val_loss did not improve from 4966.10334
# Epoch 15/500
# 585/585 [==============================] - 0s 147us/step - loss: 3802.9692 - mean_absolute_error: 3802.9692 - val_loss: 6549.5836 - val_mean_absolute_error: 6549.5836
#
# Epoch 00015: val_loss did not improve from 4966.10334
# Epoch 16/500
# 585/585 [==============================] - 0s 148us/step - loss: 3766.5532 - mean_absolute_error: 3766.5532 - val_loss: 7486.6605 - val_mean_absolute_error: 7486.6605
#
# Epoch 00016: val_loss did not improve from 4966.10334
# Epoch 17/500
# 585/585 [==============================] - 0s 126us/step - loss: 3864.5709 - mean_absolute_error: 3864.5709 - val_loss: 5063.3524 - val_mean_absolute_error: 5063.3524
#
# Epoch 00017: val_loss did not improve from 4966.10334
# Epoch 18/500
# 585/585 [==============================] - 0s 130us/step - loss: 3703.2099 - mean_absolute_error: 3703.2099 - val_loss: 5920.5393 - val_mean_absolute_error: 5920.5393
#
# Epoch 00018: val_loss did not improve from 4966.10334
# Epoch 19/500
# 585/585 [==============================] - 0s 135us/step - loss: 3654.3165 - mean_absolute_error: 3654.3165 - val_loss: 5081.6868 - val_mean_absolute_error: 5081.6868
#
# Epoch 00019: val_loss did not improve from 4966.10334
# Epoch 20/500
# 585/585 [==============================] - 0s 147us/step - loss: 3636.4223 - mean_absolute_error: 3636.4223 - val_loss: 5473.3077 - val_mean_absolute_error: 5473.3077
#
# Epoch 00020: val_loss did not improve from 4966.10334
# Epoch 21/500
# 585/585 [==============================] - 0s 138us/step - loss: 3614.9406 - mean_absolute_error: 3614.9406 - val_loss: 5900.4491 - val_mean_absolute_error: 5900.4491
#
# Epoch 00021: val_loss did not improve from 4966.10334
# Epoch 22/500
# 585/585 [==============================] - 0s 143us/step - loss: 3633.7523 - mean_absolute_error: 3633.7523 - val_loss: 5923.9291 - val_mean_absolute_error: 5923.9291
#
# Epoch 00022: val_loss did not improve from 4966.10334
# Epoch 23/500
# 585/585 [==============================] - 0s 155us/step - loss: 3578.8267 - mean_absolute_error: 3578.8267 - val_loss: 5457.6740 - val_mean_absolute_error: 5457.6740
#
# Epoch 00023: val_loss did not improve from 4966.10334
# Epoch 24/500
# 585/585 [==============================] - 0s 148us/step - loss: 3562.6973 - mean_absolute_error: 3562.6973 - val_loss: 5294.2935 - val_mean_absolute_error: 5294.2935
#
# Epoch 00024: val_loss did not improve from 4966.10334
# Epoch 25/500
# 585/585 [==============================] - 0s 150us/step - loss: 3635.1283 - mean_absolute_error: 3635.1283 - val_loss: 5984.1128 - val_mean_absolute_error: 5984.1128
#
# Epoch 00025: val_loss did not improve from 4966.10334
# Epoch 26/500
# 585/585 [==============================] - 0s 130us/step - loss: 3540.2482 - mean_absolute_error: 3540.2482 - val_loss: 5094.9569 - val_mean_absolute_error: 5094.9569
#
# Epoch 00026: val_loss did not improve from 4966.10334
# Epoch 27/500
# 585/585 [==============================] - 0s 155us/step - loss: 3543.8432 - mean_absolute_error: 3543.8432 - val_loss: 6280.5572 - val_mean_absolute_error: 6280.5572
#
# Epoch 00027: val_loss did not improve from 4966.10334
# Epoch 28/500
# 585/585 [==============================] - 0s 143us/step - loss: 3578.5079 - mean_absolute_error: 3578.5079 - val_loss: 5976.0511 - val_mean_absolute_error: 5976.0511
#
# Epoch 00028: val_loss did not improve from 4966.10334
# Epoch 29/500
# 585/585 [==============================] - 0s 157us/step - loss: 3529.1666 - mean_absolute_error: 3529.1666 - val_loss: 6135.9737 - val_mean_absolute_error: 6135.9737
#
# Epoch 00029: val_loss did not improve from 4966.10334
# Epoch 30/500
# 585/585 [==============================] - 0s 157us/step - loss: 3498.6742 - mean_absolute_error: 3498.6742 - val_loss: 5087.2824 - val_mean_absolute_error: 5087.2824
#
# Epoch 00030: val_loss did not improve from 4966.10334
# Epoch 31/500
# 585/585 [==============================] - 0s 147us/step - loss: 3534.6342 - mean_absolute_error: 3534.6342 - val_loss: 5582.3331 - val_mean_absolute_error: 5582.3331
#
# Epoch 00031: val_loss did not improve from 4966.10334
# Epoch 32/500
# 585/585 [==============================] - 0s 166us/step - loss: 3513.3982 - mean_absolute_error: 3513.3982 - val_loss: 4589.6224 - val_mean_absolute_error: 4589.6224
#
# Epoch 00032: val_loss improved from 4966.10334 to 4589.62237, saving model to 아이스크림date-Weights-032--4589.62237-cat02-vf05.hdf5
# Epoch 33/500
# 585/585 [==============================] - 0s 157us/step - loss: 3572.0078 - mean_absolute_error: 3572.0078 - val_loss: 5667.7209 - val_mean_absolute_error: 5667.7209
#
# Epoch 00033: val_loss did not improve from 4589.62237
# Epoch 34/500
# 585/585 [==============================] - 0s 170us/step - loss: 3507.2748 - mean_absolute_error: 3507.2748 - val_loss: 5650.9767 - val_mean_absolute_error: 5650.9767
#
# Epoch 00034: val_loss did not improve from 4589.62237
# Epoch 35/500
# 585/585 [==============================] - 0s 162us/step - loss: 3493.7811 - mean_absolute_error: 3493.7811 - val_loss: 5361.9451 - val_mean_absolute_error: 5361.9451
#
# Epoch 00035: val_loss did not improve from 4589.62237
# Epoch 36/500
# 585/585 [==============================] - 0s 145us/step - loss: 3503.2842 - mean_absolute_error: 3503.2842 - val_loss: 5472.8549 - val_mean_absolute_error: 5472.8549
#
# Epoch 00036: val_loss did not improve from 4589.62237
# Epoch 37/500
# 585/585 [==============================] - 0s 155us/step - loss: 3496.3706 - mean_absolute_error: 3496.3706 - val_loss: 4510.0438 - val_mean_absolute_error: 4510.0438
#
# Epoch 00037: val_loss improved from 4589.62237 to 4510.04379, saving model to 아이스크림date-Weights-037--4510.04379-cat02-vf05.hdf5
# Epoch 38/500
# 585/585 [==============================] - 0s 217us/step - loss: 3532.9752 - mean_absolute_error: 3532.9752 - val_loss: 5257.6926 - val_mean_absolute_error: 5257.6926
#
# Epoch 00038: val_loss did not improve from 4510.04379
# Epoch 39/500
# 585/585 [==============================] - 0s 162us/step - loss: 3467.1656 - mean_absolute_error: 3467.1656 - val_loss: 5992.2182 - val_mean_absolute_error: 5992.2182
#
# Epoch 00039: val_loss did not improve from 4510.04379
# Epoch 40/500
# 585/585 [==============================] - 0s 181us/step - loss: 3513.4335 - mean_absolute_error: 3513.4335 - val_loss: 6759.1562 - val_mean_absolute_error: 6759.1562
#
# Epoch 00040: val_loss did not improve from 4510.04379
# Epoch 41/500
# 585/585 [==============================] - 0s 218us/step - loss: 3546.7098 - mean_absolute_error: 3546.7098 - val_loss: 6306.7898 - val_mean_absolute_error: 6306.7898
#
# Epoch 00041: val_loss did not improve from 4510.04379
# Epoch 42/500
# 585/585 [==============================] - 0s 148us/step - loss: 3525.5070 - mean_absolute_error: 3525.5070 - val_loss: 6535.9914 - val_mean_absolute_error: 6535.9914
#
# Epoch 00042: val_loss did not improve from 4510.04379
# Epoch 43/500
# 585/585 [==============================] - 0s 157us/step - loss: 3578.4962 - mean_absolute_error: 3578.4962 - val_loss: 6196.0540 - val_mean_absolute_error: 6196.0540
#
# Epoch 00043: val_loss did not improve from 4510.04379
# Epoch 44/500
# 585/585 [==============================] - 0s 162us/step - loss: 3485.3463 - mean_absolute_error: 3485.3463 - val_loss: 5552.9824 - val_mean_absolute_error: 5552.9824
#
# Epoch 00044: val_loss did not improve from 4510.04379
# Epoch 45/500
# 585/585 [==============================] - 0s 175us/step - loss: 3472.9474 - mean_absolute_error: 3472.9474 - val_loss: 5289.7378 - val_mean_absolute_error: 5289.7378
#
# Epoch 00045: val_loss did not improve from 4510.04379
# Epoch 46/500
# 585/585 [==============================] - 0s 228us/step - loss: 3473.4594 - mean_absolute_error: 3473.4594 - val_loss: 5400.6656 - val_mean_absolute_error: 5400.6656
#
# Epoch 00046: val_loss did not improve from 4510.04379
# Epoch 47/500
# 585/585 [==============================] - 0s 155us/step - loss: 3458.1109 - mean_absolute_error: 3458.1109 - val_loss: 5815.2477 - val_mean_absolute_error: 5815.2477
#
# Epoch 00047: val_loss did not improve from 4510.04379
# Epoch 48/500
# 585/585 [==============================] - 0s 157us/step - loss: 3462.2131 - mean_absolute_error: 3462.2131 - val_loss: 6516.1572 - val_mean_absolute_error: 6516.1572
#
# Epoch 00048: val_loss did not improve from 4510.04379
# Epoch 49/500
# 585/585 [==============================] - 0s 153us/step - loss: 3535.3195 - mean_absolute_error: 3535.3195 - val_loss: 5038.4149 - val_mean_absolute_error: 5038.4149
#
# Epoch 00049: val_loss did not improve from 4510.04379
# Epoch 50/500
# 585/585 [==============================] - 0s 159us/step - loss: 3469.2498 - mean_absolute_error: 3469.2498 - val_loss: 6253.6449 - val_mean_absolute_error: 6253.6449
#
# Epoch 00050: val_loss did not improve from 4510.04379
# Epoch 51/500
# 585/585 [==============================] - 0s 194us/step - loss: 3507.6112 - mean_absolute_error: 3507.6112 - val_loss: 5555.1081 - val_mean_absolute_error: 5555.1081
#
# Epoch 00051: val_loss did not improve from 4510.04379
# Epoch 52/500
# 585/585 [==============================] - 0s 165us/step - loss: 3470.2676 - mean_absolute_error: 3470.2676 - val_loss: 5813.5590 - val_mean_absolute_error: 5813.5590
#
# Epoch 00052: val_loss did not improve from 4510.04379
# Epoch 53/500
# 585/585 [==============================] - 0s 174us/step - loss: 3546.9867 - mean_absolute_error: 3546.9867 - val_loss: 5432.9094 - val_mean_absolute_error: 5432.9094
#
# Epoch 00053: val_loss did not improve from 4510.04379
# Epoch 54/500
# 585/585 [==============================] - 0s 167us/step - loss: 3433.8065 - mean_absolute_error: 3433.8065 - val_loss: 5022.4684 - val_mean_absolute_error: 5022.4684
#
# Epoch 00054: val_loss did not improve from 4510.04379
# Epoch 55/500
# 585/585 [==============================] - 0s 159us/step - loss: 3500.8573 - mean_absolute_error: 3500.8573 - val_loss: 4537.4963 - val_mean_absolute_error: 4537.4963
#
# Epoch 00055: val_loss did not improve from 4510.04379
# Epoch 56/500
# 585/585 [==============================] - 0s 165us/step - loss: 3509.7467 - mean_absolute_error: 3509.7467 - val_loss: 5195.4829 - val_mean_absolute_error: 5195.4829
#
# Epoch 00056: val_loss did not improve from 4510.04379
# Epoch 57/500
# 585/585 [==============================] - 0s 147us/step - loss: 3458.7522 - mean_absolute_error: 3458.7522 - val_loss: 5562.2177 - val_mean_absolute_error: 5562.2177
#
# Epoch 00057: val_loss did not improve from 4510.04379
# Epoch 58/500
# 585/585 [==============================] - 0s 192us/step - loss: 3444.4518 - mean_absolute_error: 3444.4518 - val_loss: 4731.5258 - val_mean_absolute_error: 4731.5258
#
# Epoch 00058: val_loss did not improve from 4510.04379
# Epoch 59/500
# 585/585 [==============================] - 0s 200us/step - loss: 3471.9053 - mean_absolute_error: 3471.9053 - val_loss: 4686.2025 - val_mean_absolute_error: 4686.2025
#
# Epoch 00059: val_loss did not improve from 4510.04379
# Epoch 60/500
# 585/585 [==============================] - 0s 175us/step - loss: 3563.2176 - mean_absolute_error: 3563.2176 - val_loss: 5914.4175 - val_mean_absolute_error: 5914.4175
#
# Epoch 00060: val_loss did not improve from 4510.04379
# Epoch 61/500
# 585/585 [==============================] - 0s 166us/step - loss: 3622.7833 - mean_absolute_error: 3622.7833 - val_loss: 5087.0155 - val_mean_absolute_error: 5087.0155
#
# Epoch 00061: val_loss did not improve from 4510.04379
# Epoch 62/500
# 585/585 [==============================] - 0s 160us/step - loss: 3528.3094 - mean_absolute_error: 3528.3094 - val_loss: 4393.0142 - val_mean_absolute_error: 4393.0142
#
# Epoch 00062: val_loss improved from 4510.04379 to 4393.01424, saving model to 아이스크림date-Weights-062--4393.01424-cat02-vf05.hdf5
# Epoch 63/500
# 585/585 [==============================] - 0s 179us/step - loss: 3656.3505 - mean_absolute_error: 3656.3505 - val_loss: 4469.2662 - val_mean_absolute_error: 4469.2662
#
# Epoch 00063: val_loss did not improve from 4393.01424
# Epoch 64/500
# 585/585 [==============================] - 0s 174us/step - loss: 3507.2248 - mean_absolute_error: 3507.2248 - val_loss: 4841.1803 - val_mean_absolute_error: 4841.1803
#
# Epoch 00064: val_loss did not improve from 4393.01424
# Epoch 65/500
# 585/585 [==============================] - 0s 159us/step - loss: 3585.1749 - mean_absolute_error: 3585.1749 - val_loss: 4783.6547 - val_mean_absolute_error: 4783.6547
#
# Epoch 00065: val_loss did not improve from 4393.01424
# Epoch 66/500
# 585/585 [==============================] - 0s 159us/step - loss: 3540.9951 - mean_absolute_error: 3540.9951 - val_loss: 4689.6891 - val_mean_absolute_error: 4689.6891
#
# Epoch 00066: val_loss did not improve from 4393.01424
# Epoch 67/500
# 585/585 [==============================] - 0s 165us/step - loss: 3498.5744 - mean_absolute_error: 3498.5744 - val_loss: 4513.5262 - val_mean_absolute_error: 4513.5262
#
# Epoch 00067: val_loss did not improve from 4393.01424
# Epoch 68/500
# 585/585 [==============================] - 0s 157us/step - loss: 3475.1808 - mean_absolute_error: 3475.1808 - val_loss: 4855.5237 - val_mean_absolute_error: 4855.5237
#
# Epoch 00068: val_loss did not improve from 4393.01424
# Epoch 69/500
# 585/585 [==============================] - 0s 165us/step - loss: 3423.4798 - mean_absolute_error: 3423.4798 - val_loss: 5776.3660 - val_mean_absolute_error: 5776.3660
#
# Epoch 00069: val_loss did not improve from 4393.01424
# Epoch 70/500
# 585/585 [==============================] - 0s 167us/step - loss: 3483.9601 - mean_absolute_error: 3483.9601 - val_loss: 5484.6088 - val_mean_absolute_error: 5484.6088
#
# Epoch 00070: val_loss did not improve from 4393.01424
# Epoch 71/500
# 585/585 [==============================] - 0s 169us/step - loss: 3468.9430 - mean_absolute_error: 3468.9430 - val_loss: 4301.8455 - val_mean_absolute_error: 4301.8455
#
# Epoch 00071: val_loss improved from 4393.01424 to 4301.84554, saving model to 아이스크림date-Weights-071--4301.84554-cat02-vf05.hdf5
# Epoch 72/500
# 585/585 [==============================] - 0s 170us/step - loss: 3551.6160 - mean_absolute_error: 3551.6160 - val_loss: 4639.0089 - val_mean_absolute_error: 4639.0089
#
# Epoch 00072: val_loss did not improve from 4301.84554
# Epoch 73/500
# 585/585 [==============================] - 0s 186us/step - loss: 3487.2217 - mean_absolute_error: 3487.2217 - val_loss: 5999.5932 - val_mean_absolute_error: 5999.5932
#
# Epoch 00073: val_loss did not improve from 4301.84554
# Epoch 74/500
# 585/585 [==============================] - 0s 178us/step - loss: 3452.0989 - mean_absolute_error: 3452.0989 - val_loss: 5882.7997 - val_mean_absolute_error: 5882.7997
#
# Epoch 00074: val_loss did not improve from 4301.84554
# Epoch 75/500
# 585/585 [==============================] - 0s 219us/step - loss: 3446.7034 - mean_absolute_error: 3446.7034 - val_loss: 6038.0055 - val_mean_absolute_error: 6038.0055
#
# Epoch 00075: val_loss did not improve from 4301.84554
# Epoch 76/500
# 585/585 [==============================] - 0s 237us/step - loss: 3517.4191 - mean_absolute_error: 3517.4191 - val_loss: 5934.8512 - val_mean_absolute_error: 5934.8512
#
# Epoch 00076: val_loss did not improve from 4301.84554
# Epoch 77/500
# 585/585 [==============================] - 0s 164us/step - loss: 3578.2349 - mean_absolute_error: 3578.2349 - val_loss: 5224.6596 - val_mean_absolute_error: 5224.6596
#
# Epoch 00077: val_loss did not improve from 4301.84554
# Epoch 78/500
# 585/585 [==============================] - 0s 152us/step - loss: 3445.8064 - mean_absolute_error: 3445.8064 - val_loss: 5153.0674 - val_mean_absolute_error: 5153.0674
#
# Epoch 00078: val_loss did not improve from 4301.84554
# Epoch 79/500
# 585/585 [==============================] - 0s 167us/step - loss: 3427.5587 - mean_absolute_error: 3427.5587 - val_loss: 5142.7469 - val_mean_absolute_error: 5142.7469
#
# Epoch 00079: val_loss did not improve from 4301.84554
# Epoch 80/500
# 585/585 [==============================] - 0s 188us/step - loss: 3423.1466 - mean_absolute_error: 3423.1466 - val_loss: 5601.9576 - val_mean_absolute_error: 5601.9576
#
# Epoch 00080: val_loss did not improve from 4301.84554
# Epoch 81/500
# 585/585 [==============================] - 0s 153us/step - loss: 3409.3844 - mean_absolute_error: 3409.3844 - val_loss: 6323.2014 - val_mean_absolute_error: 6323.2014
#
# Epoch 00081: val_loss did not improve from 4301.84554
# Epoch 82/500
# 585/585 [==============================] - 0s 164us/step - loss: 3453.3644 - mean_absolute_error: 3453.3644 - val_loss: 5194.7418 - val_mean_absolute_error: 5194.7418
#
# Epoch 00082: val_loss did not improve from 4301.84554
# Epoch 83/500
# 585/585 [==============================] - 0s 167us/step - loss: 3467.3635 - mean_absolute_error: 3467.3635 - val_loss: 5225.0599 - val_mean_absolute_error: 5225.0599
#
# Epoch 00083: val_loss did not improve from 4301.84554
# Epoch 84/500
# 585/585 [==============================] - 0s 167us/step - loss: 3417.2746 - mean_absolute_error: 3417.2746 - val_loss: 4335.3371 - val_mean_absolute_error: 4335.3371
#
# Epoch 00084: val_loss did not improve from 4301.84554
# Epoch 85/500
# 585/585 [==============================] - 0s 186us/step - loss: 3554.0132 - mean_absolute_error: 3554.0132 - val_loss: 4048.0088 - val_mean_absolute_error: 4048.0088
#
# Epoch 00085: val_loss improved from 4301.84554 to 4048.00878, saving model to 아이스크림date-Weights-085--4048.00878-cat02-vf05.hdf5
# Epoch 86/500
# 585/585 [==============================] - 0s 146us/step - loss: 3535.8567 - mean_absolute_error: 3535.8567 - val_loss: 4950.9164 - val_mean_absolute_error: 4950.9164
#
# Epoch 00086: val_loss did not improve from 4048.00878
# Epoch 87/500
# 585/585 [==============================] - 0s 150us/step - loss: 3399.3705 - mean_absolute_error: 3399.3705 - val_loss: 5627.6547 - val_mean_absolute_error: 5627.6547
#
# Epoch 00087: val_loss did not improve from 4048.00878
# Epoch 88/500
# 585/585 [==============================] - 0s 157us/step - loss: 3408.9963 - mean_absolute_error: 3408.9963 - val_loss: 5176.2500 - val_mean_absolute_error: 5176.2500
#
# Epoch 00088: val_loss did not improve from 4048.00878
# Epoch 89/500
# 585/585 [==============================] - 0s 164us/step - loss: 3408.1230 - mean_absolute_error: 3408.1230 - val_loss: 6201.7349 - val_mean_absolute_error: 6201.7349
#
# Epoch 00089: val_loss did not improve from 4048.00878
# Epoch 90/500
# 585/585 [==============================] - 0s 172us/step - loss: 3362.4875 - mean_absolute_error: 3362.4875 - val_loss: 5243.5992 - val_mean_absolute_error: 5243.5992
#
# Epoch 00090: val_loss did not improve from 4048.00878
# Epoch 91/500
# 585/585 [==============================] - 0s 130us/step - loss: 3446.4252 - mean_absolute_error: 3446.4252 - val_loss: 5611.8134 - val_mean_absolute_error: 5611.8134
#
# Epoch 00091: val_loss did not improve from 4048.00878
# Epoch 92/500
# 585/585 [==============================] - 0s 152us/step - loss: 3388.6895 - mean_absolute_error: 3388.6895 - val_loss: 6087.5109 - val_mean_absolute_error: 6087.5109
#
# Epoch 00092: val_loss did not improve from 4048.00878
# Epoch 93/500
# 585/585 [==============================] - 0s 155us/step - loss: 3436.8127 - mean_absolute_error: 3436.8127 - val_loss: 5230.7353 - val_mean_absolute_error: 5230.7353
#
# Epoch 00093: val_loss did not improve from 4048.00878
# Epoch 94/500
# 585/585 [==============================] - 0s 145us/step - loss: 3380.8066 - mean_absolute_error: 3380.8066 - val_loss: 5807.8186 - val_mean_absolute_error: 5807.8186
#
# Epoch 00094: val_loss did not improve from 4048.00878
# Epoch 95/500
# 585/585 [==============================] - 0s 157us/step - loss: 3388.2816 - mean_absolute_error: 3388.2816 - val_loss: 5739.6593 - val_mean_absolute_error: 5739.6593
#
# Epoch 00095: val_loss did not improve from 4048.00878
# Epoch 96/500
# 585/585 [==============================] - 0s 146us/step - loss: 3403.1568 - mean_absolute_error: 3403.1568 - val_loss: 5117.3508 - val_mean_absolute_error: 5117.3508
#
# Epoch 00096: val_loss did not improve from 4048.00878
# Epoch 97/500
# 585/585 [==============================] - 0s 143us/step - loss: 3469.4744 - mean_absolute_error: 3469.4744 - val_loss: 5532.8831 - val_mean_absolute_error: 5532.8831
#
# Epoch 00097: val_loss did not improve from 4048.00878
# Epoch 98/500
# 585/585 [==============================] - 0s 142us/step - loss: 3407.6727 - mean_absolute_error: 3407.6727 - val_loss: 5531.4167 - val_mean_absolute_error: 5531.4167
#
# Epoch 00098: val_loss did not improve from 4048.00878
# Epoch 99/500
# 585/585 [==============================] - 0s 199us/step - loss: 3395.4409 - mean_absolute_error: 3395.4409 - val_loss: 5519.4550 - val_mean_absolute_error: 5519.4550
#
# Epoch 00099: val_loss did not improve from 4048.00878
# Epoch 100/500
# 585/585 [==============================] - 0s 157us/step - loss: 3395.8561 - mean_absolute_error: 3395.8561 - val_loss: 6127.6681 - val_mean_absolute_error: 6127.6681
#
# Epoch 00100: val_loss did not improve from 4048.00878
# Epoch 101/500
# 585/585 [==============================] - 0s 187us/step - loss: 3408.4397 - mean_absolute_error: 3408.4397 - val_loss: 6296.0334 - val_mean_absolute_error: 6296.0334
#
# Epoch 00101: val_loss did not improve from 4048.00878
# Epoch 102/500
# 585/585 [==============================] - 0s 173us/step - loss: 3397.3713 - mean_absolute_error: 3397.3713 - val_loss: 5912.9461 - val_mean_absolute_error: 5912.9461
#
# Epoch 00102: val_loss did not improve from 4048.00878
# Epoch 103/500
# 585/585 [==============================] - 0s 149us/step - loss: 3538.2254 - mean_absolute_error: 3538.2254 - val_loss: 5870.2210 - val_mean_absolute_error: 5870.2210
#
# Epoch 00103: val_loss did not improve from 4048.00878
# Epoch 104/500
# 585/585 [==============================] - 0s 161us/step - loss: 3412.5980 - mean_absolute_error: 3412.5980 - val_loss: 5822.6099 - val_mean_absolute_error: 5822.6099
#
# Epoch 00104: val_loss did not improve from 4048.00878
# Epoch 105/500
# 585/585 [==============================] - 0s 174us/step - loss: 3406.1071 - mean_absolute_error: 3406.1071 - val_loss: 4660.4948 - val_mean_absolute_error: 4660.4948
#
# Epoch 00105: val_loss did not improve from 4048.00878
# Epoch 106/500
# 585/585 [==============================] - 0s 155us/step - loss: 3508.1100 - mean_absolute_error: 3508.1100 - val_loss: 4462.6177 - val_mean_absolute_error: 4462.6177
#
# Epoch 00106: val_loss did not improve from 4048.00878
# Epoch 107/500
# 585/585 [==============================] - 0s 150us/step - loss: 3386.3421 - mean_absolute_error: 3386.3421 - val_loss: 5750.7647 - val_mean_absolute_error: 5750.7647
#
# Epoch 00107: val_loss did not improve from 4048.00878
# Epoch 108/500
# 585/585 [==============================] - 0s 169us/step - loss: 3366.7126 - mean_absolute_error: 3366.7126 - val_loss: 5390.2149 - val_mean_absolute_error: 5390.2149
#
# Epoch 00108: val_loss did not improve from 4048.00878
# Epoch 109/500
# 585/585 [==============================] - 0s 181us/step - loss: 3380.1129 - mean_absolute_error: 3380.1129 - val_loss: 5021.5967 - val_mean_absolute_error: 5021.5967
#
# Epoch 00109: val_loss did not improve from 4048.00878
# Epoch 110/500
# 585/585 [==============================] - 0s 177us/step - loss: 3375.1937 - mean_absolute_error: 3375.1937 - val_loss: 4842.4625 - val_mean_absolute_error: 4842.4625
#
# Epoch 00110: val_loss did not improve from 4048.00878
# Epoch 111/500
# 585/585 [==============================] - 0s 317us/step - loss: 3441.9541 - mean_absolute_error: 3441.9541 - val_loss: 4168.9728 - val_mean_absolute_error: 4168.9728
#
# Epoch 00111: val_loss did not improve from 4048.00878
# Epoch 112/500
# 585/585 [==============================] - 0s 275us/step - loss: 3461.7194 - mean_absolute_error: 3461.7194 - val_loss: 4954.0040 - val_mean_absolute_error: 4954.0040
#
# Epoch 00112: val_loss did not improve from 4048.00878
# Epoch 113/500
# 585/585 [==============================] - 0s 224us/step - loss: 3408.5950 - mean_absolute_error: 3408.5950 - val_loss: 4454.8959 - val_mean_absolute_error: 4454.8959
#
# Epoch 00113: val_loss did not improve from 4048.00878
# Epoch 114/500
# 585/585 [==============================] - 0s 201us/step - loss: 3369.7555 - mean_absolute_error: 3369.7555 - val_loss: 4185.4422 - val_mean_absolute_error: 4185.4422
#
# Epoch 00114: val_loss did not improve from 4048.00878
# Epoch 115/500
# 585/585 [==============================] - 0s 193us/step - loss: 3491.4972 - mean_absolute_error: 3491.4972 - val_loss: 4889.6885 - val_mean_absolute_error: 4889.6885
#
# Epoch 00115: val_loss did not improve from 4048.00878
# Epoch 116/500
# 585/585 [==============================] - 0s 178us/step - loss: 3389.5463 - mean_absolute_error: 3389.5463 - val_loss: 5418.5875 - val_mean_absolute_error: 5418.5875
#
# Epoch 00116: val_loss did not improve from 4048.00878
# Epoch 117/500
# 585/585 [==============================] - 0s 187us/step - loss: 3327.5731 - mean_absolute_error: 3327.5731 - val_loss: 4610.9136 - val_mean_absolute_error: 4610.9136
#
# Epoch 00117: val_loss did not improve from 4048.00878
# Epoch 118/500
# 585/585 [==============================] - 0s 178us/step - loss: 3507.8194 - mean_absolute_error: 3507.8194 - val_loss: 4618.5305 - val_mean_absolute_error: 4618.5305
#
# Epoch 00118: val_loss did not improve from 4048.00878
# Epoch 119/500
# 585/585 [==============================] - 0s 191us/step - loss: 3396.3023 - mean_absolute_error: 3396.3023 - val_loss: 5784.2446 - val_mean_absolute_error: 5784.2446
#
# Epoch 00119: val_loss did not improve from 4048.00878
# Epoch 120/500
# 585/585 [==============================] - 0s 182us/step - loss: 3378.5818 - mean_absolute_error: 3378.5818 - val_loss: 5627.6220 - val_mean_absolute_error: 5627.6220
#
# Epoch 00120: val_loss did not improve from 4048.00878
# Epoch 121/500
# 585/585 [==============================] - 0s 170us/step - loss: 3370.1734 - mean_absolute_error: 3370.1734 - val_loss: 5516.9815 - val_mean_absolute_error: 5516.9815
#
# Epoch 00121: val_loss did not improve from 4048.00878
# Epoch 122/500
# 585/585 [==============================] - 0s 196us/step - loss: 3352.1048 - mean_absolute_error: 3352.1048 - val_loss: 5655.0183 - val_mean_absolute_error: 5655.0183
#
# Epoch 00122: val_loss did not improve from 4048.00878
# Epoch 123/500
# 585/585 [==============================] - 0s 188us/step - loss: 3340.6310 - mean_absolute_error: 3340.6310 - val_loss: 5592.6779 - val_mean_absolute_error: 5592.6779
#
# Epoch 00123: val_loss did not improve from 4048.00878
# Epoch 124/500
# 585/585 [==============================] - 0s 188us/step - loss: 3358.4685 - mean_absolute_error: 3358.4685 - val_loss: 5171.6538 - val_mean_absolute_error: 5171.6538
#
# Epoch 00124: val_loss did not improve from 4048.00878
# Epoch 125/500
# 585/585 [==============================] - 0s 182us/step - loss: 3353.1364 - mean_absolute_error: 3353.1364 - val_loss: 5163.2408 - val_mean_absolute_error: 5163.2408
#
# Epoch 00125: val_loss did not improve from 4048.00878
# Epoch 126/500
# 585/585 [==============================] - 0s 193us/step - loss: 3349.6874 - mean_absolute_error: 3349.6874 - val_loss: 5611.7262 - val_mean_absolute_error: 5611.7262
#
# Epoch 00126: val_loss did not improve from 4048.00878
# Epoch 127/500
# 585/585 [==============================] - 0s 153us/step - loss: 3366.2607 - mean_absolute_error: 3366.2607 - val_loss: 5925.8425 - val_mean_absolute_error: 5925.8425
#
# Epoch 00127: val_loss did not improve from 4048.00878
# Epoch 128/500
# 585/585 [==============================] - 0s 176us/step - loss: 3324.2999 - mean_absolute_error: 3324.2999 - val_loss: 4842.6929 - val_mean_absolute_error: 4842.6929
#
# Epoch 00128: val_loss did not improve from 4048.00878
# Epoch 129/500
# 585/585 [==============================] - 0s 153us/step - loss: 3381.8297 - mean_absolute_error: 3381.8297 - val_loss: 4800.5923 - val_mean_absolute_error: 4800.5923
#
# Epoch 00129: val_loss did not improve from 4048.00878
# Epoch 130/500
# 585/585 [==============================] - 0s 165us/step - loss: 3373.4807 - mean_absolute_error: 3373.4807 - val_loss: 5935.9772 - val_mean_absolute_error: 5935.9772
#
# Epoch 00130: val_loss did not improve from 4048.00878
# Epoch 131/500
# 585/585 [==============================] - 0s 155us/step - loss: 3398.6176 - mean_absolute_error: 3398.6176 - val_loss: 6627.3019 - val_mean_absolute_error: 6627.3019
#
# Epoch 00131: val_loss did not improve from 4048.00878
# Epoch 132/500
# 585/585 [==============================] - 0s 293us/step - loss: 3391.4938 - mean_absolute_error: 3391.4938 - val_loss: 5549.4428 - val_mean_absolute_error: 5549.4428
#
# Epoch 00132: val_loss did not improve from 4048.00878
# Epoch 133/500
# 585/585 [==============================] - 0s 207us/step - loss: 3350.0230 - mean_absolute_error: 3350.0230 - val_loss: 5469.8740 - val_mean_absolute_error: 5469.8740
#
# Epoch 00133: val_loss did not improve from 4048.00878
# Epoch 134/500
# 585/585 [==============================] - 0s 184us/step - loss: 3330.6512 - mean_absolute_error: 3330.6512 - val_loss: 4498.3611 - val_mean_absolute_error: 4498.3611
#
# Epoch 00134: val_loss did not improve from 4048.00878
# Epoch 135/500
# 585/585 [==============================] - 0s 150us/step - loss: 3427.6084 - mean_absolute_error: 3427.6084 - val_loss: 5276.6658 - val_mean_absolute_error: 5276.6658
#
# Epoch 00135: val_loss did not improve from 4048.00878
# Epoch 136/500
# 585/585 [==============================] - 0s 152us/step - loss: 3329.9769 - mean_absolute_error: 3329.9769 - val_loss: 5143.7263 - val_mean_absolute_error: 5143.7263
#
# Epoch 00136: val_loss did not improve from 4048.00878
# Epoch 137/500
# 585/585 [==============================] - 0s 155us/step - loss: 3322.9874 - mean_absolute_error: 3322.9874 - val_loss: 6012.5596 - val_mean_absolute_error: 6012.5596
#
# Epoch 00137: val_loss did not improve from 4048.00878
# Epoch 138/500
# 585/585 [==============================] - 0s 161us/step - loss: 3372.8426 - mean_absolute_error: 3372.8426 - val_loss: 5947.4959 - val_mean_absolute_error: 5947.4959
#
# Epoch 00138: val_loss did not improve from 4048.00878
# Epoch 139/500
# 585/585 [==============================] - 0s 163us/step - loss: 3497.8902 - mean_absolute_error: 3497.8902 - val_loss: 6268.9881 - val_mean_absolute_error: 6268.9881
#
# Epoch 00139: val_loss did not improve from 4048.00878
# Epoch 140/500
# 585/585 [==============================] - 0s 155us/step - loss: 3425.4665 - mean_absolute_error: 3425.4665 - val_loss: 5174.1050 - val_mean_absolute_error: 5174.1050
#
# Epoch 00140: val_loss did not improve from 4048.00878
# Epoch 141/500
# 585/585 [==============================] - 0s 162us/step - loss: 3381.7592 - mean_absolute_error: 3381.7592 - val_loss: 4786.0834 - val_mean_absolute_error: 4786.0834
#
# Epoch 00141: val_loss did not improve from 4048.00878
# Epoch 142/500
# 585/585 [==============================] - 0s 162us/step - loss: 3340.8482 - mean_absolute_error: 3340.8482 - val_loss: 5790.7778 - val_mean_absolute_error: 5790.7778
#
# Epoch 00142: val_loss did not improve from 4048.00878
# Epoch 143/500
# 585/585 [==============================] - 0s 170us/step - loss: 3390.8854 - mean_absolute_error: 3390.8854 - val_loss: 6073.2454 - val_mean_absolute_error: 6073.2454
#
# Epoch 00143: val_loss did not improve from 4048.00878
# Epoch 144/500
# 585/585 [==============================] - 0s 170us/step - loss: 3350.1195 - mean_absolute_error: 3350.1195 - val_loss: 6728.1501 - val_mean_absolute_error: 6728.1501
#
# Epoch 00144: val_loss did not improve from 4048.00878
# Epoch 145/500
# 585/585 [==============================] - 0s 169us/step - loss: 3499.3735 - mean_absolute_error: 3499.3735 - val_loss: 5224.5688 - val_mean_absolute_error: 5224.5688
#
# Epoch 00145: val_loss did not improve from 4048.00878
# Epoch 146/500
# 585/585 [==============================] - 0s 174us/step - loss: 3347.4036 - mean_absolute_error: 3347.4036 - val_loss: 6043.6561 - val_mean_absolute_error: 6043.6561
#
# Epoch 00146: val_loss did not improve from 4048.00878
# Epoch 147/500
# 585/585 [==============================] - 0s 189us/step - loss: 3323.0419 - mean_absolute_error: 3323.0419 - val_loss: 5522.9076 - val_mean_absolute_error: 5522.9076
#
# Epoch 00147: val_loss did not improve from 4048.00878
# Epoch 148/500
# 585/585 [==============================] - 0s 191us/step - loss: 3327.2059 - mean_absolute_error: 3327.2059 - val_loss: 5304.4294 - val_mean_absolute_error: 5304.4294
#
# Epoch 00148: val_loss did not improve from 4048.00878
# Epoch 149/500
# 585/585 [==============================] - 0s 268us/step - loss: 3370.1746 - mean_absolute_error: 3370.1746 - val_loss: 5079.0158 - val_mean_absolute_error: 5079.0158
#
# Epoch 00149: val_loss did not improve from 4048.00878
# Epoch 150/500
# 585/585 [==============================] - 0s 228us/step - loss: 3349.7613 - mean_absolute_error: 3349.7613 - val_loss: 5733.5673 - val_mean_absolute_error: 5733.5673
#
# Epoch 00150: val_loss did not improve from 4048.00878
# Epoch 151/500
# 585/585 [==============================] - 0s 203us/step - loss: 3360.7251 - mean_absolute_error: 3360.7251 - val_loss: 5386.9695 - val_mean_absolute_error: 5386.9695
#
# Epoch 00151: val_loss did not improve from 4048.00878
# Epoch 152/500
# 585/585 [==============================] - 0s 224us/step - loss: 3415.3442 - mean_absolute_error: 3415.3442 - val_loss: 5030.2145 - val_mean_absolute_error: 5030.2145
#
# Epoch 00152: val_loss did not improve from 4048.00878
# Epoch 153/500
# 585/585 [==============================] - 0s 261us/step - loss: 3348.7803 - mean_absolute_error: 3348.7803 - val_loss: 5103.8796 - val_mean_absolute_error: 5103.8796
#
# Epoch 00153: val_loss did not improve from 4048.00878
# Epoch 154/500
# 585/585 [==============================] - 0s 189us/step - loss: 3313.3706 - mean_absolute_error: 3313.3706 - val_loss: 5723.2940 - val_mean_absolute_error: 5723.2940
#
# Epoch 00154: val_loss did not improve from 4048.00878
# Epoch 155/500
# 585/585 [==============================] - 0s 175us/step - loss: 3309.2122 - mean_absolute_error: 3309.2122 - val_loss: 5338.3219 - val_mean_absolute_error: 5338.3219
#
# Epoch 00155: val_loss did not improve from 4048.00878
# Epoch 156/500
# 585/585 [==============================] - 0s 172us/step - loss: 3320.4887 - mean_absolute_error: 3320.4887 - val_loss: 5183.8448 - val_mean_absolute_error: 5183.8448
#
# Epoch 00156: val_loss did not improve from 4048.00878
# Epoch 157/500
# 585/585 [==============================] - 0s 177us/step - loss: 3339.4174 - mean_absolute_error: 3339.4174 - val_loss: 5889.2715 - val_mean_absolute_error: 5889.2715
#
# Epoch 00157: val_loss did not improve from 4048.00878
# Epoch 158/500
# 585/585 [==============================] - 0s 165us/step - loss: 3374.0730 - mean_absolute_error: 3374.0730 - val_loss: 5392.4472 - val_mean_absolute_error: 5392.4472
#
# Epoch 00158: val_loss did not improve from 4048.00878
# Epoch 159/500
# 585/585 [==============================] - 0s 182us/step - loss: 3355.5841 - mean_absolute_error: 3355.5841 - val_loss: 5047.4308 - val_mean_absolute_error: 5047.4308
#
# Epoch 00159: val_loss did not improve from 4048.00878
# Epoch 160/500
# 585/585 [==============================] - 0s 176us/step - loss: 3356.1603 - mean_absolute_error: 3356.1603 - val_loss: 5156.4739 - val_mean_absolute_error: 5156.4739
#
# Epoch 00160: val_loss did not improve from 4048.00878
# Epoch 161/500
# 585/585 [==============================] - 0s 188us/step - loss: 3341.3043 - mean_absolute_error: 3341.3043 - val_loss: 5217.7047 - val_mean_absolute_error: 5217.7047
#
# Epoch 00161: val_loss did not improve from 4048.00878
# Epoch 162/500
# 585/585 [==============================] - 0s 169us/step - loss: 3326.7183 - mean_absolute_error: 3326.7183 - val_loss: 4742.8523 - val_mean_absolute_error: 4742.8523
#
# Epoch 00162: val_loss did not improve from 4048.00878
# Epoch 163/500
# 585/585 [==============================] - 0s 188us/step - loss: 3323.6119 - mean_absolute_error: 3323.6119 - val_loss: 4691.8914 - val_mean_absolute_error: 4691.8914
#
# Epoch 00163: val_loss did not improve from 4048.00878
# Epoch 164/500
# 585/585 [==============================] - 0s 276us/step - loss: 3336.3832 - mean_absolute_error: 3336.3832 - val_loss: 3919.4026 - val_mean_absolute_error: 3919.4026
#
# Epoch 00164: val_loss improved from 4048.00878 to 3919.40262, saving model to 아이스크림date-Weights-164--3919.40262-cat02-vf05.hdf5
# Epoch 165/500
# 585/585 [==============================] - 0s 171us/step - loss: 3628.3253 - mean_absolute_error: 3628.3253 - val_loss: 4454.5471 - val_mean_absolute_error: 4454.5471
#
# Epoch 00165: val_loss did not improve from 3919.40262
# Epoch 166/500
# 585/585 [==============================] - 0s 176us/step - loss: 3419.7540 - mean_absolute_error: 3419.7540 - val_loss: 4951.9168 - val_mean_absolute_error: 4951.9168
#
# Epoch 00166: val_loss did not improve from 3919.40262
# Epoch 167/500
# 585/585 [==============================] - 0s 175us/step - loss: 3322.7662 - mean_absolute_error: 3322.7662 - val_loss: 6658.9690 - val_mean_absolute_error: 6658.9690
#
# Epoch 00167: val_loss did not improve from 3919.40262
# Epoch 168/500
# 585/585 [==============================] - 0s 190us/step - loss: 3368.6152 - mean_absolute_error: 3368.6152 - val_loss: 6091.4977 - val_mean_absolute_error: 6091.4977
#
# Epoch 00168: val_loss did not improve from 3919.40262
# Epoch 169/500
# 585/585 [==============================] - 0s 198us/step - loss: 3362.7933 - mean_absolute_error: 3362.7933 - val_loss: 7392.2951 - val_mean_absolute_error: 7392.2951
#
# Epoch 00169: val_loss did not improve from 3919.40262
# Epoch 170/500
# 585/585 [==============================] - 0s 162us/step - loss: 3563.6911 - mean_absolute_error: 3563.6911 - val_loss: 5986.0976 - val_mean_absolute_error: 5986.0976
#
# Epoch 00170: val_loss did not improve from 3919.40262
# Epoch 171/500
# 585/585 [==============================] - 0s 188us/step - loss: 3333.1850 - mean_absolute_error: 3333.1850 - val_loss: 5104.8284 - val_mean_absolute_error: 5104.8284
#
# Epoch 00171: val_loss did not improve from 3919.40262
# Epoch 172/500
# 585/585 [==============================] - 0s 239us/step - loss: 3361.4336 - mean_absolute_error: 3361.4336 - val_loss: 4131.4140 - val_mean_absolute_error: 4131.4140
#
# Epoch 00172: val_loss did not improve from 3919.40262
# Epoch 173/500
# 585/585 [==============================] - 0s 198us/step - loss: 3355.5301 - mean_absolute_error: 3355.5301 - val_loss: 4430.0398 - val_mean_absolute_error: 4430.0398
#
# Epoch 00173: val_loss did not improve from 3919.40262
# Epoch 174/500
# 585/585 [==============================] - 0s 203us/step - loss: 3380.4937 - mean_absolute_error: 3380.4937 - val_loss: 5310.3400 - val_mean_absolute_error: 5310.3400
#
# Epoch 00174: val_loss did not improve from 3919.40262
# Epoch 175/500
# 585/585 [==============================] - 0s 213us/step - loss: 3311.0483 - mean_absolute_error: 3311.0483 - val_loss: 4882.9790 - val_mean_absolute_error: 4882.9790
#
# Epoch 00175: val_loss did not improve from 3919.40262
# Epoch 176/500
# 585/585 [==============================] - 0s 176us/step - loss: 3285.1915 - mean_absolute_error: 3285.1915 - val_loss: 6077.7550 - val_mean_absolute_error: 6077.7550
#
# Epoch 00176: val_loss did not improve from 3919.40262
# Epoch 177/500
# 585/585 [==============================] - 0s 203us/step - loss: 3324.3574 - mean_absolute_error: 3324.3574 - val_loss: 6269.3934 - val_mean_absolute_error: 6269.3934
#
# Epoch 00177: val_loss did not improve from 3919.40262
# Epoch 178/500
# 585/585 [==============================] - 0s 162us/step - loss: 3432.9006 - mean_absolute_error: 3432.9006 - val_loss: 5656.1713 - val_mean_absolute_error: 5656.1713
#
# Epoch 00178: val_loss did not improve from 3919.40262
# Epoch 179/500
# 585/585 [==============================] - 0s 179us/step - loss: 3278.8099 - mean_absolute_error: 3278.8099 - val_loss: 5703.8204 - val_mean_absolute_error: 5703.8204
#
# Epoch 00179: val_loss did not improve from 3919.40262
# Epoch 180/500
# 585/585 [==============================] - 0s 188us/step - loss: 3289.8280 - mean_absolute_error: 3289.8280 - val_loss: 4291.8175 - val_mean_absolute_error: 4291.8175
#
# Epoch 00180: val_loss did not improve from 3919.40262
# Epoch 181/500
# 585/585 [==============================] - 0s 188us/step - loss: 3377.6715 - mean_absolute_error: 3377.6715 - val_loss: 5614.6132 - val_mean_absolute_error: 5614.6132
#
# Epoch 00181: val_loss did not improve from 3919.40262
# Epoch 182/500
# 585/585 [==============================] - 0s 220us/step - loss: 3377.1910 - mean_absolute_error: 3377.1910 - val_loss: 5182.7362 - val_mean_absolute_error: 5182.7362
#
# Epoch 00182: val_loss did not improve from 3919.40262
# Epoch 183/500
# 585/585 [==============================] - 0s 228us/step - loss: 3293.2318 - mean_absolute_error: 3293.2318 - val_loss: 6020.9941 - val_mean_absolute_error: 6020.9941
#
# Epoch 00183: val_loss did not improve from 3919.40262
# Epoch 184/500
# 585/585 [==============================] - 0s 220us/step - loss: 3327.0779 - mean_absolute_error: 3327.0779 - val_loss: 6024.4040 - val_mean_absolute_error: 6024.4040
#
# Epoch 00184: val_loss did not improve from 3919.40262
# Epoch 185/500
# 585/585 [==============================] - 0s 181us/step - loss: 3372.7109 - mean_absolute_error: 3372.7109 - val_loss: 5756.4733 - val_mean_absolute_error: 5756.4733
#
# Epoch 00185: val_loss did not improve from 3919.40262
# Epoch 186/500
# 585/585 [==============================] - 0s 186us/step - loss: 3328.6140 - mean_absolute_error: 3328.6140 - val_loss: 5953.7711 - val_mean_absolute_error: 5953.7711
#
# Epoch 00186: val_loss did not improve from 3919.40262
# Epoch 187/500
# 585/585 [==============================] - 0s 189us/step - loss: 3303.3717 - mean_absolute_error: 3303.3717 - val_loss: 5572.0431 - val_mean_absolute_error: 5572.0431
#
# Epoch 00187: val_loss did not improve from 3919.40262
# Epoch 188/500
# 585/585 [==============================] - 0s 199us/step - loss: 3367.6164 - mean_absolute_error: 3367.6164 - val_loss: 4729.0151 - val_mean_absolute_error: 4729.0151
#
# Epoch 00188: val_loss did not improve from 3919.40262
# Epoch 189/500
# 585/585 [==============================] - 0s 205us/step - loss: 3323.7576 - mean_absolute_error: 3323.7576 - val_loss: 6025.2573 - val_mean_absolute_error: 6025.2573
#
# Epoch 00189: val_loss did not improve from 3919.40262
# Epoch 190/500
# 585/585 [==============================] - 0s 191us/step - loss: 3335.7955 - mean_absolute_error: 3335.7955 - val_loss: 6365.1653 - val_mean_absolute_error: 6365.1653
#
# Epoch 00190: val_loss did not improve from 3919.40262
# Epoch 191/500
# 585/585 [==============================] - 0s 263us/step - loss: 3337.0425 - mean_absolute_error: 3337.0425 - val_loss: 5347.0827 - val_mean_absolute_error: 5347.0827
#
# Epoch 00191: val_loss did not improve from 3919.40262
# Epoch 192/500
# 585/585 [==============================] - 0s 264us/step - loss: 3276.3851 - mean_absolute_error: 3276.3851 - val_loss: 5546.3003 - val_mean_absolute_error: 5546.3003
#
# Epoch 00192: val_loss did not improve from 3919.40262
# Epoch 193/500
# 585/585 [==============================] - 0s 219us/step - loss: 3308.2622 - mean_absolute_error: 3308.2622 - val_loss: 5543.0455 - val_mean_absolute_error: 5543.0455
#
# Epoch 00193: val_loss did not improve from 3919.40262
# Epoch 194/500
# 585/585 [==============================] - 0s 203us/step - loss: 3294.5339 - mean_absolute_error: 3294.5339 - val_loss: 5446.9830 - val_mean_absolute_error: 5446.9830
#
# Epoch 00194: val_loss did not improve from 3919.40262
# Epoch 195/500
# 585/585 [==============================] - 0s 199us/step - loss: 3301.7566 - mean_absolute_error: 3301.7566 - val_loss: 4764.7820 - val_mean_absolute_error: 4764.7820
#
# Epoch 00195: val_loss did not improve from 3919.40262
# Epoch 196/500
# 585/585 [==============================] - 0s 292us/step - loss: 3327.3995 - mean_absolute_error: 3327.3995 - val_loss: 5805.3530 - val_mean_absolute_error: 5805.3530
#
# Epoch 00196: val_loss did not improve from 3919.40262
# Epoch 197/500
# 585/585 [==============================] - 0s 259us/step - loss: 3320.8524 - mean_absolute_error: 3320.8524 - val_loss: 4745.5075 - val_mean_absolute_error: 4745.5075
#
# Epoch 00197: val_loss did not improve from 3919.40262
# Epoch 198/500
# 585/585 [==============================] - 0s 177us/step - loss: 3283.7182 - mean_absolute_error: 3283.7182 - val_loss: 5760.0790 - val_mean_absolute_error: 5760.0790
#
# Epoch 00198: val_loss did not improve from 3919.40262
# Epoch 199/500
# ...
#
# Epoch 00433: val_loss did not improve from 3850.32151
# Epoch 434/500
# 585/585 [==============================] - 0s 172us/step - loss: 3037.7907 - mean_absolute_error: 3037.7907 - val_loss: 5539.9578 - val_mean_absolute_error: 5539.9578
#
# Epoch 00434: val_loss did not improve from 3850.32151
# Epoch 435/500
# 585/585 [==============================] - 0s 160us/step - loss: 3076.5035 - mean_absolute_error: 3076.5035 - val_loss: 5171.4943 - val_mean_absolute_error: 5171.4943
#
# Epoch 00435: val_loss did not improve from 3850.32151
# Epoch 436/500
# 585/585 [==============================] - 0s 160us/step - loss: 3079.1539 - mean_absolute_error: 3079.1539 - val_loss: 5338.4854 - val_mean_absolute_error: 5338.4854
#
# Epoch 00436: val_loss did not improve from 3850.32151
# Epoch 437/500
# 585/585 [==============================] - 0s 150us/step - loss: 3060.9228 - mean_absolute_error: 3060.9228 - val_loss: 4114.8189 - val_mean_absolute_error: 4114.8189
#
# Epoch 00437: val_loss did not improve from 3850.32151
# Epoch 438/500
# 585/585 [==============================] - 0s 155us/step - loss: 3115.2952 - mean_absolute_error: 3115.2952 - val_loss: 5105.8409 - val_mean_absolute_error: 5105.8409
#
# Epoch 00438: val_loss did not improve from 3850.32151
# Epoch 439/500
# 585/585 [==============================] - 0s 158us/step - loss: 3039.6519 - mean_absolute_error: 3039.6519 - val_loss: 5583.6522 - val_mean_absolute_error: 5583.6522
#
# Epoch 00439: val_loss did not improve from 3850.32151
# Epoch 440/500
# 585/585 [==============================] - 0s 154us/step - loss: 3070.9120 - mean_absolute_error: 3070.9120 - val_loss: 5645.9228 - val_mean_absolute_error: 5645.9228
#
# Epoch 00440: val_loss did not improve from 3850.32151
# Epoch 441/500
# 585/585 [==============================] - 0s 145us/step - loss: 3048.2434 - mean_absolute_error: 3048.2434 - val_loss: 5942.8993 - val_mean_absolute_error: 5942.8993
#
# Epoch 00441: val_loss did not improve from 3850.32151
# Epoch 442/500
# 585/585 [==============================] - 0s 159us/step - loss: 3088.4841 - mean_absolute_error: 3088.4841 - val_loss: 5480.6578 - val_mean_absolute_error: 5480.6578
#
# Epoch 00442: val_loss did not improve from 3850.32151
# Epoch 443/500
# 585/585 [==============================] - 0s 166us/step - loss: 3012.3754 - mean_absolute_error: 3012.3754 - val_loss: 4670.2221 - val_mean_absolute_error: 4670.2221
#
# Epoch 00443: val_loss did not improve from 3850.32151
# Epoch 444/500
# 585/585 [==============================] - 0s 163us/step - loss: 3033.2282 - mean_absolute_error: 3033.2282 - val_loss: 4917.3248 - val_mean_absolute_error: 4917.3248
#
# Epoch 00444: val_loss did not improve from 3850.32151
# Epoch 445/500
# 585/585 [==============================] - 0s 165us/step - loss: 3053.7365 - mean_absolute_error: 3053.7365 - val_loss: 5077.2445 - val_mean_absolute_error: 5077.2445
#
# Epoch 00445: val_loss did not improve from 3850.32151
# Epoch 446/500
# 585/585 [==============================] - 0s 181us/step - loss: 3054.0821 - mean_absolute_error: 3054.0821 - val_loss: 5761.0363 - val_mean_absolute_error: 5761.0363
#
# Epoch 00446: val_loss did not improve from 3850.32151
# Epoch 447/500
# 585/585 [==============================] - 0s 160us/step - loss: 3127.4282 - mean_absolute_error: 3127.4282 - val_loss: 5791.6745 - val_mean_absolute_error: 5791.6745
#
# Epoch 00447: val_loss did not improve from 3850.32151
# Epoch 448/500
# 585/585 [==============================] - 0s 157us/step - loss: 3137.3146 - mean_absolute_error: 3137.3146 - val_loss: 5208.0286 - val_mean_absolute_error: 5208.0286
#
# Epoch 00448: val_loss did not improve from 3850.32151
# Epoch 449/500
# 585/585 [==============================] - 0s 155us/step - loss: 3038.8926 - mean_absolute_error: 3038.8926 - val_loss: 4889.9698 - val_mean_absolute_error: 4889.9698
#
# Epoch 00449: val_loss did not improve from 3850.32151
# Epoch 450/500
# 585/585 [==============================] - 0s 162us/step - loss: 3020.0757 - mean_absolute_error: 3020.0757 - val_loss: 5731.6814 - val_mean_absolute_error: 5731.6814
#
# Epoch 00450: val_loss did not improve from 3850.32151
# Epoch 451/500
# 585/585 [==============================] - 0s 169us/step - loss: 3083.8103 - mean_absolute_error: 3083.8103 - val_loss: 5542.2282 - val_mean_absolute_error: 5542.2282
#
# Epoch 00451: val_loss did not improve from 3850.32151
# Epoch 452/500
# 585/585 [==============================] - 0s 174us/step - loss: 3039.2787 - mean_absolute_error: 3039.2787 - val_loss: 4682.6866 - val_mean_absolute_error: 4682.6866
#
# Epoch 00452: val_loss did not improve from 3850.32151
# Epoch 453/500
# 585/585 [==============================] - 0s 199us/step - loss: 3032.0228 - mean_absolute_error: 3032.0228 - val_loss: 4691.7889 - val_mean_absolute_error: 4691.7889
#
# Epoch 00453: val_loss did not improve from 3850.32151
# Epoch 454/500
# 585/585 [==============================] - 0s 176us/step - loss: 3086.6565 - mean_absolute_error: 3086.6565 - val_loss: 4377.8822 - val_mean_absolute_error: 4377.8822
#
# Epoch 00454: val_loss did not improve from 3850.32151
# Epoch 455/500
# 585/585 [==============================] - 0s 186us/step - loss: 3069.6841 - mean_absolute_error: 3069.6841 - val_loss: 4752.4727 - val_mean_absolute_error: 4752.4727
#
# Epoch 00455: val_loss did not improve from 3850.32151
# Epoch 456/500
# 585/585 [==============================] - 0s 184us/step - loss: 3038.1287 - mean_absolute_error: 3038.1287 - val_loss: 4600.4977 - val_mean_absolute_error: 4600.4977
#
# Epoch 00456: val_loss did not improve from 3850.32151
# Epoch 457/500
# 585/585 [==============================] - 0s 200us/step - loss: 3009.9956 - mean_absolute_error: 3009.9956 - val_loss: 5272.4284 - val_mean_absolute_error: 5272.4284
#
# Epoch 00457: val_loss did not improve from 3850.32151
# Epoch 458/500
# 585/585 [==============================] - 0s 203us/step - loss: 3016.9397 - mean_absolute_error: 3016.9397 - val_loss: 4971.9192 - val_mean_absolute_error: 4971.9192
#
# Epoch 00458: val_loss did not improve from 3850.32151
# Epoch 459/500
# 585/585 [==============================] - 0s 166us/step - loss: 3029.6203 - mean_absolute_error: 3029.6203 - val_loss: 4188.3758 - val_mean_absolute_error: 4188.3758
#
# Epoch 00459: val_loss did not improve from 3850.32151
# Epoch 460/500
# 585/585 [==============================] - 0s 167us/step - loss: 3028.6283 - mean_absolute_error: 3028.6283 - val_loss: 4888.5846 - val_mean_absolute_error: 4888.5846
#
# Epoch 00460: val_loss did not improve from 3850.32151
# Epoch 461/500
# 585/585 [==============================] - 0s 167us/step - loss: 3081.7840 - mean_absolute_error: 3081.7840 - val_loss: 5014.6150 - val_mean_absolute_error: 5014.6150
#
# Epoch 00461: val_loss did not improve from 3850.32151
# Epoch 462/500
# 585/585 [==============================] - 0s 177us/step - loss: 2985.0568 - mean_absolute_error: 2985.0568 - val_loss: 5377.9109 - val_mean_absolute_error: 5377.9109
#
# Epoch 00462: val_loss did not improve from 3850.32151
# Epoch 463/500
# 585/585 [==============================] - 0s 174us/step - loss: 3089.6005 - mean_absolute_error: 3089.6005 - val_loss: 5316.9695 - val_mean_absolute_error: 5316.9695
#
# Epoch 00463: val_loss did not improve from 3850.32151
# Epoch 464/500
# 585/585 [==============================] - 0s 176us/step - loss: 3005.0985 - mean_absolute_error: 3005.0985 - val_loss: 5699.1547 - val_mean_absolute_error: 5699.1547
#
# Epoch 00464: val_loss did not improve from 3850.32151
# Epoch 465/500
# 585/585 [==============================] - 0s 189us/step - loss: 3038.9993 - mean_absolute_error: 3038.9993 - val_loss: 5720.7532 - val_mean_absolute_error: 5720.7532
#
# Epoch 00465: val_loss did not improve from 3850.32151
# Epoch 466/500
# 585/585 [==============================] - 0s 237us/step - loss: 3092.1657 - mean_absolute_error: 3092.1657 - val_loss: 5882.3317 - val_mean_absolute_error: 5882.3317
#
# Epoch 00466: val_loss did not improve from 3850.32151
# Epoch 467/500
# 585/585 [==============================] - 0s 182us/step - loss: 3054.5548 - mean_absolute_error: 3054.5548 - val_loss: 4930.5283 - val_mean_absolute_error: 4930.5283
#
# Epoch 00467: val_loss did not improve from 3850.32151
# Epoch 468/500
# 585/585 [==============================] - 0s 184us/step - loss: 2988.4873 - mean_absolute_error: 2988.4873 - val_loss: 4741.9097 - val_mean_absolute_error: 4741.9097
#
# Epoch 00468: val_loss did not improve from 3850.32151
# Epoch 469/500
# 585/585 [==============================] - 0s 203us/step - loss: 3004.1100 - mean_absolute_error: 3004.1100 - val_loss: 4635.9947 - val_mean_absolute_error: 4635.9947
#
# Epoch 00469: val_loss did not improve from 3850.32151
# Epoch 470/500
# 585/585 [==============================] - 0s 189us/step - loss: 3016.8447 - mean_absolute_error: 3016.8447 - val_loss: 4930.7996 - val_mean_absolute_error: 4930.7996
#
# Epoch 00470: val_loss did not improve from 3850.32151
# Epoch 471/500
# 585/585 [==============================] - 0s 183us/step - loss: 3006.3033 - mean_absolute_error: 3006.3033 - val_loss: 4435.0536 - val_mean_absolute_error: 4435.0536
#
# Epoch 00471: val_loss did not improve from 3850.32151
# Epoch 472/500
# 585/585 [==============================] - 0s 178us/step - loss: 3018.5940 - mean_absolute_error: 3018.5940 - val_loss: 4635.4637 - val_mean_absolute_error: 4635.4637
#
# Epoch 00472: val_loss did not improve from 3850.32151
# Epoch 473/500
# 585/585 [==============================] - 0s 177us/step - loss: 2992.7764 - mean_absolute_error: 2992.7764 - val_loss: 5425.9348 - val_mean_absolute_error: 5425.9348
#
# Epoch 00473: val_loss did not improve from 3850.32151
# Epoch 474/500
# 585/585 [==============================] - 0s 208us/step - loss: 2981.3430 - mean_absolute_error: 2981.3430 - val_loss: 4548.9066 - val_mean_absolute_error: 4548.9066
#
# Epoch 00474: val_loss did not improve from 3850.32151
# Epoch 475/500
# 585/585 [==============================] - 0s 201us/step - loss: 3013.7328 - mean_absolute_error: 3013.7328 - val_loss: 4958.0293 - val_mean_absolute_error: 4958.0293
#
# Epoch 00475: val_loss did not improve from 3850.32151
# Epoch 476/500
# 585/585 [==============================] - 0s 179us/step - loss: 3069.1403 - mean_absolute_error: 3069.1403 - val_loss: 4870.8551 - val_mean_absolute_error: 4870.8551
#
# Epoch 00476: val_loss did not improve from 3850.32151
# Epoch 477/500
# 585/585 [==============================] - 0s 210us/step - loss: 3066.7122 - mean_absolute_error: 3066.7122 - val_loss: 4780.0770 - val_mean_absolute_error: 4780.0770
#
# Epoch 00477: val_loss did not improve from 3850.32151
# Epoch 478/500
# 585/585 [==============================] - 0s 186us/step - loss: 2991.3755 - mean_absolute_error: 2991.3755 - val_loss: 4130.9073 - val_mean_absolute_error: 4130.9073
#
# Epoch 00478: val_loss did not improve from 3850.32151
# Epoch 479/500
# 585/585 [==============================] - 0s 193us/step - loss: 3075.3017 - mean_absolute_error: 3075.3017 - val_loss: 4299.1426 - val_mean_absolute_error: 4299.1426
#
# Epoch 00479: val_loss did not improve from 3850.32151
# Epoch 480/500
# 585/585 [==============================] - 0s 178us/step - loss: 3019.0334 - mean_absolute_error: 3019.0334 - val_loss: 4344.7552 - val_mean_absolute_error: 4344.7552
#
# Epoch 00480: val_loss did not improve from 3850.32151
# Epoch 481/500
# 585/585 [==============================] - 0s 198us/step - loss: 3108.9472 - mean_absolute_error: 3108.9472 - val_loss: 5066.7390 - val_mean_absolute_error: 5066.7390
#
# Epoch 00481: val_loss did not improve from 3850.32151
# Epoch 482/500
# 585/585 [==============================] - 0s 182us/step - loss: 2997.9209 - mean_absolute_error: 2997.9209 - val_loss: 5006.7125 - val_mean_absolute_error: 5006.7125
#
# Epoch 00482: val_loss did not improve from 3850.32151
# Epoch 483/500
# 585/585 [==============================] - 0s 193us/step - loss: 3090.2649 - mean_absolute_error: 3090.2649 - val_loss: 4200.4510 - val_mean_absolute_error: 4200.4510
#
# Epoch 00483: val_loss did not improve from 3850.32151
# Epoch 484/500
# 585/585 [==============================] - 0s 173us/step - loss: 3040.3556 - mean_absolute_error: 3040.3556 - val_loss: 4380.8287 - val_mean_absolute_error: 4380.8287
#
# Epoch 00484: val_loss did not improve from 3850.32151
# Epoch 485/500
# 585/585 [==============================] - 0s 170us/step - loss: 3031.0554 - mean_absolute_error: 3031.0554 - val_loss: 4362.2971 - val_mean_absolute_error: 4362.2971
#
# Epoch 00485: val_loss did not improve from 3850.32151
# Epoch 486/500
# 585/585 [==============================] - 0s 202us/step - loss: 3022.5395 - mean_absolute_error: 3022.5395 - val_loss: 5000.8530 - val_mean_absolute_error: 5000.8530
#
# Epoch 00486: val_loss did not improve from 3850.32151
# Epoch 487/500
# 585/585 [==============================] - 0s 199us/step - loss: 2979.3219 - mean_absolute_error: 2979.3219 - val_loss: 5352.2885 - val_mean_absolute_error: 5352.2885
#
# Epoch 00487: val_loss did not improve from 3850.32151
# Epoch 488/500
# 585/585 [==============================] - 0s 193us/step - loss: 3065.9651 - mean_absolute_error: 3065.9651 - val_loss: 5227.0572 - val_mean_absolute_error: 5227.0572
#
# Epoch 00488: val_loss did not improve from 3850.32151
# Epoch 489/500
# 585/585 [==============================] - 0s 198us/step - loss: 2987.9091 - mean_absolute_error: 2987.9091 - val_loss: 4810.2426 - val_mean_absolute_error: 4810.2426
#
# Epoch 00489: val_loss did not improve from 3850.32151
# Epoch 490/500
# 585/585 [==============================] - 0s 203us/step - loss: 3027.8640 - mean_absolute_error: 3027.8640 - val_loss: 4339.5375 - val_mean_absolute_error: 4339.5375
#
# Epoch 00490: val_loss did not improve from 3850.32151
# Epoch 491/500
# 585/585 [==============================] - 0s 193us/step - loss: 2994.9740 - mean_absolute_error: 2994.9740 - val_loss: 4857.8787 - val_mean_absolute_error: 4857.8787
#
# Epoch 00491: val_loss did not improve from 3850.32151
# Epoch 492/500
# 585/585 [==============================] - 0s 228us/step - loss: 2952.7038 - mean_absolute_error: 2952.7038 - val_loss: 5079.4354 - val_mean_absolute_error: 5079.4354
#
# Epoch 00492: val_loss did not improve from 3850.32151
# Epoch 493/500
# 585/585 [==============================] - 0s 232us/step - loss: 3056.6980 - mean_absolute_error: 3056.6980 - val_loss: 5047.2567 - val_mean_absolute_error: 5047.2567
#
# Epoch 00493: val_loss did not improve from 3850.32151
# Epoch 494/500
# 585/585 [==============================] - 0s 194us/step - loss: 2960.0890 - mean_absolute_error: 2960.0890 - val_loss: 5060.1678 - val_mean_absolute_error: 5060.1678
#
# Epoch 00494: val_loss did not improve from 3850.32151
# Epoch 495/500
# 585/585 [==============================] - 0s 182us/step - loss: 2948.1601 - mean_absolute_error: 2948.1601 - val_loss: 5545.8317 - val_mean_absolute_error: 5545.8317
#
# Epoch 00495: val_loss did not improve from 3850.32151
# Epoch 496/500
# 585/585 [==============================] - 0s 193us/step - loss: 2996.6981 - mean_absolute_error: 2996.6981 - val_loss: 5249.5378 - val_mean_absolute_error: 5249.5378
#
# Epoch 00496: val_loss did not improve from 3850.32151
# Epoch 497/500
# 585/585 [==============================] - 0s 185us/step - loss: 2969.0679 - mean_absolute_error: 2969.0679 - val_loss: 5070.4596 - val_mean_absolute_error: 5070.4596
#
# Epoch 00497: val_loss did not improve from 3850.32151
# Epoch 498/500
# 585/585 [==============================] - 0s 195us/step - loss: 2954.4300 - mean_absolute_error: 2954.4300 - val_loss: 4435.2863 - val_mean_absolute_error: 4435.2863
#
# Epoch 00498: val_loss did not improve from 3850.32151
# Epoch 499/500
# 585/585 [==============================] - 0s 176us/step - loss: 2993.6499 - mean_absolute_error: 2993.6499 - val_loss: 4919.6535 - val_mean_absolute_error: 4919.6535
#
# Epoch 00499: val_loss did not improve from 3850.32151
# Epoch 500/500
# 585/585 [==============================] - 0s 196us/step - loss: 3149.8695 - mean_absolute_error: 3149.8695 - val_loss: 6053.0565 - val_mean_absolute_error: 6053.0565
#
# Epoch 00500: val_loss did not improve from 3850.32151

# %%
# 500번을 학습하여 나온 결과들중, 가장 좋은(마지막에 저장된) Weights파일을 가져온다.
# Load wights file of the best model :
# 파일은 이 코드랑 같은 폴더에 위치해있어야 작동
wights_file = '아이스크림date-Weights-394--3850.32151-cat02-vf05.hdf5'
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# Out:
# W0719 18:29:36.814241   208 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0719 18:29:36.815238   208 deprecation_wrapper.py:119] From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.

# %%
#2016~2018전체를 난수로 0.67:0.33 = 2:1
# train3 = combined.loc[:,'temp':]
# target3 = combined.loc[:,'qty']
# train_X, val_X, train_y, val_y = train_test_split(train3, target3, test_size = 0.33, random_state = 14)

# 2016~2017 : 훈련 / 2018 검증 2:1
# 1~732 / 732~1096
trainXy = Xy[:cut_line]
testXy = Xy[cut_line:]

# 독립변수들
train_X = trainXy.loc[:,'temp':]
# 정답(판매량)
train_y = trainXy.loc[:,'qty']

val_X = testXy.loc[:,'temp':]
val_y = testXy.loc[:,'qty']

print('여기서 점수란 R-square값을 의미한다.')
# RandomForest 회귀분석
RFmodel = RandomForestRegressor()
RFmodel.fit(train_X,train_y)
# Get the mean absolute error on the validation data
RFpredicted = RFmodel.predict(val_X)
MAE = mean_absolute_error(val_y , RFpredicted)
print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# print('Random forest validation MAE = ', MAE)
print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# XGBRegressor 회귀분석
XGBModel = XGBRegressor(objective='reg:squarederror')
XGBModel.fit(train_X,train_y , verbose=False)
# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# print('XGBoost validation MAE = ',MAE)
print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

linReg = LinearRegression().fit(train_X, train_y)
print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

columns_in_data = list(train_X.columns)
customF = formulaGen(target='qty',ind_features=columns_in_data)
olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )
print('검증세트점수 : {:.3f}'.format( r2_score(val_y, olsModel.predict(val_X))   ) )
# Out:
# 여기서 점수란 R-square값을 의미한다.
# Random forest을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.973
# 검증세트점수 : 0.813
# XGBoost을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.926
# 검증세트점수 : 0.835
# LinearRegression을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.751
# 검증세트점수 : 0.713
# RidgeRegression을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.742
# 검증세트점수 : 0.711
# LassoRegression을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.751
# 검증세트점수 : 0.713
# OLS을 이용한 아이스크림의 회귀분석 결과 :
# 훈련세트점수 : 0.751
# 검증세트점수 : 0.713

# %%
print(item, 'ols model')
# ind_features = 넣고 싶은 독립변수를 리스트로 넣어주면 알아서 formula생성해 준다.
# customF = formulaGen(target='qty',ind_features=['temp'])
# print(customF) qty ~ temp
# customF = formulaGen(target='qty',ind_features=['temp','cloud'])
# print(customF) # qty ~ temp + cloud
columns_in_data

# formulaGen은 단순 1차 다항식을 제조해준다.
# customF = formulaGen(target='qty',ind_features=columns_in_data)
customF = 'qty ~ temp + I((temp)**2) + cloud + 공기상태_0 + 공기상태_1'


olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()

print('사람이 직접 식을 때려 박았을때 검증세트 점수: {:.3f}'.format(r2_score(val_y, olsModel.predict(val_X))) )

print(olsModel.summary())
# Out:
# 아이스크림 ols model
# 사람이 직접 식을 때려 박았을때 검증세트 점수: 0.812
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    qty   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     803.5
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          5.07e-293
# Time:                        18:29:44   Log-Likelihood:                -7255.5
# No. Observations:                 732   AIC:                         1.452e+04
# Df Residuals:                     726   BIC:                         1.455e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       1.132e+04    506.212     22.353      0.000    1.03e+04    1.23e+04
# temp             120.2834     45.114      2.666      0.008      31.714     208.853
# I((temp) ** 2)    38.2637      1.744     21.937      0.000      34.839      41.688
# cloud           -333.6439     63.417     -5.261      0.000    -458.147    -209.141
# 공기상태_0         -6637.0081    624.069    -10.635      0.000   -7862.203   -5411.813
# 공기상태_1         -2237.5281    466.698     -4.794      0.000   -3153.767   -1321.289
# ==============================================================================
# Omnibus:                        9.132   Durbin-Watson:                   0.724
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               10.533
# Skew:                           0.181   Prob(JB):                      0.00516
# Kurtosis:                       3.463   Cond. No.                     1.76e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
#             '공기상태_0', '공기상태_1', '공기상태_2']
col_list = ['temp', 'cloud', 'wind', 'lgt_time', 'PM10', 'rain_or_not_o', 'snow_or_not_o',
            '공기상태']
combined = Xy.loc[:,'temp':]
target = Xy.loc[:,'qty']

# 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
predictions = NN_model.predict(combined)
# RandomForest 회귀분석 예측 qty생산
RFpredicted = RFmodel.predict(combined)
# XGBRegressor 회귀분석 예측 qty생산
XGBpredictions = XGBModel.predict(combined)
# linearRegression 회귀분석 예측 qty생산
linPred = linReg.predict(combined)
# Ridge 회귀분석 예측 qty생산
ridPred = ridge.predict(combined)
# Lasso 회귀분석 예측 qty생산
lassoPred = lasso.predict(combined)
# OLS 회귀분석 예측 qty생산
olsPred = olsModel.predict(combined)

result_df = pd.DataFrame()
result_df['date'] = gs_day_w['date']
result_df['qty'] = Xy.loc[:,'qty']

# print("keras 신경망 predictions",predictions.shape)
result_df['keras_qty'] = predictions

# print("randomforest 예상",RFpredicted.shape)
result_df['rf_qty'] = RFpredicted

# print("XGBpredictions",XGBpredictions.shape)
result_df['xgb_qty'] = XGBpredictions

# print("linearRegression 예상",RFpredicted.shape)
result_df['lin_qty'] = linPred

# print("Ridge 예상",RFpredicted.shape)
result_df['ridge_qty'] = ridPred

# print("Lasso 예상",RFpredicted.shape)
result_df['lasso_qty'] = lassoPred

# print("OLS 예상",RFpredicted.shape)
result_df['ols_qty'] = olsPred

# %%
# 예측률 계산
# https://yamalab.tistory.com/46
# RMSE (Root Mean Squared Error) : 
# OLS 추정에서 일반적인 표준 오차이다. 예측 대상의 scale(단위 크기)에 주의해야하는 단점이 있다. 
# MSE는 root를 수식에서 제외, SSE는 root와 분모를 제외한 수식으로, SE가 붙은 척도들은 거기서 거기인 척도들이라고 보면 된다.
# 다만 디테일한 사용법에 차이가 있을 뿐.

# MAPE (Mean Absolute Percentage Error) :

# 위 방법의 단점을 보완한 것이다. 
# At는 실제값, Ft는 예측값인데, 이를 At로 나누어서 오차를 절대적 크기로 보는것이 아닌 비율의 크기로 보고자 하는 것이 핵심이다.
# 이 방법은 At가 0에 가까울수록 비정상적인 값이 나온다는 단점이 있다.

# mre가 0에 가까울수록 좋은 모델
result_df['mape_keras'] = abs((result_df.qty - result_df.keras_qty) / result_df.qty )
result_df['mape_rf'] = abs((result_df.qty - result_df.rf_qty) / result_df.qty )
result_df['mape_xgb'] = abs((result_df.qty - result_df.xgb_qty) / result_df.qty )
result_df['mape_lin'] = abs((result_df.qty - result_df.lin_qty) / result_df.qty )
result_df['mape_ridge'] = abs((result_df.qty - result_df.ridge_qty) / result_df.qty )
result_df['mape_lasso'] = abs((result_df.qty - result_df.lasso_qty) / result_df.qty )
result_df['mape_ols'] = abs((result_df.qty - result_df.ols_qty) / result_df.qty )

print('Keras 인공 신경망 모델 MAPE \t: {:<.2f}'.format(result_df['mape_keras'].sum() / result_df.shape[0] ))
print('RandomForest 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_rf'].sum() / result_df.shape[0] ))
print('XGBoosting  모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_xgb'].sum() / result_df.shape[0] ))
print('Linear 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lin'].sum() / result_df.shape[0] ))
print('Ridge 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_ridge'].sum() / result_df.shape[0] ))
print('Lasso 모델 MAPE \t\t: {:<.2f}'.format(result_df['mape_lasso'].sum() / result_df.shape[0] ))
print('OLS 모델 MAPE \t\t\t: {:<.2f}'.format(result_df['mape_ols'].sum() / result_df.shape[0] ))
# Out:
# Keras 인공 신경망 모델 MAPE 	: 0.23
# RandomForest 모델 MAPE 		: 0.15
# XGBoosting  모델 MAPE 		: 0.20
# Linear 모델 MAPE 		: 0.38
# Ridge 모델 MAPE 		: 0.37
# Lasso 모델 MAPE 		: 0.38
# OLS 모델 MAPE 			: 0.27

# %%
# 독립변수 Xy의 col번호: 0=qty
# ['qty', 'temp', 'cloud', 'wind', 'lgt_time', 'rain_or_not','snow_or_not', 
#                                                   '공기상태_0', '공기상태_1', '공기상태_2']

# 숫자를 바꾸면 (1~9) : 각 날씨 변수에 다른 판매량 변화량을 보여준다.
# 예: n = 1 # 'temp' 온도변화량 vs 판매량
n=1
# alpha 값 0~1
alp = 0.8
# scatter plot 점 크기
dot_size = 10

matplotlib.rcParams['font.family'] = 'NanumGothicCoding'
plt.figure(figsize=(15.5,7))
plt.style.use('ggplot')
plt.title('%s - %s vs 판매량' % (item, Xy.columns[n]) )
plt.scatter(Xy.iloc[:,n],result_df.qty, label = '실 판매량', s=20, c='k')
plt.scatter(Xy.iloc[:,n],result_df.keras_qty, label = '케라스 신경망 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.rf_qty, label = 'RandomForest 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.xgb_qty, label = 'XGBoosting 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.lin_qty, label = '선형 예측', alpha=alp, s=dot_size)
# plt.scatter(Xy.iloc[:,n],result_df.ridge_qty, label = 'Ridge 예측', alpha=alp, s=dot_size)
plt.scatter(Xy.iloc[:,n],result_df.ols_qty, label = 'OLS 예측', alpha=alp, s=dot_size)

# X axis
plt.xlabel('{}'.format(Xy.columns[n]))

# y axis
plt.ylabel('판매량')

# 범례
plt.legend()
plt.show()

# %% [markdown]
# ## 실험 구간

# %%
# # 2016~2017 : 훈련 / 2018 검증 2:1
# # 1~106 / 106~156
# trainXy = gs_week_w.loc[:cut_line]
# testXy = gs_week_w.loc[cut_line:]
# train_X =pd.DataFrame(trainXy.loc[:,'temp'])
# train_y = trainXy.loc[:,'qty']
# val_X = pd.DataFrame(testXy.loc[:,'temp'])
# val_y = testXy.loc[:,'qty']



# print('여기서 점수란 R-square값을 의미한다.')
# # RandomForest 회귀분석
# RFmodel = RandomForestRegressor()
# RFmodel.fit(train_X,train_y)
# # Get the mean absolute error on the validation data
# RFpredicted = RFmodel.predict(val_X)
# MAE = mean_absolute_error(val_y , RFpredicted)
# print('Random forest을 이용한 %s의 회귀분석 결과 :'%item)
# # print('Random forest validation MAE = ', MAE)
# print('훈련세트점수 : {:.3f}'.format(RFmodel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(RFmodel.score(val_X, val_y)))

# # XGBRegressor 회귀분석
# XGBModel = XGBRegressor(objective='reg:squarederror')
# XGBModel.fit(train_X,train_y , verbose=False)
# # Get the mean absolute error on the validation data :
# XGBpredictions = XGBModel.predict(val_X)
# MAE = mean_absolute_error(val_y , XGBpredictions)
# print('XGBoost을 이용한 %s의 회귀분석 결과 :'%item)
# # print('XGBoost validation MAE = ',MAE)
# print('훈련세트점수 : {:.3f}'.format(XGBModel.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(XGBModel.score(val_X, val_y)))

# linReg = LinearRegression().fit(train_X, train_y)
# print('LinearRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(linReg.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(linReg.score(val_X, val_y)))

# ridge = Ridge(alpha=0.1, normalize=True, random_state=0, tol=0.001).fit(train_X, train_y)
# print('RidgeRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(ridge.score(train_X, train_y)))
# print('검증세트점수 : {:.3f}'.format(ridge.score(val_X, val_y)))

# lasso = Lasso(alpha=0.1, max_iter=1000).fit(train_X, train_y)
# print('LassoRegression을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(lasso.score(train_X, train_y)) )
# print('검증세트점수 : {:.3f}'.format(lasso.score(val_X, val_y)) )

# customF = formulaGen(target='qty',ind_features=['temp'])
# olsModel = sm.OLS.from_formula(customF, data=trainXy).fit()
# print('OLS을 이용한 %s의 회귀분석 결과 :'%item)
# print('훈련세트점수 : {:.3f}'.format(olsModel.rsquared) )

# combined = pd.DataFrame(gs_week_w.loc[:,'temp'])
# target = gs_week_w.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# # predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# result_df = pd.DataFrame()
# result_df['week'] = gs_week_w['week']
# result_df['qty'] = gs_week_w.loc[:,'qty']

# # print("keras 신경망 predictions",predictions.shape)
# # result_df['keras_qty'] = predictions

# # print("randomforest 예상",RFpredicted.shape)
# result_df['rf_qty'] = RFpredicted

# # print("XGBpredictions",XGBpredictions.shape)
# result_df['xgb_qty'] = XGBpredictions

# # print("linearRegression 예상",RFpredicted.shape)
# result_df['lin_qty'] = linPred

# # print("Ridge 예상",RFpredicted.shape)
# result_df['ridge_qty'] = ridPred

# # print("Lasso 예상",RFpredicted.shape)
# result_df['lasso_qty'] = lassoPred

# # print("OLS 예상",RFpredicted.shape)
# result_df['ols_qty'] = olsPred

# %% [markdown]
# # ============================================

# %%
# df_graph = result_df.loc[:,['week','qty','keras_qty','rf_qty','xgb_qty','lin_qty','ridge_qty','lasso_qty','ols_qty']]
# for_visual_col = ['week','temp','cloud','wind','lgt_time','snow','rain','PM10']
# df = pd.merge(df_graph, gs_week_w[for_visual_col], on='week', how='left')
# # df.head(1)

# %%
# 2016, 온도
# df_graph = df.loc[df.week <= 53]
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph.temp,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.scatter(df_graph.temp,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.scatter(df_graph.temp,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.scatter(df_graph.temp,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.scatter(df_graph.temp,df_graph.lin_qty, ls='-', label='linear예측')
# plt.scatter(df_graph.temp,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.scatter(df_graph.temp,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.scatter(df_graph.temp,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# qty_columns = list(df_graph.columns)[1:9]
# weather_columns = list(df_graph.columns)[9:]
# print(qty_columns)
# print(weather_columns)

# %%
# x_temp = pd.DataFrame()
# # x_temp['temp'] = list(range(-10,35,1))
# x_temp['temp'] = np.arange(-9,35,0.5)
# combined = x_temp
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.7)
# plt.plot(x_temp, RFpredicted, label = 'rf')
# plt.plot(x_temp, XGBpredictions, label = 'xgb')
# plt.plot(x_temp, linPred, label = 'line')
# plt.plot(x_temp, ridPred, label = 'ridge')
# plt.plot(x_temp, lassoPred, label = 'lasso')
# plt.plot(x_temp, olsPred, label = 'ols')
# plt.plot()
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 실험

# %%
# intercept_lin = linReg.intercept_
# coef_line = linReg.coef_
# # list_col
# linePredict = list()
# x_temp = list(range(-10,38,1))
# for temperature in x_temp:
#     linePredict.append(intercept_lin + coef_line[0]*temperature)

    
# # 2016~2018, 일조시간
# df_graph = df.copy()
# plt.figure(figsize=(15.5, 10))
# plt.scatter(df_graph[weather_columns[0]],df_graph['qty'], ls='-', color='k',label='실 판매량', s=100, alpha=0.3)
# # for q_name in qty_columns:
# #     plt.plot(df_graph[weather_columns[0]],df_graph[q_name], ls='-', label=q_name)
# #     plt.scatter(df_graph.lgt_time,df_graph[q_name], ls='-', label='실제', color='green', alpha=0.5, lw=8)
# #     plt.scatter(df_graph.lgt_time,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# #     plt.scatter(df_graph.lgt_time,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# #     plt.scatter(df_graph.lgt_time,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# #     plt.scatter(df_graph.lgt_time,df_graph.lin_qty, ls='-', label='linear예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.ridge_qty, ls='-', label='ridge예측')
# #     plt.scatter(df_graph.lgt_time,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# #     plt.scatter(df_graph.lgt_time,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.plot(x_temp, linePredict, 'r--', label='linear회귀, 온도만')

# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.xlabel(weather_columns[0])
# plt.ylabel('판매량 (단위 : 1개)')
# plt.show()

# %% [markdown]
# # 시간의 경과에 따른 예측량 비교

# %%
# # 2016
# df_graph = result_df.loc[result_df.week <=53]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.legend()
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016',item ))
# plt.show()

# %%
# # 2017
# df_graph = result_df.loc[(result_df.week >=53)&(result_df.week <=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2017',item ))
# plt.legend()
# plt.show()

# %%
# # 2018
# df_graph = result_df.loc[(result_df.week >=105)]
# plt.figure(figsize=(15.5, 10))
# plt.plot(df_graph.week,df_graph.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(df_graph.week,df_graph.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(df_graph.week,df_graph.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(df_graph.week,df_graph.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2018',item ))
# plt.legend()
# plt.show()

# %%
# # 2016~2018
# plt.figure(figsize=(15.5, 10))
# plt.plot(result_df.week,result_df.qty, ls='-', label='실제', color='green', alpha=0.5, lw=8)
# plt.plot(result_df.week,result_df.keras_qty, ls='-', label='keras예측', color='r')
# plt.plot(result_df.week,result_df.rf_qty, ls='-', label='rf예측', color='cyan')
# plt.plot(result_df.week,result_df.xgb_qty, ls='-', label='xgb예측', color='b')
# plt.plot(df_graph.week,df_graph.lin_qty, ls='-', label='linear예측')
# plt.plot(df_graph.week,df_graph.ridge_qty, ls='-', label='ridge예측')
# plt.plot(df_graph.week,df_graph.lasso_qty, ls='-', label='lasso예측',color='yellow')
# plt.plot(df_graph.week,df_graph.ols_qty, ls='-', label='ols예측', color='violet')
# plt.title('{}년도 {} 판매량 실제/예측'.format( '2016~2018',item ))
# plt.legend()
# plt.show()

# %%
# def r2_score(v_true, v_pred):
#     ssr = np.sum(np.square(v_pred - np.mean(v_true)))
#     sst = np.sum(np.square(v_true - np.mean(v_true)))
#     return ( ssr / sst)

# %%
# checked_for = '2016~2017'
# combined = aaaaa.loc[:106,'temp':'PM10']
# target = aaaaa.loc[:106,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)
# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2018'
# combined = aaaaa.loc[106:,'temp':'PM10']
# target = aaaaa.loc[106:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# checked_for = '2016~2018'
# combined = aaaaa.loc[:,'temp':'PM10']
# target = aaaaa.loc[:,'qty']

# # 가장 좋다고 판명된 설정을 이용하여, 예측qty생산
# predictions = NN_model.predict(combined)
# # RandomForest 회귀분석 예측 qty생산
# RFpredicted = RFmodel.predict(combined)
# # XGBRegressor 회귀분석 예측 qty생산
# XGBpredictions = XGBModel.predict(combined)
# # linearRegression 회귀분석 예측 qty생산
# linPred = linReg.predict(combined)
# # Ridge 회귀분석 예측 qty생산
# ridPred = ridge.predict(combined)
# # Lasso 회귀분석 예측 qty생산
# lassoPred = lasso.predict(combined)
# # OLS 회귀분석 예측 qty생산
# olsPred = olsModel.predict(combined)

# qty = target

# print(checked_for)
# print('RF R2값  \t: ','{:<.5f}'.format(r2_score(qty, RFpredicted)) )
# print('XGB R2값  \t: ','{:<.5f}'.format(r2_score(qty, XGBpredictions)) )
# print('KerasNN R2값\t: ','{:<.5f}'.format(r2_score(qty,predictions )) )
# print('LinReg R2값\t: ','{:<.5f}'.format(r2_score(qty, linPred)) )
# print('Ridge R2값  \t: ','{:<.5f}'.format(r2_score(qty, ridPred)) )
# print('Lasso R2값\t: ','{:<.5f}'.format(r2_score(qty, lassoPred )) )
# print('OLS R2값\t: ','{:<.5f}'.format(r2_score(qty, olsPred )) )

# %%
# path = 'D:/project/contest/data/result/'
# result_df.to_csv(path+item+'_'+grouped_by+'_predict(lowVIF07).csv', encoding='utf-8', index=False)
